# %% [markdown]
# ## Table of Contents <a class="anchor" id="top"></a>
# * [Data Preparation](#Data Prep)
# * [Entity Resolution](#Entity)
# * [Relation Extraction](#Relation)
# * [Query System](#Query)

# %% [markdown]
# ## Data Prep <a class="anchor" id="Data Prep"></a>
# [[back to top]](#top)

# %%
# %load_ext autoreload
# %autoreload 2

#standard library imports
import re
import nltk
import numpy as np
import pandas as pd
import os
from collections import Counter

#modeling functions & utilities
from pronounResolution import pronResolution_base, pronResolution_nnMod, pronResolution_nn, pronEval
from relationExtract import simpleRE, REEval, getRelations, extract_relation_categories
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
files = [x for x in os.listdir('prep_scripts') if '_gapi' in x]
df = pd.read_csv('prep_scripts/' + files[1])[['speaker', 'dialogue', 'sentences', 'sentiment', 'entities', 'tokens']]
df['tokens'] = df['tokens'].apply(lambda x: eval(x))
df['sentiment'] = df['sentiment'].apply(lambda x: eval(x))
df['speaker'] = df['speaker'].apply(lambda x: x.strip())
df['entities'] = df['entities'].apply(lambda x: eval(x))
df.head()
# Out:
#         speaker                                           dialogue  \
# 0     Announcer  [first lines; announcement over speaker] Repor...
# 1      narrator  the Avengers are in the process of infiltratin...
# 2    Tony Stark                                              Shit!
# 3  Steve Rogers   Language! JARVIS, what's the view from upstairs?
# 4        JARVIS  The central building is protected by some kind...
#
#                                            sentences  \
# 0  [{'content': u'[first lines; announcement over...
# 1  [{'content': u'the Avengers are in the process...
# 2  [{'content': u'Shit!', 'begin': 0, 'score': -0...
# 3  [{'content': u'Language!', 'begin': 0, 'score'...
# 4  [{'content': u'The central building is protect...
#
#                            sentiment  \
# 0  {'score': -0.2, 'magnitude': 1.6}
# 1   {'score': 0.1, 'magnitude': 0.1}
# 2  {'score': -0.6, 'magnitude': 0.6}
# 3     {'score': 0, 'magnitude': 0.1}
# 4   {'score': 0.7, 'magnitude': 1.5}
#
#                                             entities  \
# 0  [{'name': 'lines', 'salience': 0.35250518, 'me...
# 1  [{'name': 'Avengers', 'salience': 0.47595453, ...
# 2                                                 []
# 3  [{'name': 'Language', 'salience': 0.7599061, '...
# 4  [{'name': 'building', 'salience': 0.47500995, ...
#
#                                               tokens
# 0  [{'pos': 'PUNCT', 'content': '[', 'begin': 0, ...
# 1  [{'pos': 'DET', 'content': 'the', 'begin': 0, ...
# 2  [{'pos': 'X', 'content': 'Shit', 'begin': 0, '...
# 3  [{'pos': 'NOUN', 'content': 'Language', 'begin...
# 4  [{'pos': 'DET', 'content': 'The', 'begin': 0, ...

# %%
cList = list(df.speaker.unique())
cCount = Counter(df.speaker)
df['total_sent'] = df['sentiment'].apply(lambda x: x['score'] * x['magnitude'])
cDict = dict(df.groupby('speaker').total_sent.sum())

# number of pronouns for each line
df['num_pron'] = df['tokens'].apply(lambda x: sum([int(t['pos'] == 'PRON') for t in x]))

# total sentiment score for each line
df['total_sent'] = df['sentiment'].apply(lambda x: x['score'] * x['magnitude'])

#set nearby speakers
charRange = 10
nearbyList = np.dstack((df.shift(i).speaker.values for i in range(-charRange, charRange+1)))[0]
df['nearbyChars'] = None
for i, nearbyChars in enumerate(nearbyList):
    df.set_value(i, 'nearbyChars', nearbyChars)

df.head()
# Out:
#         speaker                                           dialogue  \
# 0     Announcer  [first lines; announcement over speaker] Repor...
# 1      narrator  the Avengers are in the process of infiltratin...
# 2    Tony Stark                                              Shit!
# 3  Steve Rogers   Language! JARVIS, what's the view from upstairs?
# 4        JARVIS  The central building is protected by some kind...
#
#                                            sentences  \
# 0  [{'content': u'[first lines; announcement over...
# 1  [{'content': u'the Avengers are in the process...
# 2  [{'content': u'Shit!', 'begin': 0, 'score': -0...
# 3  [{'content': u'Language!', 'begin': 0, 'score'...
# 4  [{'content': u'The central building is protect...
#
#                            sentiment  \
# 0  {'score': -0.2, 'magnitude': 1.6}
# 1   {'score': 0.1, 'magnitude': 0.1}
# 2  {'score': -0.6, 'magnitude': 0.6}
# 3     {'score': 0, 'magnitude': 0.1}
# 4   {'score': 0.7, 'magnitude': 1.5}
#
#                                             entities  \
# 0  [{'name': 'lines', 'salience': 0.35250518, 'me...
# 1  [{'name': 'Avengers', 'salience': 0.47595453, ...
# 2                                                 []
# 3  [{'name': 'Language', 'salience': 0.7599061, '...
# 4  [{'name': 'building', 'salience': 0.47500995, ...
#
#                                               tokens  total_sent  num_pron  \
# 0  [{'pos': 'PUNCT', 'content': '[', 'begin': 0, ...       -0.32         3
# 1  [{'pos': 'DET', 'content': 'the', 'begin': 0, ...        0.01         0
# 2  [{'pos': 'X', 'content': 'Shit', 'begin': 0, '...       -0.36         0
# 3  [{'pos': 'NOUN', 'content': 'Language', 'begin...        0.00         1
# 4  [{'pos': 'DET', 'content': 'The', 'begin': 0, ...        1.05         1
#
#                                          nearbyChars
# 0  [Tony Stark, Clint Barton, narrator, Natasha R...
# 1  [Steve Rogers, Tony Stark, Clint Barton, narra...
# 2  [narrator, Steve Rogers, Tony Stark, Clint Bar...
# 3  [Steve Rogers, narrator, Steve Rogers, Tony St...
# 4  [Strucker, Steve Rogers, narrator, Steve Roger...

# %% [markdown]
# ## Task 1. Entity Resolution <a class="anchor" id="Entity"></a>
# [[back to top]](#top)

# %%
df.apply(lambda x:pronResolution_nnMod(cCount, x, absolute=False), axis=1)
df.head(20)
# Out:
#              speaker                                           dialogue  \
# 0          Announcer  [first lines; announcement over speaker] Repor...
# 1           narrator  the Avengers are in the process of infiltratin...
# 2         Tony Stark                                              Shit!
# 3       Steve Rogers   Language! JARVIS, what's the view from upstairs?
# 4             JARVIS  The central building is protected by some kind...
# 5               Thor  Loki's scepter must be here. Strucker couldn't...
# 6           narrator                   Natasha knocks out some soldiers
# 7   Natasha Romanoff       At long last is lasting a little long, boys.
# 8           narrator                      as some soldiers shoot at him
# 9       Clint Barton     Yeah. I think we lost the element of surprise.
# 10        Tony Stark  Wait a second. No one else is going to deal wi...
# 11      Steve Rogers                                            I know.
# 12          narrator  Steve throws his bike at some soldiers driving...
# 13      Steve Rogers  <span style="line-height:21px;">It just slippe...
# 14          Strucker                      Who gave the order to attack?
# 15  Fortress Soldier  Herr Strucker, it's the Avengers. They landed ...
# 16          Strucker  [to List] They have to be after the scepter. [...
# 17  Fortress Soldier                             They are the Avengers!
# 18          Strucker                      Deploy the rest of the tanks.
# 19  Fortress Soldier                                          Yes, sir.
#
#                                             sentences  \
# 0   [{'content': u'[first lines; announcement over...
# 1   [{'content': u'the Avengers are in the process...
# 2   [{'content': u'Shit!', 'begin': 0, 'score': -0...
# 3   [{'content': u'Language!', 'begin': 0, 'score'...
# 4   [{'content': u'The central building is protect...
# 5   [{'content': u"Loki's scepter must be here.", ...
# 6   [{'content': u'Natasha knocks out some soldier...
# 7   [{'content': u'At long last is lasting a littl...
# 8   [{'content': u'as some soldiers shoot at him',...
# 9   [{'content': u'Yeah.', 'begin': 0, 'score': 0....
# 10  [{'content': u'Wait a second.', 'begin': 0, 's...
# 11  [{'content': u'I know.', 'begin': 0, 'score': ...
# 12  [{'content': u'Steve throws his bike at some s...
# 13  [{'content': u'<span style="line-height:21px;"...
# 14  [{'content': u'Who gave the order to attack?',...
# 15  [{'content': u"Herr Strucker, it's the Avenger...
# 16  [{'content': u'[to List] They have to be after...
# 17  [{'content': u'They are the Avengers!', 'begin...
# 18  [{'content': u'Deploy the rest of the tanks.',...
# 19  [{'content': u'Yes, sir.', 'begin': 0, 'score'...
#
#                             sentiment  \
# 0   {'score': -0.2, 'magnitude': 1.6}
# 1    {'score': 0.1, 'magnitude': 0.1}
# 2   {'score': -0.6, 'magnitude': 0.6}
# 3      {'score': 0, 'magnitude': 0.1}
# 4    {'score': 0.7, 'magnitude': 1.5}
# 5    {'score': 0.1, 'magnitude': 0.6}
# 6    {'score': 0.2, 'magnitude': 0.2}
# 7    {'score': 0.4, 'magnitude': 0.4}
# 8    {'score': 0.2, 'magnitude': 0.2}
# 9    {'score': 0.1, 'magnitude': 0.3}
# 10  {'score': -0.4, 'magnitude': 0.8}
# 11   {'score': 0.2, 'magnitude': 0.2}
# 12       {'score': 0, 'magnitude': 0}
# 13       {'score': 0, 'magnitude': 0}
# 14  {'score': -0.3, 'magnitude': 0.3}
# 15   {'score': 0.3, 'magnitude': 0.7}
# 16   {'score': 0.1, 'magnitude': 0.1}
# 17       {'score': 0, 'magnitude': 0}
# 18   {'score': 0.2, 'magnitude': 0.2}
# 19   {'score': 0.4, 'magnitude': 0.4}
#
#                                              entities  \
# 0   [{'name': 'lines', 'salience': 0.35250518, 'me...
# 1   [{'name': 'Avengers', 'salience': 0.47595453, ...
# 2                                                  []
# 3   [{'name': 'Language', 'salience': 0.7599061, '...
# 4   [{'name': 'building', 'salience': 0.47500995, ...
# 5   [{'name': 'scepter', 'salience': 0.54812527, '...
# 6   [{'name': 'Natasha Romanoff', 'salience': 0.76...
# 7   [{'name': 'boys', 'salience': 1, 'meta': {}, '...
# 8   [{'name': 'Soldiers', 'salience': 1, 'meta': {...
# 9   [{'name': 'surprise', 'salience': 0.64406866, ...
# 10  [{'name': 'second', 'salience': 0.62507236, 'm...
# 11  [{'name': 'Steve Rogers', 'mentions': ['I'], '...
# 12  [{'name': 'Steve Rogers', 'salience': 0.650747...
# 13  [{'name': 'line-height', 'salience': 0.4376441...
# 14  [{'name': 'order', 'salience': 1, 'meta': {}, ...
# 15  [{'name': 'Herr Strucker', 'salience': 0.70942...
# 16  [{'name': 'List', 'salience': 0.6853893, 'meta...
# 17  [{'name': 'Avengers', 'salience': 1, 'meta': {...
# 18  [{'name': 'rest', 'salience': 0.72139335, 'met...
# 19  [{'name': 'sir', 'salience': 1, 'meta': {}, 't...
#
#                                                tokens  total_sent  num_pron  \
# 0   [{'pos': 'PUNCT', 'content': '[', 'begin': 0, ...       -0.32         3
# 1   [{'pos': 'DET', 'content': 'the', 'begin': 0, ...        0.01         0
# 2   [{'pos': 'X', 'content': 'Shit', 'begin': 0, '...       -0.36         0
# 3   [{'pos': 'NOUN', 'content': 'Language', 'begin...        0.00         1
# 4   [{'pos': 'DET', 'content': 'The', 'begin': 0, ...        1.05         1
# 5   [{'pos': 'NOUN', 'content': 'Loki', 'begin': 0...        0.06         1
# 6   [{'pos': 'NOUN', 'content': 'Natasha', 'begin'...        0.04         0
# 7   [{'pos': 'ADP', 'content': 'At', 'begin': 0, '...        0.16         0
# 8   [{'pos': 'ADP', 'content': 'as', 'begin': 0, '...        0.04         1
# 9   [{'pos': 'X', 'content': 'Yeah', 'begin': 0, '...        0.03         2
# 10  [{'pos': 'VERB', 'content': 'Wait', 'begin': 0...       -0.32         0
# 11  [{'pos': 'PRON', 'content': 'I', 'begin': 0, '...        0.04         1
# 12  [{'pos': 'NOUN', 'content': 'Steve', 'begin': ...        0.00         2
# 13  [{'pos': 'PUNCT', 'content': '<', 'begin': 0, ...        0.00         1
# 14  [{'pos': 'PRON', 'content': 'Who', 'begin': 0,...       -0.09         1
# 15  [{'pos': 'NOUN', 'content': 'Herr', 'begin': 0...        0.21         2
# 16  [{'pos': 'PUNCT', 'content': '[', 'begin': 0, ...        0.01         3
# 17  [{'pos': 'PRON', 'content': 'They', 'begin': 0...        0.00         1
# 18  [{'pos': 'VERB', 'content': 'Deploy', 'begin':...        0.04         0
# 19  [{'pos': 'X', 'content': 'Yes', 'begin': 0, 'i...        0.16         0
#
#                                           nearbyChars
# 0   [Tony Stark, Clint Barton, narrator, Natasha R...
# 1   [Steve Rogers, Tony Stark, Clint Barton, narra...
# 2   [narrator, Steve Rogers, Tony Stark, Clint Bar...
# 3   [Steve Rogers, narrator, Steve Rogers, Tony St...
# 4   [Strucker, Steve Rogers, narrator, Steve Roger...
# 5   [Fortress Soldier, Strucker, Steve Rogers, nar...
# 6   [Strucker, Fortress Soldier, Strucker, Steve R...
# 7   [Fortress Soldier, Strucker, Fortress Soldier,...
# 8   [Strucker, Fortress Soldier, Strucker, Fortres...
# 9   [Fortress Soldier, Strucker, Fortress Soldier,...
# 10  [Strucker, Fortress Soldier, Strucker, Fortres...
# 11  [Dr. List, Strucker, Fortress Soldier, Strucke...
# 12  [Strucker, Dr. List, Strucker, Fortress Soldie...
# 13  [Dr. List, Strucker, Dr. List, Strucker, Fortr...
# 14  [Strucker, Dr. List, Strucker, Dr. List, Struc...
# 15  [narrator, Strucker, Dr. List, Strucker, Dr. L...
# 16  [Jarvis, narrator, Strucker, Dr. List, Strucke...
# 17  [Tony Stark, Jarvis, narrator, Strucker, Dr. L...
# 18  [Iron Legion, Tony Stark, Jarvis, narrator, St...
# 19  [narrator, Iron Legion, Tony Stark, Jarvis, na...

# %%
pronEval([df, df], numExamples=2)
# Out:
# ******** line 766 ********
# 764. Kurt:
# Oh, no.
#
# 765. narrator:
# back with Scott and the ants
#
# => 766. Scott Lang:
# => I'm employing the bullet ants. Hapanera-clamda-mana-merna. I don't remember what it's called but I feel bad for this guy. [using the ants Scott takes down one of the security guards with Luis also punching him]
#
# 767. Luis:
# See, that's what I'm talkin’ bout. That's what I call it, an unfortunate casualty, in a very serious operation, you know? [Hope then comes along and enters the room and places the signal decoy]
#
# 768. Kurt:
# Signal decoy in place. Mean pretty lady did good, Scott.
#
# ******** test model 1: line 766 ********
# 6 pronouns resolved
# 1. I => ['Peggy Carter']
# 2. I => ['Pym Tech Employee']
# 3. what => ['Hope van Dyne']
# 4. it => ['Cop on Speaker']
# 5. I => ['Hideous Rabbit']
# 6. him => ['Pym Tech Employee']
#
# how many are correctly identified? 2
#
# ******** line 766 ********
# 764. Kurt:
# Oh, no.
#
# 765. narrator:
# back with Scott and the ants
#
# => 766. Scott Lang:
# => I'm employing the bullet ants. Hapanera-clamda-mana-merna. I don't remember what it's called but I feel bad for this guy. [using the ants Scott takes down one of the security guards with Luis also punching him]
#
# 767. Luis:
# See, that's what I'm talkin’ bout. That's what I call it, an unfortunate casualty, in a very serious operation, you know? [Hope then comes along and enters the room and places the signal decoy]
#
# 768. Kurt:
# Signal decoy in place. Mean pretty lady did good, Scott.
#
# ******** test model 2: line 766 ********
# 6 pronouns resolved
# 1. I => ['Peggy Carter']
# 2. I => ['Pym Tech Employee']
# 3. what => ['Hope van Dyne']
# 4. it => ['Cop on Speaker']
# 5. I => ['Hideous Rabbit']
# 6. him => ['Pym Tech Employee']
#
# how many are correctly identified? 2
#
# ******** line 516 ********
# 514. narrator:
# Pym finds Scott playing around with the suit's regulator
#
# 515. Scott Lang:
# You know, I think this regulator is holding me back.
#
# => 516. Dr. Hank Pym:
# => Do not screw with the regulator. If that regulator is compromised you would go sub-atomic.
#
# 517. Scott Lang:
# What does that mean?
#
# 518. Dr. Hank Pym:
# It means that you would enter a quantum realm.
#
# ******** test model 1: line 516 ********
# 1 pronouns resolved
# 1. you => ['Luis']
#
# how many are correctly identified? 1
#
# ******** line 516 ********
# 514. narrator:
# Pym finds Scott playing around with the suit's regulator
#
# 515. Scott Lang:
# You know, I think this regulator is holding me back.
#
# => 516. Dr. Hank Pym:
# => Do not screw with the regulator. If that regulator is compromised you would go sub-atomic.
#
# 517. Scott Lang:
# What does that mean?
#
# 518. Dr. Hank Pym:
# It means that you would enter a quantum realm.
#
# ******** test model 2: line 516 ********
# 1 pronouns resolved
# 1. you => ['Luis']
#
# how many are correctly identified? 0
#
# ******** test results ********
# model 1: precision = 0.43 (3/7 correct)
# model 2: precision = 0.29 (2/7 correct)

# %% [markdown]
# ## Task 2. Relation Extraction <a class="anchor" id="Relation"></a>
# [[back to top]](#top)

# %%
df.apply(lambda x: pronResolution_nnMod(cCount, x), axis=1)
df.head()
# Out:
#         speaker                                           dialogue  \
# 0     Announcer  [first lines; announcement over speaker] Repor...
# 1      narrator  the Avengers are in the process of infiltratin...
# 2    Tony Stark                                              Shit!
# 3  Steve Rogers   Language! JARVIS, what's the view from upstairs?
# 4        JARVIS  The central building is protected by some kind...
#
#                                            sentences  \
# 0  [{'content': u'[first lines; announcement over...
# 1  [{'content': u'the Avengers are in the process...
# 2  [{'content': u'Shit!', 'begin': 0, 'score': -0...
# 3  [{'content': u'Language!', 'begin': 0, 'score'...
# 4  [{'content': u'The central building is protect...
#
#                            sentiment  \
# 0  {'magnitude': 1.6, 'score': -0.2}
# 1   {'magnitude': 0.1, 'score': 0.1}
# 2  {'magnitude': 0.6, 'score': -0.6}
# 3     {'magnitude': 0.1, 'score': 0}
# 4   {'magnitude': 1.5, 'score': 0.7}
#
#                                             entities  \
# 0  [{'salience': 0.35250518, 'type': 'OTHER', 'me...
# 1  [{'salience': 0.47595453, 'type': 'PERSON', 'm...
# 2                                                 []
# 3  [{'salience': 0.7599061, 'type': 'OTHER', 'men...
# 4  [{'salience': 0.47500995, 'type': 'LOCATION', ...
#
#                                               tokens  total_sent  num_pron  \
# 0  [{'content': '[', 'pos': 'PUNCT', 'label': 'P'...       -0.32         3
# 1  [{'content': 'the', 'pos': 'DET', 'label': 'DE...        0.01         0
# 2  [{'content': 'Shit', 'pos': 'X', 'label': 'ROO...       -0.36         0
# 3  [{'content': 'Language', 'pos': 'NOUN', 'label...        0.00         1
# 4  [{'content': 'The', 'pos': 'DET', 'label': 'DE...        1.05         1
#
#                                          nearbyChars
# 0  [Tony Stark, Clint Barton, narrator, Natasha R...
# 1  [Steve Rogers, Tony Stark, Clint Barton, narra...
# 2  [narrator, Steve Rogers, Tony Stark, Clint Bar...
# 3  [Steve Rogers, narrator, Steve Rogers, Tony St...
# 4  [Strucker, Steve Rogers, narrator, Steve Roger...

# %%
df['relations'] = df.apply(lambda x:extract_relation_categories(cList, x), axis=1)
df.head()
# Out:
# 15
# {'pos': 'PRON', 'content': 'They', 'begin': 34, 'index': 9, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Tony Stark', 'Steve Rogers', 'Bruce Banner']}
# 16
# {'pos': 'PRON', 'content': 'They', 'begin': 10, 'index': 5, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Ultron', 'Vision', 'Clint Barton']}
# 16
# {'pos': 'PRON', 'content': 'them', 'begin': 74, 'index': 18, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Ultron', 'Vision', 'Clint Barton']}
# 17
# {'pos': 'PRON', 'content': 'They', 'begin': 0, 'index': 1, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Steve Rogers', 'Strucker', 'Wanda Maximoff']}
# 20
# {'pos': 'PRON', 'content': 'them', 'begin': 50, 'index': 12, 'lemma': 'them', 'label': 'NSUBJ', 'char': ['Steve Rogers', 'Ulysses Klaue', 'Tony Stark']}
# 21
# {'pos': 'PRON', 'content': 'them', 'begin': 16, 'index': 3, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Peggy Carter', 'Ultron']}
# 23
# {'pos': 'PRON', 'content': 'they', 'begin': 10, 'index': 4, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Pietro Maximoff', 'Wanda Maximoff', 'Vision']}
# 24
# {'pos': 'PRON', 'content': 'them', 'begin': 16, 'index': 3, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Thor', 'Steve Rogers', 'Bruce Banner']}
# 32
# {'pos': 'PRON', 'content': 'them', 'begin': 83, 'index': 17, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Steve Rogers', 'Tony Stark', 'Bruce Banner']}
# 34
# {'pos': 'PRON', 'content': 'they', 'begin': 108, 'index': 27, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Nick Fury', 'Bruce Banner']}
# 36
# {'pos': 'PRON', 'content': 'They', 'begin': 0, 'index': 1, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Stan Lee', 'Sam Wilson']}
# 61
# {'pos': 'PRON', 'content': 'they', 'begin': 74, 'index': 16, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Clint Barton', 'Natasha Romanoff', 'Steve Rogers']}
# 62
# {'pos': 'PRON', 'content': 'they', 'begin': 6, 'index': 3, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['FRIDAY', 'Specialist Cameron Klein']}
# 112
# {'pos': 'PRON', 'content': 'them', 'begin': 21, 'index': 7, 'lemma': 'them', 'label': 'NSUBJ', 'char': ['Soldiers', 'Tony Stark']}
# 152
# {'pos': 'PRON', 'content': 'they', 'begin': 6, 'index': 4, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Erik Selvig', 'Tony Stark']}
# 153
# {'pos': 'PRON', 'content': 'they', 'begin': 18, 'index': 5, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Tony Stark', 'Ultron', 'Steve Rogers', 'Dr. Helen Cho']}
# 154
# {'pos': 'PRON', 'content': 'them', 'begin': 71, 'index': 12, 'lemma': 'them', 'label': 'POBJ', 'char': ['Clint Barton', 'Tony Stark']}
# 156
# {'pos': 'PRON', 'content': 'They', 'begin': 0, 'index': 1, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['James Rhodes', 'Nick Fury', 'Clint Barton', 'Sam Wilson']}
# 167
# {'pos': 'PRON', 'content': 'they', 'begin': 113, 'index': 22, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Nick Fury', 'Bruce Banner', 'Thor']}
# 198
# {'pos': 'PRON', 'content': 'They', 'begin': 22, 'index': 8, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['James Rhodes', 'Clint Barton', 'Tony Stark', 'Erik Selvig']}
# 199
# {'pos': 'PRON', 'content': 'They', 'begin': 65, 'index': 16, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Ultron', 'Nick Fury']}
# 207
# {'pos': 'PRON', 'content': 'they', 'begin': 133, 'index': 36, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Clint Barton', 'Laura Barton']}
# 207
# {'pos': 'PRON', 'content': 'they', 'begin': 144, 'index': 41, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Clint Barton', 'Laura Barton']}
# 231
# {'pos': 'PRON', 'content': 'they', 'begin': 16, 'index': 8, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Thor', 'Vision', 'Clint Barton', 'Tony Stark']}
# 250
# {'pos': 'PRON', 'content': 'they', 'begin': 6, 'index': 6, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Natasha Romanoff', 'Tony Stark']}
# 250
# {'pos': 'PRON', 'content': 'they', 'begin': 13, 'index': 6, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Natasha Romanoff', 'Tony Stark']}
# 250
# {'pos': 'PRON', 'content': 'they', 'begin': 39, 'index': 11, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Natasha Romanoff', 'Tony Stark']}
# 311
# {'pos': 'PRON', 'content': 'they', 'begin': 20, 'index': 9, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Steve Rogers', 'Vision', 'Wanda Maximoff']}
# 311
# {'pos': 'PRON', 'content': 'they', 'begin': 46, 'index': 14, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Steve Rogers', 'Vision', 'Wanda Maximoff']}
# 324
# {'pos': 'PRON', 'content': 'They', 'begin': 277, 'index': 68, 'lemma': 'They', 'label': 'NSUBJ', 'char': ["Klaue's Mercenary", 'Natasha Romanoff', 'Ultron', 'Tony Stark']}
# 338
# {'pos': 'PRON', 'content': 'them', 'begin': 173, 'index': 34, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Tony Stark', 'Dr. Helen Cho']}
# 341
# {'pos': 'PRON', 'content': 'they', 'begin': 10, 'index': 7, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Clint Barton', 'Thor', 'Ultron', 'Tony Stark']}
# 389
# {'pos': 'PRON', 'content': 'them', 'begin': 210, 'index': 46, 'lemma': 'them', 'label': 'POBJ', 'char': ['Natasha Romanoff', 'Clint Barton', 'Thor']}
# 390
# {'pos': 'PRON', 'content': 'them', 'begin': 92, 'index': 19, 'lemma': 'them', 'label': 'DOBJ', 'char': ['JARVIS', 'Tony Stark']}
# 391
# {'pos': 'PRON', 'content': 'they', 'begin': 13, 'index': 6, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Bruce Banner', 'JARVIS', 'Tony Stark', 'Thor']}
# 393
# {'pos': 'PRON', 'content': 'they', 'begin': 27, 'index': 5, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Natasha Romanoff', 'Steve Rogers', 'Tony Stark']}
# 393
# {'pos': 'PRON', 'content': 'them', 'begin': 202, 'index': 39, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Natasha Romanoff', 'Steve Rogers', 'Tony Stark']}
# 393
# {'pos': 'PRON', 'content': 'them', 'begin': 216, 'index': 43, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Natasha Romanoff', 'Steve Rogers', 'Tony Stark']}
# 397
# {'pos': 'PRON', 'content': 'They', 'begin': 50, 'index': 13, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Thor', 'Clint Barton']}
# 397
# {'pos': 'PRON', 'content': 'them', 'begin': 104, 'index': 23, 'lemma': 'them', 'label': 'NSUBJ', 'char': ['Thor', 'Clint Barton']}
# 398
# {'pos': 'PRON', 'content': 'them', 'begin': 31, 'index': 6, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Bruce Banner', 'Wanda Maximoff', 'Natasha Romanoff']}
# 399
# {'pos': 'PRON', 'content': 'them', 'begin': 9, 'index': 3, 'lemma': 'them', 'label': 'NSUBJ', 'char': ['FRIDAY', 'Wanda Maximoff', 'Thor']}
# 409
# {'pos': 'PRON', 'content': 'they', 'begin': 12, 'index': 4, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Clint Barton', 'Thor', 'Nick Fury', 'Natasha Romanoff']}
# 410
# {'pos': 'PRON', 'content': 'them', 'begin': 116, 'index': 26, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Steve Rogers', 'Maria Hill']}
# 410
# {'pos': 'PRON', 'content': 'them', 'begin': 151, 'index': 36, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Steve Rogers', 'Maria Hill']}
# 414
# {'pos': 'PRON', 'content': 'them', 'begin': 45, 'index': 10, 'lemma': 'them', 'label': 'POBJ', 'char': ['Ultron', 'Natasha Romanoff', 'Thor']}
# 414
# {'pos': 'PRON', 'content': 'they', 'begin': 51, 'index': 14, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Ultron', 'Natasha Romanoff', 'Thor']}
# 420
# {'pos': 'PRON', 'content': 'them', 'begin': 68, 'index': 12, 'lemma': 'them', 'label': 'IOBJ', 'char': ['Bruce Banner', 'Natasha Romanoff', 'Ultron', 'Steve Rogers']}
# 427
# {'pos': 'PRON', 'content': 'they', 'begin': 56, 'index': 12, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Dr. Helen Cho', 'Bruce Banner', 'Clint Barton']}
# 444
# {'pos': 'PRON', 'content': 'They', 'begin': 27, 'index': 7, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['James Rhodes', 'Ultron', 'Pietro Maximoff']}
# 467
# {'pos': 'PRON', 'content': 'them', 'begin': 6, 'index': 0, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Ultron', 'Maria Hill']}
# 469
# {'pos': 'PRON', 'content': 'them', 'begin': 7, 'index': 1, 'lemma': 'them', 'label': 'POBJ', 'char': ['Erik Selvig', 'Steve Rogers']}
# 479
# {'pos': 'PRON', 'content': 'them', 'begin': 13, 'index': 2, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Tony Stark', 'Ultron', 'Steve Rogers', 'Bruce Banner']}
# 486
# {'pos': 'PRON', 'content': 'they', 'begin': 4, 'index': 3, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Clint Barton', 'Madame B']}
# 486
# {'pos': 'PRON', 'content': 'They', 'begin': 25, 'index': 7, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Clint Barton', 'Madame B']}
# 501
# {'pos': 'PRON', 'content': 'they', 'begin': 429, 'index': 98, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Clint Barton', 'JARVIS']}
# 501
# {'pos': 'PRON', 'content': 'they', 'begin': 514, 'index': 117, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Clint Barton', 'JARVIS']}
# 501
# {'pos': 'PRON', 'content': 'they', 'begin': 839, 'index': 197, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Clint Barton', 'JARVIS']}
# 501
# {'pos': 'PRON', 'content': 'they', 'begin': 902, 'index': 214, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Clint Barton', 'JARVIS']}
# 512
# {'pos': 'PRON', 'content': 'they', 'begin': 63, 'index': 15, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['FRIDAY', 'Pietro Maximoff', 'Maria Hill', 'Strucker']}
# 515
# {'pos': 'PRON', 'content': 'they', 'begin': 13, 'index': 7, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Thor', 'Steve Rogers']}
# 520
# {'pos': 'PRON', 'content': 'they', 'begin': 24, 'index': 9, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Bruce Banner', 'Heimdall']}
# 524
# {'pos': 'PRON', 'content': 'they', 'begin': 18, 'index': 6, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Party Guest', 'Natasha Romanoff']}
# 536
# {'pos': 'PRON', 'content': 'them', 'begin': 60, 'index': 14, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Natasha Romanoff', 'Clint Barton', 'Ultron', 'Laura Barton']}
# 539
# {'pos': 'PRON', 'content': 'they', 'begin': 3, 'index': 3, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Natasha Romanoff', 'Clint Barton', 'Dr. Helen Cho']}
# 539
# {'pos': 'PRON', 'content': 'them', 'begin': 34, 'index': 7, 'lemma': 'them', 'label': 'POBJ', 'char': ['Natasha Romanoff', 'Clint Barton', 'Dr. Helen Cho']}
# 548
# {'pos': 'PRON', 'content': 'they', 'begin': 41, 'index': 11, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Tony Stark', 'Steve Rogers', 'Natasha Romanoff', 'Heimdall']}
# 548
# {'pos': 'PRON', 'content': 'They', 'begin': 63, 'index': 16, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Tony Stark', 'Steve Rogers', 'Natasha Romanoff', 'Heimdall']}
# 550
# {'pos': 'PRON', 'content': 'they', 'begin': 16, 'index': 5, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Tony Stark', 'Thor', 'Ultron', 'Steve Rogers']}
# 551
# {'pos': 'PRON', 'content': 'they', 'begin': 8, 'index': 3, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Natasha Romanoff', 'Nick Fury']}
# 551
# {'pos': 'PRON', 'content': 'They', 'begin': 41, 'index': 12, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Natasha Romanoff', 'Nick Fury']}
# 552
# {'pos': 'PRON', 'content': 'they', 'begin': 14, 'index': 5, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Bruce Banner', 'FRIDAY', 'James Rhodes']}
# 553
# {'pos': 'PRON', 'content': 'they', 'begin': 61, 'index': 15, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Tony Stark', 'Steve Rogers', 'Vision']}
# 565
# {'pos': 'PRON', 'content': 'They', 'begin': 0, 'index': 1, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Tony Stark', 'FRIDAY']}
# 572
# {'pos': 'PRON', 'content': 'they', 'begin': 66, 'index': 15, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Ultron', 'Strucker']}
# 582
# {'pos': 'PRON', 'content': 'they', 'begin': 77, 'index': 22, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Thor', 'Clint Barton', 'Steve Rogers', 'Tony Stark']}
# 582
# {'pos': 'PRON', 'content': 'They', 'begin': 110, 'index': 28, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Thor', 'Clint Barton', 'Steve Rogers', 'Tony Stark']}
# 597
# {'pos': 'PRON', 'content': 'them', 'begin': 107, 'index': 21, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Clint Barton', 'Maria Hill', 'Tony Stark']}
# 607
# {'pos': 'PRON', 'content': 'them', 'begin': 94, 'index': 26, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Thor', 'Dr. List', 'Vision', 'Steve Rogers']}
# 610
# {'pos': 'PRON', 'content': 'them', 'begin': 78, 'index': 16, 'lemma': 'them', 'label': 'POBJ', 'char': ['Laura Barton', 'Steve Rogers', 'Thor']}
# 626
# {'pos': 'PRON', 'content': 'they', 'begin': 10, 'index': 4, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['JARVIS', 'Steve Rogers', 'Natasha Romanoff', 'Thor']}
# 641
# {'pos': 'PRON', 'content': 'They', 'begin': 0, 'index': 3, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['FRIDAY', 'Steve Rogers', 'Tony Stark', 'Natasha Romanoff']}
# 641
# {'pos': 'PRON', 'content': 'they', 'begin': 33, 'index': 9, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['FRIDAY', 'Steve Rogers', 'Tony Stark', 'Natasha Romanoff']}
# 644
# {'pos': 'PRON', 'content': 'they', 'begin': 82, 'index': 18, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Steve Rogers', 'Ultron', 'Clint Barton']}
# 644
# {'pos': 'PRON', 'content': 'them', 'begin': 98, 'index': 18, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Steve Rogers', 'Ultron', 'Clint Barton']}
# 645
# {'pos': 'PRON', 'content': 'they', 'begin': 47, 'index': 9, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['JARVIS', 'Tony Stark']}
# 645
# {'pos': 'PRON', 'content': 'they', 'begin': 98, 'index': 21, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['JARVIS', 'Tony Stark']}
# 656
# {'pos': 'PRON', 'content': 'them', 'begin': 74, 'index': 20, 'lemma': 'them', 'label': 'NSUBJ', 'char': ['Maria Hill', 'Wanda Maximoff', 'Bruce Banner', 'Dr. Helen Cho']}
# 677
# {'pos': 'PRON', 'content': 'they', 'begin': 7, 'index': 3, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Tony Stark', 'Ultron']}
# 680
# {'pos': 'PRON', 'content': 'theirs', 'begin': 83, 'index': 13, 'lemma': 'theirs', 'label': 'DOBJ', 'char': ['Tony Stark', 'Bruce Banner', 'Steve Rogers', 'Dr. Helen Cho']}
# 684
# {'pos': 'PRON', 'content': 'They', 'begin': 47, 'index': 15, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Dr. List', 'Tony Stark']}
# 684
# {'pos': 'PRON', 'content': 'they', 'begin': 72, 'index': 19, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Dr. List', 'Tony Stark']}
# 684
# {'pos': 'PRON', 'content': 'they', 'begin': 81, 'index': 22, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Dr. List', 'Tony Stark']}
# 694
# {'pos': 'PRON', 'content': 'them', 'begin': 125, 'index': 32, 'lemma': 'them', 'label': 'ATTR', 'char': ['Tony Stark', 'Laura Barton']}
# 705
# {'pos': 'PRON', 'content': 'They', 'begin': 0, 'index': 2, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Sam Wilson', 'Pietro Maximoff']}
# 757
# {'pos': 'PRON', 'content': 'they', 'begin': 57, 'index': 19, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Dr. Helen Cho', 'Strucker', 'Steve Rogers', 'Ultron']}
# 758
# {'pos': 'PRON', 'content': 'them', 'begin': 180, 'index': 43, 'lemma': 'them', 'label': 'POBJ', 'char': ['Tony Stark', 'Bruce Banner', 'Natasha Romanoff', 'Madame B']}
# 758
# {'pos': 'PRON', 'content': 'they', 'begin': 387, 'index': 97, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Tony Stark', 'Bruce Banner', 'Natasha Romanoff', 'Madame B']}
# 777
# {'pos': 'PRON', 'content': 'they', 'begin': 170, 'index': 42, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Thor', 'Natasha Romanoff']}
# 797
# {'pos': 'PRON', 'content': 'they', 'begin': 56, 'index': 14, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Tony Stark', 'Steve Rogers', 'Clint Barton', 'Ultron']}
# 797
# {'pos': 'PRON', 'content': 'they', 'begin': 95, 'index': 22, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Tony Stark', 'Steve Rogers', 'Clint Barton', 'Ultron']}
# 807
# {'pos': 'PRON', 'content': 'them', 'begin': 31, 'index': 8, 'lemma': 'them', 'label': 'POBJ', 'char': ['Steve Rogers', 'Laura Barton', 'Clint Barton', 'Ultron']}
# 807
# {'pos': 'PRON', 'content': 'they', 'begin': 50, 'index': 14, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Steve Rogers', 'Laura Barton', 'Clint Barton', 'Ultron']}
# 809
# {'pos': 'PRON', 'content': 'they', 'begin': 51, 'index': 16, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Clint Barton', 'JARVIS', 'Ultron']}
# 815
# {'pos': 'PRON', 'content': 'they', 'begin': 130, 'index': 32, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Ultron', 'Bruce Banner']}
# 815
# {'pos': 'PRON', 'content': 'them', 'begin': 170, 'index': 39, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Ultron', 'Bruce Banner']}
# 816
# {'pos': 'PRON', 'content': 'them', 'begin': 217, 'index': 51, 'lemma': 'them', 'label': 'NSUBJ', 'char': ['Steve Rogers', "Klaue's Mercenary"]}
# 817
# {'pos': 'PRON', 'content': 'they', 'begin': 4, 'index': 2, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Wanda Maximoff', 'Tony Stark', 'Ultron']}
# 817
# {'pos': 'PRON', 'content': 'them', 'begin': 119, 'index': 27, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Wanda Maximoff', 'Tony Stark', 'Ultron']}
# 842
# {'pos': 'PRON', 'content': 'They', 'begin': 11, 'index': 6, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Clint Barton', 'James Rhodes', 'Steve Rogers']}
# 843
# {'pos': 'PRON', 'content': 'them', 'begin': 34, 'index': 7, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Wanda Maximoff', 'Ultron', 'Thor']}
# 844
# {'pos': 'PRON', 'content': 'they', 'begin': 10, 'index': 4, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Natasha Romanoff', 'Nick Fury']}
# 850
# {'pos': 'PRON', 'content': 'them', 'begin': 388, 'index': 86, 'lemma': 'them', 'label': 'POBJ', 'char': ['Sam Wilson', 'Clint Barton', 'Steve Rogers', 'Maria Hill']}
# 866
# {'pos': 'PRON', 'content': 'them', 'begin': 15, 'index': 3, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Bruce Banner', 'Tony Stark', 'Wanda Maximoff', 'Natasha Romanoff']}
# 868
# {'pos': 'PRON', 'content': 'them', 'begin': 208, 'index': 42, 'lemma': 'them', 'label': 'DOBJ', 'char': ['FRIDAY', 'Bruce Banner', 'Specialist Cameron Klein']}
# 874
# {'pos': 'PRON', 'content': 'them', 'begin': 18, 'index': 3, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Vision', 'Thor', 'Soldiers', 'Tony Stark']}
# 876
# {'pos': 'PRON', 'content': 'they', 'begin': 46, 'index': 13, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Steve Rogers', 'Tony Stark', 'Dr. List']}
# 894
# {'pos': 'PRON', 'content': 'they', 'begin': 72, 'index': 19, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Vision', 'Natasha Romanoff', 'Wanda Maximoff']}
# 894
# {'pos': 'NOUN', 'content': 'them', 'begin': 116, 'index': 24, 'lemma': 'them', 'label': 'POBJ', 'char': ['Vision', 'Natasha Romanoff', 'Wanda Maximoff']}
# 918
# {'pos': 'PRON', 'content': 'They', 'begin': 19, 'index': 8, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Tony Stark', 'Clint Barton']}
# 930
# {'pos': 'PRON', 'content': 'they', 'begin': 40, 'index': 13, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Thor', 'Clint Barton']}
# 932
# {'pos': 'PRON', 'content': 'They', 'begin': 0, 'index': 2, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Ultron', 'FRIDAY', 'Bruce Banner']}
# 949
# {'pos': 'PRON', 'content': 'they', 'begin': 31, 'index': 10, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Tony Stark', 'Steve Rogers']}
# 953
# {'pos': 'PRON', 'content': 'them', 'begin': 73, 'index': 14, 'lemma': 'them', 'label': 'POBJ', 'char': ['Vision', 'Bruce Banner']}
# 956
# {'pos': 'PRON', 'content': 'them', 'begin': 134, 'index': 28, 'lemma': 'them', 'label': 'POBJ', 'char': ['Ultron', 'Wanda Maximoff', 'Nick Fury', 'Tony Stark']}
# 957
# {'pos': 'PRON', 'content': 'them', 'begin': 132, 'index': 34, 'lemma': 'them', 'label': 'POBJ', 'char': ['Peggy Carter', 'Sam Wilson']}
# 957
# {'pos': 'PRON', 'content': 'them', 'begin': 187, 'index': 44, 'lemma': 'them', 'label': 'DOBJ', 'char': ['Peggy Carter', 'Sam Wilson']}
# 971
# {'pos': 'PRON', 'content': 'They', 'begin': 16, 'index': 5, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Tony Stark', 'Strucker', 'Clint Barton', 'Thor']}
# 972
# {'pos': 'PRON', 'content': 'They', 'begin': 0, 'index': 2, 'lemma': 'They', 'label': 'NSUBJPASS', 'char': ['Steve Rogers', 'Natasha Romanoff']}
# 973
# {'pos': 'PRON', 'content': 'them', 'begin': 80, 'index': 18, 'lemma': 'them', 'label': 'POBJ', 'char': ['Natasha Romanoff', 'Tony Stark']}
# 1004
# {'pos': 'PRON', 'content': 'they', 'begin': 142, 'index': 39, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Steve Rogers', 'Bruce Banner']}
# 1015
# {'pos': 'PRON', 'content': 'They', 'begin': 0, 'index': 1, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Tony Stark', 'Nick Fury']}
# 1015
# {'pos': 'PRON', 'content': 'They', 'begin': 14, 'index': 5, 'lemma': 'They', 'label': 'NSUBJ', 'char': ['Tony Stark', 'Nick Fury']}
# 1016
# {'pos': 'PRON', 'content': 'they', 'begin': 28, 'index': 10, 'lemma': 'they', 'label': 'NSUBJ', 'char': ['Dr. List', 'Steve Rogers', 'Wanda Maximoff']}
#         speaker                                           dialogue  \
# 0     Announcer  [first lines; announcement over speaker] Repor...
# 1      narrator  the Avengers are in the process of infiltratin...
# 2    Tony Stark                                              Shit!
# 3  Steve Rogers   Language! JARVIS, what's the view from upstairs?
# 4        JARVIS  The central building is protected by some kind...
#
#                                            sentences  \
# 0  [{'content': u'[first lines; announcement over...
# 1  [{'content': u'the Avengers are in the process...
# 2  [{'content': u'Shit!', 'begin': 0, 'score': -0...
# 3  [{'content': u'Language!', 'begin': 0, 'score'...
# 4  [{'content': u'The central building is protect...
#
#                            sentiment  \
# 0  {'score': -0.2, 'magnitude': 1.6}
# 1   {'score': 0.1, 'magnitude': 0.1}
# 2  {'score': -0.6, 'magnitude': 0.6}
# 3     {'score': 0, 'magnitude': 0.1}
# 4   {'score': 0.7, 'magnitude': 1.5}
#
#                                             entities  \
# 0  [{'name': 'lines', 'salience': 0.35250518, 'me...
# 1  [{'name': 'Avengers', 'salience': 0.47595453, ...
# 2                                                 []
# 3  [{'name': 'Language', 'salience': 0.7599061, '...
# 4  [{'name': 'building', 'salience': 0.47500995, ...
#
#                                               tokens  total_sent  num_pron  \
# 0  [{'pos': 'PUNCT', 'content': '[', 'begin': 0, ...       -0.32         3
# 1  [{'pos': 'DET', 'content': 'the', 'begin': 0, ...        0.01         0
# 2  [{'pos': 'X', 'content': 'Shit', 'begin': 0, '...       -0.36         0
# 3  [{'pos': 'NOUN', 'content': 'Language', 'begin...        0.00         1
# 4  [{'pos': 'DET', 'content': 'The', 'begin': 0, ...        1.05         1
#
#                                          nearbyChars  \
# 0  [Tony Stark, Clint Barton, narrator, Natasha R...
# 1  [Steve Rogers, Tony Stark, Clint Barton, narra...
# 2  [narrator, Steve Rogers, Tony Stark, Clint Bar...
# 3  [Steve Rogers, narrator, Steve Rogers, Tony St...
# 4  [Strucker, Steve Rogers, narrator, Steve Roger...
#
#                                            relations
# 0  [{'ent2': 'Clint Barton', 'men2': ['We'], 'lin...
# 1                                               None
# 2                                               None
# 3                                               None
# 4  [{'ent2': 'Thor', 'men2': ['we'], 'line': 4, '...

# %%
REEval([df], 5)
# Out:
# ******** line 705 ********
# 703. Clint Barton:
# [to Natasha] We got a window. Four, three...give 'em hell. [Natasha drops out of the Quinjet on a bike and rides towards the truck and picks up Steve's shield]
#
# 704. Natasha Romanoff:
# I'm always picking up after you boys.
#
# => 705. Clint Barton:
# => They're heading under the overpass, I've got no shot.
#
# 706. Natasha Romanoff:
# Which way?
#
# 707. Clint Barton:
# Hard right... Now. [Natasha heads over the truck, she throws Steve back his shield and he uses it to knock off Ultron from him]
#
# ******** test model 1: line 705 ********
# 1 relations identified
# entities: Sam Wilson => Pietro Maximoff-['They']
# relation: belong to same team
# category: 6. same team mentioning
#
# how many are correctly identified? 1
#
# ******** line 837 ********
# 835. Ultron:
# You're stalling to protect the people.
#
# 836. Tony Stark:
# Well, that is the mission. Did you forget?
#
# => 837. Ultron:
# => I've moved beyond your mission. I'm free. [suddenly the Vibranium core he's placed beneath the floor erupts] What, you think you're the only one stalling?
#
# 838. Ultron:
# This is how you end, Tony. This is peace in my time. [Ultron's army of robots start attacking the city as everyone is evacuating]
#
# 839. Steve Rogers:
# Go!
#
# ******** test model 1: line 837 ********
# 1 relations identified
# entities: Ultron => Clint Barton-['he']
# relation: I've moved beyond your mission. I'm free. [suddenly the Vibranium core he's placed beneath the floor erupts] What, you think you're the only one stalling?
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 265 ********
# 263. Party Guest:
# I gotta have some of that!
#
# 264. Thor:
# Oh, no, no, no. See this, this was aged for a thousand years, in the barrels built from the wreck of Brunhilde's fleet, it's not meant for mortal men. [Thor pours the drink into two glasses and hands one to Steve]
#
# => 265. Stan Lee:
# => Neither was Omaha Beach, blondie. Stop trying to scare us. Come on.
#
# 266. Thor:
# Alright. [Thor pours some of the drink into the Stan Lee's glass; later Stan, looking extremely drunk is being carried off by two men]
#
# 267. Stan Lee:
# [singing] Excelsior. [Natasha is pouring a drink behind the bar when Banner walks up to her]
#
# ******** test model 1: line 265 ********
# 3 relations identified
# entities: Stan Lee => Sam Wilson-['us']
# relation: belong to same team
# category: 6. same team mentioning
# entities: Stan Lee => Natasha Romanoff-['us']
# relation: belong to same team
# category: 6. same team mentioning
# entities: Stan Lee => Steve Rogers-['us']
# relation: belong to same team
# category: 6. same team mentioning
#
# how many are correctly identified? 1
#
# ******** line 49 ********
# 47. Natasha Romanoff:
# [Natasha goes over to where Clint is lying down] Somebody want to deal with that bunker?
#
# 48. narrator:
# she sees the Hulk coming in to the rescue
#
# => 49. Natasha Romanoff:
# => Thank you.
#
# 50. Steve Rogers:
# [as he's fighting with the soldiers] Stark, we're really need to get inside.
#
# 51. Tony Stark:
# I'm closing in. JARVIS, am I...closing in? Do you see a power source for that shield?
#
# ******** test model 1: line 49 ********
# 1 relations identified
# entities: Natasha Romanoff => Steve Rogers-['you']
# relation: Thank you.
# category: 2. positive mentioning
#
# how many are correctly identified? 1
#
# ******** line 632 ********
# 630. Natasha Romanoff:
# Do we have an ally?
#
# 631. Nick Fury:
# Ultron's got an enemy, that's not the same thing. Still, I'd pay folding money to know who it is.
#
# => 632. Tony Stark:
# => I might need to visit Oslo, find our "unknown."
#
# 633. Natasha Romanoff:
# Well, this is good times, boss, but I was kind of hoping when I saw you, you'd have more than that.
#
# 634. Nick Fury:
# I do, I have you. Back in the day, I had eyes everywhere, ears everywhere else. Here we all are, back on earth, with nothing but our wit, and our will to save the world. So stand. Outwit the platinum bastard.
#
# ******** test model 1: line 632 ********
# 2 relations identified
# entities: Tony Stark => Steve Rogers-['our']
# relation: belong to same team
# category: 6. same team mentioning
# entities: Tony Stark => Nick Fury-['our']
# relation: belong to same team
# category: 6. same team mentioning
#
# how many are correctly identified? 1
#
# ******** test results ********
# model 1: precision = 0.62 (5/8 correct)

# %% [markdown]
# ## Putting Everything Together, a Simple Query System <a class="anchor" id="Query"></a>
# [[back to top]](#top)

# %%
def checkQuery(relationList, ent1, ent2, relationClass):
    for relation in relationList:
        if ent1 in relation['ent1'] and ent2 in relation['ent2'] and relationClass == relation['class']:
            return True
    return False

def printAnswer(row):
    print('Movie: {}, Line {}'.format(row.movie, row.lineNum))
    print('{}: {}'.format(row.speaker, row.dialogue))
    print()
    
def queryScore(relationList, query, relationClass):
    querySet = set(query.split(' '))
    resultScore = 0
    
    for relation in relationList:
        relationSet = set()
        if type(relation['ent1']) == str:
            relationSet |= set(relation['ent1'].lower().split())
        else:
            for ent in relation['ent1']:
                #print(set(ent.split()))
                relationSet |= set(ent.lower().split())
            
        if type(relation['ent2']) == str:
            #print(relation['ent2'])
            relationSet |= set(relation['ent2'].lower().split())
        else:
            for ent in relation['ent2']:
                relationSet |= set(ent.lower().split())
        
        relationSet |= set(relation['relation'].lower().split())
        relationSet |= set(relationClass[relation['class']].lower().split())
        tempScore = len(relationSet & querySet) / (len(relationSet) + len(querySet))
        
        if tempScore > resultScore:
            resultScore = tempScore
        
    return resultScore

#Simple Query System

print('Select the movies of your interest:')
print('***Enter all to use all movies')
print('***Enter n, m, x, y (numbers separated by commas) for specific selections')
print('***Enter random, n for n random selections\n')

files = [x for x in os.listdir('prep_scripts') if '_gapi' in x]
for i, fileName in enumerate(files):
    print('{}. {}'.format(i+1, re.split(r'_tw_|_imsdb_', fileName)[0]))


x = input()


#random selection
try:
    if 'random' in x:
        queryFiles = np.random.choice(files, int(x.split(',')[-1]), replace=False)
    elif x != 'all':
        queryFiles = np.array(files)[[int(select) - 1 for select in x.split(',')]]
    #use all files
    else:
        queryFiles = files    
        
except:
    print('\nunexpected input, will use all movie files\n')
    queryFiles = files    

#print(queryFiles)
df_data = None
charSet = set()

for i, fileName in enumerate(queryFiles):    
    df = pd.read_csv('prep_scripts/'+fileName)[['speaker', 'dialogue', 'sentences', 'sentiment', 'entities', 'tokens']]
    df['tokens'] = df['tokens'].apply(lambda x: eval(x))
    df['sentiment'] = df['sentiment'].apply(lambda x: eval(x))
    df['total_sent'] = df['sentiment'].apply(lambda x: x['score'] * x['magnitude'])
    df['entities'] = df['entities'].apply(lambda x: eval(x))
    df['movie'] = re.split(r'_tw_|_imsdb_', fileName)[0]
    df['lineNum'] = df.index + 1
    
    charRange = 10
    nearbyList = np.dstack((df.shift(i).speaker.values for i in range(-charRange, charRange+1)))[0]
    df['nearbyChars'] = None
    for line, nearbyChars in enumerate(nearbyList):
        df.set_value(line, 'nearbyChars', nearbyChars)
    
    cList = list(df.speaker.unique())
    cDict = dict(df.groupby('speaker').total_sent.sum())
    
    #resolve entities
    df.apply(lambda x:pronResolution_nnMod(cList, x), axis=1)
    
    #extract relations
    df['relations'] = df.apply(lambda x:extract_relation_categories(x), axis=1)
    
    if i == 0:
        df_data = df[df.relations.notnull()]        
        
    else:
        df_data = pd.concat((df_data, df[df.relations.notnull()]))
    
    charSet |= set(df.speaker.unique())

relationClasses = getRelations()
    
print('Type end to finish at any time')
print('Choose one of the following:')
print('1. Structured search')
print('2. Free form query')
searchType = int(input()) - 1

#relationList = df_data[df_data.hasRelation == True]['relations'].values

if not searchType:
    
    while True:
        print('Characters: ')
        print(charSet)
        print('\nRelations:')
        for k, v in relationClasses.items():
            print('{}. {}'.format(k+1, v))
        print('What relation are you looking for?')
        ent1 = input('Entity 1:')
        if ent1 == 'end':
            break
        ent2 = input('Entity 2:')
        if ent2 == 'end':
            break
        relationClass = int(input('Relation category: '))-1

        qMatch = df_data.relations.apply(lambda x: checkQuery(x, ent1, ent2, relationClass))
        if sum(qMatch) == 0:
            print('nothing found\n')
        else:
            df_data[qMatch].apply(lambda x: printAnswer(x), axis=1)

else:
    while True:
        query = input('Enter query')
        if query == 'end':
            break
        df = df_data.copy()
        df['queryScore'] = df.relations.apply(lambda x: queryScore(x, query, relationClasses))
        df = df.sort_values(by='queryScore', ascending=False).head().copy()
        df.apply(lambda x: printAnswer(x), axis=1)
# Out:
# Select the movies of your interest:
# ***Enter all to use all movies
# ***Enter n, m, x, y (numbers separated by commas) for specific selections
# ***Enter random, n for n random selections
#
# 1. ant-man
# 2. avengers_age_of_ultron
# 3. captain_america_civil_war
# 4. captain_america_the_first_avenger
# 5. captain_america_the_winter_soldier
# 6. fantastic_four
# 7. iron_man_3
# 8. lego_marvel_super_heroes
# 9. spider-man
# 10. the_amazing_spider-man_2
# 11. the_amazing_spider-man
# 12. the_avengers
# 13. the_wolverine
# 14. thor_the_dark_world
# 15. thor
# 16. x-men_apocalypse
# 17. x-men_days_of_future_past
# 18. x-men
# 19. x-men_the_last_stand
# all
# Type end to finish at any time
# Choose one of the following:
# 1. Structured search
# 2. Free form query
# 2
# Enter querycaptain america helps thor fight loki and iron man
# Movie: lego_marvel_super_heroes, Line 348
# Captain America: Colonel Fury, sir, Loki jumped into a Vortex and vanished.
#
# Movie: lego_marvel_super_heroes, Line 386
# Loki: Oh and so am I, brother! I intend to get my revenge on you, on Earth, and on Asgard!
#
# Movie: thor, Line 143
# Thor: [shouting] And you are an old man and a fool!
#
# Movie: thor, Line 116
# narrator: he comes walks closer to Thor and Loki
#
# Movie: thor, Line 95
# narrator: Thor walks passed Heimdall, the others follow behind and Volstagg turns to Loki
#
# Enter queryblack window and captain america discusses battle strategy
# Movie: lego_marvel_super_heroes, Line 348
# Captain America: Colonel Fury, sir, Loki jumped into a Vortex and vanished.
#
# Movie: captain_america_the_winter_soldier, Line 214
# The Smithsonian Narrator: Battle tested, Captain America and his Howling Commandos quickly earned their stripes. Their mission, taking down HYDRA, the Nazi rogue science division.
#
# Movie: captain_america_the_winter_soldier, Line 208
# The Smithsonian Narrator: A symbol to the nation. A hero to the world. The story of Captain America is one of honor, bravery and sacrifice.
#
# Movie: lego_marvel_super_heroes, Line 666
# Captain America: He's quite the show man. And he's got a flying island? Is this come sort of Hydra trick?
#
# Movie: lego_marvel_super_heroes, Line 801
# Captain America: Okay, people, let's go to work! Avengers, assemble!
#
# Enter querytony stark admits he is the iron man
# Movie: avengers_age_of_ultron, Line 931
# Tony Stark: Well, like the old man said. Together. [they all fight off Ultron's attacking robots]
#
# Movie: avengers_age_of_ultron, Line 502
# Tony Stark: I'm calling in VERONICA. [as Hulk is wreaking havoc on the nearest city Stark Tony comes brings out his Hulkbuster armor to stop him] Alright everybody, stand down! [to Hulk] You listening? That little witch is messing with your mind. You're stronger than her, you're smarter than her, you're Bruce Banner. [Hulk roars in anger] Right, right, right! Don't mention puny Banner. [Hulk throws a car at Stark and attacks him] Okay. [they start fighting and throwing each other around] In the back? Dick move, Banner. [they battle it out more but Stark is struggling to beat Hulk] VERONICA, gimme a hand. [as Hulk destroyed one of Stark's armor arms VERONICA sends in a new Hulkbuster armor arm and Stark uses it to repeatedly punch Hulk] Go to sleep, go to sleep, go to sleep! [picking up Hulk] Okay, pal, we're gonna get you out of town. [as they head towards a building] No, not that way, not that way! [they crash through the building] Come on, Bruce! You gotta work with me! [Hulk continues to battle with him] [to the people in the building] Everybody out! Going to get ugly! [after he knocks down Hulk] I'm sorry. [Hulk attacks Stark and pulls out parts of the Hulkbuster armor] Damage report. [the damaged computer buzzes a reply] That's comprehensive. Show me something. [the computer shows him the building ahead is clear of civilians] How quickly can we buy this building? [Stark drops Hulk through the building completely destroying it; at the same time the army arrives to intervene, as Hulk comes out of Wanda's mind-hold Stark knocks him out cold] [with Banner back to normal and everybody back on the Quinjet]
#
# Movie: iron_man_3, Line 407
# narrator: Pepper sees Tony is in fact not in his Iron Man suit, but in the lab exercising as he remotely controls the suit, which follows Pepper into the lab
#
# Movie: the_avengers, Line 219
# narrator: as Stark arrives at his skyscraper penthouse and is in the process of taking off his Iron Man suit
#
# Movie: the_avengers, Line 271
# Tony Stark: How did you notice? Why is he Phil? [referring to the file Coulson had given to Stark]
#
# Enter queryhulk tries to grab thor's hammer
# Movie: lego_marvel_super_heroes, Line 801
# Captain America: Okay, people, let's go to work! Avengers, assemble!
#
# Movie: lego_marvel_super_heroes, Line 20
# Iron Man: Hulk, you have to remember to look... before you leap.
#
# Movie: avengers_age_of_ultron, Line 502
# Tony Stark: I'm calling in VERONICA. [as Hulk is wreaking havoc on the nearest city Stark Tony comes brings out his Hulkbuster armor to stop him] Alright everybody, stand down! [to Hulk] You listening? That little witch is messing with your mind. You're stronger than her, you're smarter than her, you're Bruce Banner. [Hulk roars in anger] Right, right, right! Don't mention puny Banner. [Hulk throws a car at Stark and attacks him] Okay. [they start fighting and throwing each other around] In the back? Dick move, Banner. [they battle it out more but Stark is struggling to beat Hulk] VERONICA, gimme a hand. [as Hulk destroyed one of Stark's armor arms VERONICA sends in a new Hulkbuster armor arm and Stark uses it to repeatedly punch Hulk] Go to sleep, go to sleep, go to sleep! [picking up Hulk] Okay, pal, we're gonna get you out of town. [as they head towards a building] No, not that way, not that way! [they crash through the building] Come on, Bruce! You gotta work with me! [Hulk continues to battle with him] [to the people in the building] Everybody out! Going to get ugly! [after he knocks down Hulk] I'm sorry. [Hulk attacks Stark and pulls out parts of the Hulkbuster armor] Damage report. [the damaged computer buzzes a reply] That's comprehensive. Show me something. [the computer shows him the building ahead is clear of civilians] How quickly can we buy this building? [Stark drops Hulk through the building completely destroying it; at the same time the army arrives to intervene, as Hulk comes out of Wanda's mind-hold Stark knocks him out cold] [with Banner back to normal and everybody back on the Quinjet]
#
# Movie: lego_marvel_super_heroes, Line 528
# Nick Fury: We need to get him off his board!
#
# Movie: lego_marvel_super_heroes, Line 218
# Hulk: Hulk need the bathroom. Iron Man Really? You couldn't have gone before we left?
#
# Enter queryprofessor x talks to jean about the past
# Movie: lego_marvel_super_heroes, Line 454
# Professor X: The students are safe, you must stop Magneto.
#
# Movie: lego_marvel_super_heroes, Line 427
# Professor X: Cylcops, Jean... You need to rescue any trapped students.
#
# Movie: x-men_the_last_stand, Line 285
# Logan: No. Maybe you ought to take it easy. The professor said you might be different.
#
# Movie: x-men_days_of_future_past, Line 42
# Professor X: She projects Bishop back in time a few days to warn the others... of the coming attack.
#
# Movie: x-men_days_of_future_past, Line 278
# Sectary: [she hands him a piece of paper] Oh. We added some names to the Paris meeting.
#
# Enter queryend
