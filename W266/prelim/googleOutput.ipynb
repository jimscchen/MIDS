# %%
import re
import nltk
import pandas as pd
import numpy as np
from google.cloud import language
import random
import ast
import os

# %%
language_client = language.Client()

# %% [markdown]
# ## Parsing Preprocessed Scripts

# %%
def googleAnnotate(fileName, nrows=None, saveFile=False):
    '''
    Takes a csv file in the form of [speaker, dialogue]
    Pass each dialogue into google language API
    Attach the output to the dataframe: [speaker, dialogue, sentences, sentiment, entities, tokens]
    sentences contain a dict {content, begin(index), (sentiment)score, (sentiment)magnitude} for each sentence
    sentiment contain {score, magnitude} for the entire dialogue
    entities contain {name, type, metadata, salience, mentions} for each entity
    tokens contain {content, begin(index), pos(partofspeech), index(edge index), label(edge label), lemma} for each token
    nrows can be used to read small number of rows for testing
    '''
    language_client = language.Client()
    df = pd.read_csv(fileName, names=['speaker', 'dialogue'], nrows=nrows)
    df['sentences'] = None
    df['sentiment'] = None
    df['entities'] = None
    df['tokens'] = None
    
    for i in range(len(df)):
        document = language_client.document_from_text(df.loc[i, 'dialogue'])
        annText = document.annotate_text()
        
        df.set_value(i, 'sentences', [{'content':x.content,
                                       'begin':x.begin,
                                       'score':x.sentiment.score,
                                       'magnitude':x.sentiment.magnitude} for x in annText.sentences])
        
        df.set_value(i, 'sentiment', {'score':annText.sentiment.score,
                                      'magnitude':annText.sentiment.magnitude})
        
        df.set_value(i, 'entities', [{'name':x.name,
                                      'type':x.entity_type,
                                      'meta':x.metadata,
                                      'salience':x.salience,
                                      'mentions':[m.text.content for m in x.mentions]} for x in annText.entities])
        
        df.set_value(i, 'tokens', [{'content':x.text_content,
                                    'begin':x.text_begin,
                                    'pos':x.part_of_speech,
                                    'index':x.edge_index,
                                    'label':x.edge_label,
                                    'lemma':x.lemma} for x in annText.tokens])
    if saveFile:
        df.to_csv(fileName[:-4] + '_gapi.csv')
        #print(fileName[:-4])
    return df

# %% [markdown]
# The code below runs googleAnnotate() on all preprocessed movie scripts and returns annotations with sentences, sentiment, entities, and tokens for each (character, dialogue) tuple.  The annotations are saved to a CSV file for later analysis and modeling, so this code only needs to be run once.

# %%
# set working directory
wd = os.path.join(os.getcwd(), 'prep_scripts')
print wd, '\n'

# view script files
files = os.listdir(wd)
print files, '\n'

# get files for scripts from transcripts.wikia
# guardians of the galaxy and x-men first class are detected as non-English?  breaks syntax and sentiment analysis
prep_scripts = [file for file in files if (file.endswith('_tw.csv') or file.endswith('_imsdb.csv')) and
                not (file.endswith('galaxy_tw.csv') or file.endswith('class_tw.csv'))]
print prep_scripts, '\n'

# parse all preprocessed scripts and save to csv
for script in prep_scripts:
    fileName = os.path.join(os.getcwd(), 'prep_scripts', script)
    
    # if parsed script file doesn't exist, annotate script
    if not(os.path.exists(fileName[:-4] + '_gapi.csv')):
        print 'Annotating script: ' + fileName 
        googleAnnotate(fileName, saveFile=True)
        print 'Finished annotating: ' + fileName
# Out:
# /Users/winlin/Desktop/w266-nlp/w266_project/prep_scripts
#
# ['ant-man_tw.csv', 'ant-man_tw_gapi.csv', 'avengers_age_of_ultron_tw.csv', 'avengers_age_of_ultron_tw_gapi.csv', 'captain_america_civil_war_tw.csv', 'captain_america_civil_war_tw_gapi.csv', 'captain_america_the_first_avenger_tw.csv', 'captain_america_the_first_avenger_tw_gapi.csv', 'captain_america_the_winter_soldier_tw.csv', 'captain_america_the_winter_soldier_tw_gapi.csv', 'fantastic_four_imsdb.csv', 'fantastic_four_imsdb_gapi.csv', 'guardians_of_the_galaxy_tw.csv', 'iron_man_3_tw.csv', 'iron_man_3_tw_gapi.csv', 'lego_marvel_super_heroes_tw.csv', 'lego_marvel_super_heroes_tw_gapi.csv', 'spider-man_imsdb.csv', 'spider-man_imsdb_gapi.csv', 'the_amazing_spider-man_2_tw.csv', 'the_amazing_spider-man_2_tw_gapi.csv', 'the_amazing_spider-man_tw.csv', 'the_amazing_spider-man_tw_gapi.csv', 'the_avengers_tw.csv', 'the_avengers_tw_gapi.csv', 'the_wolverine_tw.csv', 'the_wolverine_tw_gapi.csv', 'thor_the_dark_world_tw.csv', 'thor_the_dark_world_tw_gapi.csv', 'thor_tw.csv', 'thor_tw_gapi.csv', 'x-men_apocalypse_tw.csv', 'x-men_apocalypse_tw_gapi.csv', 'x-men_days_of_future_past_tw.csv', 'x-men_days_of_future_past_tw_gapi.csv', 'x-men_first_class_tw.csv', 'x-men_imsdb.csv', 'x-men_imsdb_gapi.csv', 'x-men_the_last_stand_tw.csv', 'x-men_the_last_stand_tw_gapi.csv']
#
# ['ant-man_tw.csv', 'avengers_age_of_ultron_tw.csv', 'captain_america_civil_war_tw.csv', 'captain_america_the_first_avenger_tw.csv', 'captain_america_the_winter_soldier_tw.csv', 'fantastic_four_imsdb.csv', 'iron_man_3_tw.csv', 'lego_marvel_super_heroes_tw.csv', 'spider-man_imsdb.csv', 'the_amazing_spider-man_2_tw.csv', 'the_amazing_spider-man_tw.csv', 'the_avengers_tw.csv', 'the_wolverine_tw.csv', 'thor_the_dark_world_tw.csv', 'thor_tw.csv', 'x-men_apocalypse_tw.csv', 'x-men_days_of_future_past_tw.csv', 'x-men_imsdb.csv', 'x-men_the_last_stand_tw.csv']

# %%
# df = googleAnnotate('prep_scripts/the_amazing_spider-man_tw.csv',saveFile=True)
# googleAnnotate('prep_scripts/thor_tw.csv',saveFile=True)
# Out:
#          speaker                                           dialogue  \
# 0       narrator                                        first lines
# 1    Jane Foster                                       Wait for it.
# 2    Darcy Lewis                           Can I turn on the radio?
# 3    Jane Foster                                                No!
# 4    Erik Selvig                   Jane, you can't keep doing this.
# 5    Jane Foster  The last seventeen occurrences had been predic...
# 6    Erik Selvig  Jane, you're an astrophysicist, not some storm...
# 7    Jane Foster  I'm telling you, there's a connection between ...
# 8    Erik Selvig         I thought you said it was a subtle aurora!
# 9    Jane Foster                                     [to Darcy] Go!
# 10      narrator  Darcy suddenly starts the car and speeds towar...
# 11   Jane Foster  [to the body that's just dropped to the ground...
# 12          Odin  [voice over] Once mankind accepted a simple tr...
# 13      narrator     humans are attacked and frozen by Frost Giants
# 14          Odin  [voice over] But humanity would not face this ...
# 15      narrator         Asgardians led by Odin arrive on Jotunheim
# 16          Odin  {voice over] Our armies drove the Frost Giants...
# 17      narrator  Odin strikes down Laufey, and steals the Caske...
# 18      narrator                                    Asgard is shown
# 19          Odin  [voice over] With the last great war ended, we...
# 20      narrator  Odin, young Thor, and young Loki are walking t...
# 21          Odin  But the day will come when one of you will hav...
# 22    Young Loki                    Do the Frost Giants still live?
# 23    Young Thor  When I'm king, I'll hunt the monsters down and...
# 24          Odin  A wise king, never seeks out war. But...he mus...
# 25    Young Thor                                 I'm ready, father.
# 26    Young Loki                                           So am I!
# 27          Odin  Only one of you can ascend to the throne. But ...
# 28      narrator                               at Thor's coronation
# 29          Odin  Thor Odinson, my heir, my first born. So long ...
# ..           ...                                                ...
# 512         Thor                     You can't kill an entire race!
# 513         Loki  Why not? And what is this new found love for t...
# 514         Thor                                      I've changed.
# 515         Loki  So have I. [he hits Thor in the face with his ...
# 516         Thor          [shouting] I will not fight you, brother!
# 517         Loki                 I'm not your brother. I never was!
# 518         Thor                             Loki, this is madness!
# 519         Loki  Is it madness? Is it? Is it? Come on, what hap...
# 520         Odin  No, Loki. [Loki looking dismayed loosens his g...
# 521         Thor  Loki, no! [he lets go and falls, disappearing ...
# 522         Odin                                                No.
# 523          Sif  My Queen, I'm so sorry for your loss. [referri...
# 524       Frigga  He mourns for his brother. And...he misses her...
# 525         Odin                             You'll be a wise king.
# 526         Thor  There will never be a wiser king than you. Nor...
# 527         Odin  You've already made me proud. [last lines; Tho...
# 528         Thor                            So earth is lost to us?
# 529     Heimdall                          No. There is always hope.
# 530         Thor                                   Can you see her?
# 531     Heimdall  Yes. [we see Jane, Erik and Darcy as they get ...
# 532         Thor                                        How is she?
# 533     Heimdall  She searches for you. [lines after end of cred...
# 534    Nick Fury                                     Doctor Selvig?
# 535  Erik Selvig  So, you're the man behind all this? [he walks ...
# 536    Nick Fury  I've been hearing about the New Mexico situati...
# 537  Erik Selvig  I have a lot to work with. The Forster theory,...
# 538    Nick Fury  Legend tell us one thing, history another. But...
# 539    Nick Fury  Power, doctor. If we can figure out how to tap...
# 540         Loki  [whispering] Well, I guess that's worth a look...
# 541  Erik Selvig                 Well, I guess that's worth a look.
#
#                                              sentences  \
# 0    [{u'content': u'first lines', u'begin': 0, u's...
# 1    [{u'content': u'Wait for it.', u'begin': 0, u'...
# 2    [{u'content': u'Can I turn on the radio?', u'b...
# 3    [{u'content': u'No!', u'begin': 0, u'score': -...
# 4    [{u'content': u'Jane, you can't keep doing thi...
# 5    [{u'content': u'The last seventeen occurrences...
# 6    [{u'content': u'Jane, you're an astrophysicist...
# 7    [{u'content': u'I'm telling you, there's a con...
# 8    [{u'content': u'I thought you said it was a su...
# 9    [{u'content': u'[to Darcy] Go!', u'begin': 0, ...
# 10   [{u'content': u'Darcy suddenly starts the car ...
# 11   [{u'content': u'[to the body that's just dropp...
# 12   [{u'content': u'[voice over] Once mankind acce...
# 13   [{u'content': u'humans are attacked and frozen...
# 14   [{u'content': u'[voice over] But humanity woul...
# 15   [{u'content': u'Asgardians led by Odin arrive ...
# 16   [{u'content': u'{voice over] Our armies drove ...
# 17   [{u'content': u'Odin strikes down Laufey, and ...
# 18   [{u'content': u'Asgard is shown', u'begin': 0,...
# 19   [{u'content': u'[voice over] With the last gre...
# 20   [{u'content': u'Odin, young Thor, and young Lo...
# 21   [{u'content': u'But the day will come when one...
# 22   [{u'content': u'Do the Frost Giants still live...
# 23   [{u'content': u'When I'm king, I'll hunt the m...
# 24   [{u'content': u'A wise king, never seeks out w...
# 25   [{u'content': u'I'm ready, father.', u'begin':...
# 26   [{u'content': u'So am I!', u'begin': 0, u'scor...
# 27   [{u'content': u'Only one of you can ascend to ...
# 28   [{u'content': u'at Thor's coronation', u'begin...
# 29   [{u'content': u'Thor Odinson, my heir, my firs...
# ..                                                 ...
# 512  [{u'content': u'You can't kill an entire race!...
# 513  [{u'content': u'Why not?', u'begin': 0, u'scor...
# 514  [{u'content': u'I've changed.', u'begin': 0, u...
# 515  [{u'content': u'So have I. [he hits Thor in th...
# 516  [{u'content': u'[shouting] I will not fight yo...
# 517  [{u'content': u'I'm not your brother.', u'begi...
# 518  [{u'content': u'Loki, this is madness!', u'beg...
# 519  [{u'content': u'Is it madness?', u'begin': 0, ...
# 520  [{u'content': u'No, Loki.', u'begin': 0, u'sco...
# 521  [{u'content': u'Loki, no! [he lets go and fall...
# 522  [{u'content': u'No.', u'begin': 0, u'score': -...
# 523  [{u'content': u'My Queen, I'm so sorry for you...
# 524  [{u'content': u'He mourns for his brother.', u...
# 525  [{u'content': u'You'll be a wise king.', u'beg...
# 526  [{u'content': u'There will never be a wiser ki...
# 527  [{u'content': u'You've already made me proud.'...
# 528  [{u'content': u'So earth is lost to us?', u'be...
# 529  [{u'content': u'No.', u'begin': 0, u'score': -...
# 530  [{u'content': u'Can you see her?', u'begin': 0...
# 531  [{u'content': u'Yes.', u'begin': 0, u'score': ...
# 532  [{u'content': u'How is she?', u'begin': 0, u's...
# 533  [{u'content': u'She searches for you.', u'begi...
# 534  [{u'content': u'Doctor Selvig?', u'begin': 0, ...
# 535  [{u'content': u'So, you're the man behind all ...
# 536  [{u'content': u'I've been hearing about the Ne...
# 537  [{u'content': u'I have a lot to work with.', u...
# 538  [{u'content': u'Legend tell us one thing, hist...
# 539  [{u'content': u'Power, doctor.', u'begin': 0, ...
# 540  [{u'content': u'[whispering] Well, I guess tha...
# 541  [{u'content': u'Well, I guess that's worth a l...
#
#                                sentiment  \
# 0         {u'score': 0, u'magnitude': 0}
# 1         {u'score': 0, u'magnitude': 0}
# 2         {u'score': 0, u'magnitude': 0}
# 3    {u'score': -0.4, u'magnitude': 0.4}
# 4    {u'score': -0.6, u'magnitude': 0.6}
# 5    {u'score': -0.2, u'magnitude': 0.2}
# 6     {u'score': 0.2, u'magnitude': 0.2}
# 7       {u'score': 0, u'magnitude': 1.1}
# 8     {u'score': 0.1, u'magnitude': 0.1}
# 9     {u'score': 0.2, u'magnitude': 0.2}
# 10        {u'score': 0, u'magnitude': 0}
# 11   {u'score': -0.1, u'magnitude': 0.3}
# 12    {u'score': 0.3, u'magnitude': 1.9}
# 13   {u'score': -0.4, u'magnitude': 0.4}
# 14    {u'score': 0.1, u'magnitude': 0.1}
# 15        {u'score': 0, u'magnitude': 0}
# 16    {u'score': 0.1, u'magnitude': 1.2}
# 17   {u'score': -0.5, u'magnitude': 0.5}
# 18        {u'score': 0, u'magnitude': 0}
# 19      {u'score': 0, u'magnitude': 1.3}
# 20    {u'score': 0.1, u'magnitude': 0.1}
# 21    {u'score': 0.5, u'magnitude': 0.5}
# 22   {u'score': -0.1, u'magnitude': 0.1}
# 23    {u'score': 0.3, u'magnitude': 0.7}
# 24    {u'score': 0.4, u'magnitude': 1.2}
# 25    {u'score': 0.6, u'magnitude': 0.6}
# 26    {u'score': 0.2, u'magnitude': 0.2}
# 27    {u'score': 0.3, u'magnitude': 0.6}
# 28    {u'score': 0.3, u'magnitude': 0.3}
# 29      {u'score': 0.1, u'magnitude': 2}
# ..                                   ...
# 512  {u'score': -0.4, u'magnitude': 0.4}
# 513     {u'score': 0, u'magnitude': 1.1}
# 514   {u'score': 0.1, u'magnitude': 0.1}
# 515     {u'score': 0, u'magnitude': 0.1}
# 516  {u'score': -0.1, u'magnitude': 0.1}
# 517  {u'score': -0.1, u'magnitude': 0.2}
# 518       {u'score': 0, u'magnitude': 0}
# 519     {u'score': 0, u'magnitude': 4.7}
# 520   {u'score': 0.1, u'magnitude': 1.1}
# 521  {u'score': -0.7, u'magnitude': 0.7}
# 522  {u'score': -0.4, u'magnitude': 0.4}
# 523  {u'score': -0.3, u'magnitude': 0.6}
# 524   {u'score': 0.3, u'magnitude': 0.7}
# 525       {u'score': 0, u'magnitude': 0}
# 526   {u'score': 0.1, u'magnitude': 0.8}
# 527   {u'score': 0.1, u'magnitude': 0.3}
# 528  {u'score': -0.5, u'magnitude': 0.5}
# 529     {u'score': 0, u'magnitude': 0.7}
# 530       {u'score': 0, u'magnitude': 0}
# 531   {u'score': 0.4, u'magnitude': 0.9}
# 532  {u'score': -0.2, u'magnitude': 0.2}
# 533     {u'score': 0, u'magnitude': 0.3}
# 534  {u'score': -0.1, u'magnitude': 0.1}
# 535     {u'score': 0, u'magnitude': 0.4}
# 536     {u'score': 0.5, u'magnitude': 1}
# 537   {u'score': 0.1, u'magnitude': 1.4}
# 538     {u'score': 0, u'magnitude': 0.7}
# 539     {u'score': 0, u'magnitude': 0.3}
# 540   {u'score': 0.3, u'magnitude': 0.6}
# 541   {u'score': 0.3, u'magnitude': 0.3}
#
#                                               entities  \
# 0    [{u'salience': 1, u'meta': {}, u'type': u'OTHE...
# 1                                                   []
# 2    [{u'salience': 1, u'meta': {}, u'type': u'OTHE...
# 3                                                   []
# 4    [{u'salience': 1, u'meta': {u'mid': u'/m/05d4r...
# 5    [{u'salience': 0.583006, u'meta': {}, u'type':...
# 6    [{u'salience': 0.8433054, u'meta': {u'mid': u'...
# 7    [{u'salience': 0.29372552, u'meta': {}, u'type...
# 8    [{u'salience': 1, u'meta': {}, u'type': u'LOCA...
# 9    [{u'salience': 1, u'meta': {}, u'type': u'PERS...
# 10   [{u'salience': 0.50794494, u'meta': {}, u'type...
# 11   [{u'salience': 0.587984, u'meta': {}, u'type':...
# 12   [{u'salience': 0.26486114, u'meta': {}, u'type...
# 13   [{u'salience': 0.8522242, u'meta': {}, u'type'...
# 14   [{u'salience': 0.5457904, u'meta': {}, u'type'...
# 15   [{u'salience': 0.6472829, u'meta': {u'mid': u'...
# 16   [{u'salience': 0.4217308, u'meta': {}, u'type'...
# 17   [{u'salience': 0.6453615, u'meta': {u'mid': u'...
# 18   [{u'salience': 1, u'meta': {}, u'type': u'LOCA...
# 19   [{u'salience': 0.37095958, u'meta': {}, u'type...
# 20   [{u'salience': 0.5032934, u'meta': {u'mid': u'...
# 21   [{u'salience': 0.57081145, u'meta': {}, u'type...
# 22   [{u'salience': 1, u'meta': {u'mid': u'/m/026kb...
# 23   [{u'salience': 0.79287213, u'meta': {}, u'type...
# 24   [{u'salience': 0.8474705, u'meta': {}, u'type'...
# 25   [{u'salience': 1, u'meta': {}, u'type': u'PERS...
# 26                                                  []
# 27   [{u'salience': 0.6424591, u'meta': {}, u'type'...
# 28   [{u'salience': 0.72024405, u'meta': {}, u'type...
# 29   [{u'salience': 0.32205275, u'meta': {}, u'type...
# ..                                                 ...
# 512  [{u'salience': 1, u'meta': {}, u'type': u'EVEN...
# 513  [{u'salience': 0.51759803, u'meta': {}, u'type...
# 514                                                 []
# 515  [{u'salience': 0.8058213, u'meta': {u'mid': u'...
# 516  [{u'salience': 1, u'meta': {}, u'type': u'PERS...
# 517  [{u'salience': 1, u'meta': {}, u'type': u'PERS...
# 518  [{u'salience': 0.83583826, u'meta': {u'mid': u...
# 519  [{u'salience': 0.5505257, u'meta': {u'mid': u'...
# 520  [{u'salience': 0.9148425, u'meta': {u'mid': u'...
# 521  [{u'salience': 0.74794286, u'meta': {u'mid': u...
# 522                                                 []
# 523  [{u'salience': 0.74846417, u'meta': {}, u'type...
# 524  [{u'salience': 0.742963, u'meta': {}, u'type':...
# 525  [{u'salience': 1, u'meta': {}, u'type': u'PERS...
# 526  [{u'salience': 0.64589727, u'meta': {}, u'type...
# 527  [{u'salience': 0.523416, u'meta': {u'mid': u'/...
# 528  [{u'salience': 1, u'meta': {}, u'type': u'LOCA...
# 529  [{u'salience': 1, u'meta': {}, u'type': u'OTHE...
# 530                                                 []
# 531  [{u'salience': 0.31489804, u'meta': {u'mid': u...
# 532                                                 []
# 533  [{u'salience': 0.50127876, u'meta': {}, u'type...
# 534  [{u'salience': 1, u'meta': {}, u'type': u'PERS...
# 535  [{u'salience': 0.6816547, u'meta': {}, u'type'...
# 536  [{u'salience': 0.34520563, u'meta': {}, u'type...
# 537  [{u'salience': 0.65680695, u'meta': {}, u'type...
# 538  [{u'salience': 0.24162053, u'meta': {}, u'type...
# 539  [{u'salience': 0.35777506, u'meta': {}, u'type...
# 540  [{u'salience': 0.63463855, u'meta': {}, u'type...
# 541  [{u'salience': 1, u'meta': {}, u'type': u'OTHE...
#
#                                                 tokens
# 0    [{u'index': 1, u'begin': 0, u'pos': u'ADJ', u'...
# 1    [{u'index': 0, u'begin': 0, u'pos': u'VERB', u...
# 2    [{u'index': 2, u'begin': 0, u'pos': u'VERB', u...
# 3    [{u'index': 0, u'begin': 0, u'pos': u'X', u'la...
# 4    [{u'index': 5, u'begin': 0, u'pos': u'NOUN', u...
# 5    [{u'index': 3, u'begin': 0, u'pos': u'DET', u'...
# 6    [{u'index': 3, u'begin': 0, u'pos': u'NOUN', u...
# 7    [{u'index': 2, u'begin': 0, u'pos': u'PRON', u...
# 8    [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...
# 9    [{u'index': 4, u'begin': 0, u'pos': u'PUNCT', ...
# 10   [{u'index': 2, u'begin': 0, u'pos': u'NOUN', u...
# 11   [{u'index': 15, u'begin': 0, u'pos': u'PUNCT',...
# 12   [{u'index': 1, u'begin': 0, u'pos': u'PUNCT', ...
# 13   [{u'index': 2, u'begin': 0, u'pos': u'NOUN', u...
# 14   [{u'index': 1, u'begin': 0, u'pos': u'PUNCT', ...
# 15   [{u'index': 4, u'begin': 0, u'pos': u'NOUN', u...
# 16   [{u'index': 1, u'begin': 0, u'pos': u'PUNCT', ...
# 17   [{u'index': 1, u'begin': 0, u'pos': u'NOUN', u...
# 18   [{u'index': 2, u'begin': 0, u'pos': u'NOUN', u...
# 19   [{u'index': 1, u'begin': 0, u'pos': u'PUNCT', ...
# 20   [{u'index': 9, u'begin': 0, u'pos': u'NOUN', u...
# 21   [{u'index': 4, u'begin': 0, u'pos': u'CONJ', u...
# 22   [{u'index': 5, u'begin': 0, u'pos': u'VERB', u...
# 23   [{u'index': 2, u'begin': 0, u'pos': u'ADV', u'...
# 24   [{u'index': 2, u'begin': 0, u'pos': u'DET', u'...
# 25   [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...
# 26   [{u'index': 1, u'begin': 0, u'pos': u'CONJ', u...
# 27   [{u'index': 1, u'begin': 0, u'pos': u'ADV', u'...
# 28   [{u'index': 0, u'begin': 0, u'pos': u'ADP', u'...
# 29   [{u'index': 1, u'begin': 0, u'pos': u'NOUN', u...
# ..                                                 ...
# 512  [{u'index': 3, u'begin': 0, u'pos': u'PRON', u...
# 513  [{u'index': 0, u'begin': 0, u'pos': u'ADV', u'...
# 514  [{u'index': 2, u'begin': 0, u'pos': u'PRON', u...
# 515  [{u'index': 1, u'begin': 0, u'pos': u'ADV', u'...
# 516  [{u'index': 1, u'begin': 0, u'pos': u'PUNCT', ...
# 517  [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...
# 518  [{u'index': 3, u'begin': 0, u'pos': u'NOUN', u...
# 519  [{u'index': 0, u'begin': 0, u'pos': u'VERB', u...
# 520  [{u'index': 2, u'begin': 0, u'pos': u'X', u'la...
# 521  [{u'index': 0, u'begin': 0, u'pos': u'NOUN', u...
# 522  [{u'index': 0, u'begin': 0, u'pos': u'X', u'la...
# 523  [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...
# 524  [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...
# 525  [{u'index': 2, u'begin': 0, u'pos': u'PRON', u...
# 526  [{u'index': 3, u'begin': 0, u'pos': u'DET', u'...
# 527  [{u'index': 3, u'begin': 0, u'pos': u'PRON', u...
# 528  [{u'index': 3, u'begin': 0, u'pos': u'ADV', u'...
# 529  [{u'index': 0, u'begin': 0, u'pos': u'X', u'la...
# 530  [{u'index': 2, u'begin': 0, u'pos': u'VERB', u...
# 531  [{u'index': 0, u'begin': 0, u'pos': u'X', u'la...
# 532  [{u'index': 1, u'begin': 0, u'pos': u'ADV', u'...
# 533  [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...
# 534  [{u'index': 1, u'begin': 0, u'pos': u'NOUN', u...
# 535  [{u'index': 3, u'begin': 0, u'pos': u'ADV', u'...
# 536  [{u'index': 3, u'begin': 0, u'pos': u'PRON', u...
# 537  [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...
# 538  [{u'index': 1, u'begin': 0, u'pos': u'NOUN', u...
# 539  [{u'index': 0, u'begin': 0, u'pos': u'NOUN', u...
# 540  [{u'index': 1, u'begin': 0, u'pos': u'PUNCT', ...
# 541  [{u'index': 3, u'begin': 0, u'pos': u'X', u'la...
#
# [542 rows x 6 columns]

# %% [markdown]
# ## Loading Saved Parsed Scripts

# %%
# read annotated script
fileName = os.path.join(os.getcwd(), 'prep_scripts', 'x-men_imsdb'+'_gapi.csv')
df = pd.read_csv(fileName, index_col=0, quotechar='"')
print df.head(5)

# convert annnotation strings to lists and dicts
parse = lambda x: ast.literal_eval(x)

# convert annotation strings for sentences, tokens, entities to parse trees
df.sentences = df.sentences.apply(parse)
df.entities = df.entities.apply(parse)
df.tokens = df.tokens.apply(parse)
df.sentiment = df.sentiment.apply(parse)

print df.head(5)

print df.sentences[0][0]['content']
print df.tokens[0][0]['index']
print df.entities[0][0]['salience']
# Out:
#         speaker                                           dialogue  \
# 0      narrator  BLACK Sounds of a train rolling to a halt, a s...
# 1  FRECKLED KID                   Man, what's the matter with you?
# 2      narrator  His friend is on the toilet with his head in h...
# 3  FRECKLED KID  Dude. Lighten up. She's just a girl. You just ...
# 4         SCOTT             No, my eyes... my eyes are killing me.
#
#                                            sentences  \
# 0  [{'content': u'BLACK Sounds of a train rolling...
# 1  [{'content': u"Man, what's the matter with you...
# 2  [{'content': u'His friend is on the toilet wit...
# 3  [{'content': u'Dude.', 'begin': 0, 'score': 0....
# 4  [{'content': u'No, my eyes... my eyes are kill...
#
#                            sentiment  \
# 0    {'score': 0, 'magnitude': 36.3}
# 1       {'score': 0, 'magnitude': 0}
# 2     {'score': 0.3, 'magnitude': 1}
# 3     {'score': 0, 'magnitude': 0.5}
# 4  {'score': -0.4, 'magnitude': 0.4}
#
#                                             entities  \
# 0  [{'salience': 0.06211695, 'meta': {}, 'type': ...
# 1  [{'salience': 0.7685706, 'meta': {}, 'type': u...
# 2  [{'salience': 0.51122355, 'meta': {}, 'type': ...
# 3  [{'salience': 1, 'meta': {}, 'type': u'PERSON'...
# 4  [{'salience': 0.53754914, 'meta': {}, 'type': ...
#
#                                               tokens
# 0  [{'index': 1, 'begin': 0, 'pos': u'NOUN', 'lab...
# 1  [{'index': 3, 'begin': 0, 'pos': u'X', 'label'...
# 2  [{'index': 1, 'begin': 0, 'pos': u'PRON', 'lab...
# 3  [{'index': 0, 'begin': 0, 'pos': u'NOUN', 'lab...
# 4  [{'index': 8, 'begin': 0, 'pos': u'X', 'label'...
#         speaker                                           dialogue  \
# 0      narrator  BLACK Sounds of a train rolling to a halt, a s...
# 1  FRECKLED KID                   Man, what's the matter with you?
# 2      narrator  His friend is on the toilet with his head in h...
# 3  FRECKLED KID  Dude. Lighten up. She's just a girl. You just ...
# 4         SCOTT             No, my eyes... my eyes are killing me.
#
#                                            sentences  \
# 0  [{u'content': u'BLACK Sounds of a train rollin...
# 1  [{u'content': u'Man, what's the matter with yo...
# 2  [{u'content': u'His friend is on the toilet wi...
# 3  [{u'content': u'Dude.', u'begin': 0, u'score':...
# 4  [{u'content': u'No, my eyes... my eyes are kil...
#
#                              sentiment  \
# 0    {u'score': 0, u'magnitude': 36.3}
# 1       {u'score': 0, u'magnitude': 0}
# 2     {u'score': 0.3, u'magnitude': 1}
# 3     {u'score': 0, u'magnitude': 0.5}
# 4  {u'score': -0.4, u'magnitude': 0.4}
#
#                                             entities  \
# 0  [{u'type': u'PERSON', u'meta': {}, u'salience'...
# 1  [{u'type': u'PERSON', u'meta': {}, u'salience'...
# 2  [{u'type': u'PERSON', u'meta': {}, u'salience'...
# 3  [{u'type': u'PERSON', u'meta': {}, u'salience'...
# 4  [{u'type': u'OTHER', u'meta': {}, u'salience':...
#
#                                               tokens
# 0  [{u'index': 1, u'begin': 0, u'pos': u'NOUN', u...
# 1  [{u'index': 3, u'begin': 0, u'pos': u'X', u'la...
# 2  [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...
# 3  [{u'index': 0, u'begin': 0, u'pos': u'NOUN', u...
# 4  [{u'index': 8, u'begin': 0, u'pos': u'X', u'la...
# BLACK Sounds of a train rolling to a halt, a shrill whistle.
# 1
# 0.06211695

# %%
print sum(df.entities.apply(len)), 'entities identified'

entList = df.entities.apply(lambda x: [ent['name'] for ent in x]).tolist()
entSet = set([val for x in entList for val in x])
print len(entSet), 'unique entities identified'

df['totalSent'] = df.sentiment.apply(lambda x: x['score']*x['magnitude'])

print('*'*50)
df_totalSent = df[['speaker', 'totalSent']].groupby('speaker').sum().reset_index()
print('good guys from the script:')
print(df_totalSent[df_totalSent.totalSent >= 0].sort_values(by='totalSent', ascending=False))

print('*'*50)
print('bad guys from the script:')
print(df_totalSent[df_totalSent.totalSent < 0].sort_values(by='totalSent'))
# Out:
# 6127 entities identified
# 2331 unique entities identified
# **************************************************
# good guys from the script:
#                    speaker  totalSent
# 34                narrator      26.40
# 33                  XAVIER       4.34
# 16                 MAGNETO       2.57
# 29                   STORM       1.79
# 32                   VOICE       0.49
# 3                    BEAST       0.46
# 9                  CYCLOPS       0.35
# 15                   LOGAN       0.31
# 4                   BRAD 1       0.30
# 19              NEWSCASTER       0.25
# 20     OPERATION COMMANDER       0.24
# 17                MYSTIQUE       0.12
# 30                    TOAD       0.08
# 21                    PYRO       0.07
# 6                   BRAD 3       0.07
# 7                   BRAD 4       0.05
# 1            AGENTíS VOICE       0.04
# 0           AGENT/MYSTIQUE       0.01
# 18  MYSTIQUE/AGENTíS VOICE       0.00
# 22       REPORTERS/VARIOUS       0.00
# 26   SECRET SERVICE MAN #3       0.00
# 27           SENATOR ROWEE       0.00
# **************************************************
# bad guys from the script:
#           speaker  totalSent
# 13           JEAN      -1.43
# 23          ROGUE      -0.49
# 14          KELLY      -0.34
# 25          SCOTT      -0.25
# 24     SABRETOOTH      -0.20
# 5          BRAD 2      -0.16
# 12    INTERVIEWER      -0.16
# 31    TRANSIT COP      -0.16
# 11        GUYRICH      -0.09
# 10   FRECKLED KID      -0.05
# 8   CHILDíS VOICE      -0.02
# 2       ANCHORMAN      -0.01
# 28     SMALL GIRL      -0.01

# %% [markdown]
# ## Models for Relationship Extraction

# %%
def simpleRE(tokens):
    relation = []
    nsubj = -1
    verb = -1
    for i, token in enumerate(tokens):
        if token['label'] == 'NSUBJ':
            nsubj = i
            verb = token['index']
        if 'OBJ' in token['label'] and token['index'] == verb:
            relation.append({'verb':tokens[verb]['content'], 'noun':tokens[nsubj]['content'], 'obj':tokens[i]['content']})
        
    if relation:
        return relation
    else:
        return None

#basic relationship extraction
df['relations'] = None
for i in range(len(df)):
    df.set_value(i, 'relations', simpleRE(df.loc[i, 'tokens']))
    
df.head(10)
# Out:
#               speaker                                           dialogue  \
# 0            narrator  first lines; Loki has allied with the alien ra...
# 1           The Other  [voice over] The Tesseract has awakened. It is...
# 2            narrator  Nick Fury and Maria Hill arrive at a remote re...
# 3           Nick Fury                                     How bad is it?
# 4  Agent Phil Coulson            That's the problem, sir. We don't know.
# 5            narrator                              an elevator goes down
# 6  Agent Phil Coulson  Dr. Selvig read an energy surge from the Tesse...
# 7           Nick Fury  NASA didn't authorize Selvig to test the Tesse...
# 8  Agent Phil Coulson  He wasn't testing it, he wasn't even in the ro...
# 9    Agent Maria Hill                          It just turned itself on?
#
#                                            sentences  \
# 0  [{u'content': u'first lines; Loki has allied w...
# 1  [{u'content': u'[voice over] The Tesseract has...
# 2  [{u'content': u'Nick Fury and Maria Hill arriv...
# 3  [{u'content': u'How bad is it?', u'begin': 0, ...
# 4  [{u'content': u'That's the problem, sir.', u'b...
# 5  [{u'content': u'an elevator goes down', u'begi...
# 6  [{u'content': u'Dr. Selvig read an energy surg...
# 7  [{u'content': u'NASA didn't authorize Selvig t...
# 8  [{u'content': u'He wasn't testing it, he wasn'...
# 9  [{u'content': u'It just turned itself on?', u'...
#
#                              sentiment  \
# 0  {u'score': -0.1, u'magnitude': 0.1}
# 1   {u'score': 0.1, u'magnitude': 1.6}
# 2   {u'score': 0.4, u'magnitude': 0.4}
# 3  {u'score': -0.4, u'magnitude': 0.4}
# 4       {u'score': 0, u'magnitude': 0}
# 5       {u'score': 0, u'magnitude': 0}
# 6   {u'score': 0.1, u'magnitude': 0.1}
# 7  {u'score': -0.8, u'magnitude': 0.8}
# 8    {u'score': -0.2, u'magnitude': 1}
# 9  {u'score': -0.5, u'magnitude': 0.5}
#
#                                             entities  \
# 0  [{u'salience': 0.34743184, u'meta': {}, u'type...
# 1  [{u'salience': 0.31685632, u'meta': {}, u'type...
# 2  [{u'salience': 0.5691925, u'meta': {u'mid': u'...
# 3                                                 []
# 4  [{u'salience': 0.85199714, u'meta': {}, u'type...
# 5  [{u'salience': 1, u'meta': {}, u'type': u'OTHE...
# 6  [{u'salience': 0.6954503, u'meta': {}, u'type'...
# 7  [{u'salience': 0.638119, u'meta': {u'mid': u'/...
# 8  [{u'salience': 0.5917055, u'meta': {}, u'type'...
# 9                                                 []
#
#                                               tokens  totalSent  \
# 0  [{u'index': 1, u'begin': 0, u'pos': u'ADJ', u'...      -0.01
# 1  [{u'index': 1, u'begin': 0, u'pos': u'PUNCT', ...       0.16
# 2  [{u'index': 1, u'begin': 0, u'pos': u'NOUN', u...       0.16
# 3  [{u'index': 1, u'begin': 0, u'pos': u'ADV', u'...      -0.16
# 4  [{u'index': 1, u'begin': 0, u'pos': u'DET', u'...       0.00
# 5  [{u'index': 1, u'begin': 0, u'pos': u'DET', u'...       0.00
# 6  [{u'index': 1, u'begin': 0, u'pos': u'NOUN', u...       0.01
# 7  [{u'index': 3, u'begin': 0, u'pos': u'NOUN', u...      -0.64
# 8  [{u'index': 3, u'begin': 0, u'pos': u'PRON', u...      -0.20
# 9  [{u'index': 2, u'begin': 0, u'pos': u'PRON', u...      -0.25
#
#                                            relations
# 0  [{u'obj': u'Earth', u'verb': u'subjugate', u'n...
# 1  [{u'obj': u'power', u'verb': u'wield', u'noun'...
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  [{u'obj': u'surge', u'verb': u'read', u'noun':...
# 7  [{u'obj': u'Selvig', u'verb': u'authorize', u'...
# 8  [{u'obj': u'it', u'verb': u'testing', u'noun':...
# 9  [{u'obj': u'itself', u'verb': u'turned', u'nou...

# %%
for i in range(50):
    t = df[df.relations.notnull()].sample(1)
    print 'dialogue:', t.dialogue
    #print len(t.relations)
    for relation in t.relations.values[0]:
        print relation
# Out:
# dialogue: 227    I told him.
# Name: dialogue, dtype: object
# {'obj': u'him', 'verb': u'told', 'noun': u'I'}
# dialogue: 510    Why have you done this?
# Name: dialogue, dtype: object
# {'obj': u'this', 'verb': u'done', 'noun': u'you'}
# dialogue: 173    Darcy hold her taser gun at him
# Name: dialogue, dtype: object
# {'obj': u'gun', 'verb': u'hold', 'noun': u'Darcy'}
# dialogue: 340    Well, they just stole my entire life's work. I...
# Name: dialogue, dtype: object
# {'obj': u'work', 'verb': u'stole', 'noun': u'they'}
# dialogue: 516    [shouting] I will not fight you, brother!
# Name: dialogue, dtype: object
# {'obj': u'you', 'verb': u'fight', 'noun': u'I'}
# dialogue: 116    We will accept, your most gracious offer.
# Name: dialogue, dtype: object
# {'obj': u'offer', 'verb': u'accept', 'noun': u'We'}
# dialogue: 365    No. I'm gonna fly out. [he leaves her] [after ...
# Name: dialogue, dtype: object
# {'obj': u'her', 'verb': u'leaves', 'noun': u'he'}
# dialogue: 69    Thor gives him a knowing look
# Name: dialogue, dtype: object
# {'obj': u'him', 'verb': u'gives', 'noun': u'Thor'}
# {'obj': u'look', 'verb': u'gives', 'noun': u'Thor'}
# dialogue: 409    Neither did I. My father was trying to teach m...
# Name: dialogue, dtype: object
# {'obj': u'I', 'verb': u'did', 'noun': u'Neither'}
# dialogue: 538    Legend tell us one thing, history another. But...
# Name: dialogue, dtype: object
# {'obj': u'us', 'verb': u'tell', 'noun': u'Legend'}
# {'obj': u'thing', 'verb': u'tell', 'noun': u'Legend'}
# {'obj': u'something', 'verb': u'find', 'noun': u'we'}
# {'obj': u'case', 'verb': u'opens', 'noun': u'he'}
# dialogue: 340    Well, they just stole my entire life's work. I...
# Name: dialogue, dtype: object
# {'obj': u'work', 'verb': u'stole', 'noun': u'they'}
# dialogue: 424    You were shrouded from me like the Frost Giant...
# Name: dialogue, dtype: object
# {'obj': u'realm', 'verb': u'entered', 'noun': u'Giants'}
# dialogue: 486    No! I will die a warrior death! Stories will b...
# Name: dialogue, dtype: object
# {'obj': u'death', 'verb': u'die', 'noun': u'I'}
# dialogue: 169    Heimdall? I know you can hear me! Open the Bif...
# Name: dialogue, dtype: object
# {'obj': u'me', 'verb': u'hear', 'noun': u'you'}
# dialogue: 495    Borrowed. [Coulson pauses from a moment before...
# Name: dialogue, dtype: object
# {'obj': u'equipment', 'verb': u'have', 'noun': u'you'}
# dialogue: 535    So, you're the man behind all this? [he walks ...
# Name: dialogue, dtype: object
# {'obj': u'me', 'verb': u'taking', 'noun': u'they'}
# dialogue: 213    I'm so sorry! I swear I'm not doing this on pu...
# Name: dialogue, dtype: object
# {'obj': u'this', 'verb': u'doing', 'noun': u'I'}
# dialogue: 296    Yes. All the answers you seek will be yours, o...
# Name: dialogue, dtype: object
# {'obj': u'Mj\xf6llnir', 'verb': u'reclaim', 'noun': u'I'}
# dialogue: 510    Why have you done this?
# Name: dialogue, dtype: object
# {'obj': u'this', 'verb': u'done', 'noun': u'you'}
# dialogue: 210    she starts her car
# Name: dialogue, dtype: object
# {'obj': u'car', 'verb': u'starts', 'noun': u'she'}
# dialogue: 19    [voice over] With the last great war ended, we...
# Name: dialogue, dtype: object
# {'obj': u'peace', 'verb': u'brought', 'noun': u'that'}
# dialogue: 442    My father explained it to me like this, that y...
# Name: dialogue, dtype: object
# {'obj': u'it', 'verb': u'explained', 'noun': u'father'}
# {'obj': u'it', 'verb': u'see', 'noun': u'you'}
# {'obj': u'it', 'verb': u'call', 'noun': u'you'}
# dialogue: 415    So you're the one who showed us the way into A...
# Name: dialogue, dtype: object
# {'obj': u'us', 'verb': u'showed', 'noun': u'who'}
# {'obj': u'way', 'verb': u'showed', 'noun': u'who'}
# dialogue: 269    Also how could you eat an entire box of Pop Ta...
# Name: dialogue, dtype: object
# {'obj': u'box', 'verb': u'eat', 'noun': u'you'}
# dialogue: 7    I'm telling you, there's a connection between ...
# Name: dialogue, dtype: object
# {'obj': u'you', 'verb': u'telling', 'noun': u'I'}
# {'obj': u'you', 'verb': u'ask', 'noun': u'I'}
# dialogue: 540    [whispering] Well, I guess that's worth a look...
# Name: dialogue, dtype: object
# {'obj': u'words', 'verb': u'repeats', 'noun': u'Erik'}
# dialogue: 474    You think the Bifrost is the only way in and o...
# Name: dialogue, dtype: object
# {'obj': u'need', 'verb': u'have', 'noun': u'I'}
# dialogue: 373    But you're the one who's always pushing me to ...
# Name: dialogue, dtype: object
# {'obj': u'me', 'verb': u'pushing', 'noun': u'who'}
# dialogue: 450    We must go. We must find Thor.
# Name: dialogue, dtype: object
# {'obj': u'Thor', 'verb': u'find', 'noun': u'We'}
# dialogue: 370    Look! Look! It's Meowmeo. [she shows the pictu...
# Name: dialogue, dtype: object
# {'obj': u'picture', 'verb': u'shows', 'noun': u'she'}
# dialogue: 336    We don't have horses. Just dogs, cats, birds.
# Name: dialogue, dtype: object
# {'obj': u'horses', 'verb': u'have', 'noun': u'We'}
# dialogue: 102    Heimdall sends them to Jotunheim
# Name: dialogue, dtype: object
# {'obj': u'them', 'verb': u'sends', 'noun': u'Heimdall'}
# dialogue: 182    she spells out his name as she types on her co...
# Name: dialogue, dtype: object
# {'obj': u'name', 'verb': u'spells', 'noun': u'she'}
# dialogue: 373    But you're the one who's always pushing me to ...
# Name: dialogue, dtype: object
# {'obj': u'me', 'verb': u'pushing', 'noun': u'who'}
# dialogue: 496    Uh...sure. [he pulls Jane close to him and the...
# Name: dialogue, dtype: object
# {'obj': u'Jane', 'verb': u'pulls', 'noun': u'he'}
# dialogue: 305    I'm sorry. But I can't take you.
# Name: dialogue, dtype: object
# {'obj': u'you', 'verb': u'take', 'noun': u'I'}
# dialogue: 485    Sif, you've done all you can.
# Name: dialogue, dtype: object
# {'obj': u'all', 'verb': u'done', 'noun': u'you'}
# dialogue: 169    Heimdall? I know you can hear me! Open the Bif...
# Name: dialogue, dtype: object
# {'obj': u'me', 'verb': u'hear', 'noun': u'you'}
# dialogue: 236    We should be grateful to him. He saved our lives.
# Name: dialogue, dtype: object
# {'obj': u'lives', 'verb': u'saved', 'noun': u'He'}
# dialogue: 29    Thor Odinson, my heir, my first born. So long ...
# Name: dialogue, dtype: object
# {'obj': u'equal', 'verb': u'has', 'noun': u'power'}
# {'obj': u'Asgard', 'verb': u'defended', 'noun': u'I'}
# dialogue: 218    My ex! Good with patience and bad with relatio...
# Name: dialogue, dtype: object
# {'obj': u'you', 'verb': u'fit', 'noun': u'that'}
# dialogue: 63    It'll come. In time. If it's any consolation, ...
# Name: dialogue, dtype: object
# {'obj': u'way', 'verb': u'found', 'noun': u'they'}
# dialogue: 387    You're banishment. The threat of a new war. It...
# Name: dialogue, dtype: object
# {'obj': u'yourself', 'verb': u'blame', 'noun': u'You'}
# {'obj': u'him', 'verb': u'loved', 'noun': u'you'}
# {'obj': u'it', 'verb': u'lift', 'noun': u'you'}
# dialogue: 495    Borrowed. [Coulson pauses from a moment before...
# Name: dialogue, dtype: object
# {'obj': u'equipment', 'verb': u'have', 'noun': u'you'}
# dialogue: 169    Heimdall? I know you can hear me! Open the Bif...
# Name: dialogue, dtype: object
# {'obj': u'me', 'verb': u'hear', 'noun': u'you'}
# dialogue: 61    Loki rounds the corner to join him
# Name: dialogue, dtype: object
# {'obj': u'corner', 'verb': u'rounds', 'noun': u'Loki'}
# dialogue: 97    Be warned. I will honor my sworn oath to prote...
# Name: dialogue, dtype: object
# {'obj': u'oath', 'verb': u'honor', 'noun': u'I'}
# {'obj': u'threatens', 'verb': u'return', 'noun': u'you'}
# {'obj': u'safety', 'verb': u'return', 'noun': u'you'}
# dialogue: 493    Know this, son of Coul. You and I, we fight fo...
# Name: dialogue, dtype: object
# {'obj': u'protection', 'verb': u'fight', 'noun': u'we'}
# {'obj': u'me', 'verb': u'count', 'noun': u'you'}
# {'obj': u'items', 'verb': u'return', 'noun': u'you'}
# dialogue: 405    For the first time in...in my life, I have no ...
# Name: dialogue, dtype: object
# {'obj': u'idea', 'verb': u'have', 'noun': u'I'}
# dialogue: 505    Why don't you tell her? How you sent the Destr...
# Name: dialogue, dtype: object
# {'obj': u'her', 'verb': u'tell', 'noun': u'you'}
# {'obj': u'Destroyer', 'verb': u'sent', 'noun': u'you'}

# %% [markdown]
# ## Validating Extracted Relations

# %%
def REPrecision(df, num=50):
    goodRE = 0.0
    for i in range(num):
        t = df[df.relations.notnull()].sample(1)
        print 'DIALOGUE:', t.dialogue
        print 'RELATION:', random.choice(t.relations.values[0])
        x = raw_input('Is this a good relation?')
        if not x or x[0] == 'y':
            goodRE += 1
    print 'precision: ', goodRE/num
    
REPrecision(df)
# Out:
# DIALOGUE: 16    {voice over] Our armies drove the Frost Giants...
# Name: dialogue, dtype: object
# RELATION: {'obj': u'Giants', 'verb': u'drove', 'noun': u'armies'}
# Is this a good relation?yes
# DIALOGUE: 296    Yes. All the answers you seek will be yours, o...
# Name: dialogue, dtype: object
# RELATION: {'obj': u'Mj\xf6llnir', 'verb': u'reclaim', 'noun': u'I'}
# Is this a good relation?yes
# DIALOGUE: 50    He just broke your truce! They know you are vu...
# Name: dialogue, dtype: object
# RELATION: {'obj': u'truce', 'verb': u'broke', 'noun': u'He'}
# Is this a good relation?yes
# DIALOGUE: 464    Found you! [Thor looks up. Jane, Darcy and Eri...
# Name: dialogue, dtype: object
# RELATION: {'obj': u'cup', 'verb': u'drops', 'noun': u'Erik'}
