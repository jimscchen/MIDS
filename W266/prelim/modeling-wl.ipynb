# %%
# %load_ext autoreload
# %autoreload 2

import re
import nltk
import numpy as np
import pandas as pd
import os
from pronounResolution import *
from relationExtract import *
from collections import defaultdict

# %% [markdown]
# ## Prepare Dataset

# %%
# returns dataframe with script annotations
def loadScript(file_name):
    # read file
    df = pd.read_csv('prep_scripts/' + file_name)[['speaker', 'dialogue', 'sentences', 'sentiment', 'entities', 'tokens']]

    # evaluate strings for lists/dicts of tokens, sentiment, entities
    df['tokens'] = df['tokens'].apply(lambda x: eval(x))
    df['sentiment'] = df['sentiment'].apply(lambda x: eval(x))
    df['speaker'] = df['speaker'].apply(lambda x: x.strip())
    df['entities'] = df['entities'].apply(lambda x: eval(x))
    
    return df

# enhances annotations with pronoun counts, nearby speakers, and sentiments for each line
def annotateScript(df):
   
    # number of pronouns for each line
    df['num_pron'] = df['tokens'].apply(lambda x: sum([int(t['pos'] == 'PRON') for t in x]))

    # total sentiment score for each line
    df['total_sent'] = df['sentiment'].apply(lambda x: x['score'] * x['magnitude'])

    # previous and next speaker for each line
    df['speaker_prev'] = df.speaker.shift(1)
    df['speaker_next'] = df.speaker.shift(-1)

    # nearby speakers for each line - 2 speakers before and after current speaker
    df['nearbyChars'] = None
    nearbyChars = np.dstack((df.speaker.shift(i).values for i in range(-2, 3)[::-1]))[0]
    for i in range(len(df)):
        df.set_value(i, 'nearbyChars', nearbyChars[i])

    return df

# %% [markdown]
# View files for annotated movie scripts.

# %%
# get files for annotated scripts
files = [x for x in os.listdir('prep_scripts') if '_gapi.csv' in x]

print 'annotated scripts:'
for i, f in enumerate(files):
    print i, f
# Out:
# annotated scripts:
# 0 ant-man_tw_gapi.csv
# 1 avengers_age_of_ultron_tw_gapi.csv
# 2 captain_america_civil_war_tw_gapi.csv
# 3 captain_america_the_first_avenger_tw_gapi.csv
# 4 captain_america_the_winter_soldier_tw_gapi.csv
# 5 fantastic_four_imsdb_gapi.csv
# 6 iron_man_3_tw_gapi.csv
# 7 lego_marvel_super_heroes_tw_gapi.csv
# 8 spider-man_imsdb_gapi.csv
# 9 the_amazing_spider-man_2_tw_gapi.csv
# 10 the_amazing_spider-man_tw_gapi.csv
# 11 the_avengers_tw_gapi.csv
# 12 the_wolverine_tw_gapi.csv
# 13 thor_the_dark_world_tw_gapi.csv
# 14 thor_tw_gapi.csv
# 15 x-men_apocalypse_tw_gapi.csv
# 16 x-men_days_of_future_past_tw_gapi.csv
# 17 x-men_imsdb_gapi.csv
# 18 x-men_the_last_stand_tw_gapi.csv

# %% [markdown]
# 1. Load set of annotated scripts to be analyzed.
# 2. Enhance annotated scripts with features for speakers, sentiment, and pronouns

# %%
 # list of file indexes for Avengers (1,11) and X-Men movies (15-19)
fileIndex = [1, 11, 15, 16, 18]

# dict to hold name, annotations, characters, and other info for scripts
scripts = defaultdict(lambda: defaultdict())

for i in fileIndex:
    # load annotated script
    df = loadScript(files[i])
    
    # add features to annotated script
    df = annotateScript(df)
    scripts[i]['name'] = files[i]
    scripts[i]['df'] = df
    
    # list of unique characters, mentions, overall sentiment
    charMentions = dict(df.groupby('speaker').speaker.count())
#     charSentiment = dict(df.groupby('speaker').total_sent.sum())
    charList = charMentions.keys()

    # add unique characters
    scripts[i]['chars'] = charMentions
    
# print scripts[1]['name']
# print scripts[1]['chars']
scripts[11]['df'].head()
# Out:
#               speaker                                           dialogue  \
# 0            narrator  first lines; Loki has allied with the alien ra...
# 1           The Other  [voice over] The Tesseract has awakened. It is...
# 2            narrator  Nick Fury and Maria Hill arrive at a remote re...
# 3           Nick Fury                                     How bad is it?
# 4  Agent Phil Coulson            That's the problem, sir. We don't know.
#
#                                            sentences  \
# 0  [{'content': u'first lines; Loki has allied wi...
# 1  [{'content': u'[voice over] The Tesseract has ...
# 2  [{'content': u'Nick Fury and Maria Hill arrive...
# 3  [{'content': u'How bad is it?', 'begin': 0, 's...
# 4  [{'content': u"That's the problem, sir.", 'beg...
#
#                              sentiment  \
# 0  {u'score': -0.1, u'magnitude': 0.1}
# 1   {u'score': 0.1, u'magnitude': 1.6}
# 2   {u'score': 0.4, u'magnitude': 0.4}
# 3  {u'score': -0.4, u'magnitude': 0.4}
# 4       {u'score': 0, u'magnitude': 0}
#
#                                             entities  \
# 0  [{u'type': u'OTHER', u'meta': {}, u'salience':...
# 1  [{u'type': u'OTHER', u'meta': {}, u'salience':...
# 2  [{u'type': u'PERSON', u'meta': {u'mid': u'/m/0...
# 3                                                 []
# 4  [{u'type': u'OTHER', u'meta': {}, u'salience':...
#
#                                               tokens  num_pron  total_sent  \
# 0  [{u'index': 1, u'begin': 0, u'pos': u'ADJ', u'...         1       -0.01
# 1  [{u'index': 1, u'begin': 0, u'pos': u'PUNCT', ...        11        0.16
# 2  [{u'index': 1, u'begin': 0, u'pos': u'NOUN', u...         0        0.16
# 3  [{u'index': 1, u'begin': 0, u'pos': u'ADV', u'...         1       -0.16
# 4  [{u'index': 1, u'begin': 0, u'pos': u'DET', u'...         1        0.00
#
#   speaker_prev        speaker_next  \
# 0          NaN           The Other
# 1     narrator            narrator
# 2    The Other           Nick Fury
# 3     narrator  Agent Phil Coulson
# 4    Nick Fury            narrator
#
#                                          nearbyChars
# 0          [nan, nan, narrator, The Other, narrator]
# 1    [nan, narrator, The Other, narrator, Nick Fury]
# 2  [narrator, The Other, narrator, Nick Fury, Age...
# 3  [The Other, narrator, Nick Fury, Agent Phil Co...
# 4  [narrator, Nick Fury, Agent Phil Coulson, narr...

# %% [markdown]
# ## Task 1: Pronoun Resolution

# %% [markdown]
# Apply each model for pronoun resolution to multiple scripts.  Evaluate model by manually checking if characters for resolved pronouns are correct.

# %%
def selectEvalLines(df, numExamples):
    
    # indexes for lines of dialogue with resolved pronouns
    pronIndex = list(df[df.num_pron > 0].index)
    
    # sample random line to evaluate resolved pronoun
    evalLines = np.random.choice(pronIndex, min(len(pronIndex), numExamples), replace=False)
    
    return evalLines

# %% [markdown]
# Identify characters and choose lines to evaluate for each script

# %%
# for all scripts
for i in fileIndex:
    
    # get lines to evaluate for each script
    scripts[i]['eval'] = selectEvalLines(scripts[i]['df'], numExamples=20)

print scripts[1]['eval']
# Out:
# [245 768 512 874 196 606 781 451 599 906 248 202 222 955 198 378 752 103
#  195 115]

# %% [markdown]
# Model 0 (pronResolution_base): sets reference as random character from script

# %%
# copy scripts
scripts0 = scripts.copy()

# apply model to all scripts
for i in fileIndex:
    charList = scripts0[i]['chars'].keys()  
    scripts0[i]['df'].apply(lambda x: pronResolution_base(charList, x), axis=1)
    
# manually evaluate results for all scripts
pronEval(scripts0)
# Out:
# ******** line 116 ********
# 114. narrator:
# in Washington D.C., Trask is meeting with Congress to lobby his Sentinel program
#
# 115. Senator Brickman:
# We are reviewing all of our defense expenditures... and all the black books are being opened. We can't support a weapon that targets our own citizens. If these mutants as you describe... are already living among us... then they are living here peacefully. We haven't had an incident in over 10 years.
#
# => 116. Senator Brickman:
# => We are talking about a tenth of a tenth... of a tenth population.
#
# 117. Dr. Trask:
# Allow me to read something to you.
#
# 118. Senator Parker:
# Please.
#
# ******** evaluate line 116 in x-men_days_of_future_past_tw_gapi.csv ********
# 1 pronouns resolved
# 1. We => Quicksilver
#
# how many are correctly identified? 0
#
# ******** line 170 ********
# 168. narrator:
# Wolverine arrives at the X-Mansion which looks abandoned and run down, he notices the sign for Xavier School fallen on the ground, he drives to the front door, gets out of his car and knocks on the front door which is opened by Hank McCoy / Beast
#
# 169. Hank:
# Can I help you?
#
# => 170. Past Wolverine:
# => Uh... Yeah, what happened to the school?
#
# 171. Hank:
# The school's been shut for years. Are you a parent? Past Wolverine:[scoffs] I sure as hell hope not. Who are you?
#
# 172. Hank:
# I'm Hank. Hank McCoy. I look after the house now.
#
# ******** evaluate line 170 in x-men_days_of_future_past_tw_gapi.csv ********
# 1 pronouns resolved
# 1. what => Senator Parker
#
# how many are correctly identified? 0
#
# ******** line 144 ********
# 142. narrator:
# as the soldier prepares the injection Sanders walks over to Stryker
#
# 143. Colonel:
# Your men are not military.
#
# => 144. Stryker:
# => Private outfit. [Stryker gives Sanders his paperwork] We're authorized to remand these men.
#
# 145. Colonel:
# [Sanders looks at the papers] Hmm. These troops are going home.
#
# 146. Stryker:
# Well, Colonel, I don't believe you have jurisdiction in this matter.
#
# ******** evaluate line 144 in x-men_days_of_future_past_tw_gapi.csv ********
# 2 pronouns resolved
# 1. his => Colossus
# 2. We => Warpath
#
# how many are correctly identified? 0
#
# ******** line 78 ********
# 76. Kitty:
# Basically, your body will go to sleep. While your mind travels back in time. As long as you're back there, past and present will continue to coexist. But you once wake up... whatever you've done will take hold and become history. And for the rest of us, it will be the only history that we know. It will be like the last that 50 years never happened. And this world, and this war... the only person who remember it is you. All right, Logan... I need you to clear your head and to stay as calm as possible.
#
# 77. Wolverine:
# What? What do you mean?
#
# => 78. Kitty:
# => If your mind gets rocky, it will be harder for me to hold you... and you could start to slip between past and future.
#
# 79. Wolverine:
# What if I need to get a little rocky?
#
# 80. Kitty:
# Think peaceful thoughts?
#
# ******** evaluate line 78 in x-men_days_of_future_past_tw_gapi.csv ********
# 5 pronouns resolved
# 1. your => Sunspot
# 2. it => Senator Brickman
# 3. me => Hank
# 4. you => Kitty
# 5. you => Guy
#
# how many are correctly identified? 0
#
# ******** line 291 ********
# 289. Ms. Maximoff:
# What's he done now? I just write you a check for whatever he took.
#
# 290. Past Wolverine:
# We just need to talk to him.
#
# => 291. narrator:
# => she lets them enter
#
# 292. Ms. Maximoff:
# Peter! The cops are here. Again.
#
# 293. narrator:
# the three walk down to the basement where Peter is playing table tennis with himself using his powers of speed
#
# ******** evaluate line 291 in x-men_days_of_future_past_tw_gapi.csv ********
# 2 pronouns resolved
# 1. she => Quicksilver
# 2. them => narrator
#
# how many are correctly identified? 0
#
# ******** line 263 ********
# 261. Hank:
# Uh, JFK.
#
# 262. Past Wolverine:
# he killed...
#
# => 263. Young Charles:
# => What else explains a bullet miraculously curving through the air? Erik's always had a way with guns. Are you sure you want to carry on with this?
#
# 264. Young Charles:
# This is your plan, not mine.
#
# 265. Hank:
# We don't have any resources to get us in.
#
# ******** evaluate line 263 in x-men_days_of_future_past_tw_gapi.csv ********
# 3 pronouns resolved
# 1. What => Guy
# 2. you => Colonel
# 3. you => Senator Parker
#
# how many are correctly identified? 0
#
# ******** line 147 ********
# 145. Colonel:
# [Sanders looks at the papers] Hmm. These troops are going home.
#
# 146. Stryker:
# Well, Colonel, I don't believe you have jurisdiction in this matter.
#
# => 147. Colonel:
# => I'm afraid I do, son.
#
# 148. Stryker:
# I'm sorry, who are you?
#
# 149. narrator:
# Sanders turns Stryker's dog tags around to look at his name
#
# ******** evaluate line 147 in x-men_days_of_future_past_tw_gapi.csv ********
# 2 pronouns resolved
# 1. I => Warpath
# 2. I => Young Raven
#
# how many are correctly identified? 0
#
# ******** line 237 ********
# 235. Past Wolverine:
# You're just gonna walk out?
#
# 236. Young Charles:
# Ooh, top marks. Like I said, you are perceptive.
#
# => 237. Past Wolverine:
# => The Professor I know would never turn his back... on someone who'd lost their path. Especially someone he loved.
#
# 238. narrator:
# Logan angrily grabs hold of Charles
#
# 239. Past Wolverine:
# Listen to me, you little shit. I've come a long way, and I've watched a lot of people die. Good people. Friends. If you're gonna wallow in self-pity... and do nothing, then you're gonna watch the same thing... you understand?
#
# ******** evaluate line 237 in x-men_days_of_future_past_tw_gapi.csv ********
# 5 pronouns resolved
# 1. I => Toad
# 2. his => Young Raven
# 3. who => Mystique
# 4. their => Bishop
# 5. he => Beast
#
# how many are correctly identified? 0
#
# ******** line 18 ********
# 16. narrator:
# Kitty takes Bishop into a vault and starts to create a link with his consciousness. At the same time Blink goes to help Warpath fight the Sentinels when one of them strikes her down
#
# 17. Warpath:
# Blink! No!
#
# => 18. narrator:
# => she falls and dies. The remaining Sentinels quickly kill Warpath as he tries to protect the vault, and one of the Sentinels breaks into the vault
#
# 19. Kitty:
# Too late, assholes.
#
# 20. narrator:
# just as the Sentinel is about to kill Bishop and Kitty they disappear as they are transported out of there
#
# ******** evaluate line 18 in x-men_days_of_future_past_tw_gapi.csv ********
# 2 pronouns resolved
# 1. she => Guy
# 2. he => Mystique
#
# how many are correctly identified? 0
#
# ******** line 76 ********
# 74. Magneto:
# Well, it's complicated.
#
# 75. narrator:
# Logan is lying down as Kitty prepares him
#
# => 76. Kitty:
# => Basically, your body will go to sleep. While your mind travels back in time. As long as you're back there, past and present will continue to coexist. But you once wake up... whatever you've done will take hold and become history. And for the rest of us, it will be the only history that we know. It will be like the last that 50 years never happened. And this world, and this war... the only person who remember it is you. All right, Logan... I need you to clear your head and to stay as calm as possible.
#
# 77. Wolverine:
# What? What do you mean?
#
# 78. Kitty:
# If your mind gets rocky, it will be harder for me to hold you... and you could start to slip between past and future.
#
# ******** evaluate line 76 in x-men_days_of_future_past_tw_gapi.csv ********
# 15 pronouns resolved
# 1. your => Guy
# 2. your => Soldier
# 3. you => Trask(flashback)
# 4. you => Senator Brickman
# 5. you => Young Raven
# 6. us => Stryker
# 7. it => Professor X
# 8. we => Toad
# 9. It => Ms. Maximoff
# 10. who => Bishop
# 11. it => Trask(flashback)
# 12. you => Hank
# 13. I => Beast
# 14. you => Senator Brickman
# 15. your => Sunspot
#
# how many are correctly identified? 0
#
# ******** line 67 ********
# 65. Professor X:
# You'll need to go to my house and find me. Convince me of all of this.
#
# 66. Wolverine:
# Won't you be able to just read my mind?
#
# => 67. Professor X:
# => I didn't have my powers in 1973. Logan, you're going to have to do for me what I once did for you. Lead me, guide me. I was a very different man then. You'll have to be patient with me.
#
# 68. Wolverine:
# Patience is my strongest suit.
#
# 69. Magneto:
# You'll need me as well.
#
# ******** evaluate line 67 in x-men_days_of_future_past_tw_gapi.csv ********
# 12 pronouns resolved
# 1. I => Guy
# 2. my => Quicksilver
# 3. you => Guy
# 4. me => Ms. Maximoff
# 5. what => Ramone
# 6. I => Stryker
# 7. you => Gwen
# 8. me => Bobby
# 9. me => Kitty
# 10. I => Senator Parker
# 11. You => Gwen
# 12. me => Mystique
#
# how many are correctly identified? 0
#
# ******** line 296 ********
# 294. Quicksilver:
# What do you guys want? I didn't do anything. [suddenly he sits down on the couch] I've been here all day.
#
# 295. Past Wolverine:
# Just relax, Peter. We're not Cops.
#
# => 296. Quicksilver:
# => Of course you're not. If you were, you wouldn't be driving a rental car.
#
# 297. Young Charles:
# How did you know we've got a rental car?
#
# 298. Quicksilver:
# I checked your registration when you were walking to the door. I also had some time to kill so I went through your rental agreement. Saw you were from out of town. Are you FBI? [using his power he quickly swipes Charles' wallet and looks at Charles' card] No, you're not cops. Hey, what's with his gifted youngsters place? [he drops the card and wallet to the floor]
#
# ******** evaluate line 296 in x-men_days_of_future_past_tw_gapi.csv ********
# 3 pronouns resolved
# 1. you => Young Charles
# 2. you => Ramone
# 3. you => Trask(flashback)
#
# how many are correctly identified? 0
#
# ******** line 219 ********
# 217. Young Charles:
# All right, you've piqued my interest. What do you want?
#
# 218. Past Wolverine:
# We have to stop Raven. I need your help. We need your help.
#
# => 219. Young Charles:
# => [emotional] I think I'd like to wake up now. [walks away]
#
# 220. narrator:
# Charles walks turns and walks into the next room
#
# 221. Hank:
# [To Logan] What does she have to do with this?
#
# ******** evaluate line 219 in x-men_days_of_future_past_tw_gapi.csv ********
# 2 pronouns resolved
# 1. I => Young Raven
# 2. I => Stryker
#
# how many are correctly identified? 0
#
# ******** line 35 ********
# 33. narrator:
# they embrace
#
# 34. Wolverine:
# Hey, kid.
#
# => 35. narrator:
# => Bobby nods his head to Logan
#
# 36. Kitty:
# Professor, you made it.
#
# 37. narrator:
# she joins them along with Colossus, who is also alive
#
# ******** evaluate line 35 in x-men_days_of_future_past_tw_gapi.csv ********
# 1 pronouns resolved
# 1. his => Blink
#
# how many are correctly identified? 0
#
# ******** line 143 ********
# 141. Stryker:
# Something to make the ride a little smoother. I'm transferring you to a private facility... where we can run a few more tests.
#
# 142. narrator:
# as the soldier prepares the injection Sanders walks over to Stryker
#
# => 143. Colonel:
# => Your men are not military.
#
# 144. Stryker:
# Private outfit. [Stryker gives Sanders his paperwork] We're authorized to remand these men.
#
# 145. Colonel:
# [Sanders looks at the papers] Hmm. These troops are going home.
#
# ******** evaluate line 143 in x-men_days_of_future_past_tw_gapi.csv ********
# 1 pronouns resolved
# 1. Your => Bobby
#
# how many are correctly identified? 0
#
# ******** line 131 ********
# 129. Soldier:
# Atten-hut!
#
# 130. narrator:
# the soldiers all rise
#
# => 131. Colonel:
# => At ease. [as Sanders walks through the tent he looks at the mutant soldiers, he notices Alex Summers/Havok and winks at him, Alex looks at him with confusion, Strand goes over the doctor who's collecting blood samples] What's all this?
#
# 132. Soldier:
# Lab reports, blood tests. It's all getting packing up and shipped back.
#
# 133. Colonel:
# Where is it going?
#
# ******** evaluate line 131 in x-men_days_of_future_past_tw_gapi.csv ********
# 6 pronouns resolved
# 1. he => Colossus
# 2. he => Gwen
# 3. him => Wolverine
# 4. him => Quicksilver
# 5. who => Kitty
# 6. What => Wolverine
#
# how many are correctly identified? 0
#
# ******** line 5 ********
# 3. Professor X:
# Is the future truly set?
#
# 4. narrator:
# cue Main Titles
#
# => 5. narrator:
# => in Moscow a mutant, Warpath, spots several pods carrying robots and dropping them near the building they're ransacking
#
# 6. Warpath:
# They're here!
#
# 7. narrator:
# he joins another mutant, Blink. Using her powers she opens a portal to transport them to the lower level to warn their fellow mutants: Colossus, Sunspot, Bishop and Kitty Pryde
#
# ******** evaluate line 5 in x-men_days_of_future_past_tw_gapi.csv ********
# 2 pronouns resolved
# 1. them => Havok
# 2. they => Professor X
#
# how many are correctly identified? 0
#
# ******** line 204 ********
# 202. Young Charles:
# Like in the future, 50 years from now?
#
# 203. Past Wolverine:
# Yeah.
#
# => 204. Young Charles:
# => I sent you from the future?
#
# 205. Past Wolverine:
# Yeah.
#
# 206. Young Charles:
# Piss off.
#
# ******** evaluate line 204 in x-men_days_of_future_past_tw_gapi.csv ********
# 2 pronouns resolved
# 1. I => Trask(flashback)
# 2. you => Dr. Trask
#
# how many are correctly identified? 0
#
# ******** line 215 ********
# 213. Past Wolverine:
# I know you, Charles. We've been friends for years. I know your powers came when you were 9. I know you thought you were going crazy when it started... all the voices in your head. And it wasn't until you were 12... that you realized all the voices were in everyone else's head. Do you want me to go on?
#
# 214. narrator:
# Charles looks confused and shocked
#
# => 215. Young Charles:
# => I never told anyone that.
#
# 216. Past Wolverine:
# No, yet, no, but, you will.
#
# 217. Young Charles:
# All right, you've piqued my interest. What do you want?
#
# ******** evaluate line 215 in x-men_days_of_future_past_tw_gapi.csv ********
# 1 pronouns resolved
# 1. I => Professor X
#
# how many are correctly identified? 1
#
# ******** line 141 ********
# 139. narrator:
# another solider opens a case containing vials of drugs
#
# 140. Toad:
# What are you doing with those?
#
# => 141. Stryker:
# => Something to make the ride a little smoother. I'm transferring you to a private facility... where we can run a few more tests.
#
# 142. narrator:
# as the soldier prepares the injection Sanders walks over to Stryker
#
# 143. Colonel:
# Your men are not military.
#
# ******** evaluate line 141 in x-men_days_of_future_past_tw_gapi.csv ********
# 3 pronouns resolved
# 1. I => Magneto
# 2. you => Senator Parker
# 3. we => Storm
#
# how many are correctly identified? 0
#
# ******** line 245 ********
# 243. James Rhodes:
# Quality save. So, no Pepper? She's not coming?
#
# 244. Tony Stark:
# No.
#
# => 245. Maria Hill:
# => Hey, what about Jane? Where are the ladies, gentlemen?
#
# 246. Tony Stark:
# Well, Miss Potts has a company to run.
#
# 247. Thor:
# Yes, I'm not even sure what country Jane's in. Her work on the convergence has made her the world's foremost astronomer.
#
# ******** evaluate line 245 in avengers_age_of_ultron_tw_gapi.csv ********
# 1 pronouns resolved
# 1. what => Specialist Cameron Klein
#
# how many are correctly identified? 0
#
# ******** line 768 ********
# 766. Bruce Banner:
# And you do? She's not in your head?
#
# 767. Wanda Maximoff:
# I know you're angry.
#
# => 768. Bruce Banner:
# => Oh, we're way past that. I could choke the life out of you and never change a shade.
#
# 769. Steve Rogers:
# Banner, after everything that's happened...
#
# 770. Tony Stark:
# That's nothing compared to what's coming!
#
# ******** evaluate line 768 in avengers_age_of_ultron_tw_gapi.csv ********
# 3 pronouns resolved
# 1. we => Steve Rogers
# 2. I => Ulysses Klaue
# 3. you =>  Steve Rogers
#
# how many are correctly identified? 0
#
# ******** line 512 ********
# 510. Clint Barton:
# No, I'm good. If you wanna get some kip, now's a good time, cause we're still a few hours out.
#
# 511. Tony Stark:
# A few hours from where?
#
# => 512. Clint Barton:
# => A safe house. [the Quinjet lands outside a large farmhouse and they all walk towards the house]
#
# 513. Thor:
# What is this place?
#
# 514. Tony Stark:
# A safe house?
#
# ******** evaluate line 512 in avengers_age_of_ultron_tw_gapi.csv ********
# 1 pronouns resolved
# 1. they => Wanda Maximoff
#
# how many are correctly identified? 0
#
# ******** line 874 ********
# 872. Pietro Maximoff:
# Keep up old man! [Barton holds his arrow to aim it at Pietro]
#
# 873. Clint Barton:
# Nobody would know. Nobody. "The last I saw him, when Ultron was sitting on him. Uh...yeah, he'll be missed, that quick little bastard. I miss him already."
#
# => 874. Steve Rogers:
# => [as Natasha joins them in their battle with the robots] Romanoff! [he throws his shield at her so she can use it to protect herself from the attacking robot]
#
# 875. Natasha Romanoff:
# Thanks. [back to Stark]
#
# 876. FRIDAY:
# The anti-gravs are rigged to flip. Touch 'em, they'll go full reverse thrust. The city's not coming down slow.
#
# ******** evaluate line 874 in avengers_age_of_ultron_tw_gapi.csv ********
# 8 pronouns resolved
# 1. them => Wanda Maximoff
# 2. their => Sam Wilson
# 3. he => Ultron
# 4. his => Fortress Soldier
# 5. her => Announcer
# 6. she => Sam Wilson
# 7. it => Ultron
# 8. herself => Announcer
#
# how many are correctly identified? 0
#
# ******** line 196 ********
# 194. Bruce Banner:
# It's beautiful.
#
# 195. Tony Stark:
# If you had to guess, what's it look like it's doing?
#
# => 196. Bruce Banner:
# => Like it's thinking. I mean this could be a...it's not a human mind, it...
#
# 197. Tony Stark:
# Um-um.
#
# 198. Bruce Banner:
# I mean, look at this! They're like neurons firing.
#
# ******** evaluate line 196 in avengers_age_of_ultron_tw_gapi.csv ********
# 4 pronouns resolved
# 1. it => Party Guest
# 2. I => Clint Barton
# 3. it => Vision
# 4. it => Iron Legion
#
# how many are correctly identified? 0
#
# ******** line 606 ********
# 604. Nick Fury:
# Look me in the eye and tell me you're going to shut him down.
#
# 605. Tony Stark:
# You're not the director of me.
#
# => 606. Nick Fury:
# => I'm not the director of anybody. I'm just an old man, who cares very much about you.
#
# 607. Tony Stark:
# And I'm the man who killed the Avengers. I saw it. I didn't tell the team, how could I? I saw them all dead, Nick. I felt it. The whole world, too. It's because of me. I wasn't ready. I didn't do all I could.
#
# 608. Nick Fury:
# The Maximoff girl, she's working you, Stark. Playing on your fear.
#
# ******** evaluate line 606 in avengers_age_of_ultron_tw_gapi.csv ********
# 4 pronouns resolved
# 1. I => Madame B
# 2. I => Specialist Cameron Klein
# 3. who => Klaue's Mercenary
# 4. you => Klaue's Mercenary
#
# how many are correctly identified? 0
#
# ******** line 781 ********
# 779. Steve Rogers:
# Thor, you helped create this?
#
# 780. Thor:
# I've had a vision. A whirlpool that sucks in all hope of life and at it's center is that. [he points to the gem inside Vision's head]
#
# => 781. Bruce Banner:
# => What, the gem?
#
# 782. Thor:
# It's the Mind Stone. It's one of the six Infinity Stones, the greatest power in the universe, unparalleled in its destructive capabilities.
#
# 783. Steve Rogers:
# Then why would you bring it to...
#
# ******** evaluate line 781 in avengers_age_of_ultron_tw_gapi.csv ********
# 1 pronouns resolved
# 1. What => Klaue's Mercenary
#
# how many are correctly identified? 0
#
# ******** line 451 ********
# 449. Ultron:
# What?
#
# 450. Ulysses Klaue:
# Tony Stark used to say that...to me. You're one of his.
#
# => 451. Ultron:
# => What?! I'm not...! [he grabs Klaue] I'm not. You think I'm one of Stark's puppets, his hollow men? I mean look at me, do I look like Iron Man? Stark is... [suddenly he chops off Klaue's arm] I'm sorry. I am sor... Ooh, I'm sure that's going to be okay. I'm sorry, it's just I don't understand. Don't compare me with Stark! [he kicks Klaue down the stairs] It's a thing with me. Stark is, he's a sickness! [Stark appears in his Iron Man suit]
#
# 452. Tony Stark:
# Ahh, Junior. [Thor and Steve are behind him] You're gonna break your old man's heart.
#
# 453. Ultron:
# If I have to.
#
# ******** evaluate line 451 in avengers_age_of_ultron_tw_gapi.csv ********
# 23 pronouns resolved
# 1. What => Erik Selvig
# 2. I => Tony Stark
# 3. he => Fortress Soldier
# 4. I => Dr. List
# 5. You => Bruce Banner
# 6. I => FRIDAY
# 7. his =>  Steve Rogers
# 8. I => Ultron
# 9. me => Soldiers
# 10. I => James Rhodes
# 11. he => Fortress Soldier
# 12. I => Party Guest
# 13. I => Fortress Soldier
# 14. I => Clint Barton
# 15. I => World Hub Tech
# 16. it => James Rhodes
# 17. I => Steve Rogers
# 18. me => Thanos
# 19. he => Strucker
# 20. It => Steve Rogers
# 21. me => Pietro Maximoff
# 22. he => Natasha Romanoff
# 23. his => Natasha Romanoff
#
# how many are correctly identified? 1
#
# ******** line 599 ********
# 597. Steve Rogers:
# Every time someone tries to win a war before it starts, innocent people die. Every time. [Laura interrupts them]
#
# 598. Laura Barton:
# I'm sorry. Mr. Stark, uh, Clint said you wouldn't mind, but, our tractor, it doesn't seem to want to start at all. I thought maybe you might...
#
# => 599. Tony Stark:
# => Yeah, I'll give her a kick. [to Steve as he turns to leave; referring to his pile of chopped wood] Don't take from my pile. [Stark enters the barn and walks over to the tractor] Hello, Deere. Tell me everything. What ails you? [suddenly Fury shows up from the other end of the barn]
#
# 600. Nick Fury:
# Do me a favor. Try not to bring it to life.
#
# 601. Tony Stark:
# Ah, Mrs. Barton, you little minx. I get it, Maria Hill called you, right? Was she ever not working for you?
#
# ******** evaluate line 599 in avengers_age_of_ultron_tw_gapi.csv ********
# 8 pronouns resolved
# 1. I => JARVIS
# 2. her => Lila Barton
# 3. he => Vision
# 4. his => Stan Lee
# 5. my => Specialist Cameron Klein
# 6. me => Natasha Romanoff
# 7. What => Sam Wilson
# 8. you => Vision
#
# how many are correctly identified? 0
#
# ******** line 906 ********
# 904. James Rhodes:
# You think I can't hold my own?
#
# 905. Tony Stark:
# We get through this, I'll hold your own.
#
# => 906. James Rhodes:
# => You had to make it weird.
#
# 907. Clint Barton:
# [as the team helps the people onto the Helicarrier lifeboats] Alright, let's load 'em up! Alright, here we go. Here we go, let's move. Let's go everyone!
#
# 908. Specialist Cameron Klein:
# Number six boat is topped and locked. Or, uh, or stocked, topped. It...it's, uh, full of people.
#
# ******** evaluate line 906 in avengers_age_of_ultron_tw_gapi.csv ********
# 2 pronouns resolved
# 1. You => Iron Legion
# 2. it => Heimdall
#
# how many are correctly identified? 0
#
# ******** line 248 ********
# 246. Tony Stark:
# Well, Miss Potts has a company to run.
#
# 247. Thor:
# Yes, I'm not even sure what country Jane's in. Her work on the convergence has made her the world's foremost astronomer.
#
# => 248. Tony Stark:
# => And the company that Pepper runs is the largest tech conglomerate on earth. It's pretty exciting.
#
# 249. Thor:
# There's even talk of Jane getting a... um, uh... Nobel prize.
#
# 250. Maria Hill:
# Yeah, they...they must be busy because they'd hate missing you guys get together. [Maria mock coughs] Testosterone! Oh, excuse me.
#
# ******** evaluate line 248 in avengers_age_of_ultron_tw_gapi.csv ********
# 1 pronouns resolved
# 1. It => Ballet Instructor
#
# how many are correctly identified? 0
#
# ******** line 202 ********
# 200. Bruce Banner:
# Artificial intelligence.
#
# 201. Tony Stark:
# This could be it, Bruce. This could be the key to creating Ultron.
#
# => 202. Bruce Banner:
# => I thought Ultron was a fantasy.
#
# 203. Tony Stark:
# Yesterday it was. If we can harness this power, apply it to my Iron Legion protocol.
#
# 204. Bruce Banner:
# That's a mad-sized if.
#
# ******** evaluate line 202 in avengers_age_of_ultron_tw_gapi.csv ********
# 1 pronouns resolved
# 1. I => Lila Barton
#
# how many are correctly identified? 0
#
# ******** line 222 ********
# 220. JARVIS:
# Hello, I am JARVIS. You are Ultron, a global peace-keeping initiative designed by Mr. Stark. Our sentience integration trials have been unsuccessful so I'm not certain what triggered your...
#
# 221. Ultron:
# Where's my...where is your body?
#
# => 222. JARVIS:
# => I am a program. I am without form.
#
# 223. Ultron:
# This feels weird. This feels wrong.
#
# 224. JARVIS:
# I am contacting Mr. Stark now.
#
# ******** evaluate line 222 in avengers_age_of_ultron_tw_gapi.csv ********
# 2 pronouns resolved
# 1. I => Natasha Romanoff
# 2. I => Barton's Daughter
#
# how many are correctly identified? 0
#
# ******** line 955 ********
# 953. Thor:
# [referring to the people getting onto the lifeboats] Is this the last of them?
#
# 954. Steve Rogers:
# Yeah. Everyone else is on the carrier.
#
# => 955. Tony Stark:
# => You know, if this works, we maybe don't walk away.
#
# 956. Thor:
# Maybe not. [just as Natasha tries to calm Hulk down to get him back to being Banner Ultron flies in with a jet and starts shooting at them]
#
# 957. Ultron:
# [sings] I got no strings, so I have fun. I'm not tied up to anyone. [as Barton is saving the boy, Costel, Ultron starts shooting at them but Pietro intervenes and takes the shots to save them]
#
# ******** evaluate line 955 in avengers_age_of_ultron_tw_gapi.csv ********
# 2 pronouns resolved
# 1. You => James Rhodes
# 2. we => Maria Hill
#
# how many are correctly identified? 0
#
# ******** line 198 ********
# 196. Bruce Banner:
# Like it's thinking. I mean this could be a...it's not a human mind, it...
#
# 197. Tony Stark:
# Um-um.
#
# => 198. Bruce Banner:
# => I mean, look at this! They're like neurons firing.
#
# 199. Tony Stark:
# Down in Strucker's lab I saw some fairly advanced robotics work. They deep-sixed the data, but...I gotta guess he was knocking on a very particular door.
#
# 200. Bruce Banner:
# Artificial intelligence.
#
# ******** evaluate line 198 in avengers_age_of_ultron_tw_gapi.csv ********
# 2 pronouns resolved
# 1. I => Sam Wilson
# 2. They => Wanda Maximoff
#
# how many are correctly identified? 0
#
# ******** line 378 ********
# 376. Tony Stark:
# Really?! That's it? You just roll over, show your belly, every time somebody snarls.
#
# 377. Bruce Banner:
# Only when I've created a murder bot.
#
# => 378. Tony Stark:
# => We didn't. We weren't even close. Were we close to an interface?
#
# 379. Steve Rogers:
# Well, you did something right. And you did it right here. The Avengers were supposed to be different than SHIELD.
#
# 380. Tony Stark:
# Anybody remember when I carried a nuke through a wormhole?
#
# ******** evaluate line 378 in avengers_age_of_ultron_tw_gapi.csv ********
# 3 pronouns resolved
# 1. We => Jarvis
# 2. We => Bruce Banner
# 3. we => Ulysses Klaue
#
# how many are correctly identified? 0
#
# ******** line 752 ********
# 750. Tony Stark:
# Ultron didn't go after JARVIS cause he was angry. He attacked him because he was scared of what he can do. So JARVIS went underground. Okay? Scattered, dumped his memory. But not his protocols. He didn't even know he was in there, until I pieced him together.
#
# 751. Bruce Banner:
# So, you want me to help you put JARVIS into this thing?
#
# => 752. Tony Stark:
# => No, of course not! I want to help you put JARVIS in this thing. [Banner shakes his head] We're out of my field here. You know bio-organics better than anyone.
#
# 753. Bruce Banner:
# And you just assume that JARVIS' operational matrix can beat Ultron's?
#
# 754. Tony Stark:
# JARVIS has been beating him from inside without knowing it. This is the opportunity, we can create Ultron's perfect self, without the homicidal glitches he thinks are his winning personality. We have to.
#
# ******** evaluate line 752 in avengers_age_of_ultron_tw_gapi.csv ********
# 6 pronouns resolved
# 1. I => Peggy Carter
# 2. you => Dr. Helen Cho
# 3. his => Stan Lee
# 4. We => Jarvis
# 5. my => Nick Fury
# 6. You => Dr. List
#
# how many are correctly identified? 0
#
# ******** line 103 ********
# 101. narrator:
# Steve uses his shield to knock out Strucker
#
# 102. Steve Rogers:
# Guys, I got Strucker.
#
# => 103. Tony Stark:
# => Yeah, I got...something bigger.
#
# 104. narrator:
# inside the secret passageway Stark finds a room with recovered artifacts from the Battle of New York, including a gigantic Chitauri leviathan and some of his Iron Man scrapped armor, he then spots the scepter
#
# 105. Tony Stark:
# Thor, I got eyes on the prize.
#
# ******** evaluate line 103 in avengers_age_of_ultron_tw_gapi.csv ********
# 1 pronouns resolved
# 1. I => Madame B
#
# how many are correctly identified? 0
#
# ******** line 195 ********
# 193. narrator:
# he brings up another 3D image of what's inside the scepter
#
# 194. Bruce Banner:
# It's beautiful.
#
# => 195. Tony Stark:
# => If you had to guess, what's it look like it's doing?
#
# 196. Bruce Banner:
# Like it's thinking. I mean this could be a...it's not a human mind, it...
#
# 197. Tony Stark:
# Um-um.
#
# ******** evaluate line 195 in avengers_age_of_ultron_tw_gapi.csv ********
# 4 pronouns resolved
# 1. you => World Hub Tech
# 2. what => Sam Wilson
# 3. it => Madame B
# 4. it => Laura Barton
#
# how many are correctly identified? 0
#
# ******** line 115 ********
# 113. narrator:
# Wanda smiles to herself as Tony takes the scepter
#
# 114. narrator:
# Title Sequence plays
#
# => 115. narrator:
# => the Avengers are on an aircraft heading out of Sokovia, Natasha interrupts Banner who's listening to opera with his headphones
#
# 116. Natasha Romanoff:
# Hey, the lullaby worked better than ever.
#
# 117. Bruce Banner:
# Just wasn't expecting the Code Green.
#
# ******** evaluate line 115 in avengers_age_of_ultron_tw_gapi.csv ********
# 2 pronouns resolved
# 1. who => Party Guest
# 2. his => Ultron
#
# how many are correctly identified? 0
#
# ******** line 107 ********
# 105. Charles:
# I don't have to be psychic to see that something's bothering you.
#
# 106. Storm:
# I don't understand. Magneto's a fugitive, we've a mutant in the cabinet, a president who understands us - why hide?
#
# => 107. Charles:
# => We're not hiding. But we still have enemies. I must protect my students. You know that.
#
# 108. Storm:
# Yes, but we can't be students forever.
#
# 109. Charles:
# Storm, I haven't thought of you as my student for years. In fact, I thought that perhaps you might take my place some day.
#
# ******** evaluate line 107 in x-men_the_last_stand_tw_gapi.csv ********
# 5 pronouns resolved
# 1. We => Staff Woman
# 2. we => Storm
# 3. I => Psylocke
# 4. my => Kitty
# 5. You => Charles
#
# how many are correctly identified? 0
#
# ******** line 80 ********
# 78. President:
# We have some new prisons. We'll keep them mobile. Be a step ahead.
#
# 79. Interrogator:
# Where is Magneto? Raven? - Raven, I asked you a question.
#
# => 80. Raven:
# => I don't answer to my slave name.
#
# 81. Interrogator:
# Raven Darkholme. That's your real name, isn't it? Or has he convinced you you don't have a family any more?
#
# 82. Raven:
# My family tried to kill me, you pathetic meat sack.
#
# ******** evaluate line 80 in x-men_the_last_stand_tw_gapi.csv ********
# 2 pronouns resolved
# 1. I => Quill
# 2. my => Moira
#
# how many are correctly identified? 0
#
# ******** line 99 ********
# 97. Charles:
# When an individual acquires great power, the use or misuse of that power is everything. Will it be for the greater good or will it be used for personal or for destructive ends? Now, this is a question we must all ask ourselves. Why? Because we are mutants. For psychics, this presents a particular problem. When is it acceptable to use our power and when do we cross that invisible line that turns us into tyrants over our fellow man?
#
# 98. Kitty:
# But Einstein said that ethics are an exclusive human concern without any superhuman authority behind it.
#
# => 99. Charles:
# => Einstein wasn't a mutant so far as we know. This case study was sent to me by a colleague, Dr. Moira McTaggert. Jones.
#
# 100. Moira:
# The man you see here was born with no higher-level brain functions. His organs and nervous system work, but he has no consciousness to speak of.
#
# 101. Charles:
# What if we were to transfer the consciousness of one person, say a father of four with terminal cancer, into the body of this man? How are we to decide what falls within the range of ethical behavior and what...
#
# ******** evaluate line 99 in x-men_the_last_stand_tw_gapi.csv ********
# 2 pronouns resolved
# 1. we => Charles
# 2. me => Guard
#
# how many are correctly identified? 0
#
# ******** line 285 ********
# 283. Jean:
# Yes, it is me.
#
# 284. Logan:
# No. Maybe you ought to take it easy. The professor said you might be different.
#
# => 285. Phoenix:
# => He would know, wouldn't he?
#
# 286. Logan:
# What? You think he's not in your head too?
#
# 287. Phoenix:
# Look at you, Logan. He's tamed you.
#
# ******** evaluate line 285 in x-men_the_last_stand_tw_gapi.csv ********
# 2 pronouns resolved
# 1. He => Calisto
# 2. he => Cain
#
# how many are correctly identified? 0
#
# ******** line 314 ********
# 312. Storm:
# What? - That's not possible.
#
# 313. Charles:
# I warned you. She's left the mansion, but she's trying to block my thoughts. She's so strong. It may be too late. - Wait for me here.
#
# => 314. Logan:
# => What?
#
# 315. Charles:
# I need to see Jean alone.
#
# 316. Eric:
# You were right, Charles. - This one is special.
#
# ******** evaluate line 314 in x-men_the_last_stand_tw_gapi.csv ********
# 1 pronouns resolved
# 1. What => Raven
#
# how many are correctly identified? 0
#
# ******** line 202 ********
# 200. Logan:
# I can't see a damn thing.
#
# 201. Storm:
# I can take care of that.
#
# => 202. Logan:
# => What the...
#
# 203. Storm:
# Logan! She's alive.
#
# 204. Logan:
# Jean.
#
# ******** evaluate line 202 in x-men_the_last_stand_tw_gapi.csv ********
# 1 pronouns resolved
# 1. What => Interrogator
#
# how many are correctly identified? 0
#
# ******** line 302 ********
# 300. Logan:
# Stop it. Look at me. Look at me. Jean. It'll be all right. We can help you. Hey. The professor can help. He can fix it.
#
# 301. Phoenix:
# I don't want to fix it.
#
# => 302. Eric:
# => Voluntary? They put the cure in a gun. I told you they would draw first blood.
#
# 303. John:
# So what do we do? - What do we do?
#
# 304. Eric:
# We use this weapon as a lightning rod to bring countless more to our cause. Come. We have an army to build.
#
# ******** evaluate line 302 in x-men_the_last_stand_tw_gapi.csv ********
# 4 pronouns resolved
# 1. They => Interrogator
# 2. I => Mr. Grey
# 3. you => Mrs. Grey
# 4. they => Logan
#
# how many are correctly identified? 0
#
# ******** line 172 ********
# 170. Dr. Rao:
# We are in compliance with your policy.
#
# 171. Hank:
# How long will you keep the boy here?
#
# => 172. Dr. Rao:
# => Until we can fully map his DNA. We can replicate it, but we can't generate it.
#
# 173. Hank:
# And his power? What is its range?
#
# 174. Dr. Rao:
# You'll see. Jimmy. There's someone I would like you to meet.
#
# ******** evaluate line 172 in x-men_the_last_stand_tw_gapi.csv ********
# 6 pronouns resolved
# 1. we => Young Jean
# 2. his => Interrogator
# 3. We => Dr. Rao
# 4. it => Mr. Worthington
# 5. we => Logan
# 6. it => Mutant
#
# how many are correctly identified? 1
#
# ******** line 47 ********
# 45. Storm:
# You can't change the rules.
#
# 46. Loggan:
# I'm trying to teach 'em something. - I taught 'em something.
#
# => 47. Storm:
# => It was a defensive exercise.
#
# 48. Logan:
# Yeah, best defense is a good offence. Or is it the other way round?
#
# 49. Storm:
# This isn't a game, Logan.
#
# ******** evaluate line 47 in x-men_the_last_stand_tw_gapi.csv ********
# 1 pronouns resolved
# 1. It => Young Jean
#
# how many are correctly identified? 0
#
# ******** line 157 ********
# 155. John:
# You know who you're talking to?
#
# 156. Quill:
# Do you?
#
# => 157. Eric:
# => And what can you do?  So you have talents?
#
# 158. Calisto:
# That and more. I know you control metal. And I know there's 87 mutants in here, none above a class three. Other than you two.
#
# 159. Eric:
# You can sense other mutants and their powers? Could you locate one for me?
#
# ******** evaluate line 157 in x-men_the_last_stand_tw_gapi.csv ********
# 3 pronouns resolved
# 1. what => Charles
# 2. you => Bobby
# 3. you => Logn
#
# how many are correctly identified? 0
#
# ******** line 77 ********
# 75. Hank:
# Yes, sir. She can do that.
#
# 76. President:
# Not any more, she can't. We got her.
#
# => 77. Hank:
# => You think your prisons can hold her?
#
# 78. President:
# We have some new prisons. We'll keep them mobile. Be a step ahead.
#
# 79. Interrogator:
# Where is Magneto? Raven? - Raven, I asked you a question.
#
# ******** evaluate line 77 in x-men_the_last_stand_tw_gapi.csv ********
# 3 pronouns resolved
# 1. You => Lady
# 2. your => Kitty
# 3. her => Bobby
#
# how many are correctly identified? 0
#
# ******** line 223 ********
# 221. Charles:
# I had a terrible choice to make. I chose the lesser of two evils.
#
# 222. Logan:
# It sounds to me like Jean had no choice at all.
#
# => 223. Charles:
# => I don't have to explain myself, least of all to you.
#
# 224. Reporter:
# History will be made here today. For the first time, the so-called mutant cure will be available to the public. Reaction has run the gamut with mutants on both sides of the line. Some are desperate for this cure while others are offended by the very idea of it.
#
# 225. Mr. Worthington:
# Will Secretary McCoy be a problem?
#
# ******** evaluate line 223 in x-men_the_last_stand_tw_gapi.csv ********
# 3 pronouns resolved
# 1. I => Cain
# 2. myself => President
# 3. you => Hank
#
# how many are correctly identified? 0
#
# ******** line 215 ********
# 213. Charles:
# I'm keeping her that way. I'm trying to restore the psychic blocks and cage the beast again.
#
# 214. Logan:
# What have you done to her?
#
# => 215. Charles:
# => You have to understand...
#
# 216. Logan:
# You're talking about a person's mind.
#
# 217. Charles:
# She has to be controlled.
#
# ******** evaluate line 215 in x-men_the_last_stand_tw_gapi.csv ********
# 1 pronouns resolved
# 1. You => Young Jean
#
# how many are correctly identified? 0
#
# ******** line 109 ********
# 107. Charles:
# We're not hiding. But we still have enemies. I must protect my students. You know that.
#
# 108. Storm:
# Yes, but we can't be students forever.
#
# => 109. Charles:
# => Storm, I haven't thought of you as my student for years. In fact, I thought that perhaps you might take my place some day.
#
# 110. Storm:
# But Scott's...
#
# 111. Charles:
# Scott's a changed man. He took Jean's death so hard. Yes, things are better out there, but you, of all people, know how fast the weather can change.
#
# ******** evaluate line 109 in x-men_the_last_stand_tw_gapi.csv ********
# 6 pronouns resolved
# 1. I => Moira
# 2. you => Calisto
# 3. my => Jean's voice
# 4. I => Scott
# 5. you => Mutant
# 6. my => CaIisto
#
# how many are correctly identified? 0
#
# ******** line 159 ********
# 157. Eric:
# And what can you do?  So you have talents?
#
# 158. Calisto:
# That and more. I know you control metal. And I know there's 87 mutants in here, none above a class three. Other than you two.
#
# => 159. Eric:
# => You can sense other mutants and their powers? Could you locate one for me?
#
# 160. President:
# Let me out of here. I demand that you release me. Do you know who I am? I'm the president of the United States.
#
# 161. Guard:
# Oh, Mr. President. Shut up.
#
# ******** evaluate line 159 in x-men_the_last_stand_tw_gapi.csv ********
# 4 pronouns resolved
# 1. You => Dr. Rao
# 2. their => Young Jean
# 3. you => James
# 4. me => Mr. Worthington
#
# how many are correctly identified? 0
#
# ******** line 236 ********
# 234. Warren:
# Dad, can we talk about this for a second?
#
# 235. Mr. Worthington:
# We've talked about it, son. It'll all be over soon. - Everything's going to be fine.
#
# => 236. Warren:
# => Wait. I can't do this.
#
# 237. Mr. Worthington:
# Warren, calm down.
#
# 238. Warren:
# I can't do this.
#
# ******** evaluate line 236 in x-men_the_last_stand_tw_gapi.csv ********
# 1 pronouns resolved
# 1. I => Calisto
#
# how many are correctly identified? 0
#
# ******** line 283 ********
# 281. Jean:
# I don't have to. It's OK. It's OK.
#
# 282. Logan:
# Wait. - No. Jean. - This isn't you.
#
# => 283. Jean:
# => Yes, it is me.
#
# 284. Logan:
# No. Maybe you ought to take it easy. The professor said you might be different.
#
# 285. Phoenix:
# He would know, wouldn't he?
#
# ******** evaluate line 283 in x-men_the_last_stand_tw_gapi.csv ********
# 2 pronouns resolved
# 1. it => President
# 2. me => Quill
#
# how many are correctly identified? 0
#
# ******** line 295 ********
# 293. Jean:
# Kill me.
#
# 294. Logan:
# What?
#
# => 295. Jean:
# => Kill me before I kill someone else.
#
# 296. Logan:
# Don't say that.
#
# 297. Jean:
# Please.
#
# ******** evaluate line 295 in x-men_the_last_stand_tw_gapi.csv ********
# 2 pronouns resolved
# 1. me => Psylocke
# 2. I => Cain
#
# how many are correctly identified? 0
#
# ******** line 246 ********
# 244. Raven:
# Told you so. About time.
#
# 245. Eric:
# I've been busy. Did you find what you were looking for?
#
# => 246. Raven:
# => The source of the cure is a mutant. A child at Worthington Labs. Without him, they have nothing.
#
# 247. Eric:
# Read us the guest list.
#
# 248. John:
# "Cell 41205. James Madrox."
#
# ******** evaluate line 246 in x-men_the_last_stand_tw_gapi.csv ********
# 2 pronouns resolved
# 1. him => Phoenix
# 2. they => John
#
# how many are correctly identified? 0
#
# ******** line 30 ********
# 28. Bobby:
# Thanks, Kitty.
#
# 29. Storm:
# We're getting killed out here.
#
# => 30. Logan:
# => Yeah, I know. They're not ready, Storm.
#
# 31. Storm:
# Logan.
#
# 32. Logan:
# Oh, don't get your panties in a bunch. That was my last cigar.
#
# ******** evaluate line 30 in x-men_the_last_stand_tw_gapi.csv ********
# 2 pronouns resolved
# 1. I => Young Jean
# 2. They => John
#
# how many are correctly identified? 0
#
# ******** line 67 ********
# 65. Loki:
# You will know peace.
#
# 66. narrator:
# he uses his abilities to control Selvig's mind
#
# => 67. Nick Fury:
# => Yeah, you say peace, I kind of think you mean the other piece.
#
# 68. Clint Barton:
# Sir, Director Fury is stalling. This place is about to blow. Drop a hundred feet of raw material, he means to bury us.
#
# 69. Nick Fury:
# Like The Pharaohs of old.
#
# ******** evaluate line 67 in the_avengers_tw_gapi.csv ********
# 3 pronouns resolved
# 1. you => Thug
# 2. I => Agent Maria Hill
# 3. you => The Other
#
# how many are correctly identified? 0
#
# ******** line 61 ********
# 59. Loki:
# An ant has no quarrel with a boot.
#
# 60. Nick Fury:
# You planning to step on us?
#
# => 61. Loki:
# => I come with glad tidings, of a world made free.
#
# 62. Nick Fury:
# Free from what?
#
# 63. Loki:
# Freedom. Freedom is life's great lie. Once you accept that, in your heart...
#
# ******** evaluate line 61 in the_avengers_tw_gapi.csv ********
# 1 pronouns resolved
# 1. I => Selvig
#
# how many are correctly identified? 0
#
# ******** line 209 ********
# 207. narrator:
# Stark in his Iron Man suit is working on getting his energy line to work
#
# 208. Tony Stark:
# You're good to go on this end. The rest is up to you.
#
# => 209. Pepper Potts:
# => You disconnected the transition lines? Are we off the grid?
#
# 210. Tony Stark:
# Stark Towers is about to become a beacon of of self sustaining clean energy.
#
# 211. Pepper Potts:
# Wow, so maybe our reactor takes over and it actually works?
#
# ******** evaluate line 209 in the_avengers_tw_gapi.csv ********
# 2 pronouns resolved
# 1. You => Natasha Romanoff
# 2. we => Loki
#
# how many are correctly identified? 0
#
# ******** line 326 ********
# 324. Clint Barton:
# SHIELD has not shortage of enemies, Doctor. [he holds up a screen showing information in Iridium] Is this the stuff you need?
#
# 325. Selvig:
# Yeah, Iridium. It's found in meteorites, it forms anti-protons. It's very hard to get hold of.
#
# => 326. Clint Barton:
# => Specially if SHIELD knows you need it.
#
# 327. Selvig:
# Well, I didn't know! The Tesseract is showing me so much. It's...it's more than knowledge, it's truth.
#
# 328. Loki:
# I know. What did it show you, Agent Barton?
#
# ******** evaluate line 326 in the_avengers_tw_gapi.csv ********
# 2 pronouns resolved
# 1. you => Pepper Potts
# 2. it => Loki
#
# how many are correctly identified? 0
#
# ******** line 160 ********
# 158. Natasha Romanoff:
# No one's gonna put you in a...
#
# 159. narrator:
# suddenly Banner gets angry and snaps
#
# => 160. Bruce Banner:
# => Stop lying to me!
#
# 161. narrator:
# Natasha quickly grab her gun and points it at Banner
#
# 162. Bruce Banner:
# I'm sorry, that was mean. I just wanted to see what you'd do. Why don't we do this the easy way, where you don't use that, and the other guy doesn't make a mess? Okay?
#
# ******** evaluate line 160 in the_avengers_tw_gapi.csv ********
# 1 pronouns resolved
# 1. me => Natasha Romanoff
#
# how many are correctly identified? 0
#
# ******** line 84 ********
# 82. narrator:
# Hill gets into a truck and follows after Barton's truck
#
# 83. narrator:
# after the research facility has collapsed, Fury and Hill try to chase after Loki but fail to catch him escaping with the briefcase containing the Tesseract; talking through their walkie talkie's
#
# => 84. Agent Phil Coulson:
# => Director? Director Fury, do you copy?
#
# 85. Nick Fury:
# The Tesseract is with the hostile force. I have men down. Hill?
#
# 86. Agent Maria Hill:
# A lot of men still under, don't know how many survivors.
#
# ******** evaluate line 84 in the_avengers_tw_gapi.csv ********
# 1 pronouns resolved
# 1. you => Thug
#
# how many are correctly identified? 0
#
# ******** line 248 ********
# 246. Tony Stark:
# You have reached the life model decoy of Tony Stark, please leave a message.
#
# 247. Agent Phil Coulson:
# This is urgent.
#
# => 248. Tony Stark:
# => Then leave it urgently. [at that moment the elevator door opens and Coulson appears] Security breach. [to Pepper] That's on you.
#
# 249. Agent Phil Coulson:
# Mr. Stark.
#
# 250. Pepper Potts:
# Phil! Come in.
#
# ******** evaluate line 248 in the_avengers_tw_gapi.csv ********
# 2 pronouns resolved
# 1. it => Steve Rogers
# 2. you => Agent Phil Coulson
#
# how many are correctly identified? 0
#
# ******** line 25 ********
# 23. Nick Fury:
# Talk to me, doctor.
#
# 24. Selvig:
# Director.
#
# => 25. Nick Fury:
# => Is there anything we know for certain?
#
# 26. Selvig:
# The Tesseract is misbehaving.
#
# 27. Nick Fury:
# Is that supposed to be funny?
#
# ******** evaluate line 25 in the_avengers_tw_gapi.csv ********
# 1 pronouns resolved
# 1. we => Jarvis
#
# how many are correctly identified? 0
#
# ******** line 95 ********
# 93. Luchkov:
# This is not how I wanted this night to go.
#
# 94. Natasha Romanoff:
# I know how you wanted this night to go. Believe me, this is better.
#
# => 95. Luchkov:
# => Who are you working for? Lermentov, yes? Does he really think that we'll have to go through him to move our tanks?
#
# 96. Natasha Romanoff:
# I thought General Solohob was in charge of the cargo?
#
# 97. Luchkov:
# Solohob? A bagman. A front.
#
# ******** evaluate line 95 in the_avengers_tw_gapi.csv ********
# 6 pronouns resolved
# 1. Who => Clint Barton
# 2. you => Steve Rogers
# 3. he => Natasha Romanoff
# 4. we => Pepper Potts
# 5. him => Agent Jasper Sitwell
# 6. our => Jarvis
#
# how many are correctly identified? 0
#
# ******** line 197 ********
# 195. narrator:
# Fury gives Steve the file on Tesseract to look at
#
# 196. Steve Rogers:
# Hydra's secret weapon.
#
# => 197. Nick Fury:
# => Howard Stark fished that out of the ocean when he was looking for you. He thought what we think, the Tesseract could be the key to unlimited sustainable energy. That's something the world sorely needs.
#
# 198. Steve Rogers:
# Who took it from you?
#
# 199. Nick Fury:
# He's called Loki. He's not from around here. There's a lot we'll have to bring you up to speed on if you're in. The world has gotten even stranger than you already know.
#
# ******** evaluate line 197 in the_avengers_tw_gapi.csv ********
# 5 pronouns resolved
# 1. he => Selvig
# 2. you => World Security Council #1
# 3. He => Bruce Banner
# 4. what => Pepper Potts
# 5. we => Jarvis
#
# how many are correctly identified? 0
#
# ******** line 271 ********
# 269. Pepper Potts:
# I was having twelve percent of a moment. This seems serious, Phil's pretty shaken.
#
# 270. Tony Stark:
# How did you notice? Why is he Phil? [referring to the file Coulson had given to Stark]
#
# => 271. Pepper Potts:
# => What is all this?
#
# 272. Tony Stark:
# This is uh... [with a flick of his hand he spreads all the profiles of the other Avengers on to the different computer screens] This. [Pepper looks at all their profiles in awe]
#
# 273. Pepper Potts:
# I'm going to take the jet to D.C. tonight.
#
# ******** evaluate line 271 in the_avengers_tw_gapi.csv ********
# 1 pronouns resolved
# 1. What => Clint Barton
#
# how many are correctly identified? 0
#
# ******** line 285 ********
# 283. Agent Phil Coulson:
# A lot of people were. You were the world's first superhero. Banner thought gammer radiation might hold the key to unlocking Erskine's original formula.
#
# 284. Steve Rogers:
# Didn't really go his way, did it?
#
# => 285. Agent Phil Coulson:
# => Not so much. When he's got that thing though, guy's like a Stephen Hawking. [Steve looks at Coulson in confusion] He's like a smart person. I gotta say, it's an honor to meet you, officially. I sort of met you, I mean, I watched you while you were sleeping. [Steve looks at Coulson in amusement] I mean, I was...I was present while you were unconscious from the ice. You know, it's really, it's just a...just a huge honor to have you on board.
#
# 286. Steve Rogers:
# Well, I hope I'm the man for the job.
#
# 287. Agent Phil Coulson:
# Oh, you are. Absolutely. Uh...we've made some modifications to the uniform. I had a little design input.
#
# ******** evaluate line 285 in the_avengers_tw_gapi.csv ********
# 19 pronouns resolved
# 1. he => Pepper Potts
# 2. He => Bruce Banner
# 3. I => Steve Rogers
# 4. it => Bruce Banner
# 5. you => NASA Scientist
# 6. I => Agent Phil Coulson
# 7. you => Clint Barton
# ...
#
# how many are correctly identified? 0
#
# ******** line 342 ********
# 340. Raven:
# Maybe in Westchester. Out there, mutants are still running, hiding, living in fear. Just because there's not a war doesn't mean there's peace. If you want to teach your kids something, teach them that. Teach them to fight. Otherwise, they might as well live in this house for the rest of their lives.
#
# 341. Charles:
# You still sound just like him. You sound just like Erik.
#
# => 342. Raven:
# => That's why I'm here. He's resurfaced. He had a wife and a daughter. They were killed. Along with a handful of policemen. The whole world will be looking for him. But you can help me find him before they do.
#
# 343. Charles:
# Moira, I'm going to have to ask you to keep this a secret.
#
# 344. Moira:
# I don't even know what this... is.
#
# ******** evaluate line 342 in x-men_apocalypse_tw_gapi.csv ********
# 9 pronouns resolved
# 1. I => Peter's Mom
# 2. He => Kurt
# 3. He => Storm
# 4. They => Charles
# 5. him => Merchant
# 6. you => Worker
# 7. me => Student 1
# 8. him => Teacher
# 9. they => Caliban
#
# how many are correctly identified? 0
#
# ******** line 420 ********
# 418. Solider:
# X-Ray 7, I'm doing a final sweep on the ground. Alright, you! Are you clear? Clear!
#
# 419. Solider:
#  Pack them up. Let's go. Come on, let's move!
#
# => 420. Scott:
# =>  Thanks, Jean. We got to help them. - Kurt, can you get us in that thing?
#
# 421. Kurt:
#  - You want to get in there? What if the soldiers see us?
#
# 422. Jean:
#  Don't worry. They won't see us, trust me.
#
# ******** evaluate line 420 in x-men_apocalypse_tw_gapi.csv ********
# 4 pronouns resolved
# 1. We => Egyptian Guard
# 2. them => Teacher
# 3. you => Hank
# 4. us => Storm
#
# how many are correctly identified? 0
#
# ******** line 194 ********
# 192. Reporter:
# Never before has man possess so much power. With Soviet Union and the United States being superpowers...
#
# 193. Apocalypse:
# Superpowers? The weak have taken the Earth. For this, I was betrayed. False gods. Idols. No more. I have returned. The new tomorrow, that starts today.
#
# => 194. Storm:
# => Where did you come from?
#
# 195. Apocalypse:
# The time before man lost his way.
#
# 196. Storm:
# Well. Welcome to the 80s.
#
# ******** evaluate line 194 in x-men_apocalypse_tw_gapi.csv ********
# 1 pronouns resolved
# 1. you => TV
#
# how many are correctly identified? 0
#
# ******** line 88 ********
# 86. Charles:
# Nope. It was just a dream. -
#
# 87. Jean:
# But, it felt real. -
#
# => 88. Charles:
# => I know. Your mind is the most powerful I've ever seen. - It can convince itself... -
#
# 89. Jean:
# No, it's not just a mind reading or a telekinesis, it's something else. Some... dark power inside and it's growing, like a fire. - I thought I was getting better. -
#
# 90. Charles:
# You are. You will. - You just have to be patient. -
#
# ******** evaluate line 88 in x-men_apocalypse_tw_gapi.csv ********
# 5 pronouns resolved
# 1. I => Worker
# 2. Your => Student 5
# 3. I => Kurt
# 4. It => Peter
# 5. itself => Charles
#
# how many are correctly identified? 0
#
# ******** line 421 ********
# 419. Solider:
#  Pack them up. Let's go. Come on, let's move!
#
# 420. Scott:
#  Thanks, Jean. We got to help them. - Kurt, can you get us in that thing?
#
# => 421. Kurt:
# =>  - You want to get in there? What if the soldiers see us?
#
# 422. Jean:
#  Don't worry. They won't see us, trust me.
#
# 423. Kurt:
#  Hold on.
#
# ******** evaluate line 421 in x-men_apocalypse_tw_gapi.csv ********
# 3 pronouns resolved
# 1. You => Scott
# 2. What => Charles
# 3. us => Director
#
# how many are correctly identified? 1
#
# ******** line 44 ********
# 42. Erik:
# Never.
#
# 43. Alex:
# I guess we're more alike than we thought.
#
# => 44. Woman:
# => He won't listen to us. He just... He's been...
#
# 45. Alex:
# Scott. Let me try. XAVIER'S SCHOOL FOR GIFTED YOUNGSTERS
#
# 46. Scott:
# Smells pretty old in here. Is this a school or museum.
#
# ******** evaluate line 44 in x-men_apocalypse_tw_gapi.csv ********
# 4 pronouns resolved
# 1. He => Solider
# 2. us => Worker
# 3. He => Jubilee
# 4. He => Charles
#
# how many are correctly identified? 0
#
# ******** line 140 ********
# 138. Police Officer:
# What's happening? She is one of them.
#
# 139. Nina:
# Please.
#
# => 140. Police Officer:
# => Make her stop.
#
# 141. Erik:
# She can't control them.
#
# 142. Magda:
# Nina.
#
# ******** evaluate line 140 in x-men_apocalypse_tw_gapi.csv ********
# 1 pronouns resolved
# 1. her => Storm
#
# how many are correctly identified? 0
#
# ******** line 424 ********
# 422. Jean:
#  Don't worry. They won't see us, trust me.
#
# 423. Kurt:
#  Hold on.
#
# => 424. Scott:
# =>  Kurt, get us all out of here! I can't! When they closed the doors, there's some kind of electric field. - It's like Berlin all over. Scott: - Jean, get into the pilots heads. - Don't let them take off! Jean: - I can't. I can't reach the pilots. I can't reach anyone. News reporter: We're also getting reports from Europe and Asia. This was not just the US phenomenon. It seems the entire world has been disarmed of nuclear weapons. The Pentagon has confirmed multiple launches from Russia, as well as the UK, Israel and China. Student 8: - Look! - Up there. News reporter: So far, there has been no response from the White House. Eye witness accounts have been pouring in from across the globe. Authorities are not sure if it was an act of peace or an act of war. Kurt: Dear Father. Hold me in the light of God. Scott: It should have been me. He was the one who's going to do something with his life. He was always the one. Jean: That's not how he felt. He felt you were the one who's going to do something special with your life. That you're going to make a difference in the world. Maybe even change it. Scott: How did you know what he felt? I know what everybody feels. Kurt: Hold me in the light of God. Protect me from danger. Save me by your command. Listen to my prayer. And keep me safe.
#
# 425. Charles:
#  You're blocking me. How? Apocalypse: I can shield their minds from your power. It's one of the many gifts I have acquired through out the millennia. But to... see... inside a mind. To control it. That's your gift. You saw it, didn't you? The glory of what's to come. Charles: Are you going to take part in all this killing? Destruction?
#
# 426. Erik:
#  - It's all I ever known. Charles - No, it isn't. - You've just forgotten.
#
# ******** evaluate line 424 in x-men_apocalypse_tw_gapi.csv ********
# 36 pronouns resolved
# 1. us => Reporter
# 2. I => Student 5
# 3. they => Government Official
# 4. It => Computer
# 5. them => Announcer
# 6. I => EriK
# 7. I => Police Officer
# 8. I => Egyptian Guard
# 9. We => Psylocke
# 10. It => Peter's Mom
# 11. it => Black Official
# 12. me => Jubilee
# 13. It => Police Officer
# 14. me => Student 1
# 15. He => Student 6
# 16. who => Jubilee
# 17. his => Student 7
# 18. He => Teacher
# 19. he => Peter's Mom
# 20. He => Star Trek Character
# 21. you => Police Officer
# 22. who => Worker
# 23. your => Dude
# 24. you => Peter
# 25. it => Jacob
# 26. you => Jubilee
# 27. what => Government Official
# 28. he => Peter
# 29. I => Worker
# 30. what => Peter
# 31. me => Death
# 32. me => Soldier 10
# 33. me => Solider
# 34. your => Government Official
# 35. my => Nightcrawler
# 36. me => Star Trek Character
#
# how many are correctly identified? 0
#
# ******** line 23 ********
# 21. Bodyguard:
# Hey. You lost, little girl? The fight is there.
#
# 22. Angel:
# Fight! Or they'll kill us both.
#
# => 23. Bodyguard:
# => It's getting exciting.
#
# 24. Raven:
# Ah, you mean this. Yeah?
#
# 25. Crowd:
# Nightcrawler! - Nightcrawler! - Nightcrawler!
#
# ******** evaluate line 23 in x-men_apocalypse_tw_gapi.csv ********
# 1 pronouns resolved
# 1. It => Announcer
#
# how many are correctly identified? 0
#
# ******** line 169 ********
# 167. Moira:
# I had a husband, but... It's hard to do this job and make it home in time for dinner.
#
# 168. Charles:
# Good. Good. We all make choices, right?
#
# => 169. Moira:
# => Yes, we do. - Professor. - Yes?
#
# 170. Charles:
# Yes. I was... we were hoping that you would tell us about what happened yesterday in Egypt.
#
# 171. Moira:
# I'm afraid that's classified information. And, I don't mean to be rude, but... How did you get in here?
#
# ******** evaluate line 169 in x-men_apocalypse_tw_gapi.csv ********
# 1 pronouns resolved
# 1. we => Nina
#
# how many are correctly identified? 0
#
# ******** line 305 ********
# 303. Peter:
# What's up?
#
# 304. Peter's Mom:
# I'm just checking on you.
#
# => 305. Peter:
# => I'm good, playing Pac-Man.
#
# 306. Peter's Mom:
# Are you sure you weren't watching this?
#
# 307. Reporter:
# The world was celebrating 10 years of peace between mutants and mankind.
#
# ******** evaluate line 305 in x-men_apocalypse_tw_gapi.csv ********
# 1 pronouns resolved
# 1. I => TV
#
# how many are correctly identified? 0
#
# ******** line 334 ********
# 332. Raven:
# No, it was your home. I just lived here. I barely even recognize it now.
#
# 333. Charles:
# Yeah, I have plans for this place. I mean to turn it into a real campus. A university. Not just for mutants, even for humans too. Living and working, ... growing together.
#
# => 334. Raven:
# => You know, I really believed that once. I really believed we can change them after DC.
#
# 335. Charles:
# We did.
#
# 336. Raven:
# No Charles. They still hate and fear us. It's just harder to see because they're more polite about it. I got sick of living that lie.
#
# ******** evaluate line 334 in x-men_apocalypse_tw_gapi.csv ********
# 5 pronouns resolved
# 1. You => EriK
# 2. I => Nina
# 3. I => Student 6
# 4. we => Storm
# 5. them => Student 4
#
# how many are correctly identified? 0
#
# ******** line 152 ********
# 150. Apocalypse:
# Enough.
#
# 151. Merchant:
# If you are with her, I suggest you go away. Go away.
#
# => 152. Apocalypse:
# => Who rules this world?
#
# 153. Merchant:
# What language is that? Clown! What do you want? Go away! Sorry. Sorry.
#
# 154. Apocalypse:
# You feel it, don't you? Now, you feel it. CENTRAL INTELLIGENCE AGENCY UNITED STATES OF AMERICA
#
# ******** evaluate line 152 in x-men_apocalypse_tw_gapi.csv ********
# 1 pronouns resolved
# 1. Who => Peter
#
# how many are correctly identified? 0
#
# ******** line 1 ********
# 0. Charles:
# Mutants, born with extraordinary abilities, and yet still, they are children, stumbling in the dark, searching for guidance. A gift can often be a curse. Give someone wings, and they may fly too close to the sun. Give them the power of prophecy, and they may live in fear of the future. Give them the greatest gift of all, powers beyond imagination, and they may think they are meant to rule the world.
#
# => 1. Death:
# => Soon, you will rule forever, My Lord.
#
# 2. Egyptian Guard:
# DEATH TO THE FALSE GOD!
#
# 3. Horsemen of Apocalypse:
# Watch over him!
#
# ******** evaluate line 1 in x-men_apocalypse_tw_gapi.csv ********
# 2 pronouns resolved
# 1. you => William
# 2. My => Government Official
#
# how many are correctly identified? 0
#
# ******** line 264 ********
# 262. Psylocke:
# I know the kind of mutants you are looking for. And I know where to find them.
#
# 263. Kurt:
# It's my first time in America. I am very excited to see your culture.
#
# => 264. Jubilee:
# => Well, you are not going to see it here. The only thing American about this place is that it used to be British. This is Scott. He is new here too.
#
# 265. Scott:
# And I'm already up for a prison break. What do you say we take this blue guy on a little field trip? I'm sure there's a mall around here somewhere.
#
# 266. Kurt:
# What's a mall?
#
# ******** evaluate line 264 in x-men_apocalypse_tw_gapi.csv ********
# 4 pronouns resolved
# 1. you => Jacob
# 2. it => Psylocke
# 3. it => Jacob
# 4. He => Kurt
#
# how many are correctly identified? 0
#
# ******** line 90 ********
# 88. Charles:
# I know. Your mind is the most powerful I've ever seen. - It can convince itself... -
#
# 89. Jean:
# No, it's not just a mind reading or a telekinesis, it's something else. Some... dark power inside and it's growing, like a fire. - I thought I was getting better. -
#
# => 90. Charles:
# => You are. You will. - You just have to be patient. -
#
# 91. Jean:
# No. No. You don't know what it's like to be afraid to shut your eyes. - To be trapped inside your own head. -
#
# 92. Charles:
# Oh, but I think I do. It wasn't so long ago, that I was plagued by voices of myself. All their suffering. All their pain. Their secrets.
#
# ******** evaluate line 90 in x-men_apocalypse_tw_gapi.csv ********
# 3 pronouns resolved
# 1. You => Apocalypse
# 2. You => Star Trek Character
# 3. You => Scott
#
# how many are correctly identified? 0
#
# ******** line 360 ********
# 358. Charles:
# Hank. He's not alone.
#
# 359. Apocalypse:
# Extraordinary.
#
# => 360. Warren:
# => What do you see?
#
# 361. Apocalypse:
# The answer.
#
# 362. Charles:
# Oh my god.
#
# ******** evaluate line 360 in x-men_apocalypse_tw_gapi.csv ********
# 2 pronouns resolved
# 1. What => Horsemen of Apocalypse
# 2. you => Kurt
#
# how many are correctly identified? 0
#
# ******** line 59 ********
# 57. Jean:
# No, you didn't.
#
# 58. Hank:
# Alex Summers?
#
# => 59. Alex:
# => Hank McCoy! Whoa. What happen to the big blue... furry you?
#
# 60. Hank:
# I, keep it under control now.
#
# 61. Alex:
# This is my brother, Scott.
#
# ******** evaluate line 59 in x-men_apocalypse_tw_gapi.csv ********
# 2 pronouns resolved
# 1. What => Dude
# 2. you => Horsemen of Apocalypse
#
# how many are correctly identified? 0
#
# ******** line 151 ********
# 149. Merchant:
# You know what we do with thieves? Choose a hand.
#
# 150. Apocalypse:
# Enough.
#
# => 151. Merchant:
# => If you are with her, I suggest you go away. Go away.
#
# 152. Apocalypse:
# Who rules this world?
#
# 153. Merchant:
# What language is that? Clown! What do you want? Go away! Sorry. Sorry.
#
# ******** evaluate line 151 in x-men_apocalypse_tw_gapi.csv ********
# 4 pronouns resolved
# 1. you => Merchant
# 2. her => Student 3
# 3. I => Angel
# 4. you => Peter's Mom
#
# how many are correctly identified? 0
#
# ******** line 445 ********
# 443. Apocalypse:
#  Useless. Apocalypse: Charles. I know you can hear me. We're still connected. Charles! Show yourself! CHARLES! SHOW YOURSELF! Apocalypse: Foolish child.
#
# 444. Charles:
# Peter. Apocalypse: End him. Charles: Raven. Apocayplse: The great hero. Hank: - I'm going out there. Scott: - I'm going with you. Charles: No. - It's me he wants. Moria: - Charles, you can't give yourself up. If he has you, he has us all. The whole world. Apocalypse: You are feeble. Just like the others. Charles! Come! Rescue your weakling! Give your life, for their's! Charles: No. He was right. There is still some part of me connected to him.
#
# => 445. Apocalypse:
# =>  Charles! Charles: I can get inside his head. Apocalypse: Will you do nothing? Charles: Thank you for letting me in. You want what I have? You want to feel what I feel? Welcome to my world! You're in my house now! Apocalypse: You'll need a bigger house. You betray me? Erik: No. I betrayed them.
#
# 446. Hank:
# Let's jump. Scott: What? Hank: Cover me. I got you. Peter: Come on! Apocalypse: They lack strength, Charles. Charles:Jean. Apocalypse: Come here. Charles: Help... Me. Hank: Stay here. Moira: They can't stop him. Charles: Jean. Help me! Scott: Hank! Hank! Apocalypse: It's over, Charles. You're finished. You're mine now. Charles: You will never win. Apocalypse: And why is that? Charles: Because you are alone. And I am not! Let ... go. Unleash your power, Jean. No fear. Unleash your power! Let go, Jean! Jean, let go! Hank: He's getting away. Apocalypse: All is revealed. Moira: Charles! Charles! - We've lost him! Hank: - Charles. Moira: - He's gone. Hank: - No, Charles. Charles... Jean: No, he's not. I can still feel him. Charles: Thank you, Jean. Moira: Charles? Charles, do you know where you are? Charles: I'm on a beach. In Cuba. With you. Moira: What beach?
#
# ******** evaluate line 445 in x-men_apocalypse_tw_gapi.csv ********
# 19 pronouns resolved
# 1. I => Solider
# 2. his => Warren
# 3. you => Worker
# 4. you => Student 2
# 5. me => Director
# 6. You => William
# 7. what => Crowd
# 8. I => Raven
# 9. You => Dude
# 10. what => Hank
# 11. I => Jacob
# 12. my => Caliban
# 13. You => Merchant
# 14. my => Director
# 15. You => Teacher
# 16. You => Horsemen of Apocalypse
# 17. me => Jacob
# 18. I => Moira
# 19. them => Psylocke
#
# how many are correctly identified? 0
#
# ******** test results ********
# script 1: precision = 0.01 (1/71 correct)
# script 2: precision = 0.01 (1/79 correct)
# script 3: precision = 0.02 (1/53 correct)
# script 4: precision = 0.03 (2/67 correct)
# script 5: precision = 0.01 (1/108 correct)

# %%
df = scripts[1]['df']
df[df.correct.notnull()]
# Out:
#           speaker                                           dialogue  \
# 103    Tony Stark                    Yeah, I got...something bigger.
# 115      narrator  the Avengers are on an aircraft heading out of...
# 195    Tony Stark  If you had to guess, what's it look like it's ...
# 196  Bruce Banner  Like it's thinking. I mean this could be a...i...
# 198  Bruce Banner  I mean, look at this! They're like neurons fir...
# 202  Bruce Banner                    I thought Ultron was a fantasy.
# 222        JARVIS                 I am a program. I am without form.
# 245    Maria Hill  Hey, what about Jane? Where are the ladies, ge...
# 248    Tony Stark  And the company that Pepper runs is the larges...
# 378    Tony Stark  We didn't. We weren't even close. Were we clos...
# 451        Ultron  What?! I'm not...! [he grabs Klaue] I'm not. Y...
# 512  Clint Barton  A safe house. [the Quinjet lands outside a lar...
# 599    Tony Stark  Yeah, I'll give her a kick. [to Steve as he tu...
# 606     Nick Fury  I'm not the director of anybody. I'm just an o...
# 752    Tony Stark  No, of course not! I want to help you put JARV...
# 768  Bruce Banner  Oh, we're way past that. I could choke the lif...
# 781  Bruce Banner                                     What, the gem?
# 874  Steve Rogers  [as Natasha joins them in their battle with th...
# 906  James Rhodes                          You had to make it weird.
# 955    Tony Stark  You know, if this works, we maybe don't walk a...
#
#                                              sentences  \
# 103  [{'content': u'Yeah, I got...something bigger....
# 115  [{'content': u"the Avengers are on an aircraft...
# 195  [{'content': u"If you had to guess, what's it ...
# 196  [{'content': u"Like it's thinking.", 'begin': ...
# 198  [{'content': u'I mean, look at this!', 'begin'...
# 202  [{'content': u'I thought Ultron was a fantasy....
# 222  [{'content': u'I am a program.', 'begin': 0, '...
# 245  [{'content': u'Hey, what about Jane?', 'begin'...
# 248  [{'content': u'And the company that Pepper run...
# 378  [{'content': u"We didn't.", 'begin': 0, 'score...
# 451  [{'content': u'What?!', 'begin': 0, 'score': -...
# 512  [{'content': u'A safe house.', 'begin': 0, 'sc...
# 599  [{'content': u"Yeah, I'll give her a kick. [to...
# 606  [{'content': u"I'm not the director of anybody...
# 752  [{'content': u'No, of course not!', 'begin': 0...
# 768  [{'content': u"Oh, we're way past that.", 'beg...
# 781  [{'content': u'What, the gem?', 'begin': 0, 's...
# 874  [{'content': u'[as Natasha joins them in their...
# 906  [{'content': u'You had to make it weird.', 'be...
# 955  [{'content': u"You know, if this works, we may...
#
#                                sentiment  \
# 103   {u'score': 0.1, u'magnitude': 0.1}
# 115       {u'score': 0, u'magnitude': 0}
# 195  {u'score': -0.1, u'magnitude': 0.1}
# 196   {u'score': 0.3, u'magnitude': 0.7}
# 198   {u'score': 0.4, u'magnitude': 0.8}
# 202  {u'score': -0.1, u'magnitude': 0.1}
# 222   {u'score': 0.1, u'magnitude': 0.2}
# 245  {u'score': -0.1, u'magnitude': 0.4}
# 248   {u'score': 0.4, u'magnitude': 0.8}
# 378  {u'score': -0.4, u'magnitude': 1.3}
# 451  {u'score': -0.1, u'magnitude': 3.5}
# 512   {u'score': 0.2, u'magnitude': 0.5}
# 599  {u'score': -0.1, u'magnitude': 0.8}
# 606    {u'score': -0.1, u'magnitude': 1}
# 752   {u'score': 0.1, u'magnitude': 1.8}
# 768   {u'score': 0.1, u'magnitude': 0.3}
# 781  {u'score': -0.1, u'magnitude': 0.1}
# 874   {u'score': 0.4, u'magnitude': 0.4}
# 906  {u'score': -0.5, u'magnitude': 0.5}
# 955       {u'score': 0, u'magnitude': 0}
#
#                                               entities  \
# 103  [{u'type': u'OTHER', u'meta': {}, u'salience':...
# 115  [{u'type': u'PERSON', u'meta': {u'mid': u'/m/0...
# 195                                                 []
# 196  [{u'type': u'OTHER', u'meta': {}, u'salience':...
# 198  [{u'type': u'OTHER', u'meta': {}, u'salience':...
# 202  [{u'type': u'PERSON', u'meta': {u'mid': u'/m/0...
# 222  [{u'type': u'OTHER', u'meta': {}, u'salience':...
# 245  [{u'type': u'PERSON', u'meta': {u'mid': u'/m/0...
# 248  [{u'type': u'ORGANIZATION', u'meta': {}, u'sal...
# 378  [{u'type': u'OTHER', u'meta': {}, u'salience':...
# 451  [{u'type': u'PERSON', u'meta': {}, u'salience'...
# 512  [{u'type': u'OTHER', u'meta': {}, u'salience':...
# 599  [{u'type': u'PERSON', u'meta': {u'mid': u'/m/0...
# 606  [{u'type': u'PERSON', u'meta': {}, u'salience'...
# 752  [{u'type': u'OTHER', u'meta': {}, u'salience':...
# 768  [{u'type': u'OTHER', u'meta': {}, u'salience':...
# 781  [{u'type': u'OTHER', u'meta': {}, u'salience':...
# 874  [{u'type': u'PERSON', u'meta': {}, u'salience'...
# 906                                                 []
# 955  [{u'type': u'WORK_OF_ART', u'meta': {}, u'sali...
#
#                                                 tokens  num_pron  total_sent  \
# 103  [{u'index': 3, u'begin': 0, u'pos': u'X', u'la...         1        0.01
# 115  [{u'index': 1, u'begin': 0, u'pos': u'DET', u'...         2        0.00
# 195  [{u'index': 2, u'begin': 0, u'pos': u'ADP', u'...         4       -0.01
# 196  [{u'index': 3, u'begin': 0, u'pos': u'ADP', u'...         4        0.21
# 198  [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...         2        0.32
# 202  [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...         1       -0.01
# 222  [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...         2        0.02
# 245  [{u'index': 2, u'begin': 0, u'pos': u'X', u'la...         1       -0.04
# 248  [{u'index': 6, u'begin': 0, u'pos': u'CONJ', u...         1        0.32
# 378  [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...         3       -0.52
# 451  [{u'index': 0, u'begin': 0, u'pos': u'PRON', u...        23       -0.35
# 512  [{u'index': 2, u'begin': 0, u'pos': u'DET', u'...         1        0.10
# 599  [{u'index': 4, u'begin': 0, u'pos': u'X', u'la...         8       -0.08
# 606  [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...         4       -0.10
# 752  [{u'index': 2, u'begin': 0, u'pos': u'X', u'la...         6        0.18
# 768  [{u'index': 3, u'begin': 0, u'pos': u'X', u'la...         3        0.03
# 781  [{u'index': 3, u'begin': 0, u'pos': u'PRON', u...         1       -0.01
# 874  [{u'index': 12, u'begin': 0, u'pos': u'PUNCT',...         8        0.16
# 906  [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...         2       -0.25
# 955  [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...         2        0.00
#
#        speaker_prev      speaker_next  \
# 103    Steve Rogers          narrator
# 115        narrator  Natasha Romanoff
# 195    Bruce Banner      Bruce Banner
# 196      Tony Stark        Tony Stark
# 198      Tony Stark        Tony Stark
# 202      Tony Stark        Tony Stark
# 222          Ultron            Ultron
# 245      Tony Stark        Tony Stark
# 248            Thor              Thor
# 378    Bruce Banner      Steve Rogers
# 451   Ulysses Klaue        Tony Stark
# 512      Tony Stark              Thor
# 599    Laura Barton         Nick Fury
# 606      Tony Stark        Tony Stark
# 752    Bruce Banner      Bruce Banner
# 768  Wanda Maximoff      Steve Rogers
# 781            Thor              Thor
# 874    Clint Barton  Natasha Romanoff
# 906      Tony Stark      Clint Barton
# 955    Steve Rogers              Thor
#
#                                            nearbyChars  correct
# 103  [narrator, Steve Rogers, Tony Stark, narrator,...      0.0
# 115  [narrator, narrator, narrator, Natasha Romanof...      0.0
# 195  [narrator, Bruce Banner, Tony Stark, Bruce Ban...      0.0
# 196  [Bruce Banner, Tony Stark, Bruce Banner, Tony ...      0.0
# 198  [Bruce Banner, Tony Stark, Bruce Banner, Tony ...      0.0
# 202  [Bruce Banner, Tony Stark, Bruce Banner, Tony ...      0.0
# 222           [JARVIS, Ultron, JARVIS, Ultron, JARVIS]      0.0
# 245  [James Rhodes, Tony Stark, Maria Hill, Tony St...      0.0
# 248   [Tony Stark, Thor, Tony Stark, Thor, Maria Hill]      0.0
# 378  [Tony Stark, Bruce Banner, Tony Stark, Steve R...      0.0
# 451  [Ultron, Ulysses Klaue, Ultron, Tony Stark, Ul...      1.0
# 512  [Clint Barton, Tony Stark, Clint Barton, Thor,...      0.0
# 599  [Steve Rogers, Laura Barton, Tony Stark, Nick ...      0.0
# 606  [Nick Fury, Tony Stark, Nick Fury, Tony Stark,...      0.0
# 752  [Tony Stark, Bruce Banner, Tony Stark, Bruce B...      0.0
# 768  [Bruce Banner, Wanda Maximoff, Bruce Banner, S...      0.0
# 781  [Steve Rogers, Thor, Bruce Banner, Thor, Steve...      0.0
# 874  [Pietro Maximoff, Clint Barton, Steve Rogers, ...      0.0
# 906  [James Rhodes, Tony Stark, James Rhodes, Clint...      0.0
# 955     [Thor, Steve Rogers, Tony Stark, Thor, Ultron]      0.0

# %% [markdown]
# Model 1 (pronResolution_nn): sets reference for first-person pronouns to speaker; for second-person pronouns to random choice between previous and next speaker

# %%
# copy scripts
scripts1 = scripts.copy()

# apply model to all scripts
for i in fileIndex:
    charList = scripts1[i]['chars'].keys()  
    scripts1[i]['df'].apply(lambda x: pronResolution_nn(charList, x), axis=1)
    
# manually evaluate results for all scripts
pronEval(scripts1)
# Out:
# ******** line 116 ********
# 114. narrator:
# in Washington D.C., Trask is meeting with Congress to lobby his Sentinel program
#
# 115. Senator Brickman:
# We are reviewing all of our defense expenditures... and all the black books are being opened. We can't support a weapon that targets our own citizens. If these mutants as you describe... are already living among us... then they are living here peacefully. We haven't had an incident in over 10 years.
#
# => 116. Senator Brickman:
# => We are talking about a tenth of a tenth... of a tenth population.
#
# 117. Dr. Trask:
# Allow me to read something to you.
#
# 118. Senator Parker:
# Please.
#
# ******** evaluate line 116 in x-men_days_of_future_past_tw_gapi.csv ********
# 1 pronouns resolved
# 1. We => Guard
#
# how many are correctly identified? 0
#
# ******** line 170 ********
# 168. narrator:
# Wolverine arrives at the X-Mansion which looks abandoned and run down, he notices the sign for Xavier School fallen on the ground, he drives to the front door, gets out of his car and knocks on the front door which is opened by Hank McCoy / Beast
#
# 169. Hank:
# Can I help you?
#
# => 170. Past Wolverine:
# => Uh... Yeah, what happened to the school?
#
# 171. Hank:
# The school's been shut for years. Are you a parent? Past Wolverine:[scoffs] I sure as hell hope not. Who are you?
#
# 172. Hank:
# I'm Hank. Hank McCoy. I look after the house now.
#
# ******** evaluate line 170 in x-men_days_of_future_past_tw_gapi.csv ********
# 1 pronouns resolved
# 1. what => Sunspot
#
# how many are correctly identified? 0
#
# ******** line 144 ********
# 142. narrator:
# as the soldier prepares the injection Sanders walks over to Stryker
#
# 143. Colonel:
# Your men are not military.
#
# => 144. Stryker:
# => Private outfit. [Stryker gives Sanders his paperwork] We're authorized to remand these men.
#
# 145. Colonel:
# [Sanders looks at the papers] Hmm. These troops are going home.
#
# 146. Stryker:
# Well, Colonel, I don't believe you have jurisdiction in this matter.
#
# ******** evaluate line 144 in x-men_days_of_future_past_tw_gapi.csv ********
# 2 pronouns resolved
# 1. his => Bishop
# 2. We => Professor X
#
# how many are correctly identified? 0
#
# ******** line 78 ********
# 76. Kitty:
# Basically, your body will go to sleep. While your mind travels back in time. As long as you're back there, past and present will continue to coexist. But you once wake up... whatever you've done will take hold and become history. And for the rest of us, it will be the only history that we know. It will be like the last that 50 years never happened. And this world, and this war... the only person who remember it is you. All right, Logan... I need you to clear your head and to stay as calm as possible.
#
# 77. Wolverine:
# What? What do you mean?
#
# => 78. Kitty:
# => If your mind gets rocky, it will be harder for me to hold you... and you could start to slip between past and future.
#
# 79. Wolverine:
# What if I need to get a little rocky?
#
# 80. Kitty:
# Think peaceful thoughts?
#
# ******** evaluate line 78 in x-men_days_of_future_past_tw_gapi.csv ********
# 5 pronouns resolved
# 1. your => Wolverine
# 2. it => Dr. Trask
# 3. me => Kitty
# 4. you => Wolverine
# 5. you => Wolverine
#
# how many are correctly identified? 4
#
# ******** line 291 ********
# 289. Ms. Maximoff:
# What's he done now? I just write you a check for whatever he took.
#
# 290. Past Wolverine:
# We just need to talk to him.
#
# => 291. narrator:
# => she lets them enter
#
# 292. Ms. Maximoff:
# Peter! The cops are here. Again.
#
# 293. narrator:
# the three walk down to the basement where Peter is playing table tennis with himself using his powers of speed
#
# ******** evaluate line 291 in x-men_days_of_future_past_tw_gapi.csv ********
# 2 pronouns resolved
# 1. she => Mystique
# 2. them => Guy
#
# how many are correctly identified? 0
#
# ******** line 263 ********
# 261. Hank:
# Uh, JFK.
#
# 262. Past Wolverine:
# he killed...
#
# => 263. Young Charles:
# => What else explains a bullet miraculously curving through the air? Erik's always had a way with guns. Are you sure you want to carry on with this?
#
# 264. Young Charles:
# This is your plan, not mine.
#
# 265. Hank:
# We don't have any resources to get us in.
#
# ******** evaluate line 263 in x-men_days_of_future_past_tw_gapi.csv ********
# 3 pronouns resolved
# 1. What => Magneto
# 2. you => Young Charles
# 3. you => Past Wolverine
#
# how many are correctly identified? 1
#
# ******** line 147 ********
# 145. Colonel:
# [Sanders looks at the papers] Hmm. These troops are going home.
#
# 146. Stryker:
# Well, Colonel, I don't believe you have jurisdiction in this matter.
#
# => 147. Colonel:
# => I'm afraid I do, son.
#
# 148. Stryker:
# I'm sorry, who are you?
#
# 149. narrator:
# Sanders turns Stryker's dog tags around to look at his name
#
# ******** evaluate line 147 in x-men_days_of_future_past_tw_gapi.csv ********
# 2 pronouns resolved
# 1. I => Colonel
# 2. I => Colonel
#
# how many are correctly identified? 2
#
# ******** line 237 ********
# 235. Past Wolverine:
# You're just gonna walk out?
#
# 236. Young Charles:
# Ooh, top marks. Like I said, you are perceptive.
#
# => 237. Past Wolverine:
# => The Professor I know would never turn his back... on someone who'd lost their path. Especially someone he loved.
#
# 238. narrator:
# Logan angrily grabs hold of Charles
#
# 239. Past Wolverine:
# Listen to me, you little shit. I've come a long way, and I've watched a lot of people die. Good people. Friends. If you're gonna wallow in self-pity... and do nothing, then you're gonna watch the same thing... you understand?
#
# ******** evaluate line 237 in x-men_days_of_future_past_tw_gapi.csv ********
# 5 pronouns resolved
# 1. I => Past Wolverine
# 2. his => Bobby
# 3. who => Senator Parker
# 4. their => Beast
# 5. he => Senator Brickman
#
# how many are correctly identified? 1
#
# ******** line 18 ********
# 16. narrator:
# Kitty takes Bishop into a vault and starts to create a link with his consciousness. At the same time Blink goes to help Warpath fight the Sentinels when one of them strikes her down
#
# 17. Warpath:
# Blink! No!
#
# => 18. narrator:
# => she falls and dies. The remaining Sentinels quickly kill Warpath as he tries to protect the vault, and one of the Sentinels breaks into the vault
#
# 19. Kitty:
# Too late, assholes.
#
# 20. narrator:
# just as the Sentinel is about to kill Bishop and Kitty they disappear as they are transported out of there
#
# ******** evaluate line 18 in x-men_days_of_future_past_tw_gapi.csv ********
# 2 pronouns resolved
# 1. she => Colonel
# 2. he => Sectary
#
# how many are correctly identified? 0
#
# ******** line 76 ********
# 74. Magneto:
# Well, it's complicated.
#
# 75. narrator:
# Logan is lying down as Kitty prepares him
#
# => 76. Kitty:
# => Basically, your body will go to sleep. While your mind travels back in time. As long as you're back there, past and present will continue to coexist. But you once wake up... whatever you've done will take hold and become history. And for the rest of us, it will be the only history that we know. It will be like the last that 50 years never happened. And this world, and this war... the only person who remember it is you. All right, Logan... I need you to clear your head and to stay as calm as possible.
#
# 77. Wolverine:
# What? What do you mean?
#
# 78. Kitty:
# If your mind gets rocky, it will be harder for me to hold you... and you could start to slip between past and future.
#
# ******** evaluate line 76 in x-men_days_of_future_past_tw_gapi.csv ********
# 15 pronouns resolved
# 1. your => Wolverine
# 2. your => narrator
# 3. you => Wolverine
# 4. you => Wolverine
# 5. you => narrator
# 6. us => Senator Parker
# 7. it => Soldier
# 8. we => Mystique
# 9. It => Stryker
# 10. who => Toad
# 11. it => Sectary
# 12. you => Wolverine
# 13. I => Kitty
# 14. you => narrator
# 15. your => narrator
#
# how many are correctly identified? 5
#
# ******** line 67 ********
# 65. Professor X:
# You'll need to go to my house and find me. Convince me of all of this.
#
# 66. Wolverine:
# Won't you be able to just read my mind?
#
# => 67. Professor X:
# => I didn't have my powers in 1973. Logan, you're going to have to do for me what I once did for you. Lead me, guide me. I was a very different man then. You'll have to be patient with me.
#
# 68. Wolverine:
# Patience is my strongest suit.
#
# 69. Magneto:
# You'll need me as well.
#
# ******** evaluate line 67 in x-men_days_of_future_past_tw_gapi.csv ********
# 12 pronouns resolved
# 1. I => Professor X
# 2. my => Professor X
# 3. you => Wolverine
# 4. me => Professor X
# 5. what => Ms. Maximoff
# 6. I => Professor X
# 7. you => Wolverine
# 8. me => Professor X
# 9. me => Professor X
# 10. I => Professor X
# 11. You => Wolverine
# 12. me => Professor X
#
# how many are correctly identified? 11
#
# ******** line 296 ********
# 294. Quicksilver:
# What do you guys want? I didn't do anything. [suddenly he sits down on the couch] I've been here all day.
#
# 295. Past Wolverine:
# Just relax, Peter. We're not Cops.
#
# => 296. Quicksilver:
# => Of course you're not. If you were, you wouldn't be driving a rental car.
#
# 297. Young Charles:
# How did you know we've got a rental car?
#
# 298. Quicksilver:
# I checked your registration when you were walking to the door. I also had some time to kill so I went through your rental agreement. Saw you were from out of town. Are you FBI? [using his power he quickly swipes Charles' wallet and looks at Charles' card] No, you're not cops. Hey, what's with his gifted youngsters place? [he drops the card and wallet to the floor]
#
# ******** evaluate line 296 in x-men_days_of_future_past_tw_gapi.csv ********
# 3 pronouns resolved
# 1. you => Past Wolverine
# 2. you => Past Wolverine
# 3. you => Past Wolverine
#
# how many are correctly identified? 3
#
# ******** line 219 ********
# 217. Young Charles:
# All right, you've piqued my interest. What do you want?
#
# 218. Past Wolverine:
# We have to stop Raven. I need your help. We need your help.
#
# => 219. Young Charles:
# => [emotional] I think I'd like to wake up now. [walks away]
#
# 220. narrator:
# Charles walks turns and walks into the next room
#
# 221. Hank:
# [To Logan] What does she have to do with this?
#
# ******** evaluate line 219 in x-men_days_of_future_past_tw_gapi.csv ********
# 2 pronouns resolved
# 1. I => Young Charles
# 2. I => Young Charles
#
# how many are correctly identified? 0
#
# ******** line 35 ********
# 33. narrator:
# they embrace
#
# 34. Wolverine:
# Hey, kid.
#
# => 35. narrator:
# => Bobby nods his head to Logan
#
# 36. Kitty:
# Professor, you made it.
#
# 37. narrator:
# she joins them along with Colossus, who is also alive
#
# ******** evaluate line 35 in x-men_days_of_future_past_tw_gapi.csv ********
# 1 pronouns resolved
# 1. his => Past Wolverine
#
# how many are correctly identified? 0
#
# ******** line 143 ********
# 141. Stryker:
# Something to make the ride a little smoother. I'm transferring you to a private facility... where we can run a few more tests.
#
# 142. narrator:
# as the soldier prepares the injection Sanders walks over to Stryker
#
# => 143. Colonel:
# => Your men are not military.
#
# 144. Stryker:
# Private outfit. [Stryker gives Sanders his paperwork] We're authorized to remand these men.
#
# 145. Colonel:
# [Sanders looks at the papers] Hmm. These troops are going home.
#
# ******** evaluate line 143 in x-men_days_of_future_past_tw_gapi.csv ********
# 1 pronouns resolved
# 1. Your => narrator
#
# how many are correctly identified? 0
#
# ******** line 131 ********
# 129. Soldier:
# Atten-hut!
#
# 130. narrator:
# the soldiers all rise
#
# => 131. Colonel:
# => At ease. [as Sanders walks through the tent he looks at the mutant soldiers, he notices Alex Summers/Havok and winks at him, Alex looks at him with confusion, Strand goes over the doctor who's collecting blood samples] What's all this?
#
# 132. Soldier:
# Lab reports, blood tests. It's all getting packing up and shipped back.
#
# 133. Colonel:
# Where is it going?
#
# ******** evaluate line 131 in x-men_days_of_future_past_tw_gapi.csv ********
# 6 pronouns resolved
# 1. he => Senator Brickman
# 2. he => Soldier
# 3. him => Trask(flashback)
# 4. him => Havok
# 5. who => Warpath
# 6. What => Ms. Maximoff
#
# how many are correctly identified? 0
#
# ******** line 5 ********
# 3. Professor X:
# Is the future truly set?
#
# 4. narrator:
# cue Main Titles
#
# => 5. narrator:
# => in Moscow a mutant, Warpath, spots several pods carrying robots and dropping them near the building they're ransacking
#
# 6. Warpath:
# They're here!
#
# 7. narrator:
# he joins another mutant, Blink. Using her powers she opens a portal to transport them to the lower level to warn their fellow mutants: Colossus, Sunspot, Bishop and Kitty Pryde
#
# ******** evaluate line 5 in x-men_days_of_future_past_tw_gapi.csv ********
# 2 pronouns resolved
# 1. them => Young Raven
# 2. they => Ramone
#
# how many are correctly identified? 0
#
# ******** line 204 ********
# 202. Young Charles:
# Like in the future, 50 years from now?
#
# 203. Past Wolverine:
# Yeah.
#
# => 204. Young Charles:
# => I sent you from the future?
#
# 205. Past Wolverine:
# Yeah.
#
# 206. Young Charles:
# Piss off.
#
# ******** evaluate line 204 in x-men_days_of_future_past_tw_gapi.csv ********
# 2 pronouns resolved
# 1. I => Young Charles
# 2. you => Past Wolverine
#
# how many are correctly identified? 2
#
# ******** line 215 ********
# 213. Past Wolverine:
# I know you, Charles. We've been friends for years. I know your powers came when you were 9. I know you thought you were going crazy when it started... all the voices in your head. And it wasn't until you were 12... that you realized all the voices were in everyone else's head. Do you want me to go on?
#
# 214. narrator:
# Charles looks confused and shocked
#
# => 215. Young Charles:
# => I never told anyone that.
#
# 216. Past Wolverine:
# No, yet, no, but, you will.
#
# 217. Young Charles:
# All right, you've piqued my interest. What do you want?
#
# ******** evaluate line 215 in x-men_days_of_future_past_tw_gapi.csv ********
# 1 pronouns resolved
# 1. I => Young Charles
#
# how many are correctly identified? 0
#
# ******** line 141 ********
# 139. narrator:
# another solider opens a case containing vials of drugs
#
# 140. Toad:
# What are you doing with those?
#
# => 141. Stryker:
# => Something to make the ride a little smoother. I'm transferring you to a private facility... where we can run a few more tests.
#
# 142. narrator:
# as the soldier prepares the injection Sanders walks over to Stryker
#
# 143. Colonel:
# Your men are not military.
#
# ******** evaluate line 141 in x-men_days_of_future_past_tw_gapi.csv ********
# 3 pronouns resolved
# 1. I => Stryker
# 2. you => Toad
# 3. we => Guard
#
# how many are correctly identified? 1
#
# ******** line 245 ********
# 243. James Rhodes:
# Quality save. So, no Pepper? She's not coming?
#
# 244. Tony Stark:
# No.
#
# => 245. Maria Hill:
# => Hey, what about Jane? Where are the ladies, gentlemen?
#
# 246. Tony Stark:
# Well, Miss Potts has a company to run.
#
# 247. Thor:
# Yes, I'm not even sure what country Jane's in. Her work on the convergence has made her the world's foremost astronomer.
#
# ******** evaluate line 245 in avengers_age_of_ultron_tw_gapi.csv ********
# 1 pronouns resolved
# 1. what => Ultron
#
# how many are correctly identified? 0
#
# ******** line 768 ********
# 766. Bruce Banner:
# And you do? She's not in your head?
#
# 767. Wanda Maximoff:
# I know you're angry.
#
# => 768. Bruce Banner:
# => Oh, we're way past that. I could choke the life out of you and never change a shade.
#
# 769. Steve Rogers:
# Banner, after everything that's happened...
#
# 770. Tony Stark:
# That's nothing compared to what's coming!
#
# ******** evaluate line 768 in avengers_age_of_ultron_tw_gapi.csv ********
# 3 pronouns resolved
# 1. we => Dr. List
# 2. I => Bruce Banner
# 3. you => Wanda Maximoff
#
# how many are correctly identified? 2
#
# ******** line 512 ********
# 510. Clint Barton:
# No, I'm good. If you wanna get some kip, now's a good time, cause we're still a few hours out.
#
# 511. Tony Stark:
# A few hours from where?
#
# => 512. Clint Barton:
# => A safe house. [the Quinjet lands outside a large farmhouse and they all walk towards the house]
#
# 513. Thor:
# What is this place?
#
# 514. Tony Stark:
# A safe house?
#
# ******** evaluate line 512 in avengers_age_of_ultron_tw_gapi.csv ********
# 1 pronouns resolved
# 1. they => World Hub Tech
#
# how many are correctly identified? 0
#
# ******** line 874 ********
# 872. Pietro Maximoff:
# Keep up old man! [Barton holds his arrow to aim it at Pietro]
#
# 873. Clint Barton:
# Nobody would know. Nobody. "The last I saw him, when Ultron was sitting on him. Uh...yeah, he'll be missed, that quick little bastard. I miss him already."
#
# => 874. Steve Rogers:
# => [as Natasha joins them in their battle with the robots] Romanoff! [he throws his shield at her so she can use it to protect herself from the attacking robot]
#
# 875. Natasha Romanoff:
# Thanks. [back to Stark]
#
# 876. FRIDAY:
# The anti-gravs are rigged to flip. Touch 'em, they'll go full reverse thrust. The city's not coming down slow.
#
# ******** evaluate line 874 in avengers_age_of_ultron_tw_gapi.csv ********
# 8 pronouns resolved
# 1. them => Zrinka
# 2. their => FRIDAY
# 3. he => FRIDAY
# 4. his => Klaue's Mercenary
# 5. her => Thor
# 6. she => Ultron
# 7. it => Pietro Maximoff
# 8. herself => Maria Hill
#
# how many are correctly identified? 0
#
# ******** line 196 ********
# 194. Bruce Banner:
# It's beautiful.
#
# 195. Tony Stark:
# If you had to guess, what's it look like it's doing?
#
# => 196. Bruce Banner:
# => Like it's thinking. I mean this could be a...it's not a human mind, it...
#
# 197. Tony Stark:
# Um-um.
#
# 198. Bruce Banner:
# I mean, look at this! They're like neurons firing.
#
# ******** evaluate line 196 in avengers_age_of_ultron_tw_gapi.csv ********
# 4 pronouns resolved
# 1. it => Dr. List
# 2. I => Bruce Banner
# 3. it => Zrinka
# 4. it => Natasha Romanoff
#
# how many are correctly identified? 1
#
# ******** line 606 ********
# 604. Nick Fury:
# Look me in the eye and tell me you're going to shut him down.
#
# 605. Tony Stark:
# You're not the director of me.
#
# => 606. Nick Fury:
# => I'm not the director of anybody. I'm just an old man, who cares very much about you.
#
# 607. Tony Stark:
# And I'm the man who killed the Avengers. I saw it. I didn't tell the team, how could I? I saw them all dead, Nick. I felt it. The whole world, too. It's because of me. I wasn't ready. I didn't do all I could.
#
# 608. Nick Fury:
# The Maximoff girl, she's working you, Stark. Playing on your fear.
#
# ******** evaluate line 606 in avengers_age_of_ultron_tw_gapi.csv ********
# 4 pronouns resolved
# 1. I => Nick Fury
# 2. I => Nick Fury
# 3. who => Sam Wilson
# 4. you => Tony Stark
#
# how many are correctly identified? 3
#
# ******** line 781 ********
# 779. Steve Rogers:
# Thor, you helped create this?
#
# 780. Thor:
# I've had a vision. A whirlpool that sucks in all hope of life and at it's center is that. [he points to the gem inside Vision's head]
#
# => 781. Bruce Banner:
# => What, the gem?
#
# 782. Thor:
# It's the Mind Stone. It's one of the six Infinity Stones, the greatest power in the universe, unparalleled in its destructive capabilities.
#
# 783. Steve Rogers:
# Then why would you bring it to...
#
# ******** evaluate line 781 in avengers_age_of_ultron_tw_gapi.csv ********
# 1 pronouns resolved
# 1. What => Bruce Banner
#
# how many are correctly identified? 0
#
# ******** line 451 ********
# 449. Ultron:
# What?
#
# 450. Ulysses Klaue:
# Tony Stark used to say that...to me. You're one of his.
#
# => 451. Ultron:
# => What?! I'm not...! [he grabs Klaue] I'm not. You think I'm one of Stark's puppets, his hollow men? I mean look at me, do I look like Iron Man? Stark is... [suddenly he chops off Klaue's arm] I'm sorry. I am sor... Ooh, I'm sure that's going to be okay. I'm sorry, it's just I don't understand. Don't compare me with Stark! [he kicks Klaue down the stairs] It's a thing with me. Stark is, he's a sickness! [Stark appears in his Iron Man suit]
#
# 452. Tony Stark:
# Ahh, Junior. [Thor and Steve are behind him] You're gonna break your old man's heart.
#
# 453. Ultron:
# If I have to.
#
# ******** evaluate line 451 in avengers_age_of_ultron_tw_gapi.csv ********
# 23 pronouns resolved
# 1. What => Clint Barton
# 2. I => Ultron
# 3. he => Klaue's Mercenary
# 4. I => Ultron
# 5. You => Ulysses Klaue
# 6. I => Ultron
# 7. his => Natasha Romanoff
# 8. I => Ultron
# 9. me => Ultron
# 10. I => Ultron
# 11. he => World Hub Tech
# 12. I => Ultron
# 13. I => Ultron
# 14. I => Ultron
# 15. I => Ultron
# 16. it => James Rhodes
# 17. I => Ultron
# 18. me => Ultron
# 19. he => Strucker
# 20. It =>  Steve Rogers
# 21. me => Ultron
# 22. he => Jarvis
# 23. his => JARVIS
#
# how many are correctly identified? 14
#
# ******** line 599 ********
# 597. Steve Rogers:
# Every time someone tries to win a war before it starts, innocent people die. Every time. [Laura interrupts them]
#
# 598. Laura Barton:
# I'm sorry. Mr. Stark, uh, Clint said you wouldn't mind, but, our tractor, it doesn't seem to want to start at all. I thought maybe you might...
#
# => 599. Tony Stark:
# => Yeah, I'll give her a kick. [to Steve as he turns to leave; referring to his pile of chopped wood] Don't take from my pile. [Stark enters the barn and walks over to the tractor] Hello, Deere. Tell me everything. What ails you? [suddenly Fury shows up from the other end of the barn]
#
# 600. Nick Fury:
# Do me a favor. Try not to bring it to life.
#
# 601. Tony Stark:
# Ah, Mrs. Barton, you little minx. I get it, Maria Hill called you, right? Was she ever not working for you?
#
# ******** evaluate line 599 in avengers_age_of_ultron_tw_gapi.csv ********
# 8 pronouns resolved
# 1. I => Tony Stark
# 2. her => Ultron
# 3. he => JARVIS
# 4. his => Peggy Carter
# 5. my => Tony Stark
# 6. me => Tony Stark
# 7. What => Steve Rogers
# 8. you => Laura Barton
#
# how many are correctly identified? 3
#
# ******** line 906 ********
# 904. James Rhodes:
# You think I can't hold my own?
#
# 905. Tony Stark:
# We get through this, I'll hold your own.
#
# => 906. James Rhodes:
# => You had to make it weird.
#
# 907. Clint Barton:
# [as the team helps the people onto the Helicarrier lifeboats] Alright, let's load 'em up! Alright, here we go. Here we go, let's move. Let's go everyone!
#
# 908. Specialist Cameron Klein:
# Number six boat is topped and locked. Or, uh, or stocked, topped. It...it's, uh, full of people.
#
# ******** evaluate line 906 in avengers_age_of_ultron_tw_gapi.csv ********
# 2 pronouns resolved
# 1. You => Clint Barton
# 2. it => Maria Hill
#
# how many are correctly identified? 0
#
# ******** line 248 ********
# 246. Tony Stark:
# Well, Miss Potts has a company to run.
#
# 247. Thor:
# Yes, I'm not even sure what country Jane's in. Her work on the convergence has made her the world's foremost astronomer.
#
# => 248. Tony Stark:
# => And the company that Pepper runs is the largest tech conglomerate on earth. It's pretty exciting.
#
# 249. Thor:
# There's even talk of Jane getting a... um, uh... Nobel prize.
#
# 250. Maria Hill:
# Yeah, they...they must be busy because they'd hate missing you guys get together. [Maria mock coughs] Testosterone! Oh, excuse me.
#
# ******** evaluate line 248 in avengers_age_of_ultron_tw_gapi.csv ********
# 1 pronouns resolved
# 1. It => Laura Barton
#
# how many are correctly identified? 0
#
# ******** line 202 ********
# 200. Bruce Banner:
# Artificial intelligence.
#
# 201. Tony Stark:
# This could be it, Bruce. This could be the key to creating Ultron.
#
# => 202. Bruce Banner:
# => I thought Ultron was a fantasy.
#
# 203. Tony Stark:
# Yesterday it was. If we can harness this power, apply it to my Iron Legion protocol.
#
# 204. Bruce Banner:
# That's a mad-sized if.
#
# ******** evaluate line 202 in avengers_age_of_ultron_tw_gapi.csv ********
# 1 pronouns resolved
# 1. I => Bruce Banner
#
# how many are correctly identified? 1
#
# ******** line 222 ********
# 220. JARVIS:
# Hello, I am JARVIS. You are Ultron, a global peace-keeping initiative designed by Mr. Stark. Our sentience integration trials have been unsuccessful so I'm not certain what triggered your...
#
# 221. Ultron:
# Where's my...where is your body?
#
# => 222. JARVIS:
# => I am a program. I am without form.
#
# 223. Ultron:
# This feels weird. This feels wrong.
#
# 224. JARVIS:
# I am contacting Mr. Stark now.
#
# ******** evaluate line 222 in avengers_age_of_ultron_tw_gapi.csv ********
# 2 pronouns resolved
# 1. I => JARVIS
# 2. I => JARVIS
#
# how many are correctly identified? 0
#
# ******** line 955 ********
# 953. Thor:
# [referring to the people getting onto the lifeboats] Is this the last of them?
#
# 954. Steve Rogers:
# Yeah. Everyone else is on the carrier.
#
# => 955. Tony Stark:
# => You know, if this works, we maybe don't walk away.
#
# 956. Thor:
# Maybe not. [just as Natasha tries to calm Hulk down to get him back to being Banner Ultron flies in with a jet and starts shooting at them]
#
# 957. Ultron:
# [sings] I got no strings, so I have fun. I'm not tied up to anyone. [as Barton is saving the boy, Costel, Ultron starts shooting at them but Pietro intervenes and takes the shots to save them]
#
# ******** evaluate line 955 in avengers_age_of_ultron_tw_gapi.csv ********
# 2 pronouns resolved
# 1. You => Thor
# 2. we =>  Steve Rogers
#
# how many are correctly identified? 0
#
# ******** line 198 ********
# 196. Bruce Banner:
# Like it's thinking. I mean this could be a...it's not a human mind, it...
#
# 197. Tony Stark:
# Um-um.
#
# => 198. Bruce Banner:
# => I mean, look at this! They're like neurons firing.
#
# 199. Tony Stark:
# Down in Strucker's lab I saw some fairly advanced robotics work. They deep-sixed the data, but...I gotta guess he was knocking on a very particular door.
#
# 200. Bruce Banner:
# Artificial intelligence.
#
# ******** evaluate line 198 in avengers_age_of_ultron_tw_gapi.csv ********
# 2 pronouns resolved
# 1. I => Bruce Banner
# 2. They => Nick Fury
#
# how many are correctly identified? 1
#
# ******** line 378 ********
# 376. Tony Stark:
# Really?! That's it? You just roll over, show your belly, every time somebody snarls.
#
# 377. Bruce Banner:
# Only when I've created a murder bot.
#
# => 378. Tony Stark:
# => We didn't. We weren't even close. Were we close to an interface?
#
# 379. Steve Rogers:
# Well, you did something right. And you did it right here. The Avengers were supposed to be different than SHIELD.
#
# 380. Tony Stark:
# Anybody remember when I carried a nuke through a wormhole?
#
# ******** evaluate line 378 in avengers_age_of_ultron_tw_gapi.csv ********
# 3 pronouns resolved
# 1. We => Thor
# 2. We => Jarvis
# 3. we => Thor
#
# how many are correctly identified? 0
#
# ******** line 752 ********
# 750. Tony Stark:
# Ultron didn't go after JARVIS cause he was angry. He attacked him because he was scared of what he can do. So JARVIS went underground. Okay? Scattered, dumped his memory. But not his protocols. He didn't even know he was in there, until I pieced him together.
#
# 751. Bruce Banner:
# So, you want me to help you put JARVIS into this thing?
#
# => 752. Tony Stark:
# => No, of course not! I want to help you put JARVIS in this thing. [Banner shakes his head] We're out of my field here. You know bio-organics better than anyone.
#
# 753. Bruce Banner:
# And you just assume that JARVIS' operational matrix can beat Ultron's?
#
# 754. Tony Stark:
# JARVIS has been beating him from inside without knowing it. This is the opportunity, we can create Ultron's perfect self, without the homicidal glitches he thinks are his winning personality. We have to.
#
# ******** evaluate line 752 in avengers_age_of_ultron_tw_gapi.csv ********
# 6 pronouns resolved
# 1. I => Tony Stark
# 2. you => Bruce Banner
# 3. his => Zrinka
# 4. We => Madame B
# 5. my => Tony Stark
# 6. You => Bruce Banner
#
# how many are correctly identified? 4
#
# ******** line 103 ********
# 101. narrator:
# Steve uses his shield to knock out Strucker
#
# 102. Steve Rogers:
# Guys, I got Strucker.
#
# => 103. Tony Stark:
# => Yeah, I got...something bigger.
#
# 104. narrator:
# inside the secret passageway Stark finds a room with recovered artifacts from the Battle of New York, including a gigantic Chitauri leviathan and some of his Iron Man scrapped armor, he then spots the scepter
#
# 105. Tony Stark:
# Thor, I got eyes on the prize.
#
# ******** evaluate line 103 in avengers_age_of_ultron_tw_gapi.csv ********
# 1 pronouns resolved
# 1. I => Tony Stark
#
# how many are correctly identified? 1
#
# ******** line 195 ********
# 193. narrator:
# he brings up another 3D image of what's inside the scepter
#
# 194. Bruce Banner:
# It's beautiful.
#
# => 195. Tony Stark:
# => If you had to guess, what's it look like it's doing?
#
# 196. Bruce Banner:
# Like it's thinking. I mean this could be a...it's not a human mind, it...
#
# 197. Tony Stark:
# Um-um.
#
# ******** evaluate line 195 in avengers_age_of_ultron_tw_gapi.csv ********
# 4 pronouns resolved
# 1. you => Bruce Banner
# 2. what => Tony Stark
# 3. it => Party Guest
# 4. it =>  Steve Rogers
#
# how many are correctly identified? 1
#
# ******** line 115 ********
# 113. narrator:
# Wanda smiles to herself as Tony takes the scepter
#
# 114. narrator:
# Title Sequence plays
#
# => 115. narrator:
# => the Avengers are on an aircraft heading out of Sokovia, Natasha interrupts Banner who's listening to opera with his headphones
#
# 116. Natasha Romanoff:
# Hey, the lullaby worked better than ever.
#
# 117. Bruce Banner:
# Just wasn't expecting the Code Green.
#
# ******** evaluate line 115 in avengers_age_of_ultron_tw_gapi.csv ********
# 2 pronouns resolved
# 1. who => Bruce Banner
# 2. his => Heimdall
#
# how many are correctly identified? 0
#
# ******** line 107 ********
# 105. Charles:
# I don't have to be psychic to see that something's bothering you.
#
# 106. Storm:
# I don't understand. Magneto's a fugitive, we've a mutant in the cabinet, a president who understands us - why hide?
#
# => 107. Charles:
# => We're not hiding. But we still have enemies. I must protect my students. You know that.
#
# 108. Storm:
# Yes, but we can't be students forever.
#
# 109. Charles:
# Storm, I haven't thought of you as my student for years. In fact, I thought that perhaps you might take my place some day.
#
# ******** evaluate line 107 in x-men_the_last_stand_tw_gapi.csv ********
# 5 pronouns resolved
# 1. We => Moira
# 2. we => Reporter
# 3. I => Charles
# 4. my => Charles
# 5. You => Storm
#
# how many are correctly identified? 3
#
# ******** line 80 ********
# 78. President:
# We have some new prisons. We'll keep them mobile. Be a step ahead.
#
# 79. Interrogator:
# Where is Magneto? Raven? - Raven, I asked you a question.
#
# => 80. Raven:
# => I don't answer to my slave name.
#
# 81. Interrogator:
# Raven Darkholme. That's your real name, isn't it? Or has he convinced you you don't have a family any more?
#
# 82. Raven:
# My family tried to kill me, you pathetic meat sack.
#
# ******** evaluate line 80 in x-men_the_last_stand_tw_gapi.csv ********
# 2 pronouns resolved
# 1. I => Raven
# 2. my => Raven
#
# how many are correctly identified? 2
#
# ******** line 99 ********
# 97. Charles:
# When an individual acquires great power, the use or misuse of that power is everything. Will it be for the greater good or will it be used for personal or for destructive ends? Now, this is a question we must all ask ourselves. Why? Because we are mutants. For psychics, this presents a particular problem. When is it acceptable to use our power and when do we cross that invisible line that turns us into tyrants over our fellow man?
#
# 98. Kitty:
# But Einstein said that ethics are an exclusive human concern without any superhuman authority behind it.
#
# => 99. Charles:
# => Einstein wasn't a mutant so far as we know. This case study was sent to me by a colleague, Dr. Moira McTaggert. Jones.
#
# 100. Moira:
# The man you see here was born with no higher-level brain functions. His organs and nervous system work, but he has no consciousness to speak of.
#
# 101. Charles:
# What if we were to transfer the consciousness of one person, say a father of four with terminal cancer, into the body of this man? How are we to decide what falls within the range of ethical behavior and what...
#
# ******** evaluate line 99 in x-men_the_last_stand_tw_gapi.csv ********
# 2 pronouns resolved
# 1. we => Guard
# 2. me => Charles
#
# how many are correctly identified? 1
#
# ******** line 285 ********
# 283. Jean:
# Yes, it is me.
#
# 284. Logan:
# No. Maybe you ought to take it easy. The professor said you might be different.
#
# => 285. Phoenix:
# => He would know, wouldn't he?
#
# 286. Logan:
# What? You think he's not in your head too?
#
# 287. Phoenix:
# Look at you, Logan. He's tamed you.
#
# ******** evaluate line 285 in x-men_the_last_stand_tw_gapi.csv ********
# 2 pronouns resolved
# 1. He => Young Jean
# 2. he => CaIisto
#
# how many are correctly identified? 0
#
# ******** line 314 ********
# 312. Storm:
# What? - That's not possible.
#
# 313. Charles:
# I warned you. She's left the mansion, but she's trying to block my thoughts. She's so strong. It may be too late. - Wait for me here.
#
# => 314. Logan:
# => What?
#
# 315. Charles:
# I need to see Jean alone.
#
# 316. Eric:
# You were right, Charles. - This one is special.
#
# ******** evaluate line 314 in x-men_the_last_stand_tw_gapi.csv ********
# 1 pronouns resolved
# 1. What => Mutant
#
# how many are correctly identified? 0
#
# ******** line 202 ********
# 200. Logan:
# I can't see a damn thing.
#
# 201. Storm:
# I can take care of that.
#
# => 202. Logan:
# => What the...
#
# 203. Storm:
# Logan! She's alive.
#
# 204. Logan:
# Jean.
#
# ******** evaluate line 202 in x-men_the_last_stand_tw_gapi.csv ********
# 1 pronouns resolved
# 1. What => Raven
#
# how many are correctly identified? 0
#
# ******** line 302 ********
# 300. Logan:
# Stop it. Look at me. Look at me. Jean. It'll be all right. We can help you. Hey. The professor can help. He can fix it.
#
# 301. Phoenix:
# I don't want to fix it.
#
# => 302. Eric:
# => Voluntary? They put the cure in a gun. I told you they would draw first blood.
#
# 303. John:
# So what do we do? - What do we do?
#
# 304. Eric:
# We use this weapon as a lightning rod to bring countless more to our cause. Come. We have an army to build.
#
# ******** evaluate line 302 in x-men_the_last_stand_tw_gapi.csv ********
# 4 pronouns resolved
# 1. They => President
# 2. I => Eric
# 3. you => Phoenix
# 4. they => Staff Woman
#
# how many are correctly identified? 0
#
# ******** line 172 ********
# 170. Dr. Rao:
# We are in compliance with your policy.
#
# 171. Hank:
# How long will you keep the boy here?
#
# => 172. Dr. Rao:
# => Until we can fully map his DNA. We can replicate it, but we can't generate it.
#
# 173. Hank:
# And his power? What is its range?
#
# 174. Dr. Rao:
# You'll see. Jimmy. There's someone I would like you to meet.
#
# ******** evaluate line 172 in x-men_the_last_stand_tw_gapi.csv ********
# 6 pronouns resolved
# 1. we => Psylocke
# 2. his => Jean
# 3. We => Eric
# 4. it => Phoenix
# 5. we => Lady
# 6. it => Staff Woman
#
# how many are correctly identified? 0
#
# ******** line 47 ********
# 45. Storm:
# You can't change the rules.
#
# 46. Loggan:
# I'm trying to teach 'em something. - I taught 'em something.
#
# => 47. Storm:
# => It was a defensive exercise.
#
# 48. Logan:
# Yeah, best defense is a good offence. Or is it the other way round?
#
# 49. Storm:
# This isn't a game, Logan.
#
# ******** evaluate line 47 in x-men_the_last_stand_tw_gapi.csv ********
# 1 pronouns resolved
# 1. It => Mutant
#
# how many are correctly identified? 0
#
# ******** line 157 ********
# 155. John:
# You know who you're talking to?
#
# 156. Quill:
# Do you?
#
# => 157. Eric:
# => And what can you do?  So you have talents?
#
# 158. Calisto:
# That and more. I know you control metal. And I know there's 87 mutants in here, none above a class three. Other than you two.
#
# 159. Eric:
# You can sense other mutants and their powers? Could you locate one for me?
#
# ******** evaluate line 157 in x-men_the_last_stand_tw_gapi.csv ********
# 3 pronouns resolved
# 1. what => Lady
# 2. you => Quill
# 3. you => Quill
#
# how many are correctly identified? 0
#
# ******** line 77 ********
# 75. Hank:
# Yes, sir. She can do that.
#
# 76. President:
# Not any more, she can't. We got her.
#
# => 77. Hank:
# => You think your prisons can hold her?
#
# 78. President:
# We have some new prisons. We'll keep them mobile. Be a step ahead.
#
# 79. Interrogator:
# Where is Magneto? Raven? - Raven, I asked you a question.
#
# ******** evaluate line 77 in x-men_the_last_stand_tw_gapi.csv ********
# 3 pronouns resolved
# 1. You => President
# 2. your => President
# 3. her => Reporter
#
# how many are correctly identified? 2
#
# ******** line 223 ********
# 221. Charles:
# I had a terrible choice to make. I chose the lesser of two evils.
#
# 222. Logan:
# It sounds to me like Jean had no choice at all.
#
# => 223. Charles:
# => I don't have to explain myself, least of all to you.
#
# 224. Reporter:
# History will be made here today. For the first time, the so-called mutant cure will be available to the public. Reaction has run the gamut with mutants on both sides of the line. Some are desperate for this cure while others are offended by the very idea of it.
#
# 225. Mr. Worthington:
# Will Secretary McCoy be a problem?
#
# ******** evaluate line 223 in x-men_the_last_stand_tw_gapi.csv ********
# 3 pronouns resolved
# 1. I => Charles
# 2. myself => Mrs. Grey
# 3. you => Reporter
#
# how many are correctly identified? 1
#
# ******** line 215 ********
# 213. Charles:
# I'm keeping her that way. I'm trying to restore the psychic blocks and cage the beast again.
#
# 214. Logan:
# What have you done to her?
#
# => 215. Charles:
# => You have to understand...
#
# 216. Logan:
# You're talking about a person's mind.
#
# 217. Charles:
# She has to be controlled.
#
# ******** evaluate line 215 in x-men_the_last_stand_tw_gapi.csv ********
# 1 pronouns resolved
# 1. You => Logan
#
# how many are correctly identified? 1
#
# ******** line 109 ********
# 107. Charles:
# We're not hiding. But we still have enemies. I must protect my students. You know that.
#
# 108. Storm:
# Yes, but we can't be students forever.
#
# => 109. Charles:
# => Storm, I haven't thought of you as my student for years. In fact, I thought that perhaps you might take my place some day.
#
# 110. Storm:
# But Scott's...
#
# 111. Charles:
# Scott's a changed man. He took Jean's death so hard. Yes, things are better out there, but you, of all people, know how fast the weather can change.
#
# ******** evaluate line 109 in x-men_the_last_stand_tw_gapi.csv ********
# 6 pronouns resolved
# 1. I => Charles
# 2. you => Storm
# 3. my => Charles
# 4. I => Charles
# 5. you => Storm
# 6. my => Charles
#
# how many are correctly identified? 6
#
# ******** line 159 ********
# 157. Eric:
# And what can you do?  So you have talents?
#
# 158. Calisto:
# That and more. I know you control metal. And I know there's 87 mutants in here, none above a class three. Other than you two.
#
# => 159. Eric:
# => You can sense other mutants and their powers? Could you locate one for me?
#
# 160. President:
# Let me out of here. I demand that you release me. Do you know who I am? I'm the president of the United States.
#
# 161. Guard:
# Oh, Mr. President. Shut up.
#
# ******** evaluate line 159 in x-men_the_last_stand_tw_gapi.csv ********
# 4 pronouns resolved
# 1. You => President
# 2. their => John
# 3. you => Calisto
# 4. me => Eric
#
# how many are correctly identified? 2
#
# ******** line 236 ********
# 234. Warren:
# Dad, can we talk about this for a second?
#
# 235. Mr. Worthington:
# We've talked about it, son. It'll all be over soon. - Everything's going to be fine.
#
# => 236. Warren:
# => Wait. I can't do this.
#
# 237. Mr. Worthington:
# Warren, calm down.
#
# 238. Warren:
# I can't do this.
#
# ******** evaluate line 236 in x-men_the_last_stand_tw_gapi.csv ********
# 1 pronouns resolved
# 1. I => Warren
#
# how many are correctly identified? 1
#
# ******** line 283 ********
# 281. Jean:
# I don't have to. It's OK. It's OK.
#
# 282. Logan:
# Wait. - No. Jean. - This isn't you.
#
# => 283. Jean:
# => Yes, it is me.
#
# 284. Logan:
# No. Maybe you ought to take it easy. The professor said you might be different.
#
# 285. Phoenix:
# He would know, wouldn't he?
#
# ******** evaluate line 283 in x-men_the_last_stand_tw_gapi.csv ********
# 2 pronouns resolved
# 1. it => Moira
# 2. me => Jean
#
# how many are correctly identified? 1
#
# ******** line 295 ********
# 293. Jean:
# Kill me.
#
# 294. Logan:
# What?
#
# => 295. Jean:
# => Kill me before I kill someone else.
#
# 296. Logan:
# Don't say that.
#
# 297. Jean:
# Please.
#
# ******** evaluate line 295 in x-men_the_last_stand_tw_gapi.csv ********
# 2 pronouns resolved
# 1. me => Jean
# 2. I => Jean
#
# how many are correctly identified? 2
#
# ******** line 246 ********
# 244. Raven:
# Told you so. About time.
#
# 245. Eric:
# I've been busy. Did you find what you were looking for?
#
# => 246. Raven:
# => The source of the cure is a mutant. A child at Worthington Labs. Without him, they have nothing.
#
# 247. Eric:
# Read us the guest list.
#
# 248. John:
# "Cell 41205. James Madrox."
#
# ******** evaluate line 246 in x-men_the_last_stand_tw_gapi.csv ********
# 2 pronouns resolved
# 1. him => Bobby
# 2. they => Cain
#
# how many are correctly identified? 0
#
# ******** line 30 ********
# 28. Bobby:
# Thanks, Kitty.
#
# 29. Storm:
# We're getting killed out here.
#
# => 30. Logan:
# => Yeah, I know. They're not ready, Storm.
#
# 31. Storm:
# Logan.
#
# 32. Logan:
# Oh, don't get your panties in a bunch. That was my last cigar.
#
# ******** evaluate line 30 in x-men_the_last_stand_tw_gapi.csv ********
# 2 pronouns resolved
# 1. I => Logan
# 2. They => Moira
#
# how many are correctly identified? 1
#
# ******** line 67 ********
# 65. Loki:
# You will know peace.
#
# 66. narrator:
# he uses his abilities to control Selvig's mind
#
# => 67. Nick Fury:
# => Yeah, you say peace, I kind of think you mean the other piece.
#
# 68. Clint Barton:
# Sir, Director Fury is stalling. This place is about to blow. Drop a hundred feet of raw material, he means to bury us.
#
# 69. Nick Fury:
# Like The Pharaohs of old.
#
# ******** evaluate line 67 in the_avengers_tw_gapi.csv ********
# 3 pronouns resolved
# 1. you => Clint Barton
# 2. I => Nick Fury
# 3. you => narrator
#
# how many are correctly identified? 1
#
# ******** line 61 ********
# 59. Loki:
# An ant has no quarrel with a boot.
#
# 60. Nick Fury:
# You planning to step on us?
#
# => 61. Loki:
# => I come with glad tidings, of a world made free.
#
# 62. Nick Fury:
# Free from what?
#
# 63. Loki:
# Freedom. Freedom is life's great lie. Once you accept that, in your heart...
#
# ******** evaluate line 61 in the_avengers_tw_gapi.csv ********
# 1 pronouns resolved
# 1. I => Loki
#
# how many are correctly identified? 1
#
# ******** line 209 ********
# 207. narrator:
# Stark in his Iron Man suit is working on getting his energy line to work
#
# 208. Tony Stark:
# You're good to go on this end. The rest is up to you.
#
# => 209. Pepper Potts:
# => You disconnected the transition lines? Are we off the grid?
#
# 210. Tony Stark:
# Stark Towers is about to become a beacon of of self sustaining clean energy.
#
# 211. Pepper Potts:
# Wow, so maybe our reactor takes over and it actually works?
#
# ******** evaluate line 209 in the_avengers_tw_gapi.csv ********
# 2 pronouns resolved
# 1. You => Tony Stark
# 2. we => Thug
#
# how many are correctly identified? 1
#
# ******** line 326 ********
# 324. Clint Barton:
# SHIELD has not shortage of enemies, Doctor. [he holds up a screen showing information in Iridium] Is this the stuff you need?
#
# 325. Selvig:
# Yeah, Iridium. It's found in meteorites, it forms anti-protons. It's very hard to get hold of.
#
# => 326. Clint Barton:
# => Specially if SHIELD knows you need it.
#
# 327. Selvig:
# Well, I didn't know! The Tesseract is showing me so much. It's...it's more than knowledge, it's truth.
#
# 328. Loki:
# I know. What did it show you, Agent Barton?
#
# ******** evaluate line 326 in the_avengers_tw_gapi.csv ********
# 2 pronouns resolved
# 1. you => Selvig
# 2. it => Natasha Romanoff
#
# how many are correctly identified? 1
#
# ******** line 160 ********
# 158. Natasha Romanoff:
# No one's gonna put you in a...
#
# 159. narrator:
# suddenly Banner gets angry and snaps
#
# => 160. Bruce Banner:
# => Stop lying to me!
#
# 161. narrator:
# Natasha quickly grab her gun and points it at Banner
#
# 162. Bruce Banner:
# I'm sorry, that was mean. I just wanted to see what you'd do. Why don't we do this the easy way, where you don't use that, and the other guy doesn't make a mess? Okay?
#
# ******** evaluate line 160 in the_avengers_tw_gapi.csv ********
# 1 pronouns resolved
# 1. me => Bruce Banner
#
# how many are correctly identified? 1
#
# ******** line 84 ********
# 82. narrator:
# Hill gets into a truck and follows after Barton's truck
#
# 83. narrator:
# after the research facility has collapsed, Fury and Hill try to chase after Loki but fail to catch him escaping with the briefcase containing the Tesseract; talking through their walkie talkie's
#
# => 84. Agent Phil Coulson:
# => Director? Director Fury, do you copy?
#
# 85. Nick Fury:
# The Tesseract is with the hostile force. I have men down. Hill?
#
# 86. Agent Maria Hill:
# A lot of men still under, don't know how many survivors.
#
# ******** evaluate line 84 in the_avengers_tw_gapi.csv ********
# 1 pronouns resolved
# 1. you => narrator
#
# how many are correctly identified? 0
#
# ******** line 248 ********
# 246. Tony Stark:
# You have reached the life model decoy of Tony Stark, please leave a message.
#
# 247. Agent Phil Coulson:
# This is urgent.
#
# => 248. Tony Stark:
# => Then leave it urgently. [at that moment the elevator door opens and Coulson appears] Security breach. [to Pepper] That's on you.
#
# 249. Agent Phil Coulson:
# Mr. Stark.
#
# 250. Pepper Potts:
# Phil! Come in.
#
# ******** evaluate line 248 in the_avengers_tw_gapi.csv ********
# 2 pronouns resolved
# 1. it => Nick Fury
# 2. you => Agent Phil Coulson
#
# how many are correctly identified? 0
#
# ******** line 25 ********
# 23. Nick Fury:
# Talk to me, doctor.
#
# 24. Selvig:
# Director.
#
# => 25. Nick Fury:
# => Is there anything we know for certain?
#
# 26. Selvig:
# The Tesseract is misbehaving.
#
# 27. Nick Fury:
# Is that supposed to be funny?
#
# ******** evaluate line 25 in the_avengers_tw_gapi.csv ********
# 1 pronouns resolved
# 1. we => Thug
#
# how many are correctly identified? 0
#
# ******** line 95 ********
# 93. Luchkov:
# This is not how I wanted this night to go.
#
# 94. Natasha Romanoff:
# I know how you wanted this night to go. Believe me, this is better.
#
# => 95. Luchkov:
# => Who are you working for? Lermentov, yes? Does he really think that we'll have to go through him to move our tanks?
#
# 96. Natasha Romanoff:
# I thought General Solohob was in charge of the cargo?
#
# 97. Luchkov:
# Solohob? A bagman. A front.
#
# ******** evaluate line 95 in the_avengers_tw_gapi.csv ********
# 6 pronouns resolved
# 1. Who => Pepper Potts
# 2. you => Natasha Romanoff
# 3. he => NASA Scientist
# 4. we => Loki
# 5. him => narrator
# 6. our => World Security Council #1
#
# how many are correctly identified? 1
#
# ******** line 197 ********
# 195. narrator:
# Fury gives Steve the file on Tesseract to look at
#
# 196. Steve Rogers:
# Hydra's secret weapon.
#
# => 197. Nick Fury:
# => Howard Stark fished that out of the ocean when he was looking for you. He thought what we think, the Tesseract could be the key to unlimited sustainable energy. That's something the world sorely needs.
#
# 198. Steve Rogers:
# Who took it from you?
#
# 199. Nick Fury:
# He's called Loki. He's not from around here. There's a lot we'll have to bring you up to speed on if you're in. The world has gotten even stranger than you already know.
#
# ******** evaluate line 197 in the_avengers_tw_gapi.csv ********
# 5 pronouns resolved
# 1. he => Steve Rogers
# 2. you => Steve Rogers
# 3. He => Clint Barton
# 4. what => Luchkov
# 5. we => Bruce Banner
#
# how many are correctly identified? 1
#
# ******** line 271 ********
# 269. Pepper Potts:
# I was having twelve percent of a moment. This seems serious, Phil's pretty shaken.
#
# 270. Tony Stark:
# How did you notice? Why is he Phil? [referring to the file Coulson had given to Stark]
#
# => 271. Pepper Potts:
# => What is all this?
#
# 272. Tony Stark:
# This is uh... [with a flick of his hand he spreads all the profiles of the other Avengers on to the different computer screens] This. [Pepper looks at all their profiles in awe]
#
# 273. Pepper Potts:
# I'm going to take the jet to D.C. tonight.
#
# ******** evaluate line 271 in the_avengers_tw_gapi.csv ********
# 1 pronouns resolved
# 1. What => Nick Fury
#
# how many are correctly identified? 0
#
# ******** line 285 ********
# 283. Agent Phil Coulson:
# A lot of people were. You were the world's first superhero. Banner thought gammer radiation might hold the key to unlocking Erskine's original formula.
#
# 284. Steve Rogers:
# Didn't really go his way, did it?
#
# => 285. Agent Phil Coulson:
# => Not so much. When he's got that thing though, guy's like a Stephen Hawking. [Steve looks at Coulson in confusion] He's like a smart person. I gotta say, it's an honor to meet you, officially. I sort of met you, I mean, I watched you while you were sleeping. [Steve looks at Coulson in amusement] I mean, I was...I was present while you were unconscious from the ice. You know, it's really, it's just a...just a huge honor to have you on board.
#
# 286. Steve Rogers:
# Well, I hope I'm the man for the job.
#
# 287. Agent Phil Coulson:
# Oh, you are. Absolutely. Uh...we've made some modifications to the uniform. I had a little design input.
#
# ******** evaluate line 285 in the_avengers_tw_gapi.csv ********
# 19 pronouns resolved
# 1. he => Agent Jasper Sitwell
# 2. He => Tony Stark
# 3. I => Agent Phil Coulson
# 4. it => World Security Council #1
# 5. you => Steve Rogers
# 6. I => Agent Phil Coulson
# 7. you => Steve Rogers
# 8. I => Agent Phil Coulson
# 9. I => Agent Phil Coulson
# 10. you => Steve Rogers
# 11. you => Steve Rogers
# 12. I => Agent Phil Coulson
# ...
# 3 pronouns resolved
# 1. I => Natasha Romanoff
# 2. you => Luchkov
# 3. me => Natasha Romanoff
#
# how many are correctly identified? 3
#
# ******** line 342 ********
# 340. Raven:
# Maybe in Westchester. Out there, mutants are still running, hiding, living in fear. Just because there's not a war doesn't mean there's peace. If you want to teach your kids something, teach them that. Teach them to fight. Otherwise, they might as well live in this house for the rest of their lives.
#
# 341. Charles:
# You still sound just like him. You sound just like Erik.
#
# => 342. Raven:
# => That's why I'm here. He's resurfaced. He had a wife and a daughter. They were killed. Along with a handful of policemen. The whole world will be looking for him. But you can help me find him before they do.
#
# 343. Charles:
# Moira, I'm going to have to ask you to keep this a secret.
#
# 344. Moira:
# I don't even know what this... is.
#
# ******** evaluate line 342 in x-men_apocalypse_tw_gapi.csv ********
# 9 pronouns resolved
# 1. I => Raven
# 2. He => Woman
# 3. He => Worker
# 4. They => Alex
# 5. him => Director
# 6. you => Charles
# 7. me => Raven
# 8. him => Computer
# 9. they => Black Official
#
# how many are correctly identified? 3
#
# ******** line 420 ********
# 418. Solider:
# X-Ray 7, I'm doing a final sweep on the ground. Alright, you! Are you clear? Clear!
#
# 419. Solider:
#  Pack them up. Let's go. Come on, let's move!
#
# => 420. Scott:
# =>  Thanks, Jean. We got to help them. - Kurt, can you get us in that thing?
#
# 421. Kurt:
#  - You want to get in there? What if the soldiers see us?
#
# 422. Jean:
#  Don't worry. They won't see us, trust me.
#
# ******** evaluate line 420 in x-men_apocalypse_tw_gapi.csv ********
# 4 pronouns resolved
# 1. We => EriK
# 2. them => Nightcrawler
# 3. you => Kurt
# 4. us => Magda
#
# how many are correctly identified? 1
#
# ******** line 194 ********
# 192. Reporter:
# Never before has man possess so much power. With Soviet Union and the United States being superpowers...
#
# 193. Apocalypse:
# Superpowers? The weak have taken the Earth. For this, I was betrayed. False gods. Idols. No more. I have returned. The new tomorrow, that starts today.
#
# => 194. Storm:
# => Where did you come from?
#
# 195. Apocalypse:
# The time before man lost his way.
#
# 196. Storm:
# Well. Welcome to the 80s.
#
# ******** evaluate line 194 in x-men_apocalypse_tw_gapi.csv ********
# 1 pronouns resolved
# 1. you => Apocalypse
#
# how many are correctly identified? 1
#
# ******** line 88 ********
# 86. Charles:
# Nope. It was just a dream. -
#
# 87. Jean:
# But, it felt real. -
#
# => 88. Charles:
# => I know. Your mind is the most powerful I've ever seen. - It can convince itself... -
#
# 89. Jean:
# No, it's not just a mind reading or a telekinesis, it's something else. Some... dark power inside and it's growing, like a fire. - I thought I was getting better. -
#
# 90. Charles:
# You are. You will. - You just have to be patient. -
#
# ******** evaluate line 88 in x-men_apocalypse_tw_gapi.csv ********
# 5 pronouns resolved
# 1. I => Charles
# 2. Your => Jean
# 3. I => Charles
# 4. It => Egyptian Guard
# 5. itself => Magda
#
# how many are correctly identified? 3
#
# ******** line 421 ********
# 419. Solider:
#  Pack them up. Let's go. Come on, let's move!
#
# 420. Scott:
#  Thanks, Jean. We got to help them. - Kurt, can you get us in that thing?
#
# => 421. Kurt:
# =>  - You want to get in there? What if the soldiers see us?
#
# 422. Jean:
#  Don't worry. They won't see us, trust me.
#
# 423. Kurt:
#  Hold on.
#
# ******** evaluate line 421 in x-men_apocalypse_tw_gapi.csv ********
# 3 pronouns resolved
# 1. You => Scott
# 2. What => Jubilee
# 3. us => Kurt
#
# how many are correctly identified? 2
#
# ******** line 44 ********
# 42. Erik:
# Never.
#
# 43. Alex:
# I guess we're more alike than we thought.
#
# => 44. Woman:
# => He won't listen to us. He just... He's been...
#
# 45. Alex:
# Scott. Let me try. XAVIER'S SCHOOL FOR GIFTED YOUNGSTERS
#
# 46. Scott:
# Smells pretty old in here. Is this a school or museum.
#
# ******** evaluate line 44 in x-men_apocalypse_tw_gapi.csv ********
# 4 pronouns resolved
# 1. He => Peter
# 2. us => Reporter
# 3. He => Merchant
# 4. He => Peter
#
# how many are correctly identified? 0
#
# ******** line 140 ********
# 138. Police Officer:
# What's happening? She is one of them.
#
# 139. Nina:
# Please.
#
# => 140. Police Officer:
# => Make her stop.
#
# 141. Erik:
# She can't control them.
#
# 142. Magda:
# Nina.
#
# ******** evaluate line 140 in x-men_apocalypse_tw_gapi.csv ********
# 1 pronouns resolved
# 1. her => Alex
#
# how many are correctly identified? 0
#
# ******** line 424 ********
# 422. Jean:
#  Don't worry. They won't see us, trust me.
#
# 423. Kurt:
#  Hold on.
#
# => 424. Scott:
# =>  Kurt, get us all out of here! I can't! When they closed the doors, there's some kind of electric field. - It's like Berlin all over. Scott: - Jean, get into the pilots heads. - Don't let them take off! Jean: - I can't. I can't reach the pilots. I can't reach anyone. News reporter: We're also getting reports from Europe and Asia. This was not just the US phenomenon. It seems the entire world has been disarmed of nuclear weapons. The Pentagon has confirmed multiple launches from Russia, as well as the UK, Israel and China. Student 8: - Look! - Up there. News reporter: So far, there has been no response from the White House. Eye witness accounts have been pouring in from across the globe. Authorities are not sure if it was an act of peace or an act of war. Kurt: Dear Father. Hold me in the light of God. Scott: It should have been me. He was the one who's going to do something with his life. He was always the one. Jean: That's not how he felt. He felt you were the one who's going to do something special with your life. That you're going to make a difference in the world. Maybe even change it. Scott: How did you know what he felt? I know what everybody feels. Kurt: Hold me in the light of God. Protect me from danger. Save me by your command. Listen to my prayer. And keep me safe.
#
# 425. Charles:
#  You're blocking me. How? Apocalypse: I can shield their minds from your power. It's one of the many gifts I have acquired through out the millennia. But to... see... inside a mind. To control it. That's your gift. You saw it, didn't you? The glory of what's to come. Charles: Are you going to take part in all this killing? Destruction?
#
# 426. Erik:
#  - It's all I ever known. Charles - No, it isn't. - You've just forgotten.
#
# ******** evaluate line 424 in x-men_apocalypse_tw_gapi.csv ********
# 36 pronouns resolved
# 1. us => Dude
# 2. I => Scott
# 3. they => Scott
# 4. It => Police Officer
# 5. them => Teacher
# 6. I => Scott
# 7. I => Scott
# 8. I => Scott
# 9. We => Student 1
# 10. It => Student 3
# 11. it => Student 2
# 12. me => Scott
# 13. It => Kurt
# 14. me => Scott
# 15. He => Student 2
# 16. who => Police Officer
# 17. his => Police Officer
# 18. He => TV
# 19. he => Scott
# 20. He => Government Official
# 21. you => Charles
# 22. who => Director
# 23. your => Charles
# 24. you => Kurt
# 25. it => Student 6
# 26. you => Charles
# 27. what => Storm
# 28. he => Woman
# 29. I => Scott
# 30. what => Student 3
# 31. me => Scott
# 32. me => Scott
# 33. me => Scott
# 34. your => Charles
# 35. my => Scott
# 36. me => Scott
#
# how many are correctly identified? 12
#
# ******** line 23 ********
# 21. Bodyguard:
# Hey. You lost, little girl? The fight is there.
#
# 22. Angel:
# Fight! Or they'll kill us both.
#
# => 23. Bodyguard:
# => It's getting exciting.
#
# 24. Raven:
# Ah, you mean this. Yeah?
#
# 25. Crowd:
# Nightcrawler! - Nightcrawler! - Nightcrawler!
#
# ******** evaluate line 23 in x-men_apocalypse_tw_gapi.csv ********
# 1 pronouns resolved
# 1. It => Death
#
# how many are correctly identified? 0
#
# ******** line 169 ********
# 167. Moira:
# I had a husband, but... It's hard to do this job and make it home in time for dinner.
#
# 168. Charles:
# Good. Good. We all make choices, right?
#
# => 169. Moira:
# => Yes, we do. - Professor. - Yes?
#
# 170. Charles:
# Yes. I was... we were hoping that you would tell us about what happened yesterday in Egypt.
#
# 171. Moira:
# I'm afraid that's classified information. And, I don't mean to be rude, but... How did you get in here?
#
# ******** evaluate line 169 in x-men_apocalypse_tw_gapi.csv ********
# 1 pronouns resolved
# 1. we => Angel
#
# how many are correctly identified? 0
#
# ******** line 305 ********
# 303. Peter:
# What's up?
#
# 304. Peter's Mom:
# I'm just checking on you.
#
# => 305. Peter:
# => I'm good, playing Pac-Man.
#
# 306. Peter's Mom:
# Are you sure you weren't watching this?
#
# 307. Reporter:
# The world was celebrating 10 years of peace between mutants and mankind.
#
# ******** evaluate line 305 in x-men_apocalypse_tw_gapi.csv ********
# 1 pronouns resolved
# 1. I => Peter
#
# how many are correctly identified? 1
#
# ******** line 334 ********
# 332. Raven:
# No, it was your home. I just lived here. I barely even recognize it now.
#
# 333. Charles:
# Yeah, I have plans for this place. I mean to turn it into a real campus. A university. Not just for mutants, even for humans too. Living and working, ... growing together.
#
# => 334. Raven:
# => You know, I really believed that once. I really believed we can change them after DC.
#
# 335. Charles:
# We did.
#
# 336. Raven:
# No Charles. They still hate and fear us. It's just harder to see because they're more polite about it. I got sick of living that lie.
#
# ******** evaluate line 334 in x-men_apocalypse_tw_gapi.csv ********
# 5 pronouns resolved
# 1. You => Charles
# 2. I => Raven
# 3. I => Raven
# 4. we => Horsemen of Apocalypse
# 5. them => Jacob
#
# how many are correctly identified? 3
#
# ******** line 152 ********
# 150. Apocalypse:
# Enough.
#
# 151. Merchant:
# If you are with her, I suggest you go away. Go away.
#
# => 152. Apocalypse:
# => Who rules this world?
#
# 153. Merchant:
# What language is that? Clown! What do you want? Go away! Sorry. Sorry.
#
# 154. Apocalypse:
# You feel it, don't you? Now, you feel it. CENTRAL INTELLIGENCE AGENCY UNITED STATES OF AMERICA
#
# ******** evaluate line 152 in x-men_apocalypse_tw_gapi.csv ********
# 1 pronouns resolved
# 1. Who => EriK
#
# how many are correctly identified? 0
#
# ******** line 1 ********
# 0. Charles:
# Mutants, born with extraordinary abilities, and yet still, they are children, stumbling in the dark, searching for guidance. A gift can often be a curse. Give someone wings, and they may fly too close to the sun. Give them the power of prophecy, and they may live in fear of the future. Give them the greatest gift of all, powers beyond imagination, and they may think they are meant to rule the world.
#
# => 1. Death:
# => Soon, you will rule forever, My Lord.
#
# 2. Egyptian Guard:
# DEATH TO THE FALSE GOD!
#
# 3. Horsemen of Apocalypse:
# Watch over him!
#
# ******** evaluate line 1 in x-men_apocalypse_tw_gapi.csv ********
# 2 pronouns resolved
# 1. you => Egyptian Guard
# 2. My => Death
#
# how many are correctly identified? 0
#
# ******** line 264 ********
# 262. Psylocke:
# I know the kind of mutants you are looking for. And I know where to find them.
#
# 263. Kurt:
# It's my first time in America. I am very excited to see your culture.
#
# => 264. Jubilee:
# => Well, you are not going to see it here. The only thing American about this place is that it used to be British. This is Scott. He is new here too.
#
# 265. Scott:
# And I'm already up for a prison break. What do you say we take this blue guy on a little field trip? I'm sure there's a mall around here somewhere.
#
# 266. Kurt:
# What's a mall?
#
# ******** evaluate line 264 in x-men_apocalypse_tw_gapi.csv ********
# 4 pronouns resolved
# 1. you => Kurt
# 2. it => Death
# 3. it => Warren
# 4. He => Storm
#
# how many are correctly identified? 1
#
# ******** line 90 ********
# 88. Charles:
# I know. Your mind is the most powerful I've ever seen. - It can convince itself... -
#
# 89. Jean:
# No, it's not just a mind reading or a telekinesis, it's something else. Some... dark power inside and it's growing, like a fire. - I thought I was getting better. -
#
# => 90. Charles:
# => You are. You will. - You just have to be patient. -
#
# 91. Jean:
# No. No. You don't know what it's like to be afraid to shut your eyes. - To be trapped inside your own head. -
#
# 92. Charles:
# Oh, but I think I do. It wasn't so long ago, that I was plagued by voices of myself. All their suffering. All their pain. Their secrets.
#
# ******** evaluate line 90 in x-men_apocalypse_tw_gapi.csv ********
# 3 pronouns resolved
# 1. You => Jean
# 2. You => Jean
# 3. You => Jean
#
# how many are correctly identified? 3
#
# ******** line 360 ********
# 358. Charles:
# Hank. He's not alone.
#
# 359. Apocalypse:
# Extraordinary.
#
# => 360. Warren:
# => What do you see?
#
# 361. Apocalypse:
# The answer.
#
# 362. Charles:
# Oh my god.
#
# ******** evaluate line 360 in x-men_apocalypse_tw_gapi.csv ********
# 2 pronouns resolved
# 1. What => Scott
# 2. you => Apocalypse
#
# how many are correctly identified? 1
#
# ******** line 59 ********
# 57. Jean:
# No, you didn't.
#
# 58. Hank:
# Alex Summers?
#
# => 59. Alex:
# => Hank McCoy! Whoa. What happen to the big blue... furry you?
#
# 60. Hank:
# I, keep it under control now.
#
# 61. Alex:
# This is my brother, Scott.
#
# ******** evaluate line 59 in x-men_apocalypse_tw_gapi.csv ********
# 2 pronouns resolved
# 1. What => Warren
# 2. you => Hank
#
# how many are correctly identified? 1
#
# ******** line 151 ********
# 149. Merchant:
# You know what we do with thieves? Choose a hand.
#
# 150. Apocalypse:
# Enough.
#
# => 151. Merchant:
# => If you are with her, I suggest you go away. Go away.
#
# 152. Apocalypse:
# Who rules this world?
#
# 153. Merchant:
# What language is that? Clown! What do you want? Go away! Sorry. Sorry.
#
# ******** evaluate line 151 in x-men_apocalypse_tw_gapi.csv ********
# 4 pronouns resolved
# 1. you => Apocalypse
# 2. her => Moira
# 3. I => Merchant
# 4. you => Apocalypse
#
# how many are correctly identified? 3
#
# ******** line 445 ********
# 443. Apocalypse:
#  Useless. Apocalypse: Charles. I know you can hear me. We're still connected. Charles! Show yourself! CHARLES! SHOW YOURSELF! Apocalypse: Foolish child.
#
# 444. Charles:
# Peter. Apocalypse: End him. Charles: Raven. Apocayplse: The great hero. Hank: - I'm going out there. Scott: - I'm going with you. Charles: No. - It's me he wants. Moria: - Charles, you can't give yourself up. If he has you, he has us all. The whole world. Apocalypse: You are feeble. Just like the others. Charles! Come! Rescue your weakling! Give your life, for their's! Charles: No. He was right. There is still some part of me connected to him.
#
# => 445. Apocalypse:
# =>  Charles! Charles: I can get inside his head. Apocalypse: Will you do nothing? Charles: Thank you for letting me in. You want what I have? You want to feel what I feel? Welcome to my world! You're in my house now! Apocalypse: You'll need a bigger house. You betray me? Erik: No. I betrayed them.
#
# 446. Hank:
# Let's jump. Scott: What? Hank: Cover me. I got you. Peter: Come on! Apocalypse: They lack strength, Charles. Charles:Jean. Apocalypse: Come here. Charles: Help... Me. Hank: Stay here. Moira: They can't stop him. Charles: Jean. Help me! Scott: Hank! Hank! Apocalypse: It's over, Charles. You're finished. You're mine now. Charles: You will never win. Apocalypse: And why is that? Charles: Because you are alone. And I am not! Let ... go. Unleash your power, Jean. No fear. Unleash your power! Let go, Jean! Jean, let go! Hank: He's getting away. Apocalypse: All is revealed. Moira: Charles! Charles! - We've lost him! Hank: - Charles. Moira: - He's gone. Hank: - No, Charles. Charles... Jean: No, he's not. I can still feel him. Charles: Thank you, Jean. Moira: Charles? Charles, do you know where you are? Charles: I'm on a beach. In Cuba. With you. Moira: What beach?
#
# ******** evaluate line 445 in x-men_apocalypse_tw_gapi.csv ********
# 19 pronouns resolved
# 1. I => Apocalypse
# 2. his => Announcer
# 3. you => Charles
# 4. you => Charles
# 5. me => Apocalypse
# 6. You => Hank
# 7. what => Some Dude
# 8. I => Apocalypse
# 9. You => Charles
# 10. what => Announcer
# 11. I => Apocalypse
# 12. my => Apocalypse
# 13. You => Hank
# 14. my => Apocalypse
# 15. You => Hank
# 16. You => Hank
# 17. me => Apocalypse
# 18. I => Apocalypse
# 19. them => Student 4
#
# how many are correctly identified? 2
#
# ******** test results ********
# script 1: precision = 0.42 (30/71 correct)
# script 2: precision = 0.39 (31/79 correct)
# script 3: precision = 0.43 (23/53 correct)
# script 4: precision = 0.49 (33/67 correct)
# script 5: precision = 0.34 (37/108 correct)
# overall: precision = 0.41 (154/378 correct)

# %%
# write dfs with pronoun references added
for fileName in files:
    df = loadScript(f)
    df = annotateScript(df)
    df.apply(lambda x: pronResolution_nn(charList, x), axis=1)
    df.to_csv(fileName[:-4] + '_prons.csv')

# %% [markdown]
# Model 2 (pronResolution_nnMod): sets reference for first-person pronouns to speaker; for second-person pronouns to random choice between previous and next speaker

# %%
# copy scripts
scripts2 = scripts.copy()

# apply model to all scripts
for i in fileIndex:
    charList = scripts2[i]['chars'].keys()  
    scripts2[i]['df'].apply(lambda x: pronResolution_nnMod(charList, x), axis=1)
    
# manually evaluate results for all scripts
pronEval(scripts2)
# Out:
# -------------------------------------------------------------
# KeyboardInterrupt           Traceback (most recent call last)
# <ipython-input-33-405f3e1c919b> in <module>()
#       5 for i in fileIndex:
#       6     charList = scripts2[i]['chars'].keys()
# ----> 7     scripts2[i]['df'].apply(lambda x: pronResolution_nnMod(charList, x), axis=1)
#       8
#       9 # manually evaluate results for all scripts
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4150                     if reduce is None:
#    4151                         reduce = True
# -> 4152                     return self._apply_standard(f, axis, reduce=reduce)
#    4153             else:
#    4154                 return self._apply_broadcast(f, axis)
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4206                     labels = self._get_agg_axis(axis)
#    4207                     result = lib.reduce(values, func, axis=axis, dummy=dummy,
# -> 4208                                         labels=labels)
#    4209                     return Series(result, index=labels)
#    4210                 except Exception:
#
# pandas/src/reduce.pyx in pandas.lib.reduce (pandas/lib.c:45030)()
#
# pandas/src/reduce.pyx in pandas.lib.Reducer.get_result (pandas/lib.c:34673)()
#
# <ipython-input-33-405f3e1c919b> in <lambda>(x)
#       5 for i in fileIndex:
#       6     charList = scripts2[i]['chars'].keys()
# ----> 7     scripts2[i]['df'].apply(lambda x: pronResolution_nnMod(charList, x), axis=1)
#       8
#       9 # manually evaluate results for all scripts
#
# /Users/winlin/Desktop/w266-nlp/w266_project/pronounResolution.py in pronResolution_nnMod(charList, row)
#     134                         break
#     135                     else:
# --> 136                         row['entities'].append({'mention':token['char'][0], 'type':'PERSON', 'name':token['char'][0]})
#     137
#     138             # else, add random character name to token
#
# /anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     604
#     605             if not is_scalar(result):
# --> 606                 if is_list_like(result) and not isinstance(result, Series):
#     607
#     608                     # we need to box if we have a non-unique index here
#
# /anaconda/lib/python2.7/site-packages/pandas/types/inference.pyc in is_list_like(arg)
#      53 def is_list_like(arg):
#      54     return (hasattr(arg, '__iter__') and
# ---> 55             not isinstance(arg, string_and_binary_types))
#      56
#      57
#
# KeyboardInterrupt:

# %% [markdown]
# ## Task 2: Relation Extraction

# %%
df['relations'] = df.tokens.apply(lambda x:simpleRE(x))

# %%
df[df.relations.notnull()].head().relations.values[1]

# %%
df.head().tokens.apply(lambda x:simpleRE(x))
