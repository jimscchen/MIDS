# %% [markdown]
# ## Table of Contents <a class="anchor" id="top"></a>
# * [Data Preparation](#Data Prep)
# * [Entity Resolution](#Entity)
# * [Relation Extraction](#Relation)
# * [Query System](#Query)

# %% [markdown]
# ## [Data Prep](#top)  <a class="anchor" id="Data Prep"></a>

# %%
# %load_ext autoreload
# %autoreload 2

#standard library imports
import re
import nltk
import numpy as np
import pandas as pd
import os

#modeling functions & utilities
from pronounResolution import pronResolution_base, pronResolution_nnMod, pronResolution_nn, pronEval
from relationExtract import simpleRE, REEval, getRelations, extract_relation_categories
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
files = [x for x in os.listdir('prep_scripts') if '_gapi' in x]
df_dict = {}
for i, f in enumerate(files):
    if str(f) in 'thor_tw_gapi.csv':
        continue
    print f
    df_dict["df_{0}".format(i)] = pd.read_csv('prep_scripts/' + f)[['speaker', 'dialogue', 'sentences', 
                                                                    'sentiment', 'entities', 'tokens']]
    df_dict["df_{0}".format(i)]['tokens'] = df_dict["df_{0}".format(i)]['tokens'].apply(lambda x: eval(x.encode('utf-8')))
    df_dict["df_{0}".format(i)]['sentiment'] = df_dict["df_{0}".format(i)]['sentiment'].apply(lambda x: eval(x.encode('utf-8')))
    df_dict["df_{0}".format(i)]['entities'] = df_dict["df_{0}".format(i)]['entities'].apply(lambda x: eval(x.encode('utf-8')))
    
    cList = list(df_dict["df_{0}".format(i)].speaker.unique())
    df_dict["df_{0}".format(i)]['total_sent'] = df_dict["df_{0}".format(i)]['sentiment'].apply(lambda x: x['score'] * x['magnitude'])
    cDict = dict(df_dict["df_{0}".format(i)].groupby('speaker').total_sent.sum())

    # number of pronouns for each line
    df_dict["df_{0}".format(i)]['num_pron'] = df_dict["df_{0}".format(i)]['tokens'].apply(lambda x: sum([int(t['pos'] == 'PRON') for t in x]))

    # total sentiment score for each line
    df_dict["df_{0}".format(i)]['total_sent'] = df_dict["df_{0}".format(i)]['sentiment'].apply(lambda x: x['score'] * x['magnitude'])

    #set nearby speakers
    charRange = 10
    nearbyList = np.dstack((df_dict["df_{0}".format(i)].shift(j).speaker.values for j in range(-charRange, charRange+1)))[0]
    df_dict["df_{0}".format(i)]['nearbyChars'] = None
    for j, nearbyChars in enumerate(nearbyList):
        df_dict["df_{0}".format(i)].set_value(j, 'nearbyChars', nearbyChars)
# Out:
# ant-man_tw_gapi.csv
# avengers_age_of_ultron_tw_gapi.csv
# captain_america_civil_war_tw_gapi.csv
# captain_america_the_first_avenger_tw_gapi.csv
# captain_america_the_winter_soldier_tw_gapi.csv
# fantastic_four_imsdb_gapi.csv
# iron_man_3_tw_gapi.csv
# lego_marvel_super_heroes_tw_gapi.csv
# spider-man_imsdb_gapi.csv
# the_amazing_spider-man_2_tw_gapi.csv
# the_amazing_spider-man_tw_gapi.csv
# the_avengers_tw_gapi.csv
# the_wolverine_tw_gapi.csv
# thor_the_dark_world_tw_gapi.csv
# x-men_apocalypse_tw_gapi.csv
# x-men_days_of_future_past_tw_gapi.csv
# x-men_imsdb_gapi.csv
# x-men_the_last_stand_tw_gapi.csv

# %%
# Out:
# ant-man_tw_gapi.csv
#             speaker                                           dialogue  \
# 0          narrator           1989 – Hank Pym enters a SHIELD facility
# 1      Dr. Hank Pym                                             Stark.
# 2   Mitchell Carson                             He doesn't seem happy.
# 3      Howard Stark      Hello, Hank. You're supposed to be in Moscow.
# 4      Dr. Hank Pym  I took a detour.[he places a vial containing a...
# 5      Peggy Carter             Tell me that isn't what I think it is.
# 6      Dr. Hank Pym  It depends, if you think it's a poor attempt t...
# 7   Mitchell Carson  You were instructed to go to Russia. May I rem...
# 8      Dr. Hank Pym                                   I'm a scientist.
# 9      Howard Stark  Then act like one. The Pym Particle is the mos...
# 10     Dr. Hank Pym  First you turn me into your errand boy, and no...
# 11  Mitchell Carson  If only you'd protected Janet with such feroci...
# 12     Dr. Hank Pym  Ah. [suddenly Pym slams down Carson's face on ...
# 13     Peggy Carter                                        Easy, Hank!
# 14     Dr. Hank Pym  You mention my wife again and I'll show you fe...
# 15     Howard Stark                     Don't look at me, you said it.
# 16     Dr. Hank Pym                  I formally tender my resignation.
# 17     Howard Stark  We don't accept it. Formally. Hank, we need yo...
# 18     Dr. Hank Pym  As long as I am alive, nobody will ever get th...
# 19  Mitchell Carson           We shouldn't let him leave the building.
#
#                                             sentences  \
# 0   [{'content': u'1989 \u2013 Hank Pym enters a S...
# 1   [{'content': u'Stark.', 'begin': 0, 'score': 0...
# 2   [{'content': u"He doesn't seem happy.", 'begin...
# 3   [{'content': u'Hello, Hank.', 'begin': 0, 'sco...
# 4   [{'content': u'I took a detour.[he places a vi...
# 5   [{'content': u"Tell me that isn't what I think...
# 6   [{'content': u"It depends, if you think it's a...
# 7   [{'content': u'You were instructed to go to Ru...
# 8   [{'content': u"I'm a scientist.", 'begin': 0, ...
# 9   [{'content': u'Then act like one.', 'begin': 0...
# 10  [{'content': u'First you turn me into your err...
# 11  [{'content': u"If only you'd protected Janet w...
# 12  [{'content': u"Ah. [suddenly Pym slams down Ca...
# 13  [{'content': u'Easy, Hank!', 'begin': 0, 'scor...
# 14  [{'content': u"You mention my wife again and I...
# 15  [{'content': u"Don't look at me, you said it."...
# 16  [{'content': u'I formally tender my resignatio...
# 17  [{'content': u"We don't accept it.", 'begin': ...
# 18  [{'content': u'As long as I am alive, nobody w...
# 19  [{'content': u"We shouldn't let him leave the ...
#
#                               sentiment  \
# 0    {u'score': 0.3, u'magnitude': 0.3}
# 1    {u'score': 0.1, u'magnitude': 0.1}
# 2   {u'score': -0.6, u'magnitude': 0.6}
# 3     {u'score': -0.1, u'magnitude': 1}
# 4    {u'score': 0.4, u'magnitude': 0.4}
# 5   {u'score': -0.6, u'magnitude': 0.6}
# 6     {u'score': -0.5, u'magnitude': 1}
# 7      {u'score': 0, u'magnitude': 0.7}
# 8    {u'score': 0.3, u'magnitude': 0.3}
# 9    {u'score': 0.1, u'magnitude': 1.2}
# 10       {u'score': 0, u'magnitude': 0}
# 11   {u'score': 0.3, u'magnitude': 0.3}
# 12  {u'score': -0.5, u'magnitude': 0.5}
# 13   {u'score': 0.7, u'magnitude': 0.7}
# 14   {u'score': 0.1, u'magnitude': 0.2}
# 15  {u'score': -0.5, u'magnitude': 0.5}
# 16   {u'score': 0.5, u'magnitude': 0.5}
# 17   {u'score': 0.1, u'magnitude': 1.9}
# 18  {u'score': -0.1, u'magnitude': 0.4}
# 19  {u'score': -0.2, u'magnitude': 0.2}
#
#                                              entities  \
# 0   [{u'type': u'PERSON', u'meta': {}, u'salience'...
# 1   [{u'type': u'WORK_OF_ART', u'meta': {}, u'sali...
# 2                                                  []
# 3   [{u'type': u'PERSON', u'meta': {}, u'salience'...
# 4   [{u'type': u'OTHER', u'meta': {}, u'salience':...
# 5                                                  []
# 6   [{u'type': u'OTHER', u'meta': {}, u'salience':...
# 7   [{u'type': u'PERSON', u'meta': {}, u'salience'...
# 8   [{u'type': u'PERSON', u'meta': {}, u'salience'...
# 9   [{u'type': u'OTHER', u'meta': {}, u'salience':...
# 10  [{u'type': u'PERSON', u'meta': {}, u'salience'...
# 11  [{u'type': u'PERSON', u'meta': {u'mid': u'/m/0...
# 12  [{u'type': u'PERSON', u'meta': {u'mid': u'/m/0...
# 13  [{u'type': u'PERSON', u'meta': {}, u'salience'...
# 14  [{u'type': u'PERSON', u'meta': {}, u'salience'...
# 15                                                 []
# 16  [{u'type': u'OTHER', u'meta': {}, u'salience':...
# 17  [{u'type': u'CONSUMER_GOOD', u'meta': {}, u'sa...
# 18  [{u'type': u'PERSON', u'meta': {}, u'salience'...
# 19  [{u'type': u'LOCATION', u'meta': {}, u'salienc...
#
#                                                tokens
# 0   [{u'index': 0, u'begin': 0, u'pos': u'NUM', u'...
# 1   [{u'index': 0, u'begin': 0, u'pos': u'NOUN', u...
# 2   [{u'index': 3, u'begin': 0, u'pos': u'PRON', u...
# 3   [{u'index': 2, u'begin': 0, u'pos': u'X', u'la...
# 4   [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...
# 5   [{u'index': 0, u'begin': 0, u'pos': u'VERB', u...
# 6   [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...
# 7   [{u'index': 2, u'begin': 0, u'pos': u'PRON', u...
# 8   [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...
# 9   [{u'index': 1, u'begin': 0, u'pos': u'ADV', u'...
# 10  [{u'index': 2, u'begin': 0, u'pos': u'ADV', u'...
# 11  [{u'index': 4, u'begin': 0, u'pos': u'ADP', u'...
# 12  [{u'index': 0, u'begin': 0, u'pos': u'NOUN', u...
# 13  [{u'index': 0, u'begin': 0, u'pos': u'NOUN', u...
# 14  [{u'index': 1, u'begin': 0, u'pos': u'PRON', u...
# 15  [{u'index': 2, u'begin': 0, u'pos': u'VERB', u...
# 16  [{u'index': 2, u'begin': 0, u'pos': u'PRON', u...
# 17  [{u'index': 3, u'begin': 0, u'pos': u'PRON', u...
# 18  [{u'index': 1, u'begin': 0, u'pos': u'ADV', u'...
# 19  [{u'index': 3, u'begin': 0, u'pos': u'PRON', u...

# %%
df.entities[17]
# Out:
# [{'mentions': [u'Pym Particle', u'miracle'],
#   'meta': {},
#   'name': u'Pym Particle',
#   'salience': 0.81080335,
#   'type': u'CONSUMER_GOOD'},
#  {'mentions': [u'Hank'],
#   'meta': {},
#   'name': u'Hank',
#   'salience': 0.18919668,
#   'type': u'PERSON'}]

# %%
df.dialogue[17]
# Out:
# "We don't accept it. Formally. Hank, we need you. The Pym Particle is a miracle. Please, don't let your past determine the future."

# %%
cList = list(df.speaker.unique())
df['total_sent'] = df['sentiment'].apply(lambda x: x['score'] * x['magnitude'])
cDict = dict(df.groupby('speaker').total_sent.sum())

# number of pronouns for each line
df['num_pron'] = df['tokens'].apply(lambda x: sum([int(t['pos'] == 'PRON') for t in x]))

# total sentiment score for each line
df['total_sent'] = df['sentiment'].apply(lambda x: x['score'] * x['magnitude'])

#set nearby speakers
charRange = 10
nearbyList = np.dstack((df.shift(i).speaker.values for i in range(-charRange, charRange+1)))[0]
df['nearbyChars'] = None
for i, nearbyChars in enumerate(nearbyList):
    df.set_value(i, 'nearbyChars', nearbyChars)

df.head()['tokens'][3]
# Out:
# [{'begin': 0,
#   'content': u'Hello',
#   'index': 2,
#   'label': u'DISCOURSE',
#   'lemma': u'Hello',
#   'pos': u'X'},
#  {'begin': 5,
#   'content': u',',
#   'index': 2,
#   'label': u'P',
#   'lemma': u',',
#   'pos': u'PUNCT'},
#  {'begin': 7,
#   'content': u'Hank',
#   'index': 2,
#   'label': u'ROOT',
#   'lemma': u'Hank',
#   'pos': u'NOUN'},
#  {'begin': 11,
#   'content': u'.',
#   'index': 2,
#   'label': u'P',
#   'lemma': u'.',
#   'pos': u'PUNCT'},
#  {'begin': 13,
#   'content': u'You',
#   'index': 6,
#   'label': u'NSUBJPASS',
#   'lemma': u'You',
#   'pos': u'PRON'},
#  {'begin': 16,
#   'content': u"'re",
#   'index': 6,
#   'label': u'AUXPASS',
#   'lemma': u'be',
#   'pos': u'VERB'},
#  {'begin': 20,
#   'content': u'supposed',
#   'index': 6,
#   'label': u'ROOT',
#   'lemma': u'suppose',
#   'pos': u'VERB'},
#  {'begin': 29,
#   'content': u'to',
#   'index': 8,
#   'label': u'AUX',
#   'lemma': u'to',
#   'pos': u'PRT'},
#  {'begin': 32,
#   'content': u'be',
#   'index': 6,
#   'label': u'XCOMP',
#   'lemma': u'be',
#   'pos': u'VERB'},
#  {'begin': 35,
#   'content': u'in',
#   'index': 8,
#   'label': u'PREP',
#   'lemma': u'in',
#   'pos': u'ADP'},
#  {'begin': 38,
#   'content': u'Moscow',
#   'index': 9,
#   'label': u'POBJ',
#   'lemma': u'Moscow',
#   'pos': u'NOUN'},
#  {'begin': 44,
#   'content': u'.',
#   'index': 6,
#   'label': u'P',
#   'lemma': u'.',
#   'pos': u'PUNCT'}]

# %% [markdown]
# ## Task 1. [Entity Resolution](#top) <a class="anchor" id="Entity"></a>

# %%
for n, df in df_dict.iteritems():
    df['tokens'] = df.apply(lambda x:pronResolution_nnMod(cList, x), axis=1)

# %%
pronEval([df, df], numExamples=2)
# Out:
# ******** line 771 ********
# 769. Dave:
# Looks like Pym's getting arrested.
#
# 770. Kurt:
# Scott, we have problem.
#
# => 771. Scott Lang:
# => Problem? What's the problem? [just then Dave gets out of the can]
#
# 772. Kurt:
# Dave! Dave, that's not part of plan!
#
# 773. Dr. Hank Pym:
# [as Paxton and Gale are trying to arrest Pym] Listen to me, if I don't get into this building people will die.
#
# ******** test model 1: line 771 ********
# 0 pronouns resolved
#
# how many are correctly identified? 0
#
# ******** line 771 ********
# 769. Dave:
# Looks like Pym's getting arrested.
#
# 770. Kurt:
# Scott, we have problem.
#
# => 771. Scott Lang:
# => Problem? What's the problem? [just then Dave gets out of the can]
#
# 772. Kurt:
# Dave! Dave, that's not part of plan!
#
# 773. Dr. Hank Pym:
# [as Paxton and Gale are trying to arrest Pym] Listen to me, if I don't get into this building people will die.
#
# ******** test model 2: line 771 ********
# 0 pronouns resolved

# %% [markdown]
# ## Task 2. [Relation Extraction](#top) <a class="anchor" id="Relation"></a>

# %%
df_dict['df_1']['relations'] = df_dict['df_1'].apply(lambda x:extract_relation_categories(x), axis=1)
REEval([df_dict['df_1']])
#34/67
# Out:
# ******** line 754 ********
# 752. Tony Stark:
# No, of course not! I want to help you put JARVIS in this thing. [Banner shakes his head] We're out of my field here. You know bio-organics better than anyone.
#
# 753. Bruce Banner:
# And you just assume that JARVIS' operational matrix can beat Ultron's?
#
# => 754. Tony Stark:
# => JARVIS has been beating him from inside without knowing it. This is the opportunity, we can create Ultron's perfect self, without the homicidal glitches he thinks are his winning personality. We have to.
#
# 755. JARVIS:
# I believe it's worth a go.
#
# 756. Bruce Banner:
# No, I'm in a loop! I'm caught in a time loop, this is exactly where it all went wrong.
#
# ******** test model 1: line 754 ********
# 1 relations identified
# entities: Tony Stark => , Ultron, JARVIS, personality
# relation: JARVIS has been beating him from inside without knowing it. This is the opportunity, we can create Ultron's perfect self, without the homicidal glitches he thinks are his winning personality. We have to.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 393 ********
# 391. Ultron:
# Oh, I'm sure they do. But you needed something more than a man. That's why you let Stark take the scepter.
#
# 392. Wanda Maximoff:
# I didn't expect. But I saw Stark's fear, I knew it would control him, make him self-destruct.
#
# => 393. Ultron:
# => Everyone creates the thing they dread. Men of peace create engines of war, invaders create avengers, people create...smaller people? Uh...children! I lost the word there. Children. Designed to supplant them, to help them...end.
#
# 394. Wanda Maximoff:
# Is that why you've come? To end the Avengers?
#
# 395. Ultron:
# I've come to save the world. But also, yeah. We'll move out right away. This is a start, but there's something we need to begin the real work.
#
# ******** test model 1: line 393 ********
# 1 relations identified
# entities: Ultron => , Everyone, Men, people, people, avengers, invaders, children, Children
# relation: Everyone creates the thing they dread. Men of peace create engines of war, invaders create avengers, people create...smaller people? Uh...children! I lost the word there. Children. Designed to supplant them, to help them...end.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 218 ********
# 216. Tony Stark:
# Thanks, buddy.
#
# 217. JARVIS:
# Enjoy yourself, sir.
#
# => 218. Tony Stark:
# => I always do. [Stark leaves the lab to go to the party] [we see Stark's failed experiment integrating itself successfully to the program]
#
# 219. Ultron:
# What is this? What is this, please?
#
# 220. JARVIS:
# Hello, I am JARVIS. You are Ultron, a global peace-keeping initiative designed by Mr. Stark. Our sentience integration trials have been unsuccessful so I'm not certain what triggered your...
#
# ******** test model 1: line 218 ********
# 1 relations identified
# entities: Stark => lab
# relation:  leaves the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 470 ********
# 468. Klaue's Mercenary:
# Which ones?
#
# 469. Ulysses Klaue:
# All of them!
#
# => 470. Klaue's Mercenary:
# => [to his men] Move, move, move! [the rest of the team, including Natasha and Barton now battle it out with the Iron Legions, Klaue's men and the twins as Stark fight with Ultron]
#
# 471. Steve Rogers:
# [after knocking down Pietro] Stay down, kid!
#
# 472. Ultron:
# [to Wanda] It's time for some mind games. [Banner hears the commotion as he waits in the Quinjet]
#
# ******** test model 1: line 470 ********
# 1 relations identified
# entities: Klaue's Mercenary => , men, rest, men, Barton, twins, Stark, Natasha, Iron Legions
# relation: [to his men] Move, move, move! [the rest of the team, including Natasha and Barton now battle it out with the Iron Legions, Klaue's men and the twins as Stark fight with Ultron]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 727 ********
# 725. Steve Rogers:
# If you have the package, get it to Stark! Go!
#
# 726. Clint Barton:
# Do you have eyes on Nat?
#
# => 727. Steve Rogers:
# => Go! [reluctantly Barton takes off in the Quinjet; back on the train to the twins] Civilians in our path. [Pietro speeds off; to Wanda] Can you stop this thing? [as Pietro picks up civilians out of the way of the train Wanda uses her powers and stops the train] [after stopping the train Wanda goes over to an out of breath Pietro]
#
# 728. Pietro Maximoff:
# I'm fine. I just need to take a minute.
#
# 729. Steve Rogers:
# I'm very tempted not to give you one.
#
# ******** test model 1: line 727 ********
# 1 relations identified
# entities: Steve Rogers => , Wanda, Pietro, Barton, twins, Civilians, civilians
# relation: Go! [reluctantly Barton takes off in the Quinjet; back on the train to the twins] Civilians in our path. [Pietro speeds off; to Wanda] Can you stop this thing? [as Pietro picks up civilians out of the way of the train Wanda uses her powers and stops the train] [after stopping the train Wanda goes over to an out of breath Pietro]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 868 ********
# 866. Ultron:
# You can't save them all. You'll never... [he throws off one of the attacking robots off the edge of the bridge]
#
# 867. Steve Rogers:
# You'll never what? You didn't finish! [Thor lands on the bridge on the top of the woman's car he was saving] What, were you napping?
#
# => 868. Ultron:
# => [as Thor and Steve are fighting off the robots] Thor! You're bothering me. [as Barton is fighting off the robots Wanda suddenly comes out of the building and starts to use her powers on the robots to destroy them]
#
# 869. Clint Barton:
# Alright, we're all clear here.
#
# 870. Steve Rogers:
# We are not clear! We are very not clear!
#
# ******** test model 1: line 868 ********
# 1 relations identified
# entities: Ultron => , Thor, Steve, Wanda, Barton
# relation: [as Thor and Steve are fighting off the robots] Thor! You're bothering me. [as Barton is fighting off the robots Wanda suddenly comes out of the building and starts to use her powers on the robots to destroy them]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 569 ********
# 567. Bruce Banner:
# Missed our window.
#
# 568. Natasha Romanoff:
# Did we?
#
# => 569. Bruce Banner:
# => The world just saw the Hulk. The real Hulk, for the first time. You know I have to leave.
#
# 570. Natasha Romanoff:
# But you assume that I have to stay? I had this, um, dream. The kind that seems normal at the time, but when you wake...
#
# 571. Bruce Banner:
# What did you dream?
#
# ******** test model 1: line 569 ********
# 1 relations identified
# entities: world => Hulk
# relation:  saw the
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 444 ********
# 442. Ulysses Klaue:
# Don't tell me your man swindled you. I sent you six short range heat seekers and got a boat full of rusted parts. Now, you will make it right, or the next missile I send you will come very much faster. [he ends the call and connects to another call] Now, minister, where were we? [suddenly the lights go out causing a commotion in the salvage yard and the twins enter Klaue's office] Yeah. The enhanced. Strucker's prize pupils. [picks up a plate from his desk] Want a candy? Oh, sorry to hear about Strucker. But then, he knew what kind of world he was helping create. Human life, not a growth market. [the twins look at each other] You...you didn't know? Is this your first time intimidating someone? I'm afraid that I'm not that afraid.
#
# 443. Wanda Maximoff:
# Everybody's afraid of something.
#
# => 444. Ulysses Klaue:
# => Cuttlefish. Deep sea fish. They make lights. disco lights. Whoom, whoom, whoom! to hypnotize their prey, then whoom! I saw a documentary, it was terrifying. [Pietro speeds over to pick up a candy from Klaue's desk, and Klaue jerks back, expecting to be attacked] So if you're going to fiddle with my brain, and make me see a giant cuttlefish, then I know you don't do business, and I know you're not in charge, and I only deal with the man in charge. [suddenly Ultron breaks through the glass window and knocks down Klaue]
#
# 445. Ultron:
# There is no "man" in charge. Let's talk business. [Klaue gives Ultron some vibranium from his stash] Upon this rock I will build my church. Vibranium.
#
# 446. Ulysses Klaue:
# You know, it came at great personal cost. It's worth billions. [Ultron chuckles and remotely puts money in Klaue's bank account]
#
# ******** test model 1: line 444 ********
# 1 relations identified
# entities: Ulysses Klaue => , whoom, Whoom, man, Pietro, Ultron
# relation: Cuttlefish. Deep sea fish. They make lights. disco lights. Whoom, whoom, whoom! to hypnotize their prey, then whoom! I saw a documentary, it was terrifying. [Pietro speeds over to pick up a candy from Klaue's desk, and Klaue jerks back, expecting to be attacked] So if you're going to fiddle with my brain, and make me see a giant cuttlefish, then I know you don't do business, and I know you're not in charge, and I only deal with the man in charge. [suddenly Ultron breaks through the glass window and knocks down Klaue]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 752 ********
# 750. Tony Stark:
# Ultron didn't go after JARVIS cause he was angry. He attacked him because he was scared of what he can do. So JARVIS went underground. Okay? Scattered, dumped his memory. But not his protocols. He didn't even know he was in there, until I pieced him together.
#
# 751. Bruce Banner:
# So, you want me to help you put JARVIS into this thing?
#
# => 752. Tony Stark:
# => No, of course not! I want to help you put JARVIS in this thing. [Banner shakes his head] We're out of my field here. You know bio-organics better than anyone.
#
# 753. Bruce Banner:
# And you just assume that JARVIS' operational matrix can beat Ultron's?
#
# 754. Tony Stark:
# JARVIS has been beating him from inside without knowing it. This is the opportunity, we can create Ultron's perfect self, without the homicidal glitches he thinks are his winning personality. We have to.
#
# ******** test model 1: line 752 ********
# 1 relations identified
# entities: Tony Stark => , Banner, JARVIS, anyone
# relation: No, of course not! I want to help you put JARVIS in this thing. [Banner shakes his head] We're out of my field here. You know bio-organics better than anyone.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 475 ********
# 473. Bruce Banner:
# Guys, is this a Code Green? [Wanda uses her power on Thor then Steve comes up to him]
#
# 474. Steve Rogers:
# Thor! Status?
#
# => 475. Thor:
# => The girl tried to warp my mind. Take special care, I doubt a human could keep her at bay. Fortunately, I am mighty. [just then Thor seems himself at a party on Asgard] [Wanda then uses her power on Steve and Natasha]
#
# 476. Ultron:
# This is going very well. [Wanda tries to sneak up behind Barton, but he quickly turns and puts an electric arrow on her forehead]
#
# 477. Clint Barton:
# I've done the whole mind control thing. Not a fan. [just then Pietro speeds in, knocks down Barton, picks up Wanda and speeds off] Yeah, you better run. [we see Steve dropping his helmet and walking off; to the team] Whoever's standing, we gotta move! Guys? [Natasha sees herself in the facility where young girls are being taught ballet]
#
# ******** test model 1: line 475 ********
# 1 relations identified
# entities: Thor => , girl, Wanda, human, Steve, Natasha
# relation: The girl tried to warp my mind. Take special care, I doubt a human could keep her at bay. Fortunately, I am mighty. [just then Thor seems himself at a party on Asgard] [Wanda then uses her power on Steve and Natasha]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 680 ********
# 678. Ultron:
# Ask Noah.
#
# 679. Wanda Maximoff:
# You're a madman.
#
# => 680. Ultron:
# => There were more than a dozen extinction level events before even the dinosaurs got theirs. When the Earth starts to settle, God throws a stone at it, and believe me, he's winding up. We have to evolve. There's no room for the weak.
#
# 681. Pietro Maximoff:
# And who decides who's weak? [as Ultron is distracted Wanda breaks the scepter's hold off of Cho]
#
# 682. Ultron:
# Life. Life always decides. There's incoming. The Quinjet. We have to move. [Cho cancels the upload to Ultron's consciousness]
#
# ******** test model 1: line 680 ********
# 1 relations identified
# entities: Earth => stone
# relation:  throws a
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 499 ********
# 497. Ultron:
# Ah, the Vibranium's getting away.
#
# 498. Tony Stark:
# And you're not going anywhere.
#
# => 499. Ultron:
# => Of course not, I'm already there. You'll catch on. But first, you might need to catch Dr. Banner. [Stark angrily shoots Ultron and flies off to find Banner who's turned in to the Hulk and ready to wreak havoc on the nearest city]
#
# 500. Clint Barton:
# Well, that's not gonna happen. Not for a while. The whole team is down, you got no back up here.
#
# 501. Tony Stark:
# I'm calling in VERONICA. [as Hulk is wreaking havoc on the nearest city Stark Tony comes brings out his Hulkbuster armor to stop him] Alright everybody, stand down! [to Hulk] You listening? That little witch is messing with your mind. You're stronger than her, you're smarter than her, you're Bruce Banner. [Hulk roars in anger] Right, right, right! Don't mention puny Banner. [Hulk throws a car at Stark and attacks him] Okay. [they start fighting and throwing each other around] In the back? Dick move, Banner. [they battle it out more but Stark is struggling to beat Hulk] VERONICA, gimme a hand. [as Hulk destroyed one of Stark's armor arms VERONICA sends in a new Hulkbuster armor arm and Stark uses it to repeatedly punch Hulk] Go to sleep, go to sleep, go to sleep! [picking up Hulk] Okay, pal, we're gonna get you out of town. [as they head towards a building] No, not that way, not that way! [they crash through the building] Come on, Bruce! You gotta work with me! [Hulk continues to battle with him] [to the people in the building] Everybody out! Going to get ugly! [after he knocks down Hulk] I'm sorry. [Hulk attacks Stark and pulls out parts of the Hulkbuster armor] Damage report. [the damaged computer buzzes a reply] That's comprehensive. Show me something. [the computer shows him the building ahead is clear of civilians] How quickly can we buy this building? [Stark drops Hulk through the building completely destroying it; at the same time the army arrives to intervene, as Hulk comes out of Wanda's mind-hold Stark knocks him out cold] [with Banner back to normal and everybody back on the Quinjet]
#
# ******** test model 1: line 499 ********
# 1 relations identified
# entities: Ultron => , Banner, Stark, Hulk
# relation: Of course not, I'm already there. You'll catch on. But first, you might need to catch Dr. Banner. [Stark angrily shoots Ultron and flies off to find Banner who's turned in to the Hulk and ready to wreak havoc on the nearest city]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 1006 ********
# 1004. Tony Stark:
# That man has no regard for lawn maintenance. I'm gonna miss him though. And you're gonna miss me. There's gonna be a lot of manful tears. [as they walk over towards Stark's car]
#
# 1005. Steve Rogers:
# I will miss you, Tony.
#
# => 1006. Tony Stark:
# => Yeah? Well, it's time for me to tap out. Maybe I should take a page out of Barton's book and build Pepper a farm, hope nobody blows it up.
#
# 1007. Steve Rogers:
# The simple life.
#
# 1008. Tony Stark:
# You'll get there one day.
#
# ******** test model 1: line 1006 ********
# 1 relations identified
# entities: Tony Stark => , nobody, Barton, Pepper
# relation: Yeah? Well, it's time for me to tap out. Maybe I should take a page out of Barton's book and build Pepper a farm, hope nobody blows it up.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 964 ********
# 962. Wanda Maximoff:
# I just did. Do you know how it felt? [she uses her power to rip Ultron's core out of his body] It felt like that. [Stark fires a powerful blast to the core underneath the floating city]
#
# 963. Tony Stark:
# Thor, on my mark. [Thor brings on a blast of lightning, at the same time Vision flies in, picks up Wanda and flies off with as the city is being destroyed] Now! [Thor uses his hammer to hit the Vibranium core in the church, destroying the core and the floating city]
#
# => 964. Natasha Romanoff:
# => [to Hulk as he remains on the jet he knocked Ultron out of] Hey, big guy. We did it, the job's finished. Now I need you to turn this bird around, okay? We can't track you in stealth mode, so help me out. I need you t... [Hulk turns off Nat's camera, then sits as the jet flies off to an unknown destination, at the same time Vision finds Ultron]
#
# 965. Vision:
# You're afraid.
#
# 966. Ultron:
# Of you?
#
# ******** test model 1: line 964 ********
# 1 relations identified
# entities: Natasha Romanoff => , Hulk, Ultron, guy
# relation: [to Hulk as he remains on the jet he knocked Ultron out of] Hey, big guy. We did it, the job's finished. Now I need you to turn this bird around, okay? We can't track you in stealth mode, so help me out. I need you t... [Hulk turns off Nat's camera, then sits as the jet flies off to an unknown destination, at the same time Vision finds Ultron]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 548 ********
# 546. Clint Barton:
# Oh. Okay.
#
# 547. Laura Barton:
# It's bad, right? Nat seems really shaken.
#
# => 548. Clint Barton:
# => Ultron has these allies, these uh, kids, they're punks really. They carry a big damn stick and Nat took a serious hit. Someone's gonna have to teach 'em some manners.
#
# 549. Laura Barton:
# And that someone be you. You know I totally support your Avenging, I couldn't be prouder. But I see those guys, those "Gods"...
#
# 550. Clint Barton:
# You don't think they need me.
#
# ******** test model 1: line 548 ********
# 1 relations identified
# entities: Clint Barton => , punks, Ultron, Nat, Someone
# relation: Ultron has these allies, these uh, kids, they're punks really. They carry a big damn stick and Nat took a serious hit. Someone's gonna have to teach 'em some manners.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 537 ********
# 535. Steve Rogers:
# Thor.
#
# 536. Thor:
# I saw something in that dream. I need answers, I won't find them here. [Thor uses his hammer to fly out of there; Steve turns to enter the house when he hears Peggy's voice from Wanda's vision]
#
# => 537. Peggy Carter:
# => We can go home. [Laura checks Barton's wound that Pietro had give him]
#
# 538. Clint Barton:
# See, you worried for nothing. Can't even feel the difference, can you?
#
# 539. Laura Barton:
# If they're sleeping here, some of them are gonna have to double up. [Barton laughs]
#
# ******** test model 1: line 537 ********
# 1 relations identified
# entities: Peggy Carter => , Barton, Laura, Pietro
# relation: We can go home. [Laura checks Barton's wound that Pietro had give him]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 708 ********
# 706. Natasha Romanoff:
# Which way?
#
# 707. Clint Barton:
# Hard right... Now. [Natasha heads over the truck, she throws Steve back his shield and he uses it to knock off Ultron from him]
#
# => 708. Natasha Romanoff:
# => [to the pedestrians on the pavement as she chases after the truck on her bike] Out of the way! Coming through! Sorry, coming through! [Steve continues his battle with Ultron inside a speeding train]
#
# 709. Steve Rogers:
# Come on!
#
# 710. Natasha Romanoff:
# Clint, can you draw out the guards?
#
# ******** test model 1: line 708 ********
# 1 relations identified
# entities: Natasha Romanoff => , pedestrians, Steve, Ultron
# relation: [to the pedestrians on the pavement as she chases after the truck on her bike] Out of the way! Coming through! Sorry, coming through! [Steve continues his battle with Ultron inside a speeding train]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 807 ********
# 805. Clint Barton:
# Sokovia. He's got Nat there too.
#
# 806. Bruce Banner:
# If we're wrong about you, if you're the monster that Ultron made you to be...
#
# => 807. Vision:
# => What will you do? [he looks at them all realizing they will destroy him] I don't want to kill Ultron. He's unique, and he's in pain. But that pain will roll over the earth, so he must be destroyed. Every form he's built, every trace of his presence on the net, we have to act now. And not one of us can do it without the others. Maybe I am a monster. I don't think I'd know if I were one. I'm not what you are, and not what you intended. So there may be no way to make you trust me. But we need to go. [he holds up Thor's hammer and hands it to him, Vision walks off and everyone stares in shock]
#
# 808. Thor:
# Right. [pats Stark on the shoulder] Well done.
#
# 809. Steve Rogers:
# [to the others] Three minutes. Get what you need. [they all start getting ready to leave, Stark loads up FRIDAY into his Iron Man suit now that JARVIS is no longer available]
#
# ******** test model 1: line 807 ********
# 1 relations identified
# entities: Vision => , Ultron, others, everyone
# relation: What will you do? [he looks at them all realizing they will destroy him] I don't want to kill Ultron. He's unique, and he's in pain. But that pain will roll over the earth, so he must be destroyed. Every form he's built, every trace of his presence on the net, we have to act now. And not one of us can do it without the others. Maybe I am a monster. I don't think I'd know if I were one. I'm not what you are, and not what you intended. So there may be no way to make you trust me. But we need to go. [he holds up Thor's hammer and hands it to him, Vision walks off and everyone stares in shock]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 1016 ********
# 1014. Natasha Romanoff:
# We've got some hitters.
#
# 1015. Steve Rogers:
# They're good. They're not a team.
#
# => 1016. Natasha Romanoff:
# => Let's beat 'em into shape. [they gather Rhodes in his War Machine suit, Sam in his Falcon suit, Wanda in a new suit, and Vision]
#
# 1017. Steve Rogers:
# Avengers...! [mid-credits scene; we see the Infinity Gauntlet without any of the Stones, dissatisfied Thanos opens a vault and puts on The Infinty Gauntlet, revealing himself]
#
# 1018. Thanos:
# Fine, I'll do it myself.
#
# ******** test model 1: line 1016 ********
# 1 relations identified
# entities: Natasha Romanoff => , Sam, Rhodes, Wanda
# relation: Let's beat 'em into shape. [they gather Rhodes in his War Machine suit, Sam in his Falcon suit, Wanda in a new suit, and Vision]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 442 ********
# 440. Tony Stark:
# The strongest metal on earth.
#
# 441. Steve Rogers:
# [to Stark] Where is this guy now? [Salvage Yard, African Coast; talking on the phone in his office]
#
# => 442. Ulysses Klaue:
# => Don't tell me your man swindled you. I sent you six short range heat seekers and got a boat full of rusted parts. Now, you will make it right, or the next missile I send you will come very much faster. [he ends the call and connects to another call] Now, minister, where were we? [suddenly the lights go out causing a commotion in the salvage yard and the twins enter Klaue's office] Yeah. The enhanced. Strucker's prize pupils. [picks up a plate from his desk] Want a candy? Oh, sorry to hear about Strucker. But then, he knew what kind of world he was helping create. Human life, not a growth market. [the twins look at each other] You...you didn't know? Is this your first time intimidating someone? I'm afraid that I'm not that afraid.
#
# 443. Wanda Maximoff:
# Everybody's afraid of something.
#
# 444. Ulysses Klaue:
# Cuttlefish. Deep sea fish. They make lights. disco lights. Whoom, whoom, whoom! to hypnotize their prey, then whoom! I saw a documentary, it was terrifying. [Pietro speeds over to pick up a candy from Klaue's desk, and Klaue jerks back, expecting to be attacked] So if you're going to fiddle with my brain, and make me see a giant cuttlefish, then I know you don't do business, and I know you're not in charge, and I only deal with the man in charge. [suddenly Ultron breaks through the glass window and knocks down Klaue]
#
# ******** test model 1: line 442 ********
# 1 relations identified
# entities: Ulysses Klaue => , man, heat seekers, Strucker, twins, minister, prize pupils, twins, each other, someone
# relation: Don't tell me your man swindled you. I sent you six short range heat seekers and got a boat full of rusted parts. Now, you will make it right, or the next missile I send you will come very much faster. [he ends the call and connects to another call] Now, minister, where were we? [suddenly the lights go out causing a commotion in the salvage yard and the twins enter Klaue's office] Yeah. The enhanced. Strucker's prize pupils. [picks up a plate from his desk] Want a candy? Oh, sorry to hear about Strucker. But then, he knew what kind of world he was helping create. Human life, not a growth market. [the twins look at each other] You...you didn't know? Is this your first time intimidating someone? I'm afraid that I'm not that afraid.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 42 ********
# 40. narrator:
# Pietro speeds through the forest and knocks down Barton
#
# 41. Pietro Maximoff:
# You didn't see that coming?
#
# => 42. narrator:
# => Pietro zooms off before Clint can shoot him with an arrow, then Barton gets shot at
#
# 43. Natasha Romanoff:
# Clint!
#
# 44. narrator:
# Pietro knocks down Steve as he speeds passed him
#
# ******** test model 1: line 42 ********
# 1 relations identified
# entities: narrator => , Pietro, Clint, Barton
# relation: Pietro zooms off before Clint can shoot him with an arrow, then Barton gets shot at
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 757 ********
# 755. JARVIS:
# I believe it's worth a go.
#
# 756. Bruce Banner:
# No, I'm in a loop! I'm caught in a time loop, this is exactly where it all went wrong.
#
# => 757. Tony Stark:
# => I know, I know. I know what everyone's going to say, but they're already saying it. We're mad scientists. We're monsters, buddy. You gotta own it. Make a stand. [Banner shakes his head] It's not a loop. It's the end of the line.
#
# 758. Ultron:
# [as Natasha becomes conscious] I wasn't sure you'd wake up. I hoped you would, I wanted to show you something. I don't have anyone else. I think a lot about meteors, the purity of them. Boom! The end, start again. The world made clean for the new man to rebuild. I was meant to be new. I was meant to be beautiful. The world would've looked to the sky and seen hope, seen mercy. Instead they'll look up in horror because of you. You've wounded me. I give you full marks for that. But, like the man said, "What doesn't kill me…[bigger body of Ultron's destroys him] "…just makes me stronger." [locks Natasha in a cell] [Barton gets a Morse code message from Natasha which he's able to detect her location, at the same time Stark and Banner are experimenting on the synthetic body]
#
# 759. Tony Stark:
# This framework is not compatible.
#
# ******** test model 1: line 757 ********
# 1 relations identified
# entities: Tony Stark => , scientists, everyone, Banner, buddy
# relation: I know, I know. I know what everyone's going to say, but they're already saying it. We're mad scientists. We're monsters, buddy. You gotta own it. Make a stand. [Banner shakes his head] It's not a loop. It's the end of the line.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 115 ********
# 113. narrator:
# Wanda smiles to herself as Tony takes the scepter
#
# 114. narrator:
# Title Sequence plays
#
# => 115. narrator:
# => the Avengers are on an aircraft heading out of Sokovia, Natasha interrupts Banner who's listening to opera with his headphones
#
# 116. Natasha Romanoff:
# Hey, the lullaby worked better than ever.
#
# 117. Bruce Banner:
# Just wasn't expecting the Code Green.
#
# ******** test model 1: line 115 ********
# 1 relations identified
# entities: narrator => , Banner, Avengers, Natasha
# relation: the Avengers are on an aircraft heading out of Sokovia, Natasha interrupts Banner who's listening to opera with his headphones
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 958 ********
# 956. Thor:
# Maybe not. [just as Natasha tries to calm Hulk down to get him back to being Banner Ultron flies in with a jet and starts shooting at them]
#
# 957. Ultron:
# [sings] I got no strings, so I have fun. I'm not tied up to anyone. [as Barton is saving the boy, Costel, Ultron starts shooting at them but Pietro intervenes and takes the shots to save them]
#
# => 958. Pietro Maximoff:
# => You didn't see that coming. [Pietro falls to the ground as he dies, Wanda senses his death, causing her to fall in despair] [Hulk drops Natasha off onto the Helicarrier and then jumps onto the jet Ultron is on]
#
# 959. Ultron:
# Oh, for God's sake! [Hulk knocks Ultron out of the jet and he crashes inside a train; at the same time Barton delivers Costel safely to his sister onto the lifeboat, a man goes over to help him with his wound]
#
# 960. Clint Barton:
# No, no. I'm fine. [Barton lies down next to the dead body of Pietro] Oh, it's been a long day. [Wanda then finds the Ultron]
#
# ******** test model 1: line 958 ********
# 1 relations identified
# entities: Pietro Maximoff => , Wanda, Hulk, Natasha
# relation: You didn't see that coming. [Pietro falls to the ground as he dies, Wanda senses his death, causing her to fall in despair] [Hulk drops Natasha off onto the Helicarrier and then jumps onto the jet Ultron is on]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 477 ********
# 475. Thor:
# The girl tried to warp my mind. Take special care, I doubt a human could keep her at bay. Fortunately, I am mighty. [just then Thor seems himself at a party on Asgard] [Wanda then uses her power on Steve and Natasha]
#
# 476. Ultron:
# This is going very well. [Wanda tries to sneak up behind Barton, but he quickly turns and puts an electric arrow on her forehead]
#
# => 477. Clint Barton:
# => I've done the whole mind control thing. Not a fan. [just then Pietro speeds in, knocks down Barton, picks up Wanda and speeds off] Yeah, you better run. [we see Steve dropping his helmet and walking off; to the team] Whoever's standing, we gotta move! Guys? [Natasha sees herself in the facility where young girls are being taught ballet]
#
# 478. Ballet Instructor:
# [to the students] Again.
#
# 479. Natasha Romanoff:
# You'll break them.
#
# ******** test model 1: line 477 ********
# 1 relations identified
# entities: Clint Barton => , Steve, Natasha, fan., Pietro, Guys, Wanda, girls
# relation: I've done the whole mind control thing. Not a fan. [just then Pietro speeds in, knocks down Barton, picks up Wanda and speeds off] Yeah, you better run. [we see Steve dropping his helmet and walking off; to the team] Whoever's standing, we gotta move! Guys? [Natasha sees herself in the facility where young girls are being taught ballet]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 501 ********
# 499. Ultron:
# Of course not, I'm already there. You'll catch on. But first, you might need to catch Dr. Banner. [Stark angrily shoots Ultron and flies off to find Banner who's turned in to the Hulk and ready to wreak havoc on the nearest city]
#
# 500. Clint Barton:
# Well, that's not gonna happen. Not for a while. The whole team is down, you got no back up here.
#
# => 501. Tony Stark:
# => I'm calling in VERONICA. [as Hulk is wreaking havoc on the nearest city Stark Tony comes brings out his Hulkbuster armor to stop him] Alright everybody, stand down! [to Hulk] You listening? That little witch is messing with your mind. You're stronger than her, you're smarter than her, you're Bruce Banner. [Hulk roars in anger] Right, right, right! Don't mention puny Banner. [Hulk throws a car at Stark and attacks him] Okay. [they start fighting and throwing each other around] In the back? Dick move, Banner. [they battle it out more but Stark is struggling to beat Hulk] VERONICA, gimme a hand. [as Hulk destroyed one of Stark's armor arms VERONICA sends in a new Hulkbuster armor arm and Stark uses it to repeatedly punch Hulk] Go to sleep, go to sleep, go to sleep! [picking up Hulk] Okay, pal, we're gonna get you out of town. [as they head towards a building] No, not that way, not that way! [they crash through the building] Come on, Bruce! You gotta work with me! [Hulk continues to battle with him] [to the people in the building] Everybody out! Going to get ugly! [after he knocks down Hulk] I'm sorry. [Hulk attacks Stark and pulls out parts of the Hulkbuster armor] Damage report. [the damaged computer buzzes a reply] That's comprehensive. Show me something. [the computer shows him the building ahead is clear of civilians] How quickly can we buy this building? [Stark drops Hulk through the building completely destroying it; at the same time the army arrives to intervene, as Hulk comes out of Wanda's mind-hold Stark knocks him out cold] [with Banner back to normal and everybody back on the Quinjet]
#
# 502. Maria Hill:
# The news is loving you guys. Nobody else is. There's been no official call for Banner's arrest, but it's in the air.
#
# 503. Tony Stark:
# Stark Relief Foundation?
#
# ******** test model 1: line 501 ********
# 9 relations identified
# entities: Tony Stark => , Bruce Banner, Hulkbuster, everybody, Banner, one, each other, civilians, Dick, Okay., everybody, Everybody, people, Wanda
# relation: I'm calling in VERONICA. [as Hulk is wreaking havoc on the nearest city Stark Tony comes brings out his Hulkbuster armor to stop him] Alright everybody, stand down! [to Hulk] You listening? That little witch is messing with your mind. You're stronger than her, you're smarter than her, you're Bruce Banner. [Hulk roars in anger] Right, right, right! Don't mention puny Banner. [Hulk throws a car at Stark and attacks him] Okay. [they start fighting and throwing each other around] In the back? Dick move, Banner. [they battle it out more but Stark is struggling to beat Hulk] VERONICA, gimme a hand. [as Hulk destroyed one of Stark's armor arms VERONICA sends in a new Hulkbuster armor arm and Stark uses it to repeatedly punch Hulk] Go to sleep, go to sleep, go to sleep! [picking up Hulk] Okay, pal, we're gonna get you out of town. [as they head towards a building] No, not that way, not that way! [they crash through the building] Come on, Bruce! You gotta work with me! [Hulk continues to battle with him] [to the people in the building] Everybody out! Going to get ugly! [after he knocks down Hulk] I'm sorry. [Hulk attacks Stark and pulls out parts of the Hulkbuster armor] Damage report. [the damaged computer buzzes a reply] That's comprehensive. Show me something. [the computer shows him the building ahead is clear of civilians] How quickly can we buy this building? [Stark drops Hulk through the building completely destroying it; at the same time the army arrives to intervene, as Hulk comes out of Wanda's mind-hold Stark knocks him out cold] [with Banner back to normal and everybody back on the Quinjet]
# category: 3
# entities: Stark => ['Tony Stark']
# relation:  gim
# category: 5
# entities: Stark => hand
# relation:  gim me a
# category: 5
# entities: Stark => it
# relation:  uses
# category: 5
# entities: Stark => Hulk
# relation:  knocks down
# category: 5
# entities: Stark => reply
# relation:  buzzes a
# category: 5
# entities: Stark => ['Dr. Rao']
# relation:  shows
# category: 5
# entities: Stark => building
# relation:  buy this
# category: 5
# entities: Stark => Hulk
# relation:  drops
# category: 5
#
# how many are correctly identified? 3
#
# ******** line 166 ********
# 164. Tony Stark:
# Like a reactor?
#
# 165. JARVIS:
# Like a computer. I believe I'm ciphering code.
#
# => 166. Natasha Romanoff:
# => [to Dr. Cho as she tends to Barton's wounds] You sure he's going to be okay? Pretending to need this guy really brings the team together.
#
# 167. Dr. Helen Cho:
# There's no possibility of deterioration. The nano-molecular functionality is instantaneous. His cells don't know they're bonding with simulacrum.
#
# 168. Bruce Banner:
# She's creating tissue.
#
# ******** test model 1: line 166 ********
# 1 relations identified
# entities: Natasha Romanoff => , Cho, Barton, guy
# relation: [to Dr. Cho as she tends to Barton's wounds] You sure he's going to be okay? Pretending to need this guy really brings the team together.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 758 ********
# 756. Bruce Banner:
# No, I'm in a loop! I'm caught in a time loop, this is exactly where it all went wrong.
#
# 757. Tony Stark:
# I know, I know. I know what everyone's going to say, but they're already saying it. We're mad scientists. We're monsters, buddy. You gotta own it. Make a stand. [Banner shakes his head] It's not a loop. It's the end of the line.
#
# => 758. Ultron:
# => [as Natasha becomes conscious] I wasn't sure you'd wake up. I hoped you would, I wanted to show you something. I don't have anyone else. I think a lot about meteors, the purity of them. Boom! The end, start again. The world made clean for the new man to rebuild. I was meant to be new. I was meant to be beautiful. The world would've looked to the sky and seen hope, seen mercy. Instead they'll look up in horror because of you. You've wounded me. I give you full marks for that. But, like the man said, "What doesn't kill me…[bigger body of Ultron's destroys him] "…just makes me stronger." [locks Natasha in a cell] [Barton gets a Morse code message from Natasha which he's able to detect her location, at the same time Stark and Banner are experimenting on the synthetic body]
#
# 759. Tony Stark:
# This framework is not compatible.
#
# 760. Bruce Banner:
# The genetic coding tower's at ninety-seven percent. You have got to upload that schematic in the next three minutes. [Steve and the twins turn up at the lab]
#
# ******** test model 1: line 758 ********
# 6 relations identified
# entities: Ultron => , Natasha, meteors, Barton, anyone, man, man, Banner, Stark
# relation: [as Natasha becomes conscious] I wasn't sure you'd wake up. I hoped you would, I wanted to show you something. I don't have anyone else. I think a lot about meteors, the purity of them. Boom! The end, start again. The world made clean for the new man to rebuild. I was meant to be new. I was meant to be beautiful. The world would've looked to the sky and seen hope, seen mercy. Instead they'll look up in horror because of you. You've wounded me. I give you full marks for that. But, like the man said, "What doesn't kill me…[bigger body of Ultron's destroys him] "…just makes me stronger." [locks Natasha in a cell] [Barton gets a Morse code message from Natasha which he's able to detect her location, at the same time Stark and Banner are experimenting on the synthetic body]
# category: 3
# entities: world => ['Ultron']
# relation:  wounded
# category: 5
# entities: world => ['Tony Stark']
# relation:  give
# category: 5
# entities: world => marks
# relation:  give you full
# category: 5
# entities: world => ['Cain']
# relation:  destroys
# category: 5
# entities: world => message
# relation:  gets a Morse code
# category: 5
#
# how many are correctly identified? 2
#
# ******** line 15 ********
# 13. Steve Rogers:
# <span style="line-height:21px;">It just slipped out.</span> <span style="line-height:21px;">[at the HYDRA Research Base, Sokovia, Eastern Europe]</span>
#
# 14. Strucker:
# Who gave the order to attack?
#
# => 15. Fortress Soldier:
# => Herr Strucker, it's the Avengers. They landed in the far woods, the perimeter guard panicked.
#
# 16. Strucker:
# [to List] They have to be after the scepter. [to the soldier] Can we hold them?
#
# 17. Fortress Soldier:
# They are the Avengers!
#
# ******** test model 1: line 15 ********
# 1 relations identified
# entities: Fortress Soldier => , Herr Strucker, Avengers, perimeter guard
# relation: Herr Strucker, it's the Avengers. They landed in the far woods, the perimeter guard panicked.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 104 ********
# 102. Steve Rogers:
# Guys, I got Strucker.
#
# 103. Tony Stark:
# Yeah, I got...something bigger.
#
# => 104. narrator:
# => inside the secret passageway Stark finds a room with recovered artifacts from the Battle of New York, including a gigantic Chitauri leviathan and some of his Iron Man scrapped armor, he then spots the scepter
#
# 105. Tony Stark:
# Thor, I got eyes on the prize.
#
# 106. narrator:
# Wanda creeps up behind him and uses her powers on him, suddenly the Chitauri comes to life, then Stark sees the rest of the Avengers team are all dead, he goes over to Steve's body to check his pulse when Steve suddenly grabs him
#
# ******** test model 1: line 104 ********
# 1 relations identified
# entities: Stark => room
# relation:  finds a
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 695 ********
# 693. Natasha Romanoff:
# I got a private jet taking off, across town, no manifest. That could be him.
#
# 694. Clint Barton:
# [noticing a truck leaving the lab] There. It's the truck from the lab. Right above you, Cap. On the loop by the bridge. It's them. I got three with the Cradle, one in the cab. I could take out the driver.
#
# => 695. Steve Rogers:
# => Negative! If that truck crashes, the gem could level the city. We need to draw out Ultron. [Steve jumps onto the roof of the truck]
#
# 696. Ultron:
# No, no, no, no, no. Leave me alone!
#
# 697. Steve Rogers:
# [Ultron blasts the truck door as Steve tries to enter] Well, he's definitely unhappy! I'm gonna try and keep him that way.
#
# ******** test model 1: line 695 ********
# 1 relations identified
# entities: gem => city
# relation:  level the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 38 ********
# 36. Strucker:
# They are not ready to take on...
#
# 37. Dr. List:
# No, no. I mean...
#
# => 38. narrator:
# => he points to where the twins Wanda and Pietro Maximoff were standing but are now gone
#
# 39. Dr. List:
# The Twins.
#
# 40. narrator:
# Pietro speeds through the forest and knocks down Barton
#
# ******** test model 1: line 38 ********
# 1 relations identified
# entities: narrator => , twins, Wanda, Pietro Maximoff
# relation: he points to where the twins Wanda and Pietro Maximoff were standing but are now gone
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 245 ********
# 243. James Rhodes:
# Quality save. So, no Pepper? She's not coming?
#
# 244. Tony Stark:
# No.
#
# => 245. Maria Hill:
# => Hey, what about Jane? Where are the ladies, gentlemen?
#
# 246. Tony Stark:
# Well, Miss Potts has a company to run.
#
# 247. Thor:
# Yes, I'm not even sure what country Jane's in. Her work on the convergence has made her the world's foremost astronomer.
#
# ******** test model 1: line 245 ********
# 1 relations identified
# entities: Maria Hill => , Jane, gentlemen, ladies
# relation: Hey, what about Jane? Where are the ladies, gentlemen?
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 187 ********
# 185. Bruce Banner:
# Jarvis.
#
# 186. JARVIS:
# Doctor.
#
# => 187. Tony Stark:
# => Started out, JARVIS was just a natural language UI. Now he runs the Iron Legion. He runs more of the business than anyone besides Pepper.
#
# 188. Bruce Banner:
# Oh.
#
# 189. Tony Stark:
# Top of the line.
#
# ******** test model 1: line 187 ********
# 1 relations identified
# entities: Tony Stark => , JARVIS, anyone, Pepper
# relation: Started out, JARVIS was just a natural language UI. Now he runs the Iron Legion. He runs more of the business than anyone besides Pepper.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 536 ********
# 534. Natasha Romanoff:
# Traitor. [the hallucinations brought on by Wanda continue to creep up in Thor's mind and he walks out of the house]
#
# 535. Steve Rogers:
# Thor.
#
# => 536. Thor:
# => I saw something in that dream. I need answers, I won't find them here. [Thor uses his hammer to fly out of there; Steve turns to enter the house when he hears Peggy's voice from Wanda's vision]
#
# 537. Peggy Carter:
# We can go home. [Laura checks Barton's wound that Pietro had give him]
#
# 538. Clint Barton:
# See, you worried for nothing. Can't even feel the difference, can you?
#
# ******** test model 1: line 536 ********
# 1 relations identified
# entities: Thor => , Steve, Peggy, Wanda
# relation: I saw something in that dream. I need answers, I won't find them here. [Thor uses his hammer to fly out of there; Steve turns to enter the house when he hears Peggy's voice from Wanda's vision]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 873 ********
# 871. Clint Barton:
# Alright, coming to you. [just then Pietro speeds in, picks up Wanda and leaves]
#
# 872. Pietro Maximoff:
# Keep up old man! [Barton holds his arrow to aim it at Pietro]
#
# => 873. Clint Barton:
# => Nobody would know. Nobody. "The last I saw him, when Ultron was sitting on him. Uh...yeah, he'll be missed, that quick little bastard. I miss him already."
#
# 874. Steve Rogers:
# [as Natasha joins them in their battle with the robots] Romanoff! [he throws his shield at her so she can use it to protect herself from the attacking robot]
#
# 875. Natasha Romanoff:
# Thanks. [back to Stark]
#
# ******** test model 1: line 873 ********
# 1 relations identified
# entities: Clint Barton => , Nobody, Nobody, Ultron, bastard
# relation: Nobody would know. Nobody. "The last I saw him, when Ultron was sitting on him. Uh...yeah, he'll be missed, that quick little bastard. I miss him already."
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 959 ********
# 957. Ultron:
# [sings] I got no strings, so I have fun. I'm not tied up to anyone. [as Barton is saving the boy, Costel, Ultron starts shooting at them but Pietro intervenes and takes the shots to save them]
#
# 958. Pietro Maximoff:
# You didn't see that coming. [Pietro falls to the ground as he dies, Wanda senses his death, causing her to fall in despair] [Hulk drops Natasha off onto the Helicarrier and then jumps onto the jet Ultron is on]
#
# => 959. Ultron:
# => Oh, for God's sake! [Hulk knocks Ultron out of the jet and he crashes inside a train; at the same time Barton delivers Costel safely to his sister onto the lifeboat, a man goes over to help him with his wound]
#
# 960. Clint Barton:
# No, no. I'm fine. [Barton lies down next to the dead body of Pietro] Oh, it's been a long day. [Wanda then finds the Ultron]
#
# 961. Ultron:
# Wanda, if you stay here, you'll die.
#
# ******** test model 1: line 959 ********
# 1 relations identified
# entities: Ultron => , Hulk, God, Barton, man, sister
# relation: Oh, for God's sake! [Hulk knocks Ultron out of the jet and he crashes inside a train; at the same time Barton delivers Costel safely to his sister onto the lifeboat, a man goes over to help him with his wound]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 608 ********
# 606. Nick Fury:
# I'm not the director of anybody. I'm just an old man, who cares very much about you.
#
# 607. Tony Stark:
# And I'm the man who killed the Avengers. I saw it. I didn't tell the team, how could I? I saw them all dead, Nick. I felt it. The whole world, too. It's because of me. I wasn't ready. I didn't do all I could.
#
# => 608. Nick Fury:
# => The Maximoff girl, she's working you, Stark. Playing on your fear.
#
# 609. Tony Stark:
# I wasn't tricked, I was shown. It wasn't a nightmare, it was my legacy. The end of the path I started us on.
#
# 610. Nick Fury:
# You've come up with some pretty impressive inventions, Tony. War isn't one of them.
#
# ******** test model 1: line 608 ********
# 1 relations identified
# entities: Nick Fury => , girl, Maximoff, Stark
# relation: The Maximoff girl, she's working you, Stark. Playing on your fear.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 264 ********
# 262. James Rhodes:
# I fly it right up to the General's palace, I drop it at his feet, I'm like, "Boom! You looking for this?" [the group laughs] [Steve and Thor are talking to an elderly man at the party]
#
# 263. Party Guest:
# I gotta have some of that!
#
# => 264. Thor:
# => Oh, no, no, no. See this, this was aged for a thousand years, in the barrels built from the wreck of Brunhilde's fleet, it's not meant for mortal men. [Thor pours the drink into two glasses and hands one to Steve]
#
# 265. Stan Lee:
# Neither was Omaha Beach, blondie. Stop trying to scare us. Come on.
#
# 266. Thor:
# Alright. [Thor pours some of the drink into the Stan Lee's glass; later Stan, looking extremely drunk is being carried off by two men]
#
# ******** test model 1: line 264 ********
# 1 relations identified
# entities: Thor => , Brunhilde, men, Steve
# relation: Oh, no, no, no. See this, this was aged for a thousand years, in the barrels built from the wreck of Brunhilde's fleet, it's not meant for mortal men. [Thor pours the drink into two glasses and hands one to Steve]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 397 ********
# 395. Ultron:
# I've come to save the world. But also, yeah. We'll move out right away. This is a start, but there's something we need to begin the real work.
#
# 396. Wanda Maximoff:
# [referring to Ultron's bots] All of these are... All of these are...
#
# => 397. Ultron:
# => Me. I have what the Avengers never will. Harmony. They're discordant, disconnected. Stark's already got them turning on each other. And when you get inside the rest of their heads...
#
# 398. Pietro Maximoff:
# Everyone's plan is not to kill them.
#
# 399. Ultron:
# And make them martyrs? You need patience. Need to see the big picture.
#
# ******** test model 1: line 397 ********
# 1 relations identified
# entities: Ultron => , Avengers, Stark, each other
# relation: Me. I have what the Avengers never will. Harmony. They're discordant, disconnected. Stark's already got them turning on each other. And when you get inside the rest of their heads...
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 483 ********
# 481. Natasha Romanoff:
# What if I fail? [we see a younger Natasha being trained to be an assassin]
#
# 482. Madame B:
# You never fail. [Steve sees himself in a 1940's dance hall when Peggy Carter comes up to him]
#
# => 483. Peggy Carter:
# => Are you ready for our dance? [back to Thor's vision in Asgard, he spots someone walking in a black cloak when Heimdall comes up to him his eyes blind and unseeing]
#
# 484. Heimdall:
# Is it him? Is that the first son of Odin?
#
# 485. Thor:
# Heimdall, your eyes?!
#
# ******** test model 1: line 483 ********
# 1 relations identified
# entities: Peggy Carter => , Thor, Heimdall, someone
# relation: Are you ready for our dance? [back to Thor's vision in Asgard, he spots someone walking in a black cloak when Heimdall comes up to him his eyes blind and unseeing]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 305 ********
# 303. Tony Stark:
# It's physics.
#
# 304. Bruce Banner:
# Physics! [Stark grasps Thor's hammer]
#
# => 305. Tony Stark:
# => Right, so, if I lift it, I...I then rule Asgard?
#
# 306. Thor:
# Yes, of course.
#
# 307. Tony Stark:
# I will be re-instituting Prima Nocta. [Stark tries to lift the hammer but fails] I'll be right back. [wearing his armored hand, Stark tries to lift the hammer again and fails] [wearing their armored hands, Stark and Rhodes both try to lift Thor's hammer]
#
# ******** test model 1: line 305 ********
# 1 relations identified
# entities: ['Tony Stark'] => Asgard
# relation:  rule
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 712 ********
# 710. Natasha Romanoff:
# Clint, can you draw out the guards?
#
# 711. Clint Barton:
# Let's find out.
#
# => 712. Natasha Romanoff:
# => [to the pedestrians in her way] Beep beep! [Barton manages to draw out the Iron Legions from the truck]
#
# 713. Clint Barton:
# Cap! Keep him occupied!
#
# 714. Steve Rogers:
# [as he continues his battle with Ultron] What do you think I've been doing? [as Natasha enters the truck the Iron Legions head back, pick up the truck and lift off]
#
# ******** test model 1: line 712 ********
# 1 relations identified
# entities: Natasha Romanoff => , pedestrians, Barton, Iron Legions
# relation: [to the pedestrians in her way] Beep beep! [Barton manages to draw out the Iron Legions from the truck]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 389 ********
# 387. Steve Rogers:
# Then we'll do that together, too. [Stark looks at him for a moment before turning away] Thor's right. Ultron's calling us out. And I'd like to find him before he's ready for us. The world's a big place. Let's start making it smaller. [the twins meet with Ultron in an empty building]
#
# 388. Wanda Maximoff:
# Talk. And if you are wasting our time...
#
# => 389. Ultron:
# => Did you know this church is in the exact center of the city? The elders decreed it so that everyone could be equally close to God. I like that. The geometry of belief. [Ultron is sat in a chair faced away from them] You're wondering why you can't look inside my head.
#
# 390. Wanda Maximoff:
# Sometimes it's hard. But sooner or later, every man shows himself. [Ultron stands and faces them revealing his new body. Wanda briefly looks shocked]
#
# 391. Ultron:
# Oh, I'm sure they do. But you needed something more than a man. That's why you let Stark take the scepter.
#
# ******** test model 1: line 389 ********
# 3 relations identified
# entities: Ultron => , elders, everyone, God
# relation: Did you know this church is in the exact center of the city? The elders decreed it so that everyone could be equally close to God. I like that. The geometry of belief. [Ultron is sat in a chair faced away from them] You're wondering why you can't look inside my head.
# category: 3
# entities: church => it
# relation:  decreed
# category: 5
# entities: church => that
# relation:  like
# category: 5
#
# how many are correctly identified? 2
#
# ******** line 816 ********
# 814. Vision:
# [walks past] That's true, he hates you the most.
#
# 815. Steve Rogers:
# Ultron knows we're coming. Odds are we'll be riding into heavy fire, and that's what we signed up for. But the people of Sokovia, they didn't. So our priority is getting them out. [Pietro speeds into the Sokovian police station]
#
# => 816. Pietro Maximoff:
# => We're under attack! Clear the city, now! [no one takes this seriously so Pietro returns, takes a shotgun and starts shooting in the air] Get off your asses. [Wanda uses her mind powers on the people of Sokovia to get them to evacuate]
#
# 817. Steve Rogers:
# All they want is to live their lives in peace, and that's not going to happen today. But we can do our best to protect them. And we can get the job done, and find out what Ultron's been building. We find Romanoff, and we clear the field. Keep the fight between us. Ultron thinks we're monsters and we're what's wrong with the world. This isn't just about beating him. It's about whether he's right.
#
# 818. Bruce Banner:
# [inside her cell Natasha hears Banner's voice] Natasha! Natasha!
#
# ******** test model 1: line 816 ********
# 1 relations identified
# entities: Pietro Maximoff => , no one, people, Wanda
# relation: We're under attack! Clear the city, now! [no one takes this seriously so Pietro returns, takes a shotgun and starts shooting in the air] Get off your asses. [Wanda uses her mind powers on the people of Sokovia to get them to evacuate]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 656 ********
# 654. Clint Barton:
# I'm gonna finish re-flooring that sunroom as soon as I get back.
#
# 655. Laura Barton:
# Yeah, and then you'll find another part of the house to tear apart.
#
# => 656. Clint Barton:
# => No. It's the last project. I promise. [he kisses her; later Laura watches them fly off in the Quinjet] [Thor and Selvig enter into a cave]
#
# 657. Erik Selvig:
# This is it. The Water of Sight.
#
# 658. Thor:
# In every realm, there's a reflection. If the water spirits accept me, I can return to my dream, and find what I missed.
#
# ******** test model 1: line 656 ********
# 1 relations identified
# entities: Clint Barton => , Laura, Thor, Selvig
# relation: No. It's the last project. I promise. [he kisses her; later Laura watches them fly off in the Quinjet] [Thor and Selvig enter into a cave]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 606 ********
# 604. Nick Fury:
# Look me in the eye and tell me you're going to shut him down.
#
# 605. Tony Stark:
# You're not the director of me.
#
# => 606. Nick Fury:
# => I'm not the director of anybody. I'm just an old man, who cares very much about you.
#
# 607. Tony Stark:
# And I'm the man who killed the Avengers. I saw it. I didn't tell the team, how could I? I saw them all dead, Nick. I felt it. The whole world, too. It's because of me. I wasn't ready. I didn't do all I could.
#
# 608. Nick Fury:
# The Maximoff girl, she's working you, Stark. Playing on your fear.
#
# ******** test model 1: line 606 ********
# 1 relations identified
# entities: Nick Fury => , man, director, anybody
# relation: I'm not the director of anybody. I'm just an old man, who cares very much about you.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 938 ********
# 936. Clint Barton:
# What about the core?
#
# 937. Wanda Maximoff:
# I'll protect it. It's my job.
#
# => 938. Wanda Maximoff:
# => [Steve, Barton and Natasha leave; to Pietro] Get the people on the boats.
#
# 939. Pietro Maximoff:
# I'm not going to leave you here.
#
# 940. Wanda Maximoff:
# I can handle this. [just then she blasts off an approaching robot] Come back for me when everyone else is off, not before.
#
# ******** test model 1: line 938 ********
# 1 relations identified
# entities: Wanda Maximoff => , Steve, Barton, Pietro, Natasha, people
# relation: [Steve, Barton and Natasha leave; to Pietro] Get the people on the boats.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 261 ********
# 259. Sam Wilson:
# You find a place in Brooklyn yet?
#
# 260. Steve Rogers:
# I don't think I can afford a place in Brooklyn.
#
# => 261. Sam Wilson:
# => Well, home is home, you know? [Rhodes is telling the same story he told Stark and Thor to a group of women at the party]
#
# 262. James Rhodes:
# I fly it right up to the General's palace, I drop it at his feet, I'm like, "Boom! You looking for this?" [the group laughs] [Steve and Thor are talking to an elderly man at the party]
#
# 263. Party Guest:
# I gotta have some of that!
#
# ******** test model 1: line 261 ********
# 3 relations identified
# entities: Sam Wilson => , Rhodes, women, Stark, Thor
# relation: Well, home is home, you know? [Rhodes is telling the same story he told Stark and Thor to a group of women at the party]
# category: 3
# entities: home => story
# relation:  telling the same
# category: 5
# entities: home => Stark
# relation:  told
# category: 5
#
# how many are correctly identified? 2
#
# ******** line 106 ********
# 104. narrator:
# inside the secret passageway Stark finds a room with recovered artifacts from the Battle of New York, including a gigantic Chitauri leviathan and some of his Iron Man scrapped armor, he then spots the scepter
#
# 105. Tony Stark:
# Thor, I got eyes on the prize.
#
# => 106. narrator:
# => Wanda creeps up behind him and uses her powers on him, suddenly the Chitauri comes to life, then Stark sees the rest of the Avengers team are all dead, he goes over to Steve's body to check his pulse when Steve suddenly grabs him
#
# 107. Steve Rogers:
# You could've saved us.
#
# 108. narrator:
# Steve dies but Stark continues to hear Steve's voice in his head
#
# ******** test model 1: line 106 ********
# 1 relations identified
# entities: narrator => , Stark, Wanda, team, Steve
# relation: Wanda creeps up behind him and uses her powers on him, suddenly the Chitauri comes to life, then Stark sees the rest of the Avengers team are all dead, he goes over to Steve's body to check his pulse when Steve suddenly grabs him
# category: 3
#
# how many are correctly identified? 1
#
# ******** test results ********
# model 1: precision = 0.51 (34/67 correct)

# %%
df_dict['df_8']['relations'] = df_dict['df_8'].apply(lambda x:extract_relation_categories(x), axis=1)
REEval([df_dict['df_8']])
#13/64
# Out:
# ******** line 737 ********
# 735. narrator:
# MAY collapses.
#
# 736. DOCTOR:
# Crash cart! STAT!
#
# => 737. narrator:
# => The Detective pulls PETER gently away. The STAFF works on MAY.
#
# 738. DETECTIVE:
# Let the medics handle it. (pause) Look, if it makes you feel any better. We're gonna nail this guy. He crashed his getaway car. We got him trapped in a warehouse on Jackson.
#
# 739. NURSE:
# (to Peter) She's alright. She just fainted. We'll have to check her for symptoms of shock. If you want to wait, you can get some coffee on the third floor.
#
# ******** test model 1: line 737 ********
# 1 relations identified
# entities: narrator => , Detective, PETER, STAFF
# relation: The Detective pulls PETER gently away. The STAFF works on MAY.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 528 ********
# 526. CRUSHER:
# Oh, well, I don't know what happened to me tonight... (measures his muscles) I really don't know...
#
# 527. REISS:
# I know... you lost. Big man you lost to the Amazing Spider-Man.
#
# => 528. narrator:
# => EXT. CITY STREET - NEAR A HOSPITAL - DAY WE ARE TIGHT ON A NEW YORK JOURNAL TRUCK. On its SIDE BANNER is a PICTURE of SPIDER-MAN'S face. Headline: "Who is he? Mega-Smash Hits MTV!" The TRUCK pulls away and we see PETER, LIZ, HARRY and KIM standing on the sidewalk waiting to cross. PETER is rocking on his heels and smirking.
#
# 529. PETER:
# (indicating truck) You know who that is?
#
# 530. LIZ:
# (walking ahead) Yeah... he's some clown we saw on TV last night... boy does Flash think he's hot.
#
# ******** test model 1: line 528 ********
# 1 relations identified
# entities: narrator => , PETER, KIM, LIZ, HARRY
# relation: EXT. CITY STREET - NEAR A HOSPITAL - DAY WE ARE TIGHT ON A NEW YORK JOURNAL TRUCK. On its SIDE BANNER is a PICTURE of SPIDER-MAN'S face. Headline: "Who is he? Mega-Smash Hits MTV!" The TRUCK pulls away and we see PETER, LIZ, HARRY and KIM standing on the sidewalk waiting to cross. PETER is rocking on his heels and smirking.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 143 ********
# 141. PETER:
# Check.
#
# 142. LIZ:
# And besides, he's not all bad.
#
# => 143. narrator:
# => PETER looks at FLASH who's a few LOCKERS down. FLASH has taken a FOOTBALL from his LOCKER and is spinning it on his finger with great joy and concentration.
#
# 144. PETER:
# You don't get nicknamed Flash because you're a rocket scientist, Liz.
#
# 145. LIZ:
# Give it up, Parker. You'd die for a nickname like Flash.
#
# ******** test model 1: line 143 ********
# 1 relations identified
# entities: FLASH => FOOTBALL
# relation:  taken a
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 86 ********
# 84. narrator:
# LIZ smashes at the WINDOW, but this is an inner city school and the WINDOWS are covered by STEEL GATES. Liz wraps her fingers in the GATE.
#
# 85. LIZ:
# (out at the street) Help! Help me!
#
# => 86. narrator:
# => Outside the WINDOW the air is clear and people come and go. Some are stopping to look up at the girl on the second floor who screams (but they can't hear, of course) down at them as the FLAMES close in behind her. PETER comes flying in with a FIRE EXTINGUISHER. He fumbles with it. FLASH pushes Thorkel, grabs the extinguisher away from him with a scowl of disdain. LIZ turns to face the FLAMES. Suddenly there is an eruption of CO2 CLOUDS and the roar of a FIRE EXTINGUISHER. The FLAMES are beaten down enough for her to leap out. FLASH is there, holding the EXTINGUISHER. People CHEER.
#
# 87. PETER:
# Thanks for your help Flash.
#
# 88. FLASH:
# No problem wimp.
#
# ******** test model 1: line 86 ********
# 1 relations identified
# entities: narrator => , Some, people, girl, PETER, Thorkel, People, LIZ
# relation: Outside the WINDOW the air is clear and people come and go. Some are stopping to look up at the girl on the second floor who screams (but they can't hear, of course) down at them as the FLAMES close in behind her. PETER comes flying in with a FIRE EXTINGUISHER. He fumbles with it. FLASH pushes Thorkel, grabs the extinguisher away from him with a scowl of disdain. LIZ turns to face the FLAMES. Suddenly there is an eruption of CO2 CLOUDS and the roar of a FIRE EXTINGUISHER. The FLAMES are beaten down enough for her to leap out. FLASH is there, holding the EXTINGUISHER. People CHEER.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 781 ********
# 779. OCK:
# (reading dials and numbers) Amperage, okay. Flux, 14. Negative variable differential... good enough.
#
# 780. narrator:
# He shuts it down. The WHINE whirs down.
#
# => 781. OCK:
# => Okey, dokey... now all I need is Parker's data. Where the hell is Weiner? Damn it... I can't trust anybody. (throws his Waldo in the air) Only you, my babies... only you can I trust... Okay... If I have to do everything myself... I'm going to do it. (to his equipment) I'll be back... my babies... my new babies!
#
# 782. narrator:
# OCK hides the WALDOS under his coat and leaves the room. INT. PETER PARKER'S APARTMENT - NIGHT There is more EQUIPMENT than before. PETER is deep at work. His SPIDER-MAN UNIFORM hangs on the WALL. There is a knock at the DOOR.
#
# 783. LIZ:
# Hey, Peter! Are you finished with my computer yet? I got a paper too, you know...
#
# ******** test model 1: line 781 ********
# 1 relations identified
# entities: OCK => , babies, Okey, Parker, anybody, Weiner, babies
# relation: Okey, dokey... now all I need is Parker's data. Where the hell is Weiner? Damn it... I can't trust anybody. (throws his Waldo in the air) Only you, my babies... only you can I trust... Okay... If I have to do everything myself... I'm going to do it. (to his equipment) I'll be back... my babies... my new babies!
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 616 ********
# 614. WEINER:
# All right... boss please let go... P L E A S E ...
#
# 615. OCK:
# Just get it, Weiner. I'm running out of time. If you fail me again, you won't have to concern yourself with money anymore... DO YOU GET ME CLOWN?!
#
# => 616. narrator:
# => WEINER croaks his assent. INT. CAFETERIA - NIGHT It is all dressed up for a party: LIGHTS, STREAMERS, GLITTER BALL, the WORKS! HARRY is dressed as a SPACEMAN; PETER wears his regular clothes.
#
# 617. HARRY:
# You should have worn a costume. I told you to wear a costume.
#
# 618. PETER:
# It's... embarrassing.
#
# ******** test model 1: line 616 ********
# 1 relations identified
# entities: narrator => , WEINER, assent, PETER, SPACEMAN, HARRY
# relation: WEINER croaks his assent. INT. CAFETERIA - NIGHT It is all dressed up for a party: LIGHTS, STREAMERS, GLITTER BALL, the WORKS! HARRY is dressed as a SPACEMAN; PETER wears his regular clothes.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 1227 ********
# 1225. FLASH:
# Liz, don't... Liz come back... come back! LIZ runs inside. They run after her. A BOLT OF ELECTRICITY flashes across the doorway, stopping them.
#
# 1226. narrator:
# INT. THE CONTROL ROOM - NIGHT The PLANETS are playing on the COMPUTER SCREEN. Things in the room begin to rise, weightless. The ENERGY STORM is brewing!
#
# => 1227. OCK:
# => Okey, dokey!! My energy storm has started. My Anti-Force is on! History is being made... Spider-Man, Rosomorf cheer up friends... we're on our way to the unknown cosmos... we three are about to visit heaven... real Gods heaven.
#
# 1228. ROZ:
# (sees the sky through the window) Spider-Man! The Conjunction! It's happening!
#
# 1229. narrator:
# EXT. THE SKY - STRANGE COLORS - NIGHT The CONJUNCTION is now happening. INSERT: Surreal DIALS spin madly. INT. SCIENCE CENTER - NIGHT LIZ runs into a HALLWAY gone berserk. Stuff is flying everywhere. TILES pull from the WALLS and crash to the ceiling.
#
# ******** test model 1: line 1227 ********
# 1 relations identified
# entities: OCK => , Okey, friends, Rosomorf
# relation: Okey, dokey!! My energy storm has started. My Anti-Force is on! History is being made... Spider-Man, Rosomorf cheer up friends... we're on our way to the unknown cosmos... we three are about to visit heaven... real Gods heaven.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 357 ********
# 355. ROZ:
# (filtered through face mask) Take it easy. Take it easy with him.
#
# 356. THORKEL:
# Take him away and never bring him back!
#
# => 357. narrator:
# => Now we see ROZ and THORKEL following 2 GUARDS carrying OCK in a stretcher. They all wear RADIATION SUITS. A waldo sneaks out from under the sheet and hits Thorkel, as fast as lightning. He falls back. He's covered with a SHEET and attached to LIFE SUPPORT EQUIPMENT. Octavius moans.
#
# 358. THORKEL:
# What was that?
#
# 359. ROZ:
# What was what?
#
# ******** test model 1: line 357 ********
# 1 relations identified
# entities: narrator => , ROZ, Thorkel, Octavius
# relation: Now we see ROZ and THORKEL following 2 GUARDS carrying OCK in a stretcher. They all wear RADIATION SUITS. A waldo sneaks out from under the sheet and hits Thorkel, as fast as lightning. He falls back. He's covered with a SHEET and attached to LIFE SUPPORT EQUIPMENT. Octavius moans.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 254 ********
# 252. OCK:
# (to Thorkel) You're denying me access to my cyclotron?!
#
# 253. THORKEL:
# You bet.
#
# => 254. narrator:
# => OCK glares back and forth between the TWO MEN, the WORKER, and WEINER. Then he pulls BACK the RED POWER THROTTLE. The WHINE descends. The WALDOS pull back and dangle from their panel. The WHINE dies.
#
# 255. OCK:
# (contemplating) Okey, dokey... just give me till tomorrow. I want to clean up my papers. Tomorrow... Ha... Tomorrow you can have this room...
#
# 256. ROZ:
# Oh... well Thorkel... few more hours won't make a difference.
#
# ******** test model 1: line 254 ********
# 1 relations identified
# entities: narrator => , WEINER, MEN, WORKER
# relation: OCK glares back and forth between the TWO MEN, the WORKER, and WEINER. Then he pulls BACK the RED POWER THROTTLE. The WHINE descends. The WALDOS pull back and dangle from their panel. The WHINE dies.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 0 ********
# => 0. narrator:
# => FADE IN: INT. PROFESSOR OCK"S PRIVATE PHYSICS LABORATORY, THE CYCLOTRON ROOM (CREDIT SEQUENCE) - DAY A mighty WARNING KLAXON assaults our ears. A FLASHING RED WARNING LIGHT stabs our eyes. Several DIALS go into the RED. A hand pushes aside a YELLOW THERMOS and pushes forward a RED POWER THROTTLE. We hear the WHINING UP of a cyclotron. A DIGITAL DIAL climbs to "5% POWER." A SPIDER crawls across a DIAL. Begin OPENING CREDITS. THE CYCLOTRON ROOM is in an old basement full of peeling paint and plumbing wrapped with TAPE. Leaks are here and there. COBWEBS are all around. DOCTOR OTTO OCTAVIUS (OCK) is a strong but strange featured man in his mid-fifties. His assistant, WEINER, hovers nearby looking on. He's open mouthed with a mindless kind of curiosity. WEINER is a local, small-time hood hired by OCK to circumvent the school administration and to "procure" whatever OCK needs for his experiments. He shades his eyes against a searing BLUE-WHITE BEAM that erupts from the WINDOW. THE ROOM IS DIVIDED INTO A CONTROL ROOM AND THE EXPERIMENT CHAMBERS.
#
# 1. WEINER:
# Whoa, whoa, whoa... what's that?
#
# 2. narrator:
# With a WHOOSH, the WINDOW EXPLODES, showering the TWO with shards of GLASS, and throwing them to the floor.
#
# ******** test model 1: line 0 ********
# 2 relations identified
# entities: narrator => , DOCTOR OTTO OCTAVIUS, WEINER, EXPERIMENT CHAMBERS
# relation: FADE IN: INT. PROFESSOR OCK"S PRIVATE PHYSICS LABORATORY, THE CYCLOTRON ROOM (CREDIT SEQUENCE) - DAY A mighty WARNING KLAXON assaults our ears. A FLASHING RED WARNING LIGHT stabs our eyes. Several DIALS go into the RED. A hand pushes aside a YELLOW THERMOS and pushes forward a RED POWER THROTTLE. We hear the WHINING UP of a cyclotron. A DIGITAL DIAL climbs to "5% POWER." A SPIDER crawls across a DIAL. Begin OPENING CREDITS. THE CYCLOTRON ROOM is in an old basement full of peeling paint and plumbing wrapped with TAPE. Leaks are here and there. COBWEBS are all around. DOCTOR OTTO OCTAVIUS (OCK) is a strong but strange featured man in his mid-fifties. His assistant, WEINER, hovers nearby looking on. He's open mouthed with a mindless kind of curiosity. WEINER is a local, small-time hood hired by OCK to circumvent the school administration and to "procure" whatever OCK needs for his experiments. He shades his eyes against a searing BLUE-WHITE BEAM that erupts from the WINDOW. THE ROOM IS DIVIDED INTO A CONTROL ROOM AND THE EXPERIMENT CHAMBERS.
# category: 3
# entities: CYCLOTRON ROOM => eyes
# relation:  shades his
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 184 ********
# 182. PETER:
# Well... I'm sort of working with Professor Rosomorf and he suggested we kind of keep it between us. He thinks that my theory is... well, I don't know...
#
# 183. OCK:
# (to himself) The scoundrel... (turns angry) I want to see that data, Peter!
#
# => 184. PETER:
# => But Professor Octavius... if I knew you were interested... sorry, I've already given it to... Professor Rosomorf, and he is after all the head of our Physics Department... and I couldn't...
#
# 185. narrator:
# OCK turns sweet again. He smiles too broadly.
#
# 186. OCK:
# Well, I'm certain something can be worked out. Run along, young man.
#
# ******** test model 1: line 184 ********
# 1 relations identified
# entities: PETER => , Octavius, Rosomorf, head
# relation: But Professor Octavius... if I knew you were interested... sorry, I've already given it to... Professor Rosomorf, and he is after all the head of our Physics Department... and I couldn't...
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 823 ********
# 821. OCK:
# (gone to far) Oh, I wouldn't say shocking...
#
# 822. LIZ:
# I would!
#
# => 823. narrator:
# => She sticks his WALDO in the ELECTRIC WALL SOCKET behind the COMPUTER! The CURRENT sizzles through him and he leaps up, WALDOS akimbo, like the "cartoon cat." LIZ runs out the door. OCK extricates himself from the current and gives chase. INT. HALLWAY - NIGHT LIZ burst from the DOOR.
#
# 824. LIZ:
# Peter...!
#
# 825. narrator:
# She looks both ways for PETER, doesn't see him, and takes off! OCK bursts from the doorway and runs off after LIZ. EXT. THE STREET - NIGHT LIZ running as fast as she can, but OCK is gaining quickly. EXT. PETER PARKER'S APARTMENT - NIGHT A TAXI drives up and disgorges PETER.
#
# ******** test model 1: line 823 ********
# 1 relations identified
# entities: ['Mutant'] => WALDO
# relation:  sticks his
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 535 ********
# 533. HARRY:
# Wrestling is all bluff. Do you really believe this little guy in a stupid Spider-Man suit beat the Crusher?
#
# 534. LIZ:
# Hey, we better rush... visiting hours will be over soon.
#
# => 535. narrator:
# => INT. HOSPITAL CORRIDOR & ROOM - DAY The NURSE leads PETER and LIZ and HARRY into the room.
#
# 536. NURSE:
# Doctor Octavius? You have visitors. Doctor Octavius?
#
# 537. narrator:
# We hold for a beat. When LIZ takes a step forward to look around we expect the worst. But nothing grabs her. PETER sees a pile of PLASTER on the floor. He looks up and sees the hole in the ceiling. LIZ and HARRY look up too. OCK is not there.
#
# ******** test model 1: line 535 ********
# 1 relations identified
# entities: narrator => , NURSE, PETER, LIZ, HARRY
# relation: INT. HOSPITAL CORRIDOR & ROOM - DAY The NURSE leads PETER and LIZ and HARRY into the room.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 1013 ********
# 1011. narrator:
# Several PASSENGERS climb out of the WINDOWS of the TRAIN or pry open the DOORS.
#
# 1012. WOMAN:
# What are you doing here? Get out of here! Get out of here!
#
# => 1013. narrator:
# => EXT. THE STREET - NIGHT A CROWD has gathered to gawk and point. They look up and we see their POV. The MIDDLE CAR of the TRAIN is simply "embedded" in the HIGH-RISE, its rear sticking out of the building fifteen stories up. From its COUPLING dangles the LAST CAR. INT. MIDDLE CAR - NIGHT The car is bisected in the middle by the fused brick and glass of the WALL of the building. PASSENGERS on the outside of the WALL press their faces to the GLASS and pound for help. ROZ comes to the aid of a MOTHER with TWO CHILDREN. EXT. THE STREET - NIGHT The CROWD sees something else. Swinging high in the sky is your friendly neighborhood SPIDER-MAN. The COUPLE and TWO DRIVERS argue about what this means.
#
# 1014. WOMAN:
# It's Spider-Man!
#
# 1015. TRUCK DRIVER #1:
# Get outa here, you bum!
#
# ******** test model 1: line 1013 ********
# 1 relations identified
# entities: narrator => , THE STREET - NIGHT A CROWD, PASSENGERS, COUPLE, DRIVERS, MOTHER, CHILDREN, ROZ
# relation: EXT. THE STREET - NIGHT A CROWD has gathered to gawk and point. They look up and we see their POV. The MIDDLE CAR of the TRAIN is simply "embedded" in the HIGH-RISE, its rear sticking out of the building fifteen stories up. From its COUPLING dangles the LAST CAR. INT. MIDDLE CAR - NIGHT The car is bisected in the middle by the fused brick and glass of the WALL of the building. PASSENGERS on the outside of the WALL press their faces to the GLASS and pound for help. ROZ comes to the aid of a MOTHER with TWO CHILDREN. EXT. THE STREET - NIGHT The CROWD sees something else. Swinging high in the sky is your friendly neighborhood SPIDER-MAN. The COUPLE and TWO DRIVERS argue about what this means.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 303 ********
# 301. OCK:
# Present maximum anti-force power to date is 38 percent of theoretical limit. I have patched in the variable particle-wave accelerator... (shrugs) I will now try to reach 50% power... (big breath) And if your paper has any value... I can use it to get the power I'm missing to create the anti-force, to break through and beat any other form of power in our or any other universe, capish!
#
# 302. PETER:
# Sorry, Professor, I can't do it. I gave my word to Professor Rosomorf.
#
# => 303. narrator:
# => OCK is angry... Ock now sees the SPIDER. He shoots out a WALDO to try and crush it but the SPIDER is too fast. The WALDO slams against the wall of the chamber. He starts to push every button or switch in sight. A deafening whining starts. An URGENT WARNING TONE causes OCK to look at the "Relative Gravity" DIAL. It is at "4.999999KG" but suddenly the numbers start to tumble rapidly. INSERT: The glowing 5KG WEIGHT. INSERT: The POWER DIAL inches toward 50% POWER!
#
# 304. OCK:
# (screaming) 50 percent... anti-force... 50 percent... that's all I'm missing! Parker, we can be rich together!
#
# 305. PETER:
# Sorry... I'd better go now.
#
# ******** test model 1: line 303 ********
# 1 relations identified
# entities: ['Hank'] => WALDO
# relation:  shoots out a
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 957 ********
# 955. narrator:
# A LARGE DIGITAL DISPLAY reads, "13:00:03." The last seconds count down to, "12:59:59!"
#
# 956. OCK:
# (playing the computer) Okey, dokey. Now let's see if I have enough power to drive this beast.
#
# => 957. narrator:
# => He starts hitting KEYS on his COMPUTER. INT. PETER PARKER'S APARTMENT - NIGHT PETER is working on LIZ'S COMPUTER. There is a KNOCK at his brand new, unpainted DOOR. He hurries to it and pulls the KNOB so quickly (forgetting his own strength) that the whole assembly comes off in his hand.
#
# 958. PETER:
# (pulling Harry aside) I gotta remember to have that fixed. (opens the door) There you are, I've been looking for you all over town.
#
# 959. HARRY:
# What happened?
#
# ******** test model 1: line 957 ********
# 1 relations identified
# entities: narrator => , PETER PARKER, NIGHT PETER, LIZ
# relation: He starts hitting KEYS on his COMPUTER. INT. PETER PARKER'S APARTMENT - NIGHT PETER is working on LIZ'S COMPUTER. There is a KNOCK at his brand new, unpainted DOOR. He hurries to it and pulls the KNOB so quickly (forgetting his own strength) that the whole assembly comes off in his hand.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 158 ********
# 156. PETER:
# (embarrassed) Hi...
#
# 157. LIZ:
# We're going to the Student Reunion Meeting. You coming?
#
# => 158. narrator:
# => Peter looks at KIM. Wow. Then he looks at LIZ who's adjusting herself in a small MIRROR. HARRY jabs him in the ribs. Yeah, yeah!
#
# 159. PETER:
# (frustrated) I can't... I gotta go over to the Daily Bugle. I'm trying to sell some photos.
#
# 160. KIM:
# Soooh, a photographer...?
#
# ******** test model 1: line 158 ********
# 1 relations identified
# entities: narrator => , Peter, LIZ, KIM, HARRY
# relation: Peter looks at KIM. Wow. Then he looks at LIZ who's adjusting herself in a small MIRROR. HARRY jabs him in the ribs. Yeah, yeah!
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 1082 ********
# 1080. narrator:
# A WALDO smashes through the WINDSHIELD but misses SPIDEY. OCK leaps from the CAR.
#
# 1081. OCK:
# (on the run) You're a doomed bug, Wall Crawler. I've no time to waste on you now.
#
# => 1082. narrator:
# => EXT. STREET - NIGHT OCK runs through HONKING TRAFFIC. SPIDER-MAN leaps from CAR to CAR. OCK turns to see SPIDER-MAN leap to a LIMO at the curb. OCK turns tail and runs down an alley. A FEMALE COP pops out of a DOORWAY. Her partner, a BIG, YOUNG COP, pulls his GUN.
#
# 1083. FEMALE COP:
# (gun poised) Alright! Freeze! Up against the wall and spread 'em
#
# 1084. narrator:
# OCK complies. He raises his hands... and spreads the WALDOS to full extension! The BIG COP screams and faints. The little FEMALE COP'S eyes POP. OCK swats the GUN from her hand. He starts to choke her. SPIDEY comes swinging to the rescue. He lands on the ROOF nearby.
#
# ******** test model 1: line 1082 ********
# 1 relations identified
# entities: narrator => , FEMALE COP, partner, YOUNG COP
# relation: EXT. STREET - NIGHT OCK runs through HONKING TRAFFIC. SPIDER-MAN leaps from CAR to CAR. OCK turns to see SPIDER-MAN leap to a LIMO at the curb. OCK turns tail and runs down an alley. A FEMALE COP pops out of a DOORWAY. Her partner, a BIG, YOUNG COP, pulls his GUN.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 231 ********
# 229. PETER:
# No.
#
# 230. MAY:
# Then come on.
#
# => 231. narrator:
# => INT. LARGE COMPUTER LAB - NIGHT It is dark and empty except for COMPUTERS. Sitting at it, lit by the GLOW of its screen, is SOLOMON ROSOMORF (ROZ). As he works, a DOOR opens behind him. Someone walks quietly through the LAB. ROSOMORF keeps working. The intruder approaches...
#
# 232. THORKEL:
# (at his ear) Professor Rosomorf, what happened here?
#
# 233. ROZ:
# Someone tried to rob me of some paper... I suspect they were looking for that one.
#
# ******** test model 1: line 231 ********
# 1 relations identified
# entities: narrator => , ROZ, Someone, ROSOMORF
# relation: INT. LARGE COMPUTER LAB - NIGHT It is dark and empty except for COMPUTERS. Sitting at it, lit by the GLOW of its screen, is SOLOMON ROSOMORF (ROZ). As he works, a DOOR opens behind him. Someone walks quietly through the LAB. ROSOMORF keeps working. The intruder approaches...
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 713 ********
# 711. narrator:
# EXT. THE TRUCK - NIGHT SPIDEY stares at the lettering on the side of the TRUCK. It says, "Victory Sporting Goods."
#
# 712. SPIDER-MAN:
# (a thought) Sporting goods...
#
# => 713. narrator:
# => INT. BEN AND MAY'S DINING ROOM - NIGHT BEN comes in quietly. He looks around. He opens a closet. Nothing. He hears a CRASH. He wheels. A SHADOWY FIGURE runs by a doorway! BEN takes off like a shot! INT. BEN AND MAY'S HOUSE - NIGHT BEN runs through the rooms. INT. BEN AND MAY'S FAMILY ROOM - NIGHT BEN flies in and goes right to the RIFLE on the wall. WE hear WEINER clattering around the house in the background as BEN goes to a drawer and pulls out a BOX of BULLETS. He begins to fight the BULLETS into the RIFLE. WEINER comes flying in and tackles him. They fall to the floor, four hands on the RIFLE. They scuffle.
#
# 714. WEINER:
# All I want it the kid's computer crap!
#
# 715. BEN:
# Let go before I blow your brain's out.
#
# ******** test model 1: line 713 ********
# 1 relations identified
# entities: narrator => , BEN, MAY, NIGHT BEN, NIGHT BEN, WEINER
# relation: INT. BEN AND MAY'S DINING ROOM - NIGHT BEN comes in quietly. He looks around. He opens a closet. Nothing. He hears a CRASH. He wheels. A SHADOWY FIGURE runs by a doorway! BEN takes off like a shot! INT. BEN AND MAY'S HOUSE - NIGHT BEN runs through the rooms. INT. BEN AND MAY'S FAMILY ROOM - NIGHT BEN flies in and goes right to the RIFLE on the wall. WE hear WEINER clattering around the house in the background as BEN goes to a drawer and pulls out a BOX of BULLETS. He begins to fight the BULLETS into the RIFLE. WEINER comes flying in and tackles him. They fall to the floor, four hands on the RIFLE. They scuffle.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 1020 ********
# 1018. narrator:
# This is the DRIVER of a DAILY BUGLE truck carrying the historically famous Bugle headline, "Spider-Man - Threat or Menace?"
#
# 1019. MAN:
# Go Spidey! Go!
#
# => 1020. narrator:
# => INT. LAST CAR - NIGHT It's nearly vertical! People are tumbled over each other. The scared TEENAGER is tearing at the door. The SKINNY GIRL screams in a mechanical way. The DOOR opens. He nearly falls! The SKINNY GIRL screams again. He manages to get back inside. She looks at him, safe now. But she screams again anyway. ROZ struggles to right himself against a pole. A BAG OF GROCERIES goes sliding past him. It continues downward and out the OPEN DOOR. INSERT: The BAG tumbles down through the air. Down, down, and down... INT. MIDDLE CAR - NIGHT SPIDEY'S face appears in the WINDOW upside down.
#
# 1021. SPIDER-MAN:
# Hello, everybody...
#
# 1022. narrator:
# He slides the WINDOW down and flips inside. He walks through the parting PASSENGERS to the BUILDING WALL. He feels it.
#
# ******** test model 1: line 1020 ********
# 1 relations identified
# entities: narrator => , SKINNY GIRL, each other, People, ROZ, TEENAGER
# relation: INT. LAST CAR - NIGHT It's nearly vertical! People are tumbled over each other. The scared TEENAGER is tearing at the door. The SKINNY GIRL screams in a mechanical way. The DOOR opens. He nearly falls! The SKINNY GIRL screams again. He manages to get back inside. She looks at him, safe now. But she screams again anyway. ROZ struggles to right himself against a pole. A BAG OF GROCERIES goes sliding past him. It continues downward and out the OPEN DOOR. INSERT: The BAG tumbles down through the air. Down, down, and down... INT. MIDDLE CAR - NIGHT SPIDEY'S face appears in the WINDOW upside down.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 1247 ********
# 1245. narrator:
# INT. JAMESON'S OFFICE - NIGHT He's looking out his window seeing the University's Lab Building flying by. Up and up toward the sky.
#
# 1246. JAMESON:
# (shouting) Tear out the front page! Change the headline... The biggest news is happening right now... we need photos... a camera... get me a camera...!
#
# => 1247. narrator:
# => EXT. SKY - NIGHT A very long shot of the SCIENCE CENTER rising into the CLOUDS. INT. AUNT MAY'S BEDROOM - NIGHT She pulls aside a CURTAIN and watches the SCIENCE CENTER rise. INT. CONTROL ROOM - NIGHT OCK works the COMPUTER as the CONSOLE sends up SHOWERS of SPARKS. He glances at the "BULLET" which now PULSES. The COUNTDOWN CLOCK at "00:04:18".
#
# 1248. ROZ:
# Where is it going Otto?
#
# 1249. OCK:
# Other worlds, Roz, other times, other dimensions, who knows? Who cares?
#
# ******** test model 1: line 1247 ********
# 3 relations identified
# entities: SCIENCE CENTER => CURTAIN
# relation:  pulls aside a
# category: 5
# entities: SCIENCE CENTER => COMPUTER
# relation:  works the
# category: 5
# entities: SCIENCE CENTER => SHOWERS
# relation:  sends up
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 1294 ********
# 1292. SPIDER-MAN:
# Hold tight, Liz, hold tight!
#
# 1293. narrator:
# OCK drops calmly, beatifically, to the floor of the room. He moves slowly, under his own power, into the LIGHT.
#
# => 1294. OCK:
# => (spaced out) You cut my power... there's too little power... It's so tiny... so tiny... there's only space... for me. But I've done it, Spider-Man. I have broken through... I've broken through!
#
# 1295. LIZ:
# Don't do it, Dr. Octavius!
#
# 1296. OCK:
# Okey... dokey... Now that's what I call an experiment!!!
#
# ******** test model 1: line 1294 ********
# 2 relations identified
# entities: space => it
# relation:  done
# category: 5
# entities: space => Man
# relation:  done it , Spider -
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 13 ********
# 11. LIZ:
# (teasing softly) How'm I doing what?
#
# 12. HARRY:
# Peter! Peter! Wait up!
#
# => 13. narrator:
# => HARRY is the school nerd. A quirky kid who, like PETER, can be a little backward around girls, especially pretty ones like Liz.
#
# 14. HARRY:
# (to Liz) Would you, uh... excuse us for a minute?
#
# 15. narrator:
# Despite PETER'S protesting body language, HARRY pulls him away like a conspirator.
#
# ******** test model 1: line 13 ********
# 1 relations identified
# entities: narrator => , HARRY, kid, PETER, girls, Liz
# relation: HARRY is the school nerd. A quirky kid who, like PETER, can be a little backward around girls, especially pretty ones like Liz.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 1116 ********
# 1114. narrator:
# SPIDEY'S peering in from a HOLE in the ROOF.
#
# 1115. OCK:
# Insect! I am going to squash you to death... Once I lay my Waldos on your skinny bones...
#
# => 1116. narrator:
# => OCK hurls a DRUM at SPIDEY. It erupts in a sizzle of LIQUID and GAS. Then the SIX-ARMED FIEND runs for the door with his SL 270. EXT. THE SHACK - NIGHT OCK comes flying out and SPIDER-MAN grabs a WALDO. SPIDEY does a back flip and whips OCK so hard the WALDO snaps off! OCK recoils it and reacts in horror. With a roar, OCK attacks SPIDER-MAN. They battle as SUPER-ADVERSARIES. OCK gains the upper hand and tosses SPIDEY into a pile of RUSTING DRUMS. A GAS envelopes SPIDER-MAN and he begins coughing. EXT. THE DUMP - NIGHT OCK'S WALDOS are coiled around SPIDER-MAN'S neck as the WEB SLINGER is dragged through the dump. His WHITE EYES narrow and blink. There is a capped WELL behind a WARNING SIGN. OCK tears off the CAP and then hurls the groggy SPIDEY down the WELL.
#
# 1117. OCK:
# Goodbye, Spider-Man!
#
# 1118. narrator:
# INT. THE WELL - NIGHT SPIDEY falls. He cannot grab onto the slimy WALLS. At the bottom of the foul pit is a bubbling BLUE luminescent POOL. SPIDEY claws frantically at the WALLS.
#
# ******** test model 1: line 1116 ********
# 5 relations identified
# entities: MAN => WALDO
# relation:  grabs a
# category: 5
# entities: WALDO => it
# relation:  recoils
# category: 5
# entities: WALDO => MAN
# relation:  attacks SPIDER -
# category: 5
# entities: WALDO => hand
# relation:  gains the upper
# category: 5
# entities: WALDO => SPIDEY
# relation:  hurls the groggy
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 1103 ********
# 1101. FLASH:
# Why is he going to New Jersey, and who is it in that shitty red car...
#
# 1102. LIZ:
# Don't you recognize him... it's Ock!
#
# => 1103. SPIDER-MAN:
# => New Jersey has the largest toxic waste dump in the world.
#
# 1104. FLASH:
# What does he want with toxic waste?
#
# 1105. SPIDER-MAN:
# He's looking for Plutonium, my dear... The car has to slow down... it's in a traffic jam.
#
# ******** test model 1: line 1103 ********
# 1 relations identified
# entities: New Jersey => dump
# relation:  has the largest toxic waste
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 1318 ********
# 1316. narrator:
# LIZ swings across like TARZAN and SPIDEY gathers her in on the LEDGE. She does a comic "phew" and the LEDGE buckles beneath them but holds. SPIDER-MAN tries to open the door, but it's stuck.
#
# 1317. LIZ:
# The door is stuck.
#
# => 1318. narrator:
# => SPIDER-MAN bends his back to the task. It take all his strength, but with a comic AAAAARGGHH! He bends the DOOR open. EXT. FIRE DOOR - NIGHT They burst out onto the ROCK FOUNDATION of the building. New York is rushing up to meet them. The WIND created by their fall buffets them. The HELICOPTERS arrive, and the falling building plunges right past them. The HELICOPTERS look across at each other, helpless. EXT. THE CENTER - NIGHT It drops like a stone. EXT. FIRE DOOR - NIGHT SPIDEY and LIZ are falling away from the DOOR, sliding along the ROCK. LIZ is stopped by a RETAINING WALL. SPIDEY keeps sliding. He THWIPS the wall and then disappears over the edge. LIZ screams! LIZ fights to her feet and grabs onto the WEB STAND. She pulls on it with all her strength. She pulls and pulls and pulls. We see the WEB running up between the ROCKS. She gives one last pull and comes up with an EMPTY WEB END. A long, long beat.
#
# 1319. PETER:
# Liz, Up here!
#
# 1320. narrator:
# LIZ looks up and sees PETER hanging out the WINDOW two stories above her. He throws out a ROPE LADDER. LIZ grabs it. She begins to climb. INT. CLASSROOM - NIGHT PETER pulls LIZ through the WINDOW. There is no time for an embrace.
#
# ******** test model 1: line 1318 ********
# 1 relations identified
# entities: ['Interrogator'] => DOOR
# relation:  bends the
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 591 ********
# 589. narrator:
# EXT. STREET - OUTSIDE OF A BANK - BACK DOOR - NIGHT An ARMORED TRUCK rolls by and stops. TWO GUARDS open the Bank's DOORS. Suddenly a WALDO smashes through the DRIVER'S SIDE WINDOW of the ARMORED TRUCK, wrapping around the DRIVER'S NECK and pulling him through the WINDOW. The SHOTGUN goes for his weapon, but a WALDO smashes in and pulls the GUN out through his WINDOW. TWO WALDOS shoot out and attach themselves to the REAR DOOR.
#
# 590. BANK GUARD:
# What's going on here?
#
# => 591. narrator:
# => The WALDO knocks him over. OCK rips the DOOR off! The TRUCK is full of MONEY BAGS.
#
# 592. OCK:
# Cash!
#
# 593. narrator:
# INT. JAMESON'S OFFICE - DAY A PHOTO ASSISTANT look on as JAMESON goes over PETER'S latest PHOTOS. They are his SPIDER-MAN shots.
#
# ******** test model 1: line 591 ********
# 1 relations identified
# entities: OCK => DOOR
# relation:  rips the
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 386 ********
# 384. narrator:
# He leaps off the WALL and lands at the edge of the roof. He looks down. No one's looking back. So, he takes a step back and leaps the alley to the next roof. EXT. ROOFTOP SHACK - NIGHT PETER lands on it. The next roof is seven stories up and across the street. PETER bites his lip.
#
# 385. PETER:
# Well, what the hell!!
#
# => 386. narrator:
# => EXT. THE TALLER BUILDING - NIGHT Backlit by a FULL MOON, PETER somersaults to the roof of the taller building, and misses the top! He sticks to the brick FACADE, upside down! He laughs with the moment. A WINDOW opens below him and a pretty BLONDE in a TOWEL sticks her head out. She looks this way and that, and all she sees is a MAN in a LOUD SPORTCOAT down the street. Never thinking to look up, she withdraws into the room. EXT. CHELSEA STREET - NIGHT The MAN in the LOUD SPORTCOAT leans against a LAMP POST and lights a CIGARETTE with a BEAT UP, SILVER PLATED LIGHTER. In the LIGHTER he sees a reflection of PETER leaping off the taller building. He snaps around and looks up in time to see PETER make it to the next FACADE. EXT. ROOFTOP MONTAGE - NIGHT With the UPTOWN SKYLINE behind him, PETER casts caution to the wind and leaps from rooftop to rooftop. Watching from the street, the MAN in the LOUD SPORTCOAT follows PETER'S progress. PETER leaps to a BROWNSTONE and lands amid the WASH. He leaps up to a TENEMENT and lands on a BILLBOARD across which he does a "bug crawl" and leaps again. He touches down on a PIGEON COOP and bounds up and out of frame again. The COOP OWNER, a LATINO in an undershirt and a YANKEES CAP, comes running out of the COOP. He's so surprised that he leaves the DOOR open and twenty WHITE MORNING DOVES fly away in a furious flapping, free at last. The LATINO lets out a stream of Hispanic expletives complete with all the appropriately obscene gestures. PETER slides down a CABLE to a LAMP POST, and swirls down the POLE to a PHONE BOOTH. EXT. PHONE BOOTH - NIGHT PETER comes face to face with the man in the LOUD SPORTCOAT. He gives PETER his CARD.
#
# 387. REISS:
# You're a kid who's going places, and I'm gonna point you the right way.
#
# 388. PETER:
# (reading card) Max Reiss, models, strip dancers, escort girls, blue movies...
#
# ******** test model 1: line 386 ********
# 1 relations identified
# entities: narrator => , PETER, MAN, LATINO, SILVER, MAN, BEAT UP, PETER
# relation: EXT. THE TALLER BUILDING - NIGHT Backlit by a FULL MOON, PETER somersaults to the roof of the taller building, and misses the top! He sticks to the brick FACADE, upside down! He laughs with the moment. A WINDOW opens below him and a pretty BLONDE in a TOWEL sticks her head out. She looks this way and that, and all she sees is a MAN in a LOUD SPORTCOAT down the street. Never thinking to look up, she withdraws into the room. EXT. CHELSEA STREET - NIGHT The MAN in the LOUD SPORTCOAT leans against a LAMP POST and lights a CIGARETTE with a BEAT UP, SILVER PLATED LIGHTER. In the LIGHTER he sees a reflection of PETER leaping off the taller building. He snaps around and looks up in time to see PETER make it to the next FACADE. EXT. ROOFTOP MONTAGE - NIGHT With the UPTOWN SKYLINE behind him, PETER casts caution to the wind and leaps from rooftop to rooftop. Watching from the street, the MAN in the LOUD SPORTCOAT follows PETER'S progress. PETER leaps to a BROWNSTONE and lands amid the WASH. He leaps up to a TENEMENT and lands on a BILLBOARD across which he does a "bug crawl" and leaps again. He touches down on a PIGEON COOP and bounds up and out of frame again. The COOP OWNER, a LATINO in an undershirt and a YANKEES CAP, comes running out of the COOP. He's so surprised that he leaves the DOOR open and twenty WHITE MORNING DOVES fly away in a furious flapping, free at last. The LATINO lets out a stream of Hispanic expletives complete with all the appropriately obscene gestures. PETER slides down a CABLE to a LAMP POST, and swirls down the POLE to a PHONE BOOTH. EXT. PHONE BOOTH - NIGHT PETER comes face to face with the man in the LOUD SPORTCOAT. He gives PETER his CARD.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 1280 ********
# 1278. narrator:
# LIZ looks at some WIRING, apprehensive about even touching it.
#
# 1279. SPIDER-MAN:
# Pull!
#
# => 1280. narrator:
# => She yanks out a CABLE. The building pitches. But when SPIDEY pulls one out, it rights itself. EXT. SCIENCE CENTER - NIGHT The BIG BEAMS start cutting out one by one. The CENTER begins to PITCH and YAW. The CHOPPERS are getting closer. INT. CONTROL ROOM - NIGHT The COUNTDOWN CLOCK reads, "00:00:15" as SPIDEY and LIZ continue to pull WIRES and CABLES. TWO WALDOS erupt through the floor and grab SPIDEY. They pull SPIDEY to the floor. Entangled in these molybdimum pythons, SPIDEY struggles valiantly. LIZ leaps to his aid.
#
# 1281. LIZ:
# Oh my God...
#
# 1282. narrator:
# A third WALDO, a broken one, snakes up from the HOLE and begins feeling blindly around on the CONSOLE for the POWER THROTTLE.
#
# ******** test model 1: line 1280 ********
# 5 relations identified
# entities: narrator => , LIZ, YAW, pythons
# relation: She yanks out a CABLE. The building pitches. But when SPIDEY pulls one out, it rights itself. EXT. SCIENCE CENTER - NIGHT The BIG BEAMS start cutting out one by one. The CENTER begins to PITCH and YAW. The CHOPPERS are getting closer. INT. CONTROL ROOM - NIGHT The COUNTDOWN CLOCK reads, "00:00:15" as SPIDEY and LIZ continue to pull WIRES and CABLES. TWO WALDOS erupt through the floor and grab SPIDEY. They pull SPIDEY to the floor. Entangled in these molybdimum pythons, SPIDEY struggles valiantly. LIZ leaps to his aid.
# category: 3
# entities: building => ['Loggan']
# relation:  pulls
# category: 5
# entities: building => ['President']
# relation:  rights
# category: 5
# entities: building => 00
# relation:  reads , "
# category: 5
# entities: building => SPIDEY
# relation:  pull
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 328 ********
# 326. narrator:
# This elicits a flood of AD LIBS: "I heard a terrible explosion?" "Nuclear accidents?" "Meltdown?" "Genetic engineering?" "Are you guys making mutants in there?"
#
# 327. THORKEL:
# I have nothing to say... there will be an announcement. Now, please go home... everybody... we must clear the grounds...
#
# => 328. narrator:
# => In the back of the crowd are PETER, HARRY, LIZ, FLASH and KIM.
#
# 329. FLASH:
# You think they'll cancel classes?
#
# 330. HARRY:
# They must... the whole building must be contaminated with some kind of poisonous gas.
#
# ******** test model 1: line 328 ********
# 1 relations identified
# entities: narrator => , crowd, PETER, HARRY, KIM, LIZ
# relation: In the back of the crowd are PETER, HARRY, LIZ, FLASH and KIM.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 1258 ********
# 1256. narrator:
# OCK knocks SPIDER-MAN with a real BIG BLOW with his WALDO. OCK is slowly dragging SPIDER-MAN to a HUGE HOLE that's been ripped in the floor by the BEAMS of ELECTRICITY. We see New York a half a mile down through the hole. We see SPIDEY being drawn across the HOLE. Then ROZ comes flying in with the FIRE AXE. ROZ hacks away at the WALDO and chops it off! The stump withdraws. OCK examines it in pain and fury!
#
# 1257. OCK:
# (ultimate betrayal) You!! You were my teacher!!!
#
# => 1258. narrator:
# => ROZ doesn't even look back. He and SPIDEY are at the edge of the HOLE and he's shaking SPIDEY furiously. OCK sends out his other WALDO and begins banging it on the floor in a frenzy on either side of ROZ and SPIDEY. Like a child denied, he smashes his steel fists against the floor again and again.
#
# 1259. OCK:
# You were my teacher! And you want to destroy my experiment. You are a scientist for heaven sake... don't you want to know what's up there?
#
# 1260. ROZ:
# Yes, but not on account of our world. We have only one world... only one life. The floor begins to craze and then crack like ice around a hole on a pond. BANG! BANG! SPIDEY comes to just as the section of floor beneath himself and ROZ gives way and falls through.
#
# ******** test model 1: line 1258 ********
# 1 relations identified
# entities: narrator => , ROZ, child, fists
# relation: ROZ doesn't even look back. He and SPIDEY are at the edge of the HOLE and he's shaking SPIDEY furiously. OCK sends out his other WALDO and begins banging it on the floor in a frenzy on either side of ROZ and SPIDEY. Like a child denied, he smashes his steel fists against the floor again and again.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 1089 ********
# 1087. narrator:
# OCK leaves the COP and attacks SPIDER-MAN, shooting his iron fist at him. OCK runs to the end of the alley. SPIDEY staggers to his feet and resumes the chase. OCK breaks into a red Corvette convertible, starting it with a WALDO. SPIDER-MAN comes out in time to see the Vette drive away. A CHINESE LAUNDRY TRUCK is passing. SPIDEY THWIPS it and is whipped away. He crawls over to the WINDOW.
#
# 1088. SPIDER-MAN:
# Hey, driver. Could you follow that red Vette for me?
#
# => 1089. narrator:
# => The surprised CHINAMAN lets loose a stream of CHINESE expletives, complete with appropriate suggestive gestures. SPIDER-MAN crawls to the top of the TRUCK and surveys the situation. He sees a sea of moving traffic. He THWIPS up a WEB and swings away. SPIDEY swings along from BUILDING to BUILDING. The RED VETTE is making headway. Suddenly, SPIDER-MAN spots a blue MG with its top up.
#
# 1090. SPIDER-MAN:
# (swinging) Flash Thompson... I never thought I'd be happy to see you.
#
# 1091. narrator:
# EXT. BLUE MG - NIGHT SPIDEY swoops down on the BLUE MG. INT. BLUE MG - NIGHT SPIDEY wedges down into the car, right between FLASH and LIZ. She WHOOPS. FLASH is thrilled.
#
# ******** test model 1: line 1089 ********
# 1 relations identified
# entities: CHINAMAN => stream
# relation:  lets loose a
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 319 ********
# 317. narrator:
# He hears the police sirens approaching, he runs away.
#
# 318. WEINER:
# I better get out of here.
#
# => 319. narrator:
# => EXT. THE EMPIRE UNIVERSITY - NIGHT The long SCREAM segues to a POLICE SIREN. A COP CAR pulls to a halt in front of the COLLEGE. Many NYPD CARS are already there, along with a NUCLEAR REGULATORY VAN, some AMBULANCES, a VAN from the ENVIRONMENTAL PROTECTION AGENCY and TWO TV VANS. ROZ runs across the lawn. POLICE STRUGGLE to hold back the crowd of press, students and general gawkers. J. JAMESON pushes to the front of the mob in time to see TWO COPS hustle a BUGLE PHOTOGRAPHER back into it. The MAN shakes his head. JAMESON throws down his CIGAR, stomps it, and pulls out a fresh one. THORKEL arrives to address the CROWD.
#
# 320. THORKEL:
# (through bull horn) There is no danger. Please go back to your dorms. I repeat, there is no danger.
#
# 321. JAMESON:
# (approaches him) Spill it out, Professor! The public wants to know!
#
# ******** test model 1: line 319 ********
# 1 relations identified
# entities: narrator => , J. JAMESON, POLICE SIREN, MAN, crowd, TV VANS, AMBULANCES, students, gawkers, ROZ, CROWD, BUGLE PHOTOGRAPHER, THORKEL
# relation: EXT. THE EMPIRE UNIVERSITY - NIGHT The long SCREAM segues to a POLICE SIREN. A COP CAR pulls to a halt in front of the COLLEGE. Many NYPD CARS are already there, along with a NUCLEAR REGULATORY VAN, some AMBULANCES, a VAN from the ENVIRONMENTAL PROTECTION AGENCY and TWO TV VANS. ROZ runs across the lawn. POLICE STRUGGLE to hold back the crowd of press, students and general gawkers. J. JAMESON pushes to the front of the mob in time to see TWO COPS hustle a BUGLE PHOTOGRAPHER back into it. The MAN shakes his head. JAMESON throws down his CIGAR, stomps it, and pulls out a fresh one. THORKEL arrives to address the CROWD.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 387 ********
# 385. PETER:
# Well, what the hell!!
#
# 386. narrator:
# EXT. THE TALLER BUILDING - NIGHT Backlit by a FULL MOON, PETER somersaults to the roof of the taller building, and misses the top! He sticks to the brick FACADE, upside down! He laughs with the moment. A WINDOW opens below him and a pretty BLONDE in a TOWEL sticks her head out. She looks this way and that, and all she sees is a MAN in a LOUD SPORTCOAT down the street. Never thinking to look up, she withdraws into the room. EXT. CHELSEA STREET - NIGHT The MAN in the LOUD SPORTCOAT leans against a LAMP POST and lights a CIGARETTE with a BEAT UP, SILVER PLATED LIGHTER. In the LIGHTER he sees a reflection of PETER leaping off the taller building. He snaps around and looks up in time to see PETER make it to the next FACADE. EXT. ROOFTOP MONTAGE - NIGHT With the UPTOWN SKYLINE behind him, PETER casts caution to the wind and leaps from rooftop to rooftop. Watching from the street, the MAN in the LOUD SPORTCOAT follows PETER'S progress. PETER leaps to a BROWNSTONE and lands amid the WASH. He leaps up to a TENEMENT and lands on a BILLBOARD across which he does a "bug crawl" and leaps again. He touches down on a PIGEON COOP and bounds up and out of frame again. The COOP OWNER, a LATINO in an undershirt and a YANKEES CAP, comes running out of the COOP. He's so surprised that he leaves the DOOR open and twenty WHITE MORNING DOVES fly away in a furious flapping, free at last. The LATINO lets out a stream of Hispanic expletives complete with all the appropriately obscene gestures. PETER slides down a CABLE to a LAMP POST, and swirls down the POLE to a PHONE BOOTH. EXT. PHONE BOOTH - NIGHT PETER comes face to face with the man in the LOUD SPORTCOAT. He gives PETER his CARD.
#
# => 387. REISS:
# => You're a kid who's going places, and I'm gonna point you the right way.
#
# 388. PETER:
# (reading card) Max Reiss, models, strip dancers, escort girls, blue movies...
#
# 389. REISS:
# Oops... sorry, wrong card. (exchanges cards)
#
# ******** test model 1: line 387 ********
# 1 relations identified
# entities: ["Jean's voice"] => places
# relation:  going
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 1180 ********
# 1178. narrator:
# INT. PHONE BOOTH - NIGHT
#
# 1179. SPIDER-MAN:
# The only way we can interfere with Ock's plan is to find a computer center... fast.
#
# => 1180. HARRY:
# => Our University has the biggest center in town.
#
# 1181. SPIDER-MAN:
# Yeah, but who's gonna work 'em?
#
# 1182. narrator:
# ...
# entities: narrator => , DAY PETER, LIZ, HARRY
# relation: INT. BASEMENT HALLWAY - DAY PETER, LIZ, FLASH and HARRY all take BOOKS from their LOCKERS.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 724 ********
# 722. narrator:
# PETER rushes to BEN.
#
# 723. PETER:
# Oh my God... Uncle Ben...
#
# => 724. narrator:
# => PETER tries to revive BEN, while WEINER runs out. INT. HOSPITAL WAITING ROOM - NIGHT PLASTIC FURNITURE, GARISH LIGHTING, CIGARETTES in the ASHTRAYS.
#
# 725. AUNT MAY:
# (a brave but fragile front) Ben gets through everything. He'll be alright. The doctors are...
#
# 726. narrator:
# AUNT MAY and PETER embrace, leaning on each other for support.
#
# ******** test model 1: line 724 ********
# 1 relations identified
# entities: narrator => , PETER, WEINER, BEN
# relation: PETER tries to revive BEN, while WEINER runs out. INT. HOSPITAL WAITING ROOM - NIGHT PLASTIC FURNITURE, GARISH LIGHTING, CIGARETTES in the ASHTRAYS.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 105 ********
# 103. THORKEL:
# Wait a minute, wait a minute... you've got fire forms to fill out, Dr. Octavius.
#
# 104. OCK:
# I have no time for forms, or administrators who persist in interrupting me, Mr. Thorkel.
#
# => 105. narrator:
# => THORKEL steams out and bangs shut the DOOR.
#
# 106. OCK:
# I now believe its possible that these counter forces can be... collected... the way the magnifying glass collects the sunlight... and focused into a hard beam I call... Weiner!
#
# 107. narrator:
# WEINER backs away from the BLACKBOARD to reveal a word that OCK has scrawled in large letters. It says "Anti- Force."
#
# ******** test model 1: line 105 ********
# 1 relations identified
# entities: bangs => DOOR
# relation:  shut the
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 719 ********
# 717. BEN:
# Let go!
#
# 718. WEINER:
# You let go!
#
# => 719. narrator:
# => EXT. BEN AND MAY'S HOUSE - NIGHT PETER runs up and hears a SHOT. He runs inside. INT. BEN AND MAY'S FAMILY ROOM - NIGHT PETER runs in. He sees WEINER standing there with the RIFLE. They face off across the room. The moment hits PETER like a punch in the chest.
#
# 720. PETER:
# Uncle Ben!
#
# 721. BEN:
# (a wheeze) Peter...
#
# ******** test model 1: line 719 ********
# 1 relations identified
# entities: narrator => , BEN, NIGHT PETER, MAY, WEINER
# relation: EXT. BEN AND MAY'S HOUSE - NIGHT PETER runs up and hears a SHOT. He runs inside. INT. BEN AND MAY'S FAMILY ROOM - NIGHT PETER runs in. He sees WEINER standing there with the RIFLE. They face off across the room. The moment hits PETER like a punch in the chest.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 839 ********
# 837. SPIDER-MAN:
# Spider-Man.
#
# 838. LIZ:
# (seeing Spidey) Spider-Man...
#
# => 839. OCK:
# => That's a lot of crap, clown... I am Spider-Man, not you. (points to Liz) Ask you girlfriend. (to Liz) Tell him!
#
# 840. SPIDER-MAN:
# I'm a good friend of Peter Parker's Ock. Just like that girl you're holding. Now let her go.
#
# 841. narrator:
# OCK thinks for a moment, then he begins to extend the kicking and screaming LIZ out over the street, ten stories up.
#
# ******** test model 1: line 839 ********
# 1 relations identified
# entities: OCK => , clown, Liz, girlfriend
# relation: That's a lot of crap, clown... I am Spider-Man, not you. (points to Liz) Ask you girlfriend. (to Liz) Tell him!
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 1217 ********
# 1215. narrator:
# SPIDER-MAN SHOOTS out a WEB and flies toward the SCHOOL BUILDING taking ROZ with him. INT. EXPERIMENTAL CHAMBER - NIGHT It is a patchwork of make-shift repairs. OCK looks in through a WINDOW that's been melted out. He is lost in a mad rapture. INT. CONTROL ROOM - NIGHT RED POWER THROTTLE is at 95% POWER! SPIDER-MAN and ROZ enter, shielding their eyes from the GLARE. The COUNTDOWN CLOCK reads, "00:08:18".
#
# 1216. OCK:
# (looking back, madly) Aha! You never included the Conjunction in your calculations, did you?! Rosomorf!
#
# => 1217. ROZ:
# => Damn the calculations! My God, Otto, you have to hear me! The world we know will collapse! Everything we have devoted our lives to... all the patterns, all the harmonies... everything will be destroyed.
#
# 1218. OCK:
# A new world waits! Rosomorf! It is my destiny!!!
#
# 1219. ROZ:
# It is cosmic suicide! You have no right!
#
# ******** test model 1: line 1217 ********
# 1 relations identified
# entities: world => lives
# relation:  devoted our
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 669 ********
# 667. KIM:
# Hey, Flash-Man... Wanna dance...?
#
# 668. FLASH:
# Well, why not.
#
# => 669. narrator:
# => PETER is left alone, PETER leaves toward the entrance. At the REAR DOOR a BIG LIZARD passes a NOTE to a DALLAS COWGIRL who passes it to a KANGAROO. The KANGAROO hops across the dance floor to the STAGE where he hands the NOTE to a YOUNG WOMAN in a BASEBALL UNIFORM. She climbs the STAGE where she is bathed in a SPOTLIGHT. She gets a DRUM ROLL from the band. There are some BOOS as the bad stops.
#
# 670. YOUNG WOMAN:
# Thank you, thank you. We have a special surprise guest tonight. (booo) The Empire State University Masquerade Ball presents... The "Slammy" winning star of MTV'S wrestling tournament... The Amazing Spider-Man!
#
# 671. narrator:
# FLASH, amazed turns to LIZ. He points to himself and mouths, "Me?" (The REAL) SPIDEY drops from the ceiling and lands in a pose. The CROWD cheers. He does a flip to LIZ and extends a hand. The BAND starts up. LIZ demurs.
#
# ******** test model 1: line 669 ********
# 1 relations identified
# entities: narrator => , PETER, COWGIRL, WOMAN
# relation: PETER is left alone, PETER leaves toward the entrance. At the REAR DOOR a BIG LIZARD passes a NOTE to a DALLAS COWGIRL who passes it to a KANGAROO. The KANGAROO hops across the dance floor to the STAGE where he hands the NOTE to a YOUNG WOMAN in a BASEBALL UNIFORM. She climbs the STAGE where she is bathed in a SPOTLIGHT. She gets a DRUM ROLL from the band. There are some BOOS as the bad stops.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 830 ********
# 828. PETER:
# Liz?
#
# 829. LIZ:
# (screaming from the street) Peter! Help! Peter!
#
# => 830. narrator:
# => PETER springs into action. He grabs his SPIDEY SUIT out of a drawer and starts taking off his clothes. EXT. STREET - NIGHT LIZ looks back and sees OCK CARTWHEELING toward her. She can't outrun him. She must hide. There's a CONSTRUCTION SITE on the right. She ducks down the alley next to it. INT. CONSTRUCTION ALLEY - NIGHT LIZ runs into it and finds herself trapped on three sides by a high CYCLONE FENCE. Behind her, OCK'S WALDOS stretch out like waterbug legs. He bug-walks into the alley and laughs down at her from his perch atop the WALDOS.
#
# 831. OCK:
# Peter Parker has something I want... And I'm going to have something he wants.
#
# 832. narrator:
# She dashes past him and runs into the outboard CARGO ELEVATOR. INT. ELEVATOR - NIGHT She looks for the UP BUTTON and finds nothing! OCK, on his feet now, is on the wire mesh ELEVATOR CAGE in a flash. He tears the outer DOOR away. LIZ starts pressing KNOBS and LEVERS in panic. The LIGHT goes on. A WARNING BELL clangs. She finally finds the switch and the CAR leaps up just as OCK tears off its front door. LIZ, safe for the moment, watches OCK recede below, shaking the torn off door in a rage. EXT. CONSTRUCTION SITE - NIGHT Extending WALDO over WALDO, OCK climbs the ELEVATOR HOUSING chasing the rising CAR inside. EXT. CONSTRUCTION ROOF - NIGHT The CAR arrives and LIZ jumps out. She's on nothing but a narrow GIRDER! She tightropes on the GIRDER. OCK gets to the top. He looks across at her. She's stuck between two unfastened GIRDERS, at a dead end. He slowly telescopes a WALDO toward her. She's got no place to run, no place to hide. He grabs her by the BLOUSE and lifts her off the GIRDER.
#
# ******** test model 1: line 830 ********
# 1 relations identified
# entities: narrator => , PETER, STREET - NIGHT LIZ, CONSTRUCTION ALLEY - NIGHT LIZ
# relation: PETER springs into action. He grabs his SPIDEY SUIT out of a drawer and starts taking off his clothes. EXT. STREET - NIGHT LIZ looks back and sees OCK CARTWHEELING toward her. She can't outrun him. She must hide. There's a CONSTRUCTION SITE on the right. She ducks down the alley next to it. INT. CONSTRUCTION ALLEY - NIGHT LIZ runs into it and finds herself trapped on three sides by a high CYCLONE FENCE. Behind her, OCK'S WALDOS stretch out like waterbug legs. He bug-walks into the alley and laughs down at her from his perch atop the WALDOS.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 1004 ********
# 1002. narrator:
# INT. BROADWAY EXPRESS - NIGHT ROZ boards and takes a seat. There are the usual SUBWAY TYPES. A FAT WOMAN. A PIMPLY TEENAGER and his date, a TALL SKINNY GIRL in a PARTY DRESS. ROZ, making notations in a PAD, takes no notice of them. He sits down, closes his PAD, and taps a PENCIL against his chin.
#
# 1003. ROZ:
# Plutonium...
#
# => 1004. narrator:
# => EXT. MAJOR INTERSECTION - NIGHT TAXIS go by. TWO LOVERS stroll. We hear a familiar WHINE. The "WALK" and "DON'T WALK" signs FLASH at the same time. BOY Make up your mind! The signs EXPLODE! The COUPLE stops in their tracks. The BOY looks at the GIRL.
#
# 1005. GIRL:
# What's going on?
#
# 1006. narrator:
# An ARC of ELECTRICITY now shoots between the LIGHT PILLARS of the SUBWAY STATION on the corner. INT. BROADWAY LOCAL - NIGHT SPARKS fly by the window. ROZ, oblivious at first, is now stunned by the show. EXT. SUBWAY TRAIN ENTRANCE - NIGHT The ARCS of ELECTRICITY continue to rise. The STREET LIGHTS buckle and bend into weird shapes.
#
# ******** test model 1: line 1004 ********
# 1 relations identified
# entities: narrator => , BOY, TWO LOVERS, COUPLE, GIRL
# relation: EXT. MAJOR INTERSECTION - NIGHT TAXIS go by. TWO LOVERS stroll. We hear a familiar WHINE. The "WALK" and "DON'T WALK" signs FLASH at the same time. BOY Make up your mind! The signs EXPLODE! The COUPLE stops in their tracks. The BOY looks at the GIRL.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 213 ********
# 211. PETER:
# I know, I know. You want man bites dog...
#
# 212. JAMESON:
# Parker, this is the post modern 20th century. I want man eats dog! Get out!
#
# => 213. narrator:
# => EXT. STREET - DAY A seedy east village walk up. Peter takes his camera and takes various shots of a wino. ALL IN. He climbs the stairs to his building, looks through the mail, he collects from a beaten down mailbox.
#
# 214. PETER:
# (reading) Rent! Rent, more bills, rent... electricity, bills...
#
# 215. narrator:
# INT. PETER'S APARTMENT - DAY A one-room, shabby roof apartment, a chaos of books and papers. A photo enlarger and darkroom baths in kitchen pots; 8x10s tacked to the walls; a spare camera and lenses. Self-consciously wacky kitsch; plastic dinosaurs, wind-up toys, a stuffed carp. An unmade bed and a 50's dinette set are the only furniture. A grimy skylight leads to the roof. It's not a pretty place, but it has personality. A voice from the kitchen, a shadow of an intruder, is sneaking around.
#
# ******** test model 1: line 213 ********
# 2 relations identified
# entities: village => camera
# relation:  takes his
# category: 5
# entities: village => stairs
# relation:  climbs the
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 1236 ********
# 1234. HARRY:
# Get back! Flash... get back!
#
# 1235. FLASH:
# Wow...!
#
# => 1236. narrator:
# => Then the building lurches upward again! This time it pulls FREE from the ground. The KIDS take cover as WATER LINES BURST and ELECTRICAL WIRES SPARK. INT. SCIENCE CENTER HALLWAY - NIGHT LIZ opens a door.
#
# 1237. LIZ:
# Peter!
#
# 1238. narrator:
# The building lurches throwing her back across the HALL where she crashes through another door. INT. CHEMISTRY LAB - NIGHT All manner of stuff is flying around. LIZ comes sliding across the floor. She crashes into a CABINET. GLASSWARE starts to fall on her, but crashes into the CEILING instead. She is dragged up the WALL. She kicks and screams against the Anti-Force. EXT. SCIENCE CENTER - NIGHT FLASH, KIM and HARRY look on as heavy ELECTRICAL CABLES stretch upward to the rising CENTER and then snap in showers of sparks. As they fall away the CENTER becomes airborne. The CABLES wave up at it, shooting arcs of ELECTRICITY directly at the building. INT. CHEMISTRY LAB - NIGHT LIZ slides down the WALL. She grabs at the WINDOW and looks out. The rest of the university recedes beneath her, now a hundred feet below. And they're still rising! FLASH and HARRY look up.
#
# ******** test model 1: line 1236 ********
# 2 relations identified
# entities: building => cover
# relation:  take
# category: 5
# entities: building => door
# relation:  opens a
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 378 ********
# 376. PETER:
# I... got pictures of the Professor... in there... it's so strange in there... so bizarre...
#
# 377. JAMESON:
# (winks) Good job, kid. Bizarre is what we need. Pick this up in the morning. (holding up his camera) There'll be two crisp twenties tucked inside.
#
# => 378. narrator:
# => He hurries off. PETER peers after him and all of a sudden his vision corrects to a perfect focus. The sweat is gone. He's okay. He makes his way through the crowd to the street. We TRACK with PETER as the madding throng recedes behind him. He turns a corner. He hears a SIREN. An AMBULANCE screeches around the corner. It nearly hits PETER who leaps to avoid it. EXT. BRICK BUILDING - NIGHT PETER'S cheek is pressed against the brick. He opens his eyes and sees that he's hanging onto the side of the building like a spider. And he's three stories up! He looks down and sees the street thirty feet below him! And the Ambulance which he jumped over is driving away. He tries a downward step, but a BRICK dislodges and crashes to the sidewalk. He takes an upward step. And then another. Tentatively at first, and then with growing confidence, he "crawls" to the roof of the building. At the top he gropes for a RAILING and slips. He dangles eight stories above the street. Then, with a grunt, he vaults to the roof one-handed. EXT. THE ROOF - NIGHT PETER is flat on his back, staring at the stars. He sits up and looks wonderingly at his hands. On the back of his right hand are TWO PUNCTURE WOUNDS surrounded by a faint BLUE-WHITE PULSING GLOW. The GLOW disappears.
#
# 379. PETER:
# (mutters to himself) This is weird. My God, I feel so weird...
#
# 380. narrator:
# He leaps to his feet. He flexes. Feels weird. Good Weird. In fact, great weird! He tries a couple of "jumping jacks" and on the third jump he soars into the air!
#
# ******** test model 1: line 378 ********
# 1 relations identified
# entities: narrator => , BRICK BUILDING - NIGHT PETER'S, peers, crowd, stars
# relation: He hurries off. PETER peers after him and all of a sudden his vision corrects to a perfect focus. The sweat is gone. He's okay. He makes his way through the crowd to the street. We TRACK with PETER as the madding throng recedes behind him. He turns a corner. He hears a SIREN. An AMBULANCE screeches around the corner. It nearly hits PETER who leaps to avoid it. EXT. BRICK BUILDING - NIGHT PETER'S cheek is pressed against the brick. He opens his eyes and sees that he's hanging onto the side of the building like a spider. And he's three stories up! He looks down and sees the street thirty feet below him! And the Ambulance which he jumped over is driving away. He tries a downward step, but a BRICK dislodges and crashes to the sidewalk. He takes an upward step. And then another. Tentatively at first, and then with growing confidence, he "crawls" to the roof of the building. At the top he gropes for a RAILING and slips. He dangles eight stories above the street. Then, with a grunt, he vaults to the roof one-handed. EXT. THE ROOF - NIGHT PETER is flat on his back, staring at the stars. He sits up and looks wonderingly at his hands. On the back of his right hand are TWO PUNCTURE WOUNDS surrounded by a faint BLUE-WHITE PULSING GLOW. The GLOW disappears.
# category: 3
#
# how many are correctly identified? 0
#
# ******** test results ********
# model 1: precision = 0.20 (13/64 correct)

# %%
df_dict['df_9']['relations'] = df_dict['df_9'].apply(lambda x:extract_relation_categories(x), axis=1)
REEval([df_dict['df_9']])
#13/53
# Out:
# ******** line 666 ********
# 664. Ravencroft Guard #2:
# Sorry, Sir, without a yellow badge, I can't let anyone past this point. [suddenly Harry takes the guard's weapon and uses it to take both guards down; back at the hidden lab Peter continues to watch Richard's recorded video message]
#
# 665. Richard Parker:
# It doesn't matter because there is something else that Norman doesn't know. The Human DNA that I implanted in the spiders was my own, which means that without me, without my bloodline, OsCorp can never replicate or continue my experiments. [Harry dressed as a doctor and covering his face with a mask walks past Kafka as he's ordering one of his employees]
#
# => 666. Dr. Ashley Kafka:
# => Keep Electro incubated with four hundred milligrams of sodium iopental... [Harry then activates the fire alarm] [back to Peter watching Richard's recorded message]
#
# 667. Richard Parker:
# I have destroyed as much as possible from the archives, but I didn't have time to kill all the spiders. So as a scientist my choice is very clear now, I have to disappear, I have to get as far away from here as I can. But as a father, it means I may not see my boy again and nothing is as important to me as my son, Peter. Nothing in this world. But I have a responsibility to protect the world from what I've created and protect him from what I know Osborn is capable of. [as Peter watches tears start forming in his eyes] People will say I'm a monster for what I've done. Maybe they're right. I always thought that I'd have more time. [he's interrupted by young Peter calling out to him]
#
# 668. Young Peter Parker:
# Dad! Dad!
#
# ******** test model 1: line 666 ********
# 1 relations identified
# entities: Dr. Ashley Kafka => , Harry, Peter, Richard
# relation: Keep Electro incubated with four hundred milligrams of sodium iopental... [Harry then activates the fire alarm] [back to Peter watching Richard's recorded message]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 444 ********
# 442. Peter Parker:
# How about you come with me, we'll go somewhere, we'll talk away from these people, okay?
#
# 443. Max Dillon:
# Yeah. I guess... [as Max takes a step back his body produces a surge of electricity which immediately makes the sniper shoot at him]
#
# => 444. Peter Parker:
# => No! Stop! Stop! [in a surge of anger Max uses his power to take the sniper down, Peter goes to stop him by using his web but Max deflects it and uses his powers on Peter to throw his aside, then as one of the giant monitors is about to drop on a cop Peter manages to save the cop by using his web to pull him aside, the crowd cheers for Peter]
#
# 445. Crowd:
# Spidey! Spidey! Spidey! Spidey... [Max starts hearing the crowd calling him names]
#
# 446. Man in Crowd:
# You stupid freak! [Max sees the crowd booing him]
#
# ******** test model 1: line 444 ********
# 1 relations identified
# entities: Peter Parker => , Max, sniper, cop, cop
# relation: No! Stop! Stop! [in a surge of anger Max uses his power to take the sniper down, Peter goes to stop him by using his web but Max deflects it and uses his powers on Peter to throw his aside, then as one of the giant monitors is about to drop on a cop Peter manages to save the cop by using his web to pull him aside, the crowd cheers for Peter]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 335 ********
# 333. Harry Osborn:
# Really? She works for me?
#
# 334. Peter Parker:
# At OsCorp. She does work study at OsCorp.
#
# => 335. Harry Osborn:
# => Is she a model employee? [they both laugh] [Peter and Harry are throwing pebbles into the river] When my father sent away me I tried to forget everything about this place. I guess that kind of included you.
#
# 336. Peter Parker:
# You ain't gotta explain anything to me, man. We both got dumped.
#
# 337. Harry Osborn:
# Did you ever figure out why your parents bailed?
#
# ******** test model 1: line 335 ********
# 1 relations identified
# entities: Harry Osborn => , model employee, Peter, father
# relation: Is she a model employee? [they both laugh] [Peter and Harry are throwing pebbles into the river] When my father sent away me I tried to forget everything about this place. I guess that kind of included you.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 498 ********
# 496. OsCorp Employee Male:
# What's security doing over here?
#
# 497. OsCorp Employee Female:
# That's so weird. [Gwen turns to look at and sees them looking at her, she quickly gets up from her desk and starts to leave but the man in the black suit follows her]
#
# => 498. Man in Black Suit:
# => Hey! Miss Stacy! [as Gwen is trying to quickly get away from security she suddenly trips and bumps into Peter who's leaving from his meeting with Harry]
#
# 499. Gwen Stacy:
# Hi.
#
# 500. Peter Parker:
# Hi.
#
# ******** test model 1: line 498 ********
# 1 relations identified
# entities: Man in Black Suit => , Miss, Gwen, Harry, Peter
# relation: Hey! Miss Stacy! [as Gwen is trying to quickly get away from security she suddenly trips and bumps into Peter who's leaving from his meeting with Harry]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 71 ********
# 69. Aleksei Sytsevich:
# It's over, Spider! [then we cut back and forth between the speech and Peter trying to stop the truck]
#
# 70. Gwen Stacy:
# I know that we all think that we're immortal. We're supposed to feel that way, we're graduating. But like our brief four years in high school, what makes life valuable is that it doesn't last forever, what makes it precious is that it ends. I know that now more than ever. And I say it, today of all days, to remind us that time is luck. So don't waste it living someone else's life, make yours count for something. Fight for what matters to you, no matter what. Because even if you fall short, what better way is there to live? [as Peter tries to break through the truck's windscreen the truck crashes into a bus, so Peter leaps over the bus to stop it from overturning and protect some pedestrians in the process] [as Sytsevich is shooting at Peter, Peter swings over to him and easily grabs his gun away from him]
#
# => 71. Peter Parker:
# => I'll take that. [he then takes the plutonium vial from his hand] That's mine too. [Peter then uses his web to hold Sytsevich hands captive and then uses his web to pull down Sytsevich's trousers, Peter then turns and starts walking away] This is not over, Spider! [just then Sytsevich's gun lands on his head] [as the students are going up to the stage to receive their graduate certificates, Peter quickly swings in and changes into his graduation robe, as he walks over to the ceremony he realizes he's forgotten to take his Spider-Man mask off, as he goes to take it off one of the guests (Stan Lee) notice him]
#
# 72. Graduation Guest:
# I think I know that guy. [just then Peter's name is called out]
#
# 73. Dr. Jallings:
# Peter Parker. Peter Parker. [Peter makes it to the stage just in time, gets his certificate and kisses Gwen on stage as everyone cheers] [Peter runs over to Aunt May as she's taking a picture of him]
#
# ******** test model 1: line 71 ********
# 1 relations identified
# entities: Peter Parker => , Sytsevich, students, guests, Stan Lee
# relation: I'll take that. [he then takes the plutonium vial from his hand] That's mine too. [Peter then uses his web to hold Sytsevich hands captive and then uses his web to pull down Sytsevich's trousers, Peter then turns and starts walking away] This is not over, Spider! [just then Sytsevich's gun lands on his head] [as the students are going up to the stage to receive their graduate certificates, Peter quickly swings in and changes into his graduation robe, as he walks over to the ceremony he realizes he's forgotten to take his Spider-Man mask off, as he goes to take it off one of the guests (Stan Lee) notice him]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 825 ********
# 823. Gustav Fiers:
# How many men did you have in mind?
#
# 824. Harry Osborn:
# I want to keep it small. Everything you need is already at OsCorp. [at OsCorp Fiers enters the Special Projects lab]
#
# => 825. Aunt May:
# => Too bad about that Spider guy. Too bad he's disappeared, seems like everybody really needs him. [Peter gets up to leave] Where you going?
#
# 826. Peter Parker:
# Just...I'm not sure.
#
# 827. Aunt May:
# Peter, where you going? [Peter thinks for a moment before turning to face Aunt May]
#
# ******** test model 1: line 825 ********
# 1 relations identified
# entities: Aunt May => , guy, everybody, Peter
# relation: Too bad about that Spider guy. Too bad he's disappeared, seems like everybody really needs him. [Peter gets up to leave] Where you going?
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 455 ********
# 453. Peter Parker:
# No, I'm trying to help you! Let me help you! [Max suddenly touches the power grid on the ground sending a surge of electricity across the street which throws Peter in the air, but Peter manages to use his web to save the people standing nearby before they get electrocuted, the crowd cheers for Peter again]
#
# 454. Max Dillon:
# It's my birthday, now its time for me to light my candles! [he uses his power to try and take down Peter, but Peter deflects all his shots, getting angry Max grabs some electrical cables, jacks them into his chest which sucks the electricity into his body taking all the light out of Times Square, then Max starts blasting his power across Time Square tearing to shreds sending the crowd running for their lives]
#
# => 455. Times Square Cop:
# => [into his radio] Does anyone have visual on Spider-Man? Does anyone have visual on Spider-Man? [as Max continues to send blasts of electricity across the square suddenly Peter blasts with him with a fire hose spray which disrupts Max's powers and sends him down]
#
# 456. Peter Parker:
# Alright, that's enough. [to the firemen helping him] Mike. Big John. Nice work, fellas. It was a pleasure doing business with you. [as Max lies on the ground]
#
# 457. Max Dillon:
# Spider-Man... [Peter swings over to Gwen]
#
# ******** test model 1: line 455 ********
# 1 relations identified
# entities: Times Square Cop => , Max, anyone, anyone, Peter
# relation: [into his radio] Does anyone have visual on Spider-Man? Does anyone have visual on Spider-Man? [as Max continues to send blasts of electricity across the square suddenly Peter blasts with him with a fire hose spray which disrupts Max's powers and sends him down]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 462 ********
# 460. NY1 News Anchor:
# Our coverage of this breaking story begins with New York 1 Jessica Abo, at the scene.
#
# 461. NY1 Reporter:
# That's right, we're standing here with two eyewitnesses, who are going to tell what they just saw. [turning to the two eyewitnesses] So tell us, how do think Spider-Man did it? How do you think he beat this creature?
#
# => 462. Times Square Bystander:
# => Yeah, it's got to be rubberized, Spidey's suit, that...that's why he didn't get electrocuted. Probably some kind of neoprene, that's what I'd use, honestly. [Peter takes his phone out and looks at a photo of himself and Gwen, he throws it aside in frustration]
#
# 463. NY1 Reporter:
# Okay, well, thank you very much to the two of you. As you can tell, so many questions remain unanswered. But we will bring you the latest information as it becomes available. For now, Jessica Abo for New York 1... [Peter looks at his busted web shooter then throws that back on the table, he lies down to listen to some music but becomes restless and instead takes his dad's briefcase out, empties the contents and sees the word "Roosevelt" on a notepad and starts to research the word on the internet, he then sticks up all the clippings he has on his parents on his wall and includes the photo of himself with Gwen and under it he's written "Do I have to lose you too????"] [Harry is sitting in his office listening to news coverage as he fiddles with the drive his father left him]
#
# 464. NY1 News Anchor:
# Online polls show a sudden uptick in public sentiment in favor of the web-crawler. Tonight it would seem New York City owes him a debt of gratitude. [Harry feels an itch on his neck and as he reaches to scratch it, the drive pricks his finger, he drops it onto the desk and suddenly initiates the desktop display and Harry begins to access the information on the drive about a secret battle armor]
#
# ******** test model 1: line 462 ********
# 1 relations identified
# entities: Times Square Bystander => , Spidey, Peter, Gwen
# relation: Yeah, it's got to be rubberized, Spidey's suit, that...that's why he didn't get electrocuted. Probably some kind of neoprene, that's what I'd use, honestly. [Peter takes his phone out and looks at a photo of himself and Gwen, he throws it aside in frustration]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 741 ********
# 739. Gwen Stacy:
# Okay. Well, remember eighth grade science class? When you magnetize a nail with a battery...
#
# 740. Peter Parker:
# It holds an electric charge.
#
# => 741. Gwen Stacy:
# => Yes. [as an airplane approaches New York]
#
# 742. Pilot #1:
# New York Approach, this is Pan National 273 on approach. How do you hear? [there's no response] Approach, do you copy?
#
# 743. Pilot #2:
# Radio's working, its not us. [Peter carries Gwen as he swings down into the panic filled street where a cop is trying to calm everyone using his megaphone]
#
# ******** test model 1: line 741 ********
# 1 relations identified
# entities: Yes. => New York
# relation:  approaches New
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 434 ********
# 432. Peter Parker:
# I can see that. I can...I believe you.
#
# 433. Max Dillon:
# It's strange. The power, that I got so much...I got so much anger. [we see Gwen making her way through the crowd to watch what's happening]
#
# => 434. Peter Parker:
# => I can see that. I can see you don't want to be here. I can see you're scared. I can see you don't know what's happening to you. I can see that you don't want to hurt anybody. You're gonna be alright. [at the same time we see a sniper aiming to shoot at Max from above a building]
#
# 435. Sniper:
# I've got a clear shot. Standing by.
#
# 436. Max Dillon:
# I don't want them shooting me anymore.
#
# ******** test model 1: line 434 ********
# 1 relations identified
# entities: Peter Parker => , sniper, anybody, Max
# relation: I can see that. I can see you don't want to be here. I can see you're scared. I can see you don't know what's happening to you. I can see that you don't want to hurt anybody. You're gonna be alright. [at the same time we see a sniper aiming to shoot at Max from above a building]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 456 ********
# 454. Max Dillon:
# It's my birthday, now its time for me to light my candles! [he uses his power to try and take down Peter, but Peter deflects all his shots, getting angry Max grabs some electrical cables, jacks them into his chest which sucks the electricity into his body taking all the light out of Times Square, then Max starts blasting his power across Time Square tearing to shreds sending the crowd running for their lives]
#
# 455. Times Square Cop:
# [into his radio] Does anyone have visual on Spider-Man? Does anyone have visual on Spider-Man? [as Max continues to send blasts of electricity across the square suddenly Peter blasts with him with a fire hose spray which disrupts Max's powers and sends him down]
#
# => 456. Peter Parker:
# => Alright, that's enough. [to the firemen helping him] Mike. Big John. Nice work, fellas. It was a pleasure doing business with you. [as Max lies on the ground]
#
# 457. Max Dillon:
# Spider-Man... [Peter swings over to Gwen]
#
# 458. Peter Parker:
# England? Really? [a car explodes behind Peter as they look at each other in silence, then Peter sighs, turns and walks away]
#
# ******** test model 1: line 456 ********
# 1 relations identified
# entities: Peter Parker => , Mike, firemen, fellas, Big John, Max
# relation: Alright, that's enough. [to the firemen helping him] Mike. Big John. Nice work, fellas. It was a pleasure doing business with you. [as Max lies on the ground]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 693 ********
# 691. Harry Osborn:
# Yes, I need you. You are my only chance that I have at surviving.
#
# 692. Max Dillon:
# You need me?
#
# => 693. Harry Osborn:
# => Yes, I need you! I need you, please! Please, I need you! [the guards rush into the chamber and grab hold of Harry and try to drag him away] Please! I know what it's like to be thrown away! Please, Max! I need you! I need you! [at that moment Max uses his electric power to escape his bondage and to take down the guards, then uses his power to electrocute Kafka and straps him in the same bondage that was holding him ready to be tested on]
#
# 694. Max Dillon:
# You want to be my friend?
#
# 695. Harry Osborn:
# I thought we were already friends?
#
# ******** test model 1: line 693 ********
# 1 relations identified
# entities: Harry Osborn => , Max, guards, Kafka
# relation: Yes, I need you! I need you, please! Please, I need you! [the guards rush into the chamber and grab hold of Harry and try to drag him away] Please! I know what it's like to be thrown away! Please, Max! I need you! I need you! [at that moment Max uses his electric power to escape his bondage and to take down the guards, then uses his power to electrocute Kafka and straps him in the same bondage that was holding him ready to be tested on]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 266 ********
# 264. Norman Osborn:
# I don't expect forgiveness from you anymore. I don't believe in miracles. How could you possibly understand that you're a child who I'd had to be sacrificed for something greater. And not just for me, for you! Are your hands started to twitch yet? When you lay awake and you feel it coming, hiding under your skin, waiting to show itself. To show you who you really are! [Osborn coughs] Retroviral hyperplasia. I never told you, but its genetic. Our disease. The Osborn curse. And it began at your age. Let me see it. Your hand, give it to me. [Harry slowly gives his hand to Osborn who holds it in his claw like hands] The greatest inheritance I can give you isn't merely money, it's this. [he places a small drive in Harry's hand] A sum total of all my work, everything I did to stay alive. Maybe you can succeed where I failed. [Harry holds the drive in his hand] [Peter is sat in a coffee shop writing an email to his boss at the Daily Bugle with a photo of himself in his Spider-Man suit swinging away from a building]
#
# 265. Peter Parker:
# "Dear Mr. Jameson. New pix and invoice enclosed. I think you should consider that maybe Spider-Man is trying to help. Sincerely, Peter Parker." [as soon as he sends the email he sees a reply from Jameson pop up with the subject heading "Wrong!!!", just then Peter sees the news reporting Osborn's death]
#
# => 266. News Reporter:
# => News just in, Norman Osborn, the legendary founder and CEO of OsCorp Industries has died. The Osborn estate has confirmed he is survived by his only son, Harry Osborn, who is the sole heir of the OsCorp corporate empire...
#
# 267. Peter Parker:
# Harry.
#
# 268. News Reporter:
# Osborn fundamentally changed the medical professions approach to human healing and effected the lives of millions. [a footage of Norman Osborn giving a presentation is shown]
#
# ******** test model 1: line 266 ********
# 1 relations identified
# entities: News Reporter => , Norman Osborn, Harry Osborn, founder, CEO
# relation: News just in, Norman Osborn, the legendary founder and CEO of OsCorp Industries has died. The Osborn estate has confirmed he is survived by his only son, Harry Osborn, who is the sole heir of the OsCorp corporate empire...
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 837 ********
# 835. Aleksei Sytsevich:
# I am the Rhino! I told you I would be back! [as Sytsevich is shooting at the cops a kid dressed in Spider-Man suit suddenly runs into the middle of the street]
#
# 836. Jorge's Mother:
# Jorge, no!
#
# => 837. Cop:
# => Hold your fire! Everybody hold your fire! [everyone stops shooting as the kid stands in the middle of the street facing Sytsevich]
#
# 838. Aleksei Sytsevich:
# Kid, you gotta get...! [suddenly Sytsevich shoots at him then he starts mocking the kid] Look, New York. Spider-Man is back! [his mothers weeps as the police try to stop her from running to get him]
#
# 839. Jorge's Mother:
# That's my baby! [the kid places his Spider-Man mask on his head]
#
# ******** test model 1: line 837 ********
# 1 relations identified
# entities: Cop => , Everybody, everyone, kid, Sytsevich
# relation: Hold your fire! Everybody hold your fire! [everyone stops shooting as the kid stands in the middle of the street facing Sytsevich]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 270 ********
# 268. News Reporter:
# Osborn fundamentally changed the medical professions approach to human healing and effected the lives of millions. [a footage of Norman Osborn giving a presentation is shown]
#
# 269. Norman Osborn:
# I started OsCorp because I looked at the world around me and I thought, we can do better, and we should do better. Einstein said the world cannot be changed without changing our thinking. But change isn't just a slogan, it begins with hard work. Change begins with persistence and commitment. [at OsCorp the department head is giving a speech to the employees which includes Gwen]
#
# => 270. OsCorp Department Head:
# => Mr. Osborn changed the world, and now it's up to each of us to ensure that his hopes and dreams remain alive. But not today. Today... [just then Gwen's phone rings]
#
# 271. Gwen Stacy:
# Hello?
#
# 272. Oxford University:
# Is this Gwen Stacy?
#
# ******** test model 1: line 270 ********
# 1 relations identified
# entities: Osborn => world
# relation:  changed the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 631 ********
# 629. Peter Parker:
# And, anyway, God save the Queen, and I'm sorry about everything happening right... [looking really embarrassed Peter turns to leave]
#
# 630. Gwen Stacy:
# Peter, can you just wait for one second? [Gwen goes after Peter] Peter. Peter! What do you want to say to me? What's the one thing? [Peter turns and looks at her but doesn't reply] I have to go to England, Peter. It's important to me. I mean, I don't know, maybe we're just...maybe we're on different paths right now. You know? I don't know. Maybe we're just going different ways. I don't know, I gotta go. I gotta go. [she turns and starts walking away]
#
# => 631. Peter Parker:
# => Gwen. [she turns to look at Peter] Good luck. [Gwen smiles, turns and walks towards the desk attendant] Good luck. [Gwen smiles, turns and walks towards the desk attendant]
#
# 632. Gwen Stacy:
# Hi. Sorry. [Peter watches Gwen as she follows the desk attendant to her interview] [back in his room, Peter takes out his anger and frustration by tearing off the information he'd stuck to his wall about his parent, he then picks up his dad's calculator and throws it against the wall, as it breaks subway tokens fall down from inside it, Peter picks them up and thinks back to what Aunt May told him]
#
# 633. Aunt May:
# He took a D train every morning at seven, came home at six o'clock every evening. [Peter then starts looking up Roosevelt station on the internet and find an article about it, he reads it out loud to himself]
#
# ******** test model 1: line 631 ********
# 1 relations identified
# entities: Peter Parker => , Gwen., desk attendant, desk attendant
# relation: Gwen. [she turns to look at Peter] Good luck. [Gwen smiles, turns and walks towards the desk attendant] Good luck. [Gwen smiles, turns and walks towards the desk attendant]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 743 ********
# 741. Gwen Stacy:
# Yes. [as an airplane approaches New York]
#
# 742. Pilot #1:
# New York Approach, this is Pan National 273 on approach. How do you hear? [there's no response] Approach, do you copy?
#
# => 743. Pilot #2:
# => Radio's working, its not us. [Peter carries Gwen as he swings down into the panic filled street where a cop is trying to calm everyone using his megaphone]
#
# 744. Police Captain:
# Do not panic. Everyone, please return to your vehicles. Go back to your cars. Remain calm. Do not panic. Everyone return to your vehicles. Go to your homes!
#
# 745. Peter Parker:
# Officer! [the cop turns and shouts through megaphone]
#
# ******** test model 1: line 743 ********
# 1 relations identified
# entities: Pilot #2 => , Peter, everyone, Gwen, cop
# relation: Radio's working, its not us. [Peter carries Gwen as he swings down into the panic filled street where a cop is trying to calm everyone using his megaphone]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 831 ********
# 829. Aunt May:
# You know, it's so...it's so funny, I've been...I've been trying to clean up around here, get organized and I've been putting some of Ben's stuff in boxes, and...and it's so funny that the heavier the box gets the lighter I feel.
#
# 830. Peter Parker:
# You throwing his stuff away?
#
# => 831. Aunt May:
# => No. No. God, no. I couldn't do that, it's...it's a part of me. I'm just finding a better place for it. I'm gonna take one last look and I'm gonna put it where it belongs. [in his room, Peter looks at a photo of Gwen, then grabs a USB stick which has "Gwen's Speech" written on it and places it in his computer to watch]
#
# 832. Gwen Stacy:
# It's easy feel hopeful on a beautiful day like today. But there will be dark days ahead of us too. There will be days where you feel all alone, and that's when hope is needed most. No matter how buried it gets, or how lost you feel, you must promise me that you will hold on to hope. Keep it alive. We have to be greater than what we suffer. My wish for you is to become hope. People need that. And even if we fail, what better way is there to live? As we look around here today at all of the people who helped make us who we are, I know it feels like we're saying goodbye. But we will carry a piece of each other into everything that we do next. To remind us of who we are and if we were meant to be. I've had a great four years with you, I'll miss you all very much. [inspired by Gwen's speech, Peter puts away his father's stuff in a box, places a framed photo of himself and Gwen on his desk, he then opens his closet and takes out his uniform] [we see Sytsevich dressed in the electromechanical suit of armor rampaging through the streets with the police shooting at him]
#
# 833. Cop:
# Let's go! Move!
#
# ******** test model 1: line 831 ********
# 1 relations identified
# entities: Aunt May => , Peter, God, Gwen
# relation: No. No. God, no. I couldn't do that, it's...it's a part of me. I'm just finding a better place for it. I'm gonna take one last look and I'm gonna put it where it belongs. [in his room, Peter looks at a photo of Gwen, then grabs a USB stick which has "Gwen's Speech" written on it and places it in his computer to watch]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 264 ********
# 262. Norman Osborn:
# This is not how I imagined I would die, looking at my son and seeing a stranger. You had such potential, Harry. Such fierce intelligence, and you're throwing it all away.
#
# 263. Harry Osborn:
# No, you threw me away. You kicked me off to boarding school when I was eleven. On my sixteenth birthday you sent me scotch, or one of your assistants did. I'm pretty sure because the card read, "With compliments, Norman Osborn."
#
# => 264. Norman Osborn:
# => I don't expect forgiveness from you anymore. I don't believe in miracles. How could you possibly understand that you're a child who I'd had to be sacrificed for something greater. And not just for me, for you! Are your hands started to twitch yet? When you lay awake and you feel it coming, hiding under your skin, waiting to show itself. To show you who you really are! [Osborn coughs] Retroviral hyperplasia. I never told you, but its genetic. Our disease. The Osborn curse. And it began at your age. Let me see it. Your hand, give it to me. [Harry slowly gives his hand to Osborn who holds it in his claw like hands] The greatest inheritance I can give you isn't merely money, it's this. [he places a small drive in Harry's hand] A sum total of all my work, everything I did to stay alive. Maybe you can succeed where I failed. [Harry holds the drive in his hand] [Peter is sat in a coffee shop writing an email to his boss at the Daily Bugle with a photo of himself in his Spider-Man suit swinging away from a building]
#
# 265. Peter Parker:
# "Dear Mr. Jameson. New pix and invoice enclosed. I think you should consider that maybe Spider-Man is trying to help. Sincerely, Peter Parker." [as soon as he sends the email he sees a reply from Jameson pop up with the subject heading "Wrong!!!", just then Peter sees the news reporting Osborn's death]
#
# 266. News Reporter:
# News just in, Norman Osborn, the legendary founder and CEO of OsCorp Industries has died. The Osborn estate has confirmed he is survived by his only son, Harry Osborn, who is the sole heir of the OsCorp corporate empire...
#
# ******** test model 1: line 264 ********
# 1 relations identified
# entities: Norman Osborn => , child, Harry, boss, Peter
# relation: I don't expect forgiveness from you anymore. I don't believe in miracles. How could you possibly understand that you're a child who I'd had to be sacrificed for something greater. And not just for me, for you! Are your hands started to twitch yet? When you lay awake and you feel it coming, hiding under your skin, waiting to show itself. To show you who you really are! [Osborn coughs] Retroviral hyperplasia. I never told you, but its genetic. Our disease. The Osborn curse. And it began at your age. Let me see it. Your hand, give it to me. [Harry slowly gives his hand to Osborn who holds it in his claw like hands] The greatest inheritance I can give you isn't merely money, it's this. [he places a small drive in Harry's hand] A sum total of all my work, everything I did to stay alive. Maybe you can succeed where I failed. [Harry holds the drive in his hand] [Peter is sat in a coffee shop writing an email to his boss at the Daily Bugle with a photo of himself in his Spider-Man suit swinging away from a building]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 153 ********
# 151. Peter Parker:
# This is a wind turbine! You made this? [Gordon nods his head] No way! This is amazing! [he mends the broken wind turbine with a couple of shots of his web] As good as new, right? [he gives the project back to Gordon, who's smiling] I'll walk you home. [Peter starts walking Jorge home] What's your name?
#
# 152. Gordon:
# Gordon.
#
# => 153. Peter Parker:
# => Gordon, I'm...I'm Spider-Man. [we see a montage as the radio call-in show debates carry one while we see Peter save a girl from getting hit by a cab]
#
# 154. Radio Male Guest:
# I don't feel like my kids are safe with him out there. Get out of the way and let the police do their job!
#
# 155. Radio Female DJ:
# Some folks think that there might be more than one man. What do you think? One guy or many? [we see Peter changing his Super-Man clothes several times after he's been saving people]
#
# ******** test model 1: line 153 ********
# 1 relations identified
# entities: Peter Parker => , Gordon, Spider-Man., girl
# relation: Gordon, I'm...I'm Spider-Man. [we see a montage as the radio call-in show debates carry one while we see Peter save a girl from getting hit by a cab]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 627 ********
# 625. Peter Parker:
# Uh, my fair lady, but um, Madame, but um...uh, who am I? I mean, who am I? I'm John Hopkins.
#
# 626. Gwen Stacy:
# What?
#
# => 627. Peter Parker:
# => I'm...I'm one of the young professors at Harvard and I've been trying to get her to be in my...be a part of my team for a while now. And she's just the best person I know and a scientific genius.
#
# 628. Gwen Stacy:
# Okay.
#
# 629. Peter Parker:
# And, anyway, God save the Queen, and I'm sorry about everything happening right... [looking really embarrassed Peter turns to leave]
#
# ******** test model 1: line 627 ********
# 1 relations identified
# entities: Peter Parker => , one, person, professors
# relation: I'm...I'm one of the young professors at Harvard and I've been trying to get her to be in my...be a part of my team for a while now. And she's just the best person I know and a scientific genius.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 660 ********
# 658. Donald Menken:
# Get him out!
#
# 659. Harry Osborn:
# Wait! Wait! [Harry stops struggling and looks coldly at Menken with a smile] I know my way home. [the guards let Harry go and Menken watches as Harry walks out] [Peter goes to the Roosevelt abandoned subway station and using one of the subway tokens manages to find his father's secret lab hidden in a subterranean train cart, on the computer Peter finds his father's recorded video footage and watches it]
#
# => 660. Richard Parker:
# => Test. My name is Richard Parker. Whatever lies will be told about me, I would like the world to know the truth. OsCorp was already a leader in genetic research when Norman Osborn made a deal with a foreign military organization to continue funding my research, and I discovered what they were going to use it for. Weapons, biological weapons, of course. So I refused, and now to eliminate me from the picture, Norman Osborn has falsified evidence against me in order to take control of my work. [Harry's car pulls up to Ravencroft]
#
# 661. Ravencroft Guard #1:
# Can I help you?
#
# 662. Harry Osborn:
# Uh, yeah, you can open the gate. I'm Harry Osborn. There's a patient in that isolation unit I need to see. [the guard takes Harry inside]
#
# ******** test model 1: line 660 ********
# 2 relations identified
# entities: Richard Parker => , OsCorp, Norman Osborn, Harry, Ravencroft
# relation: Test. My name is Richard Parker. Whatever lies will be told about me, I would like the world to know the truth. OsCorp was already a leader in genetic research when Norman Osborn made a deal with a foreign military organization to continue funding my research, and I discovered what they were going to use it for. Weapons, biological weapons, of course. So I refused, and now to eliminate me from the picture, Norman Osborn has falsified evidence against me in order to take control of my work. [Harry's car pulls up to Ravencroft]
# category: 3
# entities: ['Richard Parker'] => world
# relation:  like the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 0 ********
# => 0. Richard Parker:
# => People will say that I'm a monster for what I've done, and maybe they're right. I always thought that I'd have more time... [he's interrupted by a young Peter calling out to him] Peter! [he enters his office to find that it has been ransacked with Peter standing behind his desk] [Richard takes his family to his sister's and we see Mary Parker saying goodbye to Peter]
#
# 1. Mary Parker:
# He likes to sleep with a little light on at night.
#
# 2. Richard Parker:
# Mary, we have to go. [Richard and Mary go to leave the house when Peter grabs Richard's hand]
#
# ******** test model 1: line 0 ********
# 1 relations identified
# entities: Richard Parker => , monster, Peter, People, family, sister, Mary Parker
# relation: People will say that I'm a monster for what I've done, and maybe they're right. I always thought that I'd have more time... [he's interrupted by a young Peter calling out to him] Peter! [he enters his office to find that it has been ransacked with Peter standing behind his desk] [Richard takes his family to his sister's and we see Mary Parker saying goodbye to Peter]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 563 ********
# 561. Computer:
# Warning. Electrical capacity has been reached. Initiate lockdown procedure immediately.
#
# 562. Dr. Ashley Kafka:
# Very impressive, Electro.
#
# => 563. Computer:
# => Lockdown initiated. [Max's is then lowered into water to disrupt his power] [Aunt May is sitting in Peter's room looking at the wall of information he's created about his missing parents]
#
# 564. Peter Parker:
# Aunt May? [Peter enters his room] What are you doing?
#
# 565. Aunt May:
# When did you do this? [Peter pauses before replying]
#
# ******** test model 1: line 563 ********
# 1 relations identified
# entities: Computer => , Aunt, Peter, parents
# relation: Lockdown initiated. [Max's is then lowered into water to disrupt his power] [Aunt May is sitting in Peter's room looking at the wall of information he's created about his missing parents]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 644 ********
# 642. Felicia:
# Somewhere in the building, somewhere off books called "Special Projects". [Harry starts looking up Special Projects on the computer]
#
# 643. Harry Osborn:
# "Approved by Harry Osborn."
#
# => 644. Kari:
# => Access Ravencroft archive. [Harry looks through the file and finds the footage of Max when he had his accident] File seven-one-three.
#
# 645. Harry Osborn:
# What the hell? [Harry then finds another footage of Max after his accident being tested on by Kafka]
#
# 646. Max Dillon:
# And I'm gonna kill the light so everyone in this city is gonna know how it feels to live in my world. A world without power, a world without Spider-Man.
#
# ******** test model 1: line 644 ********
# 1 relations identified
# entities: Kari => , Harry, Ravencroft, Max
# relation: Access Ravencroft archive. [Harry looks through the file and finds the footage of Max when he had his accident] File seven-one-three.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 731 ********
# 729. Air Traffic Controller #1:
# Hey, I need uh...Tech Ops up here right now.
#
# 730. Air Traffic Controller #2:
# The phones are down, somebody go down and grab Tech Ops.
#
# => 731. Air Traffic Controller #1:
# => Hey, write down what you remember, people. [back on the bridge with Peter and Gwen]
#
# 732. Peter Parker:
# There's gotta be some sort of blackout plan, right? Some kind of backup.
#
# 733. Gwen Stacy:
# There's an emergency reset at the power plant. If he cuts the transmissions lines, they're never gonna get this back up.
#
# ******** test model 1: line 731 ********
# 1 relations identified
# entities: Air Traffic Controller #1 => , people, Peter, Gwen
# relation: Hey, write down what you remember, people. [back on the bridge with Peter and Gwen]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 352 ********
# 350. Donald Menken:
# Who was he?
#
# 351. Man in Black Suit:
# Maxwell Dillon, electrical engineer. No associates or friends to speak of. He submitted specs for the grid, that we...appropriated. The guy was...invisible.
#
# => 352. Donald Menken:
# => Wall Street's nervous enough with that child Harry taking over. We've got to find a way to get him out. In the meantime, if the press gets hold of this accident, our stock will crater. So make sure that this Mr. Dillon stays invisible. This could prove useful for us in the future. [we see Max's corpse laid out in a lab, suddenly in the midst of electrical interference, Max's body reanimates in a shower of sparks, then electrical tools jump to life as Max uses his power, he then grabs a trousers and a hoody and stumbles out of the lab] [as Peter is walking home he gets a call from Gwen]
#
# 353. Peter Parker:
# Hey. [later as Gwen waits to meet him, Peter notices her from across the street and starts walking over to her crossing the busy street and a car nearly hits him]
#
# 354. Man in Car:
# Move over! Get out of the street! [he finally makes it over to Gwen]
#
# ******** test model 1: line 352 ********
# 1 relations identified
# entities: Donald Menken => , Harry, Max, Dillon, Peter, Gwen
# relation: Wall Street's nervous enough with that child Harry taking over. We've got to find a way to get him out. In the meantime, if the press gets hold of this accident, our stock will crater. So make sure that this Mr. Dillon stays invisible. This could prove useful for us in the future. [we see Max's corpse laid out in a lab, suddenly in the midst of electrical interference, Max's body reanimates in a shower of sparks, then electrical tools jump to life as Max uses his power, he then grabs a trousers and a hoody and stumbles out of the lab] [as Peter is walking home he gets a call from Gwen]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 306 ********
# 304. Harry Osborn:
# Felicia, from now on everybody at this table works for Felicia, because Felicia works for me. Would anybody like to speak up? [there's an uncomfortable silence around the meeting room table] Well, good. Then you can all keep your jobs a little longer. [they are then interrupted by the butler entering to speak to Harry]
#
# 305. Osborn Butler:
# Sir, there's a Peter Parker here to see you.
#
# => 306. Harry Osborn:
# => Felicia, I want to see every file on this list. Every single one. [Harry follows the butler out of the room] [Harry notices Peter waiting at the bottom of the steps by the front door] Peter Parker. It's like seeing a ghost.
#
# 307. Peter Parker:
# Hi, Harry.
#
# 308. Harry Osborn:
# Random...what ten years?
#
# ******** test model 1: line 306 ********
# 1 relations identified
# entities: Harry Osborn => , Felicia, butler, Peter Parker
# relation: Felicia, I want to see every file on this list. Every single one. [Harry follows the butler out of the room] [Harry notices Peter waiting at the bottom of the steps by the front door] Peter Parker. It's like seeing a ghost.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 714 ********
# 712. Cab Driver:
# It's Spider-Man! [Gwen smiles as she looks ahead]
#
# 713. Gwen Stacy:
# Stop the cab.
#
# => 714. Cab Driver:
# => Lady, I ain't even moving! [Gwen gets out of the cab and notices that Peter has written in web "I love you" on the side of the bridge, Peter then swings in and carry's Gwen off to the top of the bridge]
#
# 715. Peter Parker:
# Hi.
#
# 716. Gwen Stacy:
# Hi!
#
# ******** test model 1: line 714 ********
# 1 relations identified
# entities: Cab Driver => , Lady, Gwen, Peter
# relation: Lady, I ain't even moving! [Gwen gets out of the cab and notices that Peter has written in web "I love you" on the side of the bridge, Peter then swings in and carry's Gwen off to the top of the bridge]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 527 ********
# 525. Peter Parker:
# I know. I know, I know. This the plan, to get to the elevator I'm gonna distract them. Okay?
#
# 526. Gwen Stacy:
# Okay.
#
# => 527. Peter Parker:
# => Okay. [Peter and Gwen exit the maintenance room, Gwen heads to the elevator with Peter following behind her, Peter then uses his web shooter to grab a cup of coffee from the nearby trolley, he waits as the man in black suit comes round the corner and bumps into him dropping the coffee all over him]
#
# 528. Man in Black Suit:
# Goddammit!
#
# 529. Peter Parker:
# I'm sorry. I just spilled coffee all over you. [Peter drops to his knees to wipe the coffee and manages to trip one of the security guards coming up behind him then as he stands he throws the rest of the coffee onto the second security guard] I didn't do that! Oh, and you too! [he then forces the man in black suit's jacket down his arms as he sees Gwen by the elevator]
#
# ******** test model 1: line 527 ********
# 2 relations identified
# entities: Peter Parker => , Gwen, web shooter, man
# relation: Okay. [Peter and Gwen exit the maintenance room, Gwen heads to the elevator with Peter following behind her, Peter then uses his web shooter to grab a cup of coffee from the nearby trolley, he waits as the man in black suit comes round the corner and bumps into him dropping the coffee all over him]
# category: 3
# entities: Peter => maintenance room
# relation:  exit the maintenance
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 796 ********
# 794. Peter Parker:
# No matter what. [to Gwen as Max becomes conscious] Go! Go! [as Gwen goes to reset the system, Peter looks ahead and suddenly has a vision of Captain Stacy looking at him, but it's quickly gone as Max attacks him, at the same time at air traffic control they are keeping time on the two planes that are about to collide]
#
# 795. Dispatcher:
# Sixty seconds to impact. [back to Peter and Max who continue to battle it out then Peter creates a web to channel Max's energy and cues Gwen to flip the switch]
#
# => 796. Peter Parker:
# => Now, Gwen! Now! Do it now! [Gwen resets the swithc and the city's power starts to restore and seemingly destroys Max, back at air traffic control]
#
# 797. Air Traffic Controller #1:
# This is LaGuardia Tower, turn immediately to heading two-eight-zero. Do it. Incoming traffic, I repeat, two-eight-zero. [as the two planes are about to collide they both turn and narrowly avoid collision and everyone at airtraffic control cheers] Alright. Get back to work, lets land these planes. [at the same time the electricity in the hospital Aunt May is working comes back up]
#
# 798. Aunt May:
# Oh, thank God! Alright! Alright! We're back! Everyone, lets go! [back at the power grid, Peter manages to get up and starts making his way to Gwen]
#
# ******** test model 1: line 796 ********
# 1 relations identified
# entities: Peter Parker => , Gwen, swithc, Max
# relation: Now, Gwen! Now! Do it now! [Gwen resets the swithc and the city's power starts to restore and seemingly destroys Max, back at air traffic control]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 494 ********
# 492. Harry Osborn:
# I put together what you said at the river.
#
# 493. Peter Parker:
# What did I...?
#
# => 494. Harry Osborn:
# => About how he gives people hope. Come on. [we see the man that was following Harry and Peter earlier becoming aware that someone has accessed the OsCorp central server to find information on Max, then it cuts to Gwen who finds the system has no information on Max and her search suddenly becomes blocked] [back to Harry and Peter] Just say yes. [conflicted, Peter rises from his seat and turns away from Harry which makes Harry angry] Don't turn your back on me! I do not want to end up like my father, Peter. Please. Peter, please. I can't. [looking distraught, Harry embraces Peter] Please.
#
# 495. Peter Parker:
# I'm gonna try and find Spider-Man. [Peter then turns and leaves] [as Gwen continues her research on Max suddenly OsCorp security shows up with the man in the black suit]
#
# 496. OsCorp Employee Male:
# What's security doing over here?
#
# ******** test model 1: line 494 ********
# 1 relations identified
# entities: Harry Osborn => , Peter, people, man, someone, Max, father, Gwen
# relation: About how he gives people hope. Come on. [we see the man that was following Harry and Peter earlier becoming aware that someone has accessed the OsCorp central server to find information on Max, then it cuts to Gwen who finds the system has no information on Max and her search suddenly becomes blocked] [back to Harry and Peter] Just say yes. [conflicted, Peter rises from his seat and turns away from Harry which makes Harry angry] Don't turn your back on me! I do not want to end up like my father, Peter. Please. Peter, please. I can't. [looking distraught, Harry embraces Peter] Please.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 155 ********
# 153. Peter Parker:
# Gordon, I'm...I'm Spider-Man. [we see a montage as the radio call-in show debates carry one while we see Peter save a girl from getting hit by a cab]
#
# 154. Radio Male Guest:
# I don't feel like my kids are safe with him out there. Get out of the way and let the police do their job!
#
# => 155. Radio Female DJ:
# => Some folks think that there might be more than one man. What do you think? One guy or many? [we see Peter changing his Super-Man clothes several times after he's been saving people]
#
# 156. Radio Female Guest:
# I'd love to know who's behind that mask. [we see Peter standing in the street with a group of people wearing fancy dresses, the woman next him dressed as Statue of Liberty looks at him]
#
# 157. Fancy Dressed Pedestrian:
# Hey, nice outfit.
#
# ******** test model 1: line 155 ********
# 1 relations identified
# entities: Radio Female DJ => , folks, Peter, man, guy, people, Super-Man
# ...
#
# 778. Max Dillon:
# Spider-Man, I bet you never saw this coming. [suddenly Gwen arrives in a police car and hits max tossing him aside] [Gwen gets out of the police car and stomps over to Peter in anger]
#
# 779. Gwen Stacy:
# Really? You webbed me to a car! What are you a caveman?!
#
# ******** test model 1: line 777 ********
# 1 relations identified
# entities: Peter Parker => , Max, web shooter, Gwen Stacy, boy
# relation: You ready to give up? [Max tries to spit electricity through his mouth at Peter, but Peter uses his web shooter to hold Max up, then as Max uses his electricity on Peter's web it doesn't hurt Peter as Gwen's magnetizing trick works] Oh, thank you, Gwen Stacy. [Peter uses his web toss Max into the power grid, but at the same time the power of the electricity current throws Peter to the ground] Just shake it off. It's just your bones, your muscles and your organs. [Peter then notices Max getting back up again] Oh, boy. [Max uses his power to play Itsy Bitsy Spider Nursery tune on the power grid] I hate this song! [Max starts pummeling Peter as he bounces between the grid towers and then holds Peter up with his electricity]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 148 ********
# 146. Radio Male DJ #2:
# How about that Spider-Man? Last night on Manhatten Bridge he saved a dozen lives. We want to hear your calls.
#
# 147. Radio Male Guest #1:
# I think without Spider-Man there'd be no hope for this...
#
# => 148. Radio Male Guest #2:
# => Well who do you think pays the bills for all the damages he causes, huh? Its you and me, taxpayers! [Peter rescues a school kid from a gang of bullys attacking him, as the kids leave Peter picks up the the kids science project from the ground]
#
# 149. Peter Parker:
# You did this?
#
# 150. Gordon:
# Yes.
#
# ******** test model 1: line 148 ********
# 1 relations identified
# entities: Radio Male Guest #2 => , Peter, taxpayers, school kid, gang, kids
# relation: Well who do you think pays the bills for all the damages he causes, huh? Its you and me, taxpayers! [Peter rescues a school kid from a gang of bullys attacking him, as the kids leave Peter picks up the the kids science project from the ground]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 4 ********
# 2. Richard Parker:
# Mary, we have to go. [Richard and Mary go to leave the house when Peter grabs Richard's hand]
#
# 3. Young Peter Parker:
# Dad.
#
# => 4. Richard Parker:
# => Be good.[Richard lets go of Peter's hand and shuts the door front door, Peter watches his parents walks away; we see Richard and Mary are on a private jet]
#
# 5. Mary Parker:
# I found a safe place for us to spend the night at Lake Geneva. [Richard is uploading project files from his laptop] Are you uploading it?
#
# 6. Richard Parker:
# To Roosevelt folder, just in case we... [Mary looks out the window with worry] We're gonna be fine, Mary.
#
# ******** test model 1: line 4 ********
# 1 relations identified
# entities: Richard Parker => , Peter, parents, Mary
# relation: Be good.[Richard lets go of Peter's hand and shuts the door front door, Peter watches his parents walks away; we see Richard and Mary are on a private jet]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 843 ********
# 841. Peter Parker:
# Hey, Spider-Man. [the kids turns to face Peter, takes off his mask and smiles at Peter]
#
# 842. Jorge:
# I knew you'd come back.
#
# => 843. Peter Parker:
# => Yeah, thanks for stepping up for me. You're the bravest kid I've ever seen. I'm gonna take care of this so you can go take care of your mom, okay? [he fist pumps with the kid] Alright, get out of here. Go. Go. [the kids runs off to join his mother as the crowd cheers] [last line; a cop hands Peter a megaphone as he faces Sytsevich]
#
# 844. Aleksei Sytsevich:
# You'll fight me! You'll fight me now! Yeah?
#
# 845. Peter Parker:
# On behalf of the fine people of New York City and real rhinos everywhere, I ask you to put your mechanized palms in the air.
#
# ******** test model 1: line 843 ********
# 1 relations identified
# entities: Peter Parker => , kid, mom, mother, kids, cop, Sytsevich
# relation: Yeah, thanks for stepping up for me. You're the bravest kid I've ever seen. I'm gonna take care of this so you can go take care of your mom, okay? [he fist pumps with the kid] Alright, get out of here. Go. Go. [the kids runs off to join his mother as the crowd cheers] [last line; a cop hands Peter a megaphone as he faces Sytsevich]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 794 ********
# 792. Peter Parker:
# I think I can reconnect the power lines, but what I need you to do, I need you to reset the system. Okay, when I say, you turn that power on. You turn it on, no matter what.
#
# 793. Gwen Stacy:
# Peter.
#
# => 794. Peter Parker:
# => No matter what. [to Gwen as Max becomes conscious] Go! Go! [as Gwen goes to reset the system, Peter looks ahead and suddenly has a vision of Captain Stacy looking at him, but it's quickly gone as Max attacks him, at the same time at air traffic control they are keeping time on the two planes that are about to collide]
#
# 795. Dispatcher:
# Sixty seconds to impact. [back to Peter and Max who continue to battle it out then Peter creates a web to channel Max's energy and cues Gwen to flip the switch]
#
# 796. Peter Parker:
# Now, Gwen! Now! Do it now! [Gwen resets the swithc and the city's power starts to restore and seemingly destroys Max, back at air traffic control]
#
# ******** test model 1: line 794 ********
# 1 relations identified
# entities: Peter Parker => , Gwen, Max, Stacy
# relation: No matter what. [to Gwen as Max becomes conscious] Go! Go! [as Gwen goes to reset the system, Peter looks ahead and suddenly has a vision of Captain Stacy looking at him, but it's quickly gone as Max attacks him, at the same time at air traffic control they are keeping time on the two planes that are about to collide]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 727 ********
# 725. Peter Parker:
# You're wrong about us being on different paths. We're not on different paths, you're my path, and you're always gonna be my path. And I know there's are a million reasons why we shouldn't be together, I know that. But I'm tired of them all. I'm tired of every single one of them. So I thought I better make a choice, right? And I choose you. So, here's my thought. England. Both of us. [Gwen laughs with joy] I'm following you now. I'm just going to follow you everywhere. I'm just going to follow you the rest of my life. I mean, they...they got crime there. In England. [Gwen nods her head] They got...they got tons of crime, it seems.
#
# 726. Gwen Stacy:
# Tons.
#
# => 727. Peter Parker:
# => They got uh...Jack the Ripper. [Gwen laughs] What? They haven't caught Jack the Ripper yet. Isn't he in London? [Gwen kisses him then suddenly the electricity power in New York going out] What the hell is that? [we see Max taking down the city's power grid]
#
# 728. Gwen Stacy:
# Is that Max? He must have cut power to the whole city. [the rest of the city's electricity gets cuts off, enveloping New York in darkness and causing problems for air traffic control]
#
# 729. Air Traffic Controller #1:
# Hey, I need uh...Tech Ops up here right now.
#
# ******** test model 1: line 727 ********
# 1 relations identified
# entities: Peter Parker => , Jack the Ripper, Gwen, Max
# relation: They got uh...Jack the Ripper. [Gwen laughs] What? They haven't caught Jack the Ripper yet. Isn't he in London? [Gwen kisses him then suddenly the electricity power in New York going out] What the hell is that? [we see Max taking down the city's power grid]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 698 ********
# 696. Max Dillon:
# I had a friend once, it didn't work out.
#
# 697. Harry Osborn:
# Yeah, me too.
#
# => 698. Max Dillon:
# => Then let's go catch a spider. [as Peter is leaving the subway station he gets a voice mail from Gwen]
#
# 699. Gwen Stacy:
# Hi, Peter. It's me. Uh...I got in to Oxford. Woo-hoo. It's very exciting. I came by your house a little bit ago and I um...you weren't there. And so I'm um...I'm on my way to the airport right now, because there's this really great summer class that I found out about and I thought that it would somehow be easier, I guess, this way. [we see Gwen sitting in a cab stuck in the traffic on the way to the airport] I think that maybe it's time to let this go. And thats not because I don't love you, but its actually because I do. So um...okay, bye. [as the message ends Peter looks distraught] [at OsCorp the electricity starts to play up in the building, the man in the black suit goes to get Menken]
#
# 700. Man in Black Suit:
# We have to move, now.
#
# ******** test model 1: line 698 ********
# 1 relations identified
# entities: Peter => subway station
# relation:  leaving the subway
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 474 ********
# 472. Harry Osborn:
# Uh...late, early. I don't know, I've been up all night. I need to see you.
#
# 473. Peter Parker:
# You alright?
#
# => 474. Harry Osborn:
# => Not really, Pete. I'm dying, but I think you can help save my life. [in Harry's office, Peter and Harry are watching the footage of Richard Parter and Norman Osborn explaining their spider research]
#
# 475. Norman Osborn:
# You're looking at the world's first Human-Spider hybrids.
#
# 476. Richard Parker:
# And the hope is to extract the venom from their glands and turn that into a cure. An agent that heals diseased cells.
#
# ******** test model 1: line 474 ********
# 1 relations identified
# entities: Harry Osborn => , Pete, Peter, Richard Parter, Norman Osborn
# relation: Not really, Pete. I'm dying, but I think you can help save my life. [in Harry's office, Peter and Harry are watching the footage of Richard Parter and Norman Osborn explaining their spider research]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 819 ********
# 817. Gustav Fiers:
# Leave us. [the guard leave and closes the cell door]
#
# 818. Harry Osborn:
# You've made progress?
#
# => 819. Gustav Fiers:
# => I've identified several worthy candidates. Now that Spider-Man's gone, this city will never be the same. [we see Harry's face which is healing from his transformation]
#
# 820. Harry Osborn:
# Oh, I'm counting on that.
#
# 821. Gustav Fiers:
# Speaking of progress, you're looking better.
#
# ******** test model 1: line 819 ********
# 1 relations identified
# entities: city => face
# relation:  see Harry 's
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 463 ********
# 461. NY1 Reporter:
# That's right, we're standing here with two eyewitnesses, who are going to tell what they just saw. [turning to the two eyewitnesses] So tell us, how do think Spider-Man did it? How do you think he beat this creature?
#
# 462. Times Square Bystander:
# Yeah, it's got to be rubberized, Spidey's suit, that...that's why he didn't get electrocuted. Probably some kind of neoprene, that's what I'd use, honestly. [Peter takes his phone out and looks at a photo of himself and Gwen, he throws it aside in frustration]
#
# => 463. NY1 Reporter:
# => Okay, well, thank you very much to the two of you. As you can tell, so many questions remain unanswered. But we will bring you the latest information as it becomes available. For now, Jessica Abo for New York 1... [Peter looks at his busted web shooter then throws that back on the table, he lies down to listen to some music but becomes restless and instead takes his dad's briefcase out, empties the contents and sees the word "Roosevelt" on a notepad and starts to research the word on the internet, he then sticks up all the clippings he has on his parents on his wall and includes the photo of himself with Gwen and under it he's written "Do I have to lose you too????"] [Harry is sitting in his office listening to news coverage as he fiddles with the drive his father left him]
#
# 464. NY1 News Anchor:
# Online polls show a sudden uptick in public sentiment in favor of the web-crawler. Tonight it would seem New York City owes him a debt of gratitude. [Harry feels an itch on his neck and as he reaches to scratch it, the drive pricks his finger, he drops it onto the desk and suddenly initiates the desktop display and Harry begins to access the information on the drive about a secret battle armor]
#
# 465. Kari:
# Next generation of military body armor. Features include, enhanced mobility, battlefield injury repair, direct nervous system interface. [he then finds footage of Richard Parker with Norman Osborn explaining their research]
#
# ******** test model 1: line 463 ********
# 1 relations identified
# entities: NY1 Reporter => , Peter, two, dad, web shooter, Jessica Abo, Harry, father, Gwen, parents
# relation: Okay, well, thank you very much to the two of you. As you can tell, so many questions remain unanswered. But we will bring you the latest information as it becomes available. For now, Jessica Abo for New York 1... [Peter looks at his busted web shooter then throws that back on the table, he lies down to listen to some music but becomes restless and instead takes his dad's briefcase out, empties the contents and sees the word "Roosevelt" on a notepad and starts to research the word on the internet, he then sticks up all the clippings he has on his parents on his wall and includes the photo of himself with Gwen and under it he's written "Do I have to lose you too????"] [Harry is sitting in his office listening to news coverage as he fiddles with the drive his father left him]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 28 ********
# 26. Richard Parker:
# What?
#
# 27. Mary Parker:
# Roosevelt. [Richard grabs the laptop from the floor and quickly opens it to continue the process of uploading the files and then goes over to Mary]
#
# => 28. Richard Parker:
# => It's back up. It's back up. Everything's fine. Hey, hey, hey. We're going to be alright, okay? Listen to me... [just then the co-pilot gets up and attacks Richard, as he's hitting Richard we see that the pilot is dead and the plane falls into a steep dive, as the co-pilot and Richard are fighting he manages to shut the laptop, seeing that Mary is dead, Richard grabs hold of the co-pilot's gun and shoots a window making the co-pilot fly out of the plane, Richard manages to hold onto the laptop and finishes the process of uploading the file, he then looks at Mary as the plane plummets] [we see Peter in his Spider-Man suit falling to earth, then we follow him as makes his way though the city using the city enjoying himself]
#
# 29. Peter Parker:
# What have you got for me today, New York? [as he goes past a helicopter he overhears their radio]
#
# 30. Helicopter Radio:
# An OsCorp truck carrying plutonium has been hijacked. A police chase is in...
#
# ******** test model 1: line 28 ********
# 2 relations identified
# entities: Richard Parker => , co-pilot, co-pilot, Mary, co-pilot, Peter
# relation: It's back up. It's back up. Everything's fine. Hey, hey, hey. We're going to be alright, okay? Listen to me... [just then the co-pilot gets up and attacks Richard, as he's hitting Richard we see that the pilot is dead and the plane falls into a steep dive, as the co-pilot and Richard are fighting he manages to shut the laptop, seeing that Mary is dead, Richard grabs hold of the co-pilot's gun and shoots a window making the co-pilot fly out of the plane, Richard manages to hold onto the laptop and finishes the process of uploading the file, he then looks at Mary as the plane plummets] [we see Peter in his Spider-Man suit falling to earth, then we follow him as makes his way though the city using the city enjoying himself]
# category: 3
# entities: city => ['Charles']
# relation:  enjoying
# category: 5
#
# how many are correctly identified? 1
#
# ******** test results ********
# model 1: precision = 0.25 (13/53 correct)

# %%
df_dict['df_4']['relations'] = df_dict['df_4'].apply(lambda x:extract_relation_categories(x), axis=1)
REEval([df_dict['df_4']])
#32/60
# Out:
# ******** line 469 ********
# 467. Natasha Romanoff:
# Going after him is a dead end. I know, I've tried. [Natasha holds up the flash drive] Like you said, he's a ghost story. [Steve takes the flash drive from her]
#
# 468. Steve Rogers:
# Well, let's find out what the ghost wants. [Pierce is holding another virtual meeting with the World Security Council]
#
# => 469. Alexander Pierce:
# => Nick Fury was murdered in cold blood. To any reasonable person, that would make him a martyr, not a traitor.
#
# 470. Councilman Rockwell:
# You know what makes him a traitor? Hiring a mercenary to hijack his own ship.
#
# 471. Councilman Singh:
# Nick Fury used your friendship to coerce this council into delaying Project Insight. A project he knew would expose his own illegal operations. At best, he lied to you. At worst...
#
# ******** test model 1: line 469 ********
# 1 relations identified
# entities: Alexander Pierce => , Nick Fury, person, traitor
# relation: Nick Fury was murdered in cold blood. To any reasonable person, that would make him a martyr, not a traitor.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 449 ********
# 447. Jasper Sitwell:
# [to the SHIELD agents] Eyes here. [everyone, including Agent 13, to look at Sitwell] Whatever your op is, bury it. This is level one. Contact DOT. All traffic lights in the district go red. Shut all runways at BWI, IAD and Reagan. All security cameras in the city go through this monitor, right here. Scan all open sources. Phones, computers, PDA's, whatever. If someone Tweets about this guy, I want to know about it.
#
# 448. Sharon Carter:
# With all due respect, If SHIELD is conducting a manhunt for Captain America, we deserve to know why.
#
# => 449. Alexander Pierce:
# => Because he lied to us. [Pierce enters the room] Captain Rogers has information regarding the death of Director Fury, he refused to share it. As difficult as this is to accept, Captain America is a fugitive from SHIELD. [disguised as a civilian dressed in a hoody, Steve goes back to the hospital to retrieve the flash drive from the vending machine but sees it's gone, then Natasha appears behind him chewing some gum, in anger Steve pushes her into a room]
#
# 450. Steve Rogers:
# Where is it?
#
# 451. Natasha Romanoff:
# Safe.
#
# ******** test model 1: line 449 ********
# 2 relations identified
# entities: Alexander Pierce => , Captain America, Steve, Captain, Director Fury, Natasha, fugitive
# relation: Because he lied to us. [Pierce enters the room] Captain Rogers has information regarding the death of Director Fury, he refused to share it. As difficult as this is to accept, Captain America is a fugitive from SHIELD. [disguised as a civilian dressed in a hoody, Steve goes back to the hospital to retrieve the flash drive from the vending machine but sees it's gone, then Natasha appears behind him chewing some gum, in anger Steve pushes her into a room]
# category: 3
# entities: Pierce => room
# relation:  enters the
# category: 5
#
# how many are correctly identified? 2
#
# ******** line 877 ********
# 875. Nick Fury:
# How about you, Wilson? I could use a man with your abilities.
#
# 876. Sam Wilson:
# I'm more of a soldier than a spy.
#
# => 877. Nick Fury:
# => Alright then. [Sam and Steve shake Fury's hand] Anybody asks for me, tell them they can find me right here. [Fury looks to his gravestone and walks away, just then Natasha joins Steve and Sam]
#
# 878. Natasha Romanoff:
# You should be honored, that's about as close as he gets to saying thank you.
#
# 879. Steve Rogers:
# Not going with him?
#
# ******** test model 1: line 877 ********
# 1 relations identified
# entities: Nick Fury => , Sam, Steve, Anybody, Natasha
# relation: Alright then. [Sam and Steve shake Fury's hand] Anybody asks for me, tell them they can find me right here. [Fury looks to his gravestone and walks away, just then Natasha joins Steve and Sam]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 778 ********
# 776. Sam Wilson:
# I had to take a detour! [Sam is flying towards one of the Helicarriers when heat-seeking missiles are shot at him by HYDRA, so he flies back towards the Helicarrier and manages to get the missiles that were aimed at him to hit the Helicarrier giving him entrance] Oh, yeah! [Sam flies into the Helicarrier; to Hill] Bravo locked. [Sam flies out of the carrier]
#
# 777. Maria Hill:
# Two down, one to go.
#
# => 778. SHIELD Pilot:
# => All SHIELD pilots, scramble. We're the only air support Captain Rogers has got. [suddenly Bucky appears and starts firing at the SHIELD pilots and agents killing them all after which he gets into one of the jets and flies off; back inside the building with Natasha, Pierce and the council members]
#
# 779. Alexander Pierce:
# Disabling the encryption is an executive order, it takes two Alpha Level members.
#
# 780. Natasha Romanoff:
# Don't worry, company's coming. [just then a helicopter appears outside, lands and Fury steps out to enter the building to Pierce's surprise]
#
# ******** test model 1: line 778 ********
# 1 relations identified
# entities: SHIELD Pilot => , pilots, Rogers, Bucky, agents, council members, Natasha, Pierce
# relation: All SHIELD pilots, scramble. We're the only air support Captain Rogers has got. [suddenly Bucky appears and starts firing at the SHIELD pilots and agents killing them all after which he gets into one of the jets and flies off; back inside the building with Natasha, Pierce and the council members]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 662 ********
# 660. Steve Rogers:
# Even when I had nothing, I had Bucky. [Sam notices Natasha is bleeding from her shoulder and looks at the guards]
#
# 661. Sam Wilson:
# We need to get a doctor here. We don't put pressure on that wound she's gonna bleed out here in the truck. [suddenly one of the guards pulls out an electric rod and neutralizes the other guard and knocks him out, the guard is revealed to be Hill as she takes off her helmet]
#
# => 662. Maria Hill:
# => That thing was squeezing my brain. [Sam looks at her in confusion; to Steve] Who's this guy? [Rumlow's crew stop their vehicles and get out]
#
# 663. Brock Rumlow:
# Three holes. Start digging. [they go over to the van holding Steve, Sam and Natasha and as they open the door they find it empty with one of the guards left unconscious and massive burnt whole on the car floor]
#
# 664. Brock Rumlow:
# Three holes. Start digging. [they go over to the van holding Steve, Sam and Natasha and as they open the door they find it empty with one of the guards left unconscious and massive burnt whole on the car floor] [Hill has taken the trio to a secret facility, a man runs towards them; referring to Natasha's wound]
#
# ******** test model 1: line 662 ********
# 1 relations identified
# entities: Maria Hill => , guy, Sam, Steve, crew, Rumlow
# relation: That thing was squeezing my brain. [Sam looks at her in confusion; to Steve] Who's this guy? [Rumlow's crew stop their vehicles and get out]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 540 ********
# 538. Steve Rogers:
# Army regulations forbid storing ammunition within five hundred yards from the barracks. This building is in the wrong place. [Steve opens the lock with his shield and they enter inside, when they turn on the lights they notice it's a SHIELD office]
#
# 539. Natasha Romanoff:
# This is SHIELD.
#
# => 540. Steve Rogers:
# => Maybe where it started. [they enter a room where they find old framed portraits of Howard Stark, Peggy and Col. Chester Phillips]
#
# 541. Natasha Romanoff:
# There's Stark's father.
#
# 542. Steve Rogers:
# Howard.
#
# ******** test model 1: line 540 ********
# 2 relations identified
# entities: Steve Rogers => , Chester Phillips, Peggy, Howard Stark
# relation: Maybe where it started. [they enter a room where they find old framed portraits of Howard Stark, Peggy and Col. Chester Phillips]
# category: 3
# entities: ['Dr. Rao'] => room
# relation:  enter a
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 663 ********
# 661. Sam Wilson:
# We need to get a doctor here. We don't put pressure on that wound she's gonna bleed out here in the truck. [suddenly one of the guards pulls out an electric rod and neutralizes the other guard and knocks him out, the guard is revealed to be Hill as she takes off her helmet]
#
# 662. Maria Hill:
# That thing was squeezing my brain. [Sam looks at her in confusion; to Steve] Who's this guy? [Rumlow's crew stop their vehicles and get out]
#
# => 663. Brock Rumlow:
# => Three holes. Start digging. [they go over to the van holding Steve, Sam and Natasha and as they open the door they find it empty with one of the guards left unconscious and massive burnt whole on the car floor]
#
# 664. Brock Rumlow:
# Three holes. Start digging. [they go over to the van holding Steve, Sam and Natasha and as they open the door they find it empty with one of the guards left unconscious and massive burnt whole on the car floor] [Hill has taken the trio to a secret facility, a man runs towards them; referring to Natasha's wound]
#
# 665. Maria Hill:
# GSW. She's lost at least a pint.
#
# ******** test model 1: line 663 ********
# 2 relations identified
# entities: Brock Rumlow => , Steve, Natasha, Sam, one, guards
# relation: Three holes. Start digging. [they go over to the van holding Steve, Sam and Natasha and as they open the door they find it empty with one of the guards left unconscious and massive burnt whole on the car floor]
# category: 3
# entities: one => whole
# relation:  left unconscious and massive burnt
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 566 ********
# 564. Dr. Arnim Zola:
# Accidents will happen. [the computer screen shows them HYDRA had killed Howard and Maria Stark making it look like a car accident along with the recent death of Fury] HYDRA created a world so chaotic that humanity is finally ready to sacrifice its freedom to gain its security. Once the purification process is complete, HYDRA's new world order will arise. We won, Captain. Your death amounts to the same as your Life; a zero sum. [in anger Steve suddenly smashes the computer screen] As I was saying... What's on this drive? Project Insight requires insight. So I wrote an algorithm.
#
# 565. Natasha Romanoff:
# What kind of algorithm? What does it do?
#
# => 566. Dr. Arnim Zola:
# => The answer to your question is fascinating. Unfortunately, you shall be too dead to hear it. [suddenly the doors starts to close, Steve tries stops it by throwing his shield in between it but he's too late] Admit it, it's better this way. We're both of us...out of time. [Steve notices a small opening on the ground, he throws the metal door aside and just as the place explodes he throws himself and Natasha into the whole and protects them with his shield, he them manages to get them out from under the building rubble just as STRIKE agents arrive to roam the area for them]
#
# 567. Brock Rumlow:
# Call in the asset. [at his home, Pierce goes to his kitchen to get a drink when he sees the Winter Soldier sat behind behind him with his gun on the table when his housekeeper calls out]
#
# 568. Renata:
# I'm going to go, Mr. Pierce. You need anything before I leave?
#
# ******** test model 1: line 566 ********
# 1 relations identified
# entities: Dr. Arnim Zola => , Steve, STRIKE agents, Natasha
# relation: The answer to your question is fascinating. Unfortunately, you shall be too dead to hear it. [suddenly the doors starts to close, Steve tries stops it by throwing his shield in between it but he's too late] Admit it, it's better this way. We're both of us...out of time. [Steve notices a small opening on the ground, he throws the metal door aside and just as the place explodes he throws himself and Natasha into the whole and protects them with his shield, he them manages to get them out from under the building rubble just as STRIKE agents arrive to roam the area for them]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 551 ********
# 549. Dr. Arnim Zola:
# Rogers, Steven. Born, 1918. Romanoff, Natalia Alianovna. Born, 1984. [they see an old camera moving above them as it analyzes them]
#
# 550. Natasha Romanoff:
# It's some kind of a recording.
#
# => 551. Dr. Arnim Zola:
# => I am not a recording, Fräulein. I may not be the man I was when the Captain took me prisoner in 1945, but I am. [the computer screen shows an old photo of Dr. Arnim Zola]
#
# 552. Natasha Romanoff:
# Do you know this thing?
#
# 553. Steve Rogers:
# Arnim Zola was a German scientist who worked for the Red Skull. He's been dead for years.
#
# ******** test model 1: line 551 ********
# 1 relations identified
# entities: Dr. Arnim Zola => , Captain, man, prisoner
# relation: I am not a recording, Fräulein. I may not be the man I was when the Captain took me prisoner in 1945, but I am. [the computer screen shows an old photo of Dr. Arnim Zola]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 414 ********
# 412. Alexander Pierce:
# Well the prevailing theory was that the hijacking was a cover for the acquisition and sale of classified intelligence. The sale went sour and that led to Nick's death.
#
# 413. Steve Rogers:
# If you really knew Nick Fury you know that's not true.
#
# => 414. Alexander Pierce:
# => Why do you think we're talking? See, I took a seat on the Council not because I wanted to but because Nick asked me to, because we were both realists. We knew that despite all the diplomacy and the handshaking and the rhetoric, that to build a really better world sometimes means having to tear the old one down. And that makes enemies. Those people that call you dirty because you got the guts to stick your hands in the mud and try to build something better. And the idea that those people could be happy today, makes me really, really angry. [he hesitates a moment] Captain, you were the last one to see Nick alive. I don't think that's an accident, and I don't think you do either. So I'm gonna ask again, why was he there?
#
# 415. Steve Rogers:
# He told me not to trust anyone.
#
# 416. Alexander Pierce:
# I wonder if that included him. [Steve pauses a moment before replying]
#
# ******** test model 1: line 414 ********
# 1 relations identified
# entities: Alexander Pierce => , realists, Nick, Captain, people, people
# relation: Why do you think we're talking? See, I took a seat on the Council not because I wanted to but because Nick asked me to, because we were both realists. We knew that despite all the diplomacy and the handshaking and the rhetoric, that to build a really better world sometimes means having to tear the old one down. And that makes enemies. Those people that call you dirty because you got the guts to stick your hands in the mud and try to build something better. And the idea that those people could be happy today, makes me really, really angry. [he hesitates a moment] Captain, you were the last one to see Nick alive. I don't think that's an accident, and I don't think you do either. So I'm gonna ask again, why was he there?
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 742 ********
# 740. Com Tech #1:
# I'll check it out. [as he goes and opens the door he's faced with Steve, Sam and Hill on the other side of the door, Sam and Hill point their guns at him]
#
# 741. Steve Rogers:
# Excuse us. [the tech holds his hands up and steps aside to let them enter] [addressing the World Security Council members]
#
# => 742. Alexander Pierce:
# => I know the road hasn't exactly been smooth, and some of you would have gladly kicked me out of the car along the way. Finally we're here, and the world should be grateful. [as they start drinking to Pierce's toast suddenly they hear Steve over the SHIELD microphone that everyone in the building can hear]
#
# 743. Sam Wilson:
# Did you write that down first, or was it off the top of your head? [to Pierce after learning the truth about him]
#
# 744. Councilman Rockwell:
# You smug son of a bitch.
#
# ******** test model 1: line 742 ********
# 3 relations identified
# entities: Alexander Pierce => , some, everyone, Steve
# relation: I know the road hasn't exactly been smooth, and some of you would have gladly kicked me out of the car along the way. Finally we're here, and the world should be grateful. [as they start drinking to Pierce's toast suddenly they hear Steve over the SHIELD microphone that everyone in the building can hear]
# category: 3
# entities: road => ['Alexander Pierce']
# relation:  kicked
# category: 5
# entities: road => Steve
# relation:  hear
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 661 ********
# 659. Natasha Romanoff:
# None of that's your fault, Steve.
#
# 660. Steve Rogers:
# Even when I had nothing, I had Bucky. [Sam notices Natasha is bleeding from her shoulder and looks at the guards]
#
# => 661. Sam Wilson:
# => We need to get a doctor here. We don't put pressure on that wound she's gonna bleed out here in the truck. [suddenly one of the guards pulls out an electric rod and neutralizes the other guard and knocks him out, the guard is revealed to be Hill as she takes off her helmet]
#
# 662. Maria Hill:
# That thing was squeezing my brain. [Sam looks at her in confusion; to Steve] Who's this guy? [Rumlow's crew stop their vehicles and get out]
#
# 663. Brock Rumlow:
# Three holes. Start digging. [they go over to the van holding Steve, Sam and Natasha and as they open the door they find it empty with one of the guards left unconscious and massive burnt whole on the car floor]
#
# ******** test model 1: line 661 ********
# 1 relations identified
# entities: Sam Wilson => , doctor, Hill, guards, guard, guard, one
# relation: We need to get a doctor here. We don't put pressure on that wound she's gonna bleed out here in the truck. [suddenly one of the guards pulls out an electric rod and neutralizes the other guard and knocks him out, the guard is revealed to be Hill as she takes off her helmet]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 745 ********
# 743. Sam Wilson:
# Did you write that down first, or was it off the top of your head? [to Pierce after learning the truth about him]
#
# 744. Councilman Rockwell:
# You smug son of a bitch.
#
# => 745. Councilman Singh:
# => [to the two HYDRA agents enter the room, thinking they are SHIELD agents] Arrest him. [the HYDRA agent points his gun at Singh]
#
# 746. Alexander Pierce:
# I guess I've got the floor. [Rumlow and his men break into the control room, where Agent 13 also is, Rumlow walks over to one of the techs] Is there a problem?
#
# 747. SHIELD Tech:
# I'm... [the tech shakes his head nervously]
#
# ******** test model 1: line 745 ********
# 1 relations identified
# entities: Councilman Singh => , agents, agents, agent
# relation: [to the two HYDRA agents enter the room, thinking they are SHIELD agents] Arrest him. [the HYDRA agent points his gun at Singh]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 596 ********
# 594. Steve Rogers:
# What's this?
#
# 595. Sam Wilson:
# Call it a resume. [Natasha picks up a photo of Sam with his para-rescue team]
#
# => 596. Natasha Romanoff:
# => Is this Bakhmala? The Khalid Khandil mission, that was you. [to Steve] You didn't say he was a para-rescue. [looking at the photo of Sam with his colleague]
#
# 597. Steve Rogers:
# Is this Riley?
#
# 598. Sam Wilson:
# Yeah.
#
# ******** test model 1: line 596 ********
# 1 relations identified
# entities: Natasha Romanoff => , Bakhmala, Steve, Sam, Khalid Khandil, colleague, para-rescue
# relation: Is this Bakhmala? The Khalid Khandil mission, that was you. [to Steve] You didn't say he was a para-rescue. [looking at the photo of Sam with his colleague]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 142 ********
# 140. narrator:
# Steve puts the shield on his back and takes off his mask
#
# 141. Steve Rogers:
# [subtitled] Let's find out.
#
# => 142. narrator:
# => they start fighting again, Steve manages to finally knock Batroc down by smashing through into one of the rooms where Natasha is downloading something from the computer
#
# 143. Natasha Romanoff:
# Well, this is awkward.
#
# 144. Steve Rogers:
# What are you doing?
#
# ******** test model 1: line 142 ********
# 1 relations identified
# entities: narrator => , Steve, Batroc, Natasha
# relation: they start fighting again, Steve manages to finally knock Batroc down by smashing through into one of the rooms where Natasha is downloading something from the computer
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 867 ********
# 865. Natasha Romanoff:
# HYDRA was selling you lies, not intelligence.
#
# 866. Committee General:
# Many of which you seem to have had a personal hand in telling.
#
# => 867. Scudder:
# => Agent, you should know that there are some on this committee who feel, given your service record, both for this country and against it, that you belong in a penitentiary, not mouthing off on Capitol Hill.
#
# 868. Natasha Romanoff:
# You're not gonna put me in a prison. You're not gonna put any of us in a prison. You know why?
#
# 869. Scudder:
# Do enlighten us.
#
# ******** test model 1: line 867 ********
# 1 relations identified
# entities: Scudder => , Agent, some, both
# relation: Agent, you should know that there are some on this committee who feel, given your service record, both for this country and against it, that you belong in a penitentiary, not mouthing off on Capitol Hill.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 564 ********
# 562. Dr. Arnim Zola:
# Accessing archive. [the computer screen shows them old footage of Johann Schmidt/Red Skull, of the how the original SHIELD founders] HYDRA was founded on the belief that humanity could not be trusted with its own freedom. What we did not realize, was that if you try to take that freedom, they resist. The war taught us much. Humanity needed to surrender its freedom willingly. After the war, SHIELD was founded and I was recruited. The new HYDRA grew. A beautiful parasite inside SHIELD. For seventy years HYDRA has been secretly feeding crisis, reaping war. And when history did not cooperate, history was changed.
#
# 563. Natasha Romanoff:
# That's impossible, SHIELD would have stopped you.
#
# => 564. Dr. Arnim Zola:
# => Accidents will happen. [the computer screen shows them HYDRA had killed Howard and Maria Stark making it look like a car accident along with the recent death of Fury] HYDRA created a world so chaotic that humanity is finally ready to sacrifice its freedom to gain its security. Once the purification process is complete, HYDRA's new world order will arise. We won, Captain. Your death amounts to the same as your Life; a zero sum. [in anger Steve suddenly smashes the computer screen] As I was saying... What's on this drive? Project Insight requires insight. So I wrote an algorithm.
#
# 565. Natasha Romanoff:
# What kind of algorithm? What does it do?
#
# 566. Dr. Arnim Zola:
# The answer to your question is fascinating. Unfortunately, you shall be too dead to hear it. [suddenly the doors starts to close, Steve tries stops it by throwing his shield in between it but he's too late] Admit it, it's better this way. We're both of us...out of time. [Steve notices a small opening on the ground, he throws the metal door aside and just as the place explodes he throws himself and Natasha into the whole and protects them with his shield, he them manages to get them out from under the building rubble just as STRIKE agents arrive to roam the area for them]
#
# ******** test model 1: line 564 ********
# 2 relations identified
# entities: Dr. Arnim Zola => , Howard, humanity, Maria Stark, Captain, Steve
# relation: Accidents will happen. [the computer screen shows them HYDRA had killed Howard and Maria Stark making it look like a car accident along with the recent death of Fury] HYDRA created a world so chaotic that humanity is finally ready to sacrifice its freedom to gain its security. Once the purification process is complete, HYDRA's new world order will arise. We won, Captain. Your death amounts to the same as your Life; a zero sum. [in anger Steve suddenly smashes the computer screen] As I was saying... What's on this drive? Project Insight requires insight. So I wrote an algorithm.
# category: 3
# entities: HYDRA => world
# relation:  created a
# category: 5
#
# how many are correctly identified? 2
#
# ******** line 820 ********
# 818. Alexander Pierce:
# Lieutenant, how much longer?
#
# 819. Charlie Weapons Tech:
# Sixty-five seconds to satellite link. Target reengaged. Lowering weapons array now.
#
# => 820. Maria Hill:
# => [to Steve as she watches from the monitor] One minute. [Steve desperately tries to get back up to the Helicarriers to get to the targeting system when Bucky becomes conscious and shoots at Steve, but Steve still manages to climb up] Thirty seconds, Cap!
#
# 821. Steve Rogers:
# Stand by. [as he gets the chip out Bucky shoots Steve in the stomach and he falls]
#
# 822. Charlie Weapons Tech:
# We've reached three thousand feet. Satellite coming online now.
#
# ******** test model 1: line 820 ********
# 1 relations identified
# entities: Maria Hill => , Steve, Bucky, Helicarriers
# relation: [to Steve as she watches from the monitor] One minute. [Steve desperately tries to get back up to the Helicarriers to get to the targeting system when Bucky becomes conscious and shoots at Steve, but Steve still manages to climb up] Thirty seconds, Cap!
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 447 ********
# 445. Jasper Sitwell:
# Are you kidding me? [ordering the STRIKE team] He's headed for the garage. Lock down the bridge! [Steve rides out of the SHIELD garage on his motorcycle, evading the obstacles laid out but then a Quinjet emerges ahead of him]
#
# 446. Quinjet Pilot:
# Stand down, Captain Rogers. Stand down. [the Quinjet lowers it's machine gun] Repeat, stand down. [as Steve doesn't stop they start shooting at him, Steve throws his shield into the propellers to jam it, giving him an opportunity to hop onto it and do more damage to the jet with his shield before jumping off as the jet goes crashing down and he escapes]
#
# => 447. Jasper Sitwell:
# => [to the SHIELD agents] Eyes here. [everyone, including Agent 13, to look at Sitwell] Whatever your op is, bury it. This is level one. Contact DOT. All traffic lights in the district go red. Shut all runways at BWI, IAD and Reagan. All security cameras in the city go through this monitor, right here. Scan all open sources. Phones, computers, PDA's, whatever. If someone Tweets about this guy, I want to know about it.
#
# 448. Sharon Carter:
# With all due respect, If SHIELD is conducting a manhunt for Captain America, we deserve to know why.
#
# 449. Alexander Pierce:
# Because he lied to us. [Pierce enters the room] Captain Rogers has information regarding the death of Director Fury, he refused to share it. As difficult as this is to accept, Captain America is a fugitive from SHIELD. [disguised as a civilian dressed in a hoody, Steve goes back to the hospital to retrieve the flash drive from the vending machine but sees it's gone, then Natasha appears behind him chewing some gum, in anger Steve pushes her into a room]
#
# ******** test model 1: line 447 ********
# 1 relations identified
# entities: Jasper Sitwell => , agents, everyone, someone, Reagan, guy
# relation: [to the SHIELD agents] Eyes here. [everyone, including Agent 13, to look at Sitwell] Whatever your op is, bury it. This is level one. Contact DOT. All traffic lights in the district go red. Shut all runways at BWI, IAD and Reagan. All security cameras in the city go through this monitor, right here. Scan all open sources. Phones, computers, PDA's, whatever. If someone Tweets about this guy, I want to know about it.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 646 ********
# 644. Natasha Romanoff:
# Insight's launching in sixteen hours, we're cutting it a little bit close here.
#
# 645. Steve Rogers:
# I know. We'll use him to bypass the DNA scans and access the Helicarriers directly.
#
# => 646. Jasper Sitwell:
# => What?! Are you crazy? That is a terrible, terrible idea. [suddenly the Winter Soldier lands on the car roof, pulls Sitwell out through the window and throws him into the oncoming traffic, killing him, he then starts shooting at them until Steve pulls the break handle making the Winter Soldier drop down onto the street, as another car smashes into the trio's car and pushes them along, the Winter Soldier jumps back onto their car, smashes through the windscreen and pulls out the steering wheel]
#
# 647. Sam Wilson:
# Shit! [Natasha starts shooting at him but the Winter Soldier jumps onto the vehicle behind them, as the trio's car is being pulled off the road Steve holds on to the car door]
#
# 648. Steve Rogers:
# Hang on! [he breaks open the door, holding onto Natasha and Sam, they slide on the car door through the streets] [the Winter Soldier is joined by HYDRA agents and they start shooting at them, the trio scatter and run off in different directions with the Winter Soldier shooting at Natasha but she manages to shoot him in his eye goggle mask and run off]
#
# ******** test model 1: line 646 ********
# 3 relations identified
# entities: Jasper Sitwell => , Winter Soldier, Steve, trio
# relation: What?! Are you crazy? That is a terrible, terrible idea. [suddenly the Winter Soldier lands on the car roof, pulls Sitwell out through the window and throws him into the oncoming traffic, killing him, he then starts shooting at them until Steve pulls the break handle making the Winter Soldier drop down onto the street, as another car smashes into the trio's car and pushes them along, the Winter Soldier jumps back onto their car, smashes through the windscreen and pulls out the steering wheel]
# category: 3
# entities: lands => Sitwell
# relation:  pulls
# category: 5
# entities: lands => handle
# relation:  pulls the break
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 577 ********
# 575. Steve Rogers:
# I'm sorry about this. We need a place to lay low.
#
# 576. Natasha Romanoff:
# Everyone we know is trying to kill us. [Sam pauses a moment before replying]
#
# => 577. Sam Wilson:
# => Not everyone. [Sam let's them enter, later as Steve and Natasha are cleaning up, Steve notices Natasha looking sad and thoughtful]
#
# 578. Steve Rogers:
# You okay?
#
# 579. Natasha Romanoff:
# Yeah.
#
# ******** test model 1: line 577 ********
# 1 relations identified
# entities: Sam Wilson => , everyone, Steve, Natasha
# relation: Not everyone. [Sam let's them enter, later as Steve and Natasha are cleaning up, Steve notices Natasha looking sad and thoughtful]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 463 ********
# 461. Natasha Romanoff:
# Well, it makes sense. The ship was dirty, Fury needed a way in, so do you.
#
# 462. Steve Rogers:
# I'm not gonna ask you again.
#
# => 463. Natasha Romanoff:
# => I know who killed Fury. Most of the intelligence community doesn't believe he exists, the ones who do call him the Winter Soldier. He's credited with over two dozen assassinations in the last fifty years.
#
# 464. Steve Rogers:
# So he's a ghost story.
#
# 465. Natasha Romanoff:
# Five years ago I was escorting a nuclear engineer out of Iran, somebody shot at my tires near Odessa. We lost control, went straight over a cliff, I pulled us out, but the Winter Soldier was there. I was covering my engineer, so he shot him straight through me. [she pulls up her shirt to show him the bullet wound on the side of her stomach] A Soviet slag, no rifling. Bye-bye bikinis.
#
# ******** test model 1: line 463 ********
# 1 relations identified
# entities: Natasha Romanoff => , Most, ones, Winter Soldier
# relation: I know who killed Fury. Most of the intelligence community doesn't believe he exists, the ones who do call him the Winter Soldier. He's credited with over two dozen assassinations in the last fifty years.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 287 ********
# 285. Female War Veteran:
# The thing is I think it's getting worse. A cop pulled me over last week, he thought I was drunk. I swerved to miss a plastic bag. I thought it was an IED.
#
# 286. Sam Wilson:
# Some stuff you leave there, other stuff you bring back. It's our job to figure out how to carry it. Is it gonna be in a big suitcase or in a little man-purse? It's up to you.
#
# => 287. narrator:
# => after the meeting ends Steve waits for Sam as he finishes saying goodbye to the veterans
#
# 288. Female War Veteran:
# I'll see you next week.
#
# 289. Sam Wilson:
# Yeah.
#
# ******** test model 1: line 287 ********
# 1 relations identified
# entities: narrator => , Sam, Steve, veterans
# relation: after the meeting ends Steve waits for Sam as he finishes saying goodbye to the veterans
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 842 ********
# 840. Nick Fury:
# Romanoff! Natasha! Natasha, come on! [Natasha opens her eyes]
#
# 841. Natasha Romanoff:
# Ow. Those really do sting. [as the Helicarriers continue to destroy each other Pierce lies on the floor and says with his last dieing breath]
#
# => 842. Alexander Pierce:
# => Hail, HYDRA. [just then one Helicarrier crashes into a dam beneath the Triskelion] [as the Helicarrier continues to fall with Cap and Winter Soldier inside, at the Triskelion Sam and Rumlow continue to fight each other]
#
# 843. Brock Rumlow:
# You're out of your depth, kid. [suddenly the second Helicarriers crashes into the Triskelion, catching Rumlow in the destruction; to Natasha who is in the helicopter]
#
# 844. Sam Wilson:
# Please, tell me you got that chopper in the air!
#
# ******** test model 1: line 842 ********
# 1 relations identified
# entities: Alexander Pierce => , Helicarrier, each other, Rumlow, Winter Soldier
# relation: Hail, HYDRA. [just then one Helicarrier crashes into a dam beneath the Triskelion] [as the Helicarrier continues to fall with Cap and Winter Soldier inside, at the Triskelion Sam and Rumlow continue to fight each other]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 753 ********
# 751. Sharon Carter:
# Like he said! [suddenly all the SHIELD agents draw their weapons and point them at Rumlow] Captain's orders.
#
# 752. Brock Rumlow:
# You picked the wrong side, Agent.
#
# => 753. Sharon Carter:
# => Depends on where you're standing. [Rumlow drops his gun, but as he does he grabs his knife and cuts Agent 13's arm, leading to the SHIELD agents firing their guns, amidst the bullets, Rumlow manages to release the Helicarriers and runs off] [as the bay doors holding the Helicarriers are about to be opened]
#
# 754. SHIELD Agent:
# Close the bay door! Close the bay door now! Close the bay door! [the HYDRA agents enter and start shooting and killing the crew and techs; at the headquarters Hill watches on the monitor as the Helicarriers are being initiated]
#
# 755. Maria Hill:
# They're initiating launch. [Steve and Sam make their way to the Helicarriers]
#
# ******** test model 1: line 753 ********
# 1 relations identified
# entities: Sharon Carter => , Rumlow, agents, Agent, Helicarriers
# relation: Depends on where you're standing. [Rumlow drops his gun, but as he does he grabs his knife and cuts Agent 13's arm, leading to the SHIELD agents firing their guns, amidst the bullets, Rumlow manages to release the Helicarriers and runs off] [as the bay doors holding the Helicarriers are about to be opened]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 227 ********
# 225. Steve Rogers:
# For as long as I can remember I just wanted to do what was right. I guess I'm not quite sure what that is anymore. And I thought I could throw myself back in and follow orders, serve. It's just not the same.
#
# 226. narrator:
# Peggy chuckles
#
# => 227. Peggy Carter:
# => You're always so dramatic. Look, you saved the world. We rather...mucked it up.
#
# 228. Steve Rogers:
# You didn't. Knowing that you helped found SHIELD is half the reason I stay.
#
# 229. narrator:
# Peggy takes Steve's hand
#
# ******** test model 1: line 227 ********
# 1 relations identified
# entities: ['narrator'] => world
# relation:  saved the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 341 ********
# 339. Sharon Carter:
# Well hopefully not too far. [Steve nods and turns to go into his apartment] Oh, and I think you left your stereo on.
#
# 340. Steve Rogers:
# Oh. Right, thank you.
#
# => 341. Sharon Carter:
# => Yeah. [Steve watches her go down the stairs before turning in suspicion to his door] [Steve hears music as he cautiously enters his apartment though the window, he grabs his shield for protection and finds Fury sitting on his couch in the dark]
#
# 342. Steve Rogers:
# I don't remember giving you a key.
#
# 343. Nick Fury:
# You really think I'd need one? My wife kicked me out.
#
# ******** test model 1: line 341 ********
# 1 relations identified
# entities: ['Jean'] => apartment
# relation:  enters his
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 834 ********
# 832. Steve Rogers:
# Fire now.
#
# 833. Maria Hill:
# But, Steve...
#
# => 834. Steve Rogers:
# => Do it! Do it now! [reluctantly Hill makes the Helicarriers open fire on each other, Steve still inside the Helicarrier looks at Bucky below him; back at the Triskelion Pierce watches the Helicarriers as they are firing at each other]
#
# 835. Alexander Pierce:
# What a waste.
#
# 836. Natasha Romanoff:
# Are you still on the fence about Roger's chances?
#
# ******** test model 1: line 834 ********
# 1 relations identified
# entities: Steve Rogers => , Bucky, each other, Helicarrier, Hill, Triskelion Pierce
# relation: Do it! Do it now! [reluctantly Hill makes the Helicarriers open fire on each other, Steve still inside the Helicarrier looks at Bucky below him; back at the Triskelion Pierce watches the Helicarriers as they are firing at each other]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 636 ********
# 634. Jasper Sitwell:
# Zola's algorithm is a program...for choosing Insight's targets!
#
# 635. Steve Rogers:
# What targets?
#
# => 636. Jasper Sitwell:
# => You! A TV anchor in Cairo, the Undersecretary of Defense, a high school valedictorian in Iowa city. Bruce Banner, Stephen Strange, anyone who's a threat to HYDRA! Now, or in the future.
#
# 637. Steve Rogers:
# The Future? How could it know? [Sitwell laughs]
#
# 638. Jasper Sitwell:
# How could it not? The 21st century is a digital book. Zola taught HYDRA how to read it. [Steve and Natasha look at him in confusion] Your bank records, medical histories, voting patterns, e-mails, phone calls, your damn SAT scores. Zola's algorithm evaluates peoples' past to predict their future.
#
# ******** test model 1: line 636 ********
# 1 relations identified
# entities: Jasper Sitwell => , high school valedictorian, Bruce Banner, Stephen Strange
# relation: You! A TV anchor in Cairo, the Undersecretary of Defense, a high school valedictorian in Iowa city. Bruce Banner, Stephen Strange, anyone who's a threat to HYDRA! Now, or in the future.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 648 ********
# 646. Jasper Sitwell:
# What?! Are you crazy? That is a terrible, terrible idea. [suddenly the Winter Soldier lands on the car roof, pulls Sitwell out through the window and throws him into the oncoming traffic, killing him, he then starts shooting at them until Steve pulls the break handle making the Winter Soldier drop down onto the street, as another car smashes into the trio's car and pushes them along, the Winter Soldier jumps back onto their car, smashes through the windscreen and pulls out the steering wheel]
#
# 647. Sam Wilson:
# Shit! [Natasha starts shooting at him but the Winter Soldier jumps onto the vehicle behind them, as the trio's car is being pulled off the road Steve holds on to the car door]
#
# => 648. Steve Rogers:
# => Hang on! [he breaks open the door, holding onto Natasha and Sam, they slide on the car door through the streets] [the Winter Soldier is joined by HYDRA agents and they start shooting at them, the trio scatter and run off in different directions with the Winter Soldier shooting at Natasha but she manages to shoot him in his eye goggle mask and run off]
#
# 649. Winter Soldier:
# [subtitled] I'll take care of her. Find him. [the Winter Soldier goes in pursuit of Natasha as the Hydra agents go after Steve and Sam who both manage to fend them off as they shoot at them, Steve then notices the Winter Soldier in pursuit of Natasha]
#
# 650. Sam Wilson:
# Go, I got this! [the Winter Soldier thinks he's found Natasha hiding behind a car as he can hear her voice]
#
# ******** test model 1: line 648 ********
# 1 relations identified
# entities: Steve Rogers => , Natasha, Winter Soldier, agents, Sam
# relation: Hang on! [he breaks open the door, holding onto Natasha and Sam, they slide on the car door through the streets] [the Winter Soldier is joined by HYDRA agents and they start shooting at them, the trio scatter and run off in different directions with the Winter Soldier shooting at Natasha but she manages to shoot him in his eye goggle mask and run off]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 391 ********
# 389. Brock Rumlow:
# I told him. [Steve suddenly notices the vending machine next to him, we then see Steve walking towards Rumlow]
#
# 390. Steve Rogers:
# Let's go.
#
# => 391. Brock Rumlow:
# => Yeah. [to the agents] STRIKE, move it out. [as they leave we see that Steve has hid the flash drive behind a pack of gums in the vending machine] [back at SHIELD, Steve is brought to Pierce who is talking to Agent 13]
#
# 392. Alexander Pierce:
# For whatever it's worth, you did your best.
#
# 393. Sharon Carter:
# Thank you, sir. [as she turns to leave she sees Steve] Captain Rogers. [Steve replies coldly as he walks towards Pierce]
#
# ******** test model 1: line 391 ********
# 1 relations identified
# entities: Brock Rumlow => , agents, Yeah., Pierce, Steve
# relation: Yeah. [to the agents] STRIKE, move it out. [as they leave we see that Steve has hid the flash drive behind a pack of gums in the vending machine] [back at SHIELD, Steve is brought to Pierce who is talking to Agent 13]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 679 ********
# 677. Dr. Arnim Zola:
# Sergeant Barnes... [he has to flashback to falling off the train at the edge of the mountain with Steve trying to save him]
#
# 678. Steve Rogers:
# Bucky, no! [he then has flashback to after he's picked up by Hydra agents]
#
# => 679. Dr. Arnim Zola:
# => The procedure has already started. [we see the Zola and the Hydra agent amputating his left arm and replacing with the metal arm] You are to be the new face of HYDRA. [to his men] Put him on ice. [we see Bucky being frozen after which he comes back to the present and knocks over the HYDRA agent fixing his arm, Rollins points his gun at him to stop him attacking any further] [as Pierce enters the bank vault Bucky is being held in]
#
# 680. Scientist #1:
# Sir, he's...he's unstable. Erratic. [Pierce enters with Rumlow and some other HYDRA agents and goes over to Bucky]
#
# 681. Alexander Pierce:
# Mission report. [Bucky; looking blank, doesn't respond] Mission report, now. [Pierce moves closer to Bucky and suddenly strikes him hard in the face]
#
# ******** test model 1: line 679 ********
# 1 relations identified
# entities: Dr. Arnim Zola => , Bucky, agent, men, agent, Pierce, Rollins
# relation: The procedure has already started. [we see the Zola and the Hydra agent amputating his left arm and replacing with the metal arm] You are to be the new face of HYDRA. [to his men] Put him on ice. [we see Bucky being frozen after which he comes back to the present and knocks over the HYDRA agent fixing his arm, Rollins points his gun at him to stop him attacking any further] [as Pierce enters the bank vault Bucky is being held in]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 254 ********
# 252. SHIELD Computer:
# Confirmed.
#
# 253. narrator:
# Alexander Pierce is holding a virtual meeting with the World Security Council
#
# => 254. Councilman Rockwell:
# => If Nick Fury thinks he can get us costumed thugs and STRIKE commandos to mop-up his mess, he's sadly mistaken. This failure is unacceptable.
#
# 255. Councilman Singh:
# Well, considering this attack took place one mile from my country's sovereign waters, it's a bit more then that. I move for immediate hearing.
#
# 256. Councilwoman Hawley:
# We don't need hearings, we need action. It's this Council's duty to oversee SHIELD.
#
# ******** test model 1: line 254 ********
# 1 relations identified
# entities: Councilman Rockwell => , Nick Fury, STRIKE commandos, thugs
# relation: If Nick Fury thinks he can get us costumed thugs and STRIKE commandos to mop-up his mess, he's sadly mistaken. This failure is unacceptable.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 740 ********
# 738. Com Tech #1:
# Negative, DT-6. The pattern is full. [to his colleague] Well, he could have said something. [suddenly they hear a sharp noise through their earpiece] Ow!
#
# 739. Com Tech #2:
# Must be the dish.
#
# => 740. Com Tech #1:
# => I'll check it out. [as he goes and opens the door he's faced with Steve, Sam and Hill on the other side of the door, Sam and Hill point their guns at him]
#
# 741. Steve Rogers:
# Excuse us. [the tech holds his hands up and steps aside to let them enter] [addressing the World Security Council members]
#
# 742. Alexander Pierce:
# I know the road hasn't exactly been smooth, and some of you would have gladly kicked me out of the car along the way. Finally we're here, and the world should be grateful. [as they start drinking to Pierce's toast suddenly they hear Steve over the SHIELD microphone that everyone in the building can hear]
#
# ******** test model 1: line 740 ********
# 1 relations identified
# entities: Com Tech #1 => , Sam, Steve, Sam, Hill
# relation: I'll check it out. [as he goes and opens the door he's faced with Steve, Sam and Hill on the other side of the door, Sam and Hill point their guns at him]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 418 ********
# 416. Alexander Pierce:
# I wonder if that included him. [Steve pauses a moment before replying]
#
# 417. Steve Rogers:
# I'm sorry. Those were his last words. Excuse me. [Steve picks up his shield, places it on his back and starts to make his out of the office]
#
# => 418. Alexander Pierce:
# => Captain. [Steve stops and looks at Pierce] Somebody murdered my friend and I'm gonna find out why. Anyone gets in my way, they're gonna regret it. Anyone.
#
# 419. Steve Rogers:
# Understood. [Steve turns and leaves] [after Steve leaves Pierce's office he steps into the elevator] Operations control.
#
# 420. SHIELD Computer:
# Confirmed. [just as the elevator doors are about to close Rumlow steps in with two STRIKE agents]
#
# ******** test model 1: line 418 ********
# 1 relations identified
# entities: Alexander Pierce => , Captain, Steve, Somebody, friend, Anyone, Anyone
# relation: Captain. [Steve stops and looks at Pierce] Somebody murdered my friend and I'm gonna find out why. Anyone gets in my way, they're gonna regret it. Anyone.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 814 ********
# 812. Steve Rogers:
# People are gonna die, Buck. I can't let that happen. [Bucky stares at him coldly] Please, don't make me do this. [seeing Bucky won't back down Steve throws his shield at him and they start battling each other, as they fight Steve manages to bring up the targeting blade system, but as Bucky attacks him the chip falls from Steve's hand; back at the Council]
#
# 813. Natasha Romanoff:
# Done. [she looks at her mobile device] And it's trending. [just them Pierce sets off the pins he gave the council members, causing it to burn deeply into their sternum, Natasha and Fury points their guns at Pierce; to Natasha]
#
# => 814. Alexander Pierce:
# => Unless you want two inch hole in your sternum, I'd put that gun down. [Natasha doesn't back down] That was armed the moment you pinned it on. [Fury and Natasha reluctantly lower their weapons] [back at the Helicarrier as they are battling it out, Bucky stabs Steve in the shoulder with his knife and then grabs the fallen chip, but Steve manages to get the knife out, grab Bucky by the throat and hold him down]
#
# 815. Steve Rogers:
# Drop it! Drop it! [as Bucky continues to hold the chip, Steve breaks both of Bucky's arms and holds on to his throat until he passes out and lets go of the chip, Steve then grabs the chip and rushes off; back at the Triskelion]
#
# 816. Brock Rumlow:
# ...
#
# => 813. Natasha Romanoff:
# => Done. [she looks at her mobile device] And it's trending. [just them Pierce sets off the pins he gave the council members, causing it to burn deeply into their sternum, Natasha and Fury points their guns at Pierce; to Natasha]
#
# 814. Alexander Pierce:
# Unless you want two inch hole in your sternum, I'd put that gun down. [Natasha doesn't back down] That was armed the moment you pinned it on. [Fury and Natasha reluctantly lower their weapons] [back at the Helicarrier as they are battling it out, Bucky stabs Steve in the shoulder with his knife and then grabs the fallen chip, but Steve manages to get the knife out, grab Bucky by the throat and hold him down]
#
# 815. Steve Rogers:
# Drop it! Drop it! [as Bucky continues to hold the chip, Steve breaks both of Bucky's arms and holds on to his throat until he passes out and lets go of the chip, Steve then grabs the chip and rushes off; back at the Triskelion]
#
# ******** test model 1: line 813 ********
# 3 relations identified
# entities: Pierce => pins
# relation:  sets off the
# category: 5
# entities: Pierce => members
# relation:  gave the council
# category: 5
# entities: Pierce => guns
# relation:  points their
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 573 ********
# 571. Alexander Pierce:
# Good night. [Renata leaves] Want some milk? [the Winter Soldier doesn't reply] The timetable has moved. Our window is limited. Two targets, level six. [he pours himself a glass of milk and goes over to join the Winter Soldier at the table] They already cost me Zola. I want confirmed death in ten hours. [just then Renata interrupts them as she enters the kitchen]
#
# 572. Renata:
# Sorry, Mr. Pierce, I...I forgot my phone. [she notices the Winter Soldier]
#
# => 573. Alexander Pierce:
# => Oh, Renata. I wish you would have knocked. [Pierce picks up the gun from the table and shoots and kills her] [returning home from his morning run Sam hears a knock at his door, he opens the door to see Steve and Natasha]
#
# 574. Sam Wilson:
# Hey, man.
#
# 575. Steve Rogers:
# I'm sorry about this. We need a place to lay low.
#
# ******** test model 1: line 573 ********
# 1 relations identified
# entities: Alexander Pierce => , Sam, Natasha, Steve
# relation: Oh, Renata. I wish you would have knocked. [Pierce picks up the gun from the table and shoots and kills her] [returning home from his morning run Sam hears a knock at his door, he opens the door to see Steve and Natasha]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 134 ********
# 132. French Pirate:
# [subtitled] Hello? Batroc, the line is dead. I lost contact with them.
#
# 133. narrator:
# just then Steve smashes in through the window using his shield but Batroc manages to escape; to Steve as he goes looking for Batroc
#
# => 134. Brock Rumlow:
# => Hostages enroot to extraction. Romanoff missed the rendezvous point, Captain. Hostiles are still in play.
#
# 135. Steve Rogers:
# Natasha, Batroc's on the move. Circle back to Rumlow and protect the hostages.
#
# 136. narrator:
# there's no reply from Natasha
#
# ******** test model 1: line 134 ********
# 1 relations identified
# entities: Brock Rumlow => , Hostages, Captain, Romanoff, Hostiles
# relation: Hostages enroot to extraction. Romanoff missed the rendezvous point, Captain. Hostiles are still in play.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 135 ********
# 133. narrator:
# just then Steve smashes in through the window using his shield but Batroc manages to escape; to Steve as he goes looking for Batroc
#
# 134. Brock Rumlow:
# Hostages enroot to extraction. Romanoff missed the rendezvous point, Captain. Hostiles are still in play.
#
# => 135. Steve Rogers:
# => Natasha, Batroc's on the move. Circle back to Rumlow and protect the hostages.
#
# 136. narrator:
# there's no reply from Natasha
#
# 137. Steve Rogers:
# Natasha!
#
# ******** test model 1: line 135 ********
# 1 relations identified
# entities: Steve Rogers => , Natasha, Batroc, hostages, Rumlow
# relation: Natasha, Batroc's on the move. Circle back to Rumlow and protect the hostages.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 859 ********
# 857. Steve Rogers:
# I'm not gonna fight you. You're my friend. [Bucky pushes Steve to the ground]
#
# 858. Bucky Barnes:
# You're my mission. [he then mercilessly punches Steve repeatedly across the face] You're my mission!
#
# => 859. Steve Rogers:
# => Then finish it. [Bucky hesitates holding his fist up] Cause I'm with you to the end of the line. [Bucky looks at Steve as if he's starting to remember just then the bottom of the Helicarrier falls sending Steve down into the river below as Bucky watches from the Helicarrier, then we see an unconscious Steve being pulled out of the water and dragged onto the shore by Bucky before he turns and walks away] [we see Steve waking up in a hospital bed to hear Marvin Gaye's "Trouble Man" playing with Sam sat next to his bed] On your left. [Sam looks at Steve and smiles; we then see Agent 13 practicing shooting at a shooting range wearing a CIA t-shirt; we see Hill at Stark Industries about to undergo a lie detector test; then Senator Stern getting arrested and then a badly burnt Rumlow being treated by doctors at the hospital; Natasha is then being sworn in at a committee hearing]
#
# 860. Committee Member:
# Do you solemnly swear to tell the truth the whole truth and nothing but the truth?
#
# 861. Natasha Romanoff:
# I do.
#
# ******** test model 1: line 859 ********
# 1 relations identified
# entities: Steve Rogers => , Bucky, Stern, Sam, Marvin Gaye, Trouble Man, doctors, Hill, Rumlow, Natasha
# relation: Then finish it. [Bucky hesitates holding his fist up] Cause I'm with you to the end of the line. [Bucky looks at Steve as if he's starting to remember just then the bottom of the Helicarrier falls sending Steve down into the river below as Bucky watches from the Helicarrier, then we see an unconscious Steve being pulled out of the water and dragged onto the shore by Bucky before he turns and walks away] [we see Steve waking up in a hospital bed to hear Marvin Gaye's "Trouble Man" playing with Sam sat next to his bed] On your left. [Sam looks at Steve and smiles; we then see Agent 13 practicing shooting at a shooting range wearing a CIA t-shirt; we see Hill at Stark Industries about to undergo a lie detector test; then Senator Stern getting arrested and then a badly burnt Rumlow being treated by doctors at the hospital; Natasha is then being sworn in at a committee hearing]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 369 ********
# 367. Doctor #1:
# He's dropping.
#
# 368. Nurse:
# Crash cart coming in.
#
# => 369. Doctor #2:
# => Nurse, help me with the gauzes, please. BP is dropping. Defibrillator! [Steve, Natasha and Hill watch in shock as Fury is flatlining] Charge to one hundred.
#
# 370. Natasha Romanoff:
# Don't do this to me, Nick.
#
# 371. Doctor #2:
# Stand back! Three, two, one. Clear! [Fury is given a shock with the defibrillator] Pulse?
#
# ******** test model 1: line 369 ********
# 1 relations identified
# entities: Doctor #2 => , Nurse, gauzes, Steve, Natasha, Hill
# relation: Nurse, help me with the gauzes, please. BP is dropping. Defibrillator! [Steve, Natasha and Hill watch in shock as Fury is flatlining] Charge to one hundred.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 475 ********
# 473. Councilwoman Hawley:
# That discussion can be tabled for a later time.
#
# 474. Alexander Pierce:
# But you do want to have a discussion.
#
# => 475. Councilman Rockwell:
# => We've already had it, Mr. Secretary. This council moves to immediately reactivate Project Insight. If you want to say something snappy, now would be a good time. [Steve and Natasha go to the mall disguised as a civilian couple]
#
# 476. Natasha Romanoff:
# First rule of going on the run is, don't run, walk.
#
# 477. Steve Rogers:
# If I run in these shoes, they're gonna fall off. [they go to a Mac store to use one of their computers]
#
# ******** test model 1: line 475 ********
# 1 relations identified
# entities: Councilman Rockwell => , Secretary, couple, Natasha, Steve
# relation: We've already had it, Mr. Secretary. This council moves to immediately reactivate Project Insight. If you want to say something snappy, now would be a good time. [Steve and Natasha go to the mall disguised as a civilian couple]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 70 ********
# 68. narrator:
# he pulls up Sitwell's photo on the monitor
#
# 69. Brock Rumlow:
# They're in the galley.
#
# => 70. Steve Rogers:
# => What's Sitwell doing on a launch ship? Alright, I'm gonna sweep the deck and find Batroc. Nat, you'll kill the engines and wait for instructions. Rumlow, you sweep aft, find the hostages, get them to life pods. get 'em out. Let's go.
#
# 71. Brock Rumlow:
# STRIKE, you heard the Captain. Gear up!
#
# 72. narrator:
# as they are getting ready to dive off the jet; into his radio
#
# ******** test model 1: line 70 ********
# 1 relations identified
# entities: Steve Rogers => , Sitwell, hostages, Batroc, Nat, Rumlow
# relation: What's Sitwell doing on a launch ship? Alright, I'm gonna sweep the deck and find Batroc. Nat, you'll kill the engines and wait for instructions. Rumlow, you sweep aft, find the hostages, get them to life pods. get 'em out. Let's go.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 47 ********
# 45. Natasha Romanoff:
# Hey, fellas. Either one of you know where the Smithsonian is? I'm here to pick up a fossil.
#
# 46. Steve Rogers:
# That's hilarious.
#
# => 47. narrator:
# => Steve walks over to her car and gets in, Sam gives Natasha and her car an appreciative look
#
# 48. Sam Wilson:
# How you doing?
#
# 49. Natasha Romanoff:
# Hey.
#
# ******** test model 1: line 47 ********
# 1 relations identified
# entities: narrator => , Steve, Natasha, Sam
# relation: Steve walks over to her car and gets in, Sam gives Natasha and her car an appreciative look
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 638 ********
# 636. Jasper Sitwell:
# You! A TV anchor in Cairo, the Undersecretary of Defense, a high school valedictorian in Iowa city. Bruce Banner, Stephen Strange, anyone who's a threat to HYDRA! Now, or in the future.
#
# 637. Steve Rogers:
# The Future? How could it know? [Sitwell laughs]
#
# => 638. Jasper Sitwell:
# => How could it not? The 21st century is a digital book. Zola taught HYDRA how to read it. [Steve and Natasha look at him in confusion] Your bank records, medical histories, voting patterns, e-mails, phone calls, your damn SAT scores. Zola's algorithm evaluates peoples' past to predict their future.
#
# 639. Steve Rogers:
# And what then?
#
# 640. Jasper Sitwell:
# Oh, my God. Pierce is gonna kill me.
#
# ******** test model 1: line 638 ********
# 1 relations identified
# entities: Jasper Sitwell => , Zola, peoples, Natasha, Steve
# relation: How could it not? The 21st century is a digital book. Zola taught HYDRA how to read it. [Steve and Natasha look at him in confusion] Your bank records, medical histories, voting patterns, e-mails, phone calls, your damn SAT scores. Zola's algorithm evaluates peoples' past to predict their future.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 754 ********
# 752. Brock Rumlow:
# You picked the wrong side, Agent.
#
# 753. Sharon Carter:
# Depends on where you're standing. [Rumlow drops his gun, but as he does he grabs his knife and cuts Agent 13's arm, leading to the SHIELD agents firing their guns, amidst the bullets, Rumlow manages to release the Helicarriers and runs off] [as the bay doors holding the Helicarriers are about to be opened]
#
# => 754. SHIELD Agent:
# => Close the bay door! Close the bay door now! Close the bay door! [the HYDRA agents enter and start shooting and killing the crew and techs; at the headquarters Hill watches on the monitor as the Helicarriers are being initiated]
#
# 755. Maria Hill:
# They're initiating launch. [Steve and Sam make their way to the Helicarriers]
#
# 756. Sam Wilson:
# Hey, Cap, how do we know the good guys from the bad guys?
#
# ******** test model 1: line 754 ********
# 1 relations identified
# entities: SHIELD Agent => , agents, crew, Helicarriers, Hill
# relation: Close the bay door! Close the bay door now! Close the bay door! [the HYDRA agents enter and start shooting and killing the crew and techs; at the headquarters Hill watches on the monitor as the Helicarriers are being initiated]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 410 ********
# 408. Alexander Pierce:
# No, it's more complicated than that. Batroc was hired anonymously to attack the Lemurian Star and he was contacted by e-mail and paid by wire transfer. And then the money was run through seventeen fictitious accounts, the last one going to a holding company that was registered to a Jacob Veech.
#
# 409. Steve Rogers:
# Am I supposed to know who that is? [he hands Steve the file]
#
# => 410. Alexander Pierce:
# => Not likely. Veech died six years ago. His last address was 14-35 Elmhurst Drive. When I first met Nick his mother lived at 14-37.
#
# 411. Steve Rogers:
# Are you saying Fury hired the pirates? Why?
#
# 412. Alexander Pierce:
# Well the prevailing theory was that the hijacking was a cover for the acquisition and sale of classified intelligence. The sale went sour and that led to Nick's death.
#
# ******** test model 1: line 410 ********
# 1 relations identified
# entities: Alexander Pierce => , Veech, mother, Nick
# relation: Not likely. Veech died six years ago. His last address was 14-35 Elmhurst Drive. When I first met Nick his mother lived at 14-37.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 660 ********
# 658. Steve Rogers:
# Zola. Bucky's whole unit was captured in '43, Zola experimented on 'em. Whatever he did, it helped Bucky survive the fall. They must have found him.
#
# 659. Natasha Romanoff:
# None of that's your fault, Steve.
#
# => 660. Steve Rogers:
# => Even when I had nothing, I had Bucky. [Sam notices Natasha is bleeding from her shoulder and looks at the guards]
#
# 661. Sam Wilson:
# We need to get a doctor here. We don't put pressure on that wound she's gonna bleed out here in the truck. [suddenly one of the guards pulls out an electric rod and neutralizes the other guard and knocks him out, the guard is revealed to be Hill as she takes off her helmet]
#
# 662. Maria Hill:
# That thing was squeezing my brain. [Sam looks at her in confusion; to Steve] Who's this guy? [Rumlow's crew stop their vehicles and get out]
#
# ******** test model 1: line 660 ********
# 1 relations identified
# entities: Steve Rogers => , Natasha, Bucky, Sam
# relation: Even when I had nothing, I had Bucky. [Sam notices Natasha is bleeding from her shoulder and looks at the guards]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 888 ********
# 886. Natasha Romanoff:
# And you're not a SHIELD agent.
#
# 887. Steve Rogers:
# What was her name again?
#
# => 888. Natasha Romanoff:
# => Sharon. She's nice. [she kisses Steve on the cheek and turns to walk away] Be careful, Steve. You might not want to pull on that thread. [as Natasha walks away Steve opens the file, which is about Bucky and the information regarding his Winter Soldier transformation, Sam walks over to Steve]
#
# 889. Sam Wilson:
# You're going after him?
#
# 890. Steve Rogers:
# You don't have to come with me.
#
# ******** test model 1: line 888 ********
# 1 relations identified
# entities: Natasha Romanoff => , Sharon, Steve, Winter Soldier, Sam
# relation: Sharon. She's nice. [she kisses Steve on the cheek and turns to walk away] Be careful, Steve. You might not want to pull on that thread. [as Natasha walks away Steve opens the file, which is about Bucky and the information regarding his Winter Soldier transformation, Sam walks over to Steve]
# category: 3
#
# how many are correctly identified? 1
#
# ******** test results ********
# model 1: precision = 0.53 (32/60 correct)

# %%
df_dict['df_5']['relations'] = df_dict['df_5'].apply(lambda x:extract_relation_categories(x), axis=1)
REEval([df_dict['df_5']])
#29/56
# Out:
# ******** line 531 ********
# 529. narrator:
# The undies drop. The cops stare open-mouthed. They turn to look at Reed, astonished. He sheepishly shrugs his shoulders.
#
# 530. JOHNNY:
# I'm gonna need serious therapy.
#
# => 531. narrator:
# => A beat. She walks away. The cops watch her, gaping. By the time they turn back around, Reed and Johnny are gone, disappearing into the clouds of smoke. EXT. BROOKLYN BRIDGE - DAY A news CHOPPER flies around the bridge, fighting for the best angle on the action. EXT. BROOKLYN BRIDGE - ACCIDENT - DAY Reed races through wreckage. He tries to see over a big TRUCK, and his neck STREEETCHES! He finally sees...BEN. Reed wraps around a car, and...BOO! His face snakes right in front of Ben. Ben jumps.
#
# 532. BEN:
# What the --!
#
# 533. REED:
# Ben. Are you okay?
#
# ******** test model 1: line 531 ********
# 1 relations identified
# entities: narrator => , DAY Reed, cops, Johnny, Ben, BEN. Reed
# relation: A beat. She walks away. The cops watch her, gaping. By the time they turn back around, Reed and Johnny are gone, disappearing into the clouds of smoke. EXT. BROOKLYN BRIDGE - DAY A news CHOPPER flies around the bridge, fighting for the best angle on the action. EXT. BROOKLYN BRIDGE - ACCIDENT - DAY Reed races through wreckage. He tries to see over a big TRUCK, and his neck STREEETCHES! He finally sees...BEN. Reed wraps around a car, and...BOO! His face snakes right in front of Ben. Ben jumps.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 227 ********
# 225. narrator:
# He turns back towards the ship. BEHIND HIM, the storm grows. INT. SPACE STATION - COMMAND CENTER - SAME TIME Victor rushes into the room, looks at the monitors. Sees the others near the airlock on one screen, and the approaching cloud on another. Anxiety creeps across his face.
#
# 226. AUTOMATED VOICE:
# Event threshold in two minutes.
#
# => 227. narrator:
# => INT. SPACE STATION - AIRLOCK DOOR - SAME TIME Reed and Johnny stand by the airlock, waiting for Ben. They heard the automated voice. It panics Reed.
#
# 228. REED:
# Come on, Ben, come on...
#
# 229. VICTOR:
# Reed, we're running out of time.
#
# ******** test model 1: line 227 ********
# 1 relations identified
# entities: narrator => , Reed, Johnny, Ben
# relation: INT. SPACE STATION - AIRLOCK DOOR - SAME TIME Reed and Johnny stand by the airlock, waiting for Ben. They heard the automated voice. It panics Reed.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 1408 ********
# 1406. ALICIA:
# We're going to have to work on your touch.
#
# 1407. BEN:
# I like the sound of that.
#
# => 1408. narrator:
# => Alicia gets close. A soft smile. Reed turns to Sue.
#
# 1409. REED:
# Sue, can I talk to you for a second?
#
# 1410. narrator:
# Reed leads her out. Ben and Johnny swap a glance. EXT. CIRCLE LINE BOAT - DECK - DUSK A romantic view of the city-scape. Reed stands with Sue.
#
# ******** test model 1: line 1408 ********
# 1 relations identified
# entities: narrator => , Alicia, Reed, Sue
# relation: Alicia gets close. A soft smile. Reed turns to Sue.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 891 ********
# 889. narrator:
# Johnny lands. The crowd roars. Ronnie bears down on the last hill. He leans over his handlebars.
#
# 890. X GAMES ANNOUNCER:
# He's going for a Kiss of Death!
#
# => 891. narrator:
# => Ronnie hits the hill, pulls this JAW-DROPPING DEATH-DEFYING STUNT! The crowd is deafening! Ronnie smiles. And... JOHNNY SPEEDS FASTER, FASTER. Trails of FLAME start to streak off his back! He RACES LIKE A ROCKET UP THE HILL! LAUNCHING TO IMPOSSIBLE HEIGHTS! SPINNING LIKE A TOP! A FLAMING BLUR! And now for the really impressive part: Johnny's bike starts to drop, but JOHNNY KEEPS RISING! He FLAMES ON, spiraling upward! For a few seconds, he's actually...almost...flying.
#
# 892. X GAMES ANNOUNCER:
# (hand over mic) Is he......flying?
#
# 893. narrator:
# A beat. Time suspended. And...WHHM! He PLUMMETS back down! LANDS on his bike in mid-air! And sticks a perfect landing, maybe even kicking a little dirt up at Ronnie. Johnny swerves to a stop, with a "holy shit" look on his face. What the hell just happened??
#
# ******** test model 1: line 891 ********
# 2 relations identified
# entities: narrator => , JOHNNY, Ronnie, crowd
# relation: Ronnie hits the hill, pulls this JAW-DROPPING DEATH-DEFYING STUNT! The crowd is deafening! Ronnie smiles. And... JOHNNY SPEEDS FASTER, FASTER. Trails of FLAME start to streak off his back! He RACES LIKE A ROCKET UP THE HILL! LAUNCHING TO IMPOSSIBLE HEIGHTS! SPINNING LIKE A TOP! A FLAMING BLUR! And now for the really impressive part: Johnny's bike starts to drop, but JOHNNY KEEPS RISING! He FLAMES ON, spiraling upward! For a few seconds, he's actually...almost...flying.
# category: 3
# entities: Ronnie => hill
# relation:  hits the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 140 ********
# 138. BEN:
# This is your dream, Reed. You should be the one up there.
#
# 139. REED:
# Victor's better at these things.
#
# => 140. narrator:
# => Just past the press area, they see...one woman standing, waiting. This is DEBBIE, Ben's fiancée. And for the first time in the entire film...Ben SMILES. They hug, kissing. Johnny and Reed watch. Reed glances at Sue, who walks ahead. Debbie slips a photo into Ben's flightsuit. A tender beat.
#
# 141. BEN:
# I'll be watching over you.
#
# 142. DEBBIE:
# Just get back soon, or I start looking for a new groom.
#
# ******** test model 1: line 140 ********
# 1 relations identified
# entities: narrator => , DEBBIE, woman, Ben, Johnny, Reed
# relation: Just past the press area, they see...one woman standing, waiting. This is DEBBIE, Ben's fiancée. And for the first time in the entire film...Ben SMILES. They hug, kissing. Johnny and Reed watch. Reed glances at Sue, who walks ahead. Debbie slips a photo into Ben's flightsuit. A tender beat.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 149 ********
# 147. BEN:
# What the hell you smiling at? Just keep your mouth shut, and your mind on those SMBs --
#
# 148. JOHNNY:
# Actually, the engines are SMEs. Hydrogenbase, carbon propellant. Couple generations past your last ride. (at the threshold) I'm not as dumb as you look.
#
# => 149. narrator:
# => Ben just glares at Reed. This is going to be a long trip. As they follow after Sue, we CUT BACK TO -- VICTOR ON STAGE Mid-speech. Playing behind him is REED'S HOLOGRAM: stars give way to a pulsating red cloud...
#
# 150. VICTOR:
# Think of a world without genetic flaws -- no asthma, allergies, baldness, breast cancer...
#
# 151. narrator:
# Ben and Reed hear the speech. Ben bristles.
#
# ******** test model 1: line 149 ********
# 1 relations identified
# entities: narrator => , Ben, Reed, stars, Sue, VICTOR
# relation: Ben just glares at Reed. This is going to be a long trip. As they follow after Sue, we CUT BACK TO -- VICTOR ON STAGE Mid-speech. Playing behind him is REED'S HOLOGRAM: stars give way to a pulsating red cloud...
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 504 ********
# 502. narrator:
# EXT. BROOKLYN BRIDGE - DAY Ben puts the seat down, with the Driver on it. He lunges behind a truck. The cops try to follow, but FLAMES push them back. Ben lurches away, head down, self-conscious. He tries to hide from ONLOOKERS around him and PEDESTRIANS on walkways overhead. He wants to escape, but hears SCREAMING MOTORISTS. He grits his teeth, and moves to help them. EXT. BROOKLYN BRIDGE - GRIDLOCK - DAY Reed, Sue, and Johnny race toward the flames. All other people head in the OPPOSITE DIRECTION. BRIDGE POLICE herd the crowd away from the accident.
#
# 503. BRIDGE COP:
# Back! We're evac-ing the bridge.
#
# => 504. narrator:
# => Reed, Sue, and Johnny slow down, swap glances.
#
# 505. SUE:
# What now? Reed...? What do we do?
#
# 506. narrator:
# MOVE IN ON REED. A first test of leadership. But he is not a leader. Not yet. Sue gets closer to him.
#
# ******** test model 1: line 504 ********
# 1 relations identified
# entities: narrator => , Reed, Sue, Johnny
# relation: Reed, Sue, and Johnny slow down, swap glances.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 192 ********
# 190. BEN:
# Put your tiny little mind at ease.
#
# 191. JOHNNY:
# Don't you wander off, boy.
#
# => 192. narrator:
# => Johnny steps out of the air-lock and shuts the door. He looks through a small window to see Ben give the thumbs up. THE AIRLOCK DOOR opens, and Ben gracefully steps into space. INT. SPACE STATION - OBSERVATION DECK - SAME TIME Sue descends the stairs at Victor's behest. Joins him.
#
# 193. VICTOR:
# Surprised I agreed to Reed's proposal?
#
# 194. SUE:
# I understand the business reasons.
#
# ******** test model 1: line 192 ********
# 2 relations identified
# entities: narrator => , Johnny, Ben, Victor, Sue
# relation: Johnny steps out of the air-lock and shuts the door. He looks through a small window to see Ben give the thumbs up. THE AIRLOCK DOOR opens, and Ben gracefully steps into space. INT. SPACE STATION - OBSERVATION DECK - SAME TIME Sue descends the stairs at Victor's behest. Joins him.
# category: 3
# entities: DOOR => stairs
# relation:  descends the
# category: 5
#
# how many are correctly identified? 2
#
# ******** line 66 ********
# 64. VICTOR:
# Funny how things turn out, isn't it?
#
# 65. REED:
# Hilarious.
#
# => 66. narrator:
# => As Reed and Sue lock eyes, Ben watches Victor. Wary. INT. VICTOR'S OFFICE - MOMENTS LATER - DAY Director of Communications LEONARD enters, checking files.
#
# 67. VICTOR:
# If Reed's right, then this little trip will double our stock offering.
#
# 68. LEONARD:
# And if he's not...?
#
# ******** test model 1: line 66 ********
# 1 relations identified
# entities: narrator => , Victor, Reed, Sue, Ben, Director of Communications LEONARD
# relation: As Reed and Sue lock eyes, Ben watches Victor. Wary. INT. VICTOR'S OFFICE - MOMENTS LATER - DAY Director of Communications LEONARD enters, checking files.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 541 ********
# 539. narrator:
# Ben spins, looking for Sue. He can't see her. But he does see...A CAR INCHES AWAY, WITH GAS TANK FLAMING! BOOOOM! The first car BLOWS! BOOOM!BOOOOM!BOOOOOM! Empty cars BLOW in a chain-reaction. The flames are mushrooming! Reed SWIPES his ARMS OUT, holding people back. His arms FLATTEN to form a barricade -- FACES INDENT his skin. FLAMES lash out. A pack of attractive YOUNG WOMEN scream. Johnny LEAPS toward them. His feet LEAVE THE GROUND, giving him extra lift. He SPINS, lands, and embraces the women, SHIELDING them from flames which burn up his back. He looks the ladies up and down, and gives a cheesy smile. Sue SCREAMS. She puts her hands up (a normal reflex). The air seems to RIPPLE around her hands, like FORCE-FIELDS. She looks at them, surprised, confused. Her invisible fields SPIRAL OUT, partially CONTAINING the blast. But the flames hurtle closer. She fights the pressure. Blood trickles from her nose. Just as the white hot blast is about to hit her... Sue is dressed again. Visible. She SCREAMS, and PUSHES THE FORCE DOWN INTO THE ROAD! She collapses, as the blast deflects off the street and into... An oncoming FIRETRUCK! BOOOOM! The firetruck is KNOCKED OFF THE GROUND, SLEWING SIDEWAYS. Brakes scream. Its tail slashes out, PUNCHING through the guard-rail. THE BACK OF THE TRUCK DANGLES OUT, HUNDREDS OF FEET ABOVE THE WATER! FIREMEN hang off the back and sides. The truck TEETERS, falling! Ben wastes no time. He GRABS onto the front of the truck, just as it goes off the side! He DIGS his heels into the ground, but his feet DRAG across the concrete, digging grooves into the street. ON THE DANGLING FIRETRUCK: FIREMEN climb out, clawing toward the bridge. Their truck SWINGS. Bits and pieces tumble down at them -- a hose, an axe, a helmet. All deadly now. The HANGING LADDER swoops down, with men RIDING ON IT! Ben SCREAMS! STRAINING with all his might. Ben SCREAMS! His muscles ripple, and...he takes his first step...back. Another scream. Another step. Another. Another. Epic, painful. He is pulling the truck back onto the bridge, inch by inch. His footsteps THUD. With monumental effort, he levels the truck. Firemen scurry over hoses and ladders, some climbing over Ben. Reed tends to Sue who has fainted from her effort. Ben steps back from the truck and slumps to the street exhausted. Wary cops close in to cover him with weapons, but... The FIREMEN slowly begin to APPLAUD. The crowd of onlookers joins in as well. Sue, Reed, and Johnny seem surprised, touched by the reaction. But Ben seems uncomfortable. Firemen step forward to offer Reed a couple of their coats; he hands one to Johnny and uses the other to cover Sue. EXT. BROOKLYN BRIDGE - DAY Ben sees a familiar face in the masses: DEBBIE. Ben steps toward her, but she stops him with a look. She places something on the ground and runs off into the crowd. Ben sees something GLISTENING on the ground. He stoops over to pick up...her ENGAGEMENT RING. His big fingers can't grip it. He tries in vain. Hopeless, pathetic. A beat. And... A hand grabs the ring. It's Reed. Quiet, close.
#
# 540. REED:
# I swear to you, I will do everything in my power until there is not a breath left in me: you are going to be Ben again.
#
# => 541. narrator:
# => Off the wounded look in Ben's eyes, wanting to believe him... INT. VICTOR'S OFFICE - DAY Victor sits with remote in hand, staring at his plasma TV. ON THE TV: he sees a crowd of firemen applauding the new Fantastic Four. For the first time they strike a heroic pose. Leonard enters, with a phone in his hand.
#
# 542. LEONARD:
# Uh, sir...Larry King called, to cancel. (seeing the TV, a beat) Apparently, there's a bigger story.
#
# 543. narrator:
# Victor sees Reed put his arms around Sue as he covers her with the jacket. And the penny drops: he's FURIOUS. As it hits him, he feels something odd. He looks down at his hand...at glints of gleaming METAL poking through flesh. EXT./INT. EMERGENCY HOLDING AREA - DAY An impromptu command center -- a series of police tents, surrounded by EMERGENCY VEHICLES, NEWS VANS, FIRETRUCKS. INT. EMERGENCY HOLDING AREA - TENT - DAY Reed, Sue, Ben and Johnny sit together, getting changed. They get ready to go, but the CHIEF FIREMAN enters, stopping them.
#
# ******** test model 1: line 541 ********
# 1 relations identified
# entities: narrator => , DAY Victor, Ben, Leonard, firemen, crowd
# relation: Off the wounded look in Ben's eyes, wanting to believe him... INT. VICTOR'S OFFICE - DAY Victor sits with remote in hand, staring at his plasma TV. ON THE TV: he sees a crowd of firemen applauding the new Fantastic Four. For the first time they strike a heroic pose. Leonard enters, with a phone in his hand.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 1087 ********
# 1085. narrator:
# Victor nods, knowing he has Johnny on the hook.
#
# 1086. JOHNNY:
# You talk to Reed and Sue about this?
#
# => 1087. VICTOR:
# => Johnny. Let's be honest here. Ben, Reed, Sue. Good people, all. But stars? (shaking his head, a beat) I don't want to break up the band, but you're the one they want. Don't you think it's time to go solo...?
#
# 1088. narrator:
# Victor subtly nods to the models. They envelop Johnny.
#
# 1089. VICTOR:
# Take the car for a spin. Think about it. Is this the life you want? Or would you rather live in Reed's lab...?
#
# ******** test model 1: line 1087 ********
# 1 relations identified
# entities: VICTOR => , Johnny, stars, people, Ben, Reed, Sue, one
# relation: Johnny. Let's be honest here. Ben, Reed, Sue. Good people, all. But stars? (shaking his head, a beat) I don't want to break up the band, but you're the one they want. Don't you think it's time to go solo...?
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 157 ********
# 155. narrator:
# The red cloud of cosmic rays wash over the Earth.
#
# 156. VICTOR:
# ...a little country boy from Latveria build one of the biggest companies in the world, and truly reach the stars. Now if you'll excuse me, history awaits...
#
# => 157. narrator:
# => On those words, the HOLOGRAM TRANSFORMS TO...Von Doom's SHUTTLE on the launch pad. BOOM! THRUSTERS FIRE WHITE HOT. Smoke billows across the pad. Ready for take off. Victor walks past the hologram and exits. His departure perfectly timed with the shuttle LIFTING OFF. We push in on the shuttle, and follow the ship as it leaves Earth's atmosphere. BOOM -- booster rockets fall away and the shuttle fires its thrusters. The hologram transitions to... A shot of the SPACE STATION high above the Earth. The shuttle enters from the top, lighting up the hologram with engines afire. As the shuttle approaches the station we CUT TO -- EXT. DEEP SPACE - SAME THE SPACE STATION in the distance, rotating in orbit above Earth. THE SHUTTLE eases in and docks. INT. SPACE STATION - COMMAND CENTER - SAME Victor and Sue lead the others into the command center.
#
# 158. JOHNNY:
# (a "dad voice": to Ben) If you behave, maybe next time daddy'll let you drive.
#
# 159. BEN:
# Keep talking, there won't be a next time.
#
# ******** test model 1: line 157 ********
# 1 relations identified
# entities: narrator => , Victor, others, Sue
# relation: On those words, the HOLOGRAM TRANSFORMS TO...Von Doom's SHUTTLE on the launch pad. BOOM! THRUSTERS FIRE WHITE HOT. Smoke billows across the pad. Ready for take off. Victor walks past the hologram and exits. His departure perfectly timed with the shuttle LIFTING OFF. We push in on the shuttle, and follow the ship as it leaves Earth's atmosphere. BOOM -- booster rockets fall away and the shuttle fires its thrusters. The hologram transitions to... A shot of the SPACE STATION high above the Earth. The shuttle enters from the top, lighting up the hologram with engines afire. As the shuttle approaches the station we CUT TO -- EXT. DEEP SPACE - SAME THE SPACE STATION in the distance, rotating in orbit above Earth. THE SHUTTLE eases in and docks. INT. SPACE STATION - COMMAND CENTER - SAME Victor and Sue lead the others into the command center.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 624 ********
# 622. SUE:
# Grow up, Johnny. You want to run around on fire for the rest of your life?
#
# 623. JOHNNY:
# Is that a trick question? C'mon, I can't be the only one who thinks this is cool.
#
# => 624. narrator:
# => Reed considers. But Sue cuts him short with a look. DING! The elevator stops. INT. BAXTER BUILDING - ATRIUM - MOMENTS LATER The elevator opens. They step out. They might be on the 20th floor, but Reed owns the building from here to floor sixty. It's a massive atrium, lit by skylights far above -- Reed leads them into another area filled with separate "apartments" and all the amenities of home.
#
# 625. REED:
# We should stay here until we can define the extent of our changes...
#
# 626. JOHNNY:
# This place is deluxe. You got cable?
#
# ******** test model 1: line 624 ********
# 2 relations identified
# entities: narrator => , Reed, Sue, elevator
# relation: Reed considers. But Sue cuts him short with a look. DING! The elevator stops. INT. BAXTER BUILDING - ATRIUM - MOMENTS LATER The elevator opens. They step out. They might be on the 20th floor, but Reed owns the building from here to floor sixty. It's a massive atrium, lit by skylights far above -- Reed leads them into another area filled with separate "apartments" and all the amenities of home.
# category: 3
# entities: Reed => building
# relation:  owns the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 298 ********
# 296. narrator:
# WHOOSH. A NURSE rolls in with a tray bearing ten more extravagant bouquets. Reed looks resigned. He walks out.
#
# 297. REED:
# She's allergic to orchids. Put that Amaryllis Apapathos by her bed. The African lilies? They're her favorites.
#
# => 298. narrator:
# => Reed exits, dropping his two wilted lilies into the trash. Sue opens one eye, as the big lilies land by the bed. INT. VON DOOM COMPOUND HOSPITAL ROOM - DAY A SEXY NURSE wheels a testing station into Johnny's room. He's stripped down to Calvins, changing into a ski outfit.
#
# 299. SEXY NURSE:
# And where do we think we're going?
#
# 300. JOHNNY:
# I don't know if "we've" noticed, but the sickest runs this side of the Alps are right outside that window --
#
# ******** test model 1: line 298 ********
# 1 relations identified
# entities: narrator => , Reed, Johnny, Sue, NURSE, Calvins
# relation: Reed exits, dropping his two wilted lilies into the trash. Sue opens one eye, as the big lilies land by the bed. INT. VON DOOM COMPOUND HOSPITAL ROOM - DAY A SEXY NURSE wheels a testing station into Johnny's room. He's stripped down to Calvins, changing into a ski outfit.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 1090 ********
# 1088. narrator:
# Victor subtly nods to the models. They envelop Johnny.
#
# 1089. VICTOR:
# Take the car for a spin. Think about it. Is this the life you want? Or would you rather live in Reed's lab...?
#
# => 1090. narrator:
# => The car stops. Victor gets out. He stands on the pavement. As he shuts the door, we see the women climbing onto Johnny. The door shuts, and... WHHHMMMPF! The windows all suddenly STEAM UP! INT. HAYDEN PLANETARIUM - NIGHT STARS on the ceiling. A VOICE drones about the galaxy. In the LAST ROW, we find: Reed and Sue. Reed is thinking about work.
#
# 1091. REED:
# I could get Ben to tap into the Baxter's main power to generate enough voltage --
#
# 1092. SUE:
# Reed. Shh. Just be quiet. And look up.
#
# ******** test model 1: line 1090 ********
# 1 relations identified
# entities: narrator => , Victor, women, Johnny, STARS, Reed, Sue. Reed
# relation: The car stops. Victor gets out. He stands on the pavement. As he shuts the door, we see the women climbing onto Johnny. The door shuts, and... WHHHMMMPF! The windows all suddenly STEAM UP! INT. HAYDEN PLANETARIUM - NIGHT STARS on the ceiling. A VOICE drones about the galaxy. In the LAST ROW, we find: Reed and Sue. Reed is thinking about work.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 571 ********
# 569. JOHNNY:
# Symptoms? Please. If having powers is a disease, then yeah we got it. And we are gonna blow your minds. There's a new day dawning. The day of the Fantastic Four.
#
# 570. REPORTER #3:
# That thing doesn't look too fantastic.
#
# => 571. narrator:
# => The Reporter nods toward Ben. Ben's fists tighten, the sound of rocks crushing together. Reed feels the pain.
#
# 572. REED:
# Ben Grimm is a genuine American hero who's been through a terrible orde--
#
# 573. JOHNNY:
# What he's trying to say is: every team needs a mascot...
#
# ******** test model 1: line 571 ********
# 1 relations identified
# entities: narrator => , Reporter, Ben, fists, Reed
# relation: The Reporter nods toward Ben. Ben's fists tighten, the sound of rocks crushing together. Reed feels the pain.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 461 ********
# 459. narrator:
# EXT. TRAIN YARD - NIGHT A view from Brooklyn: Manhattan glistens in the distance. CAMERA MOVES down to A TRAIN YARD, where we find empty cargo trains. We PUSH IN on the main track, where... A CARGO TRAIN has just stopped. We hear a cargo DOOR slide open, then WHUMP! Big FEET hit the ground. Someone, or someTHING barrels into the night. EXT. BIG & TALL SHOP - NIGHT A locked storefront on Flatbush Ave. SOUND of breaking glass. INT. BIG & TALL SHOP - NIGHT SERIES OF SHOTS: Ben tries on clothes, shoes. Jackets rip, shoes split. He needs an extra extra extra large. EXT. PAY PHONE - NIGHT A HUGE FIGURE is huddled in shadow. It's Ben. CLOSE ON: The dial pad. Big fingers try to push keys but they're too large. Ben tries for a few seconds, getting more and more frustrated. He manages to press "0" with his pinky.
#
# 460. BEN:
# Hello, Operator?
#
# => 461. narrator:
# => Ben looks up the street, into the 2nd story window of a modest, working-class home. His eyes go soft when he sees Debbie grab the phone.
#
# 462. BEN:
# Deb... It's me. I need you to step out front.
#
# 463. DEBBIE:
# Out front? You home, baby? I got a surprise for you.
#
# ******** test model 1: line 461 ********
# 1 relations identified
# entities: Ben => street
# relation:  looks up the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 797 ********
# 795. narrator:
# As if suddenly made aware of their vulnerability, Sue and Reed stand, backing off. As they part, we see: BEN watching from the doorway. Melancholy. He disappears. We slowly MOVE TO...A SURVEILLANCE CAMERA in a VENT GRATE. INT. VICTOR'S OFFICE - NIGHT Victor watches a bank of videoscreens. He has the Baxter Building under surveillance. He sees Reed and Sue on monitors. He toys with Sue's diamond ring in his gloved hand. A door opens. Leonard enters. He sees the screens.
#
# 796. LEONARD:
# Is Reed any closer to a cure?
#
# => 797. narrator:
# => Victor looks at that image of Reed and Sue on the screen.
#
# 798. VICTOR:
# The only thing he's closer to is Sue...
#
# 799. narrator:
# But Victor sees something between Reed and Sue on the wall. He leans closer, and the camera ZOOMS IN, as if responding to his will. He ZOOMS all the way to a CLOSE UP of: REED'S BLUEPRINTS FOR THE TRANSFORMATION CHAMBER. Victor's eyes narrow, mind ticking, a plan forming.
#
# ******** test model 1: line 797 ********
# 1 relations identified
# entities: narrator => , Victor, Reed, Sue
# relation: Victor looks at that image of Reed and Sue on the screen.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 592 ********
# 590. narrator:
# Victor considers. His mind races, eyes narrow.
#
# 591. VICTOR:
# Very simple. I cure them. If I can cure these freaks, then I can cure anyone. What better way to restore my reputation?
#
# => 592. narrator:
# => Leonard nods, impressed. Victor is a man in motion. As they step into sunlight, we cut to...CLICKCLICKCLICK in -- EXT. BAXTER BUILDING - DAY REPORTERS snap pictures. A POLICE CONVOY drives up, stopping in front of a towering HIGH-RISE. Sue, Reed, and Johnny and get out of a police-car. Ben steps out of a BIG PADDY-WAGON, which immediately bounces back up to the normal axle position. COPS hold back the surging press. Ben keeps his head down, self-conscious. He passes Johnny, smiling for the cameras.
#
# 593. JOHNNY:
# Smile, Ben. They want to like you. Give 'em your good side. Or your less bad side.
#
# 594. narrator:
# Ben turns to a group of LITTLE KIDS. Stiff, tentative:
#
# ******** test model 1: line 592 ********
# 1 relations identified
# entities: narrator => , Victor, Leonard, Ben, Johnny, REPORTERS, Sue, Reed
# relation: Leonard nods, impressed. Victor is a man in motion. As they step into sunlight, we cut to...CLICKCLICKCLICK in -- EXT. BAXTER BUILDING - DAY REPORTERS snap pictures. A POLICE CONVOY drives up, stopping in front of a towering HIGH-RISE. Sue, Reed, and Johnny and get out of a police-car. Ben steps out of a BIG PADDY-WAGON, which immediately bounces back up to the normal axle position. COPS hold back the surging press. Ben keeps his head down, self-conscious. He passes Johnny, smiling for the cameras.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 146 ********
# 144. BEN:
# Soon as I'm back, I'm gonna trade that in for a bigger rock.
#
# 145. DEBBIE:
# I don't care about rocks, I care about you. (to Reed) You bring him back in one piece, or you can forget being Best Man.
#
# => 146. narrator:
# => Reed nods, smiles. Debbie gives Ben a last kiss. Ben turns to Johnny, who gives a cocky smile.
#
# 147. BEN:
# What the hell you smiling at? Just keep your mouth shut, and your mind on those SMBs --
#
# 148. JOHNNY:
# Actually, the engines are SMEs. Hydrogenbase, carbon propellant. Couple generations past your last ride. (at the threshold) I'm not as dumb as you look.
#
# ******** test model 1: line 146 ********
# 1 relations identified
# entities: narrator => , Reed, Johnny, Debbie, Ben
# relation: Reed nods, smiles. Debbie gives Ben a last kiss. Ben turns to Johnny, who gives a cocky smile.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 1174 ********
# 1172. JOHNNY:
# Hey! That's a prototype!
#
# 1173. BEN:
# Go back to the drawing board.
#
# => 1174. narrator:
# => He strides away. INT. BAXTER BUILDING - GROUND FLOOR - NIGHT DING. Sue speeds out of the elevator. No sign of Ben. She runs into...JOHNNY who shakes off the encounter.
#
# 1175. SUE:
# Johnny? Did you see Ben?
#
# 1176. JOHNNY:
# Yeah, for the last time, I hope. I'm done with this freak show. I'm moving back to the real world.
#
# ******** test model 1: line 1174 ********
# 1 relations identified
# entities: narrator => , Sue, JOHNNY, Ben
# relation: He strides away. INT. BAXTER BUILDING - GROUND FLOOR - NIGHT DING. Sue speeds out of the elevator. No sign of Ben. She runs into...JOHNNY who shakes off the encounter.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 1415 ********
# 1413. narrator:
# He opens his hand, revealing a circular piece of metal, just about the size of......a RING. Sue slows down.
#
# 1414. REED:
# If one of us were to wear it...
#
# => 1415. narrator:
# => She sees Johnny and Ben inside, watching -- in on a secret. Reed looks her square in the eye. Unflinching.
#
# 1416. SUE:
# Reed. What are you doing?
#
# 1417. narrator:
# Reed drops to his knees. His head stays eye-level, while his body drops. Sue gapes, so emotional she starts to DISAPPEAR.
#
# ******** test model 1: line 1415 ********
# 2 relations identified
# entities: narrator => , Johnny, Ben, Reed
# relation: She sees Johnny and Ben inside, watching -- in on a secret. Reed looks her square in the eye. Unflinching.
# category: 3
# entities: Reed => square
# relation:  looks her
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 563 ********
# 561. narrator:
# All eyes go on Reed. He looks out, gulps hard. A long beat.
#
# 562. REED:
# Uh, during our recent mission to the Von Doom space station, we were exposed to as yet-unidentified radioactive energy, most likely some kind of nucleotide compoun--
#
# => 563. narrator:
# => Nobody came for a science class. A crush of questions overwhelms Reed:
#
# 564. VARIOUS REPORTERS:
# What happened on the bridge? Does it hurt to stretch? Were you really on fire? Is it true that one of you can fly?
#
# 565. JOHNNY:
# Working on it. And it's a lot harder --
#
# ******** test model 1: line 563 ********
# 1 relations identified
# entities: narrator => , Nobody, science class, crush, Reed
# relation: Nobody came for a science class. A crush of questions overwhelms Reed:
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 1417 ********
# 1415. narrator:
# She sees Johnny and Ben inside, watching -- in on a secret. Reed looks her square in the eye. Unflinching.
#
# 1416. SUE:
# Reed. What are you doing?
#
# => 1417. narrator:
# => Reed drops to his knees. His head stays eye-level, while his body drops. Sue gapes, so emotional she starts to DISAPPEAR.
#
# 1418. REED:
# No more thinking, no more variables... Sue Storm...will you... (she's gone) Sue? Sue? You there?
#
# 1419. narrator:
# Dead silence. And then... THE RING DISAPPEARS. SUE IS WEARING IT.
#
# ******** test model 1: line 1417 ********
# 1 relations identified
# entities: narrator => , Reed, Sue, head
# relation: Reed drops to his knees. His head stays eye-level, while his body drops. Sue gapes, so emotional she starts to DISAPPEAR.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 422 ********
# 420. narrator:
# Only one thing on Reed's mind --
#
# 421. REED:
# We have to find Ben.
#
# => 422. narrator:
# => EXT. VON DOOM COMPOUND - OUTSIDE BEN'S ROOM - EARLY EVENING Johnny snaps his fingers -- which generate small explosive bursts of flame. He turns it on and off, like the "CLAPPER."
#
# 423. JOHNNY:
# Flame on, flame off. Flame on, flame off --
#
# 424. SUE:
# Johnny.
#
# ******** test model 1: line 422 ********
# 1 relations identified
# entities: narrator => , Johnny, VON, BEN, CLAPPER
# relation: EXT. VON DOOM COMPOUND - OUTSIDE BEN'S ROOM - EARLY EVENING Johnny snaps his fingers -- which generate small explosive bursts of flame. He turns it on and off, like the "CLAPPER."
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 506 ********
# 504. narrator:
# Reed, Sue, and Johnny slow down, swap glances.
#
# 505. SUE:
# What now? Reed...? What do we do?
#
# => 506. narrator:
# => MOVE IN ON REED. A first test of leadership. But he is not a leader. Not yet. Sue gets closer to him.
#
# 507. SUE:
# Ben's out there. Let's go get him.
#
# 508. BRIDGE COP:
# Maybe you didn't hear me. Those cars are gonna blow sky high, any second.
#
# ******** test model 1: line 506 ********
# 1 relations identified
# entities: narrator => , REED, leader, Sue
# relation: MOVE IN ON REED. A first test of leadership. But he is not a leader. Not yet. Sue gets closer to him.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 895 ********
# 893. narrator:
# A beat. Time suspended. And...WHHM! He PLUMMETS back down! LANDS on his bike in mid-air! And sticks a perfect landing, maybe even kicking a little dirt up at Ronnie. Johnny swerves to a stop, with a "holy shit" look on his face. What the hell just happened??
#
# 894. X GAMES ANNOUNCER:
# Unbelievable, ladies and gentlemen! You've just seen the first...the first...TORCHFLIGHT! The McTORCH!
#
# => 895. narrator:
# => A new name is born. The crowd goes berserk. Standing ovation. Riders rush up to Johnny. Kenny sees his bike: THE SEAT MELTED, WHEELS BURNED OFF. Johnny smiles.
#
# 896. JOHNNY:
# My bad. Sorry about that. (a glance to Ronnie) Thanks for the lesson, bro.
#
# 897. narrator:
# HOT GIRLS swarm. As Johnny gets swallowed by fans, we see a scary thing flicker in his eyes: the birth of a star. INT. BAXTER BUILDING - KITCHEN - MORNING Sue stands alone, sifting through piles of mail. She focuses on one piece of mail that she's holding. Her hand begins to disappear and then the envelope slowly begins to disappear as well. Sue smiles at the success. Intrigued. Quiet:
#
# ******** test model 1: line 895 ********
# 1 relations identified
# entities: narrator => , Kenny, crowd, Johnny, Riders
# relation: A new name is born. The crowd goes berserk. Standing ovation. Riders rush up to Johnny. Kenny sees his bike: THE SEAT MELTED, WHEELS BURNED OFF. Johnny smiles.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 914 ********
# 912. narrator:
# REVEAL: JOHNNY standing next to an X GAMES REPORTER. He is peeling off the burned remains of his motocross outfit, revealing his FF UNIFORM, with a "4" STITCHED ONTO THE CHEST. Behind them, STEP UP RIDERS launch their MOTO-BIKES off huge 18' high mountains of dirt, thirty feet in the air.
#
# 913. JOHNNY:
# Not too much, but I will say that it's all weather and no leather. Kind of Armani meets Astronaut.
#
# => 914. narrator:
# => Ben, Sue, and Reed stare at the wall-sized TV. Mouths agape.
#
# 915. SUE:
# He didn't.
#
# 916. BEN:
# Oh, he did.
#
# ******** test model 1: line 914 ********
# 1 relations identified
# entities: narrator => , Ben, Sue, Reed
# relation: Ben, Sue, and Reed stare at the wall-sized TV. Mouths agape.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 1401 ********
# 1399. narrator:
# As they kiss, people emerge, stepping out of hiding. The sun rises around them. The Fantastic Four step into the new dawn of a new day. And we slowly DISSOLVE TO -- INT. CIRCLE LINE BOAT - BANQUET ROOM - DUSK Reed and Sue kiss on the deck of the Circle Line as it chugs around New York City.
#
# 1400. JOHNNY:
# Dude, that's still my sister.
#
# => 1401. narrator:
# => A PARTY IN PROGRESS. Drinks, food, music. We see in the crowd a familiar faces: O'HOOLIHAN (cast on his arm), bartender ERNIE, others. JOHNNY and BEN stand behind Reed and Sue. Reed and Sue pull apart. Reed turns to Ben, excited.
#
# 1402. REED:
# Ben, I've been crunching the numbers on the machine. I think if we can rework the power settings...
#
# 1403. BEN:
# Forget it, egghead. I'm good as is.
#
# ******** test model 1: line 1401 ********
# 1 relations identified
# entities: narrator => , crowd, ERNIE, others, BEN, JOHNNY, Sue. Reed, Sue
# relation: A PARTY IN PROGRESS. Drinks, food, music. We see in the crowd a familiar faces: O'HOOLIHAN (cast on his arm), bartender ERNIE, others. JOHNNY and BEN stand behind Reed and Sue. Reed and Sue pull apart. Reed turns to Ben, excited.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 885 ********
# 883. narrator:
# The CROWD goes wild. Now it's Johnny's turn. He hits the hill and pulls the exact same move. With even more height!
#
# 884. X GAMES ANNOUNCER:
# Look at that lift, ladies and gentlemen!
#
# => 885. narrator:
# => Johnny sticks the landing. The crowd swells. Ronnie tightens, pulls his throttle harder, taking the next jump, and...MAKING AN INSANE MOVE, CORKSCREWING IN THE AIR!
#
# 886. X GAMES ANNOUNCER:
# Frontside 360! He's totally flat and whipped!
#
# 887. narrator:
# He lands clean. The crowd is ready to explode. Johnny REVS his engine, his body starting to STEAM, adrenaline burning. He hits the hill, and pulls an even gnarlier SPIN!
#
# ******** test model 1: line 885 ********
# 1 relations identified
# entities: narrator => , Ronnie, Johnny, crowd
# relation: Johnny sticks the landing. The crowd swells. Ronnie tightens, pulls his throttle harder, taking the next jump, and...MAKING AN INSANE MOVE, CORKSCREWING IN THE AIR!
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 554 ********
# 552. narrator:
# Johnny pauses. Rubs his chin once. And...
#
# 553. JOHNNY:
# Okay. Done thinking.
#
# => 554. narrator:
# => He runs out. Sue, Ben, and Reed swap glances, knowing Johnny cannot be their spokesman. They take off after him, out to -- EXT. EMERGENCY HOLDING AREA - PRESS FIELD - DAY CLICKCLICKCLICK! Fifty cameras flash. The field is full of press. Our heroes freeze, shocked by the crowd. Johnny eats up the attention. Ben turns, self-conscious. Reed notices. The Chief Fireman turns to them.
#
# 555. CHIEF FIREMAN:
# So which one of you's the leader?
#
# 556. narrator:
# Johnny does not hesitate.
#
# ******** test model 1: line 554 ********
# 1 relations identified
# entities: narrator => , Reed, Sue, Ben, Johnny, spokesman, Fireman, crowd
# relation: He runs out. Sue, Ben, and Reed swap glances, knowing Johnny cannot be their spokesman. They take off after him, out to -- EXT. EMERGENCY HOLDING AREA - PRESS FIELD - DAY CLICKCLICKCLICK! Fifty cameras flash. The field is full of press. Our heroes freeze, shocked by the crowd. Johnny eats up the attention. Ben turns, self-conscious. Reed notices. The Chief Fireman turns to them.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 41 ********
# 39. VICTOR:
# I think you both know my Director of Genetic Research, Susan Storm.
#
# 40. BEN:
# Heya Susie. (under breath, to Reed) One more thing he's got.
#
# => 41. narrator:
# => Sue gracefully walks into the office, only taking her eyes off of Reed to give Ben a warm hug.
#
# 42. SUE:
# Ben, it's been too long.
#
# 43. narrator:
# She gives Reed a polite handshake. Victor watches carefully. Reed looks uncomfortable in her gaze. A little tongue-tied.
#
# ******** test model 1: line 41 ********
# 1 relations identified
# entities: narrator => , Sue, Reed, Ben
# relation: Sue gracefully walks into the office, only taking her eyes off of Reed to give Ben a warm hug.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 821 ********
# 819. REED:
# That's what I'm trying to calculate. And it's not rubber. It's muscle, tendon. I seem to have the ability to manipulate the malleability of my molecular structure and redistribute my density to --
#
# 820. JOHNNY:
# Right, whatever, have fun.
#
# => 821. narrator:
# => And Johnny is GONE, ducking under Reed's arm into -- INT. BAXTER BUILDING - KITCHEN - NIGHT Johnny opens a cupboard, pulls out some JIFFY POP. It starts to POP in his hand, the bag swelling. He casually turns on a TV, flipping to...the X- GAMES. The Jiffy Pop swells, ready to blow. He rips it open, eats popcorn, and watches the games: Cool stunts, hot girls. Johnny's brow furrows, a thought forming, a mischievous smile on his lips. EXT. BAXTER BUILDING - SIDE EXIT - NIGHT A FIGURE exits, wearing that ragged trenchcoat and fedora. Ben disappears into the dark night, and we CUT TO -- EXT. BROOKLYN STREET - NIGHT Dark. Lights flicker. Steam rises through the grates. A shadow emerges. Ben. He heads toward O'DONNEL'S PUB, a classic Brooklyn tavern. Neon sign. Music, life inside. Ben pulls his hat low, turns up his collar, and squeezes through the door into -- INT. O'DONNEL'S PUB - NIGHT A big photo of Ben Grimm in his astronaut heyday occupies a place over the bar. Ben enters, and the bar goes SILENT. He moves through the crowd. People clear out of the way. Ben reaches the bar. He sits on a stool, and CRUNCH! SMASH! The stool SNAPS like a toothpick. He hits the ground hard. Glasses shake. A few PATRONS smile, laugh softly.
#
# 822. BEN:
# That's not funny!
#
# 823. narrator:
# They go silent. They drop bills onto tables, filing out, scared of this monster. ERNIE works the bar.
#
# ******** test model 1: line 821 ********
# 1 relations identified
# entities: narrator => , BAXTER BUILDING - KITCHEN - NIGHT Johnny, Ben Grimm, Reed, girls, People, crowd, PATRONS
# relation: And Johnny is GONE, ducking under Reed's arm into -- INT. BAXTER BUILDING - KITCHEN - NIGHT Johnny opens a cupboard, pulls out some JIFFY POP. It starts to POP in his hand, the bag swelling. He casually turns on a TV, flipping to...the X- GAMES. The Jiffy Pop swells, ready to blow. He rips it open, eats popcorn, and watches the games: Cool stunts, hot girls. Johnny's brow furrows, a thought forming, a mischievous smile on his lips. EXT. BAXTER BUILDING - SIDE EXIT - NIGHT A FIGURE exits, wearing that ragged trenchcoat and fedora. Ben disappears into the dark night, and we CUT TO -- EXT. BROOKLYN STREET - NIGHT Dark. Lights flicker. Steam rises through the grates. A shadow emerges. Ben. He heads toward O'DONNEL'S PUB, a classic Brooklyn tavern. Neon sign. Music, life inside. Ben pulls his hat low, turns up his collar, and squeezes through the door into -- INT. O'DONNEL'S PUB - NIGHT A big photo of Ben Grimm in his astronaut heyday occupies a place over the bar. Ben enters, and the bar goes SILENT. He moves through the crowd. People clear out of the way. Ben reaches the bar. He sits on a stool, and CRUNCH! SMASH! The stool SNAPS like a toothpick. He hits the ground hard. Glasses shake. A few PATRONS smile, laugh softly.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 248 ********
# 246. REED:
# Victor's right. Johnny, get to the command center. Close the shields.
#
# 247. JOHNNY:
# What about you?
#
# => 248. narrator:
# => One look from Reed tells Johnny, he won't leave without Ben. Johnny eyes Ben, steels his courage. He's not going either.
#
# 249. JOHNNY:
# (to Ben) Come on big guy, you can do it!
#
# 250. narrator:
# INT. SPACE STATION COMMAND CENTER - DAY Victor watches the shields slide down. Alone. An island.
#
# ******** test model 1: line 248 ********
# 1 relations identified
# entities: narrator => , Ben, Johnny, Reed
# relation: One look from Reed tells Johnny, he won't leave without Ben. Johnny eyes Ben, steels his courage. He's not going either.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 342 ********
# 340. narrator:
# Reed steps away. Ben stands alone, an idea sparking.
#
# 341. BEN:
# Do I have to do everything myself?
#
# => 342. narrator:
# => INT. HELICOPTER/EXT. MOUNTAIN SUMMIT - DAY The chopper hovers over this pristine peak. JOHNNY and his NURSE sit in the chopper-bay, prepping their ski gear. Johnny's customized snowboard has wild, acrylic patterns. His Nurse wears a hot pink cat-suit, her skis dangling out. Their bodies are close: a sexy, competitive flirtation. They look down at a death-defying black diamond run.
#
# 343. JOHNNY:
# Me like-y.
#
# 344. SEXY NURSE:
# Stay right. Left is trouble.
#
# ******** test model 1: line 342 ********
# 1 relations identified
# entities: narrator => , JOHNNY, Nurse, NURSE
# relation: INT. HELICOPTER/EXT. MOUNTAIN SUMMIT - DAY The chopper hovers over this pristine peak. JOHNNY and his NURSE sit in the chopper-bay, prepping their ski gear. Johnny's customized snowboard has wild, acrylic patterns. His Nurse wears a hot pink cat-suit, her skis dangling out. Their bodies are close: a sexy, competitive flirtation. They look down at a death-defying black diamond run.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 502 ********
# 500. narrator:
# Ben looks at the cops. PEDESTRIANS stare, point. He realizes how this must look -- a monster holding a bloody man in hand. EXT. BROOKLYN BRIDGE - APPROACH - DAY At the back of the traffic jam, cars SCREECH to stops. The whole bridge is FULL of bumper-to-bumper traffic. We PUSH TOWARD one car: three doors pop open, and out come... REED, JOHNNY, SUE. They look through smoke and mayhem to see...their first full look at Ben. Reed stands gutpunched.
#
# 501. JOHNNY:
# Not even Ben deserves that.
#
# => 502. narrator:
# => EXT. BROOKLYN BRIDGE - DAY Ben puts the seat down, with the Driver on it. He lunges behind a truck. The cops try to follow, but FLAMES push them back. Ben lurches away, head down, self-conscious. He tries to hide from ONLOOKERS around him and PEDESTRIANS on walkways overhead. He wants to escape, but hears SCREAMING MOTORISTS. He grits his teeth, and moves to help them. EXT. BROOKLYN BRIDGE - GRIDLOCK - DAY Reed, Sue, and Johnny race toward the flames. All other people head in the OPPOSITE DIRECTION. BRIDGE POLICE herd the crowd away from the accident.
#
# 503. BRIDGE COP:
# Back! We're evac-ing the bridge.
#
# 504. narrator:
# Reed, Sue, and Johnny slow down, swap glances.
#
# ******** test model 1: line 502 ********
# 1 relations identified
# entities: narrator => , DAY Ben, cops, Driver, PEDESTRIANS, SCREAMING MOTORISTS, people, crowd, Sue, Johnny, DAY Reed
# relation: EXT. BROOKLYN BRIDGE - DAY Ben puts the seat down, with the Driver on it. He lunges behind a truck. The cops try to follow, but FLAMES push them back. Ben lurches away, head down, self-conscious. He tries to hide from ONLOOKERS around him and PEDESTRIANS on walkways overhead. He wants to escape, but hears SCREAMING MOTORISTS. He grits his teeth, and moves to help them. EXT. BROOKLYN BRIDGE - GRIDLOCK - DAY Reed, Sue, and Johnny race toward the flames. All other people head in the OPPOSITE DIRECTION. BRIDGE POLICE herd the crowd away from the accident.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 154 ********
# 152. BEN:
# What's wrong with being bald...?
#
# 153. narrator:
# Victor smiles at the crowd, commanding. A true leader.
#
# => 154. VICTOR:
# => Darwin discovered evolution. Now we -- I -- will define it. Only in America could...
#
# 155. narrator:
# The red cloud of cosmic rays wash over the Earth.
#
# 156. VICTOR:
# ...a little country boy from Latveria build one of the biggest companies in the world, and truly reach the stars. Now if you'll excuse me, history awaits...
#
# ******** test model 1: line 154 ********
# 2 relations identified
# entities: Darwin => evolution
# relation:  discovered
# category: 5
# entities: Darwin => it
# relation:  define
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 164 ********
# 162. narrator:
# Reed turns towards her -- a little stunned that she would bring that up. It's the first time she's been nice to him so far. He smiles, gently, hesitantly, always hesitant with Sue.
#
# 163. REED:
# Yes. Yes it is.
#
# => 164. narrator:
# => Johnny and Ben exchange a look. Reed keeps looking at the stars, eyes wide, like a little kid. INT. SPACE STATION - COMMAND CENTER/OBSERVATION DECK - SAME They enter the nerve center of the space station. Victor goes to a computer console on the observation deck below. The windows are closed, so there's nothing to observe.
#
# 165. VICTOR:
# (to ground; via comm-link) Leonard, how's the feed?
#
# 166. LEONARD:
# Recording, sir. We see you perfectly.
#
# ******** test model 1: line 164 ********
# 1 relations identified
# entities: narrator => , Ben, Johnny, Reed, kid, Victor
# relation: Johnny and Ben exchange a look. Reed keeps looking at the stars, eyes wide, like a little kid. INT. SPACE STATION - COMMAND CENTER/OBSERVATION DECK - SAME They enter the nerve center of the space station. Victor goes to a computer console on the observation deck below. The windows are closed, so there's nothing to observe.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 189 ********
# 187. JOHNNY:
# Yeah, well, his eyes say different.
#
# 188. BEN:
# Hey, two hearts got busted last time. Maybe she's not over it either.
#
# => 189. JOHNNY:
# ...
#
# 1368. REED:
# JOHNNY! SPOT-WELD!
#
# => 1369. narrator:
# => Johnny FLIES toward him, and uses his flames to WELD the wires back together. Sparks fly. The cables start to FUSE. Doom keeps FIRING. Sue struggles with her force-fields. The impact is too much. Her nose starts to bleed.
#
# 1370. SUE:
# Can't...hold...on...
#
# 1371. narrator:
# Doom smiles. Reed sees her. She is about to drop her hands, vulnerable, but..............REED STRETCHES HIS WHOLE BODY! He EXPANDS himself across the street, and GRABS a TREE, so he forms a WALL between Sue and Doom. Doom keeps FIRING his bolts. They SLAM into Reed's body, RUBBERBAND his skin, and DISTEND OUT his back without breaking. He strains, agonizing.
#
# ******** test model 1: line 1369 ********
# 1 relations identified
# entities: narrator => , Johnny, Sue, Sparks
# relation: Johnny FLIES toward him, and uses his flames to WELD the wires back together. Sparks fly. The cables start to FUSE. Doom keeps FIRING. Sue struggles with her force-fields. The impact is too much. Her nose starts to bleed.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 135 ********
# 133. narrator:
# They hit a set of big doors. Victor stops and looks into the reflective, metallic surface on the wall. He fixes one last strand of hair. Perfect. Then he opens the door to... SNAP!SNAP!SNAP! WHIP-PAN a row of CAMERAS snapping shots of -- EXT. LAKE LAUNCH FACILITY - NIGHT Retrofitted into a makeshift press area. Victor sits on a platform, with reporters stretched out below him.
#
# 134. VICTOR:
# Today we stand on the edge of a new frontier. In the furthest depths of outer space...we will find the secrets to inner space. The final key to unlocking our genetic code lies in a cosmic storm...
#
# => 135. narrator:
# => BEHIND THE ACTION: Reed, Sue, Johnny and Ben walk past. News crews barely notice, passing without even taking a picture. Our "Fantastic Four" are not exactly big news. Not yet.
#
# 136. BEN:
# Isn't that your speech?
#
# 137. REED:
# He's made a few changes.
#
# ******** test model 1: line 135 ********
# 1 relations identified
# entities: narrator => , Reed, Sue, Johnny, Ben, News crews
# relation: BEHIND THE ACTION: Reed, Sue, Johnny and Ben walk past. News crews barely notice, passing without even taking a picture. Our "Fantastic Four" are not exactly big news. Not yet.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 1034 ********
# 1032. narrator:
# Victor considers. He seems to enjoy watching Reed dangle.
#
# 1033. VICTOR:
# Reed. I'm not asking permission. (a final verdict) We'll build it, while you check the specs.
#
# => 1034. narrator:
# => Victor walks out. Reed looks unsure, as we CUT TO -- INT. BAXTER BUILDING TRANSFORMATION LAB - DAY The SHIELDS slowly rise. FIVE TECHNICIANS go to work. They wear the VDI jackets. Reed watches, worried. Sue enters. She sees the shields, the technicians, the VDI logo. And she is deeply worried. She steps over to Reed. Sparks fly behind them. Drills scream.
#
# 1035. SUE:
# Can I talk to you?
#
# 1036. narrator:
# INT. BAXTER BUILDING - REED'S OFFICE - DAY Sue steps into the office, followed by Reed. Quiet, urgent:
#
# ******** test model 1: line 1034 ********
# 1 relations identified
# entities: narrator => , Sue, Victor, Reed, TECHNICIANS, technicians, Sparks
# relation: Victor walks out. Reed looks unsure, as we CUT TO -- INT. BAXTER BUILDING TRANSFORMATION LAB - DAY The SHIELDS slowly rise. FIVE TECHNICIANS go to work. They wear the VDI jackets. Reed watches, worried. Sue enters. She sees the shields, the technicians, the VDI logo. And she is deeply worried. She steps over to Reed. Sparks fly behind them. Drills scream.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 1185 ********
# 1183. narrator:
# He pulls away from her, taking a step out the door.
#
# 1184. JOHNNY:
# Let's try something new: you live your life. And I'll live mine. (beat) And just for the record: they LOVE me.
#
# => 1185. narrator:
# => He strides into the night, leaving Sue alone. A dark night. The Fantastic Four is no more. The family is split apart. INT. BAXTER BUILDING - TRANSFORMATION LAB - NIGHT The transformation chamber is up and running. Numbers count down. The storm swirls in the chamber. Reed now wears the UNIFORM. He opens the door: HE'S GOING TO USE IT ON HIMSELF. HE IS FINALLY TAKING ACTION. INT. VICTOR'S OFFICE - NIGHT Victor sits enthralled. He leans forward, breathless. INT. BAXTER BUILDING - TRANSFORMATION LAB - NIGHT Reed gets closer. His heart races. So does Victor's. A moment of truth for both of them. REED STEPS INTO THE MACHINE. Reed looks up at the cosmic storm. He opens his arms, ready to risk his life. And...WHHHM! He JOLTS in JUMP-CUT-MOTION, RECONFIGURING, JERKING out of control, and we CUT TO -- VICTOR'S OFFICE - NIGHT His screens GO BLACK. He looks out the window to see...a flash atop the BAXTER BUILDING. The tip of the Baxter glows. The rest of its lights GO OUT, FLICKERING in a power surge. INT. BAXTER BUILDING - GROUND FLOOR - NIGHT Lights go haywire. Sue knows immediately...
#
# 1186. SUE:
# Oh god, Reed.
#
# 1187. narrator:
# INT. BAXTER BUILDING - TRANSFORMATION LAB - NIGHT Lights flicker in darkness. The door rips open. Sue lunges inside. She sees through smoke and sparks...REED sways in the chamber. A beat. Did it work? Then... Reed SLUMPS TO THE GROUND. His eyes flutter back. Dead...? His body is warped, twisted -- one half remains tense, hard, while the other half is loose, soft, almost melted.
#
# ******** test model 1: line 1185 ********
# 1 relations identified
# entities: narrator => , Reed, Sue, VICTOR, family, REED, both, Baxter
# relation: He strides into the night, leaving Sue alone. A dark night. The Fantastic Four is no more. The family is split apart. INT. BAXTER BUILDING - TRANSFORMATION LAB - NIGHT The transformation chamber is up and running. Numbers count down. The storm swirls in the chamber. Reed now wears the UNIFORM. He opens the door: HE'S GOING TO USE IT ON HIMSELF. HE IS FINALLY TAKING ACTION. INT. VICTOR'S OFFICE - NIGHT Victor sits enthralled. He leans forward, breathless. INT. BAXTER BUILDING - TRANSFORMATION LAB - NIGHT Reed gets closer. His heart races. So does Victor's. A moment of truth for both of them. REED STEPS INTO THE MACHINE. Reed looks up at the cosmic storm. He opens his arms, ready to risk his life. And...WHHHM! He JOLTS in JUMP-CUT-MOTION, RECONFIGURING, JERKING out of control, and we CUT TO -- VICTOR'S OFFICE - NIGHT His screens GO BLACK. He looks out the window to see...a flash atop the BAXTER BUILDING. The tip of the Baxter glows. The rest of its lights GO OUT, FLICKERING in a power surge. INT. BAXTER BUILDING - GROUND FLOOR - NIGHT Lights go haywire. Sue knows immediately...
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 1200 ********
# 1198. narrator:
# EXT. UNDER THE BROOKLYN BRIDGE - NIGHT Ben sits alone, looking at city lights. A man without a home. Without a family. A hard beat. HEADLIGHTS slash across Ben. He slowly turns, blinded in the lights of...a LIMO.
#
# 1199. LEONARD:
# Ben! They need you back at the Baxter building. It's...Reed.
#
# => 1200. narrator:
# => Ben considers. Despite it all, he's a good friend. And a good man. As he gets into the car, we hear THROBBING MUSIC IN -- INT. MANHATTAN NIGHT CLUB - NIGHT LOUD MUSIC and PULSATING LIGHTS. A young crowd dances and grinds to the beat. Among the colorful lights, STREAKS OF FLAME swirl around the ceiling. We follow them to: A BALCONY, where we see JOHNNY sitting in a cozy VIP section. He's surrounded by "groupies" climbing over each other to get a look at his various parlour tricks. He leans closer to a YOUNG WOMAN. Closer. Candles around them start to melt. Beads of sweat drip down her face.
#
# 1201. JOHNNY:
# What do you say we get out of here?
#
# 1202. narrator:
# She pauses. And...a very LARGE MAN steps up.
#
# ******** test model 1: line 1200 ********
# 1 relations identified
# entities: narrator => , Ben, man, JOHNNY, crowd, WOMAN, each other
# relation: Ben considers. Despite it all, he's a good friend. And a good man. As he gets into the car, we hear THROBBING MUSIC IN -- INT. MANHATTAN NIGHT CLUB - NIGHT LOUD MUSIC and PULSATING LIGHTS. A young crowd dances and grinds to the beat. Among the colorful lights, STREAKS OF FLAME swirl around the ceiling. We follow them to: A BALCONY, where we see JOHNNY sitting in a cozy VIP section. He's surrounded by "groupies" climbing over each other to get a look at his various parlour tricks. He leans closer to a YOUNG WOMAN. Closer. Candles around them start to melt. Beads of sweat drip down her face.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 795 ********
# 793. narrator:
# The little car sets the whole shelf off balance. A WAVE OF INVENTIONS COME CLATTERING DOWN! Reed moves fast: He LUNGES toward Sue, STREETCHING his ARMS AROUND the SHELF, pushing Sue away, just as the INVENTIONS SMASH TO THE GROUND! Reed and Sue hit the floor. A close call. Now more closeness: Sue and Reed lay face-to-face, with Reed's wrapped around her. A heated beat. Their first real intimate moment.
#
# 794. SUE:
# Sorry. My fault. I won't...touch anything.
#
# => 795. narrator:
# => As if suddenly made aware of their vulnerability, Sue and Reed stand, backing off. As they part, we see: BEN watching from the doorway. Melancholy. He disappears. We slowly MOVE TO...A SURVEILLANCE CAMERA in a VENT GRATE. INT. VICTOR'S OFFICE - NIGHT Victor watches a bank of videoscreens. He has the Baxter Building under surveillance. He sees Reed and Sue on monitors. He toys with Sue's diamond ring in his gloved hand. A door opens. Leonard enters. He sees the screens.
#
# 796. LEONARD:
# Is Reed any closer to a cure?
#
# 797. narrator:
# Victor looks at that image of Reed and Sue on the screen.
#
# ******** test model 1: line 795 ********
# 2 relations identified
# entities: narrator => , VICTOR, BEN, Sue, Reed, Leonard
# relation: As if suddenly made aware of their vulnerability, Sue and Reed stand, backing off. As they part, we see: BEN watching from the doorway. Melancholy. He disappears. We slowly MOVE TO...A SURVEILLANCE CAMERA in a VENT GRATE. INT. VICTOR'S OFFICE - NIGHT Victor watches a bank of videoscreens. He has the Baxter Building under surveillance. He sees Reed and Sue on monitors. He toys with Sue's diamond ring in his gloved hand. A door opens. Leonard enters. He sees the screens.
# category: 3
# entities: ['Cain'] => Baxter Building
# relation:  has the Baxter
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 377 ********
# 375. narrator:
# Ben's stomach growls again, even louder this time. INT. VON DOOM COMPOUND DINING HALL - EVENING The sun is long gone, and so are most of the diners. The room is darker, more romantic. Ben finishes the last shrimp on his plate, pushes it away, belches prodigiously.
#
# 376. BEN:
# Pardon me...
#
# => 377. narrator:
# => Sue and Reed stare at him. Ben's stomach growls again.
#
# 378. REED:
# Are you alright?
#
# 379. BEN:
# I think I need to lie down. Bad shrimp.
#
# ******** test model 1: line 377 ********
# 1 relations identified
# entities: narrator => , Reed, Sue, Ben
# relation: Sue and Reed stare at him. Ben's stomach growls again.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 382 ********
# 380. narrator:
# This was Ben's plan, but he really isn't feeling well, unsteady when he walks away. He looks down at his stomach.
#
# 381. BEN:
# Really bad shrimp.
#
# => 382. narrator:
# => ANGLE: Fireplace. Sue looks gorgeous in the light. A beat. A long beat. Reed doesn't know where to start with this woman.
#
# 383. REED:
# Feeling better?
#
# 384. SUE:
# Yes, thanks.
#
# ******** test model 1: line 382 ********
# 1 relations identified
# entities: narrator => , Sue, woman, Reed
# relation: ANGLE: Fireplace. Sue looks gorgeous in the light. A beat. A long beat. Reed doesn't know where to start with this woman.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 873 ********
# 871. narrator:
# He walks out. As he goes, he slips the engagement ring out of his pocket. He crushes the diamond to dust, leaves the dust in an ashtray, and disappears into the night. Sue sits embarrassed. She slowly...disappears. People gasp. She walks out, invisible, save for her clothes, which DRIFT through the air. At a TABLE FULL OF BUSINESSMEN --
#
# 872. BUSINESSMAN:
# I wish my wife would disappear.
#
# => 873. narrator:
# => The other men laugh, but WHHM! The man's wine SPILLS into his LAP! Sue walks out. The restaurant is left buzzing. Lights twinkle. And we FADE OUT. A beat. Then we CRASH INTO -- EXT. NYC ARENA - ESPN MOTO X GAMES - DAY The X games in full effect: A maze of mountainous dirt hills and ramps...where MOTO-BIKES launch into the air to the delight of 20,000 fans. The Riders spin and flip, performing aerial acrobatics on their 250CC motor bikes.
#
# 874. X GAMES ANNOUNCER:
# And now, ladies and gentlemen, we have a special guest for you... Johnny Storm of the Fantastic Four!
#
# 875. narrator:
# JOHNNY emerges, wearing his blue uniform, waving to the crowd. He steps up to the pit where RIDERS prep. He beelines to RONNIE RENNER.
#
# ******** test model 1: line 873 ********
# 1 relations identified
# entities: narrator => , man, men, Riders, Sue, fans
# relation: The other men laugh, but WHHM! The man's wine SPILLS into his LAP! Sue walks out. The restaurant is left buzzing. Lights twinkle. And we FADE OUT. A beat. Then we CRASH INTO -- EXT. NYC ARENA - ESPN MOTO X GAMES - DAY The X games in full effect: A maze of mountainous dirt hills and ramps...where MOTO-BIKES launch into the air to the delight of 20,000 fans. The Riders spin and flip, performing aerial acrobatics on their 250CC motor bikes.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 1008 ********
# 1006. narrator:
# An IMAGE of VICTOR on screen.
#
# 1007. NEWSCASTER:
# Reports have surfaced that Von Doom Industries may be filing for bankruptcy. You may remember that it was Victor Von Doom who...
#
# => 1008. narrator:
# => Victor turns away from the screen. The volume goes down. He focuses his eyes on REED. Leonard enters, stepping closer, seeing the faint flicker of VICTOR'S METALLIC SCAR. His eyes narrow, concerned.
#
# 1009. LEONARD:
# Sir, is everything okay? What happened to your...?
#
# 1010. narrator:
# Victor keeps his eyes on the screen, totally engrossed.
#
# ******** test model 1: line 1008 ********
# 1 relations identified
# entities: narrator => , Victor, Leonard, REED
# relation: Victor turns away from the screen. The volume goes down. He focuses his eyes on REED. Leonard enters, stepping closer, seeing the faint flicker of VICTOR'S METALLIC SCAR. His eyes narrow, concerned.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 738 ********
# 736. narrator:
# INT. BAXTER BUILDING LABS - DAY ANGLES of Reed in the lab, grabbing their space uniforms from various closets/containers:
#
# 737. REED:
# Our uniforms were exposed to the storm like us. So they can transform like us, becoming invisible, changing size on demand or remaining impervious to flame.
#
# => 738. narrator:
# => REVEAL: Reed, Sue, and Johnny step out to look at themselves in a mirror wearing the uniforms. No boots, no gloves. Not yet. (The uniforms will develop, like our heroes).
#
# 739. BEN:
# You look like an eighties rock band.
#
# 740. SUE:
# (to Ben) The suit will stretch. You should try it --
#
# ******** test model 1: line 738 ********
# 1 relations identified
# entities: narrator => , Reed, Sue, Johnny
# relation: REVEAL: Reed, Sue, and Johnny step out to look at themselves in a mirror wearing the uniforms. No boots, no gloves. Not yet. (The uniforms will develop, like our heroes).
# category: 3
#
# how many are correctly identified? 1
#
# ******** test results ********
# model 1: precision = 0.52 (29/56 correct)

# %%
df_dict['df_6']['relations'] = df_dict['df_6'].apply(lambda x:extract_relation_categories(x), axis=1)
REEval([df_dict['df_6']])
#21/54
# Out:
# ******** line 54 ********
# 52. Tony Stark:
# I see that, cause it's on your t-shirt.
#
# 53. Aldrich Killian:
# Oh!
#
# => 54. Tony Stark:
# => [to the party of women in the elevator; referring to Hogan as they walk out] Ladies, follow the mullet.
#
# 55. Maya Hansen:
# [to Aldrich as she walks out of the elevator] Thank you, I'll call you.
#
# 56. narrator:
# as everyone walks out of the elevator, Tony stops Aldrich from getting out by putting out his arm in front of him
#
# ******** test model 1: line 54 ********
# 1 relations identified
# entities: Tony Stark => , women, Ladies, Hogan
# relation: [to the party of women in the elevator; referring to Hogan as they walk out] Ladies, follow the mullet.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 523 ********
# 521. Pepper Potts:
# Well, you know...
#
# 522. Maya Hansen:
# Yeah.
#
# => 523. Pepper Potts:
# => You have saved yourself a world of pain.
#
# 524. Maya Hansen:
# I'm sure.
#
# 525. Tony Stark:
# What?
#
# ******** test model 1: line 523 ********
# 1 relations identified
# entities: ['Maya Hansen'] => world
# relation:  saved yourself a
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 180 ********
# 178. narrator:
# then we see Joan Rivers on 'The Fashion Police' talking about the new Iron Man suit
#
# 179. Joan Rivers:
# Same suit, but painted red, white, and blue. Look at That. And they also renamed him Iron Patriot. You know, just in case the paint was too subtle.
#
# => 180. narrator:
# => Rhodes and Tony Stark are at a bar and they see Joan Rivers making fun of the Iron Patriot suit on TV
#
# 181. Colonel James Rhodes:
# It tested well with focus groups, alright?
#
# 182. Tony Stark:
# [putting on a mocking voice] I am Iron Patriot...
#
# ******** test model 1: line 180 ********
# 1 relations identified
# entities: narrator => , Rhodes, Tony Stark, Joan Rivers
# relation: Rhodes and Tony Stark are at a bar and they see Joan Rivers making fun of the Iron Patriot suit on TV
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 331 ********
# 329. Happy Hogan:
# Of course you don't. He's not a blond with a big rack. At first it was fine, they were talking business, but now it's like getting weird. He's showing her a big brain.
#
# 330. Tony Stark:
# His what?
#
# => 331. Happy Hogan:
# => Big brain, and she likes it. Here, let me show you. Hold on. See? [he holds his tablet up and points it towards Pepper's glass office, where Aldrich and Pepper are standing close together on the coffee table watching the 3d image of the brain, but all Tony sees is Hogan pointing the tablet camera at himself]
#
# 332. Tony Stark:
# Look at what? You watching them? Flip the screen and then we can get started.
#
# 333. Happy Hogan:
# I'm not a tech genius like you. Just...just trust me, get down down here.
#
# ******** test model 1: line 331 ********
# 1 relations identified
# entities: Happy Hogan => , Pepper, Aldrich, Tony
# relation: Big brain, and she likes it. Here, let me show you. Hold on. See? [he holds his tablet up and points it towards Pepper's glass office, where Aldrich and Pepper are standing close together on the coffee table watching the 3d image of the brain, but all Tony sees is Hogan pointing the tablet camera at himself]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 619 ********
# 617. Aldrich Killian:
# I see.
#
# 618. Savin:
# No Stark.
#
# => 619. Aldrich Killian:
# => I have to go. [Aldrich rises from his seat walks towards another room] The Master is about to record and he's a little... Well, you know how he gets. Keep your appointment tonight and call me when it's done. [Aldrich walks into a room which has been set up as a set with all of Mandarin's props in place and camera crew ready to record Mandarin's message] Alright everybody. No talking and no eye contact, unless you wanna get shot in the face. [we then see the Mandarin arrive with his entourage and enter the house]
#
# 620. Mandarin Look-Out:
# The Master is traveling. [the Mandarin arrives on set and takes a sit, he looks at Aldrich]
#
# 621. The Mandarin:
# Well then, what are we waiting for? [in Rose Hills, Tennessee, Tony and Harley walk in town at night]
#
# ******** test model 1: line 619 ********
# 1 relations identified
# entities: Aldrich Killian => , entourage, crew, everybody
# relation: I have to go. [Aldrich rises from his seat walks towards another room] The Master is about to record and he's a little... Well, you know how he gets. Keep your appointment tonight and call me when it's done. [Aldrich walks into a room which has been set up as a set with all of Mandarin's props in place and camera crew ready to record Mandarin's message] Alright everybody. No talking and no eye contact, unless you wanna get shot in the face. [we then see the Mandarin arrive with his entourage and enter the house]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 672 ********
# 670. Tony Stark:
# As a weapon.
#
# 671. Mrs. Davis:
# You're not the person who called me after all, are you? [suddenly a cell phone is slammed on their table]
#
# => 672. Brandt:
# => Actually, I am. [Tony looks up and it's the woman he bumped into outsid the bar] [suddenly Brandt grabs hold of Tony's arm and twists it, slamming his head onto the table, Tony manages to quickly grab hold of Chad's dog tags that were on the table]
#
# 673. Rose Hills Sheriff:
# Hey, hey, hey! What's all this about? What the hell's going on here?
#
# 674. Brandt:
# It's called an arrest. [she pushes Tony to the ground and steps towards the Sheriff] Sheriff, is it?
#
# ******** test model 1: line 672 ********
# 1 relations identified
# entities: Brandt => , Tony, woman, Chad
# relation: Actually, I am. [Tony looks up and it's the woman he bumped into outsid the bar] [suddenly Brandt grabs hold of Tony's arm and twists it, slamming his head onto the table, Tony manages to quickly grab hold of Chad's dog tags that were on the table]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 552 ********
# 550. Maya Hansen:
# [she points to the bomb heading straight for the house, the house is suddenly hit, as everything explodes around them, Tony manages to get his Iron Man suit onto Pepper to protect her from the fall, Tony looks over to Maya, who's lying unconscious on the ground, as the ceiling is about to fall on Tony, Pepper saves him with the Iron Man suit] Do we need to worry about that?
#
# 551. Pepper Potts:
# I got you.
#
# => 552. Tony Stark:
# => I got you first. Like I said, we can't stay here. [the helicopters starts shooting at the house] Move! I'm right behind! [as they run to get out, the floor in front of Tony collapses, Pepper manages to get on the other side] Get her, I'm gonna find a way around. [Pepper hesitates] Stop stopping! Get her, get outside! Go! [Pepper manages to grab Maya and use the Iron Man suit to get them safely out of the house, but the house gets further destroyed as the helicopters continue to fire on it]
#
# 553. Pepper Potts:
# Oh my God. Tony! [back inside as the house is being destroyed around Tony]
#
# 554. Jarvis:
# Sir, Miss Potts is clear of the structure. [Tony motions for his Iron Man suit to come off Pepper and onto him]
#
# ******** test model 1: line 552 ********
# 1 relations identified
# entities: Tony Stark => , Pepper, Iron Man, Maya
# relation: I got you first. Like I said, we can't stay here. [the helicopters starts shooting at the house] Move! I'm right behind! [as they run to get out, the floor in front of Tony collapses, Pepper manages to get on the other side] Get her, I'm gonna find a way around. [Pepper hesitates] Stop stopping! Get her, get outside! Go! [Pepper manages to grab Maya and use the Iron Man suit to get them safely out of the house, but the house gets further destroyed as the helicopters continue to fire on it]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 200 ********
# 198. Tony Stark:
# If Richard doesn't mind. [to Rhodes] You alright with this, Dick?
#
# 199. Colonel James Rhodes:
# Fine with me.
#
# => 200. narrator:
# => Tony looks at the drawing of himself in his Iron Man suit that the girl has drawn
#
# 201. Erin:
# Erin.
#
# 202. narrator:
# Tony looks at the boy standing next to him
#
# ******** test model 1: line 200 ********
# 1 relations identified
# entities: narrator => , Tony, girl, Iron Man
# relation: Tony looks at the drawing of himself in his Iron Man suit that the girl has drawn
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 65 ********
# 63. narrator:
# the elevator door closes
#
# 64. Tony Stark:
# Damn betcha. Come on! I thought that was just a theory.
#
# => 65. Maya Hansen:
# => Well, it was. If I'm right, we can access the area of the brain that governs repair.
#
# 66. narrator:
# we see they are looking at a computer monitor with graph of the brain
#
# 67. Tony Stark:
# Wow.
#
# ******** test model 1: line 65 ********
# 1 relations identified
# entities: ['Mutant'] => area
# relation:  access the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 659 ********
# 657. Brandt:
# Nice watch.
#
# 658. Tony Stark:
# Yeah, limited edition.
#
# => 659. Brandt:
# => Oh, I don't doubt it. [there's a moment's pause] Well, have a good evening. [the woman turns and walks off] [Tony enters the bar and walks up to Mrs. Davis, who's sat at table drinking alone]
#
# 660. Tony Stark:
# Mrs. Davis, mind if I join you?
#
# 661. Mrs. Davis:
# Free country.
#
# ******** test model 1: line 659 ********
# 2 relations identified
# entities: Brandt => , Mrs. Davis, woman, Tony
# relation: Oh, I don't doubt it. [there's a moment's pause] Well, have a good evening. [the woman turns and walks off] [Tony enters the bar and walks up to Mrs. Davis, who's sat at table drinking alone]
# category: 3
# entities: Tony => bar
# relation:  enters the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 416 ********
# 414. Tony Stark:
# Well, yeah. I just mean we were just...just hosting you while I finished up a little work.
#
# 415. Pepper Potts:
# Uh-huh.
#
# => 416. Tony Stark:
# => And yes, I had a quick bite. I didn't know if you were comin' home or if you were having drinks with Aldrich Killian.
#
# 417. narrator:
# Mark 42 suit turns its face toward her, as if to look at her accusingly
#
# 418. Pepper Potts:
# What?
#
# ******** test model 1: line 416 ********
# 1 relations identified
# entities: ['Pepper Potts'] => home
# relation:  comin '
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 550 ********
# 548. Maya Hansen:
# Guys, can we um...
#
# 549. Tony Stark:
# What?
#
# => 550. Maya Hansen:
# => [she points to the bomb heading straight for the house, the house is suddenly hit, as everything explodes around them, Tony manages to get his Iron Man suit onto Pepper to protect her from the fall, Tony looks over to Maya, who's lying unconscious on the ground, as the ceiling is about to fall on Tony, Pepper saves him with the Iron Man suit] Do we need to worry about that?
#
# 551. Pepper Potts:
# I got you.
#
# 552. Tony Stark:
# I got you first. Like I said, we can't stay here. [the helicopters starts shooting at the house] Move! I'm right behind! [as they run to get out, the floor in front of Tony collapses, Pepper manages to get on the other side] Get her, I'm gonna find a way around. [Pepper hesitates] Stop stopping! Get her, get outside! Go! [Pepper manages to grab Maya and use the Iron Man suit to get them safely out of the house, but the house gets further destroyed as the helicopters continue to fire on it]
#
# ******** test model 1: line 550 ********
# 1 relations identified
# entities: Maya Hansen => , Tony, Pepper, Iron Man
# relation: [she points to the bomb heading straight for the house, the house is suddenly hit, as everything explodes around them, Tony manages to get his Iron Man suit onto Pepper to protect her from the fall, Tony looks over to Maya, who's lying unconscious on the ground, as the ceiling is about to fall on Tony, Pepper saves him with the Iron Man suit] Do we need to worry about that?
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 554 ********
# 552. Tony Stark:
# I got you first. Like I said, we can't stay here. [the helicopters starts shooting at the house] Move! I'm right behind! [as they run to get out, the floor in front of Tony collapses, Pepper manages to get on the other side] Get her, I'm gonna find a way around. [Pepper hesitates] Stop stopping! Get her, get outside! Go! [Pepper manages to grab Maya and use the Iron Man suit to get them safely out of the house, but the house gets further destroyed as the helicopters continue to fire on it]
#
# 553. Pepper Potts:
# Oh my God. Tony! [back inside as the house is being destroyed around Tony]
#
# => 554. Jarvis:
# => Sir, Miss Potts is clear of the structure. [Tony motions for his Iron Man suit to come off Pepper and onto him]
#
# 555. Tony Stark:
# Jarvis, where's my flight power?!
#
# 556. Jarvis:
# Working on it, sir. This is a prototype. [Tony manages to use his suit to destroy one of the helicopters]
#
# ******** test model 1: line 554 ********
# 1 relations identified
# entities: Jarvis => , Potts, Sir, Iron Man
# relation: Sir, Miss Potts is clear of the structure. [Tony motions for his Iron Man suit to come off Pepper and onto him]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 198 ********
# 196. Colonel James Rhodes:
# ...tator.
#
# 197. Erin:
# Do you mind signing my drawing?
#
# => 198. Tony Stark:
# => If Richard doesn't mind. [to Rhodes] You alright with this, Dick?
#
# 199. Colonel James Rhodes:
# Fine with me.
#
# 200. narrator:
# Tony looks at the drawing of himself in his Iron Man suit that the girl has drawn
#
# ******** test model 1: line 198 ********
# 1 relations identified
# entities: Tony Stark => , Richard, Rhodes, Dick
# relation: If Richard doesn't mind. [to Rhodes] You alright with this, Dick?
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 572 ********
# 570. Jarvis:
# I actually think I need to sleep now, sir. [the suit loses power]
#
# 571. Tony Stark:
# Jarvis. Jarvis? Don't leave me, buddy. [Tony drags the suit to a petrol station and makes a call to Pepper]
#
# => 572. Tony Stark:
# => Pepper, it's me. I've got a lot of apologies to make and not a lot of time. So first off, I'm so sorry I put you in harm's way. That was selfish and stupid and it won't happen again. Also, it's Christmas time, the rabbit's too big. Done. Sorry. And I'm sorry in advance because...I can't come home yet. I need to find this guy. You gotta stay safe. That's all I know. I just stole a poncho from a wooden Indian. [Tony drags the suit to an abandoned looking farmhouse, he places the suit on a couch and sits next to it] Let's get you comfy. [he places its hand by its side] You happy now? [as Tony tries to fix the micro-repeater implants in his arm a boy stands by the doorway and points his toy gun at Tony]
#
# 573. Harley Keener:
# Freeze! Don't move.
#
# 574. Tony Stark:
# You got me. Nice potato gun. Barrel's a little long. Between that and the wide gauge, it's gonna diminish your FPS. [the boy points his gun at a glass on a shelf and shoots at it, breaking the glass] And now you're out of ammo.
#
# ******** test model 1: line 572 ********
# 1 relations identified
# entities: Tony Stark => , Pepper, guy, boy
# relation: Pepper, it's me. I've got a lot of apologies to make and not a lot of time. So first off, I'm so sorry I put you in harm's way. That was selfish and stupid and it won't happen again. Also, it's Christmas time, the rabbit's too big. Done. Sorry. And I'm sorry in advance because...I can't come home yet. I need to find this guy. You gotta stay safe. That's all I know. I just stole a poncho from a wooden Indian. [Tony drags the suit to an abandoned looking farmhouse, he places the suit on a couch and sits next to it] Let's get you comfy. [he places its hand by its side] You happy now? [as Tony tries to fix the micro-repeater implants in his arm a boy stands by the doorway and points his toy gun at Tony]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 457 ********
# 455. Pepper Potts:
# I'm going to sleep downstairs. Tinker with that.
#
# 456. narrator:
# Pepper leaves the room
#
# => 457. narrator:
# => at the Chinese theater in Los Angeles, we see Aldrich's henchman meet a man who's sat outside the theater
#
# 458. Savin:
# Can you regulate?
#
# 459. Taggert:
# Yes, I can regulate.
#
# ******** test model 1: line 457 ********
# 1 relations identified
# entities: narrator => , henchman, man, Aldrich
# relation: at the Chinese theater in Los Angeles, we see Aldrich's henchman meet a man who's sat outside the theater
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 95 ********
# 93. Tony Stark:
# It's revolutionary.
#
# 94. Maya Hansen:
# Disease prevention...
#
# => 95. Tony Stark:
# => It can change the world.
#
# 96. narrator:
# as Maya and Tony are talking we see her plant, where Hogan had ripped of the leaf and stem, start to regenerate
#
# 97. Maya Hansen:
# Even limb regrowth.
#
# ******** test model 1: line 95 ********
# 1 relations identified
# entities: It => world
# relation:  change the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 507 ********
# 505. Tony Stark:
# Normally, I'd go for that sort of thing, but now I'm in a committed relationship. [as he turns to walk into the living room, two bags are thrown down from the above balcony] It's...with her.
#
# 506. Pepper Potts:
# Tony, is somebody there? [Tony steps out of his suit]
#
# => 507. Tony Stark:
# => Yeah, it's Maya Hansen. Old botanist pal that I used to know, barely. [as Pepper starts walking downstairs, Tony moves towards Maya and speaks quietly] Please don't tell me that there is a twelve year-old kid waiting in the car that I've never met.
#
# 508. Maya Hansen:
# He's thirteen. And no, I need your help.
#
# 509. Tony Stark:
# What...what for? Why now?
#
# ******** test model 1: line 507 ********
# 1 relations identified
# entities: Tony Stark => , Maya Hansen, botanist pal, Pepper, kid
# relation: Yeah, it's Maya Hansen. Old botanist pal that I used to know, barely. [as Pepper starts walking downstairs, Tony moves towards Maya and speaks quietly] Please don't tell me that there is a twelve year-old kid waiting in the car that I've never met.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 106 ********
# 104. narrator:
# Maya takes off Tony's glasses, Tony laughs
#
# 105. Tony Stark:
# You almost bought it, didn't you?
#
# => 106. narrator:
# => Maya wears Tony's glasses and smiles at him, as they start to kiss, Hogan starts closing the bedroom door, suddenly they are interrupted by the plant exploding
#
# 107. narrator:
# after the plant explodes
#
# 108. Maya Hansen:
# This is what I'm talking about, the glitch.
#
# ******** test model 1: line 106 ********
# 1 relations identified
# entities: narrator => , Tony, Maya, Hogan
# relation: Maya wears Tony's glasses and smiles at him, as they start to kiss, Hogan starts closing the bedroom door, suddenly they are interrupted by the plant exploding
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 456 ********
# 454. Tony Stark:
# Don't go, alright? Pepper?
#
# 455. Pepper Potts:
# I'm going to sleep downstairs. Tinker with that.
#
# => 456. narrator:
# => Pepper leaves the room
#
# 457. narrator:
# at the Chinese theater in Los Angeles, we see Aldrich's henchman meet a man who's sat outside the theater
#
# 458. Savin:
# Can you regulate?
#
# ******** test model 1: line 456 ********
# 1 relations identified
# entities: Pepper => room
# relation:  leaves the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 336 ********
# 334. Tony Stark:
# Flip the screen, then I can see what they're doing.
#
# 335. Happy Hogan:
# I can't! I don't know how to flip the screen!Don't talk to me like that anymore. You're not my boss.
#
# => 336. narrator:
# => as Hogan is talking, Tony uses his small tablet device to look up Aldrich and finds his photo
#
# 337. Happy Hogan:
# Alright, I don't work for you. Now I don't trust this guy. He's got another guy with him, he's shifty.
#
# 338. Tony Stark:
# Relax.
#
# ******** test model 1: line 336 ********
# 1 relations identified
# entities: narrator => , Tony, Hogan, Aldrich
# relation: as Hogan is talking, Tony uses his small tablet device to look up Aldrich and finds his photo
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 498 ********
# 496. Jarvis:
# Creating a flight plan for Tennessee. [as Tony is about to get ready to leave for Tennessee, he hears his door bell ring]
#
# 497. Tony Stark:
# Are we still at "ding-dong"? We're supposed to be on total security lock down. Come on, I threatened a terrorist. Who is that?
#
# => 498. Jarvis:
# => There's only so much I can do, sir, when you give the world's press your home address. [we see Maya standing outside Tony's house, the glass doors are opened and she enters]
#
# 499. Tony Stark:
# Right there's fine. [Tony dressed in his Iron Man suit walks toward her] You're not the Mandarin, are you? Are you?
#
# 500. Maya Hansen:
# You don't remember. Why am I not surprised?
#
# ******** test model 1: line 498 ********
# 1 relations identified
# entities: Jarvis => , sir, Maya, Tony
# relation: There's only so much I can do, sir, when you give the world's press your home address. [we see Maya standing outside Tony's house, the glass doors are opened and she enters]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 474 ********
# 472. Savin:
# What?
#
# 473. Taggert:
# Help! Help me! [Taggert suddenly explodes, causing a massive explosion inside the theater which wounds Hogan, as he lies injured, Hogan sees Savin, also glowing red and then healing and walking off as if nothing has happened] [we see another TV footage from The Mandarin]
#
# => 474. The Mandarin:
# => True story about fortune cookies. They look Chinese, they sound Chinese, but they're actually an American invention. Which is why they're hollow, full of lies, and leave a bad taste in the mouth. My disciples just destroyed another cheap American knock-off, The Chinese Theater. Mr. President, I know this must be getting frustrating, but this season of terror is drawing to a close. And don't worry, the big one is coming; your graduation. [as Hogan lies in hospital critically injured, Tony is sat in his room when a nurse walks in to check on Hogan]
#
# 475. Tony Stark:
# Hi.
#
# 476. Happy's Nurse:
# Oh.
#
# ******** test model 1: line 474 ********
# 1 relations identified
# entities: The Mandarin => , Hogan, President, disciples, nurse, one
# relation: True story about fortune cookies. They look Chinese, they sound Chinese, but they're actually an American invention. Which is why they're hollow, full of lies, and leave a bad taste in the mouth. My disciples just destroyed another cheap American knock-off, The Chinese Theater. Mr. President, I know this must be getting frustrating, but this season of terror is drawing to a close. And don't worry, the big one is coming; your graduation. [as Hogan lies in hospital critically injured, Tony is sat in his room when a nurse walks in to check on Hogan]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 487 ********
# 485. Tony Stark:
# No bomb parts found in a three mile radius of the Chinese theater.
#
# 486. Jarvis:
# No, sir.
#
# => 487. Tony Stark:
# => Talk to me, Happy. [in the virtual reconstruction, Tony sees Hogan pointing his finger at some dog tags] When is a bomb not a bomb? [Tony picks up the virtual image of the dog tags to investigate them further] When is a bomb not a bomb? [Tony picks up the virtual image of the dog tags to investigate them further] Any military victims?
#
# 488. Jarvis:
# Not according to public records, sir.
#
# 489. Tony Stark:
# Bring up the thermogenic signatures again, factor in three thousand degrees.
#
# ******** test model 1: line 487 ********
# 1 relations identified
# entities: Tony Stark => , Hogan, Happy., military victims
# relation: Talk to me, Happy. [in the virtual reconstruction, Tony sees Hogan pointing his finger at some dog tags] When is a bomb not a bomb? [Tony picks up the virtual image of the dog tags to investigate them further] When is a bomb not a bomb? [Tony picks up the virtual image of the dog tags to investigate them further] Any military victims?
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 686 ********
# 684. Tony Stark:
# Watch this. [Tony smashes into the window of a shop] [as Tony and Brandt are fighting in the shop, Tony starts a fire in shop] You walked right into this one, I've dated hotter chicks than you. [Tony puts Chad's dog tags into the microwave and he turns on the gas]
#
# 685. Brandt:
# That's all you got? Cheap trick and a cheesy one-liner?
#
# => 686. Tony Stark:
# => Sweetheart, that could be the name of my autobiography. [Tony quickly leaves through the back door, as the dog tags heat up in the microwave they start sparking up fire, Brandt realizes the gas has been left on and suddenly the shop explodes killing Brandt] [Tony finds the Savin has grabbed Harley]
#
# 687. Harley Keener:
# Let me go! [Savin mocks Harley]
#
# 688. Savin:
# Help me! Help me! [as Tony's leg is trapped under some rubble, Savin sits in front of him with Harley sat on his lap] Hey kid, what would you like for Christmas?
#
# ******** test model 1: line 686 ********
# 1 relations identified
# entities: shop => Harley
# relation:  grabbed
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 232 ********
# 230. narrator:
# Tony flies off in his suit
#
# 231. narrator:
# at Stark Industries Hogan points to his badge as walks through the lobby passing the other employees
#
# => 232. Happy Hogan:
# => Badge...badge...badge. Badge, guys. I put a memo in the toilet, come on. [referring to Tony's robots as Hogan meets with Pepper] Tony has got them in his basement, they're wearing party hats. This is an asset that we can put to use.
#
# 233. Pepper Potts:
# Uh-huh. So, you're suggesting that I replace the entire janitorial staff with robots?
#
# 234. Happy Hogan:
# What I'm saying is that the human element of Human Resources is our biggest point of vulnerability. We should start phasing it out immediately.
#
# ******** test model 1: line 232 ********
# 1 relations identified
# entities: Happy Hogan => , guys, Tony, Tony, Pepper
# relation: Badge...badge...badge. Badge, guys. I put a memo in the toilet, come on. [referring to Tony's robots as Hogan meets with Pepper] Tony has got them in his basement, they're wearing party hats. This is an asset that we can put to use.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 481 ********
# 479. Tony Stark:
# Sunday night's PBS 'Downtown Abbey'. That's his show, he thinks it's elegant. [he pauses for a moment] One more thing...make sure everyone wears their badges. He's a stickler for that sort of thing, plus my guys won't let anyone in without them. [Tony turns to leave] [news reporters are all waiting for Tony outside the hospital]
#
# 480. Hospital News Reporter:
# We're awaiting the arrival of Tony Stark. We're hoping he'll give us the reaction...his reaction to the latest attack. [Tony walks out and all the reporters swarm toward him] Mr. Stark! Mr. Stark! Our sources are telling us that this is another Mandarin attack. Anything else you can tell us? [Tony ignores the questions and walks toward his car]
#
# => 481. Pushy Tabloid Reporter:
# => Hey, Mr. Stark! When is somebody gonna kill this guy? Just sayin'. [Tony turns to face the reporter]
#
# 482. Jarvis:
# I've compiled a Mandarin database for you, sir. Drawn from S.H.I.E.L.D., F.B.I., and C.I.A. intercepts. Initiating virtual crime scene reconstruction. [Tony starts looking at all the data gathered]
#
# 483. Tony Stark:
# Okay, what do we got here? His name is an ancient Chinese war mantle, meaning "adviser to the King". South American insurgency tactics, talks like a Baptist preacher. There's lots of pageantry going on here...lots of theater. [Tony pushes the virtual information down to close] Close. [Tony looks at the virtual crime scene reconstruction]
#
# ******** test model 1: line 481 ********
# 1 relations identified
# entities: Pushy Tabloid Reporter => , Stark, guy, somebody, reporter, Tony
# relation: Hey, Mr. Stark! When is somebody gonna kill this guy? Just sayin'. [Tony turns to face the reporter]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 88 ********
# 86. Tony Stark:
# So you're starting with plants?
#
# 87. Maya Hansen:
# For now, yeah. I'm calling it Extremis.
#
# => 88. narrator:
# => as they enter the room, Hogan touches her plant and pulls some of the leaves off
#
# 89. narrator:
# Tony and Maya continue talking about her research in the bedroom
#
# 90. Maya Hansen:
# Well, it's...human application.
#
# ******** test model 1: line 88 ********
# 1 relations identified
# entities: ['Little Girl'] => room
# relation:  enter the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 654 ********
# 652. Tony Stark:
# Your fault, you spazzed me out. Okay, back to business. Where were we? The guy who died...relatives? Mom? Mrs. Davis, where is she?
#
# 653. Harley Keener:
# Where she always is.
#
# => 654. Tony Stark:
# => See, now you're being helpful. [later we see Tony walking towards a bar and he bumps into a woman] Sorry. [the woman drops something] Lady, this uh... [he picks up the item and hands it back to the woman]
#
# 655. Brandt:
# Thank you. [Tony notices the woman has burn marks on one side of her face]
#
# 656. Tony Stark:
# Nice haircut, suits you.
#
# ******** test model 1: line 654 ********
# 1 relations identified
# entities: Tony Stark => , woman, woman, woman, Lady
# relation: See, now you're being helpful. [later we see Tony walking towards a bar and he bumps into a woman] Sorry. [the woman drops something] Lady, this uh... [he picks up the item and hands it back to the woman]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 77 ********
# 75. Maya Hansen:
# Can you...
#
# 76. Happy Hogan:
# What?
#
# => 77. Maya Hansen:
# => Can you not touch my plant. It's not...she doesn't like it. She prefers...
#
# 78. Tony Stark:
# She's not like the others.
#
# 79. Maya Hansen:
# Interference is better.
#
# ******** test model 1: line 77 ********
# 1 relations identified
# entities: ['Tony Stark'] => plant
# relation:  touch my
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 35 ********
# 33. Tony Stark:
# [voice over] It started in Berns, Switzerland, 1999, the old days. I never thought they'd come back to bite me. Why would they?
#
# 34. narrator:
# as Tony and Maya walk towards the elevator an enthusiastic man with long hair comes up towards them
#
# => 35. Aldrich Killian:
# => Mr. Stark! Oh, wow! Hey, Tony! Aldrich Killian. [to Maya] I'm a big fan of your work!
#
# 36. Maya Hansen:
# My work?
#
# 37. Tony Stark:
# Who isn't? She needs me.
#
# ******** test model 1: line 35 ********
# 1 relations identified
# entities: Aldrich Killian => , Stark, fan, Aldrich Killian., Maya
# relation: Mr. Stark! Oh, wow! Hey, Tony! Aldrich Killian. [to Maya] I'm a big fan of your work!
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 467 ********
# 465. narrator:
# Savin walks off, Hogan walks towards Taggert and as Taggert rises to leave Hogan bumps into him which knock the briefcase out of Taggert's hand, falling open on to the ground
#
# 466. Happy Hogan:
# I'm sorry, buddy.
#
# => 467. narrator:
# => Hogan helps him put the stuff back in the suitcase, and as he looks at Taggert he notices that he is glowing red, Hogan starts to walk off taking one of the items from the suitcase, but suddenly Savin bumps into him
#
# 468. Savin:
# What are you doin', buddy? You out by yourself? A little date night? Watching your favorite chick flick maybe?
#
# 469. Happy Hogan:
# Yeah, a little movie called "The Party's Over", starring you and your junkie girlfriend, and here's the ticket. [Hogan shows him what he took from Taggert's suitcase]
#
# ******** test model 1: line 467 ********
# 1 relations identified
# entities: narrator => , Hogan, Taggert, Savin
# relation: Hogan helps him put the stuff back in the suitcase, and as he looks at Taggert he notices that he is glowing red, Hogan starts to walk off taking one of the items from the suitcase, but suddenly Savin bumps into him
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 465 ********
# 463. Savin:
# It's a decent batch. Don't say I never did nothin' for you.
#
# 464. Taggert:
# Thank you...I mean for understanding.
#
# => 465. narrator:
# => Savin walks off, Hogan walks towards Taggert and as Taggert rises to leave Hogan bumps into him which knock the briefcase out of Taggert's hand, falling open on to the ground
#
# 466. Happy Hogan:
# I'm sorry, buddy.
#
# 467. narrator:
# Hogan helps him put the stuff back in the suitcase, and as he looks at Taggert he notices that he is glowing red, Hogan starts to walk off taking one of the items from the suitcase, but suddenly Savin bumps into him
#
# ******** test model 1: line 465 ********
# 1 relations identified
# entities: narrator => , Hogan, Taggert, Savin
# relation: Savin walks off, Hogan walks towards Taggert and as Taggert rises to leave Hogan bumps into him which knock the briefcase out of Taggert's hand, falling open on to the ground
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 462 ********
# 460. Savin:
# Are you sure about that?
#
# 461. Taggert:
# Yes.
#
# => 462. narrator:
# => Hogan who's been following Savin, keeps an eye on him from a distance, he sees Savin giving the man a briefcase
#
# 463. Savin:
# It's a decent batch. Don't say I never did nothin' for you.
#
# 464. Taggert:
# Thank you...I mean for understanding.
#
# ******** test model 1: line 462 ********
# 1 relations identified
# entities: narrator => , Savin, Hogan, man
# relation: Hogan who's been following Savin, keeps an eye on him from a distance, he sees Savin giving the man a briefcase
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 283 ********
# 281. narrator:
# as Hogan waits outside Pepper's office, he sees Aldrich's man sitting in the waiting area
#
# 282. Happy Hogan:
# Hey, guy.
#
# => 283. narrator:
# => Hogan points to his security badge and the guy picks up his badge from the table next to him and holds it up to show Hogan he has a badge; to an employee as they walk past him
#
# 284. Savin:
# Merry Christmas.
#
# 285. narrator:
# Hogan looks at him with suspicion
#
# ******** test model 1: line 283 ********
# 1 relations identified
# entities: narrator => , Hogan, guy, employee
# relation: Hogan points to his security badge and the guy picks up his badge from the table next to him and holds it up to show Hogan he has a badge; to an employee as they walk past him
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 358 ********
# 356. Aldrich Killian:
# Tony. Tony. You know, I invited Tony to join AIM thirteen years ago, he turned me down. But something tells me now there is a new genius on the throne who doesn't have to answer to Tony anymore, and who has slightly less of an ego.
#
# 357. Pepper Potts:
# It's gonna be a no, Aldrich. As much as I'd like to help you.
#
# => 358. narrator:
# => we see Aldrich leaving the building
#
# 359. Aldrich Killian:
# Well, I can't say that I'm not disappointed. But then as my father used to say, 'Failure is the fog through which we glimpse triumph.'
#
# 360. Pepper Potts:
# That's very deep.
#
# ******** test model 1: line 358 ********
# 1 relations identified
# entities: Aldrich => building
# relation:  leaving the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 74 ********
# 72. Maya Hansen:
# Exactly. Yes.
#
# 73. Tony Stark:
# Wow.
#
# => 74. narrator:
# => Hogan touches Maya's plant
#
# 75. Maya Hansen:
# Can you...
#
# 76. Happy Hogan:
# What?
#
# ******** test model 1: line 74 ********
# 1 relations identified
# entities: Hogan => plant
# relation:  touches Maya 's
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 281 ********
# 279. narrator:
# Hogan steps out of Pepper's office and closes the glass door
#
# 280. Pepper Potts:
# It's very nice to see you, Killian.
#
# => 281. narrator:
# => as Hogan waits outside Pepper's office, he sees Aldrich's man sitting in the waiting area
#
# 282. Happy Hogan:
# Hey, guy.
#
# 283. narrator:
# Hogan points to his security badge and the guy picks up his badge from the table next to him and holds it up to show Hogan he has a badge; to an employee as they walk past him
#
# ******** test model 1: line 281 ********
# 1 relations identified
# entities: narrator => , Hogan, Pepper, man
# relation: as Hogan waits outside Pepper's office, he sees Aldrich's man sitting in the waiting area
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 172 ********
# 170. narrator:
# the news on TV shows footage of The Mandarin
#
# 171. Tony Stark:
# [voice over] That's when he happened.
#
# => 172. The Mandarin:
# => Some people call me a terrorist, I consider myself a teacher. America, ready for another lesson. In 1864 in Sand Creek Colorado the U.S. military waited till the friendly Cheyenne braves all gone hunting, waited to attack and slaughter their families left behind, and claim their land. Thirty-nine hours ago the Ali Al Salem Air Base in Kuwait was attacked. I...I...I did that. A quaint military church filled with wives and children, of course. The soldiers were out on maneuver, the braves were away. President Ellis you continue to resist my attempts to educate you, sir. And now, you've missed me again. You know who I am, you don't know where I am, and you'll never see me coming.
#
# 173. narrator:
# as this footage ends, the TV channels change and all the news channels are talking about The Mandarin
#
# 174. narrator:
# the news on TV shows President Ellis addresses The Mandarin Threat
#
# ******** test model 1: line 172 ********
# 4 relations identified
# entities: The Mandarin => , terrorist, people, teacher, sir, Ellis, families, Cheyenne, wives, children, soldiers, braves
# relation: Some people call me a terrorist, I consider myself a teacher. America, ready for another lesson. In 1864 in Sand Creek Colorado the U.S. military waited till the friendly Cheyenne braves all gone hunting, waited to attack and slaughter their families left behind, and claim their land. Thirty-nine hours ago the Ali Al Salem Air Base in Kuwait was attacked. I...I...I did that. A quaint military church filled with wives and children, of course. The soldiers were out on maneuver, the braves were away. President Ellis you continue to resist my attempts to educate you, sir. And now, you've missed me again. You know who I am, you don't know where I am, and you'll never see me coming.
# category: 3
# entities: America => hunting
# relation:  braves all gone
# category: 5
# entities: America => that
# relation:  did
# category: 5
# entities: America => ['The Mandarin']
# relation:  missed
# category: 5
#
# how many are correctly identified? 2
#
# ******** line 614 ********
# 612. Pepper Potts:
# This boss of yours, does he have a name?
#
# 613. Maya Hansen:
# Yeah, Aldrich Killian. [Pepper looks at her in shock] [we see Aldrich talking on the phone to Savin]
#
# => 614. Savin:
# => Well, we took the house down, sir...
#
# 615. Aldrich Killian:
# Mmhmm.
#
# 616. Savin:
# But there's no sign of a body.
#
# ******** test model 1: line 614 ********
# 1 relations identified
# entities: ['Scott'] => house
# relation:  took the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 479 ********
# 477. Tony Stark:
# [referring to the TV] Uh...mind leaving that on?
#
# 478. Happy's Nurse:
# Sure. [Tony rises from his seat]
#
# => 479. Tony Stark:
# => Sunday night's PBS 'Downtown Abbey'. That's his show, he thinks it's elegant. [he pauses for a moment] One more thing...make sure everyone wears their badges. He's a stickler for that sort of thing, plus my guys won't let anyone in without them. [Tony turns to leave] [news reporters are all waiting for Tony outside the hospital]
#
# 480. Hospital News Reporter:
# We're awaiting the arrival of Tony Stark. We're hoping he'll give us the reaction...his reaction to the latest attack. [Tony walks out and all the reporters swarm toward him] Mr. Stark! Mr. Stark! Our sources are telling us that this is another Mandarin attack. Anything else you can tell us? [Tony ignores the questions and walks toward his car]
#
# 481. Pushy Tabloid Reporter:
# Hey, Mr. Stark! When is somebody gonna kill this guy? Just sayin'. [Tony turns to face the reporter]
#
# ******** test model 1: line 479 ********
# 1 relations identified
# entities: Tony Stark => , stickler, everyone, news reporters, anyone, guys
# relation: Sunday night's PBS 'Downtown Abbey'. That's his show, he thinks it's elegant. [he pauses for a moment] One more thing...make sure everyone wears their badges. He's a stickler for that sort of thing, plus my guys won't let anyone in without them. [Tony turns to leave] [news reporters are all waiting for Tony outside the hospital]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 622 ********
# 620. Mandarin Look-Out:
# The Master is traveling. [the Mandarin arrives on set and takes a sit, he looks at Aldrich]
#
# 621. The Mandarin:
# Well then, what are we waiting for? [in Rose Hills, Tennessee, Tony and Harley walk in town at night]
#
# => 622. Tony Stark:
# => The sandwich was fair, the spring was a little rusty, the rest of the materials, I'll make do. By the way, when you said your sister had a watch, I was kinda hoping for something a little more than that. [he pulls his sleeve up and we see he's wearing a little girl's pink watch, Harley laughs]
#
# 623. Harley Keener:
# She's six! Anyway, it's limited edition. When can we talk about New York?
#
# 624. Tony Stark:
# Maybe never, relax about it.
#
# ******** test model 1: line 622 ********
# 1 relations identified
# entities: Tony Stark => , rest, sister, girl
# relation: The sandwich was fair, the spring was a little rusty, the rest of the materials, I'll make do. By the way, when you said your sister had a watch, I was kinda hoping for something a little more than that. [he pulls his sleeve up and we see he's wearing a little girl's pink watch, Harley laughs]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 668 ********
# 666. Tony Stark:
# Clearly, you're waiting for someone else. Yeah? Supposed to meet somebody here?
#
# 667. Mrs. Davis:
# Yeah. [Tony looks at the file again and notices a photo of Taggart next to the photo of Chad]
#
# => 668. Tony Stark:
# => Mrs. Davis, your son didn't kill himself, I guarantee you. He didn't kill anyone. Someone used him.
#
# 669. Mrs. Davis:
# What?
#
# 670. Tony Stark:
# As a weapon.
#
# ******** test model 1: line 668 ********
# 1 relations identified
# entities: Tony Stark => , son, Davis, Someone, anyone
# relation: Mrs. Davis, your son didn't kill himself, I guarantee you. He didn't kill anyone. Someone used him.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 546 ********
# 544. Pepper Potts:
# I don't like it!
#
# 545. Tony Stark:
# I asked you three... You don't like it?! [as Tony and Pepper are bickering, Maya notices on the TV that helicopters are coming toward Tony's home]
#
# => 546. Pepper Potts:
# => Tony, we are leaving the house; that's not even up for discussion.
#
# 547. Tony Stark:
# I said no.
#
# 548. Maya Hansen:
# Guys, can we um...
#
# ******** test model 1: line 546 ********
# 1 relations identified
# entities: ['Interrogator'] => house
# relation:  leaving the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 483 ********
# 481. Pushy Tabloid Reporter:
# Hey, Mr. Stark! When is somebody gonna kill this guy? Just sayin'. [Tony turns to face the reporter]
#
# 482. Jarvis:
# I've compiled a Mandarin database for you, sir. Drawn from S.H.I.E.L.D., F.B.I., and C.I.A. intercepts. Initiating virtual crime scene reconstruction. [Tony starts looking at all the data gathered]
#
# => 483. Tony Stark:
# => Okay, what do we got here? His name is an ancient Chinese war mantle, meaning "adviser to the King". South American insurgency tactics, talks like a Baptist preacher. There's lots of pageantry going on here...lots of theater. [Tony pushes the virtual information down to close] Close. [Tony looks at the virtual crime scene reconstruction]
#
# 484. Jarvis:
# The heat from the blast was in excess of 3000 degrees Celsius. Any subjects within 12.5 yards were vaporized instantly.
#
# 485. Tony Stark:
# No bomb parts found in a three mile radius of the Chinese theater.
#
# ******** test model 1: line 483 ********
# 1 relations identified
# entities: Tony Stark => , preacher, adviser, King
# relation: Okay, what do we got here? His name is an ancient Chinese war mantle, meaning "adviser to the King". South American insurgency tactics, talks like a Baptist preacher. There's lots of pageantry going on here...lots of theater. [Tony pushes the virtual information down to close] Close. [Tony looks at the virtual crime scene reconstruction]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 610 ********
# 608. Pepper Potts:
# Why were you at the house tonight? What was so important that you had to speak to Tony?
#
# 609. Maya Hansen:
# I think that my boss is working for the Mandarin. So if you still want to talk about it, I suggest that we get ourselves someplace safe.
#
# => 610. Pepper Potts:
# => Your boss works for the Mandarin, you think? But Tony says you're a botanist, so...
#
# 611. Maya Hansen:
# That figures. What I actually am is a biological DNA coder running a team of forty out of a privately-funded think tank, but sure you can call me a botanist.
#
# 612. Pepper Potts:
# This boss of yours, does he have a name?
#
# ******** test model 1: line 610 ********
# 1 relations identified
# entities: Pepper Potts => , botanist, boss, Tony
# relation: Your boss works for the Mandarin, you think? But Tony says you're a botanist, so...
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 217 ********
# 215. narrator:
# suddenly Tony rises and starts walking off
#
# 216. Colonel James Rhodes:
# Wait a minute! Tony!
#
# => 217. narrator:
# => Rhodes follows Tony as he walks out the bar
#
# 218. Tony Stark:
# What'd he say?!
#
# 219. Colonel James Rhodes:
# Tony!
#
# ******** test model 1: line 217 ********
# 1 relations identified
# entities: ['Reporter'] => bar
# relation:  walks out the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 613 ********
# 611. Maya Hansen:
# That figures. What I actually am is a biological DNA coder running a team of forty out of a privately-funded think tank, but sure you can call me a botanist.
#
# 612. Pepper Potts:
# This boss of yours, does he have a name?
#
# => 613. Maya Hansen:
# => Yeah, Aldrich Killian. [Pepper looks at her in shock] [we see Aldrich talking on the phone to Savin]
#
# 614. Savin:
# Well, we took the house down, sir...
#
# 615. Aldrich Killian:
# Mmhmm.
#
# ******** test model 1: line 613 ********
# 1 relations identified
# entities: Maya Hansen => , Aldrich Killian, Pepper, Savin
# relation: Yeah, Aldrich Killian. [Pepper looks at her in shock] [we see Aldrich talking on the phone to Savin]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 681 ********
# 679. Rose Hills Sheriff:
# Yeah, well, why don't you get on the horn to Nashville and uh...upgrade me? [Tony gestures to Mrs. Davis to hide the file, she pushes it under the bar]
#
# 680. Brandt:
# Alright, you know what? I was hoping to do this the smart way, but uh...the fun way's always good. [Tony notices her hand turning red hot, burning the badge in her hand]
#
# => 681. Rose Hills Sheriff:
# => Deputy, get this woman and... [suddenly Brandt shoves the hot badge into the Sheriff's face, she takes his gun and shoots him, Tony runs out of the bar and Brandt follows him, he turns to her]
#
# 682. Tony Stark:
# Hey hot wings, you wanna party? You and me, let's go. [as Tony turns to run again he sees Savin getting out of a car and walk towards him, as Savin gets his gun out to shoot at him, Tony runs off and Harley throws something at Savin to make him miss Tony, Tony stops behind a car and sees a man hiding low on the ground] Crazy, huh?
#
# 683. Rose Hill Christmas Tree Shopper:
# Yeah.
#
# ******** test model 1: line 681 ********
# 1 relations identified
# entities: Rose Hills Sheriff => , woman, Brandt, Deputy, Tony
# relation: Deputy, get this woman and... [suddenly Brandt shoves the hot badge into the Sheriff's face, she takes his gun and shoots him, Tony runs out of the bar and Brandt follows him, he turns to her]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 652 ********
# 650. Tony Stark:
# Remember when I said to stop doing that? I swear to God, you're going to freak me out! [Tony, looking agitated, suddenly rises] Ah man, you did it, didn't you? You happy now?
#
# 651. Harley Keener:
# What did I say? [Tony starts running off and Harley runs after him] Hey, wait up! Wait, wait. [Tony stops running and Harley catches up with him] What the hell was that? [Tony holds his face in his hands for a moment and then throws some snow at Harley]
#
# => 652. Tony Stark:
# => Your fault, you spazzed me out. Okay, back to business. Where were we? The guy who died...relatives? Mom? Mrs. Davis, where is she?
#
# 653. Harley Keener:
# Where she always is.
#
# 654. Tony Stark:
# See, now you're being helpful. [later we see Tony walking towards a bar and he bumps into a woman] Sorry. [the woman drops something] Lady, this uh... [he picks up the item and hands it back to the woman]
#
# ******** test model 1: line 652 ********
# 1 relations identified
# entities: Tony Stark => , guy, Mom, Davis, relatives
# relation: Your fault, you spazzed me out. Okay, back to business. Where were we? The guy who died...relatives? Mom? Mrs. Davis, where is she?
# category: 3
#
# how many are correctly identified? 0
#
# ******** test results ********
# model 1: precision = 0.39 (21/54 correct)

# %%
REEval([df])
# Out:
# ******** line 862 ********
# 860. narrator:
# outside
#
# 861. Paxton:
# [into his radio] All the chaos in here! Multiple shots fired. [suddenly a tank bursts out through the building] And there's a tank. [Luis then walks out of the building with the guard]
#
# => 862. Luis:
# => A little help. [someone takes hold of the guard, at the same time Hope helps Pym out of the tank] I got him. [Luis helps Pym]
#
# 863. Hope van Dyne:
# We need a doctor! [a medic comes over to help Pym]
#
# 864. narrator:
# Cross is in his helicopter
#
# ******** test model 1: line 862 ********
# 1 relations identified
# entities: Luis => , someone, guard, Pym
# relation: A little help. [someone takes hold of the guard, at the same time Hope helps Pym out of the tank] I got him. [Luis helps Pym]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 862 ********
# 860. narrator:
# outside
#
# 861. Paxton:
# [into his radio] All the chaos in here! Multiple shots fired. [suddenly a tank bursts out through the building] And there's a tank. [Luis then walks out of the building with the guard]
#
# => 862. Luis:
# => A little help. [someone takes hold of the guard, at the same time Hope helps Pym out of the tank] I got him. [Luis helps Pym]
#
# 863. Hope van Dyne:
# We need a doctor! [a medic comes over to help Pym]
#
# 864. narrator:
# Cross is in his helicopter
#
# ******** test model 2: line 862 ********
# 1 relations identified
# entities: Luis => , someone, guard, Pym
# relation: A little help. [someone takes hold of the guard, at the same time Hope helps Pym out of the tank] I got him. [Luis helps Pym]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 12 ********
# 10. Dr. Hank Pym:
# First you turn me into your errand boy, and now you try to steal my research.
#
# 11. Mitchell Carson:
# If only you'd protected Janet with such ferocity, Dr. Pym.
#
# => 12. Dr. Hank Pym:
# => Ah. [suddenly Pym slams down Carson's face on the table in anger, Peggy pulls him away]
#
# 13. Peggy Carter:
# Easy, Hank!
#
# 14. Dr. Hank Pym:
# You mention my wife again and I'll show you ferocity. [Carson looks at Stark as he wipes blood from his nose]
#
# ******** test model 1: line 12 ********
# 1 relations identified
# entities: Dr. Hank Pym => , Ah., Carson, Peggy
# relation: Ah. [suddenly Pym slams down Carson's face on the table in anger, Peggy pulls him away]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 12 ********
# 10. Dr. Hank Pym:
# First you turn me into your errand boy, and now you try to steal my research.
#
# 11. Mitchell Carson:
# If only you'd protected Janet with such ferocity, Dr. Pym.
#
# => 12. Dr. Hank Pym:
# => Ah. [suddenly Pym slams down Carson's face on the table in anger, Peggy pulls him away]
#
# 13. Peggy Carter:
# Easy, Hank!
#
# 14. Dr. Hank Pym:
# You mention my wife again and I'll show you ferocity. [Carson looks at Stark as he wipes blood from his nose]
#
# ******** test model 2: line 12 ********
# 1 relations identified
# entities: Dr. Hank Pym => , Ah., Carson, Peggy
# relation: Ah. [suddenly Pym slams down Carson's face on the table in anger, Peggy pulls him away]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 762 ********
# 760. Dave:
# Phshh. Got a Crown Vic right outside over there.
#
# 761. Kurt:
# This is problem?
#
# => 762. Dave:
# => Considering the Crown Vic's the most commonly used car for under-cover cops, man. Yes, this is a problem. [inside the Crown Vic is Paxton and Gale]
#
# 763. Paxton:
# That's Pym. [they get out to go after Pym]
#
# 764. Kurt:
# Oh, no.
#
# ******** test model 1: line 762 ********
# 1 relations identified
# entities: Dave => , Crown Vic, man, Paxton, Gale
# relation: Considering the Crown Vic's the most commonly used car for under-cover cops, man. Yes, this is a problem. [inside the Crown Vic is Paxton and Gale]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 762 ********
# 760. Dave:
# Phshh. Got a Crown Vic right outside over there.
#
# 761. Kurt:
# This is problem?
#
# => 762. Dave:
# => Considering the Crown Vic's the most commonly used car for under-cover cops, man. Yes, this is a problem. [inside the Crown Vic is Paxton and Gale]
#
# 763. Paxton:
# That's Pym. [they get out to go after Pym]
#
# 764. Kurt:
# Oh, no.
#
# ******** test model 2: line 762 ********
# 1 relations identified
# entities: Dave => , Crown Vic, man, Paxton, Gale
# relation: Considering the Crown Vic's the most commonly used car for under-cover cops, man. Yes, this is a problem. [inside the Crown Vic is Paxton and Gale]
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 248 ********
# 246. Dave:
# Look who grew a pair!
#
# 247. Scott Lang:
# Calm down, alright? I just need to know where it came from, it's gotta be airtight.
#
# => 248. Luis:
# => Okay. I was at a wine tasting with my cousin Ernesto, which was mainly reds, and you know I don't love reds man, you know? But there was a rosé that saved the day, it was delightful. And he tells me about this girl Emily that we used to kick it with, it was actually the first pair of boobs that I ever touched.
#
# 249. Scott Lang:
# It's the wrong details. It's wrong… It has nothing to do with the story. Go!
#
# 250. Scott Lang:
# What?
#
# ******** test model 1: line 248 ********
# 1 relations identified
# entities: Luis => , Ernesto, man, Emily, pair
# relation: Okay. I was at a wine tasting with my cousin Ernesto, which was mainly reds, and you know I don't love reds man, you know? But there was a rosé that saved the day, it was delightful. And he tells me about this girl Emily that we used to kick it with, it was actually the first pair of boobs that I ever touched.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 248 ********
# 246. Dave:
# Look who grew a pair!
#
# 247. Scott Lang:
# Calm down, alright? I just need to know where it came from, it's gotta be airtight.
#
# => 248. Luis:
# => Okay. I was at a wine tasting with my cousin Ernesto, which was mainly reds, and you know I don't love reds man, you know? But there was a rosé that saved the day, it was delightful. And he tells me about this girl Emily that we used to kick it with, it was actually the first pair of boobs that I ever touched.
#
# 249. Scott Lang:
# It's the wrong details. It's wrong… It has nothing to do with the story. Go!
#
# 250. Scott Lang:
# What?
#
# ******** test model 2: line 248 ********
# 1 relations identified
# entities: Luis => , Ernesto, man, Emily, pair
# relation: Okay. I was at a wine tasting with my cousin Ernesto, which was mainly reds, and you know I don't love reds man, you know? But there was a rosé that saved the day, it was delightful. And he tells me about this girl Emily that we used to kick it with, it was actually the first pair of boobs that I ever touched.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 145 ********
# 143. Hope van Dyne:
# After you.
#
# 144. narrator:
# Pym enters the lab
#
# => 145. Darren Cross:
# => Now before we start I'd like to introduce a very special guest, this company's founder and my mentor, Dr. Hank Pym. [everyone in the lab claps, at the same time Pym notices the miniature building of Pym Technologies has now got the logo Cross Technologies on it] When I took over this company for Dr. Pym, I immediately started researching a particle that could change the distance between atoms while increasing density and strength. Why this revolutionary idea remained buried beneath the dust and cobwebs of Hank's research, I couldn't tell you. But just imagine. A soldier the size of an insect. The ultimate secret weapon. [he shows everyone footage reel of soldiers getting killed but with a tiny costumed figure also every footage] An “Ant-Man”. [pointing to Pym] That's what they called you. Right, Hank? Silly, I know. Propaganda. Tales to astonish. Trumped up B.S. to scare the U.S.S.R. Hank, will you tell our guests what you told me every single time I asked you, was the Ant-Man real?
#
# 146. Dr. Hank Pym:
# Just a tall tale.
#
# 147. Frank:
# So it's a suit.
#
# ******** test model 1: line 145 ********
# 2 relations identified
# entities: Darren Cross => , Hank Pym., guest, founder, everyone, mentor, soldier, soldiers, guests, Ant-Man
# relation: Now before we start I'd like to introduce a very special guest, this company's founder and my mentor, Dr. Hank Pym. [everyone in the lab claps, at the same time Pym notices the miniature building of Pym Technologies has now got the logo Cross Technologies on it] When I took over this company for Dr. Pym, I immediately started researching a particle that could change the distance between atoms while increasing density and strength. Why this revolutionary idea remained buried beneath the dust and cobwebs of Hank's research, I couldn't tell you. But just imagine. A soldier the size of an insect. The ultimate secret weapon. [he shows everyone footage reel of soldiers getting killed but with a tiny costumed figure also every footage] An “Ant-Man”. [pointing to Pym] That's what they called you. Right, Hank? Silly, I know. Propaganda. Tales to astonish. Trumped up B.S. to scare the U.S.S.R. Hank, will you tell our guests what you told me every single time I asked you, was the Ant-Man real?
# category: 3
# entities: Pym => building
# relation:  notices the miniature
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 145 ********
# 143. Hope van Dyne:
# After you.
#
# 144. narrator:
# Pym enters the lab
#
# => 145. Darren Cross:
# => Now before we start I'd like to introduce a very special guest, this company's founder and my mentor, Dr. Hank Pym. [everyone in the lab claps, at the same time Pym notices the miniature building of Pym Technologies has now got the logo Cross Technologies on it] When I took over this company for Dr. Pym, I immediately started researching a particle that could change the distance between atoms while increasing density and strength. Why this revolutionary idea remained buried beneath the dust and cobwebs of Hank's research, I couldn't tell you. But just imagine. A soldier the size of an insect. The ultimate secret weapon. [he shows everyone footage reel of soldiers getting killed but with a tiny costumed figure also every footage] An “Ant-Man”. [pointing to Pym] That's what they called you. Right, Hank? Silly, I know. Propaganda. Tales to astonish. Trumped up B.S. to scare the U.S.S.R. Hank, will you tell our guests what you told me every single time I asked you, was the Ant-Man real?
#
# 146. Dr. Hank Pym:
# Just a tall tale.
#
# 147. Frank:
# So it's a suit.
#
# ******** test model 2: line 145 ********
# 2 relations identified
# entities: Darren Cross => , Hank Pym., guest, founder, everyone, mentor, soldier, soldiers, guests, Ant-Man
# relation: Now before we start I'd like to introduce a very special guest, this company's founder and my mentor, Dr. Hank Pym. [everyone in the lab claps, at the same time Pym notices the miniature building of Pym Technologies has now got the logo Cross Technologies on it] When I took over this company for Dr. Pym, I immediately started researching a particle that could change the distance between atoms while increasing density and strength. Why this revolutionary idea remained buried beneath the dust and cobwebs of Hank's research, I couldn't tell you. But just imagine. A soldier the size of an insect. The ultimate secret weapon. [he shows everyone footage reel of soldiers getting killed but with a tiny costumed figure also every footage] An “Ant-Man”. [pointing to Pym] That's what they called you. Right, Hank? Silly, I know. Propaganda. Tales to astonish. Trumped up B.S. to scare the U.S.S.R. Hank, will you tell our guests what you told me every single time I asked you, was the Ant-Man real?
# category: 3
# entities: Pym => building
# relation:  notices the miniature
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 479 ********
# 477. Paxton:
# Yeah, I am, sweetheart. I just want your daddy to be safe.
#
# 478. Cassie Lang:
# Hope you don't catch him. [Pym is showing Scott photos of the people he used to worked with]
#
# => 479. Dr. Hank Pym:
# => This isn't the first time these guys have tried to get their hands on game changing weaponry. That's Mitchell Carson, ex-head of defense at SHIELD, presently in the business of toppling governments. He always wanted my tech, and now, unless we break in and steal the Yellowjacket and destroy all the data, Darren Cross is gonna unleash chaos upon the world.
#
# 480. Scott Lang:
# I think our first move should be calling the Avengers.
#
# 481. Dr. Hank Pym:
# I've spent half my life trying to keep this technology out of the hands of a Stark. I'm sure as hell not gonna hand-deliver it to one now. This is not some cute technology like the Iron Man suit. This could change the texture of reality. Besides they're probably too busy dropping cities out of the sky.
#
# ******** test model 1: line 479 ********
# 1 relations identified
# entities: Dr. Hank Pym => , guys, Mitchell Carson, Darren Cross
# relation: This isn't the first time these guys have tried to get their hands on game changing weaponry. That's Mitchell Carson, ex-head of defense at SHIELD, presently in the business of toppling governments. He always wanted my tech, and now, unless we break in and steal the Yellowjacket and destroy all the data, Darren Cross is gonna unleash chaos upon the world.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 479 ********
# 477. Paxton:
# Yeah, I am, sweetheart. I just want your daddy to be safe.
#
# 478. Cassie Lang:
# Hope you don't catch him. [Pym is showing Scott photos of the people he used to worked with]
#
# => 479. Dr. Hank Pym:
# => This isn't the first time these guys have tried to get their hands on game changing weaponry. That's Mitchell Carson, ex-head of defense at SHIELD, presently in the business of toppling governments. He always wanted my tech, and now, unless we break in and steal the Yellowjacket and destroy all the data, Darren Cross is gonna unleash chaos upon the world.
#
# 480. Scott Lang:
# I think our first move should be calling the Avengers.
#
# 481. Dr. Hank Pym:
# I've spent half my life trying to keep this technology out of the hands of a Stark. I'm sure as hell not gonna hand-deliver it to one now. This is not some cute technology like the Iron Man suit. This could change the texture of reality. Besides they're probably too busy dropping cities out of the sky.
#
# ******** test model 2: line 479 ********
# 1 relations identified
# entities: Dr. Hank Pym => , guys, Mitchell Carson, Darren Cross
# relation: This isn't the first time these guys have tried to get their hands on game changing weaponry. That's Mitchell Carson, ex-head of defense at SHIELD, presently in the business of toppling governments. He always wanted my tech, and now, unless we break in and steal the Yellowjacket and destroy all the data, Darren Cross is gonna unleash chaos upon the world.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 766 ********
# 764. Kurt:
# Oh, no.
#
# 765. narrator:
# back with Scott and the ants
#
# => 766. Scott Lang:
# => I'm employing the bullet ants. Hapanera-clamda-mana-merna. I don't remember what it's called but I feel bad for this guy. [using the ants Scott takes down one of the security guards with Luis also punching him]
#
# 767. Luis:
# See, that's what I'm talkin’ bout. That's what I call it, an unfortunate casualty, in a very serious operation, you know? [Hope then comes along and enters the room and places the signal decoy]
#
# 768. Kurt:
# Signal decoy in place. Mean pretty lady did good, Scott.
#
# ******** test model 1: line 766 ********
# 1 relations identified
# entities: Scott Lang => , Hapanera, security guards, Luis
# relation: I'm employing the bullet ants. Hapanera-clamda-mana-merna. I don't remember what it's called but I feel bad for this guy. [using the ants Scott takes down one of the security guards with Luis also punching him]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 766 ********
# 764. Kurt:
# Oh, no.
#
# 765. narrator:
# back with Scott and the ants
#
# => 766. Scott Lang:
# => I'm employing the bullet ants. Hapanera-clamda-mana-merna. I don't remember what it's called but I feel bad for this guy. [using the ants Scott takes down one of the security guards with Luis also punching him]
#
# 767. Luis:
# See, that's what I'm talkin’ bout. That's what I call it, an unfortunate casualty, in a very serious operation, you know? [Hope then comes along and enters the room and places the signal decoy]
#
# 768. Kurt:
# Signal decoy in place. Mean pretty lady did good, Scott.
#
# ******** test model 2: line 766 ********
# 1 relations identified
# entities: Scott Lang => , Hapanera, security guards, Luis
# relation: I'm employing the bullet ants. Hapanera-clamda-mana-merna. I don't remember what it's called but I feel bad for this guy. [using the ants Scott takes down one of the security guards with Luis also punching him]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 944 ********
# 942. Cassie Lang:
# [voice] Daddy! Where are you? Daddy!
#
# 943. Scott Lang:
# Cassie.
#
# => 944. Cassie Lang:
# => [voice] Come on, daddy. [Scott remembers the discs Pym had given him and takes one out]
#
# 945. Dr. Hank Pym:
# [voice] Do not mess with the regulator. [Scott places the disc in the regulator, presses the button and finally returns to normal size] I love you so much.
#
# 946. Scott Lang:
# I love you too, so much.
#
# ******** test model 1: line 944 ********
# 1 relations identified
# entities: Cassie Lang => , Scott, daddy, Pym
# relation: [voice] Come on, daddy. [Scott remembers the discs Pym had given him and takes one out]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 944 ********
# 942. Cassie Lang:
# [voice] Daddy! Where are you? Daddy!
#
# 943. Scott Lang:
# Cassie.
#
# => 944. Cassie Lang:
# => [voice] Come on, daddy. [Scott remembers the discs Pym had given him and takes one out]
#
# 945. Dr. Hank Pym:
# [voice] Do not mess with the regulator. [Scott places the disc in the regulator, presses the button and finally returns to normal size] I love you so much.
#
# 946. Scott Lang:
# I love you too, so much.
#
# ******** test model 2: line 944 ********
# 1 relations identified
# entities: Cassie Lang => , Scott, daddy, Pym
# relation: [voice] Come on, daddy. [Scott remembers the discs Pym had given him and takes one out]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 502 ********
# 500. Hope van Dyne:
# [to Pym] Useless.
#
# 501. narrator:
# Hope trains Scott
#
# => 502. Hope van Dyne:
# => When you're small energy is compressed so you have the force of a two hundred pound man behind a fist a hundredth of an inch wide, you're like a bullet. You punch too hard, you kill someone, too soft, it's a love-tap. In other words you have to know how to punch.
#
# 503. Scott Lang:
# I was in prison for three years, I know how to punch.
#
# 504. Hope van Dyne:
# Show me. [she puts up her hands and Scott hits her hand] Terrible.
#
# ******** test model 1: line 502 ********
# 1 relations identified
# entities: Hope van Dyne => , man, hundredth, someone
# relation: When you're small energy is compressed so you have the force of a two hundred pound man behind a fist a hundredth of an inch wide, you're like a bullet. You punch too hard, you kill someone, too soft, it's a love-tap. In other words you have to know how to punch.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 502 ********
# 500. Hope van Dyne:
# [to Pym] Useless.
#
# 501. narrator:
# Hope trains Scott
#
# => 502. Hope van Dyne:
# => When you're small energy is compressed so you have the force of a two hundred pound man behind a fist a hundredth of an inch wide, you're like a bullet. You punch too hard, you kill someone, too soft, it's a love-tap. In other words you have to know how to punch.
#
# 503. Scott Lang:
# I was in prison for three years, I know how to punch.
#
# 504. Hope van Dyne:
# Show me. [she puts up her hands and Scott hits her hand] Terrible.
#
# ******** test model 2: line 502 ********
# 1 relations identified
# entities: Hope van Dyne => , man, hundredth, someone
# relation: When you're small energy is compressed so you have the force of a two hundred pound man behind a fist a hundredth of an inch wide, you're like a bullet. You punch too hard, you kill someone, too soft, it's a love-tap. In other words you have to know how to punch.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 931 ********
# 929. Scott Lang:
# I can't break through!
#
# 930. Darren Cross:
# It's titanium, you idiot!
#
# => 931. Scott Lang:
# => [to Paxton as Scott and Paxton continue fighting] Get her out of here! [Paxton carries Cassie off]
#
# 932. Paxton:
# Come on.
#
# 933. Darren Cross:
# [as Paxton goes to leave the room with Cassie in his arms Cross stops them] Sorry, sweetheart. You have to help daddy pay for his mistakes.
#
# ******** test model 1: line 931 ********
# 1 relations identified
# entities: Scott Lang => , Paxton, Paxton, Cassie
# relation: [to Paxton as Scott and Paxton continue fighting] Get her out of here! [Paxton carries Cassie off]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 931 ********
# 929. Scott Lang:
# I can't break through!
#
# 930. Darren Cross:
# It's titanium, you idiot!
#
# => 931. Scott Lang:
# => [to Paxton as Scott and Paxton continue fighting] Get her out of here! [Paxton carries Cassie off]
#
# 932. Paxton:
# Come on.
#
# 933. Darren Cross:
# [as Paxton goes to leave the room with Cassie in his arms Cross stops them] Sorry, sweetheart. You have to help daddy pay for his mistakes.
#
# ******** test model 2: line 931 ********
# 1 relations identified
# entities: Scott Lang => , Paxton, Paxton, Cassie
# relation: [to Paxton as Scott and Paxton continue fighting] Get her out of here! [Paxton carries Cassie off]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 574 ********
# 572. Hope van Dyne:
# You know, I didn't know you had a… a daughter when I called the cops on you. What's her name?
#
# 573. Scott Lang:
# Cassie.
#
# => 574. Hope van Dyne:
# => It's a pretty name. You have to clear your mind, Scott. You have to make your thoughts precise, that's how it works. Think about Cassie, about how badly you want to see her, and use that to focus. [she gives Scott the earpiece back to talk to the ants and places a coin on the dashboard] Open your eyes and just think about what you want the ants to do. [couple of ants arrive and Scott gets them to pick up the coin] That's good. [they watch as Scott gets the ants to spin the coin]
#
# 575. narrator:
# Hope and Scott enter back into the house where Pym is waiting
#
# 576. Dr. Hank Pym:
# Your mother convinced me to let her join me on my missions. They called her the Wasp. She was born to it. And there's not a day that goes by that I don't regret having said yes. It was 1987, separatists had hijacked a Soviet missile silo in Kursk and launched an ICBM at the United States. The only way to the internal mechanics was through solid titanium.
#
# ******** test model 1: line 574 ********
# 1 relations identified
# entities: Hope van Dyne => , Scott, Cassie, couple
# relation: It's a pretty name. You have to clear your mind, Scott. You have to make your thoughts precise, that's how it works. Think about Cassie, about how badly you want to see her, and use that to focus. [she gives Scott the earpiece back to talk to the ants and places a coin on the dashboard] Open your eyes and just think about what you want the ants to do. [couple of ants arrive and Scott gets them to pick up the coin] That's good. [they watch as Scott gets the ants to spin the coin]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 574 ********
# 572. Hope van Dyne:
# You know, I didn't know you had a… a daughter when I called the cops on you. What's her name?
#
# 573. Scott Lang:
# Cassie.
#
# => 574. Hope van Dyne:
# => It's a pretty name. You have to clear your mind, Scott. You have to make your thoughts precise, that's how it works. Think about Cassie, about how badly you want to see her, and use that to focus. [she gives Scott the earpiece back to talk to the ants and places a coin on the dashboard] Open your eyes and just think about what you want the ants to do. [couple of ants arrive and Scott gets them to pick up the coin] That's good. [they watch as Scott gets the ants to spin the coin]
#
# 575. narrator:
# Hope and Scott enter back into the house where Pym is waiting
#
# 576. Dr. Hank Pym:
# Your mother convinced me to let her join me on my missions. They called her the Wasp. She was born to it. And there's not a day that goes by that I don't regret having said yes. It was 1987, separatists had hijacked a Soviet missile silo in Kursk and launched an ICBM at the United States. The only way to the internal mechanics was through solid titanium.
#
# ******** test model 2: line 574 ********
# 1 relations identified
# entities: Hope van Dyne => , Scott, Cassie, couple
# relation: It's a pretty name. You have to clear your mind, Scott. You have to make your thoughts precise, that's how it works. Think about Cassie, about how badly you want to see her, and use that to focus. [she gives Scott the earpiece back to talk to the ants and places a coin on the dashboard] Open your eyes and just think about what you want the ants to do. [couple of ants arrive and Scott gets them to pick up the coin] That's good. [they watch as Scott gets the ants to spin the coin]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 527 ********
# 525. Scott Lang:
# Oh, you're not so crazy. [the crazy ant jumps on him, knocking Scott back] Hey! You're cute. [suddenly a herd of crazy ants crawl all over Scott] Oh! Aaah! [Scott turns himself back to normal size and he pops up through the ground] That was a lot scarier a second ago.
#
# 526. narrator:
# as they look at Pym Technologies building map
#
# => 527. Scott Lang:
# => It looks like the Futures lab has its own isolated power supply.
#
# 528. Hope van Dyne:
# There's a security guard posted around the clock, we'll need you to take him out to deactivate the security systems.
#
# 529. narrator:
# shrunk again and back under the earth, Scott goes looking for more ants
#
# ******** test model 1: line 527 ********
# 1 relations identified
# entities: lab => supply
# relation:  has its own isolated power
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 527 ********
# 525. Scott Lang:
# Oh, you're not so crazy. [the crazy ant jumps on him, knocking Scott back] Hey! You're cute. [suddenly a herd of crazy ants crawl all over Scott] Oh! Aaah! [Scott turns himself back to normal size and he pops up through the ground] That was a lot scarier a second ago.
#
# 526. narrator:
# as they look at Pym Technologies building map
#
# => 527. Scott Lang:
# => It looks like the Futures lab has its own isolated power supply.
#
# 528. Hope van Dyne:
# There's a security guard posted around the clock, we'll need you to take him out to deactivate the security systems.
#
# 529. narrator:
# shrunk again and back under the earth, Scott goes looking for more ants
#
# ******** test model 2: line 527 ********
# 1 relations identified
# entities: lab => supply
# relation:  has its own isolated power
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 234 ********
# 232. Darren Cross:
# Gratitude can be forgiveness. I spent years carrying around my anger for Hank Pym. I devoted my genius to him. I could've worked anywhere. I chose my mentor poorly. You didn't even have a choice. He never believed in you. It's a shame what we had to do, but he forced us to do it, didn't he? But we shouldn't be angry, we should be grateful. Because his failures as a mentor, as a father, forced us to spread our wings.
#
# 233. Hope van Dyne:
# You're a success, Darren. You deserve everything coming your way.
#
# => 234. narrator:
# => after sitting outside in the van trying to figure how many days he's got left to see Cassie again, Scott returns to Luis's apartment
#
# 235. Luis:
# Hey, what's up, hotshot?
#
# 236. narrator:
# Scott doesn't reply
#
# ******** test model 1: line 234 ********
# 1 relations identified
# entities: narrator => , Scott, Luis, Cassie
# relation: after sitting outside in the van trying to figure how many days he's got left to see Cassie again, Scott returns to Luis's apartment
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 234 ********
# 232. Darren Cross:
# Gratitude can be forgiveness. I spent years carrying around my anger for Hank Pym. I devoted my genius to him. I could've worked anywhere. I chose my mentor poorly. You didn't even have a choice. He never believed in you. It's a shame what we had to do, but he forced us to do it, didn't he? But we shouldn't be angry, we should be grateful. Because his failures as a mentor, as a father, forced us to spread our wings.
#
# 233. Hope van Dyne:
# You're a success, Darren. You deserve everything coming your way.
#
# => 234. narrator:
# => after sitting outside in the van trying to figure how many days he's got left to see Cassie again, Scott returns to Luis's apartment
#
# 235. Luis:
# Hey, what's up, hotshot?
#
# 236. narrator:
# Scott doesn't reply
#
# ******** test model 2: line 234 ********
# 1 relations identified
# entities: narrator => , Scott, Luis, Cassie
# relation: after sitting outside in the van trying to figure how many days he's got left to see Cassie again, Scott returns to Luis's apartment
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 958 ********
# 956. Dr. Hank Pym:
# There must be something else. Well I suppose the human mind just can't comprehend the experience, but you made it. You went in and you got out, that's amazing.
#
# 957. Hope van Dyne:
# Scott, I'll walk you out.
#
# => 958. Scott Lang:
# => [to Pym] Get some rest. [Scott and Hope leave the room, Pym looks over to the photo of himself with his wife holding Hope when she was a baby]
#
# 959. Dr. Hank Pym:
# Is it possible? [Pym gets up to leave his room, as he opens the door he finds Hope and Scott kissing] When did this happen?
#
# 960. Hope van Dyne:
# Nothing's happening.
#
# ******** test model 1: line 958 ********
# 2 relations identified
# entities: Scott Lang => , Pym, wife, Hope
# relation: [to Pym] Get some rest. [Scott and Hope leave the room, Pym looks over to the photo of himself with his wife holding Hope when she was a baby]
# category: 3
# entities: Scott => room
# relation:  leave the
# category: 5
#
# how many are correctly identified? 2
#
# ******** line 958 ********
# 956. Dr. Hank Pym:
# There must be something else. Well I suppose the human mind just can't comprehend the experience, but you made it. You went in and you got out, that's amazing.
#
# 957. Hope van Dyne:
# Scott, I'll walk you out.
#
# => 958. Scott Lang:
# => [to Pym] Get some rest. [Scott and Hope leave the room, Pym looks over to the photo of himself with his wife holding Hope when she was a baby]
#
# 959. Dr. Hank Pym:
# Is it possible? [Pym gets up to leave his room, as he opens the door he finds Hope and Scott kissing] When did this happen?
#
# 960. Hope van Dyne:
# Nothing's happening.
#
# ******** test model 2: line 958 ********
# 2 relations identified
# entities: Scott Lang => , Pym, wife, Hope
# relation: [to Pym] Get some rest. [Scott and Hope leave the room, Pym looks over to the photo of himself with his wife holding Hope when she was a baby]
# category: 3
# entities: Scott => room
# relation:  leave the
# category: 5
#
# how many are correctly identified? 2
#
# ******** line 688 ********
# 686. Scott Lang:
# So we expand our team. What do we need? A fake security guard on the inside to depressurize the water system, somebody else to hack into the power supply and kill the laser grid, and a getaway guy.
#
# 687. Dr. Hank Pym:
# No, no. No, no, no. Not those three wombats. No way.
#
# => 688. narrator:
# => Hope provides three cups of coffee for Luis, Dave and Kurt
#
# 689. Luis:
# Thank you for the coffee ma'am. It's not too often that you rob a place, and then get welcomed back. Because we just robbed you!
#
# 690. Hope van Dyne:
# [to Scott] You know that he was arrested for stealing a smoothie machine, right?
#
# ******** test model 1: line 688 ********
# 1 relations identified
# entities: narrator => , Luis, Kurt, Dave
# relation: Hope provides three cups of coffee for Luis, Dave and Kurt
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 688 ********
# 686. Scott Lang:
# So we expand our team. What do we need? A fake security guard on the inside to depressurize the water system, somebody else to hack into the power supply and kill the laser grid, and a getaway guy.
#
# 687. Dr. Hank Pym:
# No, no. No, no, no. Not those three wombats. No way.
#
# => 688. narrator:
# => Hope provides three cups of coffee for Luis, Dave and Kurt
#
# 689. Luis:
# Thank you for the coffee ma'am. It's not too often that you rob a place, and then get welcomed back. Because we just robbed you!
#
# 690. Hope van Dyne:
# [to Scott] You know that he was arrested for stealing a smoothie machine, right?
#
# ******** test model 2: line 688 ********
# 1 relations identified
# entities: narrator => , Luis, Kurt, Dave
# relation: Hope provides three cups of coffee for Luis, Dave and Kurt
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 722 ********
# 720. Luis:
# Ahh! Ahh! Get off! Get off! Ahh! [Luis runs off trying to get Scott off his shoulder]
#
# 721. Scott Lang:
# I thought daddy didn't get scared?
#
# => 722. narrator:
# => Luis, Dave and Kurt have all fallen asleep on the couch
#
# 723. Hope van Dyne:
# I gave them each half a Xanax and Hank explained the science of the suit to them. Fell right asleep.
#
# 724. Scott Lang:
# Hey, look. I want to thank you for…
#
# ******** test model 1: line 722 ********
# 1 relations identified
# entities: narrator => , Luis, Dave, Kurt
# relation: Luis, Dave and Kurt have all fallen asleep on the couch
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 722 ********
# 720. Luis:
# Ahh! Ahh! Get off! Get off! Ahh! [Luis runs off trying to get Scott off his shoulder]
#
# 721. Scott Lang:
# I thought daddy didn't get scared?
#
# => 722. narrator:
# => Luis, Dave and Kurt have all fallen asleep on the couch
#
# 723. Hope van Dyne:
# I gave them each half a Xanax and Hank explained the science of the suit to them. Fell right asleep.
#
# 724. Scott Lang:
# Hey, look. I want to thank you for…
#
# ******** test model 2: line 722 ********
# 1 relations identified
# entities: narrator => , Luis, Dave, Kurt
# relation: Luis, Dave and Kurt have all fallen asleep on the couch
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 31 ********
# 29. Scott Lang:
# I mean, what if I come in on the left side, right? Just out here and see this here… [suddenly Scott punches Peachy in the face]
#
# 30. Peachy:
# I'm gonna miss you, Scott.
#
# => 31. Scott Lang:
# => I'm gonna miss you too, Peachy. [they shake hands] Man, you guys got the weirdest goodbye rituals. [Scott says goodbye to the other inmates]
#
# 32. narrator:
# Scott is escorted out of the prison and is met by his friend Luis
#
# 33. Luis:
# Scotty! What's up, man! Damn!
#
# ******** test model 1: line 31 ********
# 1 relations identified
# entities: Scott Lang => , Man, guys, inmates
# relation: I'm gonna miss you too, Peachy. [they shake hands] Man, you guys got the weirdest goodbye rituals. [Scott says goodbye to the other inmates]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 31 ********
# 29. Scott Lang:
# I mean, what if I come in on the left side, right? Just out here and see this here… [suddenly Scott punches Peachy in the face]
#
# 30. Peachy:
# I'm gonna miss you, Scott.
#
# => 31. Scott Lang:
# => I'm gonna miss you too, Peachy. [they shake hands] Man, you guys got the weirdest goodbye rituals. [Scott says goodbye to the other inmates]
#
# 32. narrator:
# Scott is escorted out of the prison and is met by his friend Luis
#
# 33. Luis:
# Scotty! What's up, man! Damn!
#
# ******** test model 2: line 31 ********
# 1 relations identified
# entities: Scott Lang => , Man, guys, inmates
# relation: I'm gonna miss you too, Peachy. [they shake hands] Man, you guys got the weirdest goodbye rituals. [Scott says goodbye to the other inmates]
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 886 ********
# 884. Gale:
# Police! Put your hands up!
#
# 885. Paxton:
# Get ’em up! [Scott pulls up his helmet] Scott?
#
# => 886. Scott Lang:
# => Paxton, you have to listen to me- [as Scott goes to walk towards Paxton they taser him and falls down unconscious]
#
# 887. narrator:
# as Paxton and Gale are driving Scott back to the police station Scott wakes up Paxton, turn around, take me back.
#
# 888. Paxton:
# I'm taking you back, to prison.
#
# ******** test model 1: line 886 ********
# 1 relations identified
# entities: Paxton => ['Computer']
# relation:  taser
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 886 ********
# 884. Gale:
# Police! Put your hands up!
#
# 885. Paxton:
# Get ’em up! [Scott pulls up his helmet] Scott?
#
# => 886. Scott Lang:
# => Paxton, you have to listen to me- [as Scott goes to walk towards Paxton they taser him and falls down unconscious]
#
# 887. narrator:
# as Paxton and Gale are driving Scott back to the police station Scott wakes up Paxton, turn around, take me back.
#
# 888. Paxton:
# I'm taking you back, to prison.
#
# ******** test model 2: line 886 ********
# 1 relations identified
# entities: Paxton => ['Computer']
# relation:  taser
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 819 ********
# 817. Paxton:
# Get out.
#
# 818. Dave:
# Take it easy!
#
# => 819. Kurt:
# => [Paxton pulls Kurt out of the van at the same time the laser grid is disabled; to Scott] Go! Go now! [Scott jumps to get to the Yellowjacket] Wait!
#
# 820. Scott Lang:
# What? What do you mean wait? [Kurt manages to struggle free from Paxton's hold to press a button on his computer to fully disable the lasers and just as Scott goes to grab the suit it's pulled away] What? What? [Cross sees Scott and taps on the glass]
#
# 821. Darren Cross:
# Hi, little guy. [to Pym] I always suspected you had a suit stored away somewhere, which begs the question, who is the new Ant-Man? Who is the man that my beloved mentor trusted even more than me? [pauses a moment] Scott Lang. The martyr, who took on the system and paid the price, losing his family and his only daughter in the process. Exactly your kind of guy, Hank. He escapes his jail cell without leaving any clue as to how, and then, he disappears magically, despite having no money to his name, and now he brings me the Ant-Man suit, the only thing that can rival my creation.
#
# ******** test model 1: line 819 ********
# 1 relations identified
# entities: Kurt => , Paxton, Scott, Yellowjacket
# relation: [Paxton pulls Kurt out of the van at the same time the laser grid is disabled; to Scott] Go! Go now! [Scott jumps to get to the Yellowjacket] Wait!
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 819 ********
# 817. Paxton:
# Get out.
#
# 818. Dave:
# Take it easy!
#
# => 819. Kurt:
# => [Paxton pulls Kurt out of the van at the same time the laser grid is disabled; to Scott] Go! Go now! [Scott jumps to get to the Yellowjacket] Wait!
#
# 820. Scott Lang:
# What? What do you mean wait? [Kurt manages to struggle free from Paxton's hold to press a button on his computer to fully disable the lasers and just as Scott goes to grab the suit it's pulled away] What? What? [Cross sees Scott and taps on the glass]
#
# 821. Darren Cross:
# Hi, little guy. [to Pym] I always suspected you had a suit stored away somewhere, which begs the question, who is the new Ant-Man? Who is the man that my beloved mentor trusted even more than me? [pauses a moment] Scott Lang. The martyr, who took on the system and paid the price, losing his family and his only daughter in the process. Exactly your kind of guy, Hank. He escapes his jail cell without leaving any clue as to how, and then, he disappears magically, despite having no money to his name, and now he brings me the Ant-Man suit, the only thing that can rival my creation.
#
# ******** test model 2: line 819 ********
# 1 relations identified
# entities: Kurt => , Paxton, Scott, Yellowjacket
# relation: [Paxton pulls Kurt out of the van at the same time the laser grid is disabled; to Scott] Go! Go now! [Scott jumps to get to the Yellowjacket] Wait!
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 110 ********
# 108. Dave:
# You mean you're a pussy?
#
# 109. Scott Lang:
# Yeah.
#
# => 110. Luis:
# => They were overcharging the customers, right? And it added up to millions. He blows the whistle and he gets fired. And what does he do? He hacks into the security system, and transfers millions back to the people that they stole it from.
#
# 111. Dave:
# Posts all the bank records online.
#
# 112. Luis:
# And he drove dude's Bentley into a swimming pool.
#
# ******** test model 1: line 110 ********
# 1 relations identified
# entities: Luis => , customers, people, millions
# relation: They were overcharging the customers, right? And it added up to millions. He blows the whistle and he gets fired. And what does he do? He hacks into the security system, and transfers millions back to the people that they stole it from.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 110 ********
# 108. Dave:
# You mean you're a pussy?
#
# 109. Scott Lang:
# Yeah.
#
# => 110. Luis:
# => They were overcharging the customers, right? And it added up to millions. He blows the whistle and he gets fired. And what does he do? He hacks into the security system, and transfers millions back to the people that they stole it from.
#
# 111. Dave:
# Posts all the bank records online.
#
# 112. Luis:
# And he drove dude's Bentley into a swimming pool.
#
# ******** test model 2: line 110 ********
# 1 relations identified
# entities: Luis => , customers, people, millions
# relation: They were overcharging the customers, right? And it added up to millions. He blows the whistle and he gets fired. And what does he do? He hacks into the security system, and transfers millions back to the people that they stole it from.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 815 ********
# 813. Scott Lang:
# Ready to jump. Do you read, Kurt?
#
# 814. Kurt:
# It's so close.
#
# => 815. Paxton:
# => [suddenly the van door opens, Paxton and Gale point their guns at Kurt and Dave] Freeze!
#
# 816. Dave:
# Okay, wait a minute, wait a minute! there was a black guy that looked exactly like me who attacked us and put us in the back of this disgusting van.
#
# 817. Paxton:
# Get out.
#
# ******** test model 1: line 815 ********
# 1 relations identified
# entities: Paxton => , Gale, Dave, Kurt
# relation: [suddenly the van door opens, Paxton and Gale point their guns at Kurt and Dave] Freeze!
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 815 ********
# 813. Scott Lang:
# Ready to jump. Do you read, Kurt?
#
# 814. Kurt:
# It's so close.
#
# => 815. Paxton:
# => [suddenly the van door opens, Paxton and Gale point their guns at Kurt and Dave] Freeze!
#
# 816. Dave:
# Okay, wait a minute, wait a minute! there was a black guy that looked exactly like me who attacked us and put us in the back of this disgusting van.
#
# 817. Paxton:
# Get out.
#
# ******** test model 2: line 815 ********
# 1 relations identified
# entities: Paxton => , Gale, Dave, Kurt
# relation: [suddenly the van door opens, Paxton and Gale point their guns at Kurt and Dave] Freeze!
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 995 ********
# 993. Luis:
# Just the facts, only the facts.
#
# 994. Scott Lang:
# Breathe, focus, keep it simple.
#
# => 995. Luis:
# => No, no, no, no doubt, no doubt. Okay, so I'm at this art museum with my cousin Ignacio, right? And there was this, like, abstract expressionism exhibit, but you know me, I'm more like a Neo-Cubist kind of guy, right? But there was this one Rothko that was sublime, bro. Oh, my God…
#
# 996. Scott Lang:
# Luis.
#
# 997. Scott Lang:
# Oh, no.
#
# ******** test model 1: line 995 ********
# 1 relations identified
# entities: Luis => , Ignacio, bro, Rothko, guy, God
# relation: No, no, no, no doubt, no doubt. Okay, so I'm at this art museum with my cousin Ignacio, right? And there was this, like, abstract expressionism exhibit, but you know me, I'm more like a Neo-Cubist kind of guy, right? But there was this one Rothko that was sublime, bro. Oh, my God…
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 995 ********
# 993. Luis:
# Just the facts, only the facts.
#
# 994. Scott Lang:
# Breathe, focus, keep it simple.
#
# => 995. Luis:
# => No, no, no, no doubt, no doubt. Okay, so I'm at this art museum with my cousin Ignacio, right? And there was this, like, abstract expressionism exhibit, but you know me, I'm more like a Neo-Cubist kind of guy, right? But there was this one Rothko that was sublime, bro. Oh, my God…
#
# 996. Scott Lang:
# Luis.
#
# 997. Scott Lang:
# Oh, no.
#
# ******** test model 2: line 995 ********
# 1 relations identified
# entities: Luis => , Ignacio, bro, Rothko, guy, God
# relation: No, no, no, no doubt, no doubt. Okay, so I'm at this art museum with my cousin Ignacio, right? And there was this, like, abstract expressionism exhibit, but you know me, I'm more like a Neo-Cubist kind of guy, right? But there was this one Rothko that was sublime, bro. Oh, my God…
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 903 ********
# 901. Darren Cross:
# Do I look like a monster?
#
# 902. Cassie Lang:
# I want my daddy!
#
# => 903. Darren Cross:
# => I want your daddy too. [he picks up Cassie and she screams, just then Scott shows up] There you are.
#
# 904. Cassie Lang:
# Daddy, is that you? [Scott pulls up his helmet]
#
# 905. Scott Lang:
# Hi, Peanut. [to Cross] Why don't you pick on someone your own size? [he throws a disc at Cross which shrinks him then he shrinks himself, Cross is now on the Thomas The Tank Engine toy in Cassie's room]
#
# ******** test model 1: line 903 ********
# 1 relations identified
# entities: Darren Cross => , daddy, Cassie, Scott
# relation: I want your daddy too. [he picks up Cassie and she screams, just then Scott shows up] There you are.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 903 ********
# 901. Darren Cross:
# Do I look like a monster?
#
# 902. Cassie Lang:
# I want my daddy!
#
# => 903. Darren Cross:
# => I want your daddy too. [he picks up Cassie and she screams, just then Scott shows up] There you are.
#
# 904. Cassie Lang:
# Daddy, is that you? [Scott pulls up his helmet]
#
# 905. Scott Lang:
# Hi, Peanut. [to Cross] Why don't you pick on someone your own size? [he throws a disc at Cross which shrinks him then he shrinks himself, Cross is now on the Thomas The Tank Engine toy in Cassie's room]
#
# ******** test model 2: line 903 ********
# 1 relations identified
# entities: Darren Cross => , daddy, Cassie, Scott
# relation: I want your daddy too. [he picks up Cassie and she screams, just then Scott shows up] There you are.
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 575 ********
# 573. Scott Lang:
# Cassie.
#
# 574. Hope van Dyne:
# It's a pretty name. You have to clear your mind, Scott. You have to make your thoughts precise, that's how it works. Think about Cassie, about how badly you want to see her, and use that to focus. [she gives Scott the earpiece back to talk to the ants and places a coin on the dashboard] Open your eyes and just think about what you want the ants to do. [couple of ants arrive and Scott gets them to pick up the coin] That's good. [they watch as Scott gets the ants to spin the coin]
#
# => 575. narrator:
# => Hope and Scott enter back into the house where Pym is waiting
#
# 576. Dr. Hank Pym:
# Your mother convinced me to let her join me on my missions. They called her the Wasp. She was born to it. And there's not a day that goes by that I don't regret having said yes. It was 1987, separatists had hijacked a Soviet missile silo in Kursk and launched an ICBM at the United States. The only way to the internal mechanics was through solid titanium.
#
# 577. narrator:
# in flashback we see Pym in his Ant-Man suit and his wife in her Wasp suit intercepted the missile
#
# ******** test model 1: line 575 ********
# 1 relations identified
# entities: narrator => , Hope, Scott, Pym
# relation: Hope and Scott enter back into the house where Pym is waiting
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 575 ********
# 573. Scott Lang:
# Cassie.
#
# 574. Hope van Dyne:
# ...
#
# ******** test model 2: line 487 ********
# 1 relations identified
# entities: ['Hope van Dyne'] => facility
# relation:  know the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 211 ********
# 209. Scott Lang:
# Oh, what language. I said hat.
#
# 210. narrator:
# Maggie takes Scott out of the house
#
# => 211. Scott Lang:
# => Really, Maggie? That guy? Come on, you could marry anyone you want, you have to get engaged to a cop?
#
# 212. Maggie Lang:
# At least he's not a crook.
#
# 213. Scott Lang:
# I'm trying, okay? I've changed, and I'm straight, I had a job, and… I want to provide. I had a lot of time to think about it, and I love her. So much. I've missed so much time and I want to be a part of her life. What do I do?
#
# ******** test model 1: line 211 ********
# 1 relations identified
# entities: Scott Lang => , Maggie, guy, anyone, cop
# relation: Really, Maggie? That guy? Come on, you could marry anyone you want, you have to get engaged to a cop?
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 211 ********
# 209. Scott Lang:
# Oh, what language. I said hat.
#
# 210. narrator:
# Maggie takes Scott out of the house
#
# => 211. Scott Lang:
# => Really, Maggie? That guy? Come on, you could marry anyone you want, you have to get engaged to a cop?
#
# 212. Maggie Lang:
# At least he's not a crook.
#
# 213. Scott Lang:
# I'm trying, okay? I've changed, and I'm straight, I had a job, and… I want to provide. I had a lot of time to think about it, and I love her. So much. I've missed so much time and I want to be a part of her life. What do I do?
#
# ******** test model 2: line 211 ********
# 1 relations identified
# entities: Scott Lang => , Maggie, guy, anyone, cop
# relation: Really, Maggie? That guy? Come on, you could marry anyone you want, you have to get engaged to a cop?
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 448 ********
# 446. Dr. Hank Pym:
# Scott, I've been watching you for a while, ever since you robbed Vista Corp. Oh, excuse me, burgled Vista Corp. [Scott see Hope smile to herself] Vista's security system is one of the most advanced in the business. It's supposed to be unbeatable but you beat it. Would you like some sugar?
#
# 447. Scott Lang:
# Yeah, thanks. [he sees two ants pushing two sugar cubes on the table towards his cup] You know what, I'm okay. [referring to the ants] How do you make them do that?
#
# => 448. Dr. Hank Pym:
# => Ants can lift objects fifty times their weight. They build, farm, they cooperate with each other.
#
# 449. Scott Lang:
# Right. But how do you make them do that? [he sees the ants returning the sugar cubes into their bowl]
#
# 450. Dr. Hank Pym:
# I use electromagnetic waves to stimulate their olfactory nerve center. I speak to them. I can go anywhere, hear anything, and see everything.
#
# ******** test model 1: line 448 ********
# 1 relations identified
# entities: ['Pool BBQ Dad'] => farm
# relation:  build ,
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 448 ********
# 446. Dr. Hank Pym:
# Scott, I've been watching you for a while, ever since you robbed Vista Corp. Oh, excuse me, burgled Vista Corp. [Scott see Hope smile to herself] Vista's security system is one of the most advanced in the business. It's supposed to be unbeatable but you beat it. Would you like some sugar?
#
# 447. Scott Lang:
# Yeah, thanks. [he sees two ants pushing two sugar cubes on the table towards his cup] You know what, I'm okay. [referring to the ants] How do you make them do that?
#
# => 448. Dr. Hank Pym:
# => Ants can lift objects fifty times their weight. They build, farm, they cooperate with each other.
#
# 449. Scott Lang:
# Right. But how do you make them do that? [he sees the ants returning the sugar cubes into their bowl]
#
# 450. Dr. Hank Pym:
# I use electromagnetic waves to stimulate their olfactory nerve center. I speak to them. I can go anywhere, hear anything, and see everything.
#
# ******** test model 2: line 448 ********
# 1 relations identified
# entities: ['Pool BBQ Dad'] => farm
# relation:  build ,
# category: 5
#
# how many are correctly identified? 0
#
# ******** line 848 ********
# 846. Scott Lang:
# We need to get him out of here.
#
# 847. Hope van Dyne:
# Go get that suit. [Scott takes off and tries to get away from the two guards shooting at him]
#
# => 848. narrator:
# => Scott shrinks himself into the small building model of Cross of Tech to get away from the guards shooting at him, then Luis comes to the rescue and knocks out the guards
#
# 849. Luis:
# Hey, Scotty. Hey, did I save your life? Scotty? Scotty? [Scott makes himself large again]
#
# 850. Scott Lang:
# Thank you, Luis.
#
# ******** test model 1: line 848 ********
# 1 relations identified
# entities: narrator => , Scott, guards, guards, Luis
# relation: Scott shrinks himself into the small building model of Cross of Tech to get away from the guards shooting at him, then Luis comes to the rescue and knocks out the guards
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 848 ********
# 846. Scott Lang:
# We need to get him out of here.
#
# 847. Hope van Dyne:
# Go get that suit. [Scott takes off and tries to get away from the two guards shooting at him]
#
# => 848. narrator:
# => Scott shrinks himself into the small building model of Cross of Tech to get away from the guards shooting at him, then Luis comes to the rescue and knocks out the guards
#
# 849. Luis:
# Hey, Scotty. Hey, did I save your life? Scotty? Scotty? [Scott makes himself large again]
#
# 850. Scott Lang:
# Thank you, Luis.
#
# ******** test model 2: line 848 ********
# 1 relations identified
# entities: narrator => , Scott, guards, guards, Luis
# relation: Scott shrinks himself into the small building model of Cross of Tech to get away from the guards shooting at him, then Luis comes to the rescue and knocks out the guards
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 86 ********
# 84. Dale:
# Yeah, yeah.
#
# 85. Scott Lang:
# Oh, thank you, thank you.
#
# => 86. Dale:
# => You really stuck it to those billionaire S.O.Bs. And the more I read about what you did and stuff, I'm like, “Wow, I know this guy? I'm in charge of this guy?” Yeesh!
#
# 87. Scott Lang:
# Well, I'm very happy in this job, and I'm… I really just appreciate the opportunities and…
#
# 88. Dale:
# Yeah, yeah. Well, you're fired of course. I mean, I can't really keep you on.
#
# ******** test model 1: line 86 ********
# 1 relations identified
# entities: Dale => , guy, guy, Yeesh
# relation: You really stuck it to those billionaire S.O.Bs. And the more I read about what you did and stuff, I'm like, “Wow, I know this guy? I'm in charge of this guy?” Yeesh!
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 86 ********
# 84. Dale:
# Yeah, yeah.
#
# 85. Scott Lang:
# Oh, thank you, thank you.
#
# => 86. Dale:
# => You really stuck it to those billionaire S.O.Bs. And the more I read about what you did and stuff, I'm like, “Wow, I know this guy? I'm in charge of this guy?” Yeesh!
#
# 87. Scott Lang:
# Well, I'm very happy in this job, and I'm… I really just appreciate the opportunities and…
#
# 88. Dale:
# Yeah, yeah. Well, you're fired of course. I mean, I can't really keep you on.
#
# ******** test model 2: line 86 ********
# 1 relations identified
# entities: Dale => , guy, guy, Yeesh
# relation: You really stuck it to those billionaire S.O.Bs. And the more I read about what you did and stuff, I'm like, “Wow, I know this guy? I'm in charge of this guy?” Yeesh!
# category: 3
#
# how many are correctly identified? 0
#
# ******** line 465 ********
# 463. Dr. Hank Pym:
# But before he was a big deal he was my assistant. I thought I saw something in him, a son I never had perhaps. He was brilliant, but as we became close he began to suspect that I wasn't telling him everything. He heard rumors about what was called the Pym Particles, and he became obsessed with recreating my formula. But I wouldn't help him so he conspired against me and he voted me out of my own company.
#
# 464. Scott Lang:
# How could he do that?
#
# => 465. Dr. Hank Pym:
# => The board's chairman is my daughter, Hope. She was the deciding vote. But she came back to me when she saw how close Cross was to cracking my formula. The process is highly volatile. What isn't protected by a specialized helmet can affect the brain's chemistry. I don't think Darren realizes this, and you know, he's not the most stable guy to begin with.
#
# 466. Scott Lang:
# So, what do you want from me?
#
# 467. Dr. Hank Pym:
# Scott, I believe that everyone deserves a shot at redemption. Do you?
#
# ******** test model 1: line 465 ********
# 1 relations identified
# entities: Dr. Hank Pym => , Hope, Darren, guy
# relation: The board's chairman is my daughter, Hope. She was the deciding vote. But she came back to me when she saw how close Cross was to cracking my formula. The process is highly volatile. What isn't protected by a specialized helmet can affect the brain's chemistry. I don't think Darren realizes this, and you know, he's not the most stable guy to begin with.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 465 ********
# 463. Dr. Hank Pym:
# But before he was a big deal he was my assistant. I thought I saw something in him, a son I never had perhaps. He was brilliant, but as we became close he began to suspect that I wasn't telling him everything. He heard rumors about what was called the Pym Particles, and he became obsessed with recreating my formula. But I wouldn't help him so he conspired against me and he voted me out of my own company.
#
# 464. Scott Lang:
# How could he do that?
#
# => 465. Dr. Hank Pym:
# => The board's chairman is my daughter, Hope. She was the deciding vote. But she came back to me when she saw how close Cross was to cracking my formula. The process is highly volatile. What isn't protected by a specialized helmet can affect the brain's chemistry. I don't think Darren realizes this, and you know, he's not the most stable guy to begin with.
#
# 466. Scott Lang:
# So, what do you want from me?
#
# 467. Dr. Hank Pym:
# Scott, I believe that everyone deserves a shot at redemption. Do you?
#
# ******** test model 2: line 465 ********
# 1 relations identified
# entities: Dr. Hank Pym => , Hope, Darren, guy
# relation: The board's chairman is my daughter, Hope. She was the deciding vote. But she came back to me when she saw how close Cross was to cracking my formula. The process is highly volatile. What isn't protected by a specialized helmet can affect the brain's chemistry. I don't think Darren realizes this, and you know, he's not the most stable guy to begin with.
# category: 3
#
# how many are correctly identified? 1
#
# ******** line 144 ********
# 142. narrator:
# Carson enters the lab
#
# 143. Hope van Dyne:
# After you.
#
# => 144. narrator:
# => Pym enters the lab
#
# 145. Darren Cross:
# Now before we start I'd like to introduce a very special guest, this company's founder and my mentor, Dr. Hank Pym. [everyone in the lab claps, at the same time Pym notices the miniature building of Pym Technologies has now got the logo Cross Technologies on it] When I took over this company for Dr. Pym, I immediately started researching a particle that could change the distance between atoms while increasing density and strength. Why this revolutionary idea remained buried beneath the dust and cobwebs of Hank's research, I couldn't tell you. But just imagine. A soldier the size of an insect. The ultimate secret weapon. [he shows everyone footage reel of soldiers getting killed but with a tiny costumed figure also every footage] An “Ant-Man”. [pointing to Pym] That's what they called you. Right, Hank? Silly, I know. Propaganda. Tales to astonish. Trumped up B.S. to scare the U.S.S.R. Hank, will you tell our guests what you told me every single time I asked you, was the Ant-Man real?
#
# 146. Dr. Hank Pym:
# Just a tall tale.
#
# ******** test model 1: line 144 ********
# 1 relations identified
# entities: Pym => lab
# relation:  enters the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 144 ********
# 142. narrator:
# Carson enters the lab
#
# 143. Hope van Dyne:
# After you.
#
# => 144. narrator:
# => Pym enters the lab
#
# 145. Darren Cross:
# Now before we start I'd like to introduce a very special guest, this company's founder and my mentor, Dr. Hank Pym. [everyone in the lab claps, at the same time Pym notices the miniature building of Pym Technologies has now got the logo Cross Technologies on it] When I took over this company for Dr. Pym, I immediately started researching a particle that could change the distance between atoms while increasing density and strength. Why this revolutionary idea remained buried beneath the dust and cobwebs of Hank's research, I couldn't tell you. But just imagine. A soldier the size of an insect. The ultimate secret weapon. [he shows everyone footage reel of soldiers getting killed but with a tiny costumed figure also every footage] An “Ant-Man”. [pointing to Pym] That's what they called you. Right, Hank? Silly, I know. Propaganda. Tales to astonish. Trumped up B.S. to scare the U.S.S.R. Hank, will you tell our guests what you told me every single time I asked you, was the Ant-Man real?
#
# 146. Dr. Hank Pym:
# Just a tall tale.
#
# ******** test model 2: line 144 ********
# 1 relations identified
# entities: Pym => lab
# relation:  enters the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 654 ********
# 652. Scott Lang:
# Hey, how about the fact that I fought an Avenger, and didn't die?
#
# 653. Dr. Hank Pym:
# Now let's not dwell on the past. We gotta finish our planning. [Pym turns and leaves with the signal decoy]
#
# => 654. Hope van Dyne:
# => Don't mind him. You did good. [Pym enters his living room to find Cross standing there]
#
# 655. Dr. Hank Pym:
# Darren. How the hell did you get in here? [Pym closes the door]
#
# 656. Darren Cross:
# You left the front door open, Hank. It's official. You're old. [Hope and Scott hear them from the kitchen]
#
# ******** test model 1: line 654 ********
# 1 relations identified
# entities: Pym => living room
# relation:  enters his living
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 654 ********
# 652. Scott Lang:
# Hey, how about the fact that I fought an Avenger, and didn't die?
#
# 653. Dr. Hank Pym:
# Now let's not dwell on the past. We gotta finish our planning. [Pym turns and leaves with the signal decoy]
#
# => 654. Hope van Dyne:
# => Don't mind him. You did good. [Pym enters his living room to find Cross standing there]
#
# 655. Dr. Hank Pym:
# Darren. How the hell did you get in here? [Pym closes the door]
#
# 656. Darren Cross:
# You left the front door open, Hank. It's official. You're old. [Hope and Scott hear them from the kitchen]
#
# ******** test model 2: line 654 ********
# 1 relations identified
# entities: Pym => living room
# relation:  enters his living
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 153 ********
# 151. Hope van Dyne:
# Thank you very much, everybody. I will escort you out now. Thank you.
#
# 152. Darren Cross:
# You seem a bit shocked.
#
# => 153. narrator:
# => as everyone leaves the room Pym walks over to Cross
#
# 154. Dr. Hank Pym:
# Darren, there's a reason that I buried these secrets.
#
# 155. Darren Cross:
# So you finally admit it. We could've done this together, Hank. But you ruined that. That's why you're the past and I'm the future.
#
# ******** test model 1: line 153 ********
# 1 relations identified
# entities: everyone => room
# relation:  leaves the
# category: 5
#
# how many are correctly identified? 1
#
# ******** line 153 ********
# 151. Hope van Dyne:
# Thank you very much, everybody. I will escort you out now. Thank you.
#
# 152. Darren Cross:
# You seem a bit shocked.
#
# => 153. narrator:
# => as everyone leaves the room Pym walks over to Cross
#
# 154. Dr. Hank Pym:
# Darren, there's a reason that I buried these secrets.
#
# 155. Darren Cross:
# So you finally admit it. We could've done this together, Hank. But you ruined that. That's why you're the past and I'm the future.
#
# ******** test model 2: line 153 ********
# 1 relations identified
# entities: everyone => room
# relation:  leaves the
# category: 5
#
# how many are correctly identified? 1
#
# ******** test results ********
# model 1: precision = 0.63 (33/52 correct)
# model 2: precision = 0.63 (33/52 correct)

# %% [markdown]
# ## Putting Everything Together, a [Simple Query System](#top) <a class="anchor" id="Query"></a>

# %%
def checkQuery(relationList, ent1, ent2, relationClass):
    for relation in relationList:
        if ent1 in relation['ent1'] and ent2 in relation['ent2'] and relationClass == relation['class']:
            return True
    return False

def printAnswer(row):
    print('Movie: {}, Line {}'.format(row.movie, row.lineNum))
    print(row.dialogue)
    print()

#Simple Query System

print('Select the movies of your interest:')
print('***Enter all to use all movies')
print('***Enter n, m, x, y (numbers separated by commas) for specific selections')
print('***Enter random, n for n random selections\n')

files = [x for x in os.listdir('prep_scripts') if '_gapi' in x]
for i, fileName in enumerate(files):
    print('{}. {}'.format(i+1, re.split(r'_tw_|_imsdb_', fileName)[0]))


x = input()


#random selection
try:
    if 'random' in x:
        queryFiles = np.random.choice(files, int(x.split(',')[-1]), replace=False)
    elif x != 'all':
        queryFiles = np.array(files)[[int(select) - 1 for select in x.split(',')]]
    #use all files
    else:
        queryFiles = files    
        
except:
    print('\nunexpected input, will use all movie files\n')
    queryFiles = files    

#print(queryFiles)
df_data = None
charSet = set()

for i, fileName in enumerate(queryFiles):    
    df = pd.read_csv('prep_scripts/'+fileName)[['speaker', 'dialogue', 'sentences', 'sentiment', 'entities', 'tokens']]
    df['tokens'] = df['tokens'].apply(lambda x: eval(x))
    df['sentiment'] = df['sentiment'].apply(lambda x: eval(x))
    df['total_sent'] = df['sentiment'].apply(lambda x: x['score'] * x['magnitude'])
    df['movie'] = re.split(r'_tw_|_imsdb_', fileName)[0]
    df['lineNum'] = df.index + 1
    
    cList = list(df.speaker.unique())
    cDict = dict(df.groupby('speaker').total_sent.sum())
    
    #resolve entities
    df['tokens'] = df.apply(lambda x:pronResolution_base(cList, x), axis=1)
    
    #extract relations
    df['relations'] = df.apply(lambda x:simpleRE(x), axis=1)
    
    if i == 0:
        df_data = df[df.relations.notnull()]        
        
    else:
        df_data = pd.concat((df_data, df[df.hasRelation == True]))
    
    charSet |= set(df.speaker.unique())

relationClasses = getRelations()
    
print('Type end to finish at any time')

#relationList = df_data[df_data.hasRelation == True]['relations'].values

while True:
    print('Characters: ')
    print(charSet)
    print('\nRelations:')
    for k, v in relationClasses.items():
        print('{}. {}'.format(k+1, v))
    print('What relation are you looking for?')
    ent1 = input('Entity 1:')
    if ent1 == 'end':
        break
    ent2 = input('Entity 2:')
    if ent2 == 'end':
        break
    relationClass = int(input('Relation category: '))-1
    
    qMatch = df_data.relations.apply(lambda x: checkQuery(x, ent1, ent2, relationClass))
    if sum(qMatch) == 0:
        print('nothing found\n')
    else:
        df_data[qMatch].apply(lambda x: printAnswer(x), axis=1)
# Out:
# Select the movies of your interest:
# ***Enter all to use all movies
# ***Enter n, m, x, y (numbers separated by commas) for specific selections
# ***Enter random, n for n random selections
#
# 1. ant-man
# 2. avengers_age_of_ultron
# 3. captain_america_civil_war
# 4. captain_america_the_first_avenger
# 5. captain_america_the_winter_soldier
# 6. fantastic_four
# 7. iron_man_3
# 8. lego_marvel_super_heroes
# 9. spider-man
# 10. the_amazing_spider-man_2
# 11. the_amazing_spider-man
# 12. the_avengers
# 13. the_wolverine
# 14. thor_the_dark_world
# 15. thor
# 16. x-men_apocalypse
# 17. x-men_days_of_future_past
# 18. x-men
# 19. x-men_the_last_stand
# 1
#
# unexpected input, will use all movie files
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-69c4a05af408> in <module>()
#      58
#      59     #extract relations
# ---> 60     df['relations'] = df.apply(lambda x:simpleRE(x), axis=1)
#      61
#      62     if i == 0:
#
# C:\Users\rohan_000\Anaconda2\lib\site-packages\pandas\core\frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4040                     if reduce is None:
#    4041                         reduce = True
# -> 4042                     return self._apply_standard(f, axis, reduce=reduce)
#    4043             else:
#    4044                 return self._apply_broadcast(f, axis)
#
# C:\Users\rohan_000\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4136             try:
#    4137                 for i, v in enumerate(series_gen):
# -> 4138                     results[i] = func(v)
#    4139                     keys.append(v.name)
#    4140             except Exception as e:
#
# <ipython-input-10-69c4a05af408> in <lambda>(x)
#      58
#      59     #extract relations
# ---> 60     df['relations'] = df.apply(lambda x:simpleRE(x), axis=1)
#      61
#      62     if i == 0:
#
# C:\Users\rohan_000\Documents\Berkeley\W266-1 - NLP\Final project\w266_project\relationExtract.pyc in simpleRE(rows)
#      17     nsubj = -1
#      18     verb = -1
# ---> 19     print 'rows.token: ' + rows.token
#      20     for i, token in enumerate(rows.tokens):
#      21         print 'i: ' + i
#
# C:\Users\rohan_000\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2667             if name in self._info_axis:
#    2668                 return self[name]
# -> 2669             return object.__getattribute__(self, name)
#    2670
#    2671     def __setattr__(self, name, value):
#
# AttributeError: ("'Series' object has no attribute 'token'", u'occurred at index 0')
