# %% [markdown]
# ## Table of Contents <a class="anchor" id="top"></a>
# * [Data Preparation](#Data Prep)
# * [Entity Resolution](#Entity)
# * [Relation Extraction](#Relation)
# * [Query System](#Query)

# %% [markdown]
# ## Data Prep <a class="anchor" id="Data Prep"></a>
# [[back to top]](#top)

# %%
# %load_ext autoreload
# %autoreload 2

#standard library imports
import re
import nltk
import numpy as np
import pandas as pd
import os
from collections import Counter, defaultdict

#modeling functions & utilities
from pronounResolution import pronResolution_base, pronResolution_nnMod, pronResolution_nn, pronEval
from relationExtract import simpleRE, REEval, getRelations, extract_relation_categories

# %%
files = [x for x in os.listdir('prep_scripts') if '_gapi' in x]
for file in files:
    df = pd.read_csv('prep_scripts/' + file)[['speaker']]
    print(list(df.speaker.unique()))
    print('***')
    print('***')

# %% [markdown]
# Helper functions to load and annotate dataset

# %%
# files = [x for x in os.listdir('prep_scripts') if '_gapi' in x]
# df = pd.read_csv('prep_scripts/' + files[1])[['speaker', 'dialogue', 'sentences', 'sentiment', 'entities', 'tokens']]
# df['tokens'] = df['tokens'].apply(lambda x: eval(x))
# df['sentiment'] = df['sentiment'].apply(lambda x: eval(x))
# df['speaker'] = df['speaker'].apply(lambda x: x.strip())
# df['entities'] = df['entities'].apply(lambda x: eval(x))
# df.head()

# returns dataframe with script annotations
def loadScript(file_name):
    # read file
    df = pd.read_csv('prep_scripts/' + file_name)[['speaker', 'dialogue', 'sentences', 'sentiment', 'entities', 'tokens']]

    # evaluate strings for lists/dicts of tokens, sentiment, entities
    df['tokens'] = df['tokens'].apply(lambda x: eval(x))
    df['sentiment'] = df['sentiment'].apply(lambda x: eval(x))
    df['speaker'] = df['speaker'].apply(lambda x: x.strip())
    df['entities'] = df['entities'].apply(lambda x: eval(x))
    
    return df

# cList = list(df.speaker.unique())
# cCount = Counter(df.speaker)
# df['total_sent'] = df['sentiment'].apply(lambda x: x['score'] * x['magnitude'])
# cDict = dict(df.groupby('speaker').total_sent.sum())

# # number of pronouns for each line
# df['num_pron'] = df['tokens'].apply(lambda x: sum([int(t['pos'] == 'PRON') for t in x]))

# # total sentiment score for each line
# df['total_sent'] = df['sentiment'].apply(lambda x: x['score'] * x['magnitude'])

# #set nearby speakers
# charRange = 10
# nearbyList = np.dstack((df.shift(i).speaker.values for i in range(-charRange, charRange+1)))[0]
# df['nearbyChars'] = None
# for i, nearbyChars in enumerate(nearbyList):
#     df.set_value(i, 'nearbyChars', nearbyChars)

# df.head()


# enhances annotations with pronoun counts, nearby speakers, and sentiments for each line
def annotateScript(df):
    
    # groups of pronouns
    personPron1 = ['i', 'me', 'my', 'mine', 'myself']
    personPron1p = ['we', 'us', 'ours', 'our', 'ourselves']
    personPron2 = ['you', 'your', 'yours', 'yourself']
    personPron3m = ['he', 'his', 'him', 'himself']
    personPron3f = ['she', 'her', 'hers', 'herself']
    personPron3p = ['they', 'them', 'theirs', 'themselves']
    personPron = personPron1 + personPron1p + personPron2 + personPron3m + personPron3f + personPron3p
    
    # number of pronouns for each line
    df['num_pron'] = df['tokens'].apply(lambda x: sum([int((t['pos'] == 'PRON') and (t['content'].lower() in personPron)) for t in x]))

    # total sentiment score for each line
    df['total_sent'] = df['sentiment'].apply(lambda x: x['score'] * x['magnitude'])

    # previous and next speaker for each line
    df['speaker_prev'] = df.speaker.shift(1)
    df['speaker_next'] = df.speaker.shift(-1)

    #set nearby speakers
    charRange = 10
    nearbyList = np.dstack((df.shift(i).speaker.values for i in range(-charRange, charRange+1)))[0]
    df['nearbyChars'] = None
    for i, nearbyChars in enumerate(nearbyList):
        df.set_value(i, 'nearbyChars', nearbyChars)

    return df

# selects random lines to evaluate in annotated script with unknown entities (pronouns) resolved
def selectEvalLines(df, numExamples):
    
    # indexes for lines of dialogue with resolved pronouns
    pronIndex = list(df[df.num_pron > 0].index)
    
    # sample random line to evaluate resolved pronoun
    evalLines = np.random.choice(pronIndex, min(len(pronIndex), numExamples), replace=False)
    
    return evalLines

# %% [markdown]
# View files for annotated movie scripts.

# %%
# get files for annotated scripts
files = [x for x in os.listdir('prep_scripts') if '_gapi.csv' in x]

print 'annotated scripts:'
for i, f in enumerate(files):
    print i, f

# %% [markdown]
# Load set of raw annotated scripts and add annotations/features for speakers, sentiment, and pronouns.  Select lines to evaluate.

# %%
# list of file indexes for Avengers (1,11) and X-Men movies (15-19)
fileIndex = [1, 11, 15, 16, 18]

# dict to hold name, annotations, characters, and other info for scripts
scripts = defaultdict(lambda: defaultdict())

for i in fileIndex:
    # load annotated script
    df = loadScript(files[i])
    
    # add features to annotated script
    df = annotateScript(df)
    
    # list of unique characters, mentions, overall sentiment
    cCount = Counter(df.speaker)
    
    # script name for printing
    scripts[i]['name'] = files[i]
    
    # annotated script data
    scripts[i]['df'] = df
    
    # unique characters and counts in script
    scripts[i]['chars'] = cCount
    
    # lines to evaluate for each script
    scripts[i]['eval'] = selectEvalLines(scripts[i]['df'], numExamples=20)

# %% [markdown]
# ## Task 1. Entity Resolution <a class="anchor" id="Entity"></a>
# [[back to top]](#top)

# %% [markdown]
# 1.1. Base Model (pronResolution_base): sets reference as random character from script

# %%
### copy scripts
scripts0 = scripts.copy()

# apply model to all scripts
for i in fileIndex:
    charList = scripts0[i]['chars'].keys()
    scripts0[i]['df'].apply(lambda x: pronResolution_base(charList, x), axis=1)
    
# manually evaluate results for all scripts
#pronEval(scripts0)

# %% [markdown]
# 1.2. Nearest Speaker Model (pronResolution_nn)
# * sets entity for first-person pronouns to speaker
# * sets entity for second-person pronouns to random choice between previous and next speaker

# %%
# copy scripts
scripts1 = scripts.copy()

# apply model to all scripts
for i in fileIndex:
    charList = scripts1[i]['chars'].keys()
    scripts1[i]['df'].apply(lambda x: pronResolution_nn(charList, x), axis=1)
    
# manually evaluate results for all scripts
#pronEval(scripts1)

# %% [markdown]
# 1.3. Probability-Weighted Nearby Entities (pronResolution_nnMod):
# * Set entity for first-person pronouns to speaker
# * Set entity for second- and third-person pronouns to entity based on distribution of person entities in nearby characters

# %%
# copy scripts
scripts2 = scripts.copy()

# apply model to all scripts
for i in fileIndex:
    charCounter = scripts2[i]['chars'] 
    scripts2[i]['df'].apply(lambda x: pronResolution_nnMod(charCounter, x, absolute=False), axis=1)
    
# manually evaluate results for all scripts
#pronEval(scripts2)

# %%
# write dfs with pronoun references added
for fileName in files:
    if fileName=='x-men_imsdb_gapi.csv':
        continue
    print fileName
    df = loadScript(fileName)
    df = annotateScript(df)
    charCounter = Counter(df['speaker'])
    df.apply(lambda x: pronResolution_nnMod(charCounter, x, absolute=False), axis=1)
    df.to_csv('prep_scripts/' + fileName[:-4] + '_prons_nnMod.csv')
# Out:
# ant-man_tw_gapi.csv
# avengers_age_of_ultron_tw_gapi.csv
# captain_america_civil_war_tw_gapi.csv
# captain_america_the_first_avenger_tw_gapi.csv
# captain_america_the_winter_soldier_tw_gapi.csv
# fantastic_four_imsdb_gapi.csv
# iron_man_3_tw_gapi.csv
# lego_marvel_super_heroes_tw_gapi.csv
# spider-man_imsdb_gapi.csv
# the_amazing_spider-man_2_tw_gapi.csv
# the_amazing_spider-man_tw_gapi.csv
# the_avengers_tw_gapi.csv
# the_wolverine_tw_gapi.csv
# thor_the_dark_world_tw_gapi.csv
# thor_tw_gapi.csv
# x-men_apocalypse_tw_gapi.csv
# x-men_days_of_future_past_tw_gapi.csv
# x-men_the_last_stand_tw_gapi.csv

# %% [markdown]
# ## Task 2. Relation Extraction <a class="anchor" id="Relation"></a>
# [[back to top]](#top)

# %%
df.apply(lambda x: pronResolution_nnMod(cCount, x), axis=1)
df.head()
# Out:
#    speaker                                           dialogue  \
# 0     Eric  I still don't know why I'm here. Couldn't you ...
# 1  Charles  Yes, I could, but it's not my way. And I would...
# 2     Eric  Ah, power corrupts and all that. Yes, I know, ...
# 3  Charles  When you start listening. You're here because ...
# 4     Eric  We don't have to meet every one of them in per...
#
#                                            sentences  \
# 0  [{'content': u"I still don't know why I'm here...
# 1  [{'content': u"Yes, I could, but it's not my w...
# 2  [{'content': u'Ah, power corrupts and all that...
# 3  [{'content': u'When you start listening.', 'be...
# 4  [{'content': u"We don't have to meet every one...
#
#                              sentiment  \
# 0  {u'score': -0.2, u'magnitude': 0.4}
# 1     {u'score': 0, u'magnitude': 0.5}
# 2  {u'score': -0.1, u'magnitude': 1.1}
# 3     {u'score': 0, u'magnitude': 0.2}
# 4  {u'score': -0.2, u'magnitude': 0.2}
#
#                                             entities  \
# 0  [{u'mentions': [u'I', u'I'], u'type': u'PERSON...
# 1  [{u'type': u'OTHER', u'meta': {}, u'salience':...
# 2  [{u'type': u'OTHER', u'meta': {}, u'salience':...
# 3  [{u'mentions': [u'you', u'You', u'you'], u'typ...
# 4  [{u'type': u'OTHER', u'meta': {}, u'salience':...
#
#                                               tokens  num_pron  total_sent  \
# 0  [{u'index': 4, u'begin': 0, u'pos': u'PRON', u...         4       -0.08
# 1  [{u'index': 3, u'begin': 0, u'pos': u'X', u'la...         5        0.00
# 2  [{u'index': 3, u'begin': 0, u'pos': u'X', u'la...         3       -0.11
# 3  [{u'index': 2, u'begin': 0, u'pos': u'ADV', u'...         4        0.00
# 4  [{u'index': 3, u'begin': 0, u'pos': u'PRON', u...         2       -0.04
#
#   speaker_prev speaker_next                                        nearbyChars
# 0          NaN      Charles  [Eric, Mrs. Grey, Eric, Mr. Grey, Mrs. Grey, C...
# 1         Eric         Eric  [Charles, Eric, Mrs. Grey, Eric, Mr. Grey, Mrs...
# 2      Charles      Charles  [Mrs. Grey, Charles, Eric, Mrs. Grey, Eric, Mr...
# 3         Eric         Eric  [Mr. Grey, Mrs. Grey, Charles, Eric, Mrs. Grey...
# 4      Charles      Charles  [Charles, Mr. Grey, Mrs. Grey, Charles, Eric, ...

# %%
files = [x for x in os.listdir('prep_scripts') if '_nnMod' in x]
df_dict = {}
char_list_dict = {}

for i, f in enumerate(files):
    print f
    df_dict["df_{0}".format(i)] = pd.read_csv('prep_scripts/' + f)[['speaker', 'dialogue', 'sentences', 
                                                                    'sentiment', 'entities', 'tokens', 'num_pron', 'total_sent',
                                                                   'speaker_prev', 'speaker_next', 'nearbyChars']]
    df_dict["df_{0}".format(i)]['tokens'] = df_dict["df_{0}".format(i)]['tokens'].apply(lambda x: eval(x.encode('utf-8')))
    df_dict["df_{0}".format(i)]['sentiment'] = df_dict["df_{0}".format(i)]['sentiment'].apply(lambda x: eval(x.encode('utf-8')))
    df_dict["df_{0}".format(i)]['entities'] = df_dict["df_{0}".format(i)]['entities'].apply(lambda x: eval(x.encode('utf-8')))
    char_list_dict["cList_{0}".format(i)] = list(df_dict["df_{0}".format(i)].speaker.unique())
    #df_dict["df_{0}".format(i)].head()
#df['relations'] = df.apply(lambda x:extract_relation_categories(x), axis=1)
#df.head()
# Out:
# ant-man_tw_gapi_prons_nnMod.csv
# avengers_age_of_ultron_tw_gapi_prons_nnMod.csv
# captain_america_civil_war_tw_gapi_prons_nnMod.csv
# captain_america_the_first_avenger_tw_gapi_prons_nnMod.csv
# captain_america_the_winter_soldier_tw_gapi_prons_nnMod.csv
# fantastic_four_imsdb_gapi_prons_nnMod.csv
# iron_man_3_tw_gapi_prons_nnMod.csv
# lego_marvel_super_heroes_tw_gapi_prons_nnMod.csv
# spider-man_imsdb_gapi_prons_nnMod.csv
# the_amazing_spider-man_2_tw_gapi_prons_nnMod.csv
# the_amazing_spider-man_tw_gapi_prons_nnMod.csv
# the_avengers_tw_gapi_prons_nnMod.csv
# the_wolverine_tw_gapi_prons_nnMod.csv
# thor_the_dark_world_tw_gapi_prons_nnMod.csv
# thor_tw_gapi_prons_nnMod.csv
# x-men_apocalypse_tw_gapi_prons_nnMod.csv
# x-men_days_of_future_past_tw_gapi_prons_nnMod.csv
# x-men_imsdb_gapi_prons_nnMod.csv
# x-men_the_last_stand_tw_gapi_prons_nnMod.csv

# %%
df_dict['df_1']['relations'] = df_dict['df_1'].apply(lambda x:
                                                     extract_relation_categories(char_list_dict['cList_1'], x), axis=1)
REEval([df_dict['df_1']], 20)
#0.4 17/42
# Out:
# ******** line 106 ********
# 104. Storm:
# I'm sorry.
#
# 105. Charles:
# I don't have to be psychic to see that something's bothering you.
#
# => 106. Storm:
# => I don't understand. Magneto's a fugitive, we've a mutant in the cabinet, a president who understands us - why hide?
#
# 107. Charles:
# We're not hiding. But we still have enemies. I must protect my students. You know that.
#
# 108. Storm:
# Yes, but we can't be students forever.
#
# ******** test model 1: line 106 ********
# 1 relations identified
# entities: President => President-[u'mutant', u'president']
# relation: character President has identity of mutant
# category: 3. identity mentioning
#
# how many are correctly identified? 1
#
# ******** line 305 ********
# 303. John:
# So what do we do? - What do we do?
#
# 304. Eric:
# We use this weapon as a lightning rod to bring countless more to our cause. Come. We have an army to build.
#
# => 305. CaIisto:
# => I picked something up. An electromagnetic force. It's massive. It's a mutant. Class five. More powerful than anything I've ever felt. More powerful than you.
#
# 306. Eric:
# Where is she?
#
# 307. Storm:
# Logan.
#
# ******** test model 1: line 305 ********
# 2 relations identified
# entities: CaIisto => Mutant-[u'mutant']
# relation: I picked something up. An electromagnetic force. It's massive. It's a mutant. Class five. More powerful than anything I've ever felt. More powerful than you.
# category: 4. mixed mentioning
# entities: CaIisto => Eric-[u'you']
# relation: I picked something up. An electromagnetic force. It's massive. It's a mutant. Class five. More powerful than anything I've ever felt. More powerful than you.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 59 ********
# 57. Marie:
# I can't touch my boyfriend without killing him. Other than that I'm wonderful.
#
# 58. Bobby:
# Hey. I don't think that's fair. Have I ever put any pressure on you?
#
# => 59. Marie:
# => You're a guy, Bobby. Your mind's only on one thing.
#
# 60. Logan:
# They were looking for you. You didn't show.
#
# 61. Scott:
# What do you care?
#
# ******** test model 1: line 59 ********
# 1 relations identified
# entities: Bobby => Bobby-[u'guy', u'Bobby']
# relation: character Bobby has identity of guy
# category: 3. identity mentioning
#
# how many are correctly identified? 1
#
# ******** line 116 ********
# 114. Storm:
# I love what you've done with your hair.
#
# 115. Hank:
# You too. Thank you for seeing me on such short notice.
#
# => 116. Charles:
# => Henry, you are always welcome here. You're a part of this place.
#
# 117. Hank:
# I have news.
#
# 118. Charles:
# Is it Eric?
#
# ******** test model 1: line 116 ********
# 1 relations identified
# entities: Charles => Hank-[u'you', u'You']
# relation: Henry, you are always welcome here. You're a part of this place.
# category: 2. positive mentioning
#
# how many are correctly identified? 1
#
# ******** line 15 ********
# 13. Mr. Grey:
# We'll leave you, then.
#
# 14. Charles:
# It's very rude to read my thoughts, or Mr. Lensherr's, without our permission.
#
# => 15. Eric:
# => Did you think you were the only one of your kind, young lady?
#
# 16. Charles:
# We're mutants, Jean. We're like you.
#
# 17. Young Jean:
# Really? I doubt that.
#
# ******** test model 1: line 15 ********
# 1 relations identified
# entities: Lady => Lady-[u'one', u'lady']
# relation: character Lady has identity of one
# category: 3. identity mentioning
#
# how many are correctly identified? 0
#
# ******** line 212 ********
# 210. Logan:
# She knew all this?
#
# 211. Charles:
# It's unclear how much she knew. Far more critical is whether the woman in front of us is the Jean Grey we know, or the Phoenix furiously struggling to be free.
#
# => 212. Logan:
# => She looks peaceful to me.
#
# 213. Charles:
# I'm keeping her that way. I'm trying to restore the psychic blocks and cage the beast again.
#
# 214. Logan:
# What have you done to her?
#
# ******** test model 1: line 212 ********
# 1 relations identified
# entities: Logan => Charles-[u'She']
# relation: She looks peaceful to me.
# category: 2. positive mentioning
#
# how many are correctly identified? 1
#
# ******** line 263 ********
# 261. Eric:
# I think he'll make a fine addition to our army.
#
# 262. Raven:
# No!
#
# => 263. Eric:
# => You saved me.
#
# 264. Raven:
# Eric.
#
# 265. Eric:
# I'm sorry, my dear. You're not one of us any more. Such a shame. She was so beautiful.
#
# ******** test model 1: line 263 ********
# 1 relations identified
# entities: Eric => Raven-[u'You']
# relation: You saved me.
# category: 2. positive mentioning
#
# how many are correctly identified? 1
#
# ******** line 300 ********
# 298. Logan:
# Stop it.
#
# 299. Jean:
# Kill me.
#
# => 300. Logan:
# => Stop it. Look at me. Look at me. Jean. It'll be all right. We can help you. Hey. The professor can help. He can fix it.
#
# 301. Phoenix:
# I don't want to fix it.
#
# 302. Eric:
# Voluntary? They put the cure in a gun. I told you they would draw first blood.
#
# ******** test model 1: line 300 ********
# 5 relations identified
# entities: Logan => Jean-[u'Jean', u'We']
# relation: Stop it. Look at me. Look at me. Jean. It'll be all right. We can help you. Hey. The professor can help. He can fix it.
# category: 4. mixed mentioning
# entities: Logan => CaIisto-[u'We']
# relation: Stop it. Look at me. Look at me. Jean. It'll be all right. We can help you. Hey. The professor can help. He can fix it.
# category: 4. mixed mentioning
# entities: Logan => Charles-[u'We']
# relation: Stop it. Look at me. Look at me. Jean. It'll be all right. We can help you. Hey. The professor can help. He can fix it.
# category: 4. mixed mentioning
# entities: Logan => Phoenix-[u'you']
# relation: Stop it. Look at me. Look at me. Jean. It'll be all right. We can help you. Hey. The professor can help. He can fix it.
# category: 4. mixed mentioning
# entities: Logan => Eric-[u'He']
# relation: Stop it. Look at me. Look at me. Jean. It'll be all right. We can help you. Hey. The professor can help. He can fix it.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 250 ********
# 248. John:
# "Cell 41205. James Madrox."
#
# 249. Raven:
# This one robbed seven banks. - At the same time.
#
# => 250. Eric:
# => I could use a man of your talents.
#
# 251. James:
# I'm in.
#
# 252. Eric:
# Welcome to the Brotherhood.
#
# ******** test model 1: line 250 ********
# 2 relations identified
# entities: Eric => Staff Woman-[u'man']
# relation: I could use a man of your talents.
# category: 2. positive mentioning
# entities: Eric => James-[u'your']
# relation: I could use a man of your talents.
# category: 2. positive mentioning
#
# how many are correctly identified? 1
#
# ******** line 241 ********
# 239. Mr. Worthington:
# Yes, you can.
#
# 240. Warren:
# I can't do this!
#
# => 241. Mr. Worthington:
# => Just relax, son. Take it easy. Calm down. - I promise you it will be fine. Warren, relax. - Dad. Warren, it's a better life. - It's what we all want.
#
# 242. Warren:
# No. It's what you want.
#
# 243. Mr. Worthington:
# Warren, no!
#
# ******** test model 1: line 241 ********
# 2 relations identified
# entities: Mr. Worthington => Warren-[u'Warren', u'Warren', u'you', u'we']
# relation: Just relax, son. Take it easy. Calm down. - I promise you it will be fine. Warren, relax. - Dad. Warren, it's a better life. - It's what we all want.
# category: 2. positive mentioning
# entities: Mr. Worthington => Dr. Rao-[u'we']
# relation: Just relax, son. Take it easy. Calm down. - I promise you it will be fine. Warren, relax. - Dad. Warren, it's a better life. - It's what we all want.
# category: 2. positive mentioning
#
# how many are correctly identified? 1
#
# ******** line 246 ********
# 244. Raven:
# Told you so. About time.
#
# 245. Eric:
# I've been busy. Did you find what you were looking for?
#
# => 246. Raven:
# => The source of the cure is a mutant. A child at Worthington Labs. Without him, they have nothing.
#
# 247. Eric:
# Read us the guest list.
#
# 248. John:
# "Cell 41205. James Madrox."
#
# ******** test model 1: line 246 ********
# 6 relations identified
# entities: Raven => Mutant-[u'mutant']
# relation: The source of the cure is a mutant. A child at Worthington Labs. Without him, they have nothing.
# category: 4. mixed mentioning
# entities: Raven => Storm-[u'him']
# relation: The source of the cure is a mutant. A child at Worthington Labs. Without him, they have nothing.
# category: 4. mixed mentioning
# entities: Raven => Logan-[u'they']
# relation: The source of the cure is a mutant. A child at Worthington Labs. Without him, they have nothing.
# category: 4. mixed mentioning
# entities: Raven => Charles-[u'they']
# relation: The source of the cure is a mutant. A child at Worthington Labs. Without him, they have nothing.
# category: 4. mixed mentioning
# entities: Raven => Jean-[u'they']
# relation: The source of the cure is a mutant. A child at Worthington Labs. Without him, they have nothing.
# category: 4. mixed mentioning
# entities: Raven => Eric-[u'they']
# relation: The source of the cure is a mutant. A child at Worthington Labs. Without him, they have nothing.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 292 ********
# 290. Logan:
# You're in the mansion. You need to tell me what happened to Scott. Jean, tell me what happened to him.
#
# 291. Jean:
# Oh, God.
#
# => 292. Logan:
# => Look at me. Stay with me. Talk to me. - Look at me. Look at me. - No. Focus. Focus, Jean.
#
# 293. Jean:
# Kill me.
#
# 294. Logan:
# What?
#
# ******** test model 1: line 292 ********
# 1 relations identified
# entities: Logan => Jean-[u'Jean']
# relation: Look at me. Stay with me. Talk to me. - Look at me. Look at me. - No. Focus. Focus, Jean.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 265 ********
# 263. Eric:
# You saved me.
#
# 264. Raven:
# Eric.
#
# => 265. Eric:
# => I'm sorry, my dear. You're not one of us any more. Such a shame. She was so beautiful.
#
# 266. President:
# Think resigning will make a difference?
#
# 267. Hank:
# That's no way to influence policy. Policy is being made without me, Mr. President. The decision to turn the cure into a weapon was made without me. What happened on that convoy was inexcusable. But your actions...
#
# ******** test model 1: line 265 ********
# 5 relations identified
# entities: Eric => President-[u'You']
# relation: I'm sorry, my dear. You're not one of us any more. Such a shame. She was so beautiful.
# category: 4. mixed mentioning
# entities: Eric => Hank-[u'us']
# relation: I'm sorry, my dear. You're not one of us any more. Such a shame. She was so beautiful.
# category: 4. mixed mentioning
# entities: Eric => Cain-[u'us']
# relation: I'm sorry, my dear. You're not one of us any more. Such a shame. She was so beautiful.
# category: 4. mixed mentioning
# entities: Eric => Raven-[u'us']
# relation: I'm sorry, my dear. You're not one of us any more. Such a shame. She was so beautiful.
# category: 4. mixed mentioning
# entities: Eric => Dr. Rao-[u'She']
# relation: I'm sorry, my dear. You're not one of us any more. Such a shame. She was so beautiful.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 230 ********
# 228. Mr. Worthington:
# Good. Bring him in.
#
# 229. Dr. Rao:
# Are you sure you want to start with him?
#
# => 230. Mr. Worthington:
# => I think it's important. Yes. - Hello, Warren. - How are you, son? - Did you sleep well?
#
# 231. Warren:
# Yeah.
#
# 232. Mr. Worthington:
# You know, I'm proud of you for doing this. Everything's gonna be fine. I promise. You ready?
#
# ******** test model 1: line 230 ********
# 2 relations identified
# entities: Mr. Worthington => Warren-[u'Warren']
# relation: I think it's important. Yes. - Hello, Warren. - How are you, son? - Did you sleep well?
# category: 4. mixed mentioning
# entities: Mr. Worthington => Dr. Rao-[u'you', u'you']
# relation: I think it's important. Yes. - Hello, Warren. - How are you, son? - Did you sleep well?
# category: 4. mixed mentioning
#
# how many are correctly identified? 0
#
# ******** line 134 ********
# 132. Storm:
# When did we become a disease?
#
# 133. Charles:
# Storm. They're announcing it now.
#
# => 134. Mr. Worthington:
# => These so-called mutants are people just like us. Their affliction is nothing more than a disease, a corruption of healthy cellular activity. But I stand here today to tell you that there's hope. This site, once the world's most famous prison, will now be the source of freedom for all mutants who choose it. Ladies and gentlemen... I proudly present the answer to mutation. Finally, we have a cure.
#
# 135. Storm:
# Who would want this cure? I mean, what kind of coward would take it just to fit in?
#
# 136. Hank:
# Is it cowardice to save oneself from persecution?
#
# ******** test model 1: line 134 ********
# 3 relations identified
# entities: Mr. Worthington => Hank-[u'us', u'we']
# relation: These so-called mutants are people just like us. Their affliction is nothing more than a disease, a corruption of healthy cellular activity. But I stand here today to tell you that there's hope. This site, once the world's most famous prison, will now be the source of freedom for all mutants who choose it. Ladies and gentlemen... I proudly present the answer to mutation. Finally, we have a cure.
# category: 4. mixed mentioning
# entities: Mr. Worthington => Logan-[u'us', u'we']
# relation: These so-called mutants are people just like us. Their affliction is nothing more than a disease, a corruption of healthy cellular activity. But I stand here today to tell you that there's hope. This site, once the world's most famous prison, will now be the source of freedom for all mutants who choose it. Ladies and gentlemen... I proudly present the answer to mutation. Finally, we have a cure.
# category: 4. mixed mentioning
# entities: Mr. Worthington => Storm-[u'you']
# relation: These so-called mutants are people just like us. Their affliction is nothing more than a disease, a corruption of healthy cellular activity. But I stand here today to tell you that there's hope. This site, once the world's most famous prison, will now be the source of freedom for all mutants who choose it. Ladies and gentlemen... I proudly present the answer to mutation. Finally, we have a cure.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 161 ********
# 159. Eric:
# You can sense other mutants and their powers? Could you locate one for me?
#
# 160. President:
# Let me out of here. I demand that you release me. Do you know who I am? I'm the president of the United States.
#
# => 161. Guard:
# => Oh, Mr. President. Shut up.
#
# 162. Little Girl:
# Why are you doing this to me? Let me down. I'll be a good girl. Please let me go. Please.
#
# 163. Guard:
# Keep it up. I'll spray you in the face, bitch.
#
# ******** test model 1: line 161 ********
# 1 relations identified
# entities: President => President-[u'President', u'Mr.']
# relation: character President has identity of Mr.
# category: 3. identity mentioning
#
# how many are correctly identified? 1
#
# ******** line 207 ********
# 205. Charles:
# The sheer mass of water that collapsed on top of Jean should have obliterated her. The only explanation of Jean's survival is that her powers wrapped her in a cocoon of telekinetic energy.
#
# 206. Logan:
# Is she gonna be OK?
#
# => 207. Charles:
# => Jean Grey is the only class five mutant I've ever encountered, her potential limitless. Her mutation is seated in the unconscious part of her mind and therein lay the danger. When she was a girl, I created a series of psychic barriers to isolate her powers from her conscious mind. - Jean developed a dual personality.
#
# 208. Logan:
# What?
#
# 209. Charles:
# The conscious Jean, whose powers were always in her control, and the dormant side. A personality that, in our sessions, came to call itself the Phoenix. A purely instinctual creature, all desire and joy and rage.
#
# ******** test model 1: line 207 ********
# 1 relations identified
# entities: Charles => Eric-[u'her', u'Her', u'her', u'she', u'her', u'her']
# relation: Jean Grey is the only class five mutant I've ever encountered, her potential limitless. Her mutation is seated in the unconscious part of her mind and therein lay the danger. When she was a girl, I created a series of psychic barriers to isolate her powers from her conscious mind. - Jean developed a dual personality.
# category: 4. mixed mentioning
#
# how many are correctly identified? 0
#
# ******** line 114 ********
# 112. Storm:
# There's something you're not telling us. Hank?
#
# 113. Hank:
# Ororo. Charles.
#
# => 114. Storm:
# => I love what you've done with your hair.
#
# 115. Hank:
# You too. Thank you for seeing me on such short notice.
#
# 116. Charles:
# Henry, you are always welcome here. You're a part of this place.
#
# ******** test model 1: line 114 ********
# 1 relations identified
# entities: Storm => Hank-[u'you', u'your']
# relation: I love what you've done with your hair.
# category: 2. positive mentioning
#
# how many are correctly identified? 1
#
# ******** line 73 ********
# 71. Hank:
# Yes?
#
# 72. Staff Woman:
# The meeting's begun, sir.
#
# => 73. Hank:
# => Thank you.  Mr. President.
#
# 74. President:
# Have a seat, Hank. Homeland Security was tracking Magneto. We got hits in Lisbon, Geneva, Montreal. NAVSAT lost him crossing the border, but we did get a consolation prize. We picked her up breaking into the FDA. You know who she's been imitating? Secretary Trask here.
#
# 75. Hank:
# Yes, sir. She can do that.
#
# ******** test model 1: line 73 ********
# 2 relations identified
# entities: Hank => President-[u'President', u'Mr.', u'you']
# relation: Thank you.  Mr. President.
# category: 2. positive mentioning
# entities: President => President-[u'President', u'Mr.', u'you']
# relation: character President has identity of Mr.
# category: 3. identity mentioning
#
# how many are correctly identified? 1
#
# ******** line 304 ********
# 302. Eric:
# Voluntary? They put the cure in a gun. I told you they would draw first blood.
#
# 303. John:
# So what do we do? - What do we do?
#
# => 304. Eric:
# => We use this weapon as a lightning rod to bring countless more to our cause. Come. We have an army to build.
#
# 305. CaIisto:
# I picked something up. An electromagnetic force. It's massive. It's a mutant. Class five. More powerful than anything I've ever felt. More powerful than you.
#
# 306. Eric:
# Where is she?
#
# ******** test model 1: line 304 ********
# 3 relations identified
# entities: Eric => Logan-[u'We', u'our', u'We']
# relation: We use this weapon as a lightning rod to bring countless more to our cause. Come. We have an army to build.
# category: 4. mixed mentioning
# entities: Eric => Charles-[u'We', u'our', u'We']
# relation: We use this weapon as a lightning rod to bring countless more to our cause. Come. We have an army to build.
# category: 4. mixed mentioning
# entities: Eric => Storm-[u'We', u'our', u'We']
# relation: We use this weapon as a lightning rod to bring countless more to our cause. Come. We have an army to build.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** test results ********
# model 1: precision = 0.40 (17/42 correct)

# %%
df_dict['df_2']['relations'] = df_dict['df_2'].apply(lambda x:
                                                     extract_relation_categories(char_list_dict['cList_2'], x), axis=1)
REEval([df_dict['df_2']], 20)
#0.48 29/60
# Out:
# ******** line 576 ********
# 574. Steve:
# You're after the wrong guy.
#
# 575. Tony:
# Your judgment is askew. Your war buddy killed innocent people yesterday.
#
# => 576. Steve:
# => And there are 5 more super soldiers just like him. I can't let the doctor find them first, Tony. I can't.
#
# 577. Natasha:
# Steve. You know, what's about to happen. Do you really want to punch your way out of this one?
#
# 578. Tony:
# All right, I've run out of patience. Underoos! Nice job, kid.
#
# ******** test model 1: line 576 ********
# 3 relations identified
# entities: Steve => Sharon Carter-[u'him']
# relation: And there are 5 more super soldiers just like him. I can't let the doctor find them first, Tony. I can't.
# category: 4. mixed mentioning
# entities: Steve => Wanda-[u'them']
# relation: And there are 5 more super soldiers just like him. I can't let the doctor find them first, Tony. I can't.
# category: 4. mixed mentioning
# entities: Steve => Natasha-[u'them']
# relation: And there are 5 more super soldiers just like him. I can't let the doctor find them first, Tony. I can't.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 286 ********
# 284. Sam:
# What? Dude shows up dressed like a cat and you don't wanna know more?
#
# 285. Steve:
# Your suit. Is it Vibranium?
#
# => 286. T'Challa:
# => The Black Panther has been the protector of Wakanda for generations. A mantle passed from warrior to warrior. And now because your friend murdered my father, I also wear the mantle of king. So I ask you, as both warrior and king, how long do you think you can keep your friend safe from me?
#
# 287. Steve:
# What's going to happen?
#
# 288. Everett Ross:
# The same thing that ought to happen to you. Psychological evaluation and extradition.
#
# ******** test model 1: line 286 ********
# 3 relations identified
# entities: T'Challa => King T'Chaka-[u'king']
# relation: The Black Panther has been the protector of Wakanda for generations. A mantle passed from warrior to warrior. And now because your friend murdered my father, I also wear the mantle of king. So I ask you, as both warrior and king, how long do you think you can keep your friend safe from me?
# category: 4. mixed mentioning
# entities: T'Challa => King T'Chaka-[u'king']
# relation: The Black Panther has been the protector of Wakanda for generations. A mantle passed from warrior to warrior. And now because your friend murdered my father, I also wear the mantle of king. So I ask you, as both warrior and king, how long do you think you can keep your friend safe from me?
# category: 4. mixed mentioning
# entities: T'Challa => Steve-[u'your', u'you', u'you', u'you', u'your']
# relation: The Black Panther has been the protector of Wakanda for generations. A mantle passed from warrior to warrior. And now because your friend murdered my father, I also wear the mantle of king. So I ask you, as both warrior and king, how long do you think you can keep your friend safe from me?
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 479 ********
# 477. Peter:
# Cohesive gloves. It's a long story. I was uh...
#
# 478. Tony:
# Lordy! Can you even see in these?
#
# => 479. Peter:
# => Yes. Yes, I can! I can. I can-I can see in those. Okay? It's just that... when... whatever happened happened, it's like my senses have been dialed to 11. There's way too much input, so... they just kinda help me focus.
#
# 480. Tony:
# You're in dire need of an upgrade. Systemic, top to bottom. 100-point restoration. That's why I'm here Why are you doing this? I got to know. What's your MO? What gets you out of that twin bed in the morning?
#
# 481. Peter:
# Because... ...because l've been me my whole life, - and l've had these powers for 6 months.
#
# ******** test model 1: line 479 ********
# 4 relations identified
# entities: Peter => Tony-[u'they']
# relation: Yes. Yes, I can! I can. I can-I can see in those. Okay? It's just that... when... whatever happened happened, it's like my senses have been dialed to 11. There's way too much input, so... they just kinda help me focus.
# category: 4. mixed mentioning
# entities: Peter => Steve-[u'they']
# relation: Yes. Yes, I can! I can. I can-I can see in those. Okay? It's just that... when... whatever happened happened, it's like my senses have been dialed to 11. There's way too much input, so... they just kinda help me focus.
# category: 4. mixed mentioning
# entities: Peter => Rhodey-[u'they']
# relation: Yes. Yes, I can! I can. I can-I can see in those. Okay? It's just that... when... whatever happened happened, it's like my senses have been dialed to 11. There's way too much input, so... they just kinda help me focus.
# category: 4. mixed mentioning
# entities: Peter => T'Challa-[u'they']
# relation: Yes. Yes, I can! I can. I can-I can see in those. Okay? It's just that... when... whatever happened happened, it's like my senses have been dialed to 11. There's way too much input, so... they just kinda help me focus.
# category: 4. mixed mentioning
#
# how many are correctly identified? 2
#
# ******** line 772 ********
# 770. Tony:
# I didn't make you. -
#
# 771. Clint:
# The law. The law. The law. The law. The law.
#
# => 772. Tony:
# => You read it, you broke it. Alright, you're all grown up. You got a wife and kids. I don't understand. Why didn't you think about them before you choose the wrong side?
#
# 773. Clint:
# You better watch your back on this guy. There's a chance he's gonna break it.
#
# 774. Scott:
# Hank Pym always said, you never can trust a Stark.
#
# ******** test model 1: line 772 ********
# 5 relations identified
# entities: Tony => Zemo's Wife-[u'wife']
# relation: You read it, you broke it. Alright, you're all grown up. You got a wife and kids. I don't understand. Why didn't you think about them before you choose the wrong side?
# category: 4. mixed mentioning
# entities: Tony => Clint-[u'You', u'you', u'you', u'You', u'you', u'you']
# relation: You read it, you broke it. Alright, you're all grown up. You got a wife and kids. I don't understand. Why didn't you think about them before you choose the wrong side?
# category: 4. mixed mentioning
# entities: Tony => Steve-[u'them']
# relation: You read it, you broke it. Alright, you're all grown up. You got a wife and kids. I don't understand. Why didn't you think about them before you choose the wrong side?
# category: 4. mixed mentioning
# entities: Tony => Sharon-[u'them']
# relation: You read it, you broke it. Alright, you're all grown up. You got a wife and kids. I don't understand. Why didn't you think about them before you choose the wrong side?
# category: 4. mixed mentioning
# entities: Tony => Vision-[u'them']
# relation: You read it, you broke it. Alright, you're all grown up. You got a wife and kids. I don't understand. Why didn't you think about them before you choose the wrong side?
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 133 ********
# 131. Vision:
# I'm saying there maybe a causality. Our very strength invites challenge. Challenge incites conflict. And conflict... breeds catastrophe. Oversight. Oversight is not an idea that could be dismissed out-of-hand.
#
# 132. Rhodey:
# Boom.
#
# => 133. Natasha:
# => Tony, you're being uncharacteristically non-hyper verbal.
#
# 134. Steve:
# That's because he's already made up his mind.
#
# 135. Tony:
# Boy, you know me so well. Actually, I'm nursing my electromagnetic headache. That's what's going on, Cap. It's just pain... says Humphrey. Who's putting coffee grounds in the disposal? Am I running a bed and breakfast for a biker gang? Oh, that's Charles Spencer by the way. He's a great kid. Computer engineering degree. 3.6 GPA. Had a floor level gig. An Intel plan for the fall. But first, he wanted to put a few miles on his soul. Before he park it behind then desk. See the world, maybe be of service. Charlie didn't want to go to Vegas which is what I would do. He didn't go to Paris or Amsterdam. Sounds fun. He decided to spend his summer, building sustainable housing for the poor. Guess where, Sokovia. He want to make a difference, I suppose. I mean, we won't know because we dropped a building on him while we were kicking ass. There's no decision making process here. We need to be put in check. Whatever form that takes, I'm game. If we can't accept limitations, we're bounderless, we're no better than the bad guys.
#
# ******** test model 1: line 133 ********
# 2 relations identified
# entities: Natasha => Rhodey-[u'you']
# relation: Tony, you're being uncharacteristically non-hyper verbal.
# category: 1. negative mentioning
# entities: Tony => Tony-[u'Tony', u'verbal']
# relation: character Tony has identity of verbal
# category: 3. identity mentioning
#
# how many are correctly identified? 1
#
# ******** line 155 ********
# 153. Steve:
# I have to go. LONDON MARGARET "PEGGY" CARTER
#
# 154. Preacher:
# And now, I would like to invite Sharon Carter, to come up and say a few words.
#
# => 155. Sharon Carter:
# => Margaret Carter was known to most as a founder of SHIELD. But I just knew her as Aunt Peggy. She had a photograph in her office. Aunt Peggy standing next to JFK. As a kid, that was pretty cool. But, it was a lot to live up to. Which is why I never told anyone we were related. I asked her once how she managed to master diplomacy and espionage at a time when no one wanted to see a woman succeed at either. And she said, compromise when you can. When you can't, don't. Even if everyone is telling you that something wrong is something right. Even if the whole world is telling you to move. It is your duty, to plant yourself like a tree, look them in they eye and say, " No... ...you move. Steve:When I came out of the ice, thought I wanted to ignore she was gone. When I found out that she was alive, I was just lucky to have her.
#
# 156. Natasha:
# She'd had you're back too.
#
# 157. Steve:
# Who else sign it.
#
# ******** test model 1: line 155 ********
# 9 relations identified
# entities: world => Preacher-None
# relation:  telling
# category: 5. place mentioning
# entities: Sharon Carter => Woman-[u'woman']
# relation: Margaret Carter was known to most as a founder of SHIELD. But I just knew her as Aunt Peggy. She had a photograph in her office. Aunt Peggy standing next to JFK. As a kid, that was pretty cool. But, it was a lot to live up to. Which is why I never told anyone we were related. I asked her once how she managed to master diplomacy and espionage at a time when no one wanted to see a woman succeed at either. And she said, compromise when you can. When you can't, don't. Even if everyone is telling you that something wrong is something right. Even if the whole world is telling you to move. It is your duty, to plant yourself like a tree, look them in they eye and say, " No... ...you move. Steve:When I came out of the ice, thought I wanted to ignore she was gone. When I found out that she was alive, I was just lucky to have her.
# category: 4. mixed mentioning
# entities: Sharon Carter => Steve-[u'Steve', u'we']
# relation: Margaret Carter was known to most as a founder of SHIELD. But I just knew her as Aunt Peggy. She had a photograph in her office. Aunt Peggy standing next to JFK. As a kid, that was pretty cool. But, it was a lot to live up to. Which is why I never told anyone we were related. I asked her once how she managed to master diplomacy and espionage at a time when no one wanted to see a woman succeed at either. And she said, compromise when you can. When you can't, don't. Even if everyone is telling you that something wrong is something right. Even if the whole world is telling you to move. It is your duty, to plant yourself like a tree, look them in they eye and say, " No... ...you move. Steve:When I came out of the ice, thought I wanted to ignore she was gone. When I found out that she was alive, I was just lucky to have her.
# category: 4. mixed mentioning
# entities: Sharon Carter => Mrs. Spencer-[u'her', u'She', u'her', u'her', u'she', u'she', u'she', u'she', u'her']
# relation: Margaret Carter was known to most as a founder of SHIELD. But I just knew her as Aunt Peggy. She had a photograph in her office. Aunt Peggy standing next to JFK. As a kid, that was pretty cool. But, it was a lot to live up to. Which is why I never told anyone we were related. I asked her once how she managed to master diplomacy and espionage at a time when no one wanted to see a woman succeed at either. And she said, compromise when you can. When you can't, don't. Even if everyone is telling you that something wrong is something right. Even if the whole world is telling you to move. It is your duty, to plant yourself like a tree, look them in they eye and say, " No... ...you move. Steve:When I came out of the ice, thought I wanted to ignore she was gone. When I found out that she was alive, I was just lucky to have her.
# category: 4. mixed mentioning
# entities: Sharon Carter => Text Message-[u'we']
# relation: Margaret Carter was known to most as a founder of SHIELD. But I just knew her as Aunt Peggy. She had a photograph in her office. Aunt Peggy standing next to JFK. As a kid, that was pretty cool. But, it was a lot to live up to. Which is why I never told anyone we were related. I asked her once how she managed to master diplomacy and espionage at a time when no one wanted to see a woman succeed at either. And she said, compromise when you can. When you can't, don't. Even if everyone is telling you that something wrong is something right. Even if the whole world is telling you to move. It is your duty, to plant yourself like a tree, look them in they eye and say, " No... ...you move. Steve:When I came out of the ice, thought I wanted to ignore she was gone. When I found out that she was alive, I was just lucky to have her.
# category: 4. mixed mentioning
# entities: Sharon Carter => Tony-[u'we', u'them', u'they']
# relation: Margaret Carter was known to most as a founder of SHIELD. But I just knew her as Aunt Peggy. She had a photograph in her office. Aunt Peggy standing next to JFK. As a kid, that was pretty cool. But, it was a lot to live up to. Which is why I never told anyone we were related. I asked her once how she managed to master diplomacy and espionage at a time when no one wanted to see a woman succeed at either. And she said, compromise when you can. When you can't, don't. Even if everyone is telling you that something wrong is something right. Even if the whole world is telling you to move. It is your duty, to plant yourself like a tree, look them in they eye and say, " No... ...you move. Steve:When I came out of the ice, thought I wanted to ignore she was gone. When I found out that she was alive, I was just lucky to have her.
# category: 4. mixed mentioning
# entities: Sharon Carter => Natasha-[u'we']
# relation: Margaret Carter was known to most as a founder of SHIELD. But I just knew her as Aunt Peggy. She had a photograph in her office. Aunt Peggy standing next to JFK. As a kid, that was pretty cool. But, it was a lot to live up to. Which is why I never told anyone we were related. I asked her once how she managed to master diplomacy and espionage at a time when no one wanted to see a woman succeed at either. And she said, compromise when you can. When you can't, don't. Even if everyone is telling you that something wrong is something right. Even if the whole world is telling you to move. It is your duty, to plant yourself like a tree, look them in they eye and say, " No... ...you move. Steve:When I came out of the ice, thought I wanted to ignore she was gone. When I found out that she was alive, I was just lucky to have her.
# category: 4. mixed mentioning
# entities: Sharon Carter => Preacher-[u'you', u'you', u'you', u'you', u'your', u'yourself', u'you']
# relation: Margaret Carter was known to most as a founder of SHIELD. But I just knew her as Aunt Peggy. She had a photograph in her office. Aunt Peggy standing next to JFK. As a kid, that was pretty cool. But, it was a lot to live up to. Which is why I never told anyone we were related. I asked her once how she managed to master diplomacy and espionage at a time when no one wanted to see a woman succeed at either. And she said, compromise when you can. When you can't, don't. Even if everyone is telling you that something wrong is something right. Even if the whole world is telling you to move. It is your duty, to plant yourself like a tree, look them in they eye and say, " No... ...you move. Steve:When I came out of the ice, thought I wanted to ignore she was gone. When I found out that she was alive, I was just lucky to have her.
# category: 4. mixed mentioning
# entities: Sharon Carter => Secretary Ross-[u'them', u'they']
# relation: Margaret Carter was known to most as a founder of SHIELD. But I just knew her as Aunt Peggy. She had a photograph in her office. Aunt Peggy standing next to JFK. As a kid, that was pretty cool. But, it was a lot to live up to. Which is why I never told anyone we were related. I asked her once how she managed to master diplomacy and espionage at a time when no one wanted to see a woman succeed at either. And she said, compromise when you can. When you can't, don't. Even if everyone is telling you that something wrong is something right. Even if the whole world is telling you to move. It is your duty, to plant yourself like a tree, look them in they eye and say, " No... ...you move. Steve:When I came out of the ice, thought I wanted to ignore she was gone. When I found out that she was alive, I was just lucky to have her.
# category: 4. mixed mentioning
#
# how many are correctly identified? 4
#
# ******** line 147 ********
# 145. Vision:
# We will protect you.
#
# 146. Natasha:
# Maybe Tony is right. If, we have one hand on the wheel that can still steer.
#
# => 147. Sam:
# => Aren't you the same woman who told the government to kiss our ass a few years ago.
#
# 148. Natasha:
# I'm just... playing the field. We have made some very public mistakes. We need to win our trust back.
#
# 149. Tony:
# I'm sorry, did I just mishear you or did you agree with me.
#
# ******** test model 1: line 147 ********
# 5 relations identified
# entities: Sam => Woman-[u'woman']
# relation: Aren't you the same woman who told the government to kiss our ass a few years ago.
# category: 1. negative mentioning
# entities: Sam => Natasha-[u'you', u'our']
# relation: Aren't you the same woman who told the government to kiss our ass a few years ago.
# category: 1. negative mentioning
# entities: Sam => Tony-[u'our']
# relation: Aren't you the same woman who told the government to kiss our ass a few years ago.
# category: 1. negative mentioning
# entities: Sam => Steve-[u'our']
# relation: Aren't you the same woman who told the government to kiss our ass a few years ago.
# category: 1. negative mentioning
# entities: Sam => Rhodey-[u'our']
# relation: Aren't you the same woman who told the government to kiss our ass a few years ago.
# category: 1. negative mentioning
#
# how many are correctly identified? 1
#
# ******** line 727 ********
# 725. Zemo:
# This is room 201.
#
# 726. Room Service Lady:
# Good morning, Mr. Muller. Bacon and black coffee again?
#
# => 727. Zemo:
# => You know me so well.
#
# 728. Room Service Lady:
# Hello, Your breakfast is here. May I let myself in? Mr Muller? Mr Muller? Oh God!
#
# 729. Bucky:
# What's gonna happen to your friends?
#
# ******** test model 1: line 727 ********
# 1 relations identified
# entities: Zemo => Room Service Lady-[u'You']
# relation: You know me so well.
# category: 2. positive mentioning
#
# how many are correctly identified? 1
#
# ******** line 507 ********
# 505. Wanda:
# Oh my god. - What are you doing here?
#
# 506. Clint:
# Disappointing my kids. We're supposed to go water skiing. Cap needs our help, come on.
#
# => 507. Vision:
# => Clint! You should not be here.
#
# 508. Clint:
# Really? I retired for, what, like 5 minutes? And it all goes to shit.
#
# 509. Vision:
# Please consider the consequences of your actions.
#
# ******** test model 1: line 507 ********
# 1 relations identified
# entities: Vision => Clint-[u'You']
# relation: Clint! You should not be here.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 145 ********
# 143. Tony:
# If we don't do this now, it's going to be done to us later. That's a fact. That won't be pretty.
#
# 144. Wanda:
# You're saying they will come for me.
#
# => 145. Vision:
# => We will protect you.
#
# 146. Natasha:
# Maybe Tony is right. If, we have one hand on the wheel that can still steer.
#
# 147. Sam:
# Aren't you the same woman who told the government to kiss our ass a few years ago.
#
# ******** test model 1: line 145 ********
# 5 relations identified
# entities: Vision => Tony-[u'We']
# relation: We will protect you.
# category: 2. positive mentioning
# entities: Vision => Text Message-[u'We']
# relation: We will protect you.
# category: 2. positive mentioning
# entities: Vision => Sharon Carter-[u'We']
# relation: We will protect you.
# category: 2. positive mentioning
# entities: Vision => Preacher-[u'We']
# relation: We will protect you.
# category: 2. positive mentioning
# entities: Vision => Wanda-[u'you']
# relation: We will protect you.
# category: 2. positive mentioning
#
# how many are correctly identified? 2
#
# ******** line 106 ********
# 104. Steve:
# Okay. That's enough.
#
# 105. Secretary Ross:
# For the past 4 years, you operated with unlimited power and no supervision. That's an arrangement the governments of the world can no longer tolerate. But I think we have a solution. The Sokovia accords. Approved by 117 countries. It states, that the Avengers shall no longer be a private organization. Instead, they'll operate under the supervision of a United Nations Panel, only when and if that Panel deems it necessary.
#
# => 106. Steve:
# => The Avengers were formed to make the world a safer place. I feel we've done that.
#
# 107. Secretary Ross:
# Tell me captain, do you know where Thor and Banner are right now? If I misplaced a couple of 30 mega tonne nukes, you can bet there'd be consequences Compromise. Reassurance. That's how the world works. Believe me, this is the middle ground.
#
# 108. Rhodey:
# So, there are contingencies?
#
# ******** test model 1: line 106 ********
# 1 relations identified
# entities: world => that-None
# relation:  done
# category: 5. place mentioning
#
# how many are correctly identified? 1
#
# ******** line 741 ********
# 739. Natasha:
# Steve's not gonna stop. If you don't either, then Rhodey's gonna be the best case scenario.
#
# 740. Tony:
# You let them go, Nat. -
#
# => 741. Natasha:
# => We played this wrong.
#
# 742. Tony:
# We? Boy. It must be hard to shake the whole double agent thing, huh? Sticks in the DNA.
#
# 743. Natasha:
# Are you incapable of letting go of your ego for 1 goddamn second?
#
# ******** test model 1: line 741 ********
# 3 relations identified
# entities: Natasha => Tony-[u'We']
# relation: We played this wrong.
# category: 1. negative mentioning
# entities: Natasha => Friday-[u'We']
# relation: We played this wrong.
# category: 1. negative mentioning
# entities: Natasha => Bucky-[u'We']
# relation: We played this wrong.
# category: 1. negative mentioning
#
# how many are correctly identified? 2
#
# ******** line 460 ********
# 458. Tony:
# You're a dumpster diver.
#
# 459. Peter:
# Yeah, I was... Anyway, look. Umm. I definitely did not apply for your grant.
#
# => 460. Tony:
# => Uh,uh. Me first. - Okay. Quick question of the rhetorical variety. That's you, right?
#
# 461. Peter:
# Um, no. - What do you. What do you...
#
# 462. Tony:
# Yeah. Look at you go. Wow, nice catch! 3000 pounds. 40 miles an hour. Its not easy. You got mad skills.
#
# ******** test model 1: line 460 ********
# 1 relations identified
# entities: Tony => Peter-[u'you']
# relation: Uh,uh. Me first. - Okay. Quick question of the rhetorical variety. That's you, right?
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 297 ********
# 295. Natasha:
# For the record. This is what making things worse looks like.
#
# 296. Steve:
# He's alive.
#
# => 297. Natasha:
# => The remaining of us are now at court-sec. And, Colonel Ross is supervising the clean up. Try not to break anything while we fix this.
#
# 298. Tony:
# Consequences? You bet there will be consequences. Obviously you can quote me on that because I just said it. Anything else? Thank you, sir.
#
# 299. Steve:
# Consequences?
#
# ******** test model 1: line 297 ********
# 4 relations identified
# entities: Natasha => Secretary Ross-[u'Ross', u'Colonel']
# relation: The remaining of us are now at court-sec. And, Colonel Ross is supervising the clean up. Try not to break anything while we fix this.
# category: 4. mixed mentioning
# entities: Natasha => Steve-[u'us', u'we']
# relation: The remaining of us are now at court-sec. And, Colonel Ross is supervising the clean up. Try not to break anything while we fix this.
# category: 4. mixed mentioning
# entities: Natasha => Everett Ross-[u'us', u'we']
# relation: The remaining of us are now at court-sec. And, Colonel Ross is supervising the clean up. Try not to break anything while we fix this.
# category: 4. mixed mentioning
# entities: Secretary Ross => Secretary Ross-[u'Ross', u'Colonel']
# relation: character Secretary Ross has identity of Colonel
# category: 3. identity mentioning
#
# how many are correctly identified? 2
#
# ******** line 403 ********
# 401. Bucky:
# Enough.
#
# 402. Steve:
# He said he wanted to see an empire fall.
#
# => 403. Bucky:
# => With these guys he can do it. They speak 30 languages, can hide in plain sight, infiltrate, assassinate, destabilize, They can take a whole country down in 1 night. You'd never see them coming.
#
# 404. Sam:
# This would be a lot easier a week ago.
#
# 405. Steve:
# If we could... If we call Tony.
#
# ******** test model 1: line 403 ********
# 3 relations identified
# entities: Steve => country-None
# relation:  take a whole
# category: 5. place mentioning
# entities: Bucky => Steve-[u'he', u'They', u'They', u'them']
# relation: With these guys he can do it. They speak 30 languages, can hide in plain sight, infiltrate, assassinate, destabilize, They can take a whole country down in 1 night. You'd never see them coming.
# category: 4. mixed mentioning
# entities: Bucky => Sam-[u'They', u'They', u'You', u'them']
# relation: With these guys he can do it. They speak 30 languages, can hide in plain sight, infiltrate, assassinate, destabilize, They can take a whole country down in 1 night. You'd never see them coming.
# category: 4. mixed mentioning
#
# how many are correctly identified? 2
#
# ******** line 413 ********
# 411. Secretary Ross:
# And I don't suppose you have any idea where they are.
#
# 412. Tony:
# We will. GSG-9's got the borders covered. Recons flying 24/7. They'll get a hit. We'll handle it.
#
# => 413. Secretary Ross:
# => You don't get it, Stark. It's not yours to handle. It's clear you can't be objective. I'm putting special ops on this.
#
# 414. Tony:
# And what happens when the shooting starts, let them kill Steve Rogers?
#
# 415. Secretary Ross:
# If we are provoked.
#
# ******** test model 1: line 413 ********
# 2 relations identified
# entities: Secretary Ross => Maria Stark-[u'Stark']
# relation: You don't get it, Stark. It's not yours to handle. It's clear you can't be objective. I'm putting special ops on this.
# category: 4. mixed mentioning
# entities: Secretary Ross => Tony-[u'You', u'yours', u'you']
# relation: You don't get it, Stark. It's not yours to handle. It's clear you can't be objective. I'm putting special ops on this.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 891 ********
# 889. Peter:
# No, no, no. You don't know him, he's from Brooklyn. Ouch...
#
# 890. Aunt May:
# Well. Hope you got a few good licks in.
#
# => 891. Peter:
# => Yeah, I got quite a few in actually. His friend was huge. Like huge. That's way better. Thank you.
#
# 892. Aunt May:
# Okay, tough guy.
#
# ******** test model 1: line 891 ********
# 2 relations identified
# entities: Peter => Tony-[u'His']
# relation: Yeah, I got quite a few in actually. His friend was huge. Like huge. That's way better. Thank you.
# category: 4. mixed mentioning
# entities: Peter => Aunt May-[u'you']
# relation: Yeah, I got quite a few in actually. His friend was huge. Like huge. That's way better. Thank you.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 606 ********
# 604. Sam:
# Everyone's got a gimmick now.
#
# 605. Peter:
# You have a metal arm? That is awesome, dude! You have the right to remain silent!
#
# => 606. Rhodes:
# => Sorry, Cap. This won't kill you but it ain't gonna tickle either.
#
# 607. Tony:
# Wanda, I think you hurt Vision's feelings.
#
# 608. Wanda:
# You locked me in my room.
#
# ******** test model 1: line 606 ********
# 1 relations identified
# entities: Rhodes => Peter-[u'you']
# relation: Sorry, Cap. This won't kill you but it ain't gonna tickle either.
# category: 1. negative mentioning
#
# how many are correctly identified? 1
#
# ******** line 62 ********
# 60. Maria Stark:
# Try to remember the kind of September. When grass was green... Wake up, dear. Say goodbye to your father.
#
# 61. Howard Stark:
# Who's the homeless person on the couch?
#
# => 62. Young Tony:
# => This is why I love coming home for Christmas. Right before you leave town.
#
# 63. Maria:
# Be nice, dear. He's been studying abroad.
#
# 64. Howard:
# Really, which broad? What's her name?
#
# ******** test model 1: line 62 ********
# 1 relations identified
# entities: Maria => town-None
# relation:  leave
# category: 5. place mentioning
#
# how many are correctly identified? 1
#
# ******** line 81 ********
# 79. Teacher Man:
# We'll catch up later.
#
# 80. Mrs. Spencer:
# That was really sweet, what you did for the young people.
#
# => 81. Tony:
# => Oh, they deserve it. 'Cos it helps to ease my conscious.
#
# 82. Mrs. Spencer:
# They say, there's a correlation between generosity and guilt. But, you got the money. Break as many eggs as you like. It's brilliant.
#
# 83. Tony:
# Are you going up?
#
# ******** test model 1: line 81 ********
# 4 relations identified
# entities: Tony => Steve-[u'they']
# relation: Oh, they deserve it. 'Cos it helps to ease my conscious.
# category: 2. positive mentioning
# entities: Tony => Peter-[u'they']
# relation: Oh, they deserve it. 'Cos it helps to ease my conscious.
# category: 2. positive mentioning
# entities: Tony => Vision-[u'they']
# relation: Oh, they deserve it. 'Cos it helps to ease my conscious.
# category: 2. positive mentioning
# entities: Tony => Sam-[u'they']
# relation: Oh, they deserve it. 'Cos it helps to ease my conscious.
# category: 2. positive mentioning
#
# how many are correctly identified? 2
#
# ******** test results ********
# model 1: precision = 0.48 (29/60 correct)

# %%
df_dict['df_3']['relations'] = df_dict['df_3'].apply(lambda x:
                                                     extract_relation_categories(char_list_dict['cList_3'], x), axis=1)
REEval([df_dict['df_3']], 20)
#0.35 19/35
# Out:
# ******** line 173 ********
# 171. Col. Chester Phillips:
# [addressing the new army recruits] General Patton has said that wars are fought with weapons but they are won by men. We are going to win this war because we have the best men.
#
# 172. narrator:
# he sees Rogers and continues talking
#
# => 173. Col. Chester Phillips:
# => And because they're gonna get better. Much better. The Strategic Scientific Reserve is an allied effort made up of the best minds in the free world. Our goal is to create the best army in history. But every army starts with one man. [addressing the new army recruits] At the end of this week we will choose that man. He will be the first in a new breed of super-soldiers. And they, will personally escort Adolf Hitler to the gates of Hell.
#
# 174. narrator:
# a montage of steve's training goes by
#
# 175. narrator:
# then we see Steve and some other trainees running up to a waiting Peggy and a flagpole
#
# ******** test model 1: line 173 ********
# 7 relations identified
# entities: Col. Chester Phillips => Mandy-[u'man']
# relation: And because they're gonna get better. Much better. The Strategic Scientific Reserve is an allied effort made up of the best minds in the free world. Our goal is to create the best army in history. But every army starts with one man. [addressing the new army recruits] At the end of this week we will choose that man. He will be the first in a new breed of super-soldiers. And they, will personally escort Adolf Hitler to the gates of Hell.
# category: 2. positive mentioning
# entities: Col. Chester Phillips => Mandy-[u'man']
# relation: And because they're gonna get better. Much better. The Strategic Scientific Reserve is an allied effort made up of the best minds in the free world. Our goal is to create the best army in history. But every army starts with one man. [addressing the new army recruits] At the end of this week we will choose that man. He will be the first in a new breed of super-soldiers. And they, will personally escort Adolf Hitler to the gates of Hell.
# category: 2. positive mentioning
# entities: Col. Chester Phillips => Young Doctor-[u'they', u'they']
# relation: And because they're gonna get better. Much better. The Strategic Scientific Reserve is an allied effort made up of the best minds in the free world. Our goal is to create the best army in history. But every army starts with one man. [addressing the new army recruits] At the end of this week we will choose that man. He will be the first in a new breed of super-soldiers. And they, will personally escort Adolf Hitler to the gates of Hell.
# category: 2. positive mentioning
# entities: Col. Chester Phillips => Steve Rogers-[u'they', u'they']
# relation: And because they're gonna get better. Much better. The Strategic Scientific Reserve is an allied effort made up of the best minds in the free world. Our goal is to create the best army in history. But every army starts with one man. [addressing the new army recruits] At the end of this week we will choose that man. He will be the first in a new breed of super-soldiers. And they, will personally escort Adolf Hitler to the gates of Hell.
# category: 2. positive mentioning
# entities: Col. Chester Phillips => Dr. Abraham Erskine-[u'Our', u'we']
# relation: And because they're gonna get better. Much better. The Strategic Scientific Reserve is an allied effort made up of the best minds in the free world. Our goal is to create the best army in history. But every army starts with one man. [addressing the new army recruits] At the end of this week we will choose that man. He will be the first in a new breed of super-soldiers. And they, will personally escort Adolf Hitler to the gates of Hell.
# category: 2. positive mentioning
# entities: Col. Chester Phillips => Peggy Carter-[u'Our', u'we', u'He']
# relation: And because they're gonna get better. Much better. The Strategic Scientific Reserve is an allied effort made up of the best minds in the free world. Our goal is to create the best army in history. But every army starts with one man. [addressing the new army recruits] At the end of this week we will choose that man. He will be the first in a new breed of super-soldiers. And they, will personally escort Adolf Hitler to the gates of Hell.
# category: 2. positive mentioning
# entities: Col. Chester Phillips => Gilmore Hodge-[u'Our', u'we']
# relation: And because they're gonna get better. Much better. The Strategic Scientific Reserve is an allied effort made up of the best minds in the free world. Our goal is to create the best army in history. But every army starts with one man. [addressing the new army recruits] At the end of this week we will choose that man. He will be the first in a new breed of super-soldiers. And they, will personally escort Adolf Hitler to the gates of Hell.
# category: 2. positive mentioning
#
# how many are correctly identified? 2
#
# ******** line 344 ********
# 342. Steve Rogers:
# You got no idea.
#
# 343. Johann Schmidt:
# Haven't I! [he goes to hit Steve but Steve protects himself with his shield] No matter what lies Erskine told you, you see I was his greatest success! [he peels off the skin on his face to reveal that he is the Red Skull]
#
# => 344. Johann Schmidt:
# => You are deluded, Captain. You pretend to be a simple soldier, but in reality you are just afraid to admit that we have left humanity behind. Unlike you, I embrace it proudly. Without fear!
#
# 345. Steve Rogers:
# Then how come you're running?
#
# 346. Col. Chester Phillips:
# I can't touch Stark, he's rich and he's the army's number one weapons contractor. You are neither one!
#
# ******** test model 1: line 344 ********
# 4 relations identified
# entities: Johann Schmidt => Soldier's voice-[u'soldier']
# relation: You are deluded, Captain. You pretend to be a simple soldier, but in reality you are just afraid to admit that we have left humanity behind. Unlike you, I embrace it proudly. Without fear!
# category: 4. mixed mentioning
# entities: Johann Schmidt => Steve Rogers-[u'You', u'You', u'you', u'we', u'you']
# relation: You are deluded, Captain. You pretend to be a simple soldier, but in reality you are just afraid to admit that we have left humanity behind. Unlike you, I embrace it proudly. Without fear!
# category: 4. mixed mentioning
# entities: Johann Schmidt => Col. Chester Phillips-[u'we']
# relation: You are deluded, Captain. You pretend to be a simple soldier, but in reality you are just afraid to admit that we have left humanity behind. Unlike you, I embrace it proudly. Without fear!
# category: 4. mixed mentioning
# entities: Johann Schmidt => James Barnes-[u'we']
# relation: You are deluded, Captain. You pretend to be a simple soldier, but in reality you are just afraid to admit that we have left humanity behind. Unlike you, I embrace it proudly. Without fear!
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 268 ********
# 266. Steve Rogers:
# Sir, that's all I want.
#
# 267. Senator Brandt:
# Then, congratulations. You just got promoted.
#
# => 268. Steve Rogers:
# => [backstage as Steve is getting dressed in super-hero costume] I don't know if I can do this.
#
# 269. Brandt's Aide:
# Nothing to it. Sell off a few bonds, bonds buy bullets, bullets kills Nazi's. Bing bang boom. You're an American hero.
#
# 270. Steve Rogers:
# It's just now how I pictured getting there.
#
# ******** test model 1: line 268 ********
# 1 relations identified
# entities: Steve Rogers => Steve Roger-[u'Steve']
# relation: [backstage as Steve is getting dressed in super-hero costume] I don't know if I can do this.
# category: 2. positive mentioning
#
# how many are correctly identified? 0
#
# ******** line 343 ********
# 341. Johann Schmidt:
# Captain America! How exciting! I'm a great fan of your films. So Dr. Erskine managed it after all. Not exactly an improvement, but still impressive. [Steve punches Schmidt hard in the face]
#
# 342. Steve Rogers:
# You got no idea.
#
# => 343. Johann Schmidt:
# => Haven't I! [he goes to hit Steve but Steve protects himself with his shield] No matter what lies Erskine told you, you see I was his greatest success! [he peels off the skin on his face to reveal that he is the Red Skull]
#
# 344. Johann Schmidt:
# You are deluded, Captain. You pretend to be a simple soldier, but in reality you are just afraid to admit that we have left humanity behind. Unlike you, I embrace it proudly. Without fear!
#
# 345. Steve Rogers:
# Then how come you're running?
#
# ******** test model 1: line 343 ********
# 4 relations identified
# entities: Johann Schmidt => Steve Roger-[u'Steve', u'Steve']
# relation: Haven't I! [he goes to hit Steve but Steve protects himself with his shield] No matter what lies Erskine told you, you see I was his greatest success! [he peels off the skin on his face to reveal that he is the Red Skull]
# category: 2. positive mentioning
# entities: Johann Schmidt => Dr. Abraham Erskine-[u'Erskine']
# relation: Haven't I! [he goes to hit Steve but Steve protects himself with his shield] No matter what lies Erskine told you, you see I was his greatest success! [he peels off the skin on his face to reveal that he is the Red Skull]
# category: 2. positive mentioning
# entities: Johann Schmidt => Howard Stark-[u'he', u'himself', u'his', u'his', u'he', u'his', u'he']
# relation: Haven't I! [he goes to hit Steve but Steve protects himself with his shield] No matter what lies Erskine told you, you see I was his greatest success! [he peels off the skin on his face to reveal that he is the Red Skull]
# category: 2. positive mentioning
# entities: Johann Schmidt => Steve Rogers-[u'you', u'you']
# relation: Haven't I! [he goes to hit Steve but Steve protects himself with his shield] No matter what lies Erskine told you, you see I was his greatest success! [he peels off the skin on his face to reveal that he is the Red Skull]
# category: 2. positive mentioning
#
# how many are correctly identified? 0
#
# ******** line 422 ********
# 420. Steve Rogers:
# Did you read the reports?
#
# 421. Peggy Carter:
# Yes.
#
# => 422. Steve Rogers:
# => Then you know that's not true.
#
# 423. Peggy Carter:
# You did everything you could. Did you believe in your friend? Did you respect him? [Steve looks at her as if to say yes] Then stop blaming yourself. Allow Barnes the dignity of his choice. He damn well must have thought you were worth it.
#
# 424. Steve Rogers:
# I'm goin' after Schmidt. I'm not gonna stop till all of Hydra is dead or captured.
#
# ******** test model 1: line 422 ********
# 1 relations identified
# entities: Steve Rogers => Peggy Carter-[u'you']
# relation: Then you know that's not true.
# category: 1. negative mentioning
#
# how many are correctly identified? 1
#
# ******** line 247 ********
# 245. Steve Rogers:
# Who the hell are you?
#
# 246. Heinz Kruger:
# The first of many. Cut off one head, two more shall take its place. Hail Hydra! [he pops a fake tooth loose and swallows it, he starts to foam at the mouth and then die]
#
# => 247. Johann Schmidt:
# => Hitler speaks of a thousand year Reich, but he cannot feed his army for month. His troops spill their blood across every field in Europe. But he is still no closer to achieving his goals.
#
# 248. Roeder:
# And I suppose you still aim to end this war through magic?
#
# 249. Johann Schmidt:
# Science. But I understand your confusion. Great power has always baffled primitive men. Hydra is assembling an arsenal to destroy my enemies in one stroke. Where ever they are, regardless of how many forces they possess. All in a matter of hours.
#
# ******** test model 1: line 247 ********
# 1 relations identified
# entities: Johann Schmidt => Col. Chester Phillips-[u'he', u'his', u'His', u'he', u'his']
# relation: Hitler speaks of a thousand year Reich, but he cannot feed his army for month. His troops spill their blood across every field in Europe. But he is still no closer to achieving his goals.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 372 ********
# 370. Steve Rogers:
# [annoyed, she turns and walks ahead] Agent Carter, wait.
#
# 371. Peggy Carter:
# Looks like finding a partner wasn't that hard after all.
#
# => 372. Steve Rogers:
# => Peggy, that's not what you thought it was.
#
# 373. Peggy Carter:
# I don't think anything, Captain. Not one thing. You always wanted to be soldier and now you are. Just like all the rest.
#
# 374. Steve Rogers:
# Well, what about you and Stark? How do I know you two haven't been...fonduing?
#
# ******** test model 1: line 372 ********
# 1 relations identified
# entities: Steve Rogers => Peggy Carter-[u'Peggy', u'you']
# relation: Peggy, that's not what you thought it was.
# category: 1. negative mentioning
#
# how many are correctly identified? 1
#
# ******** line 134 ********
# 132. Steve Rogers:
# Where are you from?
#
# 133. Dr. Abraham Erskine:
# Queens. 73rd Street and Utopia Parkway. Before that, Germany. This troubles you?  [Steve shakes his head]
#
# => 134. Dr. Abraham Erskine:
# => [flipping through Steve's file] Where are you from Mr. Rogers? Mmm? Is it New Haven? Or Paramus? Five exams in five different cities.
#
# 135. Steve Rogers:
# That might not be the right file.
#
# 136. Dr. Abraham Erskine:
# No, it's not the exams I'm interested in. It's the five tries. But you didn't answer my question. Do you want to kill Nazis?
#
# ******** test model 1: line 134 ********
# 1 relations identified
# entities: Steve Rogers => Steve Rogers-[u'Rogers', u'Mr.', u'you']
# relation: character Steve Rogers has identity of Mr.
# category: 3. identity mentioning
#
# how many are correctly identified? 1
#
# ******** line 139 ********
# 137. Steve Rogers:
# Is this a test?
#
# 138. Dr. Abraham Erskine:
# Yes.
#
# => 139. Steve Rogers:
# => I don't wanna kill anyone. I don't like bullies. I don't care where they're from.
#
# 140. Dr. Abraham Erskine:
# Well, there are already so many big men fighting this war. Maybe what we need now is the little guy, huh? I can offer you a chance.
#
# 141. narrator:
# They exit the room
#
# ******** test model 1: line 139 ********
# 4 relations identified
# entities: Steve Rogers => Col. Chester Phillips-[u'they']
# relation: I don't wanna kill anyone. I don't like bullies. I don't care where they're from.
# category: 4. mixed mentioning
# entities: Steve Rogers => Peggy Carter-[u'they']
# relation: I don't wanna kill anyone. I don't like bullies. I don't care where they're from.
# category: 4. mixed mentioning
# entities: Steve Rogers => Johann Schmidt-[u'they']
# relation: I don't wanna kill anyone. I don't like bullies. I don't care where they're from.
# category: 4. mixed mentioning
# entities: Steve Rogers => Dr. Arnim Zola-[u'they']
# relation: I don't wanna kill anyone. I don't like bullies. I don't care where they're from.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 393 ********
# 391. Johann Schmidt:
# You are failing! We are close to and offensive network that will shake the planet. And yet we are continually delayed, because you cannot outwit a simpleton with a shield!
#
# 392. Dr. Arnim Zola:
# This is hardly my area of expertise! I...I merely develop the weapons. I...I cannot fire them.
#
# => 393. Johann Schmidt:
# => Finish your mission, doctor. Before the American finishes his. [Phillips brings a tray of food to Zola after he's been captured and imprisoned]
#
# 394. Dr. Arnim Zola:
# What is this?
#
# 395. Col. Chester Phillips:
# Steak.
#
# ******** test model 1: line 393 ********
# 2 relations identified
# entities: American => Peggy Carter-None
# relation:  finishes
# category: 5. place mentioning
# entities: American => tray-None
# relation:  brings a
# category: 5. place mentioning
#
# how many are correctly identified? 0
#
# ******** line 167 ********
# 165. narrator:
# Col.Phillips drives up
#
# 166. Col. Chester Phillips:
# Agent Carter.
#
# => 167. Peggy Carter:
# => Colonel Phillips.
#
# 168. Col. Chester Phillips:
# I see you're roughening up our men, that's good. [to Hodge] Pick your ass out of the dirt, soldier.
#
# 169. Gilmore Hodge:
# Yes, sir.
#
# ******** test model 1: line 167 ********
# 1 relations identified
# entities: Col. Chester Phillips => Col. Chester Phillips-[u'Phillips', u'Colonel']
# relation: character Col. Chester Phillips has identity of Colonel
# category: 3. identity mentioning
#
# how many are correctly identified? 1
#
# ******** line 464 ********
# 462. Steve Rogers:
# [he looks at her suspiciously] Where am I really?
#
# 463. SHIELD Agent:
# I'm afraid I don't understand.
#
# => 464. Steve Rogers:
# => The game, it's from May, nineteen forty one. I know, cause I was there. [he gets up from the bed] Now, I'm gonna ask you again. Where am I?
#
# 465. SHIELD Agent:
# Captain Rogers?
#
# 466. Steve Rogers:
# Who are you? [two soldiers in black uniform enter the room and Steve knocks them through the wall]
#
# ******** test model 1: line 464 ********
# 2 relations identified
# entities: Steve Rogers => Peggy Carter-[u'he']
# relation: The game, it's from May, nineteen forty one. I know, cause I was there. [he gets up from the bed] Now, I'm gonna ask you again. Where am I?
# category: 4. mixed mentioning
# entities: Steve Rogers => SHIELD Agent-[u'you']
# relation: The game, it's from May, nineteen forty one. I know, cause I was there. [he gets up from the bed] Now, I'm gonna ask you again. Where am I?
# category: 4. mixed mentioning
#
# how many are correctly identified? 0
#
# ******** line 249 ********
# 247. Johann Schmidt:
# Hitler speaks of a thousand year Reich, but he cannot feed his army for month. His troops spill their blood across every field in Europe. But he is still no closer to achieving his goals.
#
# 248. Roeder:
# And I suppose you still aim to end this war through magic?
#
# => 249. Johann Schmidt:
# => Science. But I understand your confusion. Great power has always baffled primitive men. Hydra is assembling an arsenal to destroy my enemies in one stroke. Where ever they are, regardless of how many forces they possess. All in a matter of hours.
#
# 250. Roeder:
# Your enemies?
#
# 251. Johann Schmidt:
# My weapons contain enough destructive power to decimate every hostile capital on earth. Quite simply, gentlemen, I have harnessed the power of the Gods.
#
# ******** test model 1: line 249 ********
# 5 relations identified
# entities: Johann Schmidt => Roeder-[u'your']
# relation: Science. But I understand your confusion. Great power has always baffled primitive men. Hydra is assembling an arsenal to destroy my enemies in one stroke. Where ever they are, regardless of how many forces they possess. All in a matter of hours.
# category: 4. mixed mentioning
# entities: Johann Schmidt => Col. Chester Phillips-[u'they', u'they']
# relation: Science. But I understand your confusion. Great power has always baffled primitive men. Hydra is assembling an arsenal to destroy my enemies in one stroke. Where ever they are, regardless of how many forces they possess. All in a matter of hours.
# category: 4. mixed mentioning
# entities: Johann Schmidt => Peggy Carter-[u'they', u'they']
# relation: Science. But I understand your confusion. Great power has always baffled primitive men. Hydra is assembling an arsenal to destroy my enemies in one stroke. Where ever they are, regardless of how many forces they possess. All in a matter of hours.
# category: 4. mixed mentioning
# entities: Johann Schmidt => Gabe Jones-[u'they', u'they']
# relation: Science. But I understand your confusion. Great power has always baffled primitive men. Hydra is assembling an arsenal to destroy my enemies in one stroke. Where ever they are, regardless of how many forces they possess. All in a matter of hours.
# category: 4. mixed mentioning
# entities: Johann Schmidt => James Barnes-[u'they', u'they']
# relation: Science. But I understand your confusion. Great power has always baffled primitive men. Hydra is assembling an arsenal to destroy my enemies in one stroke. Where ever they are, regardless of how many forces they possess. All in a matter of hours.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 423 ********
# 421. Peggy Carter:
# Yes.
#
# 422. Steve Rogers:
# Then you know that's not true.
#
# => 423. Peggy Carter:
# => You did everything you could. Did you believe in your friend? Did you respect him? [Steve looks at her as if to say yes] Then stop blaming yourself. Allow Barnes the dignity of his choice. He damn well must have thought you were worth it.
#
# 424. Steve Rogers:
# I'm goin' after Schmidt. I'm not gonna stop till all of Hydra is dead or captured.
#
# 425. Peggy Carter:
# You won't be alone. [the team prepare a battle plan to take down Red Skull at his headquarters]
#
# ******** test model 1: line 423 ********
# 5 relations identified
# entities: Peggy Carter => James Barnes-[u'Barnes']
# relation: You did everything you could. Did you believe in your friend? Did you respect him? [Steve looks at her as if to say yes] Then stop blaming yourself. Allow Barnes the dignity of his choice. He damn well must have thought you were worth it.
# category: 4. mixed mentioning
# entities: Peggy Carter => Steve Roger-[u'Steve']
# relation: You did everything you could. Did you believe in your friend? Did you respect him? [Steve looks at her as if to say yes] Then stop blaming yourself. Allow Barnes the dignity of his choice. He damn well must have thought you were worth it.
# category: 4. mixed mentioning
# entities: Peggy Carter => Steve Rogers-[u'You', u'you', u'you', u'your', u'you', u'yourself', u'you']
# relation: You did everything you could. Did you believe in your friend? Did you respect him? [Steve looks at her as if to say yes] Then stop blaming yourself. Allow Barnes the dignity of his choice. He damn well must have thought you were worth it.
# category: 4. mixed mentioning
# entities: Peggy Carter => 4F Doctor-[u'him', u'his', u'He']
# relation: You did everything you could. Did you believe in your friend? Did you respect him? [Steve looks at her as if to say yes] Then stop blaming yourself. Allow Barnes the dignity of his choice. He damn well must have thought you were worth it.
# category: 4. mixed mentioning
# entities: Peggy Carter => Col. Chester Phillips-[u'her']
# relation: You did everything you could. Did you believe in your friend? Did you respect him? [Steve looks at her as if to say yes] Then stop blaming yourself. Allow Barnes the dignity of his choice. He damn well must have thought you were worth it.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 271 ********
# 269. Brandt's Aide:
# Nothing to it. Sell off a few bonds, bonds buy bullets, bullets kills Nazi's. Bing bang boom. You're an American hero.
#
# 270. Steve Rogers:
# It's just now how I pictured getting there.
#
# => 271. Brandt's Aide:
# => The senator's got a lot of pull up on the hill. You play ball with us, you'll be leading your own platoon in no time. Take the shield. [as Steve puts on his head mask he pushes Steve onto the stage] [addressing a crowd of soldiers in Italy dressed in his super-hero costume]
#
# 272. Steve Rogers:
# How many of you ready to help me sock old Adolf on the jaw? [silence from the crowd of soldiers] Okay. Uh...I need in volunteer?
#
# 273. Army Heckler#1:
# I already volunteered! How do you think I got here? [the crowd of soldiers laugh] Bring back the girls! [there's a cheer from the soldiers]
#
# ******** test model 1: line 271 ********
# 5 relations identified
# entities: Brandt's Aide => Senator Brandt-[u'senator', u'us']
# relation: The senator's got a lot of pull up on the hill. You play ball with us, you'll be leading your own platoon in no time. Take the shield. [as Steve puts on his head mask he pushes Steve onto the stage] [addressing a crowd of soldiers in Italy dressed in his super-hero costume]
# category: 4. mixed mentioning
# entities: Brandt's Aide => Steve Roger-[u'Steve', u'Steve']
# relation: The senator's got a lot of pull up on the hill. You play ball with us, you'll be leading your own platoon in no time. Take the shield. [as Steve puts on his head mask he pushes Steve onto the stage] [addressing a crowd of soldiers in Italy dressed in his super-hero costume]
# category: 4. mixed mentioning
# entities: Brandt's Aide => Steve Rogers-[u'You', u'us', u'you', u'your']
# relation: The senator's got a lot of pull up on the hill. You play ball with us, you'll be leading your own platoon in no time. Take the shield. [as Steve puts on his head mask he pushes Steve onto the stage] [addressing a crowd of soldiers in Italy dressed in his super-hero costume]
# category: 4. mixed mentioning
# entities: Brandt's Aide => Army Heckler#2-[u'us']
# relation: The senator's got a lot of pull up on the hill. You play ball with us, you'll be leading your own platoon in no time. Take the shield. [as Steve puts on his head mask he pushes Steve onto the stage] [addressing a crowd of soldiers in Italy dressed in his super-hero costume]
# category: 4. mixed mentioning
# entities: Brandt's Aide => Johann Schmidt-[u'his', u'he', u'his']
# relation: The senator's got a lot of pull up on the hill. You play ball with us, you'll be leading your own platoon in no time. Take the shield. [as Steve puts on his head mask he pushes Steve onto the stage] [addressing a crowd of soldiers in Italy dressed in his super-hero costume]
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 294 ********
# 292. Col. Chester Phillips:
# Well, if it isn't the star spangled man with a plan. And what is your plan today?
#
# 293. Steve Rogers:
# I need the casualty list for Rosano.
#
# => 294. Col. Chester Phillips:
# => You don't get to give me orders, son.
#
# 295. Steve Rogers:
# I just need one name. Sergeant James Barnes from the hundred and seventh.
#
# 296. Col. Chester Phillips:
# [pointing to Peggy] You and I are gonna have a conversation later that you won't enjoy.
#
# ******** test model 1: line 294 ********
# 1 relations identified
# entities: Col. Chester Phillips => Steve Rogers-[u'You']
# relation: You don't get to give me orders, son.
# category: 1. negative mentioning
#
# how many are correctly identified? 1
#
# ******** line 391 ********
# 389. Steve Rogers:
# I had some ideas about the uniform.
#
# 390. Howard Stark:
# Whatever you want, pal.
#
# => 391. Johann Schmidt:
# => You are failing! We are close to and offensive network that will shake the planet. And yet we are continually delayed, because you cannot outwit a simpleton with a shield!
#
# 392. Dr. Arnim Zola:
# This is hardly my area of expertise! I...I merely develop the weapons. I...I cannot fire them.
#
# 393. Johann Schmidt:
# Finish your mission, doctor. Before the American finishes his. [Phillips brings a tray of food to Zola after he's been captured and imprisoned]
#
# ******** test model 1: line 391 ********
# 4 relations identified
# entities: that => planet-None
# relation:  shake the
# category: 5. place mentioning
# entities: Johann Schmidt => Howard Stark-[u'You', u'you']
# relation: You are failing! We are close to and offensive network that will shake the planet. And yet we are continually delayed, because you cannot outwit a simpleton with a shield!
# category: 1. negative mentioning
# entities: Johann Schmidt => Steve Rogers-[u'We', u'we']
# relation: You are failing! We are close to and offensive network that will shake the planet. And yet we are continually delayed, because you cannot outwit a simpleton with a shield!
# category: 1. negative mentioning
# entities: Johann Schmidt => Dr. Arnim Zola-[u'We', u'we']
# relation: You are failing! We are close to and offensive network that will shake the planet. And yet we are continually delayed, because you cannot outwit a simpleton with a shield!
# category: 1. negative mentioning
#
# how many are correctly identified? 3
#
# ******** line 106 ********
# 104. James Barnes:
# You really gonna do this again?
#
# 105. Steve Rogers:
# Well, it's a fair. I'm gonna try my luck.
#
# => 106. James Barnes:
# => As who? Steve from Ohio? They'll catch you. Or worse, they'll actually take you.
#
# 107. Steve Rogers:
# Look, I know you don't think I can do this.
#
# 108. James Barnes:
# This isn't a back alley, Steve. It's a war!
#
# ******** test model 1: line 106 ********
# 3 relations identified
# entities: James Barnes => Steve Roger-[u'Steve']
# relation: As who? Steve from Ohio? They'll catch you. Or worse, they'll actually take you.
# category: 4. mixed mentioning
# entities: James Barnes => Brandt's Aide-[u'They', u'they']
# relation: As who? Steve from Ohio? They'll catch you. Or worse, they'll actually take you.
# category: 4. mixed mentioning
# entities: James Barnes => Steve Rogers-[u'They', u'you', u'they', u'you']
# relation: As who? Steve from Ohio? They'll catch you. Or worse, they'll actually take you.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 296 ********
# 294. Col. Chester Phillips:
# You don't get to give me orders, son.
#
# 295. Steve Rogers:
# I just need one name. Sergeant James Barnes from the hundred and seventh.
#
# => 296. Col. Chester Phillips:
# => [pointing to Peggy] You and I are gonna have a conversation later that you won't enjoy.
#
# 297. Steve Rogers:
# Please tell me if he's alive, sir. B-A-R...
#
# 298. Col. Chester Phillips:
# I can spell. [referring to Barnes] I have signed more of these condolence letters today than I would care to count. But the name does sound familiar. I'm sorry.
#
# ******** test model 1: line 296 ********
# 2 relations identified
# entities: Col. Chester Phillips => Peggy Carter-[u'Peggy']
# relation: [pointing to Peggy] You and I are gonna have a conversation later that you won't enjoy.
# category: 1. negative mentioning
# entities: Col. Chester Phillips => Steve Rogers-[u'You', u'you']
# relation: [pointing to Peggy] You and I are gonna have a conversation later that you won't enjoy.
# category: 1. negative mentioning
#
# how many are correctly identified? 1
#
# ******** line 116 ********
# 114. James Barnes:
# Why not?
#
# 115. Steve Rogers:
# I'm not gonna sit in a factory, Bucky. Bucky, come on! There are men laying down their lives. I got no right to do any less than them. That's what you don't understand. This isn't about me.
#
# => 116. James Barnes:
# => Right. Cause you got nothing to prove. Don't do anything stupid until I get back.
#
# 117. Steve Rogers:
# How can I? You're taking all the stupid with you.
#
# 118. James Barnes:
# You're a punk.
#
# ******** test model 1: line 116 ********
# 1 relations identified
# entities: James Barnes => Steve Rogers-[u'you']
# relation: Right. Cause you got nothing to prove. Don't do anything stupid until I get back.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** test results ********
# model 1: precision = 0.35 (19/55 correct)

# %%
df_dict['df_4']['relations'] = df_dict['df_4'].apply(lambda x:
                                                     extract_relation_categories(char_list_dict['cList_4'], x), axis=1)
REEval([df_dict['df_4']], 20)
#0.41 28/68
# Out:
# ******** line 610 ********
# 608. Senator Stern:
# Listen, I gotta fly home tonight, cause uh...I got some constituency problem, and I gotta press the flesh.
#
# 609. Jasper Sitwell:
# Any constituent in particular, Mr. Senator?
#
# => 610. Senator Stern:
# => Uh...no, not really. Twenty-three, kind of hot. Real hot. You know, wants to be a reporter, I think. I don't know, who listens at that point?
#
# 611. Jasper Sitwell:
# Doesn't sound much of a problem to me.
#
# 612. Senator Stern:
# Really? Cause she's killing my back. Look, this isn't the place to talk about it. [he touches Sitwell's pin on his jacket] That's a nice pin.
#
# ******** test model 1: line 610 ********
# 1 relations identified
# entities: Senator Stern => Jasper Sitwell-[u'You']
# relation: Uh...no, not really. Twenty-three, kind of hot. Real hot. You know, wants to be a reporter, I think. I don't know, who listens at that point?
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 70 ********
# 68. narrator:
# he pulls up Sitwell's photo on the monitor
#
# 69. Brock Rumlow:
# They're in the galley.
#
# => 70. Steve Rogers:
# => What's Sitwell doing on a launch ship? Alright, I'm gonna sweep the deck and find Batroc. Nat, you'll kill the engines and wait for instructions. Rumlow, you sweep aft, find the hostages, get them to life pods. get 'em out. Let's go.
#
# 71. Brock Rumlow:
# STRIKE, you heard the Captain. Gear up!
#
# 72. narrator:
# as they are getting ready to dive off the jet; into his radio
#
# ******** test model 1: line 70 ********
# 5 relations identified
# entities: Steve Rogers => Jasper Sitwell-[u'Sitwell']
# relation: What's Sitwell doing on a launch ship? Alright, I'm gonna sweep the deck and find Batroc. Nat, you'll kill the engines and wait for instructions. Rumlow, you sweep aft, find the hostages, get them to life pods. get 'em out. Let's go.
# category: 4. mixed mentioning
# entities: Steve Rogers => Georges Batroc-[u'Batroc']
# relation: What's Sitwell doing on a launch ship? Alright, I'm gonna sweep the deck and find Batroc. Nat, you'll kill the engines and wait for instructions. Rumlow, you sweep aft, find the hostages, get them to life pods. get 'em out. Let's go.
# category: 4. mixed mentioning
# entities: Steve Rogers => Natasha Romanoff-[u'Nat', u'them']
# relation: What's Sitwell doing on a launch ship? Alright, I'm gonna sweep the deck and find Batroc. Nat, you'll kill the engines and wait for instructions. Rumlow, you sweep aft, find the hostages, get them to life pods. get 'em out. Let's go.
# category: 4. mixed mentioning
# entities: Steve Rogers => Brock Rumlow-[u'Rumlow', u'you', u'you']
# relation: What's Sitwell doing on a launch ship? Alright, I'm gonna sweep the deck and find Batroc. Nat, you'll kill the engines and wait for instructions. Rumlow, you sweep aft, find the hostages, get them to life pods. get 'em out. Let's go.
# category: 4. mixed mentioning
# entities: Steve Rogers => Councilman Singh-[u'them']
# relation: What's Sitwell doing on a launch ship? Alright, I'm gonna sweep the deck and find Batroc. Nat, you'll kill the engines and wait for instructions. Rumlow, you sweep aft, find the hostages, get them to life pods. get 'em out. Let's go.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 415 ********
# 413. Steve Rogers:
# If you really knew Nick Fury you know that's not true.
#
# 414. Alexander Pierce:
# Why do you think we're talking? See, I took a seat on the Council not because I wanted to but because Nick asked me to, because we were both realists. We knew that despite all the diplomacy and the handshaking and the rhetoric, that to build a really better world sometimes means having to tear the old one down. And that makes enemies. Those people that call you dirty because you got the guts to stick your hands in the mud and try to build something better. And the idea that those people could be happy today, makes me really, really angry. [he hesitates a moment] Captain, you were the last one to see Nick alive. I don't think that's an accident, and I don't think you do either. So I'm gonna ask again, why was he there?
#
# => 415. Steve Rogers:
# => He told me not to trust anyone.
#
# 416. Alexander Pierce:
# I wonder if that included him. [Steve pauses a moment before replying]
#
# 417. Steve Rogers:
# I'm sorry. Those were his last words. Excuse me. [Steve picks up his shield, places it on his back and starts to make his out of the office]
#
# ******** test model 1: line 415 ********
# 1 relations identified
# entities: Steve Rogers => Natasha Romanoff-[u'He']
# relation: He told me not to trust anyone.
# category: 1. negative mentioning
#
# how many are correctly identified? 1
#
# ******** line 855 ********
# 853. Steve Rogers:
# Bucky, you've known me your whole life. [Bucky hits Steve but Steve chooses not to fight back]
#
# 854. Bucky Barnes:
# No, I don't!
#
# => 855. Steve Rogers:
# => Bucky, you've known me your whole life. [Bucky hits Steve but Steve chooses not to fight back] Your name is James Buchanan Barnes. [Bucky hits Steve again]
#
# 856. Bucky Barnes:
# Shut up! [Steve takes off his mask and drops his shield out of the Helicarrier]
#
# 857. Steve Rogers:
# I'm not gonna fight you. You're my friend. [Bucky pushes Steve to the ground]
#
# ******** test model 1: line 855 ********
# 2 relations identified
# entities: Steve Rogers => Steve Wilson-[u'Steve', u'Steve', u'Steve']
# relation: Bucky, you've known me your whole life. [Bucky hits Steve but Steve chooses not to fight back] Your name is James Buchanan Barnes. [Bucky hits Steve again]
# category: 4. mixed mentioning
# entities: Steve Rogers => Bucky Barnes-[u'you', u'your', u'Your']
# relation: Bucky, you've known me your whole life. [Bucky hits Steve but Steve chooses not to fight back] Your name is James Buchanan Barnes. [Bucky hits Steve again]
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 482 ********
# 480. Natasha Romanoff:
# Uh...about nine minutes from... [she pops the flash drive into a MacBook Pro] Now. [we see several SHIELD vehicles heading their way] Fury was right about that ship, somebody's trying to hide something. This drive is protected by some sort of AI, it keeps rewriting itself to counter my commands.
#
# 481. Steve Rogers:
# Can you override it?
#
# => 482. Natasha Romanoff:
# => The person who developed this is slightly smarter than me. Slightly. [Rumlow and his team pull up outside the mall and head inside] [back at the Mac store, Steve and Natasha continue to try and find out what's on the flash drive] I'm gonna try running a tracer. This is a program that SHIELD developed to track hostile malware, so if we can't read the file, maybe we can find out where it came from.
#
# 483. Apple Employee:
# Can I help you guys with anything?
#
# 484. Natasha Romanoff:
# Oh, no. My fiancé was just helping me with some honeymoon destinations.
#
# ******** test model 1: line 482 ********
# 4 relations identified
# entities: Natasha Romanoff => Brock Rumlow-[u'Rumlow']
# relation: The person who developed this is slightly smarter than me. Slightly. [Rumlow and his team pull up outside the mall and head inside] [back at the Mac store, Steve and Natasha continue to try and find out what's on the flash drive] I'm gonna try running a tracer. This is a program that SHIELD developed to track hostile malware, so if we can't read the file, maybe we can find out where it came from.
# category: 4. mixed mentioning
# entities: Natasha Romanoff => Steve Wilson-[u'Steve']
# relation: The person who developed this is slightly smarter than me. Slightly. [Rumlow and his team pull up outside the mall and head inside] [back at the Mac store, Steve and Natasha continue to try and find out what's on the flash drive] I'm gonna try running a tracer. This is a program that SHIELD developed to track hostile malware, so if we can't read the file, maybe we can find out where it came from.
# category: 4. mixed mentioning
# entities: Natasha Romanoff => Steve Rogers-[u'his', u'we', u'we']
# relation: The person who developed this is slightly smarter than me. Slightly. [Rumlow and his team pull up outside the mall and head inside] [back at the Mac store, Steve and Natasha continue to try and find out what's on the flash drive] I'm gonna try running a tracer. This is a program that SHIELD developed to track hostile malware, so if we can't read the file, maybe we can find out where it came from.
# category: 4. mixed mentioning
# entities: Natasha Romanoff => Apple Employee-[u'we', u'we']
# relation: The person who developed this is slightly smarter than me. Slightly. [Rumlow and his team pull up outside the mall and head inside] [back at the Mac store, Steve and Natasha continue to try and find out what's on the flash drive] I'm gonna try running a tracer. This is a program that SHIELD developed to track hostile malware, so if we can't read the file, maybe we can find out where it came from.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 899 ********
# 897. Baron Wolfgang von Strucker:
# The dead will be buried so deep their own ghosts won't be able to find them.
#
# 898. HYDRA Scientist:
# And the survivors?
#
# => 899. Baron Wolfgang von Strucker:
# => The twins. [we see the twins, Pietro and Wanda Maximoff, aka Quicksilver and Scarlet Witch, being kept in glass cells each exhibiting their powers, Pietro having superhuman speed and Wanda having telekinetic powers] Sooner or later they will meet the twins. It's not a world of spies anymore, not even a world of heroes. This is the age of miracles, doctor. There's nothing more horrifying than a miracle. [post-credits scene; at the Captain America exhibit in the Smithsonian Museum we see Bucky in civilian clothes staring pensively at the display about himself]
#
# ******** test model 1: line 899 ********
# 7 relations identified
# entities: Baron Wolfgang von Strucker => Bucky Barnes-[u'Bucky']
# relation: The twins. [we see the twins, Pietro and Wanda Maximoff, aka Quicksilver and Scarlet Witch, being kept in glass cells each exhibiting their powers, Pietro having superhuman speed and Wanda having telekinetic powers] Sooner or later they will meet the twins. It's not a world of spies anymore, not even a world of heroes. This is the age of miracles, doctor. There's nothing more horrifying than a miracle. [post-credits scene; at the Captain America exhibit in the Smithsonian Museum we see Bucky in civilian clothes staring pensively at the display about himself]
# category: 4. mixed mentioning
# entities: Baron Wolfgang von Strucker => Doctor-[u'doctor']
# relation: The twins. [we see the twins, Pietro and Wanda Maximoff, aka Quicksilver and Scarlet Witch, being kept in glass cells each exhibiting their powers, Pietro having superhuman speed and Wanda having telekinetic powers] Sooner or later they will meet the twins. It's not a world of spies anymore, not even a world of heroes. This is the age of miracles, doctor. There's nothing more horrifying than a miracle. [post-credits scene; at the Captain America exhibit in the Smithsonian Museum we see Bucky in civilian clothes staring pensively at the display about himself]
# category: 4. mixed mentioning
# entities: Baron Wolfgang von Strucker => Sam Wilson-[u'we', u'we']
# relation: The twins. [we see the twins, Pietro and Wanda Maximoff, aka Quicksilver and Scarlet Witch, being kept in glass cells each exhibiting their powers, Pietro having superhuman speed and Wanda having telekinetic powers] Sooner or later they will meet the twins. It's not a world of spies anymore, not even a world of heroes. This is the age of miracles, doctor. There's nothing more horrifying than a miracle. [post-credits scene; at the Captain America exhibit in the Smithsonian Museum we see Bucky in civilian clothes staring pensively at the display about himself]
# category: 4. mixed mentioning
# entities: Baron Wolfgang von Strucker => HYDRA Scientist-[u'we', u'we']
# relation: The twins. [we see the twins, Pietro and Wanda Maximoff, aka Quicksilver and Scarlet Witch, being kept in glass cells each exhibiting their powers, Pietro having superhuman speed and Wanda having telekinetic powers] Sooner or later they will meet the twins. It's not a world of spies anymore, not even a world of heroes. This is the age of miracles, doctor. There's nothing more horrifying than a miracle. [post-credits scene; at the Captain America exhibit in the Smithsonian Museum we see Bucky in civilian clothes staring pensively at the display about himself]
# category: 4. mixed mentioning
# entities: Baron Wolfgang von Strucker => Steve Rogers-[u'we', u'we']
# relation: The twins. [we see the twins, Pietro and Wanda Maximoff, aka Quicksilver and Scarlet Witch, being kept in glass cells each exhibiting their powers, Pietro having superhuman speed and Wanda having telekinetic powers] Sooner or later they will meet the twins. It's not a world of spies anymore, not even a world of heroes. This is the age of miracles, doctor. There's nothing more horrifying than a miracle. [post-credits scene; at the Captain America exhibit in the Smithsonian Museum we see Bucky in civilian clothes staring pensively at the display about himself]
# category: 4. mixed mentioning
# entities: Baron Wolfgang von Strucker => Nick Fury-[u'they', u'himself']
# relation: The twins. [we see the twins, Pietro and Wanda Maximoff, aka Quicksilver and Scarlet Witch, being kept in glass cells each exhibiting their powers, Pietro having superhuman speed and Wanda having telekinetic powers] Sooner or later they will meet the twins. It's not a world of spies anymore, not even a world of heroes. This is the age of miracles, doctor. There's nothing more horrifying than a miracle. [post-credits scene; at the Captain America exhibit in the Smithsonian Museum we see Bucky in civilian clothes staring pensively at the display about himself]
# category: 4. mixed mentioning
# entities: Baron Wolfgang von Strucker => Natasha Romanoff-[u'they']
# relation: The twins. [we see the twins, Pietro and Wanda Maximoff, aka Quicksilver and Scarlet Witch, being kept in glass cells each exhibiting their powers, Pietro having superhuman speed and Wanda having telekinetic powers] Sooner or later they will meet the twins. It's not a world of spies anymore, not even a world of heroes. This is the age of miracles, doctor. There's nothing more horrifying than a miracle. [post-credits scene; at the Captain America exhibit in the Smithsonian Museum we see Bucky in civilian clothes staring pensively at the display about himself]
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 506 ********
# 504. Natasha Romanoff:
# Public displays of affection make people very uncomfortable.
#
# 505. Steve Rogers:
# Yes, they do. [she quickly pulls down Steve's head and kisses him making Rumlow look away as he goes past them on the escalator]
#
# => 506. Natasha Romanoff:
# => You still uncomfortable?
#
# 507. Steve Rogers:
# It's not exactly the word I would use. [as they drive to New Jersey]
#
# 508. Natasha Romanoff:
# Where did Captain America learn how to steal a car?
#
# ******** test model 1: line 506 ********
# 1 relations identified
# entities: Natasha Romanoff => Steve Rogers-[u'You']
# relation: You still uncomfortable?
# category: 1. negative mentioning
#
# how many are correctly identified? 1
#
# ******** line 812 ********
# 810. Maria Hill:
# Rumlow's headed for the Council.
#
# 811. Sam Wilson:
# I'm on it. [inside the Helicarrier Steve is confronted by Bucky]
#
# => 812. Steve Rogers:
# => People are gonna die, Buck. I can't let that happen. [Bucky stares at him coldly] Please, don't make me do this. [seeing Bucky won't back down Steve throws his shield at him and they start battling each other, as they fight Steve manages to bring up the targeting blade system, but as Bucky attacks him the chip falls from Steve's hand; back at the Council]
#
# 813. Natasha Romanoff:
# Done. [she looks at her mobile device] And it's trending. [just them Pierce sets off the pins he gave the council members, causing it to burn deeply into their sternum, Natasha and Fury points their guns at Pierce; to Natasha]
#
# 814. Alexander Pierce:
# Unless you want two inch hole in your sternum, I'd put that gun down. [Natasha doesn't back down] That was armed the moment you pinned it on. [Fury and Natasha reluctantly lower their weapons] [back at the Helicarrier as they are battling it out, Bucky stabs Steve in the shoulder with his knife and then grabs the fallen chip, but Steve manages to get the knife out, grab Bucky by the throat and hold him down]
#
# ******** test model 1: line 812 ********
# 5 relations identified
# entities: Steve Rogers => Bucky Barnes-[u'Bucky', u'Bucky', u'Bucky']
# relation: People are gonna die, Buck. I can't let that happen. [Bucky stares at him coldly] Please, don't make me do this. [seeing Bucky won't back down Steve throws his shield at him and they start battling each other, as they fight Steve manages to bring up the targeting blade system, but as Bucky attacks him the chip falls from Steve's hand; back at the Council]
# category: 4. mixed mentioning
# entities: Steve Rogers => Steve Wilson-[u'Steve', u'Steve', u'Steve', u'they', u'they']
# relation: People are gonna die, Buck. I can't let that happen. [Bucky stares at him coldly] Please, don't make me do this. [seeing Bucky won't back down Steve throws his shield at him and they start battling each other, as they fight Steve manages to bring up the targeting blade system, but as Bucky attacks him the chip falls from Steve's hand; back at the Council]
# category: 4. mixed mentioning
# entities: Steve Rogers => Bucky Barnes-[u'Buck']
# relation: People are gonna die, Buck. I can't let that happen. [Bucky stares at him coldly] Please, don't make me do this. [seeing Bucky won't back down Steve throws his shield at him and they start battling each other, as they fight Steve manages to bring up the targeting blade system, but as Bucky attacks him the chip falls from Steve's hand; back at the Council]
# category: 4. mixed mentioning
# entities: Steve Rogers => Alexander Pierce-[u'him', u'his', u'him', u'him']
# relation: People are gonna die, Buck. I can't let that happen. [Bucky stares at him coldly] Please, don't make me do this. [seeing Bucky won't back down Steve throws his shield at him and they start battling each other, as they fight Steve manages to bring up the targeting blade system, but as Bucky attacks him the chip falls from Steve's hand; back at the Council]
# category: 4. mixed mentioning
# entities: Steve Rogers => Nick Fury-[u'they', u'they']
# relation: People are gonna die, Buck. I can't let that happen. [Bucky stares at him coldly] Please, don't make me do this. [seeing Bucky won't back down Steve throws his shield at him and they start battling each other, as they fight Steve manages to bring up the targeting blade system, but as Bucky attacks him the chip falls from Steve's hand; back at the Council]
# category: 4. mixed mentioning
#
# how many are correctly identified? 2
#
# ******** line 414 ********
# 412. Alexander Pierce:
# Well the prevailing theory was that the hijacking was a cover for the acquisition and sale of classified intelligence. The sale went sour and that led to Nick's death.
#
# 413. Steve Rogers:
# If you really knew Nick Fury you know that's not true.
#
# => 414. Alexander Pierce:
# => Why do you think we're talking? See, I took a seat on the Council not because I wanted to but because Nick asked me to, because we were both realists. We knew that despite all the diplomacy and the handshaking and the rhetoric, that to build a really better world sometimes means having to tear the old one down. And that makes enemies. Those people that call you dirty because you got the guts to stick your hands in the mud and try to build something better. And the idea that those people could be happy today, makes me really, really angry. [he hesitates a moment] Captain, you were the last one to see Nick alive. I don't think that's an accident, and I don't think you do either. So I'm gonna ask again, why was he there?
#
# 415. Steve Rogers:
# He told me not to trust anyone.
#
# 416. Alexander Pierce:
# I wonder if that included him. [Steve pauses a moment before replying]
#
# ******** test model 1: line 414 ********
# 6 relations identified
# entities: Alexander Pierce => Nick Fury-[u'Nick', u'Nick']
# relation: Why do you think we're talking? See, I took a seat on the Council not because I wanted to but because Nick asked me to, because we were both realists. We knew that despite all the diplomacy and the handshaking and the rhetoric, that to build a really better world sometimes means having to tear the old one down. And that makes enemies. Those people that call you dirty because you got the guts to stick your hands in the mud and try to build something better. And the idea that those people could be happy today, makes me really, really angry. [he hesitates a moment] Captain, you were the last one to see Nick alive. I don't think that's an accident, and I don't think you do either. So I'm gonna ask again, why was he there?
# category: 4. mixed mentioning
# entities: Alexander Pierce => Steve Rogers-[u'you', u'we', u'we', u'We', u'you', u'you', u'your', u'you', u'you']
# relation: Why do you think we're talking? See, I took a seat on the Council not because I wanted to but because Nick asked me to, because we were both realists. We knew that despite all the diplomacy and the handshaking and the rhetoric, that to build a really better world sometimes means having to tear the old one down. And that makes enemies. Those people that call you dirty because you got the guts to stick your hands in the mud and try to build something better. And the idea that those people could be happy today, makes me really, really angry. [he hesitates a moment] Captain, you were the last one to see Nick alive. I don't think that's an accident, and I don't think you do either. So I'm gonna ask again, why was he there?
# category: 4. mixed mentioning
# entities: Alexander Pierce => STRIKE Agent #1-[u'we', u'we', u'We']
# relation: Why do you think we're talking? See, I took a seat on the Council not because I wanted to but because Nick asked me to, because we were both realists. We knew that despite all the diplomacy and the handshaking and the rhetoric, that to build a really better world sometimes means having to tear the old one down. And that makes enemies. Those people that call you dirty because you got the guts to stick your hands in the mud and try to build something better. And the idea that those people could be happy today, makes me really, really angry. [he hesitates a moment] Captain, you were the last one to see Nick alive. I don't think that's an accident, and I don't think you do either. So I'm gonna ask again, why was he there?
# category: 4. mixed mentioning
# entities: Alexander Pierce => Brock Rumlow-[u'we', u'we', u'We']
# relation: Why do you think we're talking? See, I took a seat on the Council not because I wanted to but because Nick asked me to, because we were both realists. We knew that despite all the diplomacy and the handshaking and the rhetoric, that to build a really better world sometimes means having to tear the old one down. And that makes enemies. Those people that call you dirty because you got the guts to stick your hands in the mud and try to build something better. And the idea that those people could be happy today, makes me really, really angry. [he hesitates a moment] Captain, you were the last one to see Nick alive. I don't think that's an accident, and I don't think you do either. So I'm gonna ask again, why was he there?
# category: 4. mixed mentioning
# entities: Alexander Pierce => STRIKE Agent #2-[u'we', u'we', u'We']
# relation: Why do you think we're talking? See, I took a seat on the Council not because I wanted to but because Nick asked me to, because we were both realists. We knew that despite all the diplomacy and the handshaking and the rhetoric, that to build a really better world sometimes means having to tear the old one down. And that makes enemies. Those people that call you dirty because you got the guts to stick your hands in the mud and try to build something better. And the idea that those people could be happy today, makes me really, really angry. [he hesitates a moment] Captain, you were the last one to see Nick alive. I don't think that's an accident, and I don't think you do either. So I'm gonna ask again, why was he there?
# category: 4. mixed mentioning
# entities: Alexander Pierce => French Pirate #2-[u'he', u'he']
# relation: Why do you think we're talking? See, I took a seat on the Council not because I wanted to but because Nick asked me to, because we were both realists. We knew that despite all the diplomacy and the handshaking and the rhetoric, that to build a really better world sometimes means having to tear the old one down. And that makes enemies. Those people that call you dirty because you got the guts to stick your hands in the mud and try to build something better. And the idea that those people could be happy today, makes me really, really angry. [he hesitates a moment] Captain, you were the last one to see Nick alive. I don't think that's an accident, and I don't think you do either. So I'm gonna ask again, why was he there?
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 868 ********
# 866. Committee General:
# Many of which you seem to have had a personal hand in telling.
#
# 867. Scudder:
# Agent, you should know that there are some on this committee who feel, given your service record, both for this country and against it, that you belong in a penitentiary, not mouthing off on Capitol Hill.
#
# => 868. Natasha Romanoff:
# => You're not gonna put me in a prison. You're not gonna put any of us in a prison. You know why?
#
# 869. Scudder:
# Do enlighten us.
#
# 870. Natasha Romanoff:
# Because you need us. Yes, the world is a vulnerable place, and yes, we helped make it that way. But we're also the ones best qualified to defend it. So if you want to arrest me, arrest me. You'll know where to find me. [she gets up and walks away, meanwhile Fury gets rid of any trace of his existence, including his passports and eyepatch, burning them and his hiding place]
#
# ******** test model 1: line 868 ********
# 3 relations identified
# entities: Natasha Romanoff => Scudder-[u'You', u'You', u'You']
# relation: You're not gonna put me in a prison. You're not gonna put any of us in a prison. You know why?
# category: 4. mixed mentioning
# entities: Natasha Romanoff => Bucky Barnes-[u'us']
# relation: You're not gonna put me in a prison. You're not gonna put any of us in a prison. You know why?
# category: 4. mixed mentioning
# entities: Natasha Romanoff => Committee General-[u'us']
# relation: You're not gonna put me in a prison. You're not gonna put any of us in a prison. You know why?
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 341 ********
# 339. Sharon Carter:
# Well hopefully not too far. [Steve nods and turns to go into his apartment] Oh, and I think you left your stereo on.
#
# 340. Steve Rogers:
# Oh. Right, thank you.
#
# => 341. Sharon Carter:
# => Yeah. [Steve watches her go down the stairs before turning in suspicion to his door] [Steve hears music as he cautiously enters his apartment though the window, he grabs his shield for protection and finds Fury sitting on his couch in the dark]
#
# 342. Steve Rogers:
# I don't remember giving you a key.
#
# 343. Nick Fury:
# You really think I'd need one? My wife kicked me out.
#
# ******** test model 1: line 341 ********
# 1 relations identified
# entities: Natasha Romanoff => apartment-None
# relation:  enters his
# category: 5. place mentioning
#
# how many are correctly identified? 1
#
# ******** line 647 ********
# 645. Steve Rogers:
# I know. We'll use him to bypass the DNA scans and access the Helicarriers directly.
#
# 646. Jasper Sitwell:
# What?! Are you crazy? That is a terrible, terrible idea. [suddenly the Winter Soldier lands on the car roof, pulls Sitwell out through the window and throws him into the oncoming traffic, killing him, he then starts shooting at them until Steve pulls the break handle making the Winter Soldier drop down onto the street, as another car smashes into the trio's car and pushes them along, the Winter Soldier jumps back onto their car, smashes through the windscreen and pulls out the steering wheel]
#
# => 647. Sam Wilson:
# => Shit! [Natasha starts shooting at him but the Winter Soldier jumps onto the vehicle behind them, as the trio's car is being pulled off the road Steve holds on to the car door]
#
# 648. Steve Rogers:
# Hang on! [he breaks open the door, holding onto Natasha and Sam, they slide on the car door through the streets] [the Winter Soldier is joined by HYDRA agents and they start shooting at them, the trio scatter and run off in different directions with the Winter Soldier shooting at Natasha but she manages to shoot him in his eye goggle mask and run off]
#
# 649. Winter Soldier:
# [subtitled] I'll take care of her. Find him. [the Winter Soldier goes in pursuit of Natasha as the Hydra agents go after Steve and Sam who both manage to fend them off as they shoot at them, Steve then notices the Winter Soldier in pursuit of Natasha]
#
# ******** test model 1: line 647 ********
# 5 relations identified
# entities: Sam Wilson => Natasha Romanoff-[u'Natasha', u'them']
# relation: Shit! [Natasha starts shooting at him but the Winter Soldier jumps onto the vehicle behind them, as the trio's car is being pulled off the road Steve holds on to the car door]
# category: 4. mixed mentioning
# entities: Sam Wilson => Winter Soldier-[u'Winter Soldier']
# relation: Shit! [Natasha starts shooting at him but the Winter Soldier jumps onto the vehicle behind them, as the trio's car is being pulled off the road Steve holds on to the car door]
# category: 4. mixed mentioning
# entities: Sam Wilson => Steve Wilson-[u'Steve']
# relation: Shit! [Natasha starts shooting at him but the Winter Soldier jumps onto the vehicle behind them, as the trio's car is being pulled off the road Steve holds on to the car door]
# category: 4. mixed mentioning
# entities: Sam Wilson => Baron Wolfgang von Strucker-[u'him']
# relation: Shit! [Natasha starts shooting at him but the Winter Soldier jumps onto the vehicle behind them, as the trio's car is being pulled off the road Steve holds on to the car door]
# category: 4. mixed mentioning
# entities: Sam Wilson => Doctor #2-[u'them']
# relation: Shit! [Natasha starts shooting at him but the Winter Soldier jumps onto the vehicle behind them, as the trio's car is being pulled off the road Steve holds on to the car door]
# category: 4. mixed mentioning
#
# how many are correctly identified? 2
#
# ******** line 698 ********
# 696. Maria Hill:
# One or two won't cut it. We need to link all three carriers for this to work, because if even one of those ships remains operational a whole lot of people are gonna die.
#
# 697. Nick Fury:
# We have to assume everyone aboard those carriers is HYDRA. We need to get pass them, insert the server blades, and maybe, just maybe, we can salvage what's left...
#
# => 698. Steve Rogers:
# => We're not salvaging anything. We're not just taking down the carriers, Nick, we're taking down SHIELD.
#
# 699. Nick Fury:
# SHIELD had nothing to do with it.
#
# 700. Steve Rogers:
# You gave me this mission, this is how it ends. SHIELD's been compromised, you've said so yourself. HYDRA was right under your nose and nobody noticed.
#
# ******** test model 1: line 698 ********
# 2 relations identified
# entities: Steve Rogers => Nick Fury-[u'Nick', u'We', u'We', u'we']
# relation: We're not salvaging anything. We're not just taking down the carriers, Nick, we're taking down SHIELD.
# category: 4. mixed mentioning
# entities: Steve Rogers => Bucky Barnes-[u'We', u'We', u'we']
# relation: We're not salvaging anything. We're not just taking down the carriers, Nick, we're taking down SHIELD.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 195 ********
# 193. Nick Fury:
# Once we get them in the air they never need to come down. Continuous suborbital flight courtesy of our new repulsor engines.
#
# 194. Steve Rogers:
# Stark?
#
# => 195. Nick Fury:
# => Well, he had a few suggestions once he got an up close look at our old turbines. These new long range precision guns can eliminate a thousand hostiles a minute. The satellites can read a terrorist's DNA before he steps outside his spider hole. We gonna neutralize a lot of threats before they even happen.
#
# 196. Steve Rogers:
# I thought the punishment usually came after the crime.
#
# 197. Nick Fury:
# We can't afford to wait that long.
#
# ******** test model 1: line 195 ********
# 5 relations identified
# entities: Nick Fury => Natasha Romanoff-[u'he', u'he', u'he', u'his', u'they']
# relation: Well, he had a few suggestions once he got an up close look at our old turbines. These new long range precision guns can eliminate a thousand hostiles a minute. The satellites can read a terrorist's DNA before he steps outside his spider hole. We gonna neutralize a lot of threats before they even happen.
# category: 4. mixed mentioning
# entities: Nick Fury => Steve Rogers-[u'our', u'We']
# relation: Well, he had a few suggestions once he got an up close look at our old turbines. These new long range precision guns can eliminate a thousand hostiles a minute. The satellites can read a terrorist's DNA before he steps outside his spider hole. We gonna neutralize a lot of threats before they even happen.
# category: 4. mixed mentioning
# entities: Nick Fury => SHIELD Computer-[u'they']
# relation: Well, he had a few suggestions once he got an up close look at our old turbines. These new long range precision guns can eliminate a thousand hostiles a minute. The satellites can read a terrorist's DNA before he steps outside his spider hole. We gonna neutralize a lot of threats before they even happen.
# category: 4. mixed mentioning
# entities: Nick Fury => Councilman Rockwell-[u'they']
# relation: Well, he had a few suggestions once he got an up close look at our old turbines. These new long range precision guns can eliminate a thousand hostiles a minute. The satellites can read a terrorist's DNA before he steps outside his spider hole. We gonna neutralize a lot of threats before they even happen.
# category: 4. mixed mentioning
# entities: Nick Fury => Sam Wilson-[u'they']
# relation: Well, he had a few suggestions once he got an up close look at our old turbines. These new long range precision guns can eliminate a thousand hostiles a minute. The satellites can read a terrorist's DNA before he steps outside his spider hole. We gonna neutralize a lot of threats before they even happen.
# category: 4. mixed mentioning
#
# how many are correctly identified? 2
#
# ******** line 351 ********
# 349. Nick Fury:
# Just...my friends.
#
# 350. Steve Rogers:
# Is that what we are?
#
# => 351. Nick Fury:
# => That's up to you. [suddenly Fury is shot three times from through the window and collapses, Steve looks out the window for the shooter then he quickly drags Fury to the next room, before he leaves Fury hands him the flash drive] Don't...trust anyone. [Fury passes out] [Steve hears someone breaking into his apartment and hears his neighbor calling out to him]
#
# 352. Sharon Carter:
# Captain Rogers? [Steve sees her walking in with her gun pointed] Captain, I'm Agent 13 of SHIELD's Special Service.
#
# 353. Steve Rogers:
# Kate?
#
# ******** test model 1: line 351 ********
# 4 relations identified
# entities: Nick Fury => Steve Wilson-[u'Steve', u'Steve']
# relation: That's up to you. [suddenly Fury is shot three times from through the window and collapses, Steve looks out the window for the shooter then he quickly drags Fury to the next room, before he leaves Fury hands him the flash drive] Don't...trust anyone. [Fury passes out] [Steve hears someone breaking into his apartment and hears his neighbor calling out to him]
# category: 4. mixed mentioning
# entities: Nick Fury => Fury's Car-[u'Fury', u'Fury', u'Fury', u'Fury']
# relation: That's up to you. [suddenly Fury is shot three times from through the window and collapses, Steve looks out the window for the shooter then he quickly drags Fury to the next room, before he leaves Fury hands him the flash drive] Don't...trust anyone. [Fury passes out] [Steve hears someone breaking into his apartment and hears his neighbor calling out to him]
# category: 4. mixed mentioning
# entities: Nick Fury => Sharon Carter-[u'you']
# relation: That's up to you. [suddenly Fury is shot three times from through the window and collapses, Steve looks out the window for the shooter then he quickly drags Fury to the next room, before he leaves Fury hands him the flash drive] Don't...trust anyone. [Fury passes out] [Steve hears someone breaking into his apartment and hears his neighbor calling out to him]
# category: 4. mixed mentioning
# entities: Nick Fury => Sam Wilson-[u'he', u'he', u'him', u'his', u'his', u'him']
# relation: That's up to you. [suddenly Fury is shot three times from through the window and collapses, Steve looks out the window for the shooter then he quickly drags Fury to the next room, before he leaves Fury hands him the flash drive] Don't...trust anyone. [Fury passes out] [Steve hears someone breaking into his apartment and hears his neighbor calling out to him]
# category: 4. mixed mentioning
#
# how many are correctly identified? 2
#
# ******** line 847 ********
# 845. Natasha Romanoff:
# Sam, where are you?
#
# 846. Sam Wilson:
# 41st floor, north-west corner!
#
# => 847. Natasha Romanoff:
# => We're on it, stay where you are. [Sam desperately tries to get away from the destruction the Helicarrier is causing the building] Not an option! [as the building is being destroyed Sam jumps out of the window as Natasha and Fury fly their chopper in time to catch him]
#
# 848. Sam Wilson:
# 41st floor! 41st!
#
# 849. Nick Fury:
# It's not like they put the floor numbers on the outside of the building!
#
# ******** test model 1: line 847 ********
# 2 relations identified
# entities: Helicarrier => building-None
# relation:  causing the
# category: 5. place mentioning
# entities: Helicarrier => building-None
# relation:  causing the
# category: 5. place mentioning
#
# how many are correctly identified? 2
#
# ******** line 888 ********
# 886. Natasha Romanoff:
# And you're not a SHIELD agent.
#
# 887. Steve Rogers:
# What was her name again?
#
# => 888. Natasha Romanoff:
# => Sharon. She's nice. [she kisses Steve on the cheek and turns to walk away] Be careful, Steve. You might not want to pull on that thread. [as Natasha walks away Steve opens the file, which is about Bucky and the information regarding his Winter Soldier transformation, Sam walks over to Steve]
#
# 889. Sam Wilson:
# You're going after him?
#
# 890. Steve Rogers:
# You don't have to come with me.
#
# ******** test model 1: line 888 ********
# 8 relations identified
# entities: Natasha Romanoff => Sharon Carter-[u'Sharon']
# relation: Sharon. She's nice. [she kisses Steve on the cheek and turns to walk away] Be careful, Steve. You might not want to pull on that thread. [as Natasha walks away Steve opens the file, which is about Bucky and the information regarding his Winter Soldier transformation, Sam walks over to Steve]
# category: 4. mixed mentioning
# entities: Natasha Romanoff => Steve Wilson-[u'Steve', u'Steve', u'Steve', u'Steve']
# relation: Sharon. She's nice. [she kisses Steve on the cheek and turns to walk away] Be careful, Steve. You might not want to pull on that thread. [as Natasha walks away Steve opens the file, which is about Bucky and the information regarding his Winter Soldier transformation, Sam walks over to Steve]
# category: 4. mixed mentioning
# entities: Natasha Romanoff => Winter Soldier-[u'Bucky', u'Winter Soldier']
# relation: Sharon. She's nice. [she kisses Steve on the cheek and turns to walk away] Be careful, Steve. You might not want to pull on that thread. [as Natasha walks away Steve opens the file, which is about Bucky and the information regarding his Winter Soldier transformation, Sam walks over to Steve]
# category: 4. mixed mentioning
# entities: Natasha Romanoff => Sam Wilson-[u'Sam']
# relation: Sharon. She's nice. [she kisses Steve on the cheek and turns to walk away] Be careful, Steve. You might not want to pull on that thread. [as Natasha walks away Steve opens the file, which is about Bucky and the information regarding his Winter Soldier transformation, Sam walks over to Steve]
# category: 4. mixed mentioning
# entities: Natasha Romanoff => Jasper Sitwell-[u'She', u'she']
# relation: Sharon. She's nice. [she kisses Steve on the cheek and turns to walk away] Be careful, Steve. You might not want to pull on that thread. [as Natasha walks away Steve opens the file, which is about Bucky and the information regarding his Winter Soldier transformation, Sam walks over to Steve]
# category: 4. mixed mentioning
# entities: Natasha Romanoff => Steve Rogers-[u'You']
# relation: Sharon. She's nice. [she kisses Steve on the cheek and turns to walk away] Be careful, Steve. You might not want to pull on that thread. [as Natasha walks away Steve opens the file, which is about Bucky and the information regarding his Winter Soldier transformation, Sam walks over to Steve]
# category: 4. mixed mentioning
# entities: Natasha Romanoff => SHIELD Computer-[u'his']
# relation: Sharon. She's nice. [she kisses Steve on the cheek and turns to walk away] Be careful, Steve. You might not want to pull on that thread. [as Natasha walks away Steve opens the file, which is about Bucky and the information regarding his Winter Soldier transformation, Sam walks over to Steve]
# category: 4. mixed mentioning
# entities: Winter Soldier => Winter Soldier-[u'Bucky', u'Winter Soldier']
# relation: character Winter Soldier has identity of Bucky
# category: 3. identity mentioning
#
# how many are correctly identified? 2
#
# ******** line 268 ********
# 266. Alexander Pierce:
# It depends on your definition.
#
# 267. narrator:
# the meeting ends as Pierce leaves
#
# => 268. Alexander Pierce:
# => I work forty floors away and it takes a hijacking for you to visit?
#
# 269. Nick Fury:
# Well, a nuclear war would do it too.
#
# 270. narrator:
# they shake hands; referring to Pierce's meeting with the World Security Council
#
# ******** test model 1: line 268 ********
# 1 relations identified
# entities: Alexander Pierce => narrator-[u'you']
# relation: I work forty floors away and it takes a hijacking for you to visit?
# category: 1. negative mentioning
#
# how many are correctly identified? 1
#
# ******** line 707 ********
# 705. Maria Hill:
# He's right. [Fury looks at Natasha then Sam]
#
# 706. Sam Wilson:
# Don't look at me. I do what he does, just slower.
#
# => 707. Nick Fury:
# => Well... Looks like you're giving the orders now, Captain. [Steve stands on a bridge and has a flashback to the time he spent with Bucky after Steve's mother's funeral]
#
# 708. Bucky Barnes:
# We looked for you after. My folks wanted to give you a ride from the cemetery. [they walk towards Steve's apartment]
#
# 709. Steve Rogers:
# I know, I'm sorry. I just...kind of wanted to be alone.
#
# ******** test model 1: line 707 ********
# 3 relations identified
# entities: Nick Fury => Steve Wilson-[u'Steve', u'Steve']
# relation: Well... Looks like you're giving the orders now, Captain. [Steve stands on a bridge and has a flashback to the time he spent with Bucky after Steve's mother's funeral]
# category: 4. mixed mentioning
# entities: Nick Fury => Bucky Barnes-[u'Bucky', u'you']
# relation: Well... Looks like you're giving the orders now, Captain. [Steve stands on a bridge and has a flashback to the time he spent with Bucky after Steve's mother's funeral]
# category: 4. mixed mentioning
# entities: Nick Fury => Natasha Romanoff-[u'he']
# relation: Well... Looks like you're giving the orders now, Captain. [Steve stands on a bridge and has a flashback to the time he spent with Bucky after Steve's mother's funeral]
# category: 4. mixed mentioning
#
# how many are correctly identified? 2
#
# ******** line 215 ********
# 213. The Smithsonian Narrator:
# Battle tested, Captain America and his Howling Commandos quickly earned their stripes. Their mission, taking down HYDRA, the Nazi rogue science division.
#
# 214. narrator:
# Steve walks over to the a display of his friend Bucky Barnes
#
# => 215. The Smithsonian Narrator:
# => Best friends since childhood, Bucky Barnes and Steven Rogers were inseparable on both schoolyard and battlefield. Barnes is the only Howling commando to give his life in service of his country.
#
# 216. narrator:
# Steve watches and older looking Peggy Carter being interviewed
#
# 217. Peggy Carter:
# That was a difficult winter. A blizzard had trapped half our battalion behind the German line. Steve...Captain Rogers, he fought his way through a HYDRA blockade that had pinned our allies down for months. He saved over a thousand men, including the man who would...who would become my husband as it turned out. Even after he died, Steve was still changing my life.
#
# ******** test model 1: line 215 ********
# 2 relations identified
# entities: The Smithsonian Narrator => Bucky Barnes-[u'Bucky Barnes']
# relation: Best friends since childhood, Bucky Barnes and Steven Rogers were inseparable on both schoolyard and battlefield. Barnes is the only Howling commando to give his life in service of his country.
# category: 2. positive mentioning
# entities: The Smithsonian Narrator => Steve Rogers-[u'his', u'his']
# relation: Best friends since childhood, Bucky Barnes and Steven Rogers were inseparable on both schoolyard and battlefield. Barnes is the only Howling commando to give his life in service of his country.
# category: 2. positive mentioning
#
# how many are correctly identified? 2
#
# ******** test results ********
# model 1: precision = 0.41 (28/68 correct)

# %%
df_dict['df_6']['relations'] = df_dict['df_6'].apply(lambda x:
                                                     extract_relation_categories(char_list_dict['cList_5'], x), axis=1)
REEval([df_dict['df_6']], 20)
#0.5 20/26
# Out:
# ******** line 607 ********
# 605. Tony Stark:
# Deal? [Tony gives the object to Harley] What's you're name?
#
# 606. Harley Keener:
# Harley. And you're...
#
# => 607. Tony Stark:
# => The mechanic. Tony [Tony looks at Harley for a moment] You know what keeps going through my head? Where's my sandwich? back at Tony's house, which is now surrounded by emergency rescue and news reporters, Pepper stands alone and looks at one of Tony's shattered Iron Man helmets, she notices a red flashing light inside the helmet and as she puts the helmet on she receives the message Tony had left her earlier] Pepper, it's me. I've got a lot of apologies to make and not a lot of time. So first off, I'm so sorry I put you in harm's way. That was selfish and stupid and it won't happen again. [later that night as Pepper drives Maya home]
#
# 608. Pepper Potts:
# Why were you at the house tonight? What was so important that you had to speak to Tony?
#
# 609. Maya Hansen:
# I think that my boss is working for the Mandarin. So if you still want to talk about it, I suggest that we get ourselves someplace safe.
#
# ******** test model 1: line 607 ********
# 1 relations identified
# entities: Pepper => home-None
# relation:  drives Maya
# category: 5. place mentioning
#
# how many are correctly identified? 1
#
# ******** line 416 ********
# 414. Tony Stark:
# Well, yeah. I just mean we were just...just hosting you while I finished up a little work.
#
# 415. Pepper Potts:
# Uh-huh.
#
# => 416. Tony Stark:
# => And yes, I had a quick bite. I didn't know if you were comin' home or if you were having drinks with Aldrich Killian.
#
# 417. narrator:
# Mark 42 suit turns its face toward her, as if to look at her accusingly
#
# 418. Pepper Potts:
# What?
#
# ******** test model 1: line 416 ********
# 1 relations identified
# entities: narrator => home-None
# relation:  comin '
# category: 5. place mentioning
#
# how many are correctly identified? 1
#
# ******** line 135 ********
# 133. Tony Stark:
# [voice over] So why am I telling you this? Because I had just created demons, and I didn't even know it.
#
# 134. narrator:
# we see Tony writing a note 'You know who I am', and leaving it on the bedside table for Maya before leaving; Maya hears the door close
#
# => 135. Tony Stark:
# => [voice over]Yeah, those were the good times. Then I moved on. After a brief soiree in an Afghan cave, I said goodbye to the party scene. Forgot that night in Switzerland. These days I'm a changed man, I'm different now. I'm well...you know who I am.
#
# 136. narrator:
# Present Day, Malibu, California - Tony is in his lab injecting himself with some devices
#
# 137. Jarvis:
# Sir, please may I request just a few hours to calibrate...
#
# ******** test model 1: line 135 ********
# 1 relations identified
# entities: Tony Stark => narrator-[u'you']
# relation: [voice over]Yeah, those were the good times. Then I moved on. After a brief soiree in an Afghan cave, I said goodbye to the party scene. Forgot that night in Switzerland. These days I'm a changed man, I'm different now. I'm well...you know who I am.
# category: 4. mixed mentioning
#
# how many are correctly identified? 0
#
# ******** line 280 ********
# 278. Happy Hogan:
# Okay.
#
# 279. narrator:
# Hogan steps out of Pepper's office and closes the glass door
#
# => 280. Pepper Potts:
# => It's very nice to see you, Killian.
#
# 281. narrator:
# as Hogan waits outside Pepper's office, he sees Aldrich's man sitting in the waiting area
#
# 282. Happy Hogan:
# Hey, guy.
#
# ******** test model 1: line 280 ********
# 1 relations identified
# entities: Pepper Potts => narrator-[u'you']
# relation: It's very nice to see you, Killian.
# category: 2. positive mentioning
#
# how many are correctly identified? 1
#
# ******** line 659 ********
# 657. Brandt:
# Nice watch.
#
# 658. Tony Stark:
# Yeah, limited edition.
#
# => 659. Brandt:
# => Oh, I don't doubt it. [there's a moment's pause] Well, have a good evening. [the woman turns and walks off] [Tony enters the bar and walks up to Mrs. Davis, who's sat at table drinking alone]
#
# 660. Tony Stark:
# Mrs. Davis, mind if I join you?
#
# 661. Mrs. Davis:
# Free country.
#
# ******** test model 1: line 659 ********
# 1 relations identified
# entities: Tony => bar-None
# relation:  enters the
# category: 5. place mentioning
#
# how many are correctly identified? 1
#
# ******** line 77 ********
# 75. Maya Hansen:
# Can you...
#
# 76. Happy Hogan:
# What?
#
# => 77. Maya Hansen:
# => Can you not touch my plant. It's not...she doesn't like it. She prefers...
#
# 78. Tony Stark:
# She's not like the others.
#
# 79. Maya Hansen:
# Interference is better.
#
# ******** test model 1: line 77 ********
# 1 relations identified
# entities: Happy Hogan => plant-None
# relation:  touch my
# category: 5. place mentioning
#
# how many are correctly identified? 0
#
# ******** line 614 ********
# 612. Pepper Potts:
# This boss of yours, does he have a name?
#
# 613. Maya Hansen:
# Yeah, Aldrich Killian. [Pepper looks at her in shock] [we see Aldrich talking on the phone to Savin]
#
# => 614. Savin:
# => Well, we took the house down, sir...
#
# 615. Aldrich Killian:
# Mmhmm.
#
# 616. Savin:
# But there's no sign of a body.
#
# ******** test model 1: line 614 ********
# 1 relations identified
# entities: Savin => house-None
# relation:  took the
# category: 5. place mentioning
#
# how many are correctly identified? 1
#
# ******** line 95 ********
# 93. Tony Stark:
# It's revolutionary.
#
# 94. Maya Hansen:
# Disease prevention...
#
# => 95. Tony Stark:
# => It can change the world.
#
# 96. narrator:
# as Maya and Tony are talking we see her plant, where Hogan had ripped of the leaf and stem, start to regenerate
#
# 97. Maya Hansen:
# Even limb regrowth.
#
# ******** test model 1: line 95 ********
# 1 relations identified
# entities: It => world-None
# relation:  change the
# category: 5. place mentioning
#
# how many are correctly identified? 0
#
# ******** line 126 ********
# 124. Tony Stark:
# Happy New Year.
#
# 125. Maya Hansen:
# Happy New Year.
#
# => 126. Tony Stark:
# => Alright, I'll see you in the mornin'.
#
# 127. narrator:
# Tony shakes hands with Hogan
#
# 128. Happy Hogan:
# You good?
#
# ******** test model 1: line 126 ********
# 1 relations identified
# entities: Tony Stark => narrator-[u'you']
# relation: Alright, I'll see you in the mornin'.
# category: 2. positive mentioning
#
# how many are correctly identified? 0
#
# ******** line 65 ********
# 63. narrator:
# the elevator door closes
#
# 64. Tony Stark:
# Damn betcha. Come on! I thought that was just a theory.
#
# => 65. Maya Hansen:
# => Well, it was. If I'm right, we can access the area of the brain that governs repair.
#
# 66. narrator:
# we see they are looking at a computer monitor with graph of the brain
#
# 67. Tony Stark:
# Wow.
#
# ******** test model 1: line 65 ********
# 1 relations identified
# entities: Maya Hansen => area-None
# relation:  access the
# category: 5. place mentioning
#
# how many are correctly identified? 1
#
# ******** line 483 ********
# 481. Pushy Tabloid Reporter:
# Hey, Mr. Stark! When is somebody gonna kill this guy? Just sayin'. [Tony turns to face the reporter]
#
# 482. Jarvis:
# I've compiled a Mandarin database for you, sir. Drawn from S.H.I.E.L.D., F.B.I., and C.I.A. intercepts. Initiating virtual crime scene reconstruction. [Tony starts looking at all the data gathered]
#
# => 483. Tony Stark:
# => Okay, what do we got here? His name is an ancient Chinese war mantle, meaning "adviser to the King". South American insurgency tactics, talks like a Baptist preacher. There's lots of pageantry going on here...lots of theater. [Tony pushes the virtual information down to close] Close. [Tony looks at the virtual crime scene reconstruction]
#
# 484. Jarvis:
# The heat from the blast was in excess of 3000 degrees Celsius. Any subjects within 12.5 yards were vaporized instantly.
#
# 485. Tony Stark:
# No bomb parts found in a three mile radius of the Chinese theater.
#
# ******** test model 1: line 483 ********
# 2 relations identified
# entities: lots => information-None
# relation:  pushes the virtual
# category: 5. place mentioning
# entities: lots => Close-None
# relation:  pushes the virtual information down to close ]
# category: 5. place mentioning
#
# how many are correctly identified? 0
#
# ******** line 203 ********
# 201. Erin:
# Erin.
#
# 202. narrator:
# Tony looks at the boy standing next to him
#
# => 203. Tony Stark:
# => I loved you in A Christmas Story, by the way.
#
# 204. narrator:
# as Tony is signing Erin's drawing
#
# 205. Colonel James Rhodes:
# Listen, the Pentagon is scared. After what happened in New York... aliens, come on. They need to look strong. Stopping the Mandarin is priority, but it's not...
#
# ******** test model 1: line 203 ********
# 1 relations identified
# entities: Tony Stark => narrator-[u'you']
# relation: I loved you in A Christmas Story, by the way.
# category: 2. positive mentioning
#
# how many are correctly identified? 1
#
# ******** line 312 ********
# 310. Happy Hogan:
# Hello?
#
# 311. Tony Stark:
# Is this forehead of Security?
#
# => 312. Happy Hogan:
# => What? You know, look, I got a real job. What do you want? I'm working, I got something going on here.
#
# 313. narrator:
# we see Tony is in his lab
#
# 314. Tony Stark:
# What? Harassing interns?
#
# ******** test model 1: line 312 ********
# 1 relations identified
# entities: Happy Hogan => narrator-[u'You', u'you']
# relation: What? You know, look, I got a real job. What do you want? I'm working, I got something going on here.
# category: 4. mixed mentioning
#
# how many are correctly identified? 1
#
# ******** line 393 ********
# 391. Pepper Potts:
# Wow. I appreciate the thought very much.
#
# 392. narrator:
# Pepper turns to face Tony, she rises from her seat and stands close to him
#
# => 393. Pepper Potts:
# => So why don't you lift up that face mask and give me a kiss?
#
# 394. narrator:
# Tony knocks the metal helmet on his head
#
# 395. Tony Stark:
# Huh. Yup, dammit. No can do. You wanna just kiss it on the...
#
# ******** test model 1: line 393 ********
# 1 relations identified
# entities: Pepper Potts => narrator-[u'you']
# relation: So why don't you lift up that face mask and give me a kiss?
# category: 1. negative mentioning
#
# how many are correctly identified? 0
#
# ******** line 133 ********
# 131. Tony Stark:
# Okay.
#
# 132. narrator:
# Hogan leaves the room; we then see Aldrich on top of the building waiting for Tony, who never shows
#
# => 133. Tony Stark:
# => [voice over] So why am I telling you this? Because I had just created demons, and I didn't even know it.
#
# 134. narrator:
# we see Tony writing a note 'You know who I am', and leaving it on the bedside table for Maya before leaving; Maya hears the door close
#
# 135. Tony Stark:
# [voice over]Yeah, those were the good times. Then I moved on. After a brief soiree in an Afghan cave, I said goodbye to the party scene. Forgot that night in Switzerland. These days I'm a changed man, I'm different now. I'm well...you know who I am.
#
# ******** test model 1: line 133 ********
# 1 relations identified
# entities: Tony Stark => narrator-[u'you']
# relation: [voice over] So why am I telling you this? Because I had just created demons, and I didn't even know it.
# category: 1. negative mentioning
#
# how many are correctly identified? 0
#
# ******** line 148 ********
# 146. Jarvis:
# Sir, may I remind you that you've been awake for nearly seventy-two hours.
#
# 147. narrator:
# addressing the Iron Man suits that are in their glass cages
#
# => 148. Tony Stark:
# => Focus up, ladies. Good evening, and welcome to the birthing suit. I'm pleased to announce the imminent arrival of your bouncing, bad-ass, baby brother.
#
# 149. narrator:
# to Jarvis as he records Tony with a camera
#
# 150. Tony Stark:
# Start tight and go wide, stamp in time. Mark 42 autonomous prehensile propulsion suit test. Initialize sequence.
#
# ******** test model 1: line 148 ********
# 1 relations identified
# entities: Tony Stark => narrator-[u'your']
# relation: Focus up, ladies. Good evening, and welcome to the birthing suit. I'm pleased to announce the imminent arrival of your bouncing, bad-ass, baby brother.
# category: 2. positive mentioning
#
# how many are correctly identified? 1
#
# ******** line 546 ********
# 544. Pepper Potts:
# I don't like it!
#
# 545. Tony Stark:
# I asked you three... You don't like it?! [as Tony and Pepper are bickering, Maya notices on the TV that helicopters are coming toward Tony's home]
#
# => 546. Pepper Potts:
# => Tony, we are leaving the house; that's not even up for discussion.
#
# 547. Tony Stark:
# I said no.
#
# 548. Maya Hansen:
# Guys, can we um...
#
# ******** test model 1: line 546 ********
# 1 relations identified
# entities: Pepper Potts => house-None
# relation:  leaving the
# category: 5. place mentioning
#
# how many are correctly identified? 1
#
# ******** line 172 ********
# 170. narrator:
# the news on TV shows footage of The Mandarin
#
# 171. Tony Stark:
# [voice over] That's when he happened.
#
# => 172. The Mandarin:
# => Some people call me a terrorist, I consider myself a teacher. America, ready for another lesson. In 1864 in Sand Creek Colorado the U.S. military waited till the friendly Cheyenne braves all gone hunting, waited to attack and slaughter their families left behind, and claim their land. Thirty-nine hours ago the Ali Al Salem Air Base in Kuwait was attacked. I...I...I did that. A quaint military church filled with wives and children, of course. The soldiers were out on maneuver, the braves were away. President Ellis you continue to resist my attempts to educate you, sir. And now, you've missed me again. You know who I am, you don't know where I am, and you'll never see me coming.
#
# 173. narrator:
# as this footage ends, the TV channels change and all the news channels are talking about The Mandarin
#
# 174. narrator:
# the news on TV shows President Ellis addresses The Mandarin Threat
#
# ******** test model 1: line 172 ********
# 6 relations identified
# entities: America => hunting-None
# relation:  braves all gone
# category: 5. place mentioning
# entities: America => that-None
# relation:  did
# category: 5. place mentioning
# entities: America => The Mandarin-None
# relation:  missed
# category: 5. place mentioning
# entities: military church => hunting-None
# relation:  braves all gone
# category: 5. place mentioning
# entities: military church => that-None
# relation:  did
# category: 5. place mentioning
# entities: military church => The Mandarin-None
# relation:  missed
# category: 5. place mentioning
#
# how many are correctly identified? 2
#
# ******** line 686 ********
# 684. Tony Stark:
# Watch this. [Tony smashes into the window of a shop] [as Tony and Brandt are fighting in the shop, Tony starts a fire in shop] You walked right into this one, I've dated hotter chicks than you. [Tony puts Chad's dog tags into the microwave and he turns on the gas]
#
# 685. Brandt:
# That's all you got? Cheap trick and a cheesy one-liner?
#
# => 686. Tony Stark:
# => Sweetheart, that could be the name of my autobiography. [Tony quickly leaves through the back door, as the dog tags heat up in the microwave they start sparking up fire, Brandt realizes the gas has been left on and suddenly the shop explodes killing Brandt] [Tony finds the Savin has grabbed Harley]
#
# 687. Harley Keener:
# Let me go! [Savin mocks Harley]
#
# 688. Savin:
# Help me! Help me! [as Tony's leg is trapped under some rubble, Savin sits in front of him with Harley sat on his lap] Hey kid, what would you like for Christmas?
#
# ******** test model 1: line 686 ********
# 1 relations identified
# entities: shop => Harley-None
# relation:  grabbed
# category: 5. place mentioning
#
# how many are correctly identified? 1
#
# ******** line 143 ********
# 141. Tony Stark:
# Which I will. Right, let's do this.
#
# 142. narrator:
# to the robot that's using a broom to clear the rubbish off the floor
#
# => 143. Tony Stark:
# => Dummy. Hi, Dummy. How did you get that cap on your head? You earned it.
#
# 144. narrator:
# Tony walks towards the robot
#
# 145. Tony Stark:
# Hey. Hey! What are you doing round in the corner? You know what you did. Blood on my mat, handle it.
#
# ******** test model 1: line 143 ********
# 1 relations identified
# entities: Tony Stark => narrator-[u'you', u'your', u'You']
# relation: Dummy. Hi, Dummy. How did you get that cap on your head? You earned it.
# category: 4. mixed mentioning
#
# how many are correctly identified? 0
#
# ******** test results ********
# model 1: precision = 0.50 (13/26 correct)

# %% [markdown]
# ## Putting Everything Together, a Simple Query System <a class="anchor" id="Query"></a>
# [[back to top]](#top)

# %%
def checkQuery(relationList, ent1, ent2, relationClass):
    for relation in relationList:
        if ent1 in relation['ent1'] and ent2 in relation['ent2'] and relationClass == relation['class']:
            return True
    return False

def printAnswer(row):
    print('Movie: {}, Line {}'.format(row.movie, row.lineNum))
    print('{}: {}'.format(row.speaker, row.dialogue))
    print()
    
def queryScore(relationList, query, relationClass):
    querySet = set(query.split(' '))
    resultScore = 0
    
    for relation in relationList:
        relationSet = set()
        if type(relation['ent1']) == str:
            relationSet |= set(relation['ent1'].lower().split())
        else:
            for ent in relation['ent1']:
                #print(set(ent.split()))
                relationSet |= set(ent.lower().split())
            
        if type(relation['ent2']) == str:
            #print(relation['ent2'])
            relationSet |= set(relation['ent2'].lower().split())
        else:
            for ent in relation['ent2']:
                relationSet |= set(ent.lower().split())
        
        relationSet |= set(relation['relation'].lower().split())
        relationSet |= set(relationClass[relation['class']].lower().split())
        tempScore = len(relationSet & querySet) / (len(relationSet) + len(querySet))
        
        if tempScore > resultScore:
            resultScore = tempScore
        
    return resultScore

#Simple Query System

print('Select the movies of your interest:')
print('***Enter all to use all movies')
print('***Enter n, m, x, y (numbers separated by commas) for specific selections')
print('***Enter random, n for n random selections\n')

files = [x for x in os.listdir('prep_scripts') if '_gapi' in x]
for i, fileName in enumerate(files):
    print('{}. {}'.format(i+1, re.split(r'_tw_|_imsdb_', fileName)[0]))


x = input()


#random selection
try:
    if 'random' in x:
        queryFiles = np.random.choice(files, int(x.split(',')[-1]), replace=False)
    elif x != 'all':
        queryFiles = np.array(files)[[int(select) - 1 for select in x.split(',')]]
    #use all files
    else:
        queryFiles = files    
        
except:
    print('\nunexpected input, will use all movie files\n')
    queryFiles = files    

#print(queryFiles)
df_data = None
charSet = set()

for i, fileName in enumerate(queryFiles):    
    df = pd.read_csv('prep_scripts/'+fileName)[['speaker', 'dialogue', 'sentences', 'sentiment', 'entities', 'tokens']]
    df['tokens'] = df['tokens'].apply(lambda x: eval(x))
    df['sentiment'] = df['sentiment'].apply(lambda x: eval(x))
    df['total_sent'] = df['sentiment'].apply(lambda x: x['score'] * x['magnitude'])
    df['entities'] = df['entities'].apply(lambda x: eval(x))
    df['movie'] = re.split(r'_tw_|_imsdb_', fileName)[0]
    df['lineNum'] = df.index + 1
    
    charRange = 10
    nearbyList = np.dstack((df.shift(i).speaker.values for i in range(-charRange, charRange+1)))[0]
    df['nearbyChars'] = None
    for line, nearbyChars in enumerate(nearbyList):
        df.set_value(line, 'nearbyChars', nearbyChars)
    
    cList = list(df.speaker.unique())
    cDict = dict(df.groupby('speaker').total_sent.sum())
    
    #resolve entities
    df.apply(lambda x:pronResolution_nnMod(cList, x), axis=1)
    
    #extract relations
    df['relations'] = df.apply(lambda x:extract_relation_categories(x), axis=1)
    
    if i == 0:
        df_data = df[df.relations.notnull()]        
        
    else:
        df_data = pd.concat((df_data, df[df.relations.notnull()]))
    
    charSet |= set(df.speaker.unique())

relationClasses = getRelations()
    
print('Type end to finish at any time')
print('Choose one of the following:')
print('1. Structured search')
print('2. Free form query')
searchType = int(input()) - 1

#relationList = df_data[df_data.hasRelation == True]['relations'].values

if not searchType:
    
    while True:
        print('Characters: ')
        print(charSet)
        print('\nRelations:')
        for k, v in relationClasses.items():
            print('{}. {}'.format(k+1, v))
        print('What relation are you looking for?')
        ent1 = input('Entity 1:')
        if ent1 == 'end':
            break
        ent2 = input('Entity 2:')
        if ent2 == 'end':
            break
        relationClass = int(input('Relation category: '))-1

        qMatch = df_data.relations.apply(lambda x: checkQuery(x, ent1, ent2, relationClass))
        if sum(qMatch) == 0:
            print('nothing found\n')
        else:
            df_data[qMatch].apply(lambda x: printAnswer(x), axis=1)

else:
    while True:
        query = input('Enter query')
        if query == 'end':
            break
        df = df_data.copy()
        df['queryScore'] = df.relations.apply(lambda x: queryScore(x, query, relationClasses))
        df = df.sort_values(by='queryScore', ascending=False).head().copy()
        df.apply(lambda x: printAnswer(x), axis=1)
